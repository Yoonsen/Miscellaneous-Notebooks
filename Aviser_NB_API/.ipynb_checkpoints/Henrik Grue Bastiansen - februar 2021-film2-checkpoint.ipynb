# %% [markdown]
# Starter med å importere dhlab
#
# Hvis dhlab ikke fins må den installeres

# %% [markdown]
# Når den er installert, er det bare å importere, gjør den klar i notebook

# %%
import dhlab.nbtext as nb

# %% [markdown]
# Da er alle kommandoene i modulen dhlab.nbtext tilgjengelig

# %% [markdown]
# Fyll in parametre

# %%
søkeord = 'film'

# %%
startår = 1960

# %%
sluttår = 1970

# %%
nøkkelord = ["journalist", "redaktør", "journalisten", "readaktøren", 'diktatur', 'arbeid']

# %% [markdown]
# Analyser

# %%
nb.concordance(søkeord, yearfrom = startår, yearto = sluttår, corpus = 'avis', before = 12, after = 12)
# Out:
# <table><tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_dennorskerigstidende_null_null_18470614_33_113_1?searchText=Demokrati' target='_'>dennorskerigstidende-18470614</a></td><td>stemmende Maade . Det liberale Morgenblad har dog vel ikke for lutter</td><td>Demokrati</td><td style='text-align:left'>, for luttet Tråer i Skoven , glemt dette ? Der haves</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_dennorskerigstidende_null_null_18470906_33_197_1?searchText=Demokrati' target='_'>dennorskerigstidende-18470906</a></td><td>gaaende ultra demokratiske Principer . Staten Norge er dem mindre end et</td><td>Demokrati</td><td style='text-align:left'>Norge , som endnu ikke har nogen Retstitel at paaberaabe sig .</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_dennorskerigstidende_null_null_18470531_33_99_1?searchText=Demokrati' target='_'>dennorskerigstidende-18470531</a></td><td>hoeve end bestnrke hinanden , da det ene Parti klager over forlidet</td><td>Demokrati</td><td style='text-align:left'>, det andet over formeget . Havde disse Beklagelser og morke Skildringer</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_dennorskerigstidende_null_null_18471101_33_253_1?searchText=Demokrati' target='_'>dennorskerigstidende-18471101</a></td><td>af Sfiæbnen er det at det yderste Absolutisme og det meest gjennemferte</td><td>Demokrati</td><td style='text-align:left'>i de af Cmop.ver be * derssede Jante , Rusland og Amerika</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_dennorskerigstidende_null_null_18471102_33_254_1?searchText=Demokrati' target='_'>dennorskerigstidende-18471102</a></td><td>en Besvarelse af Sporgsmaalene : om Grunden til at " det norske</td><td>Demokrati</td><td style='text-align:left'>vælger saamange Embedsmcend til Repræsentanter og overlaber til disse at styre og</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_morgenbladet_null_null_18220215_5_46_1?searchText=Demokrati' target='_'>morgenbladet-18220215</a></td><td>som man gjerne vil indbilde sig ' Tvende Garantier har man givet</td><td>Demokrati</td><td style='text-align:left'>? ! . Reprcrsentativregjeringen og Trykkefriheden . Sen fsrste er , uden</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_morgenbladet_null_null_18580411_41_99_1?searchText=Demokrati' target='_'>morgenbladet-18580411</a></td><td>« delsen af en Nedgangsperiode , eller ogsaa man bet ende med</td><td>Demokrati</td><td style='text-align:left'>. Det eienbommelige , af saa hsist forskelligartede Elementer sammensatte en ,</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_morgenbladet_null_null_18580411_41_99_1?searchText=Demokrati' target='_'>morgenbladet-18580411</a></td><td>, at Staten , fet » un » ber bet meest udstrakte</td><td>Demokrati</td><td style='text-align:left'>, kan blive vel bestyret , uagtet Folket selv er udygtigt tit</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_morgenbladet_null_null
td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_nordlyset_null_null_18440329_3_26_1?searchText=Demokrati' target='_'>nordlyset-18440329</a></td><td>vist , er , at der neppe findes et uegennyttigere og taalmobigere</td><td>Demokrati</td><td style='text-align:left'>i Verden , end det norske . ' Uagtet be i Grundloven</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_nordlyset_null_null_18441028_3_86_1?searchText=Demokrati' target='_'>nordlyset-18441028</a></td><td>, til hvad der skulde vcere det Rigtige i det fattige norske</td><td>Demokrati</td><td style='text-align:left'>. Dertil ere da begge Landes baabe materielle Tilstande , historiskt udviklede</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_dennorskerigstidende_null_null_18490526_35_129_1?searchText=Demokrati' target='_'>dennorskerigstidende-18490526</a></td><td>end i bet tydsie Fcedreland . Der vil altid blandt bet fcirenbe</td><td>Demokrati</td><td style='text-align:left'>findes et Krigsparti , som for at qvcele de indre Stridigheder paafore</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis

# %% [markdown]
# Teller opp kontekstord for målordet (her 'avis') med `collocation`

# %%
coll = nb.collocation(søkeord, yearfrom = startår, yearto = sluttår, corpus = 'avis', before = 5, after = 5)

# %% [markdown]
# Kan lage kollokasjon av ord til høyre

# %%
coll_h = nb.collocation(søkeord, yearfrom = startår, yearto = sluttår, corpus = 'avis', before = 0, after = 5)

# %% [markdown]
# Og en for ord til venstre

# %%
coll_v = nb.collocation(søkeord, yearfrom = startår, yearto = sluttår, corpus = 'avis', before = 5, after = 0)

# %%
coll.head(10)
# Out:
#         0
# !       6
# "      31
# &       2
# '       7
# (      10
# )       9
# *       2
# ,     198
# .     100
# 111.    2

# %% [markdown]
# Vi kan sammenligne med en referanse, bruker normalen fra bøker.

# %%
ref = nb.frame(nb.totals(150000))

# %%
ref.head(30)
# Out:
#                0
# .     1265723110
# ,     1105303412
# og     543432056
# i      460246057
# det    273411583
# som    265144740
# til    254500136
# er     248764786
# av     235180661
# en     231631623
# på     205990369
# for    202452659
# at     199527660
# -      195716474
# å      184201667
# med    182427175
# )      172258528
# var    153392365
# ?      151860120
# den    151216998
# (      149848981
# de     140087564
# ikke   137898651
# :      121576250
# han    115410512
# «      110767054
# »      109061643
# har    106345926
# om     105027818
# et     101265956

# %% [markdown]
# Lager en variabel `assoc`for å lagre de viktigste ordene

# %%
assoc = nb.frame_sort(nb.frame(coll[0]/ref[0]))

# %%
assoc.head(10)
# Out:
#                      0
# opdrages      0.001535
# Monarki       0.000960
# Tyranni       0.000319
# proklamerer   0.000281
# Maadc         0.000257
# organiserede  0.000248
# Demokratiet   0.000238
# scc           0.000202
# udannede      0.000197
# foregivne     0.000195

# %% [markdown]
# Da ser vi høyre og venstrekontekst

# %%
assoc_h = nb.frame_sort(nb.frame(coll_h[0]/ref[0]))

# %%
assoc_h.head(10)
# Out:
#                        0
# opdrages        0.001535
# proklamerer     0.000281
# Maadc           0.000257
# Blads           0.000184
# Sif             0.000175
# Handelsbetjent  0.000174
# ftlge           0.000174
# Polk            0.000173
# alr             0.000169
# tilvisse        0.000162

# %% [markdown]
# Her assosiasjoner til høyre

# %%
assoc_v = nb.frame_sort(nb.frame(coll_v[0]/ref[0]))

# %%
assoc_v.head(20)
# Out:
#                        0
# Monarki         0.000800
# organiserede    0.000248
# scc             0.000202
# udannede        0.000197
# foregivne       0.000195
# underfundige    0.000193
# snste           0.000173
# Organisationen  0.000170
# underkue        0.000167
# Tilbagegang     0.000165
# Tyranni         0.000160
# meeft           0.000156
# forstaas        0.000138
# Polsk           0.000138
# Sympathi        0.000137
# Civilisation    0.000136
# Garantier       0.000132
# Manifest        0.000132
# ncrsten         0.000132
# Marseilles      0.000131

# %% [markdown]
# Visualisere med ordskyer eller nettverk

# %%
nb.cloud(assoc.head(50))

# %% [markdown]
# Lager med nøkkelord, og ser på forholdet mellom dem

# %%
assoc.loc[[x for  x in nøkkelord if x in assoc.index]].plot(kind='bar', rot=30)

# %% [markdown]
# Finn totalen, hvor ofte nøkkelordene forekommer

# %%
coll.loc[[x for  x in nøkkelord if x in coll.index]].plot(kind='bar', rot=30)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-65-47ebc7ef13e2> in <module>
# ----> 1 coll.loc[[x for  x in nøkkelord if x in coll.index]].plot(kind='bar', rot=30)
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     263         self._make_plot()
#     264         self._add_table()
# --> 265         self._make_legend()
#     266         self._adorn_subplots()
#     267
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_legend(self)
#     570
#     571             if len(handles) > 0:
# --> 572                 ax.legend(handles, labels, loc="best", title=title)
#     573
#     574         elif self.subplots and self.legend:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in legend(self, *args, **kwargs)
#     404         if len(extra_args):
#     405             raise TypeError('legend only accepts two non-keyword arguments')
# --> 406         self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     407         self.legend_._remove_method = self._remove_legend
#     408         return self.legend_
#
# ~\Anaconda3\lib\site-packages\matplotlib\legend.py in __init__(self, parent, handles, labels, loc, numpoints, markerscale, markerfirst, scatterpoints, scatteryoffsets, prop, fontsize, borderpad, labelspacing, handlelength, handleheight, handletextpad, borderaxespad, columnspacing, ncol, mode, fancybox, shadow, title, title_fontsize, framealpha, edgecolor, facecolor, bbox_to_anchor, bbox_transform, frameon, handler_map)
#     573
#     574         # init with null renderer
# --> 575         self._init_legend_box(handles, labels, markerfirst)
#     576
#     577         # If shadow is activated use framealpha if not
#
# ~\Anaconda3\lib\site-packages\matplotlib\legend.py in _init_legend_box(self, handles, labels, markerfirst)
#     831                 # original artist/handle.
#     832                 handle_list.append(handler.legend_artist(self, orig_handle,
# --> 833                                                          fontsize, handlebox))
#     834                 handles_and_labels.append((handlebox, textbox))
#     835
#
# ~\Anaconda3\lib\site-packages\matplotlib\legend_handler.py in legend_artist(self, legend, orig_handle, fontsize, handlebox)
#     113         artists = self.create_artists(legend, orig_handle,
#     114                                       xdescent, ydescent, width, height,
# --> 115                                       fontsize, handlebox.get_transform())
#     116
#     117         # create_artists will return a list of artists.
#
# ~\Anaconda3\lib\site-packages\matplotlib\legend_handler.py in create_artists(self, legend, orig_handle, xdescent, ydescent, width, height, fontsize, trans)
#     297         p = self._create_patch(legend, orig_handle,
#     298                                xdescent, ydescent, width, height, fontsize)
# --> 299         self.update_prop(p, orig_handle, legend)
#     300         p.set_transform(trans)
#     301         return [p]
#
# ~\Anaconda3\lib\site-packages\matplotlib\legend_handler.py in update_prop(self, legend_handle, orig_handle, legend)
#      70     def update_prop(self, legend_handle, orig_handle, legend):
#      71
# ---> 72         self._update_prop(legend_handle, orig_handle)
#      73
#      74         legend._set_artist_props(legend_handle)
#
# ~\Anaconda3\lib\site-packages\matplotlib\legend_handler.py in _update_prop(self, legend_handle, orig_handle)
#      63             self._default_update_prop(legend_handle, orig_handle)
#      64         else:
# ---> 65             self._update_prop_func(legend_handle, orig_handle)
#      66
#      67     def _default_update_prop(self, legend_handle, orig_handle):
#
# ~\Anaconda3\lib\site-packages\matplotlib\legend_handler.py in update_from_first_child(tgt, src)
#      36
#      37 def update_from_first_child(tgt, src):
# ---> 38     tgt.update_from(src.get_children()[0])
#      39
#      40
#
# IndexError: list index out of range
