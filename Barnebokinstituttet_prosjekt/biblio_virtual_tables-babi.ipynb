# %% [markdown]
# # Studie av tekster
#
# Her for barnebøker

# %%
import json
import sqlite3
import requests
import pandas as pd
import dask
import pandas as pd
import dhlab.module_update as mu
mu.update('mods_meta')
import mods_meta as mm
import dhlab.nbtext as nb
# Out:
# Updated file `C:\Users\larsj\Documents\GitHub\Miscellaneous-Notebooks\Barnebokinstituttet_prosjekt\mods_meta.py`

# %% [markdown]
# # Henter ut data

# %%
barnebøker_fra_2015 = mm.meta_natbib(children=True, yearfrom =2015, limit=1000)

# %%
babi = pd.DataFrame()
step = 300
for i in range(0, len(barnebøker_fra_2015), step):
    print(i)
    df = nb.get_aggregated_corpus([z[1] for z in barnebøker_fra_2015[i:i+step]])
    babi = nb.frame(pd.concat([babi, df], axis=1, sort=False).sum(axis=1))
# Out:
# 0
# 300
# C:\Users\larsj\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# 600

# %%
babi.sum()
# Out:
# 0    23843421.0
# dtype: float64

# %% [markdown]
# Henter ut all tekst

# %%
corpus_text = nb.get_corpus_text([x[1] for x in barnebøker_fra_2015])

# %%
corpus_text
# Out:
#          2019072307036  2018062707194  2018090607043  2018072007025  \
# .                132.0          196.0          309.0          210.0
# /                113.0            5.0           27.0            8.0
# i                 91.0           31.0          109.0           37.0
# \                 87.0            2.0           28.0            4.0
# '                 75.0            1.0           86.0            4.0
# ...                ...            ...            ...            ...
# B-burde            NaN            NaN            NaN            NaN
# Auuue              NaN            NaN            NaN            NaN
# Ajmanda            NaN            NaN            NaN            NaN
# AMANDA             NaN            NaN            NaN            NaN
# 49143              NaN            NaN            NaN            NaN
#
#          2019011448509  2018061207220  2018091207002  2018061807579  \
# .                 46.0         6122.0         5378.0          141.0
# /                 76.0           16.0           24.0           16.0
# i                 53.0         1416.0         2308.0           69.0
# \                 64.0            5.0            NaN           25.0
# '                 45.0           20.0           31.0           67.0
# ...                ...            ...            ...            ...
# B-burde            NaN            NaN            NaN            NaN
# Auuue              NaN            NaN            NaN            NaN
# Ajmanda            NaN            NaN            NaN            NaN
# AMANDA             NaN            NaN            NaN            NaN
# 49143              NaN            NaN            NaN            NaN
#
#          2018062207513  2018103007073  ...  2017111748095  2018091207051  \
# .                787.0          114.0  ...          407.0          630.0
# /                 15.0           43.0  ...           10.0            6.0
# i                222.0           35.0  ...          169.0          141.0
# \                  9.0           19.0  ...           20.0            4.0
# '                 24.0           77.0  ...           18.0            8.0
# ...                ...            ...  ...            ...            ...
# B-burde            NaN            NaN  ...            NaN            NaN
# Auuue              NaN            NaN  ...            NaN            NaN
# Ajmanda            NaN            NaN  ...            NaN            NaN
# AMANDA             NaN            NaN  ...            NaN            NaN
# 49143              NaN            NaN  ...            NaN            NaN
#
#          2018101205008  2018072507146  2018071207097  2019052107021  \
# .               5983.0           95.0         3231.0           45.0
# /                228.0           19.0            1.0            2.0
# i               2278.0           37.0          668.0           24.0
# \                 35.0           15.0            6.0            4.0
# '                123.0           11.0            NaN            5.0
# ...                ...            ...            ...            ...
# B-burde            NaN            NaN            NaN            NaN
# Auuue              NaN            NaN            NaN            NaN
# Ajmanda            NaN            NaN            NaN            NaN
# AMANDA             NaN            NaN            NaN            NaN
# 49143              NaN            NaN            NaN            NaN
#
#          2018072507059  2018060748077  2018071707023  2018101207018
# .               6029.0        16955.0         1564.0         1389.0
# /                 10.0           78.0           52.0           19.0
# i               1238.0         2570.0          503.0          304.0
# \                  3.0           47.0           16.0           26.0
# '                  3.0           66.0           21.0           56.0
# ...                ...            ...            ...            ...
# B-burde            NaN            NaN            NaN            1.0
# Auuue              NaN            NaN            NaN            1.0
# Ajmanda            NaN            NaN            NaN            1.0
# AMANDA             NaN            NaN            NaN            1.0
# 49143              NaN            NaN            NaN            1.0
#
# [488632 rows x 736 columns]

# %% [markdown]
# # Her ser vi på ordlister

# %% [markdown]
# Henter ut ordlister fra Kristin.
#
# fra mail:
# Handikappet/funksjonshemmet
# Blind, svaksynt, tykk, tynn, døv, tunghørt, hørselshemmet, klumpfot, albino
#
# Seksuell legning
# trans, transe, homofil, homse, lesbisk, lesbe, bi, bifil
#
# Egennavn
# Fornavn, etternavn
#
# Nasjonalitet
# Pakistansk, arabisk, afrikansk, grønlender, grønlandsk, islandsk, polsk, russer, russisk, amerikaner, hindu, japaner, asiat
# Finnes det en base som angir nasjonalitet?
#
# Geografisk område
# Norden, Europa, Asia, Amerika, Afrika, Australia, Antarktis, Arktis, Ural
# Finnes det en base over land? Men dette går kanskje under kategorien Egennavn?
#
# Språk – pt kommer jeg på disse, men dersom du har en base med flere språk sier jeg ikke nei til det:
# engelsk, pakistansk, urdu, svensk, dansk, finsk, islandsk, grønlandsk, samisk, fransk, tysk, polsk, litauisk, russisk, italiensk, spansk, castillano, portugisisk, kinesisk, japansk, tamil, arabisk, swahili
#
# Religion
# kristendom, hinduisme, islam, muhammedanisme, taoisme, jødedom, koptisk, katolisisme
#
# Andre kultur-markører
# Urfolk, indianer, araber, afrikaner, amerikaner, europeer, nordisk, samisk

# %%
ordlister = """ 
diff: blind, svaksynt, tykk, tynn, døv, tunghørt, hørselshemmet, klumpfot, albino;
seksualitet: trans, transe, homofil, homse, lesbisk, lesbe, bi, bifil;
nasjonalitet: pakistansk, arabisk, afrikansk, grønlender, grønlandsk, islandsk, polsk, russer, russisk, amerikaner, hindu, japaner, asiat;
geografi: Norden, Europa, Asia, Amerika, Afrika, Australia, Antarktis, Arktis, Ural;
språk: engelsk, pakistansk, urdu, svensk, dansk, finsk, islandsk, grønlandsk, samisk, fransk, tysk, polsk, litauisk, russisk, italiensk, spansk, castillano, portugisisk, kinesisk, japansk, tamil, arabisk, swahili;
religion: kristendom, hinduisme, islam, muhammedanisme, taoisme, jødedom, koptisk, katolisisme;
kulturmarkør: urfolk, indianer, araber, afrikaner, amerikaner, europeer, nordisk, samisk;
"""

# %%
ordgrupper = {x.split(':')[0]:x.split(':')[1].split(', ') for x in [y.strip() for x in ordlister.split('\n') for y in x.split(';') if y.strip() != '']}

# %%
ordgrupper.keys()
# Out:
# dict_keys(['diff', 'seksualitet', 'nasjonalitet', 'geografi', 'språk', 'religion', 'kulturmarkør'])

# %% [markdown]
# # DF og TF

# %%
nb.frame(mm.metadata(list(corpus_text.loc['homo'].dropna().index)))
# Out:
#                            100-1- -a                   245-1-0-a  260- - -c  \
# 2014111907535            Holm, Dagny                    Zeppelin       2007
# 2018051448017            Green, John  Will Grayson, Will Grayson       2015
# 2018060807044            Lyga, Barry                        Game       2015
# 2018060807049  Johnsen, Janne Aasebø                  Kamuflasje       2015
# 2018061807034            Green, John                   Papirbyer       2015
# 2018061807069           Larsson, Åsa                  Nidstangen       2015
# 2018062507069          Taylor, Laini                  Mørk engel       2015
# 2018062607030      Aakeson, Kim Fupz              Jeg er William       2015
# 2018070507023        Sævareid, Heidi                  Slipp hold       2015
# 2018070507099          Oseman, Alice                   Solospill       2015
# 2018070507114        Nielsen, Susin.             Vi er molekyler       2015
# 2018071607133          Marsden, John                    Checkers       2015
# 2018072607141       Strandberg, Mats                    Nøkkelen       2015
# 2018072607233            Green, John  Will Grayson, Will Grayson       2015
# 2018072607271           Scott, Katie         Animalium plakatbok  cop. 2015
# 2018072607298    Hovig, Andrea Bræin             Vanessa Svartmo       2015
# 2018072607320          Gier, Kerstin                    Silber :       2015
# 2018082307078         Hurum, Jørn H.          Havets kjempeøgler       2015
# 2018091207011          Arnold, David                  Mygglandet       2015
# 2018091407049          Nelson, Jandy            Jeg gir deg sola       2015
# 2018101107031       Clare, Cassandra      De fortapte sjelers by       2015
# 2018102207052        Knudsen, Sverre               Aarons hevn :       2015
# 2018112177044         Soltvedt, Thor  Fire minutter på overtid :  cop. 2015
# 2019030177042          Smith, Andrew          Gresshoppejungel :       2015
# 2018060748070                    NaN                         NaN       2015
#
#                                                        653- - -a lang  year  \
# 2014111907535      grunnskolen, k06, lesebøker, lærebøker, norsk  nno  2015
# 2018051448017                                                NaN  nob  2015
# 2018060807044                                                NaN  nob  2015
# 2018060807049  forelskelse, norsk, oppvekst, romaner, ungdoms...  nob  2015
# 2018061807034                                                NaN  nob  2015
# 2018061807069                          barnelitteratur, spenning  nob  2015
# 2018062507069             amerikansk, fantasy, ungdomslitteratur  nob  2015
# 2018062607030                                                NaN  nob  2015
# 2018070507023  kjærlighet, kontroll, makt, skjønnlitteratur, ...  nob  2015
# 2018070507099  blogging, forelskelse, internett, tenåringer, ...  nob  2015
# 2018070507114                                                NaN  nob  2015
# 2018071607133                                                NaN  nob  2015
# 2018072607141                                                NaN  nob  2015
# 2018072607233                     skjønnlitteratur, ungdomsbøker  nob  2015
# 2018072607271                                                NaN  nob  2015
# 2018072607298                                                NaN  nob  2015
# 2018072607320  drømmer, fantasy, romaner, spenning, ungdomsbøker  nob  2015
# 2018082307078  grunnskole, grunnskolen, lærebøker, læreverk, ...  nob  2015
# 2018091207011      amerikansk, oppvekstromaner, skjønnlitteratur  nob  2015
# 2018091407049                              romaner, ungdomsbøker  nob  2015
# 2018101107031                                                NaN  nob  2015
# 2018102207052  fantastisk, fiction, litteratur, norsk, scienc...  nob  2015
# 2018112177044                                                NaN  nob  2015
# 2019030177042                                                NaN  nob  2015
# 2018060748070                                                NaN  nob  2015
#
#                                   245-1-0-b
# 2014111907535                           NaN
# 2018051448017                           NaN
# 2018060807044                           NaN
# 2018060807049                           NaN
# 2018061807034                           NaN
# 2018061807069                           NaN
# 2018062507069                           NaN
# 2018062607030                           NaN
# 2018070507023                           NaN
# 2018070507099                           NaN
# 2018070507114                           NaN
# 2018071607133                           NaN
# 2018072607141                           NaN
# 2018072607233                           NaN
# 2018072607271                           NaN
# 2018072607298                           NaN
# 2018072607320  drømmenes første bok : roman
# 2018082307078                           NaN
# 2018091207011                           NaN
# 2018091407049                           NaN
# 2018101107031                           NaN
# 2018102207052                         roman
# 2018112177044                  ungdomsroman
# 2019030177042                hele historien
# 2018060748070                           NaN

# %%
corpus_text.loc[[w for w in ordgrupper["seksualitet"] if w in corpus_text.index]].count(axis=1)
# Out:
# transe     32
# homofil    16
# homse       8
# lesbisk     8
# lesbe       3
# bi         69
# bifil       3
# dtype: int64

# %%
corpus_text.loc[[w for w in ordgrupper["seksualitet"] if w in corpus_text.index]].sum(axis=1)
# Out:
# transe      56.0
# homofil     74.0
# homse       15.0
# lesbisk     10.0
# lesbe        3.0
# bi         136.0
# bifil        6.0
# dtype: float64

# %%
barnebøker_fra_2015
# Out:
# [[991516586094702201, 2019072307036],
#  [991443196834702201, 2018062707194],
#  [991516620704702201, 2018090607043],
#  [991515969724702201, 2018072007025],
#  [991443581404702201, 2019011448509],
#  [991510238594702201, 2018061207220],
#  [991513888144702201, 2018091207002],
#  [991508408884702201, 2018061807579],
#  [991511923164702201, 2018062207513],
#  [991510239994702201, 2018103007073],
#  [991443981094702201, 2018060807125],
#  [991444135824702201, 2018081407101],
#  [991509372374702201, 2018090507127],
#  [991515496644702201, 2018120777019],
#  [991508606844702201, 2018070307076],
#  [991443899404702201, 2018091207018],
#  [991443044904702201, 2018072507075],
#  [991506495924702201, 2018070307085],
#  [991443193814702201, 2018070507032],
#  [991443583444702201, 2018060748061],
#  [991512310874702201, 2018072507199],
#  [991516046144702201, 2018062607590],
#  [991442951484702201, 2018072607264],
#  [991505316134702201, 2018071907044],
#  [991510960824702201, 2018060748078],
#  [991518327814702201, 2018082207045],
#  [991443902054702201, 2018072507201],
#  [991443902724702201, 2018102307054],
#  [991511919644702201, 2018061807652],
#  [991504927074702201, 2018071807142],
#  [991443980104702201, 2018072507196],
#  [991444134774702201, 2018102207047],
#  [991517423324702201, 2018072007192],
#  [991443814944702201, 2018101007364],
#  [991514074014702201, 2018101007059],
#  [991508408454702201, 2018071707037],
#  [991514922984702201, 2018070507073],
#  [991509844994702201, 2018072307178],
#  [991511553304702201, 2019081477002],
#  [991443643104702201, 2018112177019],
#  [991509489134702201, 2018020248128],
#  [991512444724702201, 2019052007131],
#  [991510002124702201, 2018050348007],
#  [991508399524702201, 2018091907040],
#  [991514817684702201, 2019022877013],
#  [991501641224702201, 2018022048009],
#  [991443583874702201, 2018120777022],
#  [991443582044702201, 2018071707590],
#  [991515496994702201, 2018051448601],
#  [991443044494702201, 2018061807053],
#  [991511922004702201, 2018101007288],
#  [991444705354702201, 2018041648021],
#  [991508413294702201, 2018091207024],
#  [991443821484702201, 2018060807161],
#  [991443045464702201, 2018072507154],
#  [991506483594702201, 2018101207013],
#  [991513047854702201, 2018061207541],
#  [991444130604702201, 2015091006005],
#  [991518343184702201, 2018101107164],
#  [991506714664702201, 2019011448562],
#  [991509846504702201, 2018060748062],
#  [991443980604702201, 2018072507066],
#  [991516314764702201, 2018103007068],
#  [991514458694702201, 2018020248165],
#  [991444132804702201, 2019011448533],
#  [991443642984702201, 2018091205018],
#  [991518284584702201, 2018072407012],
#  [991438161444702201, 2018081407168],
#  [991513145434702201, 2019052007132],
#  [991443195514702201, 2018072507218],
#  [991441748634702201, 2018061107006],
#  [991443820404702201, 2018072607080],
#  [991518142364702201, 2018072607165],
#  [991508407804702201, 2018072007095],
#  [991505082714702201, 2018061207002],
#  [991501278804702201, 2018061207083],
#  [991508498184702201, 2018072007005],
#  [991514603104702201, 2018072607312],
#  [991508496484702201, 2018061807582],
#  [991444132994702201, 2018072507027],
#  [991516740944702201, 2019072307095],
#  [991514921824702201, 2018092507030],
#  [991514377184702201, 2018072607073],
#  [991442951724702201, 2018062807021],
#  [991443196404702201, 2019052007002],
#  [991508400474702201, 2018110607143],
#  [991507498644702201, 2018060548201],
#  [991509848204702201, 2018061207509],
#  [991516738104702201, 2018061407507],
#  [991443044814702201, 2018072607323],
#  [991508399604702201, 2018071907158],
#  [991443822374702201, 2018072507079],
#  [991514296004702201, 2019052107022],
#  [991515969644702201, 2018072607271],
#  [991508700784702201, 2018072607189],
#  [991509851344702201, 2018070507002],
#  [991509848474702201, 2019021477022],
#  [991443197304702201, 2018060807101],
#  [991443192254702201, 2018061807069],
#  [991320021594702201, 2019022777030],
#  [991515276364702201, 2018042348546],
#  [991512880204702201, 2015092158048],
#  [991515171934702201, 2018071807038],
#  [991443815084702201, 2019032277117],
#  [991512779314702201, 2018061207160],
#  [991508398394702201, 2018081407076],
#  [991443583524702201, 2018060807168],
#  [991511679314702201, 2018021248060],
#  [991518329004702201, 2018082207048],
#  [991504840894702201, 2018061807084],
#  [991504418194702201, 2018061807565],
#  [991504418354702201, 2018061807596],
#  [991443902134702201, 2018102207015],
#  [991515472384702201, 2019061977006],
#  [991443815164702201, 2018072407144],
#  [991443581314702201, 2018081407169],
#  [991504640614702201, 2018110607190],
#  [991516739424702201, 2018061407505],
#  [991518329784702201, 2018090607108],
#  [991511738934702201, 2018081407146],
#  [991504836434702201, 2018072507217],
#  [991508401104702201, 2018060807164],
#  [991506127454702201, 2018062807091],
#  [991514071184702201, 2018072607302],
#  [991515906644702201, 2018050448258],
#  [991515188074702201, 2018071707626],
#  [991500511584702201, 2018072607319],
#  [991506785764702201, 2018083107104],
#  [991506728024702201, 2018090607085],
#  [991515172584702201, 2018090607071],
#  [991442952704702201, 2019082977040],
#  [991509488914702201, 2018020248130],
#  [991508247344702201, 2018072507195],
#  [991443194114702201, 2018092507014],
#  [991516101934702201, 2018090407003],
#  [991441750104702201, 2018061107005],
#  [991515496054702201, 2018061807593],
#  [991509848394702201, 2019021477023],
#  [991508400634702201, 2018120777091],
#  [991441749954702201, 2018061107015],
#  [991443191604702201, 2018101677002],
#  [991513175264702201, 2018013048317],
#  [991500773784702201, 2015091506131],
#  [991506263204702201, 2018062807087],
#  [991516284164702201, 2018032348091],
#  [991512299024702201, 2018081407067],
#  [991443579334702201, 2018061207016],
#  [991508412994702201, 2018120777029],
#  [991508399794702201, 2018110677076],
#  [991517459004702201, 2018072607287],
#  [991443980794702201, 2018082207055],
#  [991516731524702201, 2018061407502],
#  [991504414874702201, 2019062777016],
#  [991443901914702201, 2018061907620],
#  [991510002394702201, 2018071907161],
#  [991443197214702201, 2019052107116],
#  [991441748394702201, 2018061107020],
#  [991508413964702201, 2018102307030],
#  [991518340674702201, 2018082207046],
#  [991508561134702201, 2018030548092],
#  [991501876374702201, 2018061107044],
#  [991443813704702201, 2018081307037],
#  [991427955854702201, 2018081407170],
#  [991516739264702201, 2018072307009],
#  [991518223014702201, 2018050448238],
#  [991511712034702201, 2018081407107],
#  [991444130514702201, 2015091506024],
#  [991511325694702201, 2018072507251],
#  [991514330384702201, 2018061107093],
#  [991508496724702201, 2018103007191],
#  [991508409694702201, 2018072607074],
#  [991443045544702201, 2018072507153],
#  [991505767814702201, 2018072507082],
#  [991516632974702201, 2018060807163],
#  [991514525554702201, 2018101007316],
#  [991515481614702201, 2018061807641],
#  [991421496914702201, 2018103007055],
#  [991515495914702201, 2018072607311],
#  [991441748554702201, 2018061107009],
#  [991443821134702201, 2019062777086],
#  [991508498774702201, 2018072507194],
#  [991443817704702201, 2018101107042],
#  [991443901834702201, 2019032277143],
#  [991443199504702201, 2019091977032],
#  [991508413374702201, 2018060807049],
#  [991515449134702201, 2018071907162],
#  [991518342704702201, 2018071707132],
#  [991516046064702201, 2018020248200],
#  [991518328034702201, 2018082207042],
#  [991512687624702201, 2018101007120],
#  [991515497024702201, 2018091705027],
#  [991443813974702201, 2018061807630],
#  [991516314414702201, 2019032277165],
#  [991443198534702201, 2018091407042],
#  [991444130944702201, 2018060807166],
#  [991444136204702201, 2018032348058],
#  [991443814274702201, 2018060807165],
#  [991443579414702201, 2018061107094],
#  [991510002804702201, 2018100488501],
#  [991509849954702201, 2018061207595],
#  [991505267764702201, 2018062707213],
#  [991513324284702201, 2018103007280],
#  [991500852224702201, 2015091506022],
#  [991441749104702201, 2018061107014],
#  [991516950754702201, 2018081407035],
#  [991504927314702201, 2018090607077],
#  [991509847584702201, 2019011448531],
#  [991506264364702201, 2018062607029],
#  [991509319484702201, 2018071707090],
#  [991442611464702201, 2019072407155],
#  [991517719524702201, 2019040977258],
#  [991443814784702201, 2018090607045],
#  [991512362914702201, 2018072607099],
#  [991511712464702201, 2018082007015],
#  [991514398934702201, 2019011448506],
#  [991443194384702201, 2018060807146],
#  [991503140944702201, 2018072507156],
#  [991508497374702201, 2019101577025],
#  [991443582984702201, 2018061807560],
#  [991442950084702201, 2018102307113],
#  [991443579254702201, 2018061807523],
#  [991442950754702201, 2018102307120],
#  [991518151514702201, 2018072407017],
#  [991444134694702201, 2018062807108],
#  [991518327734702201, 2018082207041],
#  [991508699754702201, 2019032277148],
#  [991511912554702201, 2018071607094],
#  [991443816134702201, 2019030177042],
#  [991509420874702201, 2018081407102],
#  [991508414854702201, 2018060807148],
#  [991500813324702201, 2018102505077],
#  [991443819234702201, 2018050348020],
#  [991500734104702201, 2018071707123],
#  [991426861904702201, 2018061807583],
#  [991506128184702201, 2018072507198],
#  [991441749604702201, 2018061107013],
#  [991508405514702201, 2019011448529],
#  [991500773864702201, 2015091006004],
#  [991510226584702201, 2018101007190],
#  [991508408614702201, 2018061107092],
#  [991509844484702201, 2018061107023],
#  [991510239644702201, 2018061807050],
#  [991506239684702201, 2018101107103],
#  [991443195274702201, 2018061207019],
#  [991508412804702201, 2018062707051],
#  [991518330014702201, 2018082307078],
#  [991504858674702201, 2018061807085],
#  [991421049494702201, 2018062807112],
#  [991511991914702201, 2018020148157],
#  [991443199004702201, 2018061807584],
#  [991443198964702201, 2018060748079],
#  [991443817964702201, 2018050448035],
#  [991443195194702201, 2018061207186],
#  [991443581824702201, 2018072507132],
#  [991510002204702201, 2019011448534],
#  [991441841334702201, 2018081407161],
#  [991507806804702201, 2018030648100],
#  [991443816214702201, 2019061977014],
#  [991516740434702201, 2018072507165],
#  [991500773944702201, 2015091506023],
#  [991507490404702201, 2018101107114],
#  [991508187504702201, 2018030548002],
#  [991514403604702201, 2018072507253],
#  [991511679744702201, 2018082207011],
#  [991516737994702201, 2019052007115],
#  [991509849874702201, 2018072507144],
#  [991508700004702201, 2018060748076],
#  [991515186614702201, 2018103007239],
#  [991518026104702201, 2018020148076],
#  [991503377954702201, 2018062905028],
#  [991514438664702201, 2018081407150],
#  [991504602954702201, 2019052107016],
#  [991442951564702201, 2019062777075],
#  [991443192764702201, 2018060807151],
#  [991503147604702201, 2018061807065],
#  [991500683874702201, 2018061207155],
#  [991508700274702201, 2018101107049],
#  [991512392824702201, 2018060148120],
#  [991518080904702201, 2018082748001],
#  [991510240064702201, 2018041948072],
#  [991513145604702201, 2018081307044],
#  [991441748204702201, 2018061107016],
#  [991509998604702201, 2018091407051],
#  [991443582804702201, 2018072507086],
#  [991516158294702201, 2019020807503],
#  [991515496804702201, 2018071707526],
#  [991444398324702201, 2018061207517],
#  [991508400394702201, 2019081477049],
#  [991512107054702201, 2018062607026],
#  [991508699674702201, 2018020848059],
#  [991517421894702201, 2019072407153],
#  [991508411164702201, 2018061907571],
#  [991500773434702201, 2015091006002],
#  [991444137104702201, 2018062707298],
#  [991513145354702201, 2018071207150],
#  [991443192844702201, 2018071807048],
#  [991500734294702201, 2018062607124],
#  [991443045624702201, 2018060807142],
#  [991500800184702201, 2019072307060],
#  [991506263474702201, 2018061207017],
#  [991512688274702201, 2018110607058],
#  [991518328704702201, 2018082207044],
#  [991443903534702201, 2018081407167],
#  [991516105764702201, 2018060807051],
#  [991511840974702201, 2018082207002],
#  [991500299854702201, 2018062607117],
#  [991518341054702201, 2018082207086],
#  [991509999764702201, 2018101107110],
#  [991515711634702201, 2018020948005],
#  [991443980444702201, 2018101007205],
#  [991506131804702201, 2019040977225],
#  [991441748984702201, 2018061107018],
#  [991501351144702201, 2018062705141],
#  [991518341484702201, 2018082207090],
#  [991518221314702201, 2018081607070],
#  [991510958504702201, 2018072507129],
#  [991443816304702201, 2018103007076],
#  [991518329514702201, 2018072507172],
#  [991514767134702201, 2018061207544],
#  [991443191954702201, 2018072507211],
#  [991509849604702201, 2018072607178],
#  [991515811424702201, 2018020548069],
#  [991501876614702201, 2018051648060],
#  [991508410434702201, 2018020248164],
#  [991443194974702201, 2019032277171],
#  [991443902214702201, 2018101107031],
#  [991443814004702201, 2018072307008],
#  [991512861164702201, 2019011448517],
#  [991511381504702201, 2018030248032],
#  [991509999334702201, 2018061807068],
#  [991443581234702201, 2018072607310],
#  [991516621774702201, 2018061207048],
#  [991509850454702201, 2019022777029],
#  [991441748804702201, 2018061107012],
#  [991443199424702201, 2018062507013],
#  [991511262164702201, 2018061207516],
#  [991508409504702201, 2018081407099],
#  [991517952904702201, 2018062807019],
#  [991516737304702201, 2018061907615],
#  [991518174564702201, 2019011448520],
#  [991443579504702201, 2019011448514],
#  [991505052134702201, 2018061207518],
#  [991509999414702201, 2018072607143],
#  [991501167644702201, 2018071807144],
#  [991510002554702201, 2018061807020],
#  [991443816484702201, 2018070507114],
#  [991508498424702201, 2018072507080],
#  [991504360764702201, 2018071707046],
#  [991518285044702201, 2018070405041],
#  [991506086754702201, 2018060807149],
#  [991444131404702201, 2018101107029],
#  [991515360824702201, 2018082207001],
#  [991443582554702201, 2018110607048],
#  [991517090844702201, 2018040948111],
#  [991443193224702201, 2018060807044],
#  [991500852304702201, 2015090906138],
#  [991510001154702201, 2018051448017],
#  [991511679584702201, 2018061807573],
#  [991508399284702201, 2018061807567],
#  [991518343344702201, 2018082207047],
#  [991514403104702201, 2018072607121],
#  [991434236574702201, 2018072507145],
#  [991515496484702201, 2018072607072],
#  [991443196594702201, 2018091907057],
#  [991508644774702201, 2018062207516],
#  [991507454354702201, 2019102877022],
#  [991505054184702201, 2018071607137],
#  [991515934934702201, 2018092707054],
#  [991442950914702201, 2018052948030],
#  [991443581904702201, 2018072607081],
#  [991514728744702201, 2019011448516],
#  [991514377264702201, 2019052107177],
#  [991507554304702201, 2019082977037],
#  [991513859984702201, 2018071707602],
#  [991503147794702201, 2018101007175],
#  [991444131594702201, 2018060748060],
#  [991420963854702201, 2018072607220],
#  [991508406594702201, 2018061807581],
#  [991501263444702201, 2018070307047],
#  [991508400714702201, 2018062707252],
#  [991508498694702201, 2018072607167],
#  [991511832794702201, 2018071707031],
#  [991443818184702201, 2018091205064],
#  [991510002634702201, 2019011448525],
#  [991506262904702201, 2018072007092],
#  [991506726914702201, 2018071807318],
#  [991443196164702201, 2018091407057],
#  [991441748124702201, 2018072307192],
#  [991508700434702201, 2018061807080],
#  [991507575734702201, 2018041748224],
#  [991509848634702201, 2018031248072],
#  [991514398774702201, 2019011448575],
#  [991505376704702201, 2018020548041],
#  [991421493304702201, 2018071607089],
#  [991513279124702201, 2018062607050],
#  [991443815834702201, 2018060807068],
#  [991506377304702201, 2019011448511],
#  [991514277394702201, 2018062207514],
#  [991514762254702201, 2018061207040],
#  [991515186534702201, 2018100488504],
#  [991511261944702201, 2018112177044],
#  [991444136474702201, 2018030548012],
#  [991508414934702201, 2018062807048],
#  [991513888574702201, 2018081607054],
#  [991508440774702201, 2018092507013],
#  [991443197054702201, 2019012877001],
#  [991507399404702201, 2018110607129],
#  [991508410784702201, 2019052107138],
#  [991513076874702201, 2018061807516],
#  [991516435204702201, 2018110607223],
#  [991442952964702201, 2018072607320],
#  [991506712024702201, 2018072007166],
#  [991501577974702201, 2018071907004],
#  [991509362494702201, 2018013048046],
#  [991504683004702201, 2018062607615],
#  [991515511114702201, 2018052348076],
#  [991515969994702201, 2018101007087],
#  [991509846264702201, 2018071207094],
#  [991506869514702201, 2018061807086],
#  [991443818694702201, 2018061107021],
#  [991516735274702201, 2019072307123],
#  [991506786224702201, 2018072607101],
#  [991507441454702201, 2018071807321],
#  [991512364294702201, 2018061807577],
#  [991503059314702201, 2018072607086],
#  [991515327104702201, 2018061807021],
#  [991504421654702201, 2018061207003],
#  [991443899914702201, 2018061107516],
#  [991512698824702201, 2018071707024],
#  [991444133454702201, 2018072607088],
#  [991443579684702201, 2018061207004],
#  [991512396574702201, 2018082007012],
#  [991506460034702201, 2018070307078],
#  [991515813204702201, 2018053048035],
#  [991518342454702201, 2018082207053],
#  [991443578954702201, 2018101007127],
#  [991502798094702201, 2018071707589],
#  [991514582274702201, 2018061807531],
#  [991508364064702201, 2018050748043],
#  [991510000504702201, 2018060807170],
#  [991513317744702201, 2018051448241],
#  [991515116914702201, 2019072307093],
#  [991506142334702201, 2018071707621],
#  [991508407054702201, 2018061107082],
#  [991505010644702201, 2018090507131],
#  [991512637014702201, 2018062707003],
#  [991508403494702201, 2018072607078],
#  [991512018384702201, 2017121908077],
#  [991516028594702201, 2019072307244],
#  [991510001074702201, 2018072507204],
#  [991509850374702201, 2018061807019],
#  [991441749444702201, 2018071607091],
#  [991514517614702201, 2018101007168],
#  [991514402984702201, 2018072607119],
#  [991514399074702201, 2019011448536],
#  [991443822294702201, 2018081307045],
#  [991508699834702201, 2018101107020],
#  [991516734204702201, 2018061907613],
#  [991506339634702201, 2018092507061],
#  [991514527254702201, 2017112148522],
#  [991511382654702201, 2018061807082],
#  [991513871504702201, 2018073048215],
#  [991503425944702201, 2018061207020],
#  [991513166274702201, 2018051448093],
#  [990709806084702201, 2014111907535],
#  [991514377004702201, 2019062507125],
#  [991515732394702201, 2018072007193],
#  [991509846774702201, 2018060807147],
#  [991516741164702201, 2018101007404],
#  [991516734384702201, 2018061407508],
#  [991506262314702201, 2018111205052],
#  [991443045114702201, 2018061807578],
#  [991516731954702201, 2018061407510],
#  [991508406914702201, 2019051407004],
#  [991442949904702201, 2018101007238],
#  [991508644854702201, 2018071207031],
#  [991515276014702201, 2018013148155],
#  [991508701244702201, 2018101007343],
#  [991514297404702201, 2018091805035],
#  [991510000934702201, 2018070507056],
#  [991515626284702201, 2018072307050],
#  [991516346294702201, 2019011448566],
#  [991509848124702201, 2019011448552],
#  [991511867904702201, 2018072007158],
#  [991443191794702201, 2018061807024],
#  [991510263274702201, 2018081407135],
#  [991509851264702201, 2018062607030],
#  [991511920224702201, 2018072507252],
#  [991507633604702201, 2019062507014],
#  [991507661574702201, 2018081407036],
#  [991508400124702201, 2018050748567],
#  [991443582474702201, 2018020148018],
#  [991501365604702201, 2018103007200],
#  [991515700514702201, 2018071807161],
#  [991508700354702201, 2019011577020],
#  [991443583284702201, 2018120777084],
#  [991443821214702201, 2018071807261],
#  [991511380874702201, 2018091907032],
#  [991443045384702201, 2018072607298],
#  [991517571864702201, 2018092507081],
#  [991508413534702201, 2018070507005],
#  [991511714834702201, 2018072007189],
#  [991443191874702201, 2018102207052],
#  [991443900944702201, 2018103077004],
#  [991515583704702201, 2018103007345],
#  [991509999924702201, 2018101007056],
#  [991512018624702201, 2018071807138],
#  [991511729514702201, 2018070405001],
#  [991511324104702201, 2018072507254],
#  [991441747904702201, 2018061107004],
#  [991518328544702201, 2018082207043],
#  [991504699504702201, 2018071907026],
#  [991506869604702201, 2018071807295],
#  [991442612194702201, 2019072407152],
#  [991517403724702201, 2018061807022],
#  [991443193734702201, 2018081607055],
#  [991509844564702201, 2018070507008],
#  [991510000264702201, 2018091207011],
#  [991515385904702201, 2018042048091],
#  [991441749014702201, 2018091907039],
#  [991516646174702201, 2019082977035],
#  [991510000694702201, 2018060748070],
#  [991509999684702201, 2018072507250],
#  [991509438654702201, 2018071607133],
#  [991441749794702201, 2018081407037],
#  [991443817454702201, 2017121808074],
#  [991444131164702201, 2018072507087],
#  [991443582394702201, 2018091907093],
#  [991509864404702201, 2018091805101],
#  [991443818774702201, 2018060807150],
#  [991514526794702201, 2017112148519],
#  [991501577894702201, 2018050748285],
#  [991516621004702201, 2018061107068],
#  [991443818004702201, 2018060748085],
#  [991505870234702201, 2018101107109],
#  [991508398474702201, 2018101007396],
#  [991512305284702201, 2018073148072],
#  [991514715414702201, 2018090707067],
#  [991516633514702201, 2018060807173],
#  [990714097004702201, 2011062708095],
#  [991516739774702201, 2018061407504],
#  [991506339554702201, 2018020848041],
#  [991421245914702201, 2018071707598],
#  [991512016684702201, 2018031248066],
#  [991511755434702201, 2018060748090],
#  [991508407134702201, 2018103007299],
#  [991500773604702201, 2015091506021],
#  [991443043684702201, 2018072607233],
#  [991443903884702201, 2019011448521],
#  [991515712524702201, 2018081407123],
#  [991501365794702201, 2019052107170],
#  [991420963774702201, 2018102307108],
#  [991506126564702201, 2018060807141],
#  [991443199184702201, 2018072607262],
#  [991515261764702201, 2018103007024],
#  [991514772484702201, 2018081407121],
#  [991442942904702201, 2018090607026],
#  [991508497454702201, 2018103077006],
#  [991443820594702201, 2018070507023],
#  [991516732684702201, 2018061407517],
#  [991507453704702201, 2018050748080],
#  [991511679404702201, 2018082007036],
#  [991508416044702201, 2018081607080],
#  [991508409934702201, 2018071807208],
#  [991514528654702201, 2017112348581],
#  [991509999254702201, 2018072507085],
#  [991509850104702201, 2018071607045],
#  [991516737724702201, 2018061907614],
#  [991508399104702201, 2018062807068],
#  [991505767654702201, 2018061207204],
#  [991444131324702201, 2019062777081],
#  [991509999504702201, 2018091907063],
#  [991441750614702201, 2018061107011],
#  [991508400984702201, 2018070507097],
#  [991515276284702201, 2019052107102],
#  [991443199344702201, 2018071907159],
#  [991508667804702201, 2018081407031],
#  [991512304984702201, 2017112048523],
#  [991444298104702201, 2018031248157],
#  [991515327374702201, 2018061807524],
#  [991500852494702201, 2018060807058],
#  [991506869434702201, 2018061807088],
#  [991508731824702201, 2018061807629],
#  [991511262084702201, 2019052107171],
#  [991504833924702201, 2018072507216],
#  [991443821644702201, 2018090407030],
#  [991505328144702201, 2018073148001],
#  [991516739694702201, 2018061407506],
#  [991511380604702201, 2019052007126],
#  [991508411244702201, 2018072607198],
#  [991514402804702201, 2018072607120],
#  [991441749524702201, 2018072507182],
#  [991443817614702201, 2018072407083],
#  [991507418984702201, 2018050748307],
#  [991518309324702201, 2018092807029],
#  [991503141324702201, 2018072507155],
#  [991515717914702201, 2018050448237],
#  [991516529704702201, 2018050748007],
#  [991508496994702201, 2018072507197],
#  [991443043254702201, 2018071907014],
#  [991515276104702201, 2018062207512],
#  [991511617634702201, 2018061807034],
#  [991508410944702201, 2018072507151],
#  [991509371484702201, 2018091705079],
#  [991506257824702201, 2018061807585],
#  [991443583794702201, 2018050748283],
#  [991444135664702201, 2018101007358],
#  [991443198884702201, 2018091205038],
#  [991508475564702201, 2018062507069],
#  [991517403644702201, 2019011448515],
#  [991443901084702201, 2018071807267],
#  [991516737134702201, 2018101007052],
#  [991512496604702201, 2018092707049],
#  [991444705194702201, 2018072607033],
#  [991444136714702201, 2018112377040],
#  [991511639524702201, 2018050748058],
#  [991443580004702201, 2019022777017],
#  [991443643444702201, 2018103007083],
#  [991518328384702201, 2018082207049],
#  [991441747824702201, 2018061107007],
#  [991513129404702201, 2018101007162],
#  [991444705784702201, 2018071207014],
#  [991511679664702201, 2018082007037],
#  [991511325344702201, 2018071207044],
#  [991507419284702201, 2018050748306],
#  [991508410194702201, 2018061207508],
#  [991517898514702201, 2019012577012],
#  [991511721454702201, 2019011577029],
#  [991508405864702201, 2018061807580],
#  [991515781254702201, 2018042348631],
#  [991444131084702201, 2018061207035],
#  [991441750024702201, 2018061107010],
#  [991507213824702201, 2018083107101],
#  [991443583364702201, 2018091707005],
#  [991442949664702201, 2018061207546],
#  [991443197564702201, 2018072607110],
#  [991511920654702201, 2018072748032],
#  [991508406404702201, 2018101007148],
#  [991509358384702201, 2018081407144],
#  [991509846694702201, 2018050748568],
#  [991516732094702201, 2018061407501],
#  [991514729124702201, 2018101107218],
#  [991508415904702201, 2018081607079],
#  [991512802404702201, 2018090507138],
#  [991508700864702201, 2019082977071],
#  [991510239214702201, 2018070507099],
#  [991443821054702201, 2018061207046],
#  [991443583104702201, 2018090407141],
#  [991500773514702201, 2015091006003],
#  [991510000344702201, 2018062507072],
#  [991443901594702201, 2018061207023],
#  [991504683264702201, 2018062607616],
#  [991516731874702201, 2018061407503],
#  [991504416574702201, 2018081307043],
#  [991515448244702201, 2018072607308],
#  [991443902484702201, 2018072507065],
#  [991508409774702201, 2018061207007],
#  [991516731104702201, 2018062607041],
#  [991427956234702201, 2018081407171],
#  [991515935664702201, 2018082007029],
#  [991514277204702201, 2019011448532],
#  [991507452734702201, 2018072607022],
#  [991517504914702201, 2018061807572],
#  [991510238674702201, 2019062777024],
#  [991514398694702201, 2019011448576],
#  [991443815324702201, 2018081407160],
#  [991509848554702201, 2018081407155],
#  [991514524154702201, 2018101107094],
#  [991516950674702201, 2018061807546],
#  [991443899834702201, 2018062507081],
#  [991422236974702201, 2018081407103],
#  [991444136634702201, 2018072507152],
#  [991516732414702201, 2018061407516],
#  [991441748714702201, 2018061107019],
#  [991512174834702201, 2018061907511],
#  [991516616184702201, 2018070507046],
#  [991443193654702201, 2018060807160],
#  [991443581664702201, 2018072607079],
#  [991508497534702201, 2018110607212],
#  [991443045034702201, 2018060748068],
#  [991510238754702201, 2018013048165],
#  [991509421414702201, 2018081407066],
#  [991508413454702201, 2018060807050],
#  [991443193304702201, 2019072307202],
#  [991509998874702201, 2018100807072],
#  [991506786064702201, 2018072607193],
#  [991508497884702201, 2019062777117],
#  [991518244284702201, 2018071807113],
#  [991441749874702201, 2018061107008],
#  [991514496004702201, 2018053048078],
#  [991509318914702201, 2019072307096],
#  [991443194704702201, 2018061807055],
#  [991511115964702201, 2019072407161],
#  [991444135744702201, 2018061207548],
#  [991511835034702201, 2018101207012],
#  [991504727574702201, 2018091107080],
#  [991421245834702201, 2018020148095],
#  [991516188444702201, 2018071807155],
#  [991508699914702201, 2018060748080],
#  [991508409424702201, 2018081407100],
#  [991518367284702201, 2019091977020],
#  [991509851004702201, 2018061807012],
#  [991443642714702201, 2018072607234],
#  [991517173204702201, 2018081307029],
#  [991513864044702201, 2018090707062],
#  [991505680294702201, 2019052107114],
#  [991505322534702201, 2018062707211],
#  [991444133534702201, 2019020807505],
#  [991507225404702201, 2018091407021],
#  [991443199694702201, 2018072507084],
#  [991443816054702201, 2019091977003],
#  [991517567164702201, 2018061207001],
#  [991442952374702201, 2018072607141],
#  [991441750374702201, 2018061107017],
#  [991441749284702201, 2018061107003],
#  [991443193904702201, 2018091407049],
#  [991509851184702201, 2018070507030],
#  [991515276444702201, 2018062207515],
#  [991508415824702201, 2018081607078],
#  [991442950674702201, 2018070507115],
#  [991444130864702201, 2018070507083],
#  [991508410004702201, 2018090507015],
#  [991516346704702201, 2019011448568],
#  [991508497704702201, 2018061807087],
#  [991443197484702201, 2018061207545],
#  [991516433854702201, 2018081407158],
#  [991514528064702201, 2017111748095],
#  [991512106914702201, 2018091207051],
#  [991506338664702201, 2018101205008],
#  [991500733724702201, 2018072507146],
#  [991508497964702201, 2018071207097],
#  [991516730394702201, 2019052107021],
#  [991514496864702201, 2018072507059],
#  [991510000854702201, 2018060748077],
#  [991512553004702201, 2018071707023],
#  [991508406324702201, 2018101207018]]

# %%
nb.refine_book_urn(urns=[x[1] for x in barnebøker_fra_2015], words=['homo'])
# Out:
# [[2014111907535, 'Holm, Dagny', 'Zeppelin', 2007]]

# %%
konks = lambda w,urner = [x[1] for x in barnebøker_fra_2015]: [ ' '.join([str(y) for y in x]) for x in mm.konk(word=w,urns=urner)]

# %%
all_ordene = [y.strip() for x in ordgrupper for y in ordgrupper[x]]
#all_ordene

# %%
konkordanser = {w:konks(w) for w in all_ordene}
# Out:
# {'blind': ['2018061207220 jeg skjønner at du er blind som en moldvarp i dagslys',
#   '2018061207220 ganske godt til å være blind . » Ruby stirret på',
#   '2018061207220 . « Er Connie Slowfoot blind ? » « Blind som',
#   '2018060807125 er henne ? Er du blind ? »',
#   '2018060807125 se , men jeg var blind .',
#   '2018060807125 « Jeg har vært så blind , » sa jeg ,',
#   '2018090507127 Q Hunden skulle bli nesten blind ei stund .',
#   '2018072507075 Men å være blind , å bortforklare og glemme',
#   '2018102207047 hadde lurt henne . En blind datel Nå sto hun her',
#   '2018102207047 for den spøken med ‘ blind date ’ med Markus .',
#   '2018072007192 How was it being blind ?',
#   "2018072007192 What do you think the blind man ' s plan is",
#   '2018070507073 og bestemoren hans , en blind gammel dame som har som',
#   '2018112177019 kroppen min. Jeg er nesten blind av panikk , og hendene',
#   '2018022048009 bråk ? » spurte en blind tigger . Han satt ved',
#   '2018022048009 , for han var blitt blind .',
#   '2018061807053 . Snart var han helt blind , med knærne og ryggen',
#   '2018061807053 Og så kan man bli blind av hjemmebrent , og jeg',
#   '2018061807053 « Ble du blind av den ? »',
#   '2018091207024 Jeg kunne ha gjort ham blind .',
#   '2018091207024 en ung mann som er blind av kjærlighet . » Hun',
#   '2018091207024 « Jeg er ikke blind av kjærlighet . »',
#   '2018091207024 håpe at Mercury er så blind av hat at hun ikke',
#   '2018091205018 ham blind . Men hva slags unnskyldning',
#   '2018072007005 B : Hunden til en blind person C : Hunden til',
#   '2018072007005 B - Hunden til en blind 9. B-Hest',
#   '2018060548201 Han strittet imot , var blind av raseri . Han snudde',
#   '2018060548201 og hatet som gjør deg blind , den stoltheten som får',
#   '2018060548201 ? At jeg har vært blind , at jeg har vært',
#   '2018072607323 - Er du blind og døv ? Majke himlet',
#   '2018072507079 ikke tro at jeg er blind None',
#   '2018072607189 oss blinde . Gjorde meg blind . Vet dere , før',
#   '2018060807101 sterkt at hun nesten ble blind av raseri . Han hadde',
#   '2018061807565 bråstoppet . - Er du blind ?',
#   '2018061807565 Om jeg var blind ?',
#   '2018102207015 skade som har gjort henne blind på det ene øyet og',
#   '2018102207015 i ferd med å bli blind og miste pusten , men',
#   '2018072407144 mot menneskene som skrek i blind dødsangst foran dem . Men',
#   '2018060807164 langsynt at du nesten er blind . Hun tenker kanskje på',
#   '2018060807164 - Da er du blind . Da må du begynne',
#   '2018060807164 meg på å være nesten blind , sier Alice . Å',
#   '2018060807164 ikke vite om du blir blind en dag så DET er',
#   '2018060807164 - Jeg er blitt nesten blind , sier Alice . -',
#   '2018072607319 det er lett å bli blind når man tror at ingenting',
#   '2019021477023 mens gutten satt der , blind og stum og angret nok',
#   '2018120777091 kunne jeg ha vært så blind ? Men jeg visste svaret',
#   '2018110677076 med mindre du er fullstendig blind , og jeg kan se',
#   '2018072607287 ikke kunne ta med en blind katt på en så lang',
#   '2019052107116 , du må være ganske blind hvis du ikke så de',
#   '2018030548092 så ingenting . Jeg var blind også .',
#   '2018101007316 alt , og kjærlighet gjør blind ,',
#   '2018061807641 asked his friend who was blind to go with him to',
#   '2018061807641 this ? " asked the blind man. " You can \'',
#   '2018061807641 then , " said the blind man. He lifted the lame',
#   '2018061807641 and died instantly . The blind man helped him to skin',
#   '2018061807641 to his friend . The blind man asked his friend to',
#   '2018061107009 Dommeren er blind None',
#   '2018061107009 Dommeren er blind None',
#   '2018061107009 . « Dommeren var jo blind » , sa jeg .',
#   '2018061107009 nok en gang hadde vært blind . Jeg så for meg',
#   '2018061107009 noe komisk at dommeren er blind .',
#   '2018101107042 , for kanskje er du blind på det ene øyet .',
#   '2019032277143 . Hvis du ikke er blind , må du ha sett',
#   '2019032277143 spiller . Du er ikke blind , er du vel ?',
#   '2019032277143 vi dra og besøke en blind mann i Portland . »',
#   '2019032277143 vi bare å finne en blind mann i regnet , »',
#   '2019032277143 Han var åpenbart blind . Øynene hans var melkehvite',
#   '2019091977032 om jeg skulle vært født blind og prøve å se for',
#   '2018071707090 Vi har også en blind flekk . Det er stedet',
#   '2018060807146 en blind date for dem ! Kan',
#   '2018060807146 å sende mamma på en blind date med Augusts onkel Ben',
#   '2019101577025 feil at jeg har vært blind for mine egne ?',
#   '2019101577025 at hun nærmest hadde vært blind . Hun hadde brukt månedsvis',
#   '2018102307120 i rotte etter rotte , blind for alt annet .',
#   '2018062807108 , enda han verken var blind eller het Bertil . Det',
#   '2019030177042 han presenterte to stykker på blind date på låvedans .',
#   '2019030177042 tilbake til livet og en blind gutt fikk synet tilbake ,',
#   '2018050348020 at stoltheten ville gjøre ham blind for min plutselige unnskyldning .',
#   '2018050348020 Han er blind . Den ene hånden holder',
#   '2018050348020 vinteren dere hadde sammen deg blind for at det bare er',
#   '2018050348020 . Stolthet kan gjøre en blind . »',
#   '2018072507198 Det virket som enda en blind vei .',
#   '2018061807050 for han er nesten helt blind . Han snakker med klar',
#   '2018060748079 den ned i strømpebuksa i blind panikk , langt nok ned',
#   '2018060748079 kaster meg mot døra i blind panikk , og glemmer et',
#   '2018060748079 . Hvis Rose er så blind at hun ikke ser hvordan',
#   '2018050448035 er visst både døv og blind , du , » sa',
#   '2018050448035 ikke være verken døv eller blind likevel . Fra huset kom',
#   '2018050448035 stadig flere som advarte mot blind tro på gamle autoriteter .',
#   '2018050448035 er visst både døv og blind , du . » I',
#   '2018050448035 er du både døv og blind ? Sperret hun ikke opp',
#   '2018072507132 Ronny ? Er du helt blind , eller ? »',
#   '2019061977014 første var at fangen var blind ; øynene var melkehvite .',
#   '2019061977014 ble mørkt . Jeg var blind .',
#   '2019061977014 « Er du ikke blind ? » spurte jeg .',
#   '2019061977014 I blind panikk kjempet jeg meg opp',
#   '2018072507144 er ne $ teh helt blind . På tuppen av snuta',
#   '2018060748076 både døv , stum og blind . »',
#   '2018060748076 ? Jeg hater å være blind ! »',
#   '2018060748076 øyeblikk trodde han var blitt blind .',
#   '2018101107049 arrangement , og du er blind som en muldvarp . Det',
#   '2018101107049 Hadde jeg ikke reddet en blind mann fra en løpsk hest',
#   '2018062607026 Bartimeus er blind . Han tigger .',
#   '2018020848059 hadde fanget fire edderkoppen ei blind rotte og noe som så',
#   '2018020848059 skjønte det , Knuterotta var blind .',
#   '2018020848059 regnet med det hos en blind knuterotte .',
#   '2018020848059 hans og gjort ham midlertidig blind .',
#   '2018060807051 Det var en gang en blind nordmann , en døv danske',
#   '2018103007076 « Da er du blind ! Du må da se',
#   '2018103007076 kapteinen . « Mannen er blind . Men du har jo',
#   '2018103007076 egg . Den var blitt blind av lynet . Hesten mistet',
#   '2018020548069 her ordtaket « kjærlighet gjør blind » kommer fra .',
#   '2018101107031 derfor hadde hun vært fullstendig blind for hans følelser for henne',
#   '2018101107031 åpenbart at hun ikke var blind . « Er det sant',
#   '2019011448520 som drar med seg en blind mann 11. Fire fisker',
#   '2018071807144 svært dårleg ... er nesten blind , faktisk . Ikkje heilt',
#   '2018101107029 Så blind var han av kjærleik .',
#   '2018060807044 men hun var heller ikke blind . Hun visste at hun',
#   '2018060807044 ham som farger for en blind .',
#   '2018060807044 Et utfall i mørket , blind , men ikke døv .',
#   '2018051448017 på henne siden jeg er blind av skam .',
#   '2018051448017 Jeg er homo , ikke blind . Håret hennes er skikkelig',
#   '2018072507145 deg : Du skal være blind en tid og ikke se',
#   '2018091907057 « Du har gjort meg blind ! »',
#   '2019102877022 vi er ? Er du blind ?',
#   '2018072607220 Tordenklanen ; så godt som blind og døv',
#   '2018072607220 om han var døv , blind og lam , og at',
#   '2018072607220 Ildstjerne var nesten blind av alt regnet , og',
#   '2018062707252 noen øyeblikk ville jeg være blind .',
#   '2018041748224 gregers . Blir blind !',
#   '2018041748224 med at « kjærlighet gjør blind » ? Tenkeskriv i to-tre',
#   '2018020548041 still free Are you so blind that you cannot see ?',
#   '2018020548041 Are you so blind that you cannot see ?',
#   '2018020548041 Are you so blind that you cannot see ?',
#   "2018020548041 . To man ' s blind indifference to his fellow man",
#   '2018112177044 Du må faen meg være blind på begge øynene ! »',
#   '2018062807048 og hun er overbodet ikke blind for elendigheten som finnes .',
#   '2018062807048 seg langs containerveggen som en blind , føle seg frem med',
#   '2018110607129 være . Når jeg er blind , ser du klart .',
#   '2018110607129 knus speilene jeg stirrer meg blind på .',
#   '2018072607320 vanvittig . Vanligvis er jeg blind som en muldvarp uten briller',
#   '2018072607320 , dommer ! Er du blind , eller ? »',
#   '2018061807086 grunnen like godt ha vore blind , og høyrsla kunne eg',
#   '2018061807086 begynte å gå , nesten blind av tårer . Ved føtene',
#   '2018071807321 alt , og kjærlighet gjør blind ,',
#   '2018061107516 siden . Jeg var ikke blind for Kronos ’ grusomhet .',
#   '2018061107516 beina , så hun både blind og livredd ut .',
#   '2018061107516 snuble omkring , hjelpeløs og blind og overbevist om at han',
#   '2018061107516 kunne like gjerne ha vært blind . Hun grep Percys hånd',
#   '2018061107516 i en ørken og blitt blind .',
#   '2018053048035 Alexandria . Lillian så en blind mann som satt på huk',
#   '2018053048035 broen , så jeg en blind mann som skulle til å',
#   '2018053048035 . Hun var også delvis blind og ventet sitt fjerde barn',
#   '2018053048035 ei seks år gammel , blind jente som hadde et skjevt',
#   '2018053048035 William , sønn av en blind mann , som nå var',
#   '2018101007168 til at du kan bli blind .',
#   '2018101107020 . « Jeg har ingen blind lojalitet overfor Luke . Jeg',
#   '2018061807082 dagene ? Er du helt blind ? ! »',
#   '2014111907535 kvitt det som gjorde han blind , men kappa sveipte seg',
#   '2018060807147 alle , har vore så blind .',
#   '2018091805035 Now the blind man decided to play a',
#   '2018091805035 play a trick on the blind man. He only gave him',
#   "2018091805035 the end , the ' blind man ' and the Tame",
#   '2018091805035 tough to eat that the blind man had to use all',
#   '2018091805035 The lame man told the blind man that this was the',
#   '2018070507056 i rotte etter rotte , blind for alt annet .',
#   '2019011577020 øyne . Hvis Orion er blind ... »',
#   '2019011577020 « Han var blind , » rettet Hades .',
#   '2018072607298 både døv , stum og blind . Så mye å jobbe',
#   '2018072607298 Han virka døv og blind for vår fomling og mangel',
#   '2018102207052 en grense når det gjaldt blind lydighet . Hun måtte diskutere',
#   '2018102207052 han , plutselig naken og blind og på vei mot et',
#   '2018102207052 Øye for øye gjør verden blind ... » svarte Strøm .',
#   '2018102207052 nesegrus beundring for milliardærer og blind tro på profitt har de',
#   '2018102207052 når han kunne utvise litt blind lydighet i praksis .',
#   '2018072507254 Saga , men Saga var blind for dem , bare opptatt',
#   '2018091207011 Nå er jeg halvt blind .',
#   '2018091207011 om at du ikke er blind . »',
#   '2018091207011 å spørre ... er du blind ? »',
#   '2018091207011 « Jeg er ikke blind , » sier jeg .',
#   '2018091207011 holde balansen . Jeg er blind og våt , og jeg',
#   '2018042048091 « Hun er blind , men med dem kan',
#   '2018060748070 om at hun ikke var blind , eller en dverg som',
#   '2017121808074 Gregor . « Jeg er blind ! »',
#   '2018072507087 var eg så godt som blind . Og tåkene ...',
#   '2018072507087 det , var jo Thuja blind og kunne ikkje lese sjølv',
#   '2018072507087 flaks for deg at ei blind gammal kjerring hadde bruk for',
#   '2018072507087 ? Er du verkeleg så blind , vesle heks , at',
#   '2018060748085 . Kanskje var det en blind tilfeldighet at fattern og jeg',
#   '2018060748085 kunne også være en sånn blind tilfeldighet at jeg fikk en',
#   '2018060748085 måte hadde han jo vært blind hele tida .',
#   '2018101007396 snille venn , være så blind ? Hvilket valg hadde disse',
#   '2018101007396 « Du er blind som en Blå » ,',
#   '2018101007396 i en mørk skog , blind og fortapt som Dante for',
#   '2018101007396 han skal ha vært like blind som meg . Er det',
#   '2018101007396 nær en statue av en blind kvinne som holder en vekt',
#   '2018060807173 . Sola hadde vært for blind eller naiv til å se',
#   '2018060807173 prate . - Er jeg blind ?',
#   '2018031248066 . Seeren er seiv en blind , og former Evna på',
#   '2018031248066 Han var en blind . Nåbyrn . En likfødt',
#   '2018031248066 han så på henne , blind eller ikke . Hun la',
#   '2018031248066 sent . Han var en blind . Hun hadde sett hva',
#   '2018031248066 Vettskremt . Til og med blind , med bind for øynene',
#   '2018060748090 . Seeren er seiv en blind , og former Evna på',
#   '2018060748090 Han var en blind . Nåbyrn . En likfødt',
#   '2018060748090 han så på henne , blind eller ikke . Hun la',
#   '2018060748090 sent . Han var en blind . Hun hadde sett hva',
#   '2018060748090 Vettskremt . Til og med blind , med bind for øynene',
#   '2018072607233 på henne siden jeg er blind av skam .',
#   '2018072607233 Jeg er homo , ikke blind . Håret hennes er skikkelig',
#   '2018102307108 i Tordenklanen , nesten helt blind og døv',
#   '2018060807141 Stan . - Var hun blind , eller ? Josie går',
#   '2018090607026 om hun ble døv eller blind her inne . Det passet',
#   '2018090607026 om Sabine , er du blind . Og det er du',
#   '2018103077006 som om hun hadde vært blind for det til nå .',
#   '2018070507023 er mye man kan bli blind for når man er dypt',
#   '2019062777081 kvitt det som gjorde han blind , men kappa sveipte seg',
#   '2019062777081 avtalt det medan eg låg blind og bunden på den andre',
#   '2019062777081 att. Som å bli gjord blind . Og eg ville aldri',
#   '2018061807088 « Trur du eg er blind ? Eller døv ? Eller',
#   '2018061807088 . Eg ville ikkje vere blind , ville ikkje ...',
#   '2018061807088 med eitt var blitt både blind og døv .',
#   '2018061807088 ho no gjorde og krype blind og døv gjennom snøen .',
#   '2018061807088 enn mørker . Eg var blind og døv og meir enn',
#   '2018072507216 « Natten gjør blind , » svarte Epsilon litt',
#   '2018072507216 gjort ham både dum og blind . »',
#   '2018072607198 retning , på samme tid blind og direkte . Skrik og',
#   '2018061807034 , Gud . Jeg er blind . Jeg er blind .',
#   '2018061807034 er blind . Jeg er blind . »',
#   '2018091705079 | Hunden skulle bli nesten blind en stund .',
#   '2018062507069 da var han alltid halweis blind av blod og krigens raseri',
#   '2018050748058 aveugle [ avægl ] adj blind ; ( fig ) forblindet',
#   '2018050748058 aveugle d ’ un æil blind på et øye en aveugle',
#   '2018050748058 amour rend aveugle kjærlighet gjør blind None',
#   '2018050748058 vue miste synet ; bli blind None',
#   '2018050748058 une mer d ’ huile blind adj aveugle',
#   '2018103007083 Han var blind .',
#   '2018061107007 , Gulrot ! Er du blind , eller ? Det er',
#   '2018071207044 lenge på sola og bli blind .',
#   '2018071207044 helt til han ble evig blind . Han var nødt til',
#   '2019012577012 den siden av jordet i blind panikk . Jeg kan bare',
#   '2018083107101 a system of writing for blind people . Braille is based',
#   '2018083107101 six dots . Louis was blind himself and wanted to be',
#   '2018090507138 asked his friend who was blind to go with him to',
#   '2018090507138 this ? " asked the blind man. " You can \'',
#   '2018090507138 then , " said the blind man. He lifted the lame',
#   '2018090507138 and died instantly . The blind man helped him to skin',
#   '2018090507138 to his friend . The blind man asked his friend to',
#   '2018070507099 mindre han er stum , blind eller døv . Eller alt',
#   '2018070507099 det som om jeg er blind eller kanskje døv - jeg',
#   '2018090407141 kunne likså godt vært fullstendig blind .',
#   '2018072607308 , etter hvert døv og blind , sitt arbeid i hemmelighet',
#   '2019062777024 min feil . Dommeren er blind ! murret han da han',
#   '2018062507081 ville gjort meg enda mer blind . Med den ene hånden',
#   '2018062507081 Tror du jeg er blitt blind ? »',
#   '2018061107019 « Hallo , er du blind , eller ? » roper',
#   '2018061107019 « Er den blind ? » undrer Ester .',
#   '2018072607079 Nei , jeg er ikke blind , jeg er bare sjøsyk',
#   '2018060748068 så jeg at han var blind . Han vugget frem og',
#   '2018060807050 , og jeg følte meg blind og venneløs , isolert fra',
#   '2018060807050 - Tror du jeg er blind ? Kan du ikke begynne',
#   '2018060807050 måtte man bokstavelig talt være blind for ikke å greie det',
#   '2019072407161 som om ein skulle vere blind , når ein ser på',
#   '2018101207012 still free Are you so blind that you cannot see ?',
#   '2018101207012 Are you so blind that you cannot see ?',
#   '2018101207012 Are you so blind that you cannot see ?',
#   "2018101207012 . To man ' s blind indifference to his fellow man",
#   '2018091107080 Om mannen var delvis blind eller bare svært skjødesløs vet',
#   '2018091107080 trenger , så er han blind . Jeg kunne ikke for',
#   '2018091107080 tryggere å kjøre en stokk blind hest enn en som er',
#   '2019091977003 — Er du blind , eller ? sa Aladdin',
#   '2018072607141 . « Man kan bli blind ! »',
#   '2018072607141 « Er du blind ? » spør Ida .',
#   '2018091407049 er som om han er blind . Hvor er han da',
#   '2018091407049 « Du kan bli blind og alt mulig . Det',
#   '2018091407049 så hardt at jeg blir blind .',
#   '2018091407049 Jeg er bare blind et øyeblikk , så begynner',
#   '2018070507115 Røskeren . « Alle viser blind lojalitet overfor dronningen ... Nei',
#   '2018070507083 « Vil du bli blind ? » ropte Bethany .',
#   '2018070507083 på at han kunne bli blind , skremde han , men',
#   '2018071207097 « Øyh , er du blind , eller ? ! »',
#   '2018071207097 « Hjelp ! Jeg er blind ! » og snublet i',
#   '2018071207097 None blind ? » sa Johannes .',
#   '2018072507059 Slikt kunne gjøre blind , men det var likevel',
#   '2018060748077 hun med undring . En blind og litt styggere Thorrald .',
#   '2018060748077 Ravnhov , sammen med en blind . Hun hadde sett elva',
#   '2018060748077 . Han var jo en blind . Umpiri . Han var',
#   '2018060748077 Hun var blind . Hun sto i mørke',
#   '2018060748077 ligne ei gaupe . Ei blind gaupe . Lyset fra lyktene'],
#  'svaksynt': ['2018102207047 . Dessverre er jeg ganske svaksynt og kan ikke si deg',
#   '2018060807164 eneste i verden som er svaksynt , da , mumler Alice',
#   '2018091205064 på at keiserkobraen var like svaksynt som en gammel professor .',
#   '2018072607298 Jessica var svaksynt og var av det mer',
#   '2018072607298 . En trettenåring som på svaksynt vis betrakter sin bestefar skyte',
#   '2018050748058 None svaksynt adj mal-voyant m ( -'],
#  'tykk': ['2018060807125 smeltet smør , og en tykk , fyldig saus fløt utover',
#   '2018060807125 i hendene til Zeke , tykk av verdifulle sedler . Hvis',
#   '2018060807125 » sa hun . En tykk lupe fikk det ene øyet',
#   '2018060807125 smil rakte Babs meg en tykk manilakonvolutt . « Vær så',
#   '2018060807125 på fingeren hans , en tykk gullring uten ornamenter . «',
#   '2018120777019 . Som en strøm av tykk tjære , dekket de bakken',
#   '2018072507075 Det løp en stor , tykk ledning fra et skur langs',
#   '2018072507075 tunge fenderballen var laget av tykk gummi , var stor som',
#   '2018072507075 bordplaten . Han valgte en tykk blyant , og reiv av',
#   '2018060748061 Klappen med en kort , tykk finger . « Men hun',
#   '2018060748061 var bred også . Og tykk . Faktisk var han så',
#   '2018060748061 han så bred og så tykk at det så ut til',
#   '2018060748061 av voks som virket så tykk at Emma lurte på hvordån',
#   '2018060748061 tunnelen og inn i en tykk og fuktig tåke , og',
#   '2018062607590 bred og omtrent 1000 lysår tykk .',
#   '2018062607590 fra Solen . Den er tykk , for å',
#   '2018072607264 . - Er du blitt tykk i hodet sånn helt plutselig',
#   '2018072607264 Hun hadde med seg en tykk bok . Hun åpnet den',
#   '2018072607264 hun med en finger så tykk som en salamipølse rett mot',
#   '2018072607264 Gutten skar en ny , tykk skive og begynte å spise',
#   '2018072607264 Den var kanskje litt for tykk , men vekten var akkurat',
#   '2018072507201 en ullfrakk som var altfor tykk for denne varme septemberkvelden .',
#   '2018072507201 bare med spøkelsesaktig jarnring og tykk tåke . Jeg var glad',
#   '2018072507201 men spenningen i rommet var tykk som smogen i Kairo .',
#   '2018072507201 - en kjempestor sjakal med tykk , svart pels , lodne',
#   '2018072507201 rundt meg . Huden føltes tykk som stål og musklene kraftige',
#   '2018102307054 sa Frank Stein , en tykk gutt med grønn hud og',
#   '2018072507196 hun dro på seg en tykk genser .',
#   '2018072507196 la hun merke til en tykk konvolutt som lå på benken',
#   '2018072507196 komme langt . Snøen lå tykk utenfor , og hun var',
#   '2018072507196 Han hadde på seg en tykk jakke , lue , solide',
#   '2018072507196 med skjerf rundt halsen , tykk lue tredd ned over ørene',
#   '2018102207047 Ikke det at hun var tykk , akkurat , heller det',
#   '2018102207047 bygget inntil en stor , tykk trestamme . Hun så at',
#   '2018101007059 None tykk None',
#   '2018070507073 og gjorde sengen dobbelt så tykk så det harde gulvet ikke',
#   '2018070507073 og foran den satt en tykk grå katt og freste ,',
#   '2018070507073 hundehode av gull med en tykk ring i munnen , »',
#   '2018070507073 så vennlig og har en tykk gullkjede , og i den',
#   '2019081477002 Foran ham lå en tykk , brun konvolutt . Logoen',
#   '2019081477002 Grenen han satt på var tykk og kraftig . Over klippen',
#   '2019081477002 Foran dem vokste en tykk tåkebanke . Begge kledde seg',
#   '2019081477002 gummistrikker flettet sammen til en tykk , elastisk gummivaier . Fortøyningen',
#   '2019081477002 Nautilus hadde form som en tykk sigar , var han uansett',
#   '2019052007131 så var han dekket av tykk grå og svart pels -',
#   '2018071707590 der . Han er altfor tykk .',
#   '2018061807053 unnlot å pleie ) en tykk , bred bart som nådde',
#   '2018041648021 Suppe - tykk , laget av erter ,',
#   '2018041648021 . Romerske soldater hadde en tykk 1 jn | hånd og',
#   '2018091207024 - den er varm og tykk og laget av ull .',
#   '2018091207024 ved , plukker ut en tykk kubbe og setter den på',
#   '2018091207024 Knivbladet er beskyttet av en tykk lærslire . Det er en',
#   '2018091207024 meg - en lang , tykk ål som kunne svelget meg',
#   '2018091207024 flaske , setter i en tykk kork , holder den opp',
#   '2018091205018 sitringen - var som en tykk vegg jeg snublende og stotrende',
#   '2018091205018 » Jeg hørte pappa bli tykk i stemmen . Folk pleide',
#   '2019052007132 silke . Elastisk , litt tykk silke . Det er solid',
#   '2018062807021 og søkte dekning bak en tykk furustamme . Han krøp sammen',
#   '2018062807021 se ham , for en tykk furustamme',
#   '2018062807021 fryseren var dekket av en tykk , blodig væske , og',
#   '2018062807021 mennene hans dro ut en tykk vaier fra undersiden av helikopteret',
#   '2018062807021 Fryseren dundret inn i en tykk trestamme med et ekkelt knas',
#   '2019052007002 der røyken allerede var så tykk at det var umulig å',
#   '2018060548201 plutselig dannet det seg en tykk tåke under føttene hans ,',
#   '2018072607323 Så stakk legen ei tykk nål inn i armen hennes',
#   '2018072607323 var i stål med ei tykk glassplate . Første frie leders',
#   '2018072607323 , og fisket fram ei tykk bok .',
#   '2018072607323 , før de stakk ei tykk nål inn i armen hennes',
#   '2018072607323 en glassbit . Den var tykk . Flaskegrønn . Han kunne',
#   '2018072507079 klatt smør som var like tykk som hans egen underarm .',
#   '2018072607189 poteter og gulrøtter dekket av tykk , varm , salt saus',
#   '2018072607189 Seiv om isen var tykk , var den klar som',
#   '2018072607189 en berøring gjennom så mye tykk pels føltes litt som å',
#   '2018072607189 Pelsen hans var så tykk at det ikke virket som',
#   '2019021477022 det en flaske med en tykk , gulaktig væske . TIL',
#   '2019021477022 fantastiske blandingen . Miksturen var tykk som krem , og mens',
#   '2018060807101 henne høy , lav , tykk eller syltynn , en bekmørk',
#   '2018060807168 , vi skal lage en tykk , bred borg , større',
#   '2018061807084 kom til syne - en tykk gullring med edelstener og med',
#   '2018102207015 arr strekker seg som en tykk strek fra like over høyre',
#   '2018072507217 et kraftig trebord lå en tykk None',
#   '2018072507217 ned i skjul bak en tykk trerot , og kikket fram',
#   '2018072507217 - og stanset ved en tykk bok i sort skinn .',
#   '2018072607319 , og far hadde en tykk bok med skinnpermer i hendene',
#   '2018072607319 himmelranden kunne man se en tykk mur av mørke , fuktige',
#   '2018072607319 meg , og strupen føltes tykk . Jeg visste ikke hva',
#   '2018072607319 fuktighet . Den inneholdt en tykk plastpakke som vi kunne se',
#   '2018072607319 smell , som om en tykk planke var blitt kløyvd i',
#   '2018072507195 gått . Bestemor leser en tykk bok mens hun rydder av',
#   '2018072507195 hvitt , kort skjegg og tykk mage . Det er alltid',
#   '2018072507195 ryggen . Pelsen kjennes så tykk ! Den er ganske myk',
#   '2019021477023 til fabrikken og hengte en tykk kjetting med en diger hengelås',
#   '2019021477023 - Du verden , så tykk han er ! - Skrekkelig',
#   '2019021477023 malerkost ! Så glupsk og tykk og dorsk og lat ,',
#   '2019021477023 . Kasserollen var fylt med tykk , seig og fiolett sirup',
#   '2019021477023 . Fru Salt var veldig tykk og hadde korte ben og',
#   '2018120777091 . Døren var laget av tykk stål . I stedet tok',
#   '2018101677002 så jeg en liten , tykk mann med hornbriller komme farende',
#   '2018062807087 Noen kikket fram fra en tykk trestamme . Det var Hailey',
#   '2018081407067 et brusende piff-paff- poff av tykk og glitrende røyk . Prins',
#   '2018081407067 i en fresende sky av tykk røyk som begynte å snurre',
#   '2019062777016 en energisk islandshest med vaiende tykk man.',
#   '2019062777016 En energisk islandshest med flagrende tykk man passer ikke inn i',
#   '2018061907620 i kinnene , briller med tykk innfatning , regulering , og',
#   '2018061907620 elendig . Tåken var så tykk at Percy ikke kunne se',
#   '2018061107044 drøyere , så skaren var tykk nok til at den bar',
#   '2018061107044 drøye munnfuller med blåbærgrøt med tykk fløte . Han fortake henne',
#   '2018081407170 . Acrocanthosaurus hadde også en tykk hale , som nok ikke',
#   '2018103007191 dag : Himmelen var fortsatt tykk av røyk fra brannene de',
#   '2018103007191 tærne til en stor , tykk fot , » hadde hun',
#   '2018103007191 var mørkt ; luften var tykk og stinket avskyelig - av',
#   '2018103007191 av krigen . Hun var tykk og full av arr og',
#   '2018103007191 nesten luften i munnen , tykk og kvelende , dunstende og',
#   '2018060807163 , med en fem centimeter tykk grein . Mordvåpenet ble funnet',
#   '2019062777086 er trærne krokete , barken tykk , furet og nesten grålig',
#   '2019062777086 renner fra den i en tykk stråle . Tør jeg spørre',
#   '2019032277143 ingen bukser , bortsett fra tykk geitepels . Den store afroen',
#   '2019032277143 rumlende drønn , og en tykk vannstråle pløyde opp en grøft',
#   '2019032277143 som fløt rundt i en tykk suppe av olje . Det',
#   '2019091977032 jeg ser avkjørselsskiltet . En tykk røyksøyle stiger dovent mot den',
#   '2019091977032 er han der , en tykk , svart pupill i det',
#   '2019091977032 foran en hangar . En tykk mann hopper inn på bussen',
#   '2018020248200 Jordskorpen er ikke Like tykk over alt. Under kontinentene er',
#   '2018020248200 den i gjennomsnitt 35 km tykk , men under havene er',
#   '2018020248200 fra 6 til 10 km tykk .',
#   '2018020248200 fra 6 til 10 km tykk None',
#   '2018020248200 gjennomsnitt 35 km tykk None',
#   '2018103007280 . Callum pekte på en tykk sigar , halvrøkt , som',
#   '2018103007280 nervøst rundt . Lufta var tykk av støv , og den',
#   '2018103007280 portrett av en mann med tykk , svart mustasje og glattslikket',
#   '2018103007280 han en kort jakke med tykk pelsbesetning . Noe ved det',
#   '2018103007280 . - Veggen er ganske tykk . Da bokhylla åpnet seg',
#   '2018071707090 fleste steder er jordskorpa så tykk at vi ikke merker noe',
#   '2018071707090 en bøtte til en så tykk pudding at du kan snu',
#   '2018071707090 Og den boka ville blitt tykk .',
#   '2019101577025 ( jeg blir hyper OG tykk av det ) .',
#   '2019101577025 Bak huset vellet det frem tykk , mørk røyk i feite',
#   '2018102307120 hjemveien . En stor , tykk bok med hodebry . Den',
#   '2018102307120 den var minst tre meter tykk og utgjorde en solid base',
#   '2018102307120 helt . Døra var en tykk tredør . Det ville ta',
#   '2018102307120 hundre ? Røyken ville ligge tykk , og her var det',
#   '2018060807148 det som om lufta ble tykk som grøt , og jeg',
#   '2018060807148 på presenningen , veltet plutselig tykk , grå røyk mot oss',
#   '2018060807148 hadde tatt på meg en tykk ullgenser før jeg la meg',
#   '2018060807148 senere hadde jeg laget en tykk knute etter fri fantasi ,',
#   '2018060807148 , og fant snart en tykk , blå bokrygg jeg kjente',
#   '2018050348020 - svart , som en tykk slyngtråd av olje . De',
#   '2018050348020 uvanlig . Men han er tykk og fryktelig gammel , kanskje',
#   '2018050348020 . Rødt kjøtt , en tykk , kremaktig masse , brød',
#   '2018050348020 en av hestene med en tykk grein som han har skåret',
#   '2018050348020 En tykk røyksøyle stiger opp i det',
#   '2018072507198 i mørket , eller i tykk tåke , som nå .',
#   '2018072507198 men så ble den like tykk igjen . Det kiktet sterkt',
#   '2018062707051 ha passet . Den er tykk og mørk , slett ikke',
#   '2018062707051 min død . Den er tykk og svart og altfor sterk',
#   '2018062707051 én er over to centimeter tykk og sirlig merket med årstall',
#   '2018062707051 og én minst tretti centimeter tykk og av stål . Det',
#   '2018060748079 sommeren . Svarte sko , tykk strømpebukse , svart skjørt til',
#   '2018060748079 » spør en fyr med tykk hals , jeg tror han',
#   '2018060748079 rundt meg , som en tykk tåke , og plutselig fikk',
#   '2018060748079 og , selvfølgelig , en tykk , ugjennomsiktig strømpebukse som får',
#   '2018050448035 ettermiddagen , lå det en tykk konvolutt til henne i postkassen',
#   '2018050448035 treplate som var noen millimeter tykk i den ene enden og',
#   '2018061207186 Han gir meg en tykk mappe full av ark .',
#   '2018061207186 Den er for tykk til at jeg kan ta',
#   '2018072507132 . Med rødbrun pels og tykk , buskete hale . Det',
#   '2018072507132 dyrlegen . » Pappa var tykk i stemmen . Han gikk',
#   '2018072507132 på kjøkkenet og smurte en tykk skive med leverpostei . Så',
#   '2019061977014 bak oss og fulgte en tykk hagtornhekk nordover i noen hundre',
#   '2019061977014 oss . Han hadde en tykk trekølle i hånden . Klo',
#   '2019061977014 , vanntett frakk med en tykk , grå ullgenser under .',
#   '2019061977014 . « Celledøra er for tykk til at jeg kan bryte',
#   '2019061977014 kropp , omtrent som en tykk slange , med små ,',
#   '2018072507253 Hulegangen var fylt av en tykk sky av støv .',
#   '2018082207011 km tykk og er så varm at',
#   '2018082207011 landmasse som er skjult under tykk is . Plantefossiler viser at',
#   '2018060748076 halsen . Det var en tykk lenke i sølv med en',
#   '2018060748076 horn stakk opp fra en tykk , svart hår manke .',
#   '2018103007239 seg å bestå av en tykk samling med papirer . Foran',
#   '2019062777075 så at det var en tykk , fuktskadet bok .',
#   '2019062777075 mindre vondt der det er tykk ... eller ikke være så',
#   '2019062777075 ... Ikke mene du er tykk ... »',
#   '2019062777075 ved å finne fram en tykk bunke med kvitteringer . Det',
#   '2018061807065 på grasslettene . Den har tykk , rufsete pels som er',
#   '2018061807065 tundraen , og har tykk peis',
#   '2018061807065 i Sentral-Afrika . Den har tykk pels som',
#   "2018061807065 . Hannløven har en Æ tykk man av rufsete p '",
#   '2018101107049 . » Hun løftet en tykk finger og vinket meg nærmere',
#   '2018101107049 land gjennom et teppe av tykk tåke . B ritannia skulle',
#   '2018101107049 . Hun gikk med en tykk kåpe , og ansiktet var',
#   '2018101107049 . Hun rettet ut en tykk finger , som knirket og',
#   '2019081477049 på meg den og en tykk ,',
#   '2019072407153 En ring er 2 ... tykk . d ) En nyfødt',
#   '2018062707298 klart . Fatima hadde sånn tykk snute og bredt ansikt .',
#   '2018060807142 . Netting . Solid , tykk netting som har vært brukt',
#   '2018062607117 Da barnebølingen møtte en tykk tåke nederst i trappen ,',
#   '2018062607117 , og hvor strimer av tykk , grønn røyk drev ut',
#   '2018062607117 Kåpen var av tykk , svart pels og var',
#   '2018062607117 så å forsegle endene med tykk teip . Da',
#   '2018062607117 Eieren var en jovial , tykk mann som ga barna hver',
#   '2018072507129 . De var dekket av tykk rufsete pels og bar svarte',
#   '2018072507129 høyeste , kunne tilby en tykk vegg som ville gi ly',
#   '2018072507129 , sa han med en tykk , nesten uforståelig skandisk dialekt',
#   '2018072507129 og undersøkte ham . En tykk tommel grep',
#   '2018103007076 , men faren seiv var tykk . Tykkere enn noen andre',
#   '2018103007076 « Er Brynhilde en sånn tykk dame som bare synger og',
#   '2018103007076 seg seiv . Var hun tykk ? Det var ikke lett',
#   '2018103007076 sikkert at hun var for tykk . Og hun hatet de',
#   '2018103007076 Den var fuktig og virket tykk , som om den var',
#   '2018072507211 . Det var en ganske tykk bunke , full av tekst',
#   '2018101107031 hennes var hes , så tykk av redsel at den nesten',
#   '2018101107031 strødd rundt omkring - en tykk utgave av Skyggejeger nes kodeks',
#   '2018101107031 , og hang i en tykk flette nedover ryggen hennes .',
#   '2018101107031 av pentagrammet , og en tykk , svart røyk steg opp',
#   '2018101107031 - iallfall hadde den en tykk , skjellet kropp og et',
#   '2018061807068 svinger så brått at en tykk , brun konvolutt',
#   '2018061807068 dashbordet . Oi , så tykk den er . Det må',
#   '2018061807068 , sier Anders og er tykk i stemmen . - Som',
#   '2018061807068 snakke . Tunga kjennes så tykk i munnen . Leppene er',
#   '2018061207048 den er ca 3 cm tykk . Trykk forsiktig for å',
#   '2018061207048 kan du ha i ! tykk . Hvis deigen er I',
#   '2018062507013 på skolen . Han var tykk . Han var klønete .',
#   '2018062507013 Han er kledd i en tykk parkas og bærer',
#   '2018062507013 er mer enn tretti centimeter tykk , er jeg ferdig .',
#   '2018062507013 og tynn , iført en tykk parkas , med en rifle',
#   '2018051448017 en hettegenser som ikke er tykk nok , og kommer bort',
#   '2019102877022 - Litt tykk , sa Adolf . -',
#   '2019102877022 var ikke lett å bli tykk , så lite mat som',
#   '2018101007175 trege planteeteren hadde en veldig tykk skalle . Ekspertene vet ikke',
#   '2018101007175 pa cefalosaurene , hadde en tykk bein- bakbeina og kunne kuppel',
#   '2018101007175 Blomsterløs plante med tykk stamme , ingen greiner og',
#   '2018101007175 planteetende dinosaur med kuppelformet , tykk beinhjelm på hodet .',
#   '2018072607220 stripete katt og en med tykk , grå pels . De',
#   '2018070307047 , for en stor og tykk liane hindret trestammen fra',
#   '2018070307047 ca 22 cm , med tykk kropp . Fuglen oppdages lettest',
#   '2018070307047 men andefar var stor og tykk , og han klarte å',
#   '2018062707252 , og en sky av tykk , svart røyk begynte å',
#   '2018062707252 tydelige skader . Muren var tykk , men det ytterste steinlaget',
#   '2018072607167 Alt er dekket av tykk , grønn gørr , og',
#   '2018061807080 flytende eyelineren , la en tykk strek på øyenlokkene og dynget',
#   '2018061807080 , » apet Allie med tykk fransk aksent , og igjen',
#   '2018061807080 brent tre og murpuss var tykk og kvalmende , og det',
#   '2018061807080 I hånden holdt hun en tykk mappe med navnet hennes skrevet',
#   '2018061807080 hennes skrevet på forsiden med tykk , svart skrift .',
#   '2018031248072 som om mannen hadde en tykk , stram strømpe over fjeset',
#   '2018062607050 bålet og trakk fram en tykk grein som brant i den',
#   '2018060807068 og slapp to dråper med tykk , karmosinrød væske ned i',
#   '2018061207040 Herr Knoll var kort og tykk akkurat som sønnen sin .',
#   '2018062807048 av betong , der en tykk , svart slange stakk oppi',
#   '2018062807048 kontor hvor det sitter en tykk mann med bart og røyker',
#   '2018110607223 mot ballplassen . Tåken ligger tykk , som om skyene har',
#   '2018072607320 og gjemte meg bak en tykk trestamme . Trodde de liksom',
#   '2018072607320 grepet på en tykk amerikansk kvinnelig turist med lilla',
#   '2018072607320 og var heller ikke så tykk . Det var ikke stort',
#   '2018061107021 og holdt seg i en tykk gren . Han så lenge',
#   '2018071807321 skrevet med tykk , svart skrift , er',
#   '2018071807321 blings - en tykk brødskive',
#   '2018071807321 varme innside , man blir tykk av å spise loff ,',
#   '2018061807021 De fleste appaloosaer hadde ikke tykk man og hale slik som',
#   '2018061107516 sletta , ble tåken så tykk at Percy måtte stå imot',
#   '2018061107516 unna steg en søyle av tykk , svart røyk i været',
#   '2018072607088 Om høsten spiser den seg tykk på fisk , for å',
#   '2018060807170 halv meter , og ganske tykk . Tuppen av snurrebarten nådde',
#   '2018060807170 hele skipet . Snart steg tykk røyk opp og ut gjennom',
#   '2019072307093 snakk om enorme uhyrer med tykk hale der snuten skulle være',
#   '2019072307093 Boken var skinninnbundet og enormt tykk . Den lå på kontorpulten',
#   '2019072307093 likevel gikk Stryken med en tykk strikkejakke utenpå skjorten .',
#   '2018062707003 7 Kofte - tykk lang jakke-genser som holdes sammen',
#   '2018062707003 liksom miste ham i en tykk bjørkeskog . Men han var',
#   '2018062707003 forbi . To steder veltet tykk røyk opp fra hus som',
#   '2018072607078 . Det er en stor tykk krok som sitter fast på',
#   '2017121908077 foran dem finnes det bare tykk , mørkegrønn skog .',
#   '2017121908077 lang , tykk hale . Langs hele ryggraden',
#   '2017121908077 Kurk har en lang , tykk og hårete hale .',
#   '2017121908077 henger og dmgler i en tykk kabel , langt nedenfor selve',
#   '2017121908077 gris er og brun , tykk gjørme .',
#   '2018061807019 ham . Pelsen hans er tykk og myk . Plutselig ønsker',
#   '2018101107020 og nå var stemmen hans tykk av sarkasme . « Enklaven',
#   '2018101107020 ; luften var elendig , tykk av røyk og aske ,',
#   '2018101107020 på døren - den var tykk , lagd av eik og',
#   '2018101107020 husene , og asken lå tykk i gatene og over',
#   '2018101107020 var en svart varmetrøye , tykk og myk under fingrene hans',
#   '2018092507061 hentet fram en stor , tykk ullgenser hun hadde liggende i',
#   '2018092507061 pledd , ( tykk )',
#   '2018092507061 ord du kan bruke : tykk , grønn , gammel ,',
#   '2018061807082 bussen . Resultatet ble en tykk og dekkende gardin .',
#   '2018061807082 da han hadde funnet en tykk grein å sitte på .',
#   '2018073048215 lotteriboden . Han er tykk og har en flott snurrebart',
#   '2018073048215 Han er tykk og har en flott snurrebart',
#   '2018051448093 kilo og er 2,5 meter tykk .',
#   '2018051448093 cm bred , 2 cm tykk og veier 20 gram .',
#   '2018070507056 hjemveien . En stor , tykk bok med hodebry . Den',
#   '2018070507056 den var minst tre meter tykk og utgjorde en solid base',
#   '2018070507056 helt . Døra var en tykk tredør . Det ville ta',
#   '2018070507056 hundre ? Røyken ville ligge tykk , og her var det',
#   '2018081407135 Herr Knoll var kort og tykk akkurat som sønnen sin .',
#   '2018072507252 reagensrør med en mørkeblå , tykk væske .',
#   '2018050748567 hoiet og sigarettrøyken lå som tykk tåke . Antikvaren henvendte seg',
#   '2018050748567 rommene ifdrdos Vententy jrdvkdmmen Hun tykk store skdtter - yull otj',
#   '2019011577020 En tykk , rød væske skvalpet rundt',
#   '2019011577020 mange kilometer unna . En tykk søyle av damp steg opp',
#   '2019011577020 kjempen og fylte ruinene som tykk sigarrøyk . Jason prøvde å',
#   '2019011577020 og ned hadde han en tykk slangekropp - en om lag',
#   '2018091907032 Til slutt blir Lavrans så tykk at huden sprekker . Likevel',
#   '2018091907032 at de ble til ei tykk og grå dyne som dekket',
#   '2018091907032 så lenge at den ble tykk og seig . Da ble',
#   '2018070507005 det ? sier hun med tykk stemme .',
#   '2018102207052 og bare et par meter tykk , » sa Strøm .',
#   '2018103007345 hører seiv at hun er tykk i stemmen . Og hjertet',
#   '2018072507254 En høy , tykk mur reiste seg opp fra',
#   '2018072507254 spurte kvinnen med en stemme tykk av aksent . Saga så',
#   '2018072507254 fant en mugge og helte tykk , hvit melk over i',
#   '2018072507254 ? » spurte hun med tykk stemme .',
#   '2018072507254 snakke . Stemmen hans var tykk og lav . « Cellia',
#   '2018061807022 « Noen har satt en tykk strek over hele teksten og',
#   '2018061807022 tydelig kryss tegnet med en tykk tusj . »',
#   '2018061807022 hadde gjemt oss bak en tykk bjørkestamme i skogkanten . Mellom',
#   '2018091207011 lokket , tar ut en tykk bunke sedler og teller opp',
#   '2018091207011 den første . Så en tykk loddrett strek midt i ansiktet',
#   '2018091207011 . » Fyren har en tykk aksent av uviss opprinnelse .',
#   '2018091207011 , » sier han med tykk stemme . « Ingenting som',
#   '2018091207011 , » sier kan med tykk stemme . « Ingenting som',
#   '2018042048091 og veggen rundt . En tykk støvsky fylte rommet .',
#   '2019082977035 viktigere enn regnestykkene til en tykk rød herre ? Og hvis',
#   '2018060748070 jeg . Stemmen min ble tykk , og jeg tvang i',
#   '2018060748070 « Denne tightsen er veldig tykk . Og disse støvlene ...',
#   '2018072507250 frakken . Den andre var tykk og fikk ikke frakken helt',
#   '2018071607133 hud . Folk snakker om tykk hud og tynn hud ,',
#   '2017121808074 og en sånn hyggelig , tykk mann som fikk Lise til',
#   '2018050748285 , er bare 2 mikrometer tykk . Det -',
#   '2018050748285 Blodet ser ut som en tykk , rød væske , men',
#   '2018050748285 håndleddet som er dekket med tykk hud , brukes til å',
#   '2018060748085 som var låst med en tykk hengelås .',
#   '2018101007396 . Han er nesten like tykk som trestammen , og symbolet',
#   '2018101007396 Han er tykk . Markert hake , et',
#   '2018101007396 . Halsen hans er så tykk at jeg ikke kunne holdt',
#   '2018101007396 rund metallinnretning , én meter tykk og to meter i diameter',
#   '2018060807173 øye på en liten og tykk palomino med altfor store ører',
#   '2018031248066 på fanget . Den var tykk . Med brunt læromslag ,',
#   '2018060748090 på fanget . Den var tykk . Med brunt læromslag ,',
#   '2018072607233 en hettegenser som ikke er tykk nok , og kommer bort',
#   '2019052107170 lang , tykk hårlokk i starten for å',
#   '2018102307108 og underskogen var fortsatt ikke tykk nok til å gi dem',
#   '2018072607262 en stor , gammel , tykk topplue . Den la hun',
#   '2018103007024 None tykk .',
#   '2018090607026 hatt på hodet og en tykk ytterfrakk som så ut til',
#   '2018090607026 inn på kontoret med en tykk mappe i hånden . Ravnsvart',
#   '2018103077006 meg fordi jeg er for tykk ?',
#   '2018103077006 aldri sagt at du er tykk , du er ikke tykk',
#   '2018103077006 tykk , du er ikke tykk . Det er bare det',
#   '2018103077006 så var hun kanskje litt tykk . Når hun bøyde seg',
#   '2018103077006 hadde syntes hun var for tykk ? Kanskje han allerede da',
#   '2018082007036 delene er forbundet med en tykk bunt av nerver nederst i',
#   '2018072507085 bort til en grav med tykk kjetting som gjerde rundt på',
#   '2018072507085 Hun bøyer seg over en tykk bok som inneholder besvergelser mot',
#   '2018072507085 mamma , fortsetter Alrik med tykk stemme . - Hun klarer',
#   '2018062807068 Frøken Råthe plukket fram en tykk , hvit tube med store',
#   '2018062807068 . Kioskmannen var stor og tykk og bløt . Han var',
#   '2018062807068 hadde hun utviklet en svært tykk hud , og hun var',
#   '2018061807629 omrisset av platene med en tykk svart tusj , og rommet',
#   '2018061807629 hav som er dekket med tykk pakkis . Om vinteren brer',
#   '2018061807629 her er opptil 3 mm tykk , mye',
#   '2018061807629 * • O Elefanter bar tykk , skrukkete hud . ►',
#   '2018072507216 etter hvert opp til en tykk furustamme på bakketoppen . Der',
#   '2018072507216 en kriger med skjegg og tykk flette i nakken . «',
#   '2018072507216 veldig gravstein , nesten halvmeteren tykk ,',
#   '2018072507216 strøk en hånd over en tykk bok foran seg . «',
#   '2018072607198 Heldigvis var eføyen tykk nok til at de fikk',
#   '2018072607198 en finger hadde han en tykk gullring med edderkoppsymbolet gravert inn',
#   '2018072607198 godt pakket inn i en tykk , grønn jakke , med',
#   '2018072407083 svarte med å blåse en tykk sky av sigarrøyk ut i',
#   '2018050748307 liten pannekake tykk None',
#   '2018050748007 eller pappkartong , teip , tykk tusj , avis eller TV',
#   '2018050748007 saks , lim og en tykk tusj .',
#   '2018061807034 taekwondo-mester banke seg gjennom en tykk treblokk , og alle var',
#   '2018061807034 , » sier hun med tykk stemme uten å snu seg',
#   '2018091205038 Erik . Stemmen hans var tykk .',
#   '2018091205038 store lepper . Halsen ble tykk .',
#   '2018091205038 mot Flora og sa med tykk stemme :',
#   '2018091205038 og armer til en ekstremt tykk skikkelse . Det runde hodet',
#   '2018091205038 var pakket inn i en tykk , rød boblejakke , og',
#   '2018062507069 Røyken fra grillet kjøtt var tykk og lammende , som om',
#   '2018092707049 de flyr inn i en tykk lyrr — uhyret ! Er',
#   '2018112377040 vi blir stanset av en tykk aspargesmur . Den er tykkere',
#   '2018050748058 adj fast ; tett ; tykk ( om saus , suppe',
#   '2018050748058 ; frodig ; tett ; tykk du [ dy ] art',
#   '2018050748058 / [ epes ] adj tykk ; tett épaisseur [ epesær',
#   '2018050748058 , flink 4 svær ; tykk None',
#   '2018050748058 2 ( om personer ) tykk ; tykkfallen 3 grov ;',
#   '2018071207044 , og videre langs en tykk gren .',
#   '2018071207044 Himmelen var dyster og tåken tykk da Leeli kjørte sleden ned',
#   '2018071207044 var store , huden var tykk som bark , og de',
#   '2018071207044 nådde vannkanten var tåken så tykk at klærne deres ble pyntet',
#   '2018071207044 hun smalt inn i en tykk gren og mistet pusten .',
#   '2019011577029 - Heisan , sa en tykk dame i dongeribukser og en',
#   '2018042348631 følge vasset gjennom myrer med tykk , svart gjørme til livet',
#   '2018101107218 Den er rød og har tykk vaniljesaus over seg . Ida',
#   '2018070507099 store , firkantede briller med tykk innfatning . De ligner sånne',
#   '2018070507099 , men den er veldig tykk , og han er nesten',
#   '2018070507099 . Så finner jeg en tykk , svart tusj , for',
#   '2018061207046 en 3 - 4 mm tykk leiv . Bruk en 9',
#   '2018061207046 det blir en jevn og tykk 50 g finkornet strøsukker masse',
#   '2018061207046 ut til en 5 mm tykk leiv . Bruk en 7',
#   '2018061207046 det blir en jevn og tykk 1 ss finkornet strøsukker ,',
#   '2018061207046 ut til en 2 cm tykk firkantet leiv som måler 15',
#   '2018090407141 » spurte han med en tykk fransk aksent .',
#   '2018090407141 , kledd i frakk med tykk pelskrage . Skarpe øyne glimtet',
#   '2018090407141 fra kranarmen hang det en tykk kjetting . Og i enden',
#   '2018090407141 en slagmark . Mørk , tykk røyk veltet opp av steinruinen',
#   '2018090407141 , » sa Serpionov med tykk russisk aksent . Han rakte',
#   '2018081307043 bare klissete masse , like tykk som sirup . Heine måtte',
#   '2018081307043 - og den var så tykk at jeg kun ville bli',
#   '2018081307043 det viste jo bare hvor tykk døra var .',
#   '2019062777024 Pleieren rettet en tykk finger mot korridoren vi nettopp',
#   '2018062507081 stund tittet en lav , tykk ung fyr med fett hår',
#   '2018062507081 med stort hode og en tykk , musegrå hårmanke , lo',
#   '2018062507081 , en solid fem centimeter tykk sak , og slepte den',
#   '2018062507081 meg , som vognhjul gjennom tykk gjørme . « Kanskje ingen',
#   '2018062507081 mot tinningene . Luffen var tykk og sirupsaktig . Den vamle',
#   '2018060807050 lufta i rommet føltes så tykk at man nesten kunne løfte',
#   '2018060807050 hadde det begynt å sive tykk , grå røyk opp mellom',
#   '2018060807050 . Røyken var nå så tykk at det med jevne mellomrom',
#   '2019062777117 påfølgende dag , og en tykk tåke lå over leiren og',
#   '2019062777117 overhenget , så han en tykk , hvit tåke slynge seg',
#   '2018071807113 horn og til og med tykk panserhud for å forsvare seg',
#   '2018071807113 som fungerte som en slags tykk rustning .',
#   '2018071807113 bli mer enn 70 cm tykk , og en forskning viser',
#   '2018091107080 fet grå ponni , med tykk man og hale , et',
#   '2018091107080 min , og en slik tykk høyseng ! Og jeg var',
#   '2018091107080 le , men stemmen var tykk da han sa : «',
# ...
#   '2018082007037 Taoisme En gammel kinesisk religion eller tro som oppfordrer',
#   '2018082007037 Trigram Et kinesisk symbol som reprenterer et naturelement',
#   '2019011577029 - Duken er faktisk et kinesisk laken , fortalte Flora .',
#   '2019011577029 å spise med pinner på kinesisk restaurant et par ganger ,',
#   '2018042348631 Hvis vitenskapen kan åpne et kinesisk hjerte for Gud , må',
#   "2018083107101 Sifu - kinesisk for ' dyktig person '",
#   '2019082977071 None kinesisk .',
#   '2019082977071 mindre alt jeg kan på kinesisk .',
#   '2018062607616 med at beskjeden var på kinesisk og helt uforståelig da den',
#   '2018110607212 ikke engelsk . Det er kinesisk . Men kinesisk er ikke',
#   '2018110607212 Det er kinesisk . Men kinesisk er ikke bare ett språk',
#   '2018110607212 Seiv om alle kinesere snakker kinesisk , er det ikke sikkert',
#   '2018110607212 bloggen deres . Da en kinesisk kvinne ble ansatt som test-sover',
#   '2018060807050 hentet ned et glass med kinesisk sursøt saus . - Tar',
#   '2019072307202 kom en diger og feit kinesisk fyr vaggende inn som en',
#   '2019072307202 ut fra at alle med kinesisk eller japansk bakgrunn er flinke',
#   '2019072307202 som var fange i en kinesisk versjon av Camp Fatso',
#   '2019072307202 noe som lyder litt mer kinesisk , som Den sovende overvektige'],
#  'japansk': ['2018061807053 føre en enkel samtale på japansk , men spisepinner skjønte han',
#   '2018072007005 A : En japansk kjole B : Et verktøy',
#   '2018061207160 av Hayao Miyazaki Oversatt fra japansk av Øyvor Nyborg Språkkonsulent :',
#   '2018061207160 er innredet som et luksuriøst japansk vertshus ,',
#   '2018061207160 inspirert av mytiske skapninger fra japansk religion og sagn . Men',
#   '2018061207160 ikke basert på noe spesiell japansk myte , men er skapt',
#   '2018061207160 eller " støv-ånder " ( japansk original : makkuro kurosuke )',
#   '2018061907620 henne som om hun snakket japansk . « Du er klar',
#   '2018103007191 ut som en synopsis for japansk reality-tv , og Karou klarte',
#   '2019032277148 en high school-hacker med en japansk kjæreste han bare har møtt',
#   '2018060807148 None japansk by som hadde gått løs',
#   '2018030648100 kanskje ut som et vanlig japansk tempel , men La Pagode',
#   '2019062777075 med kaffe , sjasmin-te og japansk honningkake .',
#   '2019062777075 « Vi har jo et japansk tema her i kveld ,',
#   '2018060807151 . — Også kjent som japansk nasjonalrett .',
#   '2018071707526 å følge en gammel , japansk tradisjon ; Hun ville brette',
#   '2018071707526 Ifølge en japansk legende , vil alle som',
#   '2018071707526 vårdag i 1954 ble en japansk fiskebåt fanget i nedfallet etter',
#   '2019072407153 finne ut i hvilket tidsrom japansk tid Hanna kan ringe hjem',
#   '2018062707298 ene siden er det en japansk hage , på den andre',
#   '2018062707298 Clairmont . Hard modernitet og japansk None',
#   '2018060807142 jeg deg . Kinesisk eller japansk , kanskje ? Muligens koreansk',
#   '2018062607117 minnet det om kinesisk eller japansk , for tegnene var forseggjorte',
#   '2018072607143 å se ut som en japansk tegneseriefigur .',
#   '2018070507114 små selvstendige klesbutikker , en japansk , en thailandsk og en',
#   '2018091205064 at dette sannsynligvis var en japansk keiserkobra , en av de',
#   '2018091205064 som finnes . Og at japansk keiserkobra var verdens raskeste slange',
#   '2018091205064 Det var giften til en japansk keiserkobra .',
#   '2018091205064 nødt til å fange en japansk keiserkobra .',
#   '2018091205064 at ett bitt fra en japansk keiserkobra som regel var nok',
#   '2018091407057 jente hadde et veldig overbevisende japansk pass , seiv om hun',
#   '2018091407057 seiv om hun ikke var japansk seiv . Erin Bang Bang',
#   '2018092507061 , bengali , russisk , japansk , men her varierer rekkefølgen',
#   '2018061807082 skrikende , et eller annet japansk hands beste låt .',
#   '2018061807082 fylt med en grusom , japansk , poplåt som fikk Jake',
#   '2018081407135 disse språkene er kinesisk , japansk og russisk . Når du',
#   '2018060748085 på fransk eller engelsk , japansk eller italiensk . Andre satt',
#   '2011062708095 ein japanar . Eg er japansk None',
#   '2018031248066 renset nålene . Hun var japansk . Liten og svarthåret ,',
#   '2018060748090 renset nålene . Hun var japansk . Liten og svarthåret ,',
#   '2018070507023 bevegelser i en stille , japansk hage med bonsaitrær og rennende',
#   '2018070507023 lest en bok av en japansk forfatter som heter Hitomi Kanehara',
#   '2018061807629 Et japansk shintotempel',
#   '2018050748058 japonaise / føaponez ] adj japansk None',
#   '2018050748058 m ( - ef ) japansk adj japonais m ( -',
#   '2018091707005 hørtes ut som en middelmådig japansk fotballspiller .',
#   '2018070507046 farger , med en merkelig japansk tegneseriefigur på . Det er',
#   '2018110607212 en « dytter » på japansk . Og dytting er akkurat',
#   '2019072307202 at alle med kinesisk eller japansk bakgrunn er flinke til å',
#   '2019072307202 Den ettermiddagens verdenssport var sint japansk grynting ( den sinteste grynteren',
#   '2019091977020 finne ut i kva tidsrom japansk tid Hanna kan ringje heim',
#   '2018070507083 kasta gjennom vindauget på ein japansk restaurant . Like etter blei'],
#  'tamil': [],
#  'swahili': ['2018091407049 han sa . Han snakker swahili .',
#   '2018091407049 og tilbake , britisk og swahili , mens de stirrer opp'],
#  'kristendom': ['2018101007059 KRLE = kristendom , religion livssyn og etikk',
#   '2018101007059 kristen . Min religion heter kristendom . Det er omtrent',
#   '2018050448035 skulle kanskje ha lekseprøve i kristendom , men læreren hadde alltid',
#   '2018050448035 vestlige religionene - jødedom , kristendom og islam - har en',
#   '2018050448035 han kristen , men Augustins kristendom er i høy grad preget',
#   '2018050448035 ville tilbake til den opprinnelige kristendom slik',
#   '2018050448035 Tilbake til naturen 6. Humanisert kristendom 7. Menneskerettigheter',
#   '2018030548002 verdens skaper . Jødedom , kristendom og islam er religioner med',
#   '2018030548002 er felles for jødedom og kristendom , til dels også islam',
#   '2018030548002 i Bibelen , og ifølge kristendom , jødedom og islam de',
#   '2018030548002 over kunst knyttet til kristendom og jødedom',
#   '2018081307044 det finnes flere former for kristendom None',
#   '2018071707602 heile verda . Jødedom , kristendom og islam er religionar med',
#   '2018071707602 er felles for jødedom og kristendom , til dels også islam',
#   '2018071707602 i Bibelen - og ifølgje kristendom , jødedom og islam dei',
#   '2018041748224 , men gjennom innføring av kristendom blant samer , og etter',
#   '2018041748224 forsvinne etter 200 år med kristendom .',
#   '2018041748224 ætt og fostret opp i kristendom og ærbarhet skiller seg så',
#   '2018051448241 spørsmål . Det er i kristendom . De avtaler spørsmål og',
#   '2018101007238 Alexandria blir et sentrum for kristendom . Et av de første',
#   '2018061807629 None kristendom 244 , 245',
#   '2018050748058 [ kristjanism ] s m kristendom chrome [ krom ] s'],
#  'hinduisme': ['2018070507032 « Skriv om sex og hinduisme ... så blir det gøy',
#   '2018070507032 enn at jeg skal ha hinduisme og mytologi som tema .',
#   '2018050448035 None hinduisme 141 , 155 indre årsak',
#   '2018082007037 None hinduisme 26'],
#  'islam': ['2018101007059 Mona : Kristendommen , islam , jødedommen , og .',
#   '2018101007059 None islam og jødedommen',
#   '2018101007059 i islam .',
#   '2018101007059 muslim . Min religion heter islam . I verden finnes det',
#   '2018061807053 som betyr « forbudt av islam » .',
#   '2018061807053 spise svin er haram i islam . Det er også forbudt',
#   '2018061807053 imot å omvende henne til islam , hvis du skjønner hva',
#   '2018050448035 trodde på kristendommen eller på islam , da kaltes det bare',
#   '2018050448035 innen jødedommen , kristendommen og islam - understreker mystikeren at det',
#   '2018050448035 nådd langt gjennom utbredelsen av islam .',
#   '2018050448035 - jødedom , kristendom og islam - har en semittisk bakgrunn',
#   '2018050448035 i jødedommen , kristendommen og islam er det en grunnleggende tanke',
#   '2018030548002 . Jødedom , kristendom og islam er religioner med bare én',
#   '2018030548002 kristendom , til dels også islam - er Gud hellig .',
#   '2018030548002 ifølge kristendom , jødedom og islam de første som ble skapt',
#   '2018030548002 også en viktig plass i islam .',
#   '2018030548002 jødene skulle omvende seg til islam . De brente synagoger og',
#   '2018081307044 og innbyggere som frykter at islam og muslimer skal ta kontroll',
#   '2018081307044 PSV , ble diskusjonene om islam og muslimer i Europa mindre',
#   '2018081307044 Kvinnesynet i islam None',
#   '2018081307044 Mange av dem som kritiserer islam , peker på kvinnesynet i',
#   '2018081307044 det finnes flere former av islam , akkurat som det finnes',
#   '2018071707602 . Jødedom , kristendom og islam er religionar med berre éin',
#   '2018071707602 kristendom , til dels også islam - er Gud heilag .',
#   '2018071707602 ifølgje kristendom , jødedom og islam dei første som vart skapte',
#   '2018071707602 også ein viktig plass i islam .',
#   '2018071707602 og kva har han med islam å gjere ? 5 Korleis',
#   '2018101007238 30 - 31 ) og islam som preger dagliglivet . Jeg',
#   '2018101007238 mytologien blandes med ornamenter fra islam og symboler fra den koptiske',
#   '2018101007238 tilhører den sunni-muslimske retningen av islam . Det er en fundamentalistisk',
#   '2018101007238 dette vært praktisert lenge før islam kom til landene , og',
#   '2018101007238 erobres av araberne og innfører islam None',
#   '2018072307050 eksempel i islam , er det ikke akseptert',
#   '2018071807161 mange av innvandrerne som tilhøer islam , men at det er',
#   '2018071807161 Mange nordmenn er redde for islam og muslimer . De mener',
#   '2018071807161 og muslimer . De mener islam er en brutal religion .',
#   '2018071807161 om mange er skeptiske til islam , betyr det ikke at',
#   '2018071807161 . Dette hadde ingenting med islam å gjøre , sa de.',
#   '2018061807629 6 , ° # av islam , og ogsa for jøde',
#   '2018061807629 None islam 244 , 245',
#   '2018050748058 [ irypsjo ] sf invasjon islam [ islam ] s m',
#   '2018050748058 ] sf invasjon islam [ islam ] s m islam',
#   '2018050748058 [ islam ] s m islam None',
#   '2018050748058 / ; créme / glacée islam s islam m',
#   '2018050748058 créme / glacée islam s islam m',
#   '2018082007037 en grønn stjerne som symboliserer islam . Den arabiske påvirkningen er',
#   '2018082007037 og gjenspeiler befolkningens tro på islam .',
#   '2018082007037 for islam , Algeries statsreligion .',
#   '2018082007037 flagget , som står for islam . På Bhutans flagg representerer',
#   '2018082007037 nasjonalflagg 25 Irlands nasjonalflagg 19 islam 12 , 13 , 42'],
#  'muhammedanisme': [],
#  'taoisme': ['2019032277143 lest om buddhisme . Og taoisme . Jeg har ikke helt',
#   '2019032277143 hadde flørtet med buddhisme og taoisme . Frank lurte på om',
#   '2018082007037 None taoisme 26'],
#  'jødedom': ['2018060748079 fordi hun konverterte fra vanlig jødedom til chabad da hun var',
#   '2018050448035 de tre vestlige religionene - jødedom , kristendom og islam -',
#   '2018030548002 - som er felles for jødedom og kristendom , til dels',
#   '2018030548002 , og ifølge kristendom , jødedom og islam de første som',
#   '2018030548002 kunst knyttet til kristendom og jødedom None',
#   '2018030548002 og religionen deres ble kalt jødedom , I Babylon bygde de',
#   '2018030548002 og religionen deres ble kalt jødedom . Etter femti år i',
#   '2018071707602 - som er felles for jødedom og kristendom , til dels',
#   '2018071707602 - og ifølgje kristendom , jødedom og islam dei første som',
#   '2018071707602 og religionen deira vart kalla jødedom . I Babylon bygde dei',
#   '2018071707602 og religionen deira vart kalla jødedom . Etter femti år i'],
#  'koptisk': ['2018101007238 Kairo er det en egen koptisk bydel med flere veldig gamle',
#   '2018101007238 eksploderte en bombe i en koptisk kirke i Alexandria . 21',
#   '2018101007238 . Det finnes også en koptisk bydel med eldgamle kirker og',
#   '2018101007238 med eldgamle kirker og et koptisk komme tilbake . museum .'],
#  'katolisisme': ['2019030177042 jeg rådgivning om onani og katolisisme .',
#   '2018050748058 [ katolisism ] s m katolisisme catholique [ katolik ] s'],
#  'urfolk': ['2018072007192 a great time - har urfolk det flott / herleg tribe',
#   '2018061807641 None urfolk None',
#   '2018061807641 None urfolk None',
#   '2018061807641 None urfolk i',
#   '2018061807641 ( a ) n / urfolk inexperienced',
#   '2018061807641 opphavlege folkesetnad , urfolk None',
#   '2018020548041 native people innfødte , urfolk None',
#   '2018101007168 ★ Korleis samar og andre urfolk utnyttar ressursane i naturen .',
#   '2018101007168 . Desse folkegruppene blir kalla urfolk eller urfolks- Urfolk er folkegrupper',
#   '2018101007168 Dei fleste urfolk har eit levevis som gir',
#   '2018101007168 på har og gjort at urfolk kan ha store kunnskapar om',
#   '2018101007168 lenge ? Slike spørsmål kan urfolk rundt om i verda gi',
#   '2018101207012 native people innfødde , urfolk None',
#   '2018101205008 Fortel at samane er eit urfolk som har levd i Noreg'],
#  'indianer': ['2018070507073 ut som en hedning og indianer , så folk er glade',
#   '2018061807053 vært innfødt amerikaner eller muligens indianer eller førsteperson eller urinnvåner ,',
#   '2019032277143 seiv både som farget og indianer . « De burde gi',
#   '2018060807148 - Var faren din indianer , eller ?',
#   '2018030248032 enten det var å leke indianer eller å tegne . Da',
#   '2018050748058 2 indianer None',
#   '2018050748058 2 indianer y indifférence [ ediferas ]',
#   '2018050748058 None indianer s Indien m ( -',
#   '2018061107007 siden av gata ? En indianer , nærmere bestemt Jonas !',
#   '2018061807546 Antagelig sneket seg som en indianer gjennom buskene .',
#   '2018060748068 Kvinnen var indianer , mens mannen var hvit',
#   '2018060748068 var stengt når du var indianer og når du bodde på'],
#  'araber': ['2018061807053 sett en ekte , levende araber ? »',
#   '2018061807053 . Helt seriøst . En araber og en halvt jøde går',
#   '2018061807053 « Var han araber ? »',
#   '2018061807053 Nei , han var ikke araber . Han var fra Tyskland',
#   '2018050448035 None araber , arabisk 175 , 180',
#   '2019040977225 men mer som en liten araber . Den er smal over',
#   '2018050748058 ] s m / f araber None'],
#  'afrikaner': ['2018091205064 kunne bli brun som en afrikaner .',
#   '2018050748058 / [ afriken ] s afrikaner None',
#   '2018050748058 None afrikaner s Africain m ( -'],
#  'europeer': ['2018060748085 gang jeg byr en ekte europeer på tuff .',
#   '2018061807585 at han var den første europeer som hadde vært på stedet',
#   '2018050748058 / [ øropeen ] s europeer None',
#   '2018050748058 None europeer s Européen m ( -'],
#  'nordisk': ['2018072007005 10 m Hvilket nordisk flagg er rødt og hvitt',
#   '2018020248130 . Statsborgarar i eit anna nordisk land ( Sverige , Finland',
#   '2018050448035 Både indisk , gresk og nordisk mytologi har klare tilløp til',
#   '2018030548002 eller et urstoff . En nordisk myte forteller om da gudene',
#   '2018072507129 svarte offiseren med en bred nordisk dialekt som gjorde ordene hans',
#   '2018071707602 eller eit urstoff . Ein nordisk myte fortel om da gudane',
#   '2018041748224 , slik som nordorg.no ; nordisk None',
#   '2018041748224 Torp , pensjonert professor i nordisk språkvitenskap ved Universitetet i Oslo',
#   '2018061207040 del i Sverige og vant nordisk mesterskap i fjor . I',
#   '2018071707621 blir skildra som lys og nordisk . Mens den etterlyste mannen',
#   '2014111907535 , Seriepocket 194 SEMIC / nordisk forlag AS 1994',
#   '2018081407135 del i Sverige og vant nordisk mesterskap i fjor . I',
#   '2018050748058 nordique [ nordik ] adj nordisk None',
#   '2018050748058 nordfrå adv du nord nordisk adj nordique',
#   '2018082007037 land og har aiie et nordisk kors i sitt tiagg .',
#   '2018082007037 Nicaraguas nasjonalflagg 9 nordisk kors 16',
#   '2018110607212 i alpint , nordisk , snowboard eller telemark på',
#   '2018110607212 , hun ble også både nordisk og olympisk mester i kokkekunst',
#   '2018091407049 inn i skogen av en nordisk kjempe . Så jeg må']}

# %%
mmeta = mm.metadata(urns=list({x.split()[0] for w in konkordanser for x in konkordanser[w]}))
# Out:
# {'2011062708095': {'100-1- -a': 'Holm, Dagny',
#   '245-1-0-a': 'Zeppelin',
#   '260- - -c': '2007',
#   '653- - -a': 'grunnskolen, k06, lesebøker, lærebøker, mellomtrinnet, norsk',
#   'lang': 'nno',
#   'year': 2016},
#  '2014111907535': {'100-1- -a': 'Holm, Dagny',
#   '245-1-0-a': 'Zeppelin',
#   '260- - -c': '2007',
#   '653- - -a': 'grunnskolen, k06, lesebøker, lærebøker, norsk',
#   'lang': 'nno',
#   'year': 2015},
#  '2015090906138': {'100-1- -a': 'Daynes, Katie.',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, drager, draker, lettlest',
#   'lang': 'nno',
#   'year': 2015},
#  '2015091006002': {'100-1- -a': 'Punter, Russell.',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, lettlest',
#   'lang': 'nno',
#   'year': 2015},
#  '2015091006003': {'100-1- -a': 'Punter, Russell.',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, katter, lettlest',
#   'lang': 'nno',
#   'year': 2015},
#  '2015091006004': {'100-1- -a': 'Likar, Gudrun.',
#   '245-1-0-a': 'Prinsesse Fibi og draken',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, drager, draker, lettlest, prinsesser',
#   'lang': 'nno',
#   'year': 2015},
#  '2015091506021': {'100-1- -a': 'Muszynski, Eva',
#   '245-1-0-a': 'Cowboy-Claus og den prompande ponnien',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, lettlest',
#   'lang': 'nno',
#   'year': 2015},
#  '2015091506022': {'100-1- -a': 'Mackinnon, Mairi.',
#   '245-1-0-a': 'Sola og vinden :',
#   '245-1-0-b': 'basert på ein fabel av Æsop',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, fabler, lettlest, æsop',
#   'lang': 'nno',
#   'year': 2015},
#  '2015091506023': {'100-1- -a': 'Heinlein, Sylvia',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, lettlest',
#   'lang': 'nno',
#   'year': 2015},
#  '2015091506024': {'100-1- -a': 'Markhus, Vegard',
#   '245-1-0-a': 'Epleslang',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, barnelitteratur, lettlest, norsk',
#   'lang': 'nno',
#   'year': 2015},
#  '2015091506131': {'100-1- -a': 'Baltscheit, Martin.',
#   '245-1-0-a': 'Felline, professor Pål og kjemisettet',
#   '260- - -c': '2015',
#   'lang': 'nno',
#   'year': 2015},
#  '2017112048523': {'100-1- -a': 'Einarsen, Heidi Guttorm',
#   '260- - -c': 'Cop. 2015',
#   '653- - -a': 'geografi, grunnskole, k06, kunnskapsløftet, lærebøker, læreverk, samisk, språk',
#   'lang': 'sme',
#   'year': 2015},
#  '2017121808074': {'100-1- -a': 'Nesbø, Jo',
#   '245-1-0-a': 'Doktor Proktors tidsbadekar',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2017121908077': {'100-1- -a': 'Svingen, Vegard',
#   '245-1-0-a': 'Fredrik Fompel og tankemonstrene',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018013048046': {'260- - -c': '2015',
#   '653- - -a': 'grunnskole, k13, kunnskapsløftet, lærebøker, læreplan, læreverk, matematikk, revidert, ungdomstrinnet',
#   'lang': 'nob',
#   'year': 2015},
#  '2018013048165': {'100-1- -a': 'Arvola, Ingeborg',
#   '245-1-0-a': 'Ryktet',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018013048317': {'100-1- -a': 'Buchweitz, Donaldo.',
#   '245-1-0-a': 'Sjakk for barn',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018020148157': {'100-1- -a': 'Stranger, Simon',
#   '245-1-0-a': 'Bestefar på rømmen',
#   '260- - -c': '2015',
#   '653- - -a': 'alzheimers, barnebarn, barnebøker, barnelitteratur, besteforeldre, billedbøker, demens, norsk, sykdom',
#   'lang': 'nob',
#   'year': 2015},
#  '2018020248130': {'260- - -c': '2015', 'lang': 'nno', 'year': 2015},
#  '2018020248200': {'100-1- -a': 'Ganeri, Anita',
#   '245-1-0-a': 'Jorden på 2 minutter',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018020548041': {'260- - -c': '2015',
#   '653- - -a': 'engelsk, k13, lærebøker, læreverk, ungdomstrinnet',
#   'lang': 'mul',
#   'year': 2015},
#  '2018020548069': {'100-1- -a': 'Hofstad, Gunnleik',
#   '245-1-0-a': 'Venner for alltid :',
#   '245-1-0-b': 'en bok for tenåringer om relasjoner, kjærlighet og sex',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018020848041': {'100-1- -a': 'Diskin, Elizabeth',
#   '245-1-0-a': 'Enter 8',
#   '245-1-0-b': 'engelsk for ungdomstrinnet',
#   '260- - -c': '2015',
#   '653- - -a': 'engelsk, k13, lærebøker, læreverk, ungdomsskole, ungdomstrinnet',
#   'lang': 'mul',
#   'year': 2015},
#  '2018020848059': {'100-1- -a': 'Durham, Paul.',
#   '245-1-0-a': 'Lykkeravnene',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018020948005': {'260- - -c': '2015',
#   '653- - -a': 'grunnskolen, k13, kunnskapsløftetk06, lærebøker, læreplan, læreverk, matematikk, revidert, ungdomstrinnet',
#   'lang': 'nob',
#   'year': 2015},
#  '2018021248060': {'100-1- -a': 'From, Käte',
#   '245-1-0-a': 'Jeg tør ikke :',
#   '245-1-0-b': 'Line og Hamid engster seg',
#   '260- - -c': '2015',
#   '653- - -a': 'angst, barn, barnebøker, barnehagen, foreldre, intervensjon, mestring, panikk, panikkangst, psykologi, skolen, sosial',
#   'lang': 'nob',
#   'year': 2015},
#  '2018022048009': {'100-1- -a': 'Wright, Sally Ann.',
#   '245-1-0-a': 'Bibelandaktsboka',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018030248032': {'100-1- -a': 'Kroglund, Torolf',
#   '245-1-0-a': 'Tenk brett :',
#   '245-1-0-b': 'skateboarding i Norge',
#   '260- - -c': '2015',
#   '653- - -a': 'rullebrett, skateboarding, skating, sport',
#   'lang': 'nob',
#   'year': 2015},
#  '2018030548002': {'260- - -c': '2015', 'lang': 'nob', 'year': 2015},
#  '2018030548092': {'100-1- -a': 'Naas, Tor Erling',
#   '245-1-0-a': 'Ulvehjerte',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018030648100': {'100-1- -a': 'Bioret, Hugues',
#   '245-1-0-a': 'Paris for barn :',
#   '245-1-0-b': '64 sider med fakta og lek for å oppdage Paris',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018031248066': {'100-1- -a': 'Pettersen, Siri',
#   '245-1-0-a': 'Råta',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018031248072': {'100-1- -a': 'Svingen, Arne',
#   '245-1-0-a': 'Stormen',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, grøsser',
#   'lang': 'nob',
#   'year': 2015},
#  '2018031248157': {'260- - -c': '2015',
#   '653- - -a': 'grunnskolen, lærebøker, naturfag, samisk, språk',
#   'lang': 'sme',
#   'year': 2015},
#  '2018032348058': {'100-1- -a': 'Evensen, Liv Eirill',
#   '245-1-0-a': 'Drømmen om Neboria',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018032348091': {'100-1- -a': 'Williamson, Karen.',
#   '245-1-0-a': 'Godnatthistorier fra Bibelen :',
#   '245-1-0-b': 'tre, fem og ti minutters fortellinger',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018040948111': {'260- - -c': '2015',
#   '653- - -a': 'internett, personrett',
#   'lang': 'nob',
#   'year': 2015},
#  '2018041648021': {'100-1- -a': 'Adams, Anne',
#   '245-1-0-a': 'Bibel-fakta',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018041748224': {'260- - -c': '2015',
#   '653- - -a': 'grunnskole, grunnskolen, lærebøker, læreverk, norsk, språk, ungdomstrinnet',
#   'lang': 'mul',
#   'year': 2015},
#  '2018042048091': {'100-1- -a': 'Peers, Bobbie',
#   '245-1-0-a': 'Luridiumstyven',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018042348546': {'260- - -c': '2015', 'lang': 'nob', 'year': 2015},
#  '2018042348631': {'100-1- -a': 'Benge, Janet',
#   '245-1-0-a': 'David Livingstone :',
#   '245-1-0-b': 'Afrikas ildsjel',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018050348020': {'100-1- -a': 'Brown, Pierce.',
#   '245-1-0-a': 'Rød revolt',
#   '260- - -c': 'cop. 2015',
#   '653- - -a': 'fiction, framtidssamfunn, science, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018050448035': {'100-1- -a': 'Gaarder, Jostein',
#   '245-1-0-a': 'Sofies verden',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018050448237': {'100-1- -a': 'Bringsværd, Tor Åge',
#   '245-1-0-a': 'Karsten + Petra i Afrika :',
#   '245-1-0-b': 'aktivitetsbok med flotte klistremerker og en helt ny historie om Løveungen og Frøken Kanin',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018050448258': {'260- - -c': '2015', 'lang': 'nob', 'year': 2015},
#  '2018050748007': {'100-1- -a': 'Blanco, Laura',
#   '245-1-0-a': 'Moro med verdier :',
#   '245-1-0-b': '52 uker med aktiviteter for å lære barna',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018050748043': {'260- - -c': '2015', 'lang': 'nob', 'year': 2015},
#  '2018050748058': {'260- - -c': '2015', 'lang': 'mul', 'year': 2015},
#  '2018050748285': {'260- - -c': 'cop. 2015',
#   '653- - -a': 'barnebøker, dyr, forskning, jorda, kropp',
#   'lang': 'nob',
#   'year': 2015},
#  '2018050748306': {'260- - -c': '[2015?]',
#   '653- - -a': 'finsk, grunnskole, lærebøker, språk',
#   'lang': 'mul',
#   'year': 2015},
#  '2018050748307': {'100-1- -a': 'Taavetti, Salla',
#   '245-1-0-a': 'Finsk :',
#   '245-1-0-b': '6',
#   '260- - -c': '[2015?]',
#   '653- - -a': 'finsk, grunnskole, lærebøker, språk',
#   'lang': 'mul',
#   'year': 2015},
#  '2018050748567': {'100-1- -a': 'Egeland, Tom',
#   '245-1-0-a': 'Mumiens mysterium',
#   '260- - -c': 'cop. 2015',
#   '653- - -a': 'barnebøker, krim, litteratur, norsk, romaner, spenning, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018050748568': {'100-1- -a': 'Røssland, Tor Arve',
#   '245-1-0-a': 'Glimt',
#   '260- - -c': '2015',
#   'lang': 'nno',
#   'year': 2015},
#  '2018051448017': {'100-1- -a': 'Green, John',
#   '245-1-0-a': 'Will Grayson, Will Grayson',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018051448093': {'260- - -c': 'cop. 2015', 'lang': 'nob', 'year': 2018},
#  '2018051448241': {'100-1- -a': 'From, Käte',
#   '245-1-0-a': 'Tenk hvis? :',
#   '245-1-0-b': 'Sigrid og Erik engster seg',
#   '260- - -c': '2015',
#   '653- - -a': 'OCD, PTSD, angst, barn, barnebøker, fobier, generalisert, helseangst, intervensjon, mestring, panikk, panikkangst, posttraumatisk stresslidelse, separasjonsangst, skolen, sosial, sosial, sosial fobi, sykdomsangst, tvangslidelse, tvangstanker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018051448601': {'100-1- -a': 'Grøntvedt, Nina Elisabeth',
#   '245-1-0-a': 'Hei, det er meg! :',
#   '245-1-0-b': 'ikke la meg bli alene igjen her- ; (PS: Alt jeg nå skal fortelle deg, er 110 % sant!!!)',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018051648060': {'100-1- -a': 'Brandt, Sverre',
#   '245-1-0-a': 'Reisen til julestjernen :',
#   '245-1-0-b': 'et eventyr for barn i 5 bilder',
#   '260- - -c': '2015',
#   '653- - -a': 'barn, drama',
#   'lang': 'nob',
#   'year': 2015},
#  '2018052348076': {'100-1- -a': 'Alseth, Bjørnar',
#   '245-1-0-a': 'Multi [5-7]',
#   '260- - -c': '2015',
#   '653- - -a': 'grunnskolen, k13, kunnskapsløftetk06, lærebøker, læreplan, læreverk, matematikk, revidert',
#   'lang': 'nob',
#   'year': 2015},
#  '2018053048035': {'100-1- -a': 'Benge, Janet',
#   '245-1-0-a': 'Lillian Trasher :',
#   '245-1-0-b': 'Egypts største underverk',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060148120': {'260- - -c': '2015', 'lang': 'nob', 'year': 2015},
#  '2018060548201': {'100-1- -a': 'Gallego García, Laura',
#   '245-1-0-a': 'Til minne om Idhun',
#   '260- - -c': '[2015]',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060748060': {'100-1- -a': 'Kaldhol, Marit',
#   '245-1-0-a': 'Zweet',
#   '260- - -c': '2015',
#   '653- - -a': 'etikk, mot, ungdom, ungdomsbøker',
#   'lang': 'nno',
#   'year': 2015},
#  '2018060748061': {'100-1- -a': 'Stephens, John',
#   '245-1-0-a': 'Dødens bok',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060748062': {'100-1- -a': 'Rydland, Asbjørn',
#   '245-1-0-a': 'Fredlaus',
#   '260- - -c': '2015',
#   '653- - -a': 'fantastisk litteratur, fantasy, ungdomsbøker',
#   'lang': 'nno',
#   'year': 2015},
#  '2018060748068': {'100-1- -a': 'Hjulstad, Kjartan',
#   '245-1-0-a': 'Minnesota og støvet',
#   '260- - -c': '2015',
#   '653- - -a': 'alkoholisme, alkoholmisbruk, barn, familievold, indianere, litteratur, norsk, rasisme, skjønnlitteratur, ungdom',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060748070': {'260- - -c': '2015', 'lang': 'nob', 'year': 2015},
#  '2018060748076': {'100-1- -a': 'Linmo, Bente René',
#   '245-1-0-a': 'Lysbæreren',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060748077': {'100-1- -a': 'Pettersen, Siri',
#   '245-1-0-a': 'Evna',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060748078': {'100-1- -a': 'Guåker, Helene',
#   '245-1-0-a': 'Juksemaker',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060748079': {'100-1- -a': 'LaMarche, Una.',
#   '245-1-0-a': 'Bare i Brooklyn',
#   '260- - -c': '2015',
#   '653- - -a': 'amerikansk, litteratur, roman',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060748080': {'100-1- -a': 'Fjestad, Ellen',
#   '245-1-0-a': 'Døgnfluedans',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060748085': {'100-1- -a': 'Gaarder, Jostein',
#   '245-1-0-a': 'Kabalmysteriet',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060748090': {'100-1- -a': 'Pettersen, Siri',
#   '245-1-0-a': 'Råta',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060807044': {'100-1- -a': 'Lyga, Barry',
#   '245-1-0-a': 'Game',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060807049': {'100-1- -a': 'Johnsen, Janne Aasebø',
#   '245-1-0-a': 'Kamuflasje',
#   '260- - -c': '2015',
#   '653- - -a': 'forelskelse, norsk, oppvekst, romaner, ungdomsbøker, ungdomslitteratur',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060807050': {'100-1- -a': 'Mostue, Sigbjørn',
#   '245-1-0-a': 'Marlens historie',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060807051': {'260- - -c': 'cop. 2015', 'lang': 'nob', 'year': 2015},
#  '2018060807058': {'100-1- -a': 'Dashner, James',
#   '260- - -c': '2015',
#   '653- - -a': 'amerikansk, fiction, roman, science, ungdomslitteratur',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060807068': {'100-1- -a': 'Everest, D.D..',
#   '245-1-0-a': 'Archie Greene og det magiske museet',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, fantastisk, fantasy, magi, spenning, trolldom, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060807101': {'100-1- -a': 'Simukka, Salla',
#   '245-1-0-a': 'Svart som ibenholt',
#   '260- - -c': '2015',
#   '653- - -a': 'fantasy, finske, skjønnlitteratur, spenning, thrillere, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060807125': {'100-1- -a': 'Shannon, Samantha',
#   '245-1-0-a': 'Mimeordenen',
#   '260- - -c': 'cop. 2015',
#   '653- - -a': 'fantasy, romaner, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060807141': {'100-1- -a': 'Loughead, Deb',
#   '245-1-0-a': 'Trommer og trøbbel',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060807142': {'100-1- -a': 'Ingvaldsen, Bjørn',
#   '245-1-0-a': 'Sønnen til læreren',
#   '260- - -c': '2015',
#   '653- - -a': 'barn, barnebøker, fedre, humor',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060807146': {'100-1- -a': 'Palacio, R.J.',
#   '245-1-0-a': 'Mirakel',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060807147': {'100-1- -a': 'Rødstøl, Berit',
#   '245-1-0-a': 'Frøppeldunk',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, camping, miljøvern, vennskap',
#   'lang': 'nno',
#   'year': 2015},
#  '2018060807148': {'100-1- -a': 'Mostue, Sigbjørn',
#   '245-1-0-a': 'Brages historie',
#   '260- - -c': '2015',
#   '653- - -a': 'epidemier, framtidssamfunn',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060807149': {'100-1- -a': 'Jones, Gareth P.',
#   '245-1-0-a': 'Arvingene',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060807150': {'100-1- -a': 'Lindell, Unni',
#   '245-1-0-a': 'Elsker, elsker ikke',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060807151': {'100-1- -a': 'Linde, Heidi',
#   '245-1-0-a': 'Pym Pettersons mislykka skoleball',
#   '260- - -c': '2015',
#   '653- - -a': 'antiheltinner, barnelitteratur, humor, norsk, roman',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060807160': {'100-1- -a': 'Molaug, Marius Horn',
#   '245-1-0-a': 'Verdens verste ferie',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060807163': {'100-1- -a': 'McClintock, Norah.',
#   '245-1-0-a': 'Falske toner',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060807164': {'100-1- -a': 'Lian, Torun',
#   '245-1-0-a': 'Reserveprinsesse Andersen',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060807166': {'100-1- -a': 'Nortun, Harald',
#   '245-1-0-a': 'Eksperimentet :',
#   '245-1-0-b': 'roman',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, kjønnsroller, tvillinger',
#   'lang': 'nno',
#   'year': 2015},
#  '2018060807168': {'100-1- -a': 'Svingen, Arne',
#   '245-1-0-a': '[Gravplyndrere]',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060807170': {'100-1- -a': 'Karlsson, Ørjan N.',
#   '245-1-0-a': 'Tidsrosen',
#   '260- - -c': '2015',
#   '653- - -a': 'fantasy, norsk, skjønnlitteratur, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018060807173': {'100-1- -a': 'Dorsey, Angela.',
#   '245-1-0-a': 'Fanget av skygger',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061107004': {'100-1- -a': 'Kaup, Ulrike',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061107006': {'100-1- -a': 'Bosse, Sarah',
#   '245-1-3-a': 'Et monster i mattetimen',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061107007': {'100-1- -a': 'Bieniek, Christian',
#   '245-1-0-a': 'Gulrot-Guro og de sterke jentenes klubb',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061107008': {'100-1- -a': 'Kaup, Ulrike',
#   '245-1-3-a': 'En ny hest på gården',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061107009': {'100-1- -a': 'Nahrgang, Frauke',
#   '245-1-0-a': 'Fotballfortellinger',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061107011': {'100-1- -a': 'Mai, Manfred',
#   '245-1-0-a': 'Vennskapsfortellinger',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061107013': {'245-1-0-a': 'Heksa Lilli feirer fødselsdag',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061107015': {'100-1- -a': 'Kaup, Ulrike',
#   '245-1-0-a': 'Hestehistorier',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061107016': {'100-1- -a': 'Frey, Jana',
#   '245-1-0-a': 'Detektivhistorier',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061107017': {'245-1-0-a': 'Heksa Lilli tryller lekser',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061107018': {'100-1- -a': 'Banscherus, Jürgen',
#   '245-1-0-a': 'Tyggegummikomplottet',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061107019': {'100-1- -a': 'Bieniek, Christian',
#   '245-1-0-a': 'Gulrot-Guro og verdens søteste hund',
#   '260- - -c': '2015',
#   '653- - -a': 'hunder',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061107021': {'100-1- -a': 'Lindell, Unni',
#   '245-1-0-a': 'Kyss meg da, sa Ella',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061107023': {'100-1- -a': 'Losnegård, Rolf',
#   '260- - -c': 'cop. 2015',
#   '653- - -a': 'Arktis, barnebøker, humor, klimaendringer, litteratur, nynorsk   $$  norsk, oppfinnelser',
#   'lang': 'nno',
#   'year': 2015},
#  '2018061107044': {'100-1- -a': 'Pedersen, Bente',
#   '245-1-0-a': 'Ingen vei tilbake',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061107516': {'100-1- -a': 'Riordan, Rick',
#   '245-1-0-a': "Hades' hus",
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061207002': {'100-1- -a': 'Svatun, Birte',
#   '245-1-0-a': 'Kroppen',
#   '260- - -c': '2015',
#   '653- - -a': 'anatomi, barnebok, kropp, kroppen',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061207003': {'100-1- -a': 'Stokholm, Steen',
#   '245-1-0-a': 'Robin van Persie',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061207017': {'100-1- -a': 'Barder, Gemma.',
#   '245-1-0-a': 'Jentekveld',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061207020': {'100-1- -a': 'Bosse, Sarah',
#   '245-1-0-a': 'FK Kokosnøtt',
#   '260- - -c': '[2015]',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061207023': {'100-1- -a': 'Wahl, Andreas',
#   '245-1-0-a': 'Hvorfor smelter ost, men ikke skinke?',
#   '260- - -c': 'cop. 2015',
#   '653- - -a': 'barnebøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061207035': {'100-1- -a': 'Osland, Erna',
#   '245-1-0-a': 'Når det regnar i Afrika :',
#   '245-1-0-b': 'ei bok om vêr og klimaendringar',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, klima, klimaendringer, meteorologi, vêr, vær, værvarslinger',
#   'lang': 'nno',
#   'year': 2015},
#  '2018061207040': {'260- - -c': '2015',
#   '653- - -a': 'grunnskolen, lærebøker, mellomtrinnet, norsk',
#   'lang': 'nno',
#   'year': 2015},
#  '2018061207046': {'260- - -c': 'cop. 2015', 'lang': 'nob', 'year': 2015},
#  '2018061207048': {'100-1- -a': 'Jonsen, Jen.',
#   '245-1-0-a': 'Inviter til bursdagsfest!',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061207083': {'260- - -c': '2015',
#   '653- - -a': 'grunnskolen, k06, k13, kunnskapsløftet, lærebøker, læreplan, læreverk, matematikk, revidert',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061207155': {'260- - -c': '2015',
#   '653- - -a': 'grunnskolen, kunnskapsløftetk13, lærebøker, læreplan, læreverk, matematikk, revidert',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061207160': {'100-1- -a': 'Miyazaki, Hayao',
#   '245-1-0-a': 'Chihiro og heksene',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061207186': {'100-1- -a': 'Pastis, Stephan',
#   '245-1-0-a': 'Vi møtes igjen',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061207220': {'100-1- -a': 'Child, Lauren',
#   '245-1-0-a': 'Duften av død',
#   '260- - -c': '2015',
#   '653- - -a': 'spenningsromaner, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061207541': {'100-1- -a': 'Skjelvik, Jonny',
#   '245-1-0-a': 'Litt om dyr, og så god natt',
#   '260- - -c': '2015',
#   'lang': 'nno',
#   'year': 2015},
#  '2018061207595': {'100-1- -a': 'Nadin, Joanna',
#   '245-1-0-a': 'Krise-Kristine knuser rekorder',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, barnelitteratur, humor',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061407501': {'100-1- -a': 'Wegge, Kathrine',
#   '245-1-0-a': 'Rektor Knirk',
#   '260- - -c': '2015',
#   '653- - -a': 'grunnskole, lesing, lærebøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061407510': {'100-1- -a': 'Heiberg, Anette V.',
#   '245-1-0-a': 'Onkel Bjørn',
#   '260- - -c': '2015',
#   '653- - -a': 'grunnskole, lesing, lærebøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807012': {'100-1- -a': 'Banke, Peter',
#   '245-1-0-a': 'Alt om Chelsea',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807019': {'100-1- -a': 'Klepp, Anneli',
#   '245-1-0-a': 'Boble-løgner',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807021': {'100-1- -a': 'Platt, Chris.',
#   '245-1-0-a': 'Tilbake til livet',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807022': {'100-1- -a': 'Kallestad, Jarle',
#   '245-1-0-a': 'Som en tyv om natten',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807034': {'100-1- -a': 'Green, John',
#   '245-1-0-a': 'Papirbyer',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807050': {'100-1- -a': 'Grevet, Yves',
#   '245-1-0-a': 'Huset',
#   '260- - -c': '2015',
#   '653- - -a': 'dystopier, framtidssamfunn, franske, science fiction, spenning, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807053': {'100-1- -a': 'Green, John',
#   '245-1-3-a': 'En overflod av Katheriner',
#   '260- - -c': '2015',
#   '653- - -a': 'forelskelse, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807055': {'100-1- -a': 'Pantermüller, Alice',
#   '245-1-0-a': 'Skikkelig markelig',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807065': {'100-1- -a': 'Morgan, Sally',
#   '245-1-0-a': 'Dyrene',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, dyr, faktabøker, fauna, oppslagsverk',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807068': {'100-1- -a': 'Larsson, Åsa',
#   '245-1-0-a': 'Trollharen',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807069': {'100-1- -a': 'Larsson, Åsa',
#   '245-1-0-a': 'Nidstangen',
#   '260- - -c': '2015',
#   '653- - -a': 'barnelitteratur, spenning',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807080': {'100-1- -a': 'Daugherty, C.J.',
#   '245-1-0-a': 'Bak murene',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807082': {'100-1- -a': 'Bolstad, Anna Eline',
#   '245-1-0-a': 'Ut av byen',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807084': {'100-1- -a': 'Kapelrud, Kristian',
#   '245-1-0-a': 'Pakten',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807085': {'100-1- -a': 'Benge, Janet',
#   '245-1-0-a': 'C.S. Lewis :',
#   '245-1-0-b': 'fantastisk historieforteller',
#   '260- - -c': 'cop. 2015',
#   '653- - -a': 'forfattere, storbritannia',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807086': {'100-1- -a': 'Kaaberbøl, Lene',
#   '245-1-0-a': 'Slangens gåve',
#   '260- - -c': '2015',
#   '653- - -a': 'fantastisk, fantasy, litteratur',
#   'lang': 'nno',
#   'year': 2015},
#  '2018061807087': {'100-1- -a': 'Hunter, Erin',
#   '245-1-0-a': 'Midnatt',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807088': {'100-1- -a': 'Kaaberbøl, Lene',
#   '245-1-0-a': 'Skammarkrigen',
#   '260- - -c': '2015',
#   '653- - -a': 'fantastisk, fantasy, litteratur',
#   'lang': 'nno',
#   'year': 2015},
#  '2018061807524': {'100-1- -a': 'Berlin, Andrea',
#   '245-1-0-a': 'Hester i konkurranse',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807531': {'100-1- -a': 'Alseth, Bjørnar',
#   '245-1-0-a': 'Multi [5-7]',
#   '260- - -c': '2015',
#   '653- - -a': 'grunnskolen, k13, kunnskapsløftet, lærebøker, læreverk, matematikk, revidert læreplan',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807546': {'100-1- -a': 'Ødegård, Jan',
#   '245-1-0-a': 'Balder spion og fippskjeggkjæresten',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807560': {'100-1- -a': 'Widmark, Martin',
#   '245-1-0-a': 'Brannmysteriet',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, barnelitteratur, krim, svensk',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807565': {'100-1- -a': 'McClintock, Norah.',
#   '245-1-0-a': 'Hvem er den skyldige?',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807572': {'100-1- -a': 'Master, Maryam',
#   '245-1-0-a': 'Rumling i jungelen',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807581': {'260- - -c': 'cop. 2015', 'lang': 'nob', 'year': 2015},
#  '2018061807585': {'100-1- -a': 'Røste, Inger Johanne',
#   '245-1-0-a': 'Løven og gutten som ble glad :',
#   '245-1-0-b': 'en historie fra Zimbabwe',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, flukt, zimbabwe',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807629': {'100-1- -a': 'Morris, Neil',
#   '245-1-0-a': 'Juniorleksikon',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018061807641': {'100-1- -a': 'Solberg, Cecilie',
#   '245-1-0-a': 'Stairs',
#   '260- - -c': '2015',
#   '653- - -a': 'engelsk, grunnskolen, lærebøker, mellomtrinnet',
#   'lang': 'mul',
#   'year': 2015},
#  '2018061907620': {'100-1- -a': 'Riordan, Rick',
#   '245-1-0-a': 'Athenes merke',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, fantastisk, fantasy, gresk mytologi, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062207513': {'100-1- -a': 'Velander, Pernilla',
#   '245-1-0-a': 'Herlige føll',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062507013': {'100-1- -a': 'Yancey, Rick.',
#   '245-1-0-a': 'Det endeløse havet',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062507069': {'100-1- -a': 'Taylor, Laini',
#   '245-1-0-a': 'Mørk engel',
#   '260- - -c': '2015',
#   '653- - -a': 'amerikansk, fantasy, ungdomslitteratur',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062507072': {'100-1- -a': 'Noreng, Jan Tore',
#   '260- - -c': '2015',
#   '653- - -a': 'instagram, internett, skjønnlitteratur, ungdomsbøker, ungdomsromaner',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062507081': {'100-1- -a': 'Stroud, Jonathan',
#   '260- - -c': '2015',
#   '653- - -a': 'ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062607026': {'100-1- -a': 'Kort, Kees de.',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062607029': {'260- - -c': 'cop. 2015', 'lang': 'nob', 'year': 2015},
#  '2018062607030': {'100-1- -a': 'Aakeson, Kim Fupz',
#   '245-1-0-a': 'Jeg er William',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062607050': {'100-1- -a': 'Cooper, Sari.',
#   '245-1-0-a': 'Elvehesten',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062607117': {'100-1- -a': 'Stephens, John',
#   '245-1-0-a': 'Ildkrøniken',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062607590': {'100-1- -a': 'Gifford, Clive.',
#   '245-1-0-a': 'Verdensrommet på 2 minutter',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062607615': {'100-1- -a': 'From, Käte.',
#   '245-1-0-a': 'Jeg vil! :',
#   '245-1-0-b': 'Emil og Trine bestemmer selv',
#   '260- - -c': '2015',
#   '653- - -a': 'ansvar, barn, barnepsykologi, bestemme, psykologi, selv, selvbestemmelse, utviklingspsykologi, vilje',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062607616': {'100-1- -a': 'From, Käte',
#   '245-1-0-a': 'Konger og dronninger :',
#   '245-1-0-b': 'Aleksander og Julie bestemmer selv',
#   '260- - -c': '2015',
#   '653- - -a': 'ansvar, atferd, barn, barnepsykologi, bestemme, psykologi, selvbestemmelse, utfordrende, utviklingspsykologi, vilje',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062707003': {'100-1- -a': 'Husebye, Sylvi Jane',
#   '245-1-0-a': 'Perlene',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062707051': {'100-1- -a': 'Aveyard, Victoria',
#   '245-1-0-a': 'Rød dronning',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062707211': {'100-1- -a': 'Bade, Anne Helene Røise',
#   '245-1-0-a': 'Quest',
#   '260- - -c': '2015',
#   '653- - -a': 'engelsk, grunnskolen, lærebøker, læreverk',
#   'lang': 'mul',
#   'year': 2015},
#  '2018062707213': {'100-1- -a': 'Bade, Anne Helene Røise',
#   '245-1-0-a': 'Quest 1-7',
#   '260- - -c': '2015',
#   '653- - -a': 'barnetrinnet, engelsk, grunnskolen, k13, lærebøker, læreverk',
#   'lang': 'mul',
#   'year': 2015},
#  '2018062707252': {'100-1- -a': 'Delaney, Joseph',
#   '245-1-0-a': 'Vokterens skjebne',
#   '260- - -c': '2015',
#   '653- - -a': 'fantasy, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062707298': {'100-1- -a': 'Lockhart, E.',
#   '245-1-0-a': 'Vi var løgnere',
#   '260- - -c': '2015',
#   '653- - -a': 'romaner, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062807019': {'100-1- -a': 'Fry, Michael',
#   '245-1-0-a': 'Bøllebråk',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062807021': {'100-1- -a': 'Smith, Dan',
#   '245-1-0-a': 'Big game :',
#   '245-1-0-b': 'jakten er i gang',
#   '260- - -c': '2015',
#   '653- - -a': 'ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062807048': {'100-1- -a': 'Stranger, Simon',
#   '245-1-0-a': 'De som ikke finnes',
#   '260- - -c': '2015',
#   '653- - -a': 'skjønnlitteratur, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062807068': {'100-1- -a': 'Walliams, David',
#   '245-1-0-a': 'Demontannlegen',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, barnelitteratur, humor, romaner, tannlegeskrekk',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062807087': {'100-1- -a': 'Loughead, Deb',
#   '245-1-0-a': '3 ville sommerdager',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062807091': {'100-1- -a': 'Wandahl, Camilla',
#   '245-1-0-a': 'Havets tåre',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018062807108': {'100-1- -a': 'Næss, Robert',
#   '245-1-0-a': 'Katastrofekvelden',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018070307047': {'100-1- -a': 'Renslebråten, Line',
#   '245-1-0-a': 'Fugler :',
#   '245-1-0-b': 'fakta og fortellinger fra hele verden',
#   '260- - -c': 'cop. 2015',
#   '653- - -a': 'barnebøker, eventyr, fabler, folketro, fugler, sagaer',
#   'lang': 'nob',
#   'year': 2015},
#  '2018070307078': {'100-1- -a': 'Schulze, Anne-Marie',
#   '245-1-0-a': "Los geht's",
#   '260- - -c': '2015',
#   '653- - -a': 'grunnskole, lærebøker, tysk',
#   'lang': 'mul',
#   'year': 2015},
#  '2018070307085': {'245-1-0-a': 'Skal vi starte band?',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018070405001': {'100-1- -a': 'Schulze, Anne-Marie',
#   '245-1-0-a': "Los geht's",
#   '260- - -c': '2015',
#   '653- - -a': 'grunnskole, lærebøker, tysk',
#   'lang': 'mul',
#   'year': 2015},
#  '2018070405041': {'100-1- -a': 'Joma, Liv Karin',
#   '245-1-0-a': 'Gïeline åahpenidh 5 :',
#   '245-1-0-b': 'barkoe-gærja : åarjelsaemien voestesgïeline',
#   '260- - -c': '2015',
#   '653- - -a': 'grunnskole, lærebøker, språk, sørsamisk',
#   'lang': 'sma',
#   'year': 2015},
#  '2018070507002': {'100-1- -a': 'Shusterman, Neal',
#   '245-1-0-a': 'Edisons kjeller',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018070507005': {'100-1- -a': 'Munch, Charlotte Glaser',
#   '245-1-0-a': '7 døgn for oss',
#   '260- - -c': '2015',
#   '653- - -a': 'litteratur, norsk, romaner, tenåringer, ungdomsbøker, ungdomsromaner',
#   'lang': 'nob',
#   'year': 2015},
#  '2018070507008': {'100-1- -a': 'Mæhle, Lars',
#   '245-1-0-a': 'Bouvetøya 2052 :',
#   '245-1-0-b': 'roman',
#   '260- - -c': '2015',
#   '653- - -a': 'Bouvetøya, framtidssamfunn, klimaendringer, romanar, science fiction, skjønnlitteratur, spenning, ungdomsbøker',
#   'lang': 'nno',
#   'year': 2015},
#  '2018070507023': {'100-1- -a': 'Sævareid, Heidi',
#   '245-1-0-a': 'Slipp hold',
#   '260- - -c': '2015',
#   '653- - -a': 'kjærlighet, kontroll, makt, skjønnlitteratur, suspension, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018070507030': {'100-1- -a': 'Bødker, Benni',
#   '245-1-0-a': 'Alene i mørket',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018070507032': {'100-1- -a': 'Naveen, Neha',
#   '245-1-0-a': 'Stupekontroll',
#   '260- - -c': '2015',
#   '653- - -a': 'litteratur, norsk, roman, søstre a   $$  hemmeligheter, ungdomsbøker, ungdomslitteratur',
#   'lang': 'nob',
#   'year': 2015},
#  '2018070507046': {'100-1- -a': 'McLachlan, Jenny.',
#   '245-1-0-a': 'Danse-trøbbel',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018070507056': {'100-1- -a': 'Collins, Suzanne',
#   '245-1-0-a': 'Underland-krøniken',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018070507073': {'100-1- -a': 'Spyri, Johanna',
#   '245-1-0-a': 'Heidis lære- og vandreår :',
#   '245-1-0-b': 'roman',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018070507083': {'100-1- -a': 'Muchamore, Robert',
#   '245-1-0-a': 'Generalen',
#   '260- - -c': '2015',
#   'lang': 'nno',
#   'year': 2015},
#  '2018070507097': {'100-1- -a': 'Weberg, Liv Marit',
#   '245-1-0-a': 'Det er heldigvis ingen som trenger meg',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018070507099': {'100-1- -a': 'Oseman, Alice',
#   '245-1-0-a': 'Solospill',
#   '260- - -c': '2015',
#   '653- - -a': 'blogging, forelskelse, internett, tenåringer, ungdom, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018070507114': {'100-1- -a': 'Nielsen, Susin.',
#   '245-1-0-a': 'Vi er molekyler',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018070507115': {'100-1- -a': 'Collins, Suzanne',
#   '245-1-0-a': 'Underland-krøniken',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018071207014': {'100-1- -a': 'Dixon, Franklin W..',
#   '245-1-0-a': 'Forsakelsens hus',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018071207031': {'100-1- -a': 'Torkildsen, Terje',
#   '245-1-0-a': 'Arrfjes :',
#   '245-1-0-b': 'roman',
#   '260- - -c': '2015',
#   '653- - -a': '1800-tallet, historie, seilskuter, sjømenn',
#   'lang': 'nno',
#   'year': 2015},
#  '2018071207044': {'100-1- -a': 'Peterson, Andrew',
#   '245-1-0-a': 'Vokteren og Vargekongen :',
#   '245-1-0-b': 'havdrager, en desperat søken, og det endelige slaget om Den skinnende øya',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018071207094': {'100-1- -a': 'Røyset, Ingunn',
#   '245-1-0-a': 'Aldri fred å få :',
#   '245-1-0-b': 'roman',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, barnelitteratur, litteratur, norsk, tidsreiser, verdenskrigen',
#   'lang': 'nno',
#   'year': 2015},
#  '2018071207097': {'100-1- -a': 'Næss, Robert',
#   '245-1-0-a': 'Gullfeber',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018071207150': {'100-1- -a': 'Parvela, Timo',
#   '245-1-0-a': 'Invitasjonen',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018071607045': {'100-1- -a': 'Aspeli, Widar',
#   '245-1-0-a': 'Sort enke :',
#   '245-1-0-b': 'Mustangen',
#   '260- - -c': '2015',
#   '653- - -a': 'barn, besteforeldre, kjærlighet, savn, sorg',
#   'lang': 'nob',
#   'year': 2015},
#  '2018071607094': {'260- - -c': '2015',
#   '653- - -a': 'barnetrinnet, grunnskolen, lærebøker, naturfag, samfunnsfag',
#   'lang': 'nno',
#   'year': 2015},
#  '2018071607133': {'100-1- -a': 'Marsden, John',
#   '245-1-0-a': 'Checkers',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018071707023': {'100-1- -a': 'Ecklund, Gunhild J.',
#   '245-1-0-a': 'Hva er økonomi? :',
#   '245-1-0-b': 'fakta og funderinger',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018071707031': {'100-1- -a': 'Edwards, Ellen M. Tudor',
#   '245-1-0-a': 'Explore',
#   '245-1-0-b': 'engelsk for barnesteget',
#   '260- - -c': '2015',
#   '653- - -a': 'barnetrinnet, engelsk, grunnskolen, k06, lærebøker',
#   'lang': 'mul',
#   'year': 2015},
#  '2018071707046': {'260- - -c': '2015',
#   '653- - -a': 'barnetrinnet, grunnskolen, lærebøker, læreverk, naturfag, samfunnsfag',
#   'lang': 'nno',
#   'year': 2015},
#  '2018071707090': {'100-1- -a': 'Schutten, Jan Paul',
#   '245-1-0-a': 'Livets gåter og de stinkende sokkene til Jonas Gnist',
#   '260- - -c': 'cop. 2015',
#   '653- - -a': 'barnebøker, biologi, evolusjon, naturfag, naturhistorie, utviklingslæren',
#   'lang': 'nob',
#   'year': 2015},
#  '2018071707526': {'100-1- -a': 'Kompelien, Kåre',
#   '245-1-0-a': 'Sadako og de 1000 papirtranene',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018071707590': {'100-1- -a': 'Rørvik, Bjørn F.',
#   '245-1-0-a': 'Purriot og skimysteriet',
#   '260- - -c': '[2015]',
#   '653- - -a': 'barnelitteratur, humor, krim, norsk',
#   'lang': 'nob',
#   'year': 2015},
#  '2018071707602': {'260- - -c': '2015',
#   '653- - -a': 'etikk, livssyn, religion',
#   'lang': 'nno',
#   'year': 2015},
#  '2018071707621': {'100-1- -a': 'Bruheim, Magnhild',
#   '245-1-0-a': 'Hyttemysteriet :',
#   '245-1-0-b': 'roman',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, litteratur, norsk, spenning, spenningsbøker, stesøsken, ungdomsbøker',
#   'lang': 'nno',
#   'year': 2015},
#  '2018071707626': {'100-1- -a': 'Hagerup, Hilde',
#   '245-1-0-a': 'Hvite mareritt',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018071807113': {'260- - -c': 'cop. 2015', 'lang': 'nob', 'year': 2015},
#  '2018071807138': {'100-1- -a': 'Edwards, Ellen M. Tudor',
#   '245-1-0-a': 'Explore',
#   '245-1-0-b': 'engelsk for barnesteget',
#   '260- - -c': '2015',
#   '653- - -a': 'barnetrinnet, engelsk, grunnskolen, k06, lærebøker',
#   'lang': 'mul',
#   'year': 2015},
#  '2018071807142': {'100-1- -a': 'Rasch-Halvorsen, Anne',
#   '245-1-0-a': 'Tusen millioner',
#   '260- - -c': '2015',
#   '653- - -a': 'grunnskolen, kunnskapsløftetk13, lærebøker, læreplan, læreverk, matematikk, revidert',
#   'lang': 'nob',
#   'year': 2015},
#  '2018071807144': {'260- - -c': '2015',
#   '653- - -a': 'barnetrinnet, grunnskolen, lærebøker, læremiddel, læreverk, norsk',
#   'lang': 'nno',
#   'year': 2015},
#  '2018071807155': {'260- - -c': '2015',
#   '653- - -a': 'grunnskolen, grunnskulen, k06, kunnskapsløftet, lærebøker, læreverk, matematikk, ungdomstrinnet',
#   'lang': 'nno',
#   'year': 2015},
#  '2018071807161': {'100-1- -a': 'Skjønsberg, Harald',
#   '245-1-0-a': 'Terror',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, historie, terror, terrorisme, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018071807208': {'100-1- -a': 'Solbjør, Cathrine Myhre',
#   '245-1-0-a': 'På rømmen i dusteland',
#   '260- - -c': '2015',
#   '653- - -a': 'barnelitteratur, norsk',
#   'lang': 'nob',
#   'year': 2015},
#  '2018071807261': {'100-1- -a': 'Norlin, Arne',
#   '245-1-0-a': 'Oppgjøret',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018071807267': {'100-1- -a': 'Fitzgerald, Sarah Moore.',
#   '245-1-0-a': 'Tro, håp og eplekake :',
#   '245-1-0-b': 'det er alltid noen smuler igjen-',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018071807295': {'100-1- -a': 'Kaaberbøl, Lene',
#   '245-1-0-a': 'Skammarteiknet',
#   '260- - -c': '2015',
#   '653- - -a': 'fantastisk, fantasy, litteratur',
#   'lang': 'nno',
#   'year': 2015},
#  '2018071807321': {'100-1- -a': 'Anly, Ingeborg',
#   '245-1-0-a': 'Kaleido',
#   '260- - -c': '2015',
#   '653- - -a': 'barnetrinnet, grunnskolen, k13, lærebøker, læreverk, norsk',
#   'lang': 'nob',
#   'year': 2015},
#  '2018071907044': {'100-1- -a': 'Alseth, Bjørnar',
#   '245-1-0-a': 'Multi [5-7]',
#   '260- - -c': '2015',
#   '653- - -a': 'grunnskolen, k06, kunnskapsløftet, lærebøker, læreverk, matematikk',
#   'lang': 'nno',
#   'year': 2015},
#  '2018071907159': {'100-1- -a': 'Wänblad, Mats',
#   '245-1-3-a': 'Et monster går på kino',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072007005': {'260- - -c': 'cop. 2015', 'lang': 'nob', 'year': 2015},
#  '2018072007092': {'100-1- -a': 'Tufvesson, Paulina.',
#   '245-1-0-a': 'Hest &amp; klikkertrening',
#   '260- - -c': '[2015?]',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072007158': {'100-1- -a': 'Hjardar, Espen',
#   '245-1-0-a': 'Faktor',
#   '260- - -c': '2015',
#   '653- - -a': 'grunnskolen, k13, kunnskapsløftetk06, lærebøker, læreplan, læreverk, matematikk, revidert, ungdomstrinnet',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072007166': {'100-1- -a': 'Gjerdrum, Anne-Lise',
#   '245-1-0-a': 'Tusen millioner',
#   '260- - -c': '2015',
#   '653- - -a': 'grunnskolen, kunnskapsløftetk06, lærebøker, læreverk, matematikk',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072007192': {'100-1- -a': 'Solberg, Cecilie',
#   '245-1-0-a': 'Stairs',
#   '260- - -c': '2015',
#   '653- - -a': 'engelsk, grunnskolen, lærebøker, læreverk, mellomtrinnet',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072007193': {'100-1- -a': 'Diskin, Elizabeth',
#   '245-1-0-a': 'Enter 8',
#   '245-1-0-b': 'engelsk for ungdomssteget',
#   '260- - -c': '2015',
#   '653- - -a': 'engelsk, grunnskolen, k0613, lærebøker, ungdomstrinnet',
#   'lang': 'mul',
#   'year': 2015},
#  '2018072307050': {'100-1- -a': 'Helland, Tarjei',
#   '245-1-0-a': 'Samfunnskunnskap 9',
#   '260- - -c': '2015',
#   '653- - -a': 'grunnskolen, k06, k13, kunnskapsløftet, lærebøker, læreplan, læreverk, revidert, samfunnsfag',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072307178': {'100-1- -a': 'Øvreås, Håkon',
#   '245-1-0-a': 'Svartle',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072307192': {'100-1- -a': 'Knape, Wolfgang',
#   '245-1-0-a': 'Robinson Crusoe',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072407083': {'100-1- -a': 'Gaarder, Jostein',
#   '245-1-0-a': 'I et speil i en gåte',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072407144': {'100-1- -a': 'Hovden, Magne',
#   '245-1-0-a': 'Blodhevn',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507027': {'260- - -c': 'cop. 2015', 'lang': 'nob', 'year': 2015},
#  '2018072507059': {'100-1- -a': 'Larsen, Frode Eie',
#   '245-1-0-a': 'Englefjær :',
#   '245-1-0-b': 'krimroman',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507066': {'100-1- -a': 'Ragde, Anne B.',
#   '245-1-0-a': 'Mannen og de kranglesyke sønnene',
#   '260- - -c': 'cop. 2015',
#   '653- - -a': 'barnebøker, billedbøker, fabler, lettlest, æsops',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507075': {'100-1- -a': 'Igland, Torborg',
#   '245-1-0-a': 'Flukten',
#   '260- - -c': '2015',
#   '653- - -a': 'framtidssamfunn',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507079': {'100-1- -a': 'Kolu, Siri',
#   '245-1-0-a': 'Røvernes herre',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507082': {'100-1- -a': 'Saanum, Kari',
#   '245-1-0-a': 'Gråt, baby :',
#   '245-1-0-b': 'roman',
#   '260- - -c': '2015',
#   '653- - -a': 'alkoholmisbruk, foreldre, forelskelse, lettlest, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507084': {'100-1- -a': 'Larsson, Åsa',
#   '245-1-0-a': 'Grimen',
#   '260- - -c': '2015',
#   '653- - -a': 'barnelitteratur, spenning, varulver',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507085': {'100-1- -a': 'Larsson, Åsa',
#   '245-1-0-a': 'Utburden',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507086': {'100-1- -a': 'Lampard, Frank',
#   '245-1-0-a': 'Frankie vs. Ridder FK',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507087': {'100-1- -a': 'Kaaberbøl, Lene',
#   '245-1-0-a': 'Atterkomaren',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, dansk, fantastisk, hekser, litteratur, trolldom',
#   'lang': 'nno',
#   'year': 2015},
#  '2018072507129': {'100-1- -a': 'Flanagan, John',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507132': {'100-1- -a': 'Frohde, Liv',
#   '245-1-0-a': 'Jacob og hunden',
#   '260- - -c': '2015',
#   '653- - -a': 'dyr, hundar, hunder, litteratur, norsk, sorg',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507144': {'100-1- -a': 'Simon, Francesca',
#   '245-1-0-a': 'Rampete Robins fakta om dyr',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507145': {'100-1- -a': 'Søgaard, Pia',
#   '245-1-0-a': 'Bibel - hverdag - tweens',
#   '260- - -c': 'cop. 2015',
#   '653- - -a': 'barnebøker, bibelen, fortellinger, gt, kristendom',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507151': {'100-1- -a': 'Ewo, Jon',
#   '245-1-0-a': 'Zombiejakten',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507154': {'100-1- -a': 'Ingvaldsen, Bjørn',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507172': {'100-1- -a': 'Borge, Synnøve',
#   '245-1-0-a': 'Bubo bubo',
#   '260- - -c': '2015',
#   '653- - -a': 'grunnskole, grunnskolen, lærebøker, læreverk, norsk, språk',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507194': {'100-1- -a': 'Griffiths, Andy',
#   '245-1-0-a': 'Verdens mest korrekte faktabok om kroppen',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507195': {'100-1- -a': 'Ingebrigtsen, Hilde Hurlen',
#   '245-1-0-a': 'Skogens hemmelighet',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507196': {'100-1- -a': 'Horst, Jørn Lier',
#   '245-1-0-a': 'Rivertongåten',
#   '260- - -c': 'cop. 2015',
#   '653- - -a': 'barnebøker, spenning',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507197': {'100-1- -a': 'Horst, Jørn Lier',
#   '245-1-0-a': 'Hodeskallegåten',
#   '260- - -c': 'cop. 2015',
#   '653- - -a': 'barn, barnebøker, kriminalromaner, norsk, skjønnlitteratur, ungdom',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507198': {'100-1- -a': 'Kavanagh, Pamela.',
#   '245-1-0-a': 'Hovslag i det fjerne',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507201': {'100-1- -a': 'Riordan, Rick',
#   '245-1-0-a': 'Slangens skygge',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507204': {'100-1- -a': 'Shepard, Sara',
#   '245-1-0-a': 'Knust',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507211': {'100-1- -a': 'Knudsen, Sverre',
#   '245-1-0-a': 'Aarons maskin :',
#   '245-1-0-b': 'roman',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507216': {'100-1- -a': 'Kapelrud, Kristian',
#   '245-1-0-a': 'Det siste slaget',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507217': {'100-1- -a': 'Kapelrud, Kristian',
#   '245-1-0-a': 'I begynnelsen var tegnet',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507218': {'100-1- -a': 'Scieszka, Jon',
#   '245-1-0-a': 'Frank Einstein og antimateriemotoren',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, fiction, roboter, science, vitenskap',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507250': {'100-1- -a': 'Ingvaldsen, Bjørn',
#   '245-1-0-a': 'Nissekrigen',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018072507251': {'100-1- -a': 'Johansen, Eldrid',
#   '245-1-0-a': 'Scenegrøss',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, barnelitteratur, korsang, lettlest, mot, norsk, sceneskrekk',
#   'lang': 'nob',
# ...
#   'lang': 'mul',
#   'year': 2015},
#  '2018101107218': {'100-1- -a': 'Heide, Beate',
#   '245-1-0-a': 'Iiddáš ja guovssahas :',
#   '245-1-0-b': 'girjjáš eallima - ja jápmima - birra',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebok, død, døden',
#   'lang': 'mul',
#   'year': 2015},
#  '2018101205008': {'260- - -c': '2015',
#   '653- - -a': 'grunnskole, lærebøker, norsk',
#   'lang': 'nno',
#   'year': 2015},
#  '2018101207012': {'260- - -c': '2015',
#   '653- - -a': 'engelsk, grunnskolen, k0613, lærebøker, ungdomstrinnet',
#   'lang': 'mul',
#   'year': 2015},
#  '2018101677002': {'100-1- -a': 'Kirkegaard, Ole Lund',
#   '245-1-0-a': 'Frode og de andre skøyerne',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, danske, humor',
#   'lang': 'nob',
#   'year': 2015},
#  '2018102207015': {'100-1- -a': 'Roth, Veronica',
#   '245-1-0-a': 'Opprøreren',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018102207047': {'100-1- -a': 'Kroglund, Andrew P.',
#   '245-1-0-a': 'Farlig date :',
#   '245-1-0-b': 'ungdomsroman',
#   '260- - -c': 'cop. 2015',
#   '653- - -a': 'spenning, ungdomsroman',
#   'lang': 'nob',
#   'year': 2015},
#  '2018102207052': {'100-1- -a': 'Knudsen, Sverre',
#   '245-1-0-a': 'Aarons hevn :',
#   '245-1-0-b': 'roman',
#   '260- - -c': '2015',
#   '653- - -a': 'fantastisk, fiction, litteratur, norsk, science, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018102307030': {'100-1- -a': 'Uri, Helene',
#   '245-1-0-a': 'Fordi jeg elsker deg',
#   '260- - -c': '2015',
#   '653- - -a': 'barnelitteratur, forelskelse, forelskingmanipulering, mishandling, norsk, svik, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018102307054': {'100-1- -a': 'Saddlewick, A.B.',
#   '245-1-0-a': 'Skoleskrekk',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018102307108': {'100-1- -a': 'Hunter, Erin.',
#   '245-1-0-a': 'Farlige spor',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018102307113': {'100-1- -a': 'Bredow, Katarina von',
#   '245-1-0-a': 'Hun &amp; han',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018102307120': {'100-1- -a': 'Collins, Suzanne',
#   '245-1-0-a': 'Underland-krøniken',
#   '260- - -c': '2015',
#   '653- - -a': 'ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018102505077': {'100-1- -a': 'Heger, Halvor',
#   '245-1-0-a': 'Crossroads 10',
#   '245-1-0-b': 'engelsk for ungdomstrinnet',
#   '260- - -c': '2015',
#   '653- - -a': 'engelsk, grunnskolen, k06, k13, læreplan, læreverk, revidert, ungdomstrinnet',
#   'lang': 'mul',
#   'year': 2015},
#  '2018103007024': {'100-1- -a': 'Alseth, Bjørnar',
#   '245-1-0-a': 'Multi [5-7]',
#   '260- - -c': '2015',
#   '653- - -a': 'grunnskolen, k06, k13, kunnskapsløftet, lærebøker, læreplan, læreverk, matematikk, revidert',
#   'lang': 'nob',
#   'year': 2015},
#  '2018103007055': {'100-1- -a': 'Naas, Tor Erling',
#   '245-1-0-a': 'Flammetenner',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018103007068': {'100-1- -a': 'Waldemar, Karina',
#   '245-1-0-a': 'Lappe-Mikkel',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018103007073': {'100-1- -a': 'Otterlei, Camilla Dahle',
#   '245-1-0-a': 'Kunsten å møte en bjørn',
#   '260- - -c': '2015',
#   '653- - -a': 'barnehager, bildebøker, billedbøker, mobbing, norsk barnelitteratur',
#   'lang': 'nob',
#   'year': 2015},
#  '2018103007076': {'100-1- -a': 'Wiik, Øystein',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018103007083': {'100-1- -a': 'Dashner, James',
#   '245-1-0-a': 'The maze runner',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018103007191': {'100-1- -a': 'Taylor, Laini',
#   '245-1-0-a': 'Støv &amp; stjerneskinn',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018103007239': {'100-1- -a': 'Dougherty, John',
#   '245-1-0-a': 'Pizzatrøbbel',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018103007280': {'100-1- -a': 'Byron, Louise.',
#   '245-1-0-a': 'Det forlatte hotellet',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018103007345': {'100-1- -a': 'Aurstad, Tore',
#   '245-1-0-a': 'Stå dønn stille! ; Knask eller knep',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018103077004': {'100-1- -a': 'Steinholm, Monika',
#   '245-1-0-a': 'Fuck verden',
#   '260- - -c': 'cop. 2015',
#   '653- - -a': 'forelskelse, forelsking, kjærleik, kjærlighet, litteratur, norsk, skjønnlitteratur, ungdomsbøker, ungdomslitteratur',
#   'lang': 'nob',
#   'year': 2015},
#  '2018103077006': {'100-1- -a': 'Voss, Vera.',
#   '245-1-0-a': 'Modellene',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018110607129': {'260- - -c': '2015',
#   '653- - -a': 'bønnebøker, bønner, kristne',
#   'lang': 'nob',
#   'year': 2015},
#  '2018110607143': {'100-1- -a': 'Pritchett, Georgia',
#   '245-1-0-a': 'Wilfred redder verden',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, engstelse, humor, lettlest',
#   'lang': 'nob',
#   'year': 2015},
#  '2018110607212': {'100-1- -a': 'Fuglehaug, Randi',
#   '245-1-0-a': 'Slik blir du statsminister :',
#   '245-1-0-b': 'og 99 andre morsomme ting du kan gjøre når du blir stor',
#   '260- - -c': 'cop. 2015',
#   '653- - -a': 'barnebøker, yrker, yrkesvalg',
#   'lang': 'nob',
#   'year': 2015},
#  '2018110607223': {'100-1- -a': 'Alvær, Frøydis',
#   '245-1-0-a': 'Mer enn bare luft',
#   '260- - -c': 'cop. 2015',
#   '653- - -a': 'barnebøker, barnelitteratur, norsk',
#   'lang': 'nob',
#   'year': 2015},
#  '2018110677076': {'100-1- -a': 'Grøntvedt, Nina Elisabeth',
#   '245-1-0-a': 'Happy ending, liksom?',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, barnelitteratur, forelskelse, norsk, ungdomsskolen',
#   'lang': 'nob',
#   'year': 2015},
#  '2018112177019': {'100-1- -a': 'Ryan, Carrie.',
#   '245-1-0-a': 'Skogen av klør og tenner',
#   '260- - -c': '2015',
#   '653- - -a': 'ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018112177044': {'100-1- -a': 'Soltvedt, Thor',
#   '245-1-0-a': 'Fire minutter på overtid :',
#   '245-1-0-b': 'ungdomsroman',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018112377040': {'100-1- -a': 'Griffiths, Andy',
#   '245-1-0-a': 'Gutta i det du-tror-det-ikke-før-du-får-se-det store trehuset med 52 etasjer',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018120777019': {'100-1- -a': 'Døvle, Monica Østby',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018120777022': {'260- - -c': '2015',
#   '653- - -a': 'litteratur, musikarar, musikere, musikk, norsk, noveller, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2018120777029': {'100-1- -a': 'Ewo, Jon',
#   '245-1-0-a': '1992',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018120777084': {'100-1- -a': 'Mæhle, Lars',
#   '245-1-0-a': 'Skoddefyrstens hevn',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2018120777091': {'100-1- -a': 'Coben, Harlan',
#   '245-1-0-a': 'Oppdageren :',
#   '245-1-0-b': 'en Mickey Bolitar-roman',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019011448520': {'100-1- -a': 'Waldemar, Jarle',
#   '245-1-0-a': 'Let og finn i bibelhistorier :',
#   '245-1-0-b': 'Jesus-fortellinger',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019011577020': {'100-1- -a': 'Riordan, Rick',
#   '245-1-0-a': "Olympos' blod",
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019011577029': {'100-1- -a': 'Roholte, Dorte.',
#   '245-1-0-a': 'Skjøre hjerter',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019012577012': {'100-1- -a': 'Wills, Amanda',
#   '245-1-0-a': 'Ponnien i skogen :',
#   '245-1-0-b': 'Amanda Wills',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019021477022': {'100-1- -a': 'Dahl, Roald',
#   '245-1-0-a': 'Georgs magiske medisin',
#   '260- - -c': '2015',
#   '653- - -a': 'banebøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2019021477023': {'100-1- -a': 'Dahl, Roald',
#   '245-1-0-a': 'Charlie og sjokoladefabrikken',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, humor, nonsens',
#   'lang': 'nob',
#   'year': 2015},
#  '2019022777017': {'100-1- -a': 'Lindgren, Astrid',
#   '245-1-0-a': 'Pippi Langstrømpe går ombord',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, litteratur, svensk',
#   'lang': 'nob',
#   'year': 2015},
#  '2019022777029': {'100-1- -a': 'Svingen, Arne',
#   '245-1-0-a': 'Benny-Bobs biffbanan',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019022777030': {'100-1- -a': 'Walgermo, Alf Kjetil',
#   '245-1-0-a': 'Kjære søster',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, døden, facebook, sorg, søstre, ungdomsbøker',
#   'lang': 'nno',
#   'year': 2015},
#  '2019022877013': {'100-1- -a': 'Lunde, Maja',
#   '245-1-0-a': 'Sceneskrekk',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019030177042': {'100-1- -a': 'Smith, Andrew',
#   '245-1-0-a': 'Gresshoppejungel :',
#   '245-1-0-b': 'hele historien',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019032277117': {'100-1- -a': 'Hoftun, Guro',
#   '245-1-0-a': 'Ord på S',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, død, døden, foreldreløs, litteratur, norsk, sakn, savn, sorg, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2019032277143': {'100-1- -a': 'Riordan, Rick',
#   '245-1-0-a': 'Neptuns sønn',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, fantastisk, fantasy, gresk mytologi, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2019032277148': {'100-1- -a': 'Zadoff, Allen.',
#   '245-1-0-a': 'Oppdraget',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019032277165': {'100-1- -a': 'Malot, Hector',
#   '245-1-0-a': 'Frendelaus',
#   '260- - -c': '2015',
#   'lang': 'nno',
#   'year': 2015},
#  '2019040977225': {'100-1- -a': 'Bruhn, Ina.',
#   '245-1-0-a': 'Sofie &amp; Alvar',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019040977258': {'100-1- -a': 'Storaker, Marit Fadum',
#   '245-1-0-a': 'Desemberreisen',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019051407004': {'100-1- -a': 'Dybvig, Per',
#   '245-1-0-a': 'Jegeren :',
#   '245-1-0-b': 'en fortelling fra skogen',
#   '260- - -c': 'cop. 2015',
#   '653- - -a': 'barnelitteratur, bildebok, dyr, natur, skog, tegning',
#   'lang': 'nob',
#   'year': 2015},
#  '2019052007002': {'100-1- -a': 'Shusterman, Neal',
#   '245-1-0-a': 'Teslas loft',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019052007126': {'100-1- -a': 'Tjønn, Brynjulf Jung',
#   '245-1-0-a': 'Så vakker du er :',
#   '245-1-0-b': 'ungdomsroman',
#   '260- - -c': '2015',
#   'lang': 'nno',
#   'year': 2015},
#  '2019052007131': {'100-1- -a': 'Dougherty, John',
#   '245-1-0-a': 'Grøss og grevling!',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019052007132': {'100-1- -a': 'Sortland, Bjørn',
#   '245-1-0-a': 'Nedtelling',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019052107016': {'100-1- -a': 'Ragde, Anne B.',
#   '245-1-0-a': 'Haren og skilpadden',
#   '260- - -c': 'cop. 2015',
#   '653- - -a': 'barnebøker, bildebøker, billedbøker, eventyr, fabler, lettlest, æsops',
#   'lang': 'nob',
#   'year': 2015},
#  '2019052107114': {'100-1- -a': 'Dybvig, Ingeborg',
#   '245-1-0-a': 'Forfulgt i London',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, detektivfortellinger, spenning',
#   'lang': 'nob',
#   'year': 2015},
#  '2019052107116': {'100-1- -a': 'Simukka, Salla',
#   '245-1-0-a': 'Rød som blod',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019052107170': {'100-1- -a': 'Arnesen, Laura Kristine.',
#   '245-1-0-a': 'Lett å flette :',
#   '245-1-0-b': 'trinn-for-trinn : en guide til de flotteste flettefrisyrene',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019052107171': {'100-1- -a': 'Hagerup, Hilde',
#   '245-1-0-a': 'Barnet mitt',
#   '260- - -c': '2015',
#   '653- - -a': 'barn, foreldre, lettlest, skjønnlitteratur',
#   'lang': 'nob',
#   'year': 2015},
#  '2019061977006': {'100-1- -a': 'Guttorm, Anna Anita',
#   '245-1-0-a': 'Skuvlla-Biehtára Ánne ja Bohkosahtti dáža sirkus =',
#   '245-1-0-b': 'Skole-Petter Anna og Det lattervekkende norske sirkus',
#   '260- - -c': '2015',
#   'lang': 'mul',
#   'year': 2015},
#  '2019061977014': {'100-1- -a': 'Delaney, Joseph',
#   '245-1-0-a': 'Vokterens mareritt',
#   '260- - -c': '2015',
#   '653- - -a': 'fantasy, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2019062507014': {'100-1- -a': 'Edwards, Ellen M. Tudor',
#   '245-1-0-a': 'Explore',
#   '245-1-0-b': 'engelsk for barnetrinnet',
#   '260- - -c': '2015',
#   '653- - -a': 'barnetrinnet, engelsk, grunnskolen, k13, lk06, lærebøker, læreverk',
#   'lang': 'mul',
#   'year': 2015},
#  '2019062777016': {'100-1- -a': 'Wandel, Andrea.',
#   '245-1-0-a': 'Lumske planer',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019062777024': {'100-1- -a': 'Parvela, Timo',
#   '245-1-0-a': 'Ella og nattens riddere',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019062777075': {'100-1- -a': 'Dahlin, Petrus',
#   '245-1-0-a': 'Samlingen',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019062777081': {'100-1- -a': 'Kaaberbøl, Lene',
#   '245-1-0-a': 'Skammarens dotter',
#   '260- - -c': '2015',
#   'lang': 'nno',
#   'year': 2015},
#  '2019062777086': {'100-1- -a': 'Rendtorff, Ida-Marie',
#   '245-1-0-a': 'Atomsonen',
#   '260- - -c': '2015',
#   '653- - -a': 'fantasy, framtidssamfunn, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2019062777117': {'100-1- -a': 'Hunter, Erin',
#   '245-1-0-a': 'Måneskinn',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019072307060': {'260- - -c': '2015',
#   '653- - -a': 'barnetrinnet, grunnskolen, lærebøker, læreverk, norsk',
#   'lang': 'nno',
#   'year': 2015},
#  '2019072307093': {'100-1- -a': 'Egeland, Tom',
#   '245-1-0-a': 'Skatten fra Miklagard',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019072307096': {'100-1- -a': 'Walstad, Anette M.',
#   '245-1-0-a': 'Advokatbaronen',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019072307202': {'100-1- -a': 'McGowan, Anthony',
#   '245-1-0-a': 'Flukten fra Camp Fatso',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019072407152': {'260- - -c': '2015',
#   '653- - -a': 'grunnskolen, k13, kunnskapsløftet, lærebøker, læreplan, læreverk, matematikk, revidert',
#   'lang': 'nob',
#   'year': 2015},
#  '2019072407153': {'260- - -c': '2015',
#   '653- - -a': 'grunnskolen, k13, kunnskapsløftet, lærebøker, læreplan, læreverk, matematikk, revidert',
#   'lang': 'nob',
#   'year': 2015},
#  '2019072407161': {'260- - -c': '2015',
#   '653- - -a': 'barnetrinnet, grunnskolen, lærebøker, læremiddel, læreverk, norsk',
#   'lang': 'nno',
#   'year': 2015},
#  '2019081477002': {'100-1- -a': 'Mjønes, Johan B.',
#   '245-1-0-a': 'Kaptein Nemos testamente',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019081477049': {'100-1- -a': 'Sugg, Zoe',
#   '245-1-0-a': 'Girl online',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019082977035': {'100-1- -a': 'Saint-Exupéry, Antoine de',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019082977037': {'100-1- -a': 'Parvela, Timo',
#   '245-1-0-a': 'Ella dag og natt',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019082977040': {'100-1- -a': 'Enger, Cecilie',
#   '245-1-0-a': 'Kjell-Aksel rocker',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019082977071': {'100-1- -a': 'Zadoff, Allen.',
#   '245-1-0-a': 'Våpenet',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019091977003': {'100-1- -a': 'Ohlsson, Kristina',
#   '245-1-0-a': 'Sølvgutten',
#   '260- - -c': '2015',
#   '653- - -a': 'barnebøker, romaner, spenning, ungdomsbøker',
#   'lang': 'nob',
#   'year': 2015},
#  '2019091977020': {'260- - -c': '2015',
#   '653- - -a': 'barnetrinnet, grunnskolen, k0613, lærebøker, matematikk',
#   'lang': 'nno',
#   'year': 2015},
#  '2019091977032': {'100-1- -a': 'Yancey, Rick.',
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019101577025': {'100-1- -a': 'Voss, Vera.',
#   '245-1-0-a': 'Hevnen',
#   '260- - -c': 'cop. 2015',
#   'lang': 'nob',
#   'year': 2015},
#  '2019102877022': {'100-1- -a': 'Dahl, Tor Edvin',
#   '245-1-0-a': "Seier'n er vår!",
#   '260- - -c': '2015',
#   'lang': 'nob',
#   'year': 2015}}

# %%
from IPython.display import HTML

# %%
nb.frame(mmeta).to_excel('metadata.xls')

# %% [markdown]
# ## Lag katalog over ordlistene

# %%
oversikt ={key: nb.frame_sort(
    nb.frame(
        {w:float(babi.loc[babi.index == w].sum()) for w in ordgrupper[key] },
        'frekv'
    )
) for key in ordgrupper.keys()}

# %% [markdown]
# # Oversikt over frekvens av ord
#
# Her vil vi også kunne lage dokumentfrekvens ganske greit. "Om litt" :)

# %%
oversikt['seksualitet']
# Out:
#          frekv
# bi       136.0
# homofil   74.0
# transe    56.0
# homse     15.0
# lesbisk   10.0
# bifil      6.0
# lesbe      3.0
#  trans     0.0

# %%
oversikt['nasjonalitet']
# Out:
#              frekv
# russisk      115.0
# arabisk       82.0
# polsk         50.0
# afrikansk     37.0
# amerikaner    27.0
# islandsk      22.0
# russer        10.0
# hindu          5.0
# asiat          5.0
# grønlandsk     2.0
# japaner        2.0
#  pakistansk    0.0
# grønlender     0.0

# %%
oversikt['religion']
# Out:
#                 frekv
# islam            66.0
# jødedom          11.0
# hinduisme         4.0
# koptisk           4.0
# taoisme           3.0
# katolisisme       2.0
#  kristendom       0.0
# muhammedanisme    0.0

# %%
oversikt['geografi']
# Out:
#            frekv
# Europa     576.0
# Australia  478.0
# Afrika     411.0
# Amerika    223.0
# Asia       192.0
# Antarktis  112.0
# Arktis      39.0
# Ural         3.0
#  Norden      0.0

# %%
oversikt['nasjonalitet']
# Out:
#              frekv
# russisk      115.0
# arabisk       82.0
# polsk         50.0
# afrikansk     37.0
# amerikaner    27.0
# islandsk      22.0
# russer        10.0
# hindu          5.0
# asiat          5.0
# grønlandsk     2.0
# japaner        2.0
#  pakistansk    0.0
# grønlender     0.0

# %%
oversikt['språk']
# Out:
#              frekv
# fransk       360.0
# tysk         348.0
# svensk       221.0
# dansk        179.0
# finsk        150.0
# spansk       122.0
# russisk      115.0
# italiensk    113.0
# kinesisk     105.0
# arabisk       82.0
# samisk        68.0
# japansk       60.0
# polsk         50.0
# islandsk      22.0
# portugisisk   16.0
# urdu           7.0
# pakistansk     4.0
# swahili        2.0
# grønlandsk     2.0
# litauisk       1.0
# castillano     0.0
# tamil          0.0
#  engelsk       0.0

# %%
oversikt['kulturmarkør']
# Out:
#             frekv
# samisk       68.0
# amerikaner   27.0
# nordisk      19.0
# indianer     12.0
# araber        7.0
# europeer      4.0
# afrikaner     3.0
#  urfolk       0.0
