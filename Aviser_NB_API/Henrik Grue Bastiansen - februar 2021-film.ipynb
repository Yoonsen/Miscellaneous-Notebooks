# %% [markdown]
# Starter med å importere dhlab
#
# Hvis dhlab ikke fins må den installeres

# %% [markdown]
# Når den er installert, er det bare å importere, gjør den klar i notebook

# %%
import dhlab.nbtext as nb

# %% [markdown]
# Da er alle kommandoene i modulen dhlab.nbtext tilgjengelig

# %%
søkeord = 'film'

# %%
nb.concordance(søkeord, yearfrom = 1950, yearto = 1960, corpus = 'avis', before = 12, after = 12)
# Out:
# <table><tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_jaerbladet_null_null_19550104_7_1_1?searchText=film' target='_'>jaerbladet-19550104</a></td><td>kan fremja kultur og moral mel lom ungdomen , som foredrag ,</td><td>film</td><td style='text-align:left'>, musikk 03 god underhaldning . Og så lar vi organisasjonane stella</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_jaerbladet_null_null_19550114_7_4_1?searchText=film' target='_'>jaerbladet-19550114</a></td><td>og interessant . Det var lagt opp på ein populær måte med</td><td>film</td><td style='text-align:left'>, foredrag og ordskifte , og trass i det vart kort tid</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_jaerbladet_null_null_19550114_7_4_1?searchText=film' target='_'>jaerbladet-19550114</a></td><td>utgreiing om 4 - H-klubbane og ideen med desse . Han viste</td><td>film</td><td style='text-align:left'>frå klubbarbeidet , og frå dyrkingsfelt som klubbane har . Etter foredraget</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_jaerbladet_null_null_19550114_7_4_1?searchText=film' target='_'>jaerbladet-19550114</a></td><td>heldt eit lærerikt foredrag om hand- og maskinmjølking , og viste ellss</td><td>film</td><td style='text-align:left'>. Laurdags kvelden var kurset gjester hjå Time Bygdeungdomslag til fest på</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_jaerbladet_null_null_19550121_7_6_1?searchText=film' target='_'>jaerbladet-19550121</a></td><td>— Skudedirektør h . v. K . Markhus fortel og syner ein</td><td>film</td><td style='text-align:left'>. — Ein film om Israel . Opplesing . Musikk , Mat</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_hamararbeiderblad_null_null_19600810_35_183_1?searchText=film' target='_'>hamararbeiderblad-19600810</a></td><td>Norge og så trajf det seg slik at jeg skulle lage en</td><td>film</td><td style='text-align:left'>for Finnemisjonen . Misjonens sekretær skal også nordover og meningen er å</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_hamararbeiderblad_null_null_19600810_35_183_1?searchText=film' target='_'>hamararbeiderblad-19600810</a></td><td>. Misjonens sekretær skal også nordover og meningen er å lage en</td><td>film</td><td style='text-align:left'>i 15 mm og i farger om Finnemisjonens arbeid og . virke</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_hamararbeiderblad_null_null_19600810_35_183_1?searchText=film' target='_'>hamararbeiderblad-19600810</a></td><td>om Finnemisjonens arbeid og . virke der nord . Til en slik</td><td>film</td><td style='text-align:left'>er det vanskelig å lage manuskriptet på forhand , men et synopsis</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_hamararbeiderblad_null_null_19600324_35_71_1?searchText=film' target='_'>hamararbeiderblad-19600324</a></td><td>det hele med offentlig fest . Her får man tale og kanskje</td><td>film</td><td style='text-align:left'>av stortingsrepresentanten , som vil ta en med til fiskernes kår .</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_hamararbeiderblad_null_null_19600324_35_71_1?searchText=film' target='_'>hamararbeiderblad-19600324</a></td><td>turisttrafikken . Tradisjonen tro spanderte samvirkelaget god bevertning og det ble vist</td><td>film</td><td style='text-align:left'>. Johansens trio spilte så opp til dans og gamle og unge</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_haugesundsavis_null_null_
td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19550104_63_2_1?searchText=film' target='_'>stavangeraftenblad-19550104</a></td><td>til Amerika . En gang i siste halvpart av januar står en</td><td>film</td><td style='text-align:left'>, nokså langt utenom det vanlige , på programmet i Verdensteatret .</td></tr>
# <tr><td><a href='h

# %% [markdown]
# Teller opp kontekstord for målordet (her 'avis') med `collocation`

# %%
coll = nb.collocation(søkeord, yearfrom = 1950, yearto = 1960, corpus = 'avis', before = 5, after = 5)

# %% [markdown]
# Kan lage kollokasjon av ord til høyre

# %%
coll_h = nb.collocation(søkeord, yearfrom = 1950, yearto = 1960, corpus = 'avis', before = 0, after = 5)

# %% [markdown]
# Og en for ord til venstre

# %%
coll_v = nb.collocation(søkeord, yearfrom = 1950, yearto = 1960, corpus = 'avis', before = 5, after = 0)

# %%
coll.head(10)
# Out:
#       0
# !   500
# "   284
# #    15
# $    13
# %    49
# &   104
# '   866
# (  1250
# )  1193
# *   629

# %% [markdown]
# Vi kan sammenligne med en referanse, bruker normalen fra bøker.

# %%
ref = nb.frame(nb.totals(150000))

# %%
ref.head(30)
# Out:
#                0
# .     1265723110
# ,     1105303412
# og     543432056
# i      460246057
# det    273411583
# som    265144740
# til    254500136
# er     248764786
# av     235180661
# en     231631623
# på     205990369
# for    202452659
# at     199527660
# -      195716474
# å      184201667
# med    182427175
# )      172258528
# var    153392365
# ?      151860120
# den    151216998
# (      149848981
# de     140087564
# ikke   137898651
# :      121576250
# han    115410512
# «      110767054
# »      109061643
# har    106345926
# om     105027818
# et     101265956

# %% [markdown]
# Lager en variabel `assoc`for å lagre de viktigste ordene

# %%
assoc = nb.frame_sort(nb.frame(coll[0]/ref[0]))

# %%
assoc.head(10)
# Out:
#                      0
# bevertning    0.014732
# 13.00         0.014117
# televisjon    0.013641
# lysbilder     0.012039
# Entré         0.010770
# 14.00         0.010391
# kåseri        0.009146
# hovedrollene  0.008564
# Entre         0.008280
# utlodning     0.007440

# %% [markdown]
# Da ser vi høyre og venstrekontekst

# %%
assoc_h = nb.frame_sort(nb.frame(coll_h[0]/ref[0]))

# %%
assoc_h.head(10)
# Out:
#                    0
# Entré       0.010770
# bevertning  0.010511
# televisjon  0.009428
# 13.00       0.009098
# Entre       0.008280
# lysbilder   0.007168
# Filmen      0.006612
# utlodning   0.006437
# 6.40        0.004569
# kåseri      0.004143

# %% [markdown]
# Her assosiasjoner til høyre

# %%
assoc_v = nb.frame_sort(nb.frame(coll_v[0]/ref[0]))

# %%
assoc_v.head(20)
# Out:
#                        0
# 14.00           0.010353
# innspillingen   0.006720
# Heyerdahls      0.006690
# hovedrollene    0.006272
# tredimensjonal  0.006097
# fremvisning     0.006042
# instruktiv      0.005895
# 19.30           0.005110
# 13.00           0.005018
# kåseri          0.005003
# lysbilder       0.004871
# allsang         0.004786
# framsyning      0.004551
# bevertning      0.004222
# televisjon      0.004213
# fremvist        0.004131
# fornøyelig      0.003999
# underholdende   0.003954
# Arets           0.003493
# hovedrollen     0.003259

# %% [markdown]
# Visualisere med ordskyer eller nettverk

# %%
nb.cloud(assoc.head(50))

# %% [markdown]
# Lager med nøkkelord, og ser på forholdet mellom dem

# %%
nøkkelord = ["journalist", "redaktør", "journalisten", "readaktøren"]

# %%
assoc.loc[[x for  x in nøkkelord if x in assoc.index]].plot(kind='bar', rot=30)

# %% [markdown]
# Finn totalen, hvor ofte nøkkelordene forekommer

# %%
coll.loc[[x for  x in nøkkelord if x in coll.index]].plot(kind='bar', rot=30)
