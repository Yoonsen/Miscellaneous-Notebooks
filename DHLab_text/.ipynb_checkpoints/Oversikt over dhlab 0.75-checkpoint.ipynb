# %% [markdown]
# # Oversikt over dhlab versjon 0.75
#
# Her følger litt info om dagens DHlab, som kan hjelpe litt i planleggingen videre. Mer enn det som er strengt tatt nødvendig, men skulle dekke det meste - ikke alt. Samtidig gis det litt kontekst for noe av funksjonaliteten.
#
# Selv om DHlab er rettet mot et sett pythonkommandoer som sluttbrukere kan benytte, bør vi nok se mer mer på mulighetene for å lage apper i skyen (les GCP), spesielt med Streamlit. Det har vært litt klager på at Jupyter ikke er så brukervennlig. Men det ligger uansett ett stykke uti. Vi har en vei fra Github til GCP, som kan brukes, og som kan utvikles videre.
#
# Modellen, eller dhlab-stacken, ser omtrent sånn ut:
#
# &nbsp;&nbsp;&nbsp;&nbsp;server/fulltekst &rarr; api/Flask &rarr; pythonwrapper &rarr; dhlabkode/notebook &rarr; apper/Streamlit
#
# Vi har allerede fått noe kode fra server og ut til notebook-nivået. Sjekk eksemplene med konkordans. Det gjenstår alstå litt.
#
# Koden for dhlab ligger i et pypi-repo med det passende navnet dhlab, som består av fire moduler, nbtext, module_update, nbpicture, graph_networkx_louvain, pluss en del ekstra kode som har kommet til i ettertid.
#
# Det som vises her, er det som er tenkt innarbeidet i neste versjon av dhlab (0.8?). Noe av koden er tenkt å utføres på server, og noe lokalt på en klientmaskin, så her er det med litt av begge deler. Noe av beregningene nedenfor, som kollokasjon, er mest for å vise gangen og logikken i det hele, og hvordan dataene som kommer fra dhlab kan benyttes. Til slutt i dokumentet summeres opp de kommandoene som skal gå på serversiden, og som trengs implementasjon. En del av de tingene som gjøres lokalt på klientsiden i dag, kan om mulig flyttes til serversiden, som for eksempel en default kollokasjonsanalyse.
#
# Til forskjell fra dagens dhlab, er det nok best å legge alle pythonwrapperne rundt APIet i en egen modul, som andre kan bygge på. Da vil den pythonkoden også kunne fungere som en dokumentasjon på APIet. Neste versjon av dhlab bygges over de wrapperne. I dagens løsning er modulene en lett blanding av wrappere og utvidet kode.

# %% [markdown]
# ### Importer modulene

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
import dhlab.graph_networkx_louvain as gnl
import dhlab.nbpictures as np
from dhlab.nbtokenizer import tokenize

# %% [markdown]
# Modulen `mu` har litt funksjonalitet som å hente nye moduler, toggle kode og sånn. Og sette CSS.

# %%
mu.css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Merriweather|Shippori+Mincho|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Shippori+Mincho';
# 	font-size:1.1em;
# 	color: DarkSlateGray;
# }
#
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
#
#
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
# Av og til kan det være greit å skjule koden

#mu.code_toggle()

# %% [markdown]
# Jupyter notebook har også muligheten til å manipulere CSS direkte. Koden gjør seg nok best i en egen CSS-fil. Men det får gå for den her gangen!

# %%
# %%HTML
# <style>
#
# p  {font-size:1.2em;
#    color:#142850;
#    };
#
# h1, h2, h3, h4 {
#     color:#27496d;
# }
#
# .prompt {
#     visibility: hidden; /* skjuler In [] og Out [] - fjern om du skal kjøre... */
#
# }
# </style>
# Out:
# <style>
#
# p  {font-size:1.2em;
#    color:#142850;
#    };
#
# h1, h2, h3, h4 {
#     color:#27496d;
# }
#
# .prompt {
#     visibility: hidden; /* skjuler In [] og Out [] - fjern om du skal kjøre... */
#
# }
# </style>

# %% [markdown]
# # Modulen `nb`
#
# Her ligger det meste av kommandoer for tekstbehandling som konkordans og kollokasjon, og statistikk fra bøker.
#
# Det ligger en del i moduler som er utviklet i etterkant også, som vi tar etter hvert.
#
# Det vi først og fremst skal gjøre er å hente ut informasjon om ord og tekster fra et korpus.  Korpuset vil typisk være et sett referanser til dokumenter i form av en liste av URN-er (eller reduserte URN-er). URN-ene kan være implisitt eller eksplisitt.
#
# Søk etter URNer er fasettert slik at forfattere markeres med 'author', emneord med 'subject', ett for hver type fasett eller parameter. Mekanismen og indekseringen for de nye metadata er noe forskjellig, men kommandoene som møter brukeren vil være noenlunde lik.

# %% [markdown]
# ## Konkordans, kollokasjon og nøkkelord

# %%
# For noen av parametrene til book_corpus bør det brukes jokertegn

korpus = nb.book_corpus(ddk = '641.2%', limit = 100)

# %%
# det er flere kommandoer for korpus, den her gir en dataramme med grunnleggende informasjon

korpus.head(10)
# Out:
#              urn                    author                        title  year
# 0  2010061603006             Laurin, Urban       Whisky fra hele verden  1998
# 1  2007071101006           Berg, Karl-Arne        Om kjærlighet til vin  1979
# 2  2014110448118              Ronold, Arne    Norges beste vinkjøp 2004  2003
# 3  2013101408007                                          Rødvinsguiden  2004
# 4  2016062948072           Bezzant, Norman                          Vin  1987
# 5  2016070648041                                        Fish &amp; wine  2001
# 6  2015091148085             Johnson, Hugh                Vinens verden  1986
# 7  2010072210012                            Vinelskerens lille notatbok  1998
# 8  2009071604017  Ornäs, Catarina Hiort af      Vinkjenner på rekordtid  1997
# 9  2015050748052                                          Rødvinsguiden  2012

# %% [markdown]
# For å gjøre søk med URN, legges de til fra datarammen sammen med et søkeord.

# %%
nb.urn_concordance(word='maltpreg', urns=nb.pure_urn(korpus), before = 10, after = 10, size=2)
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010061603006?searchText=maltpreg' target='_blank' style='text-decoration:none'>Whisky fra hele verden, Laurin, Urban, 1998</a>
#                 </td>
#                 <td>Smak : Ganske rik , særdeles bløt ,</td>
#                 <td>maltpreg</td>
#                 <td style='text-align:left'>, frisk , søt , mildt røykpreg.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010061603006?searchText=maltpreg' target='_blank' style='text-decoration:none'>Whisky fra hele verden, Laurin, Urban, 1998</a>
#                 </td>
#                 <td>Smak : Lett , bløt ,</td>
#                 <td>maltpreg</td>
#                 <td style='text-align:left'>, merkbar sødme , mildt røykpreg . Kritiseres ofte for</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011032108037?searchText=maltpreg' target='_blank' style='text-decoration:none'>Ansvarlig vertskap, Jørgensen, Helge, 2003</a>
#                 </td>
#                 <td>er et rundt øl med bitterhet og et noe søtlig</td>
#                 <td>maltpreg</td>
#                 <td style='text-align:left'>. Rundt i verden vil vi betegne dette som pils</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013091638058?searchText=maltpreg' target='_blank' style='text-decoration:none'>Whisky, Hoffmann, Marc A., 2009</a>
#                 </td>
#                 <td>komplementert av et behagelig</td>
#                 <td>maltpreg</td>
#                 <td style='text-align:left'>. Lagring på sherryfat gir et intenst element av sherry</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013091638058?searchText=maltpreg' target='_blank' style='text-decoration:none'>Whisky, Hoffmann, Marc A., 2009</a>
#                 </td>
#                 <td>Glenlossie whisky har gress- og</td>
#                 <td>maltpreg</td>
#                 <td style='text-align:left'>og mye blomsterpreg . Den er en populær aperitiff .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014110407618?searchText=maltpreg' target='_blank' style='text-decoration:none'>Ølboka, , 2011</a>
#                 </td>
#                 <td>Fyldig</td>
#                 <td>maltpreg</td>
#                 <td style='text-align:left'>, med karamell som bryter fram på ganen . Kompleks</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014110407618?searchText=maltpreg' target='_blank' style='text-decoration:none'>Ølboka, , 2011</a>
#                 </td>
#                 <td>mer toast , deretter sjokolade . Dempet Sprø ettersmak .</td>
#                 <td>maltpreg</td>
#                 <td style='text-align:left'>, ikke så subtil alkohol , og framtredende i munnen</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014110407618?searchText=maltpreg' target='_blank' style='text-decoration:none'>Ølboka, , 2011</a>
#                 </td>
#                 <td>Fyldig kropp og</td>
#                 <td>maltpreg</td>
#                 <td style='text-align:left'>, med typisk mørk mahognifarge ; den ristede smaken kommer</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014110407618?searchText=maltpreg' target='_blank' style='text-decoration:none'>Ølboka, , 2011</a>
#                 </td>
#                 <td>Ristet aroma ; søtlig</td>
#                 <td>maltpreg</td>
#                 <td style='text-align:left'>på starten , men ettersmaken er mild og lett bitter</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016022548133?searchText=maltpreg' target='_blank' style='text-decoration:none'>Maltwhisky, Jackson, Michael, 2000</a>
#                 </td>
#                 <td>1970 - variant ble overgått av en 1974 med mer</td>
#                 <td>maltpreg</td>
#                 <td style='text-align:left'>og deretter av en nydelig 1975 , som virket fyldigere</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016022548133?searchText=maltpreg' target='_blank' style='text-decoration:none'>Maltwhisky, Jackson, Michael, 2000</a>
#                 </td>
#                 <td>Smak Behagelig smaksrik , ikke noe fiksfakseri ,</td>
#                 <td>maltpreg</td>
#                 <td style='text-align:left'>. Flott avstemt tørrhet og sødme , korn- og nøttepreg</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016022548133?searchText=maltpreg' target='_blank' style='text-decoration:none'>Maltwhisky, Jackson, Michael, 2000</a>
#                 </td>
#                 <td>Smak Snev av sitrongress . Klart , men svakt</td>
#                 <td>maltpreg</td>
#                 <td style='text-align:left'>. Ren sødme .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016022548133?searchText=maltpreg' target='_blank' style='text-decoration:none'>Maltwhisky, Jackson, Michael, 2000</a>
#                 </td>
#                 <td>Smak Smøraktig</td>
#                 <td>maltpreg</td>
#                 <td style='text-align:left'>. Honning . Appelsin . Sitrongress . Saftig eik .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015101648036?searchText=maltpreg' target='_blank' style='text-decoration:none'>Whisky, , 2009</a>
#                 </td>
#                 <td>for å være spesielt kraftig , men har et diskret</td>
#                 <td>maltpreg</td>
#                 <td style='text-align:left'>og er lett og behagelig.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015101648036?searchText=maltpreg' target='_blank' style='text-decoration:none'>Whisky, , 2009</a>
#                 </td>
#                 <td>med ham fulgte først sønnen George , som et sterkt</td>
#                 <td>maltpreg</td>
#                 <td style='text-align:left'>. En virkelig sjel- | | dessverre døde brått ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015101648036?searchText=maltpreg' target='_blank' style='text-decoration:none'>Whisky, , 2009</a>
#                 </td>
#                 <td>dingene som det var mulig å med</td>
#                 <td>maltpreg</td>
#                 <td style='text-align:left'>og lette hint av røyk . Sma- te Horse eksporteres</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015101648036?searchText=maltpreg' target='_blank' style='text-decoration:none'>Whisky, , 2009</a>
#                 </td>
#                 <td>med</td>
#                 <td>maltpreg</td>
#                 <td style='text-align:left'>. Smaken er fyldig og kremet med tydelige innslag av</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014110407702?searchText=maltpreg' target='_blank' style='text-decoration:none'>komplette guiden til norsk øl, Mortensen, Hylje, 2009</a>
#                 </td>
#                 <td>kraftig skum . De har en lett smak uten særlig</td>
#                 <td>maltpreg</td>
#                 <td style='text-align:left'>, men med en tørr bitterhet . Alkoholfrie øl har</td>
#             </tr>
# <tr>
#                 <td>
#                     <a h

# %% [markdown]
# Kollokasjoner har tilsvarende kommando, som gir en liste av ord som kan bearbeides.

# %%
coll = nb.urn_coll(word='syrlig', urns =nb.pure_urn(korpus))
coll
# Out:
#              0
# og        1468
# ,         1241
# .         1096
# med        846
# vin        705
# ...        ...
# egg          1
# edelsøte     1
# e            1
# dybde        1
# ♦            1
#
# [1676 rows x 1 columns]

# %%
# normaliserer datarammen, men her er det flere muligheter for normalisering - alt avhengig av hva som skal gjøres.

nb.normalize_corpus_dataframe(coll)
# Out:
# True

# %% [markdown]
# Bearbeiding med kollokasjoner kan benytte frekvenslister for hele boksamlingen som referanse. Husk at kollokasjon kan sees på som en tolkning av formelen
#
# $$\frac{p(w|C)}{p(w)}$$
#
# Der $p(w)$ er sannsynligheten (eller proporsjonen) av ordet $w$ i totalkorpuset, og $p(w|C)$ er den betingede sannsylighet (proporsjon) for $w$ i ordlisten $C$, som kan komme fra en kollokasjon eller et annet korpus. Om verdien er 1  har $w$ identisk distribusjon i helheten som i korpuset. Jo lengre fra 1 desto mer relevant er $w$ for $C$. I alle fall så lengde frekvensen til $w$ er av en viss størrelse.

# %%
# kommandoen nb.totals() bygges inn i nb.frame() som er en forkortelse for pandas datarammekonstruktør

tot = nb.frame(nb.totals(200000), 'tot')
nb.normalize_corpus_dataframe(tot)
# Out:
# True

# %% [markdown]
# De mest relevant for syrlig i korpuset er. Merk at normaliseringen vi har vil jekke opp tallene noe, rett og slett fordi det er litt færre. Men sorteringen av tallene vil være det samme.

# %%
nb.frame_sort(nb.frame(coll[0]/tot.tot)).head(10)
# Out:
#                       0
# Slank      55526.877035
# Fyldig     17956.553336
# Pent        5926.625983
# duft        5323.464343
# finish      4881.519717
# distinkt    4460.450477
# sublim      3815.042527
# fyldig      3695.485233
# Rik         3523.914401
# ettersmak   3448.497145

# %% [markdown]
# ##### Kobling til formel
#
# Uttrykket $\frac{\textrm{koll}[0]}{\textrm{tot.tot}}$ har koblingene til formelen over som $p(w) \sim \textrm{tot.tot}$ og $p(w|C) \sim \textrm{koll}[0]$. Pandas skjuler variabelen $w$. En litt mer presis formulering ville vært å skrive $p(w|U)$ for $p(w)$ og $p(w|C,U)$ for $p(w|C)$, der $U$ står for den mest generelle konteksten. Merk at om $C$ er del av $U$ vil $p(w|C,U)$ være ekvivalent med $p(w|C)$. Da blir pandas-formelen ganske enkelt $\frac{C}{U}$.

# %% [markdown]
# Samme metode for å analysere hele korpuset. Kommando/funksjon for å hente ut summen av alle ord i korpuset er `nb.aggregate_urns`

# %%
korpus_total = nb.frame(nb.aggregate_urns(nb.pure_urn(korpus)))
nb.normalize_corpus_dataframe(korpus_total)
# Out:
# True

# %%
nb.frame_sort(korpus_total).head(5)
# Out:
#            0
# ,   0.056232
# .   0.046433
# og  0.028001
# i   0.020826
# er  0.017089

# %%
# Passer bra for 641.2 (alkoholholdige drikker)

korpus_keys = nb.frame_sort(nb.frame(korpus_total[0]/tot.tot))
korpus_keys.head(10)
# Out:
#                       0
# Sauvignon   1431.106017
# Riesling    1335.513059
# Cabernet    1302.901111
# Chardonnay  1297.103790
# cabernet    1279.349653
# Merlot      1275.411694
# Pinot       1246.448666
# riesling    1192.365581
# rødviner    1150.997097
# Chablis     1119.801619

# %% [markdown]
# En annen kommando for å hente URN-er er `nb.best_book_urn` som finner den beste gitt en sammenligning av ordet med alt annet i boksamlingen. Den funksjonen fordrer en bearbeiding av ordlistene med tilhørende indeksering.

# %%
nb.frame(nb.best_book_urn(word="Chomsky"), "urn forfatter tittel år".split()).head(5)
# Out:
#              urn           forfatter                                  tittel  \
# 0  2008052304018    Hiorth, Finngeir                            Noam Chomsky
# 1  2009021604003    Hovdhaugen, Even  Transformasjonell generativ grammatikk
# 2  2008061900083   Anderssen, Merete    acquisition of functional categories
# 3  2011022205085  Åfarli, Tor Anders        Grammatikk - kultur eller natur?
# 4  2016061508024        Dyvik, Helge                    Grammatikk og empiri
#
#      år
# 0  1974
# 1  1971
# 2  1996
# 3  2000
# 4  1980

# %% [markdown]
# Det er også kommandoer for å lage konkordanser uten å gå via URN, likeså for kollokasjoner. Se for eksempel notebooken https://nbviewer.jupyter.org/github/DH-LAB-NB/DHLAB/blob/master/2_Konkordans.ipynb

# %% [markdown]
# ## Frekvenslister, nøkkelord og grafkonstruksjoner
#
# Frekvenslister kan hentes ut for alle bøker med `nb.get_freq`. URN er redusert URN, altså bare sekvensnummeret. Her skal vi se hvordan vi kan bygge grafer og lage clustre fra dem med networkx og pandas. Først ved hjelp av frekvenslister på klientsiden, og deretter på serversiden ved å bruke funksjonen `nb.make_network_graph`.

# %%
# Hent ut deler av frekvensene for en bok. For å få hele listen, sett top = 0 og cutoff = 0

nb.frame(nb.get_freq(nb.pure_urn(korpus), top = 5, cutoff = 10))
# Out:
#        0
# ,   4157
# .   3679
# og  1187
# :   1133
# i   1076

# %% [markdown]
# Med `get_freq` kan det bygges en DTM rimelig kjapt. Hvor raskt avhenger av antallet tekster.

# %%
import pandas as pd

# %%
# Koden henter ut hele listen for de 10 første bøkene i korpuset 

dtm = pd.concat([nb.frame(nb.get_freq(u, top = 0, cutoff = 0), str(u)) for u in nb.pure_urn(korpus)[:10]], axis = 1)

# %%
dtm.head(8)
# Out:
#      2010061603006  2007071101006  2014110448118  2013101408007  \
# ,           4157.0          915.0         2447.0         1347.0
# .           3679.0          839.0         1936.0         1263.0
# og          1187.0          373.0         2380.0          689.0
# :           1133.0           28.0           43.0          653.0
# i           1076.0          408.0          808.0          177.0
# av          1050.0          214.0          785.0          349.0
# er           882.0          448.0          351.0           97.0
# som          781.0          221.0          206.0          122.0
#
#      2016062948072  2016070648041  2015091148085  2010072210012  \
# ,           6430.0         1227.0         9343.0         7963.0
# .           7139.0         3646.0         8660.0           86.0
# og          4889.0            6.0         4330.0          168.0
# :            518.0          229.0         1042.0         2188.0
# i           4160.0           66.0         4127.0           23.0
# av          2798.0            NaN         2447.0           28.0
# er          2782.0            NaN         3573.0            9.0
# som         2872.0            NaN         2678.0           35.0
#
#      2009071604017  2015050748052
# ,           1658.0         1092.0
# .           1234.0          752.0
# og           896.0          295.0
# :            178.0         1075.0
# i            610.0           44.0
# av           484.0          154.0
# er           501.0           53.0
# som          499.0           53.0

# %% [markdown]
# For clustring skal vi ta kryssproduktet av bøkene, som i pandas er x.dot(y). Men vi gjør det med et utvalg ord. Her med de viktigste ordene fra hver bok. I neste celle bidrar hver bok med de 150 beste ordene til en dataramme dtm_key.

# %%
dtm_key = pd.concat([(dtm[x]/tot.tot).sort_values(ascending=False).head(150) for x in dtm], axis = 1)

# %%
# kopierer over kolonnenavnene - bedre måter å gjøre det på, men ...

dtm_key.columns = dtm.columns

# %% [markdown]
# Her er datarammen med nøkkelord fra hver bok

# %%
dtm_key.sort_values(by=dtm_key.columns[2], ascending = False).head(10).fillna(0).style.background_gradient(axis = 1)
# Out:
# <style  type="text/css" >
#     #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row0_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row0_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row0_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row1_col2 {
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row1_col5 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row1_col6 {
#             background-color:  #046299;
#             color:  #f1f1f1;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row1_col7 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row1_col8 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row1_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row2_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row2_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row2_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row2_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row2_col8 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row2_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row3_col3 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row3_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row3_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row3_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row3_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row3_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row4_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row4_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row4_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row4_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row4_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row4_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row4_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row5_col1 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row5_col2 {
#             background-color:  #045b8f;
#             color:  #f1f1f1;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row5_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row5_col4 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row5_col5 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row5_col6 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row5_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row5_col8 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_095b3ba0_de83_11eb_8edb_a0a4c554f2a3row5_col9 {
#             background-color:  #529bc7;
#             color:  #000000;

# %%
graph = dtm_key.fillna(0).dot(dtm_key.fillna(0).transpose())

# %% [markdown]
# Grafkonstruksjonen gir foreløpig ikke en graf, men en matrise over alle ordene (bytt om .transpose() til venstre for .dot() og det blir en tabelll over bøkene.) Matrisen kan sees på som en avstandstabell, der tallet i hver celle er avstanden mellom ordet venstre marg til ordet i headeren. Så distansen mellom _nyanse_ og _fruktig_ er $2^{17}$ ca, mens avstanden mellom _nyanse_ og _bourbon_ er litt lavere $5^{16}$. Tallene ville hatt godt av en logaritme!

# %%
graph.head(10)
# Out:
#                 fruktig       eikefat       blended        aldere  \
# fruktig    7.932249e+17  3.157605e+17  2.688400e+17  2.460018e+17
# eikefat    3.157605e+17  1.316019e+17  1.077400e+17  9.858734e+16
# blended    2.688400e+17  1.077400e+17  9.773836e+16  8.800123e+16
# aldere     2.460018e+17  9.858734e+16  8.800123e+16  8.052543e+16
# Highlands  2.445093e+17  9.798919e+16  8.746731e+16  8.003687e+16
# nyanse     2.396412e+17  9.603829e+16  8.572589e+16  7.844339e+16
# Fyldig     2.658480e+17  1.000980e+17  8.554189e+16  7.827501e+16
# Duft       2.242693e+17  8.915199e+16  7.833947e+16  7.168445e+16
# bourbon    1.878570e+17  7.528531e+16  6.720133e+16  6.149250e+16
# OLD        1.600347e+17  6.413527e+16  5.724856e+16  5.238523e+16
#
#               Highlands        nyanse        Fyldig          Duft  \
# fruktig    2.445093e+17  2.396412e+17  2.658480e+17  2.242693e+17
# eikefat    9.798919e+16  9.603829e+16  1.000980e+17  8.915199e+16
# blended    8.746731e+16  8.572589e+16  8.554189e+16  7.833947e+16
# aldere     8.003687e+16  7.844339e+16  7.827501e+16  7.168445e+16
# Highlands  7.955127e+16  7.796746e+16  7.780010e+16  7.124953e+16
# nyanse     7.796746e+16  7.641518e+16  7.625115e+16  6.983099e+16
# Fyldig     7.780010e+16  7.625115e+16  1.155546e+17  7.512319e+16
# Duft       7.124953e+16  6.983099e+16  7.512319e+16  6.561764e+16
# bourbon    6.111942e+16  5.990257e+16  5.977399e+16  5.474117e+16
# OLD        5.206740e+16  5.103077e+16  5.092124e+16  4.663379e+16
#
#                 bourbon           OLD  ...          5,10        Varenr  \
# fruktig    1.878570e+17  1.600347e+17  ...  2.708498e+14  2.705356e+14
# eikefat    7.528531e+16  6.413527e+16  ...  0.000000e+00  0.000000e+00
# blended    6.720133e+16  5.724856e+16  ...  0.000000e+00  0.000000e+00
# aldere     6.149250e+16  5.238523e+16  ...  0.000000e+00  0.000000e+00
# Highlands  6.111942e+16  5.206740e+16  ...  0.000000e+00  0.000000e+00
# nyanse     5.990257e+16  5.103077e+16  ...  0.000000e+00  0.000000e+00
# Fyldig     5.977399e+16  5.092124e+16  ...  2.441805e+14  2.438973e+14
# Duft       5.474117e+16  4.663379e+16  ...  5.293447e+13  5.287307e+13
# bourbon    4.695818e+16  4.000350e+16  ...  0.000000e+00  0.000000e+00
# OLD        4.000350e+16  3.407883e+16  ...  0.000000e+00  0.000000e+00
#
#                   Chile         Arrow          Bois       Lehmann  \
# fruktig    2.642635e+14  2.625344e+14  2.610136e+14  2.592924e+14
# eikefat    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# blended    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# aldere     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Highlands  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# nyanse     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Fyldig     2.382427e+14  2.366840e+14  2.353128e+14  2.337612e+14
# Duft       5.164725e+13  5.130933e+13  5.101209e+13  5.067572e+13
# bourbon    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# OLD        0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#                  Kalkun  Komponentene       Kylling    Svinekjøtt
# fruktig    2.585400e+14  2.472543e+14  2.472389e+14  2.456611e+14
# eikefat    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# blended    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# aldere     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Highlands  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# nyanse     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Fyldig     2.330829e+14  2.229084e+14  2.228945e+14  2.214720e+14
# Duft       5.052867e+13  4.832301e+13  4.831999e+13  4.801163e+13
# bourbon    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# OLD        0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
# [10 rows x 1009 columns]

# %% [markdown]
# Samme tabell etter logaritme, og litt avrunding. Sånne linjer bør humanioraforskerene spares for. En av grunnene til å lage wrappere.

# %%
from math import log

# %%
graph.replace(0,0.1).fillna(0.1).applymap(log).head(10).applymap(lambda x: round(x,2))
# Out:
#            fruktig  eikefat  blended  aldere  Highlands  nyanse  Fyldig  \
# fruktig      41.21    40.29    40.13   40.04      40.04   40.02   40.12
# eikefat      40.29    39.42    39.22   39.13      39.12   39.10   39.14
# blended      40.13    39.22    39.12   39.02      39.01   38.99   38.99
# aldere       40.04    39.13    39.02   38.93      38.92   38.90   38.90
# Highlands    40.04    39.12    39.01   38.92      38.92   38.90   38.89
# nyanse       40.02    39.10    38.99   38.90      38.90   38.87   38.87
# Fyldig       40.12    39.14    38.99   38.90      38.89   38.87   39.29
# Duft         39.95    39.03    38.90   38.81      38.80   38.78   38.86
# bourbon      39.77    38.86    38.75   38.66      38.65   38.63   38.63
# OLD          39.61    38.70    38.59   38.50      38.49   38.47   38.47
#
#             Duft  bourbon    OLD  ...   5,10  Varenr  Chile  Arrow   Bois  \
# fruktig    39.95    39.77  39.61  ...  33.23   33.23  33.21  33.20  33.20
# eikefat    39.03    38.86  38.70  ...  -2.30   -2.30  -2.30  -2.30  -2.30
# blended    38.90    38.75  38.59  ...  -2.30   -2.30  -2.30  -2.30  -2.30
# aldere     38.81    38.66  38.50  ...  -2.30   -2.30  -2.30  -2.30  -2.30
# Highlands  38.80    38.65  38.49  ...  -2.30   -2.30  -2.30  -2.30  -2.30
# nyanse     38.78    38.63  38.47  ...  -2.30   -2.30  -2.30  -2.30  -2.30
# Fyldig     38.86    38.63  38.47  ...  33.13   33.13  33.10  33.10  33.09
# Duft       38.72    38.54  38.38  ...  31.60   31.60  31.58  31.57  31.56
# bourbon    38.54    38.39  38.23  ...  -2.30   -2.30  -2.30  -2.30  -2.30
# OLD        38.38    38.23  38.07  ...  -2.30   -2.30  -2.30  -2.30  -2.30
#
#            Lehmann  Kalkun  Komponentene  Kylling  Svinekjøtt
# fruktig      33.19   33.19         33.14    33.14       33.13
# eikefat      -2.30   -2.30         -2.30    -2.30       -2.30
# blended      -2.30   -2.30         -2.30    -2.30       -2.30
# aldere       -2.30   -2.30         -2.30    -2.30       -2.30
# Highlands    -2.30   -2.30         -2.30    -2.30       -2.30
# nyanse       -2.30   -2.30         -2.30    -2.30       -2.30
# Fyldig       33.09   33.08         33.04    33.04       33.03
# Duft         31.56   31.55         31.51    31.51       31.50
# bourbon      -2.30   -2.30         -2.30    -2.30       -2.30
# OLD          -2.30   -2.30         -2.30    -2.30       -2.30
#
# [10 rows x 1009 columns]

# %% [markdown]
# Fra matrisen hentes grafen ut med networkx, som har et api mot pandas.

# %%
import networkx as nx

# %%
G = nx.from_pandas_adjacency(graph)

# %% [markdown]
# Trimmer grafen ned litt, uten å kutte alt helt bort. Etter trimming tegnes grafen med `gnl.show_graph`. Den farvelegger nodene etter clustertilhørighet. Den visuelle fordelingen av nodene gjøres med Force Atlas (samme som på nb-ngram). Interessant at Louvain-clustringen stemmer ganske bra med den visuelle clustringen.

# %%
Gf = nx.from_edgelist([(u,v, e) for u,v,e in G.edges(data=True) if e['weight'] > 10**16])

# %%
gnl.show_graph(Gf, spread = 2, fontsize = 5)

# %% [markdown]
# Clustringen blir forholdsvis grov, noe som er forventet når det gjøres på boknivå, men noe får vi ut. I og med at korpuset har en viss vilkårlig karakter vil noen clustre kanskje påvirkes av enkelte bøker.
#
# Louvain-metoden gjør det mulig å lage subclustre om nødvendig. Nedenfor skal vi ta de viktigste nøkkelordene for korpuset og ta kryssprodukt basert på samforekomst i avsnitt.
#
# I visning av clustre tas de to mest sentrale nodene og brukes som navn på clusteret. Det gir ofte en god hint om hva clusterte inneholder.

# %%
gnl.show_communities(Gf)
# Out:
# fruktig-eikefat :  fruktig, eikefat, Fyldig, blended, nyanse, aldere, Highlands, Duft, forbudstiden, whiskey, Bløt, bourbon, OLD, Grunnlagt, YEARS, Moray, sødme, Premium, oljeaktig, blend, Beliggenhet, kremaktig, Whisky, whiskyen, vanilje, Scotch, kjennere, Elgin, Beam, whisky, Forholdsvis, CANADA, Rik, Nikka, Cooley, Glen, Smak, Burn, Allied, BLACK, Label, destillere, Bourbon, ildfull, Skottlands, Eiere, Whyte, søtlig, røykes, pannene, fatene, Regal, PRØVER, Rare, sødmen, Reserve, Inverness, Winkle, Ballantine, Famous, Kraftig, lagringen, Kentucky, COMPANY, Louisville, Loch, nøtt, aromatisk, parfymert, Mackay, Uvanlig, brennerier, brennevinet, Ancient, Scapa, W.L, sjenerøs, Sprit, smakene, Tennessee, delikat, Years, Single, Kilden, Montrose, lønnesirup, Brands, Gentleman, filtreres, Muir, blenderen, Old, gjenåpnet, Blandes, Johnnie, PRODUKSJON, skottene, Lang, poeng, Vann, Rudd, Cascade, dampene, spriten, stavemåten, luxe, LABEL, realt, produ-, Classic, Mist, kraftfull, Nevis, Jameson, innholdsrik, tapping, sjenerøst, WILD, Straight, Moffat, nyanser, AMERIKANSK, Malt, sherry, lagringstid, JACK, Forman, Catrine, Highland, Skottene, Selges, Midlands, smaksstoffer, Forester, Middels, råvare, panner, duftene
#
# Riesling-Cabernet :  Riesling, Cabernet, vinmark, vinstokker, vinmarkene, Pinot, hvitviner, vinmarker, rødviner, vinstokkene, viner, Médoc, Merlot, Beaujolais, Sauvignon, Beaune, Cotes, Chardonnay, Cru, alkoholstyrke, Grands, Quinta, Clos, Chablis, F5, E5, Chåteau, F3, G5, E4, F6, F4, Napa, druen, Douro, Jerez, vinproduksjon, Chianti, Rioja, destilleres, Wine, mosten, Vineyard, drue, vinene, E3, Calvados, musserende, Muscat, druene, Cote, F2, Bourgogne, Domaine, G4, Cognac, Shiraz, Alsace, Mosel, Nahe, B5, E2, bouquet, Noir, Bianco, G6, vinens, gjæringen, A5, G3, druesorter, Blanc, garvesyre, druer, Bergerac, Gironde, Bereich, Bourgeois, alkoholinnhold, Bordeaux, G2, likører, E6, MIDDAG, Baja, Viner, Garda, vintage, B4, Touraine, Chateau, Languedoc, Schloss, Adige, finesse, A4, Dordogne, Rhine, Piemonte, Californias, Rhone, Savoie, sukkerinnhold, Mers, DOC, portvinen, Garonne, Rødvin, Monterey, C5, Valley, B3, A6, C6, Pays, burgunder, beplantet, C4, Estate, brandyen, modner, A3, kooperativer, Chapelle, Frascati, Graves, Lombardia, Loire, G1, E1, Jordsmonnet, Créme, Beaulieu, vins, Umbria, årganger, méthode, hektoliter, Martell, årgang, volumprosent, cognac, Fils, bunnfallet, brandy, C2, B2, Krug, Syd-Afrika, Vinene, Pape, F1, årsproduksjonen, tilplantet, markedsføres, Hennessy, Oporto, vingårder, Fd, Portvin, innhøstingen, hvit-, etikettene, Vieux, FRANKRIKE, tappes, Montagne, Franc, AUSTRALIA, hvitvinen, Petite, drikkes, hybrider, druesaft, Latium, tredjeparter, Champagne, søtet, æringen, Corvo, Sørlige, vin-, vinen, konsumeres, madeira, Giulia, Hawkes, Harvest, foredles, stedegne, Frontera, alkoholholdige, Ebro, Erie, Orvieto, Austr, Cassis, tilhøyre, lettflytende, innfeit, rødvinen, SENTRALE, markedsfører, Rhinens
#
# VIN-aromaer :  VIN, aromaer, halvtørr, SMAK, blekgul, FARGE, POENG, knusktørr, Årgang, vassen, BALANSE, Poeng, übalansert, HUSK, brilliant, LENGDE, KOMMENTARER, mineralske, grumset, lys-, BESKRIVELSE, KONKLUSJON, MAT, lyserød, purpur, krydret, bløt, akseptabel, fiolett, NAVN, BE, Hvite, fyldig, Dårlig, oransje, produsent, søt, tiltalende, gul, servert, middels, uklar, tørr, mørk, OPPLYSNINGER, FAKTORER
#
# Barbera-Rosso :  Barbera, Rosso, PASSER, riesling, INFO, Druer, cabernet, ettersmak, Vina, finish, Produsent, Slank, Veneto, TII, EGEN, BESTE, ITALIA, kjøttretter, VURDERING, anis, Alkohol, Syre, duft, Intens, pinot, Lukt, lakris, Elegant, 13,50, Brut, Dyp, sublim, bjørnebær, SOO, streif, kirsebær, Fylde, rødfiolett, Frisk, solbær, Behagelig, overtoner, 13,00, syrlig, småvilt, 13,0, Griiner, Okse, distinkt, plommer, Robust, Aroma, FRANCE, ØSTERRIKE, moreller, Toscana, avdempet, Kraftige, Balansert, tapas, Corte, oster, Agr, eukalyptus, 13,5, gryteretter, Agricola, Alba, superb, Ekstremt, Ribera, Solid, OV, Campania, årgangen, Masi, 14,0, SPANIA, friskhet, Concha, Catalonia, Hautes, Modne, Mendoza, Farge, klissen, storvilt, syre
#
# flavour-Season :  flavour, Season, lemon, tannin, olive, tomato, freshly, onion, chopped, wine, FISH, WITH, carrots, fried, Serve, butter, boil, cooked, beans, sauce, ginger, approx, Remove, ingredients, herbs, peel, peas, Cut, fillets, dish, flour, Mix, salted, WHITE, slices, WHEN, cooking, WILL, mackerel, medium-sized, potatoes, serving, GREEN, palate, angler, juice, vegetables, stripped, Add, Strain, salad, recipe, Bake, Fry, fillet, cream, fry, cabbage, kettle, BEFORE, bowl, veal, mussels, filleting, delicate, aroma, acidity, sugar, tray, sieve, cook, icy, baked, soy, subdued, youthful, refrigerator, sour, preferably, nicely, foodstuffs, fresh, halves, adding, CHAR, clarified, yolk, texture, chicken, fruit, stalk, THAT, knife, THIS, fish, PLATE, backbone, banana, Cover, oak, PASTA, Clean, balls, FAT, baking, Beat, stirring, chefs, dishes, nuts, cleaned, crayfish, cool, OIL, mince, overnight, risotto, sweet, bones, shellfish, SOME, gently, seafood, slice, chop, GOOD, impurities, turbot, TOP, WHILE, chili, reminiscent, belly, boiling, add, smoked, jaws, HAS, dough, blender

# %% [markdown]
# En annen måte å generere grafer på er å benytte serversiden for beregninger. På klientsiden er det tre muligheter for å komme nærme teksten, enten vi frekvenslister, men da er alle ordene like nær hverandre. Ellers går det fint å hente ut konkordanser og lage matriser basert på dem. På serversiden kan alt gjøres, og en operasjon implementert der, er å lage samforekomstmatriser som den over basert på hvilke avsnitt ordene opptrer i.
#
# Kommando for å lage grafer/nettverk er `make_network_graph`, som tar et sett ord, en URN, og lager en graf over ordene basert på samforekomst i avsnitt. Grafene for flere bøker kan kobles sammen.
#
# Her tar vi topp-ordene ligger i toppen variabelen `korpus_keys` definert over.

# %%
korpus_keys.head(10)
# Out:
#                       0
# Sauvignon   1431.106017
# Riesling    1335.513059
# Cabernet    1302.901111
# Chardonnay  1297.103790
# cabernet    1279.349653
# Merlot      1275.411694
# Pinot       1246.448666
# riesling    1192.365581
# rødviner    1150.997097
# Chablis     1119.801619

# %% [markdown]
# Om vi velger de 200 på topp i den listen skulle vi være rimelig trygg på at vi får med relevante ord.

# %%
korpus_keys.head(200).iloc[199]
# Out:
# 0    122.660025
# Name: rødvinen, dtype: float64

# %% [markdown]
# Vi lager en graf over de samme bøkene som ovenfor, de 10 første i korpuset.  Grafene konstrueres på serversiden med kommandoen `make_network_graph` som loopes over hver URN i de første ti i korpuset.

# %%
Gs = [nb.make_network_graph(u, list(korpus_keys.head(200).index)) for u in nb.pure_urn(korpus)[:10]]

# %% [markdown]
# Vi kan ta en titt på de clustringen i de tre første grafene, før de slås sammen til en stor graf nedenfor. Den første tegnes også.

# %%
gnl.show_graph(Gs[0])

# %%
gnl.show_communities(Gs[0])
# Out:
# rødvin-Bordeaux :  rødvin, Bordeaux
#
# fruktig-sødme :  fruktig, sødme, Fyldig, Frisk, søtlig, sødmen, druer
#
# eikefat-blended :  eikefat, blended, whiskey, alkoholstyrke, garvesyre, forbudstiden
#
# Highlands-årgang :  Highlands, årgang, friskhet
#
# ettersmak-alkoholinnhold :  ettersmak, alkoholinnhold, smakene
#
# aromaer-aroma :  aromaer, aroma

# %%
gnl.show_communities(Gs[1])
# Out:
# Vinen-druen :  Vinen, druen, Rhone, Alsace, Cotes, Loire, burgunder, Languedoc, Riesling, Barbera, Pape, Pinot, alkoholstyrke, Rioja, Schloss
#
# Bordeaux-Cote :  Bordeaux, Cote, Bourgogne, Cru, vinmark, vinene, Beaujolais, Médoc, Chablis, Beaune, vingårder, Chateau, vinmarker, Bourgeois, Mers, Vinene, Vinmonopolets, Bereich
#
# druene-druesorter :  druene, druesorter, druer, Cabernet, drue, hvitvinen, vinstokkene, Franc, Merlot, Veneto, innhøstingen, fruktig, Toscana, Marche, vinstokker, Chianti
#
# viner-vinen :  viner, vinen, garvesyre, vinens, mosten, friskhet, sukkerinnhold, sødme, rødvin, aroma, gjæringen, bunnfallet, rødviner, årgangen, alkoholinnhold, årganger, bouquet, halvtørr, Portvin, musserende, søtlig, kooperativer, årgang, Mosel, Graves, vinproduksjon
#
# Clos-Domaine :  Clos, Domaine
#
# Nahe-rødvinen :  Nahe, rødvinen

# %%
gnl.show_communities(Gs[2])
# Out:
# årgang-Sauvignon :  årgang, Sauvignon, finish, Frisk, streif, sødme, cabernet, anis, Slank, blanc, fruktig, Fyldig, cru, vinmark, Bourgeois, Cabernet, Mosel, Chianti, hektar, vinstokker, Årgang, vintage, mineralsk, AOC, knusktørr, Castello, aperitiff
#
# viner-vinen :  viner, vinen, druer, vinens, aromaer, friskhet, Piemonte, Chablis, årgangen, druene, vinene, Druer, gjæringen, alkoholinnhold, Adige, vinmarkene, årganger, fino, musserende, drue, Skalldyr, Champagne, Toscana, Vinmonopolets, vins, Veneto, sukkerinnhold, druen, Vinen, rødvinen, Californias, bouquet, bunnfallet, Cote, Pape, druesorter, drikkes
#
# Riesling-Blanc :  Riesling, Blanc, Brut, Rosso, Cotes, Cru, Bourgogne, Pinot, Rhone, Bianco, Clos, Beaujolais, Beaune, Domaine, Rioja, Grands, Vina, Bordeaux, Estate, Merlot, Valley, Pays, Schloss, Noir
#
# riesling-rødvin :  riesling, rødvin, Chardonnay, Alsace, hvitviner, rødviner, pinot, hvitvin, burgunder, noir, sødmen, Loire, tannin, alkoholstyrke, søtlig, Vintage, Pasta, vinmarker, Rødvin, Viner, nero
#
# BESTE-ITALIA :  BESTE, ITALIA, ØSTERRIKE, PORTUGAL, FRANKRIKE, SPANIA

# %% [markdown]
# For sammenslåing fungerer i og for seg networkx egen merge-kommando, men den klarer ikke å legge sammen vektene, så ikke helt ideel.

# %%
F = nx.compose_all(Gs)

# %%
gnl.show_graph(F, spread = 1.8)

# %% [markdown]
# Clustrene her ser rimelige ut med tanke på semantiske felt. Altså en litt generell om viner og, og en om druetyper, med iblandet litt adjektiv. Louvain kan være litt random, så både antall og innholdi clustrene kan variere.
#
# Grafen er er det som kommer ut ved å kombinere graf-konstruksjon for de viktigste ordene fra korpuset. Alt gjort per URN på serverside med kommandoen `make_network_graph`, basert på samforekomst av ord i avsnitt .

# %%
gnl.show_communities(F)
# Out:
# Bordeaux-Rhone :  Bordeaux, Rhone, Champagne, Graves, Cotes, Cognac, Muscat, Mers, alkoholinnhold, rødvinen, Rødvin, Touraine, Languedoc, Bergerac, Pays, cognac, ITALIA, PORTUGAL, SPANIA, AUSTRALIA, BESTE, FRANKRIKE, ØSTERRIKE
#
# vinene-rødvin :  vinene, rødvin, Sauvignon, druene, Cabernet, rødviner, hvitviner, drue, drikkes, Toscana, DOC, Chianti, Shiraz, Bianco, modner, druesorter, Druer, Frascati, Rosso, Marche, Franc, Douro, hvitvinen, innhøstingen, Orvieto, Castello, Vintage, Romagna, Quinta, Portvin, Årgang, Fonseca, Pasta, nero
#
# druen-fruktig :  druen, fruktig, Alsace, Vinen, årgang, alkoholstyrke, aroma, vinens, garvesyre, burgunder, gjæringen, finish, sødme, Jerez, friskhet, Viner, søtlig, tannin, riesling, mosten, destilleres, streif, aromaer, ettersmak, Frisk, Fyldig, bunnfallet, trefat, blended, cabernet, vintage, årgangen, pinot, sukkerinnhold, fino, druesaft, anis, noir, blanc, sødmen, Slank, aromaen, PASSER, Highlands, Ribera, fermentation, AOC, aperitiff, FARGE, mineralsk, SMAK, fermented
#
# druer-Blanc :  druer, Blanc, Riesling, hvitvin, Pinot, vinmark, Chardonnay, Noir, musserende, Rioja, Valley, vinstokker, hektar, Merlot, Loire, Beaujolais, Napa, vinstokkene, Adige, Wine, Umbria, Vineyard, Veneto, eikefat, vinproduksjon, hektoliter, Piemonte, Barbera, Campania, Schloss, Lombardia, Californias, Mancha, whiskey, Estate, Lazio, forbudstiden, Baja, akevitt, Vina, årgangene, VIN, bryggeriet, LAGRING
#
# viner-vinen :  viner, vinen, vinmarker, vinmarkene, Chateau, Cote, Cru, bouquet, Vinene, Médoc, Chablis, Bourgogne, Clos, Chåteau, årganger, Grands, Beaune, Mosel, Domaine, Bourgeois, Pape, cru, Nahe, kooperativer, Gironde, crus, vins, Bereich, Brut, Fils, vingårder, blekgul, Vinmonopolets, Skalldyr, smakene, Zealands, Varenr
#
# halvtørr-knusktørr :  halvtørr, knusktørr

# %%
mu.update('wordbank')
import wordbank as wb
# Out:
# Updated file `C:\Users\larsj\Documents\GitHub\Miscellaneous-Notebooks\wordbank.py`
