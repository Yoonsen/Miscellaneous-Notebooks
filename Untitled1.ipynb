# %%
import json
import dhlab.module_update as mu
mu.css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# ...

# %%
themes = json.load(open('heidis_temadefinisjoner.json'))

# %%
text = ""
for th in themes:
    text += "# " + th + '\n'
    for topic in themes[th]:
        text += "## " + topic + '\n'
        text += ', '.join(themes[th][topic])
        text += "\n"
mu.printmd(text)
# Out:
# # “Jul” [Christmas]
# ## Mor_
# Mor, Mødre, moderlig, moderligt, Modcr, modcr, , Modre, Msdre, Msdrc, modre, modcrlig, modrcne, modrc, modcrlig, modcrlighcden, modcrlighed, moderlighed, modcrlighcd, Huusmoder, husmoderlig, husmoderlige, husmoderlighed, husmoderligheden, Husmor, Husmoder, Husmodcr, Husmodcrcn, Husmoderen, Husmodcren, Husmodcren, Huusmodcr, Huusmodre, Huusmoders, Huusmodcr, Huusmodrene, Huusmodcren, Huusmodercn, Huusmodcrs, Husmodre, Husmodrc, Husmoderem, Husmoderms, Huusmodcrcn, Moderlig, Moderligt, Modcrlig, Modrcne, Modrc, Modcrlighcden, Modcrlighed, Moderlighed, Modcrlighcd, Husmoderlig, Husmoderlige, Husmoderlighed, Husmoderligheden
# ## Kvinde_
# ...
