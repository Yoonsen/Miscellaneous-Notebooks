# %% [markdown]
# # Analyse av tekster for Polnet
# Lars G. Johnsen
# Yngvil Beyer
# Kirsten Sivesind
#
#
# I den her notebooken setter vi opp en kobling til tekstene som ligger i Zotero-biblioteket for Polnet-prosjektet. I første omgang prøver vi å lage kollokasjoner mot tekstene gjennom API mot NB-digital, men på sikt kan vi lage en database over alle PDF-er som ligger i Zotero https://www.zotero.org/groups/2438311/polnet2/library.

# %% [markdown]
# Aktiver moduler for å hente tekst og analysere

# %%
import dhlab.nbtext as nb
from dhlab.nbtokenizer import tokenize
import json
import pandas as pd
from collections import Counter
import re

# %%
from dhlab.module_update import css
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
def collocations_from_nb(word, corpus):
    """Get a concordance, and count the words in it. Assume konks reside a dataframe with columns 'after' and 'before'"""
    concordance = nb.frame(nap.get_all_konks(word, korpus))
    return nb.frame_sort(nb.frame(Counter(tokenize(' '.join(concordance['after'].values + concordance['before'].values))), word))

def count_from_conc(concordance):
    """From a concordance, count the words in it. Assume konks reside a dataframe with columns 'after' and 'before'"""
    word = concordance['word'][0]
    return nb.frame_sort(nb.frame(Counter(tokenize(' '.join(concordance['after'].values + concordance['before'].values))), word))

# %% [markdown]
# Modulen `nb_api` gir adgang til tekstene på samme måte som i bokhylla, eller https://nb.no

# %%
import nb_api as nap

# %% [markdown]
# Metadata fra Zotero brukes om guide til å hente tekster og lage subkorpus. Filen bør ligge i samme mappe som notebooken.

# %%
zotero = pd.read_excel("Zoterobibliotek eksportert_010420.xlsx").fillna('')
zotero.head()
# Out:
#         Key Source ID Column1    Item Type Publication Year  \
# 0  I8XV7B38                       document             1957
# 1  NA5JTD78                    bookSection             1970
# 2  235TMJP4                       document             1972
# 3  TK8NAQ9C                           book             1974
# 4  EXM5QBAL                       document             1974
#
#                                               Author  \
# 0                  Kirke,-undervisningsdepartementet
# 1                  Kirke,-undervisningsdepartementet
# 2         Forbruker- og administrasjonsdepartementet
# 3  Kirke- og undervisningsdepartementet; Østerud,...
# 4               Kirke- og undervisningsdepartementet
#
#                                                Title Publication Title  \
# 0  St.meld. nr. 35 (1957) Om lærebøkene i skoleve...
# 1  St. meld. nr. 91 (1969—70) Om reform av gymnas...
# 2              NOU 1972: 39 Førskoler : en utredning
# 3    NOU: 1974: 58 Lærarutdanning: tilråding I og II
# 4       St.meld. nr. 17 (1973—74) Nordisk samarbeid.
#
#                 ISBN ISSN  ... Programming Language Version System Code  \
# 0                          ...
# 1                          ...
# 2                          ...
# 3  978-82-00-70182-8       ...
# 4                          ...
#
#   Code Number Section Session Committee History Legislative Body
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 89 columns]

# %% [markdown]
# Kolonnene er de samme som ligger i Zotero.

# %%
zotero.columns
# Out:
# Index(['Key', 'Source ID', 'Column1', 'Item Type', 'Publication Year',
#        'Author', 'Title', 'Publication Title', 'ISBN', 'ISSN', 'DOI', 'Url',
#        'Abstract Note', 'Date', 'Date Added', 'Date Modified', 'Access Date',
#        'Pages', 'Num Pages', 'Issue', 'Volume', 'Number Of Volumes',
#        'Journal Abbreviation', 'Short Title', 'Series', 'Series Number',
#        'Series Text', 'Series Title', 'Publisher', 'Place', 'Language',
#        'Rights', 'Type', 'Archive', 'Archive Location', 'Library Catalog',
#        'Call Number', 'Extra', 'Notes', 'File Attachments', 'Link Attachments',
#        'Manual Tags', 'Automatic Tags', 'Editor', 'Series Editor',
#        'Translator', 'Contributor', 'Attorney Agent', 'Book Author',
#        'Cast Member', 'Commenter', 'Composer', 'Cosponsor', 'Counsel',
#        'Interviewer', 'Producer', 'Recipient', 'Reviewed Author',
#        'Scriptwriter', 'Words By', 'Guest', 'Number', 'Edition',
#        'Running Time', 'Scale', 'Medium', 'Artwork Size', 'Filing Date',
#        'Application Number', 'Assignee', 'Issuing Authority', 'Country',
#        'Meeting Name', 'Conference Name', 'Court', 'References', 'Reporter',
#        'Legal Status', 'Priority Numbers', 'Programming Language', 'Version',
#        'System', 'Code', 'Code Number', 'Section', 'Session', 'Committee',
#        'History', 'Legislative Body'],
#       dtype='object')

# %% [markdown]
# Dataene er utstyrt med noen tagger. Tell opp og se.

# %%
tags = nb.frame_sort(nb.frame(Counter(zotero['Manual Tags'].values), 'antall'.split()))
tags
# Out:
#                                                     antall
#                                                        249
# Høyere utdanning                                        24
# Grunnskole                                              17
# Lærerutdanning                                           9
# Videregående opplæring; Grunnskole                       9
# Videregående opplæring                                   5
# Barnehage                                                4
# Voksenopplæring                                          2
# St.meld.nr.39. Om kunst og kultur i og i tilkny...       2
# Videregående opplæring; Barnehage; Grunnskole            2
# Spesialundervisning                                      1
# Videregående opplæring; Lærerutdanning; Grunnskole       1
# Knyttet til St.meld.nr.16. Tidlig innsats for l...       1
# Fagopplæring                                             1
# Barnehage; Grunnskole                                    1

# %% [markdown]
# ### Analyse av data

# %% [markdown]
# Henter ut referanser fra zoterodataene for å komme til NB-digital.
#
# Listen over NB-data består av identifikatorer på sesamidformat eller URN-format.
#
# **Viktig: NB-digital har samleverk for statsmaktene, så søk i på sesamid tar hele samlingen, mens det kun er ett dokument som egentlig tilhører Polnet.**

# %%
dokref = zotero['Url'][zotero['Url'].str.contains('nb.no/')].values
dokref
# Out:
# array(['https://www.nb.no/statsmaktene/nb/5c15bbeeba31f51f2eeaf760d831cb99?index=11#1161',
#        'https://www.nb.no/items/URN:NBN:no-nb_digibok_2008052700008',
#        'https://urn.nb.no/URN:NBN:no-nb_digibok_2013100805016',
#        'https://www.nb.no/statsmaktene/nb/ca49bb43eeb537f04d71bb76bf978663?index=3#1231',
#        'https://urn.nb.no/URN:NBN:no-nb_digibok_2012062606119',
#        'https://urn.nb.no/URN:NBN:no-nb_digibok_2012062606119',
#        'https://www.nb.no/statsmaktene/nb/22ade39f6909f817f358a81a16ca1337?index=144#635',
#        'https://www.nb.no/statsmaktene/nb/45615976d5e5bff65500f7f8bb7fcf87?index=2#1285',
#        'https://urn.nb.no/URN:NBN:no-nb_digibok_2013100106023',
#        'https://www.nb.no/statsmaktene/nb/cc4e6f1a51d0b2b7b0f7ee91b2725dc0?index=1#717',
#        'https://urn.nb.no/URN:NBN:no-nb_digibok_2012071106024',
#        'https://urn.nb.no/URN:NBN:no-nb_digibok_2013100106024',
#        'https://urn.nb.no/URN:NBN:no-nb_digibok_2013120205188',
#        'https://urn.nb.no/URN:NBN:no-nb_digibok_2013120205188',
#        'https://urn.nb.no/URN:NBN:no-nb_digibok_2008060200027',
#        'https://www.nb.no/statsmaktene/nb/239023bb3d2c6c929cc4b0e5745ff04f?index=10#287',
#        'https://urn.nb.no/URN:NBN:no-nb_digibok_2

#        'https://www.nb.no/items/URN:NBN:no-nb_digibok_2011051308047',
#        'https://www.nb.no/statsmaktene/nb/628c101b2bf9e0c5ad55409a2bde6738?lang=no#0',
#        'https://www.nb.no/items/URN:NBN:no-nb_digibok_2008071100025',
#        'https://www.nb.no/items/URN:NBN:no-nb_digibok_2011040406096',
#        'https://www.nb.no/items/URN:NBN:no-nb_digibok_2011091906185',
#        'https://www.nb.no/statsmaktene/nb/afd81d31918f9676e0d778ac2dcac087?index=1#319',
#        'https://www.nb.no/statsmaktene/nb/402704eb18c7457f8028fb395711d67d?index=4#1327',
#        'https://www.nb.no/statsmaktene/nb/f78ceb809fcb02db622e26a136915339?index=9#1311',
#        'https://www.nb.no/statsmaktene/nb/720ed40410206d46b9ee0e9148b05580?index=10#829',
#        'https://www.nb.no/statsmaktene/nb/872aa802315825678e5bdcf61df75b53?index=8#459',
#        'https://www.nb.no/statsmaktene/nb/872aa802315825678e5bdcf61df75b53?index=8#501',
#        'https://www.nb.no/statsmaktene/nb/c3c1ecb1dac7cb5ddd145cb53d30ec42?index=1#1055',
#        'https://www.nb.no/statsmaktene/nb/281b6a62bc255e0e0952c2926184f658?index=9#453',
#        'https://www.nb.no/statsmaktene/nb/1ba9b5120159fb8ddf259a889b7b4481?index=1#347',
#        'https://www.nb.no/statsmaktene/nb/a7923729d620364642d44e105d7ff956?index=3#351',
#        'https://www.nb.no/statsmaktene/nb/a7923729d620364642d44e105d7ff956?index=1#407',
#        'https://www.nb.no/statsmaktene/nb/a7923729d620364642d44e105d7ff956?index=1#671',
#        'https://www.nb.no/statsmaktene/nb/b3d5a0afabdda4602134c69c00030867?index=2#993',
#        'https://www.nb.no/statsmaktene/nb/961622240c804d86eea99df83e513c96?index=8#843',
#        'https://www.nb.no/statsmaktene/nb/4dc5d9d66f5f6066327b3562e09b0aaa?index=1#7',
#        'https://www.nb.no/statsmaktene/nb/48ce81bc2cc5fcec84a7edfefe8c350a?index=2#913',
#        'https://www.nb.no/statsmaktene/nb/f12bfc3a6357eb9980c922634d43101e?index=1#1025',
#        'https://www.nb.no/statsmaktene/nb/45cbe0ec525978038eab13e9ae578210?index=1#525',
#        'https://www.nb.no/statsmaktene/nb/a1ca0065cbe8209097643e62d4e93859?index=5#675'],
#       dtype=object)

# %% [markdown]
# Henter først ut en liste over sesamid, ser på de fem første.

# %%
sesamids = [x.split('nb/')[-1].split('?')[0] for x in dokref if 'statsmaktene' in x]
sesamids[:5]
# Out:
# ['5c15bbeeba31f51f2eeaf760d831cb99',
#  'ca49bb43eeb537f04d71bb76bf978663',
#  '22ade39f6909f817f358a81a16ca1337',
#  '45615976d5e5bff65500f7f8bb7fcf87',
#  'cc4e6f1a51d0b2b7b0f7ee91b2725dc0']

# %% [markdown]
# så en liste over URN-er

# %%
urns = [x.split('/')[-1] for x in dokref if 'URN:NBN' in x ]
urns[:5]
# Out:
# ['URN:NBN:no-nb_digibok_2008052700008',
#  'URN:NBN:no-nb_digibok_2013100805016',
#  'URN:NBN:no-nb_digibok_2012062606119',
#  'URN:NBN:no-nb_digibok_2012062606119',
#  'URN:NBN:no-nb_digibok_2013100106023']

# %% [markdown]
# Legger sammen listene, og holder dem i variabelen `dok_ids`

# %%
dok_ids = sesamids + urns

# %% [markdown]
# Med identifikatorene på plass, kan det hentes ut konkordanser og lages kollokasjoner direkte.

# %% [markdown]
# Konkordanser hentes rett fra bokhylla for ett og ett verk, eller grupperes og summeres.

# %% [markdown]
# #### Enkeltverk

# %%
kompetanse_konk = nb.frame(nap.get_konks('a7923729d620364642d44e105d7ff956','kompetanse'))
kompetanse_konk
# Out:
#                                                    urn  \
# 0    URN:NBN:no-nb_digistorting_1990-91_part3_vol-c...
# 1    URN:NBN:no-nb_digistorting_1990-91_part3_vol-c...
# 2    URN:NBN:no-nb_digistorting_1990-91_part3_vol-c...
# 3    URN:NBN:no-nb_digistorting_1990-91_part3_vol-c...
# 4    URN:NBN:no-nb_digistorting_1990-91_part3_vol-c...
# ..                                                 ...
# 237  URN:NBN:no-nb_digistorting_1990-91_part3_vol-c...
# 238  URN:NBN:no-nb_digistorting_1990-91_part3_vol-c...
# 239  URN:NBN:no-nb_digistorting_1990-91_part3_vol-c...
# 240  URN:NBN:no-nb_digistorting_1990-91_part3_vol-c...
# 241  URN:NBN:no-nb_digistorting_1990-91_part3_vol-c...
#
#                                                 before         word  \
# 0    utgjøre grunnlaget for samarbeidsavtaler som a...   kompetanse
# 1    å sette igang et omfattende nordisk energifors...   kompetanse
# 2    en økende ulykkesfrekvens i prosesskjemisk ind...   kompetanse
# 3    . 38 7.6 Bærekraftig ressursforvaltning 40 7.7...   Kompetanse
# 4    vekst i sysselsettingen .. 78 10.3 Internasjon...   Kompetanse
# ..                                                 ...          ...
# 237  siktemål må være at et lærerkollegium skal sty...  kompetanse.
# 238  deltidsstudium og i moduler, slik at lærerne k...   kompetanse
# 239  eller arbeidsområder som er relevante for lære...   kompetanse
# 240  fagmiljøer som i dag er spredt på flere høgsko...   kompetanse
# 241  videre viktig at studenter også gjennom hovedf...   kompetanse
#
#                                                  after
# 0     disse organisasj onene har i makroøkonomiske ...
# 1     innenfor energiområdet ved de nasjonale høysk...
# 2     og sikkerhetsbevissthet i bedriftene. Man har...
# 3     - nøkkelen til økt verdiskapning og lønnsomhe...
# 4     er viktig for utvikling av næringslivet 80 10...
# ..                                                 ...
# 237   Skolens behov må da komme til uttrykk ved utl...
# 238   over tid. Departementet vil legge til rette f...
# 239   gjennom forskning og utviklingsarbeid. Med de...
# 240   og økt satsing på forsknings- og utviklingsar...
# 241   innen de skolefag de har sin grunnutdanning i...
#
# [242 rows x 4 columns]

# %% [markdown]
# #### For en samling

# %%
konks_reform = nb.frame(nap.get_all_konks('reform', dok_ids))

# %%
konks_fornyelse = nb.frame(nap.get_all_konks('fornyelse', dok_ids))

# %%
konks_reform
# Out:
#                                                     urn  \
# 0     URN:NBN:no-nb_digistorting_1969-70_part3_vol-c...
# 1     URN:NBN:no-nb_digistorting_1969-70_part3_vol-c...
# 2     URN:NBN:no-nb_digistorting_1969-70_part3_vol-c...
# 3     URN:NBN:no-nb_digistorting_1969-70_part3_vol-c...
# 4     URN:NBN:no-nb_digistorting_1969-70_part3_vol-c...
# ...                                                 ...
# 2310           URN:NBN:no-nb_digibok_2011040406096_0486
# 2311           URN:NBN:no-nb_digibok_2011040406096_0487
# 2312           URN:NBN:no-nb_digibok_2011091906185_0055
# 2313           URN:NBN:no-nb_digibok_2011091906185_0085
# 2314           URN:NBN:no-nb_digibok_2011091906185_0274
#
#                                                  before    word  \
# 0      Lønns- og inntektsoppgjørene våren 1970. 91. Om   reform
# 1     og inntektsoppgjørene våren 1970. Kirke- og un...  reform
# 2     og Skolekomitéens innstillinger 34 Kap. 111. E...  reform
# 3     elevtall i det videregående skoleverk 67 3. Ut...  reform
# 4                   i lov om realskoler og gymnas. 108   Reform
# ...                                                 ...     ...
# 2310                      Oslo På rett vei, uten rett.   Reform
# 2311  undersøkelse av den fylkeskommunale oppfølging...  Reform
# 2312  og den vidaregåande opplæring. 64 For voksne s...  Reform
# 2313  spesifikk bestemmelse, må statene rapportere s...  reform
# 2314  varige funksjonshemninger. Institutt for offen...  reform
#
#                                                   after
# 0      av gymnaset og forsøk med utbygging av det vi...
# 1      av gymnaset og forsøk med utbygging av det vi...
# 2      37 Vedlegg. 1. Uttaleleer om innstilling I og...
# 3                av gymnaset frå utvalet til å vurdere
# 4      og forsak i yrkesskolen 115 6. Om etterutdann...
# ...                                                 ...
# 2310   94 - konsekvenser for voksne. Sluttrapport. N...
# 2311   94. Sammendrag fra sluttrapportene fra KUF Ve...
# 2312   94), gir § 4A-1 rett til grunnskoleopplæ- rin...
# 2313   i 1998 håndheves EMK av Den europeiske mennes...
# 2314   og kommunal hverdag: Utviklingshemmetes levek...
#
# [2315 rows x 4 columns]

# %% [markdown]
# # Telling for kollokasjonsanalyse

# %% [markdown]
# For tellingen legger vi sammen alle konkordansene til en eneste stor tekst, som tokeniseres og telles opp på vanlig måte.

# %%
konks_reform['after'].values + konks_reform['before'].values
# Out:
# array([' av gymnaset og forsøk med utbygging av det videregående skoleverk. Vedlegg: 1. Tilråding om Lønns- og inntektsoppgjørene våren 1970. 91. Om ',
#        ' av gymnaset og forsøk med utbygging av det videregående skoleverk. INNHOLD Side Kap. I.og inntektsoppgjørene våren 1970. Kirke- og undervisningsdepartementet. St. meld. nr. 91. (1969—70) Om ',
#        ' 37 Vedlegg. 1. Uttaleleer om innstilling I og II fra Skolekomitéen av 1965 40 Struktureringog Skolekomitéens innstillinger 34 Kap. 111. En del forutsetninger for gjennomføring av forsøk og ',
#        ...,
#        ' 94), gir § 4A-1 rett til grunnskoleopplæ- ring ved behov. Voksne kan også få rett til videregåendeog den vidaregåande opplæring. 64 For voksne som ikke omfattes av retten til videregående opplæring (',
#        ' i 1998 håndheves EMK av Den europeiske menneskerettsdomstol (EMD) . 40 Både stater og individer kanspesifikk bestemmelse, må statene rapportere særskilt om denne gjennomføringen til barnekomiteen. 38 Etter en ',
#        ' og kommunal hverdag: Utviklingshemmetes levekår 10 år etter reformert. Rapportserie for sosialt arbeidvarige funksjonshemninger. Institutt for offentlig retts skriftserie nr. 3/2002. Tøssebro og Lundeby: Statlig '],
#       dtype=object)

# %% [markdown]
# Så til opptellingen

# %%
coll_reform = nb.frame_sort( nb.frame(Counter(tokenize(' '.join(konks_reform['after'].values + konks_reform['before'].values))), 'reform'))

# %%
coll_reform
# Out:
#            reform
# .            3575
# og           2127
# i            2077
# av           2051
# ,            1439
# ...           ...
# ferdig          1
# utbygget        1
# innebæreI       1
# 8.5             1
# Statlig         1
#
# [9025 rows x 1 columns]

# %% [markdown]
# Noen hjelpefunksjoner gjør det hele litt enklere:

# %%
coll_fornyelse = count_from_conc(konks_fornyelse)

# %%
coll_fornyelse
# Out:
#                 fornyelse
# og                   1998
# .                    1924
# av                   1350
# i                    1182
# ,                     997
# ...                   ...
# genera                  1
# neste                   1
# barnekulturen           1
# spenningen              1
# hovedombygging          1
#
# [6275 rows x 1 columns]

# %% [markdown]
# ## Relevante ord
#
# Sammenligner med bokhylla nå i første omgang. Det er flere måter å finne relevante ord, og flere måter å kna ordene på. Her skal vi bare bruke ordene som de er, og sammenligne med de 50000 mest frekvente i bokhylla.

# %%
tot = nb.frame(nb.totals(50000),'tot')

# %% [markdown]
# Dataene normaliseres. Siden korpusene har forskjellig størrelse, gir normaliseringen tall som kan sammenlignes.

# %%
nb.normalize_corpus_dataframe(tot)
nb.normalize_corpus_dataframe(coll_reform)
nb.normalize_corpus_dataframe(coll_fornyelse)
# Out:
# True

# %% [markdown]
# For eksempel er det omtrent samme antall punktum og høyfrekvente ord i dataene:

# %%
print(tot.loc['.'], coll_reform.loc['.'], coll_fornyelse.loc['.'])
# Out:
# tot    0.058921
# Name: ., dtype: float64 reform    0.051051
# Name: ., dtype: float64 fornyelse    0.046351
# Name: ., dtype: float64

# %% [markdown]
# Sammenligner ved se på forholdet mellom ord i den ene vs. den andre.

# %%
nb.frame(coll_reform['reform']/(coll_reform['reform'] +tot['tot'])).sort_values(by=0, ascending=False).head(40)
# Out:
#                                    0
# gymnaset                 1225.461425
# klassetrinn               459.928111
# meld                      409.653793
# Sikkerhetsrådet           387.135616
# lærlinger                 368.004758
# tot                       358.073113
# Europarådet               346.369012
# skattesystemet            324.928239
# FNs                       284.963033
# lokaler                   244.120015
# fag-                      241.605344
# ant                       234.009957
# tilrettelegging           228.976996
# skolestart                183.300186
# utviding                  169.210923
# fylkeskommunene           163.832927
# 91.                       160.928347
# læreplanene               159.313556
# videregående              153.238567
# Generalforsamlingen       149.142546
# studieretninger           143.053713
# vidtrekkende              142.524960
# 94                        137.609653
# reformen                  131.396493
# forskningsdepartementet   130.461406
# FN                        129.026759
# utbygging                 125.822565
# kommunesektoren           111.890909
# Sekretariatet             108.613905
# Albania                   108.073721
# Investeringer             105.721999
# innvandrerbakgrunn        102.079216
# tilråding                 101.267084
# faglege                   101.186402
# proposals                  99.710142
# etterutdanning             97.198432
# Forsøksrådet               96.054062
# grunnskolens               95.355378
# Boks                       95.117286
# sesjon                     94.971595

# %% [markdown]
# Alt kan puttes inn i en stor dataramme:

# %%
coll = pd.concat([coll_fornyelse, coll_reform], axis=1, sort=True)

# %% [markdown]
# Merk at når kollokasjonsteksten sorteres kommer koordinatorer høyt.

# %%
nb.frame_sort(coll).head().style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_d1a54da4_a5aa_11ea_babc_000acd2bfab2row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1a54da4_a5aa_11ea_babc_000acd2bfab2row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d1a54da4_a5aa_11ea_babc_000acd2bfab2row1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d1a54da4_a5aa_11ea_babc_000acd2bfab2row1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1a54da4_a5aa_11ea_babc_000acd2bfab2row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1a54da4_a5aa_11ea_babc_000acd2bfab2row2_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d1a54da4_a5aa_11ea_babc_000acd2bfab2row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d1a54da4_a5aa_11ea_babc_000acd2bfab2row3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1a54da4_a5aa_11ea_babc_000acd2bfab2row4_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d1a54da4_a5aa_11ea_babc_000acd2bfab2row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_d1a54da4_a5aa_11ea_babc_000acd2bfab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >fornyelse</th>        <th class="col_heading level0 col1" >reform</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d1a54da4_a5aa_11ea_babc_000acd2bfab2level0_row0" class="row_heading level0 row0" >.</th>
#                         <td id="T_d1a54da4_a5aa_11ea_babc_000acd2bfab2row0_col0" class="data row0 col0" >0.0463514</td>
#                         <td id="T_d1a54da4_a5aa_11ea_babc_000acd2bfab2row0_col1" class="data row0 col1" >0.051051</td>
#             </tr>
#             <tr>
#                         <th id="T_d1a54da4_a5aa_11ea_babc_000acd2bfab2level0_row1" class="row_heading level0 row1" >og</th>
#                         <td id="T_d1a54da4_a5aa_11ea_babc_000acd2bfab2row1_col0" class="data row1 col0" >0.0481341</td>
#                         <td id="T_d1a54da4_a5aa_11ea_babc_000acd2bfab2row1_col1" class="data row1 col1" >0.0303736</td>
#             </tr>
#             <tr>
#                         <th id="T_d1a54da4_a5aa_11ea_babc_000acd2bfab2level0_row2" class="row_heading level0 row2" >i</th>
#                         <td id="T_d1a54da4_a5aa_11ea_babc_000acd2bfab2row2_col0" class="data row2 col0" >0.0284758</td>
#                         <td id="T_d1a54da4_a5aa_11ea_babc_000acd2bfab2row2_col1" class="data row2 col1" >0.0296596</td>
#             </tr>
#             <tr>
#                         <th id="T_d1a54da4_a5aa_11ea_babc_000acd2bfab2level0_row3" class="row_heading level0 row3" >av</th>
#                         <td id="T_d1a54da4_a5aa_11ea_babc_000acd2bfab2row3_col0" class="data row3 col0" >0.0325231</td>
#                         <td id="T_d1a54da4_a5aa_11ea_babc_000acd2bfab2row3_col1" class="data row3 col1" >0.0292883</td>
#             </tr>
#             <tr>
#                         <th id="T_d1a54da4_a5aa_11ea_babc_000acd2bfab2level0_row4" class="row_heading level0 row4" >,</th>
#                         <td id="T_d1a54da4_a5aa_11ea_babc_000acd2bfab2row4_col0" class="data row4 col0" >0.0240189</td>
#                         <td id="T_d1a54da4_a5aa_11ea_babc_000acd2bfab2row4_col1" class="data row4 col1" >0.0205489</td>
#             </tr>
#     </tbody></table>

# %%
nb.frame(coll['reform']/tot['tot']).sort_values(by=0, ascending=False).head(40)
# Out:
#                                    0
# gymnaset                 1225.461425
# klassetrinn               459.928111
# meld                      409.653793
# Sikkerhetsrådet           387.135616
# lærlinger                 368.004758
# tot                       358.073113
# Europarådet               346.369012
# skattesystemet            324.928239
# FNs                       284.963033
# lokaler                   244.120015
# fag-                      241.605344
# ant                       234.009957
# tilrettelegging           228.976996
# skolestart                183.300186
# utviding                  169.210923
# fylkeskommunene           163.832927
# 91.                       160.928347
# læreplanene               159.313556
# videregående              153.238567
# Generalforsamlingen       149.142546
# studieretninger           143.053713
# vidtrekkende              142.524960
# 94                        137.609653
# reformen                  131.396493
# forskningsdepartementet   130.461406
# FN                        129.026759
# utbygging                 125.822565
# kommunesektoren           111.890909
# Sekretariatet             108.613905
# Albania                   108.073721
# Investeringer             105.721999
# innvandrerbakgrunn        102.079216
# tilråding                 101.267084
# faglege                   101.186402
# proposals                  99.710142
# etterutdanning             97.198432
# Forsøksrådet               96.054062
# grunnskolens               95.355378
# Boks                       95.117286
# sesjon                     94.971595

# %% [markdown]
# Sammenligner de forskjellige kollokasjonene

# %%
pmi = nb.frame_sort(nb.frame({x:coll[x]/tot['tot'] for x in coll}).transpose())

# %%
pmi.head(40).fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row0_col0 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row1_col1 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row2_col0 {
#             background-color:  #569dc8;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row2_col1 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row3_col1 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row4_col1 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row5_col1 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row6_col1 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row7_col1 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row8_col0 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row8_col1 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row9_col1 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row10_col0 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row10_col1 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row11_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row11_col1 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row12_col0 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row12_col1 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row13_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row13_col1 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row14_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row14_col1 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row15_col0 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row15_col1 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row16_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row16_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row17_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row17_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row18_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row18_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row19_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row19_col1 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row20_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row20_col1 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row21_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row21_col1 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row22_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row22_col1 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row23_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row23_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row24_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row24_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row25_col0 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row25_col1 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row26_col0 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row26_col1 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row27_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row27_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row28_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row28_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row29_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_78a48c8a_a5ab_11ea_b297_000acd2bfab2row29_col1 {
#             background-color:  #
