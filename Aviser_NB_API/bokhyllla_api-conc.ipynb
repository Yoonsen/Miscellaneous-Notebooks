# %%
import dhlab.nbtext as nb
import dhlab.graph_networkx_louvain as gnl
import dhlab.nbtokenizer as tok
from dhlab.module_update import css, update, code_toggle

import requests
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
import seaborn as sns
# %matplotlib inline

def get_df(frases, title='aftenposten'):
    import requests
    querystring = " + ".join(['"'+frase+'"' for frase in frases])
    query = {
        'q':querystring,
        'size':1,
        'aggs':'year',
        #'filter':'mediatype:{mt}'.format(mt=media),
        'filter':'title:{title}'.format(title=title)
    }
    r = requests.get("https://api.nb.no/catalog/v1/items", params = query)
    aggs = r.json()['_embedded']['aggregations'][0]['buckets']
    return {x['key']:x['count'] for x in aggs}

def get_json(frases, mediatype='aviser'):
    import requests
    querystring = " + ".join(['"'+frase+'"' for frase in frases])
    query = {
        'q':querystring,
        'size':1,
        'snippets':mediatype,
        'aggs':'year',
        
#        'filter':'mediatype:{mt}'.format(mt=mediatype),
        'searchType':'FULL_TEXT_SEARCH'
        #'filter':'title:{title}'.format(title=title)
    }
    r = requests.get("https://api.nb.no/catalog/v1/items", params = query)
    aggs = r.json()
    return aggs

def get_data(frase, media='avis', title='jazznytt'):
    import requests
    query = {
        'q':'"'+frase+'""',
        'size':1,
        'aggs':'year',
        'filter':'mediatype:{mt}'.format(mt=media),
        'filter':'title:{title}'.format(title=title)
    }
    r = requests.get("https://api.nb.no/catalog/v1/items", params = query)
    return r.json()

def get_data_and(frases, title='aftenposten', media='avis'):
    import requests
    querystring = " + ".join(['"'+frase+'"' for frase in frases])
    print(querystring)
    query = {
        'q':querystring,
        'size':1,
        'aggs':'year',
        #'filter':'mediatype:{mt}'.format(mt=media),
        'filter':'title:{title}'.format(title=title)
    }
    r = requests.get("https://api.nb.no/catalog/v1/items", params = query)
    return r.json()

def get_df_pd(frase, media='bøker'):
    import pandas as pd
    return pd.DataFrame.from_dict(get_df(frase, media=media ), orient='index').sort_index()

def phrase_plots(phrase_sets, title='aftenposten', fra = 1960, til = 2020, step=5, rot=0, colours = ['r', 'b','g','y','m','c']):
    df_all = []
    for f in phrase_sets:
        df_all.append(nb.frame(get_df(f, title= title), ', '.join(f)))
    df = pd.concat(df_all, sort=False)
    df.index = df.index.astype(int)
    df = df.sort_index()
    df['bins'] = pd.cut(df.index, range(fra, til, step), precision=0)
    df.groupby('bins').sum().plot(kind='bar', color=colours, figsize=(15,5), rot=rot)
    return

def phrase_plots_anno(phrase_sets, title='aftenposten', fra = 1960, til = 2020, rot=0, colours = ['r', 'b','g']):
    df_all = []
    for f in phrase_sets:
        df_all.append(nb.frame(get_df(f, title= title), ', '.join(f)))
    df = pd.concat(df_all, sort=False)
    df.index = df.index.astype(int)
    df = df.sort_index()
    #df['bins'] = pd.cut(df.index, range(fra, til, step), precision=0)
    df.plot(kind='bar', figsize=(15,5), rot=rot, color=colours)
    return

def graph_from_df(df, threshold = 100):
    edges =  []
    normalizer = {(x, y): df.stack()[(x,x)]*df.stack()[(y,y)] for (x,y) in df.stack().index}
    for (x, y) in df.stack().index:
        if x != y:
            if df.stack()[(x,y)] > threshold:
                edges.append([x,y,df.stack()[(x,y)]/normalizer[(x,y)]])
    G = nx.Graph()
    G.add_weighted_edges_from(edges)
    return G

def get_konks(urn, phrase, window=1000, n = 1000):
    import requests
    querystring = '"'+ phrase +'"' 
    query = {
        'q':querystring,
        'fragments': n,
        'fragSize':window
       
    }
    r = requests.get("https://api.nb.no/catalog/v1/items/{urn}/contentfragments".format(urn=urn), params = query)
    res = r.json()
    results = []
    try:
        for x in res['contentFragments']:
            urn = x['pageid']
            hit = x['text']
            splits = hit.split('<em>')
            s2 = splits[1].split('</em>')
            before = splits[0]
            word = s2[0]
            after = s2[1]
            results.append({'urn': urn, 'before': before, 'word':word, 'after':after})
    except:
        True
    return results

# %%
def item(frases, title='aftenposten'):
    import requests
    querystring = " + ".join(['"'+frase+'"' for frase in frases])
    query = {
        'q':querystring,
        'size':50,
        'aggs':'year',
        'scroll':True,
        #'filter':'mediatype:{mt}'.format(mt=media),
        'filter':'title:{title}'.format(title=title)
    }
    r = requests.get("https://api.nb.no/catalog/v1/items", params = query)
    #aggs = r.json()['_embedded']['aggregations'][0]['buckets']
    return r.json()

# %%
r =item('fred')

# %%
r
# Out:
# {'_links': {'next': {'href': 'https://api.nb.no/catalog/v1/items/scroll?scrollId=...-hoYWaFlaQ25md2hUWC04QjZyTGVKZkNhQRQwMERnUUhVQnVlUlBFYzhZTEwxUwAAAAABfpZ8Fk5zeXNnRUVCVEJtX2ZHNm1uYWdqclEUUzFuZ1FIVUJIRDF0U1F2SExOdFMAAAAAAX6Z_-mZ0WXzhsSkVmLTVRbENnR1I1QS1WVDRJQRRvLV9nUUhVQktmcTVuamNHTElkUwAAAAABfoaHFmhZWkNuZndoVFgtOEI2ckxlSmZDYUEUSUREZ1FIVUJDYllxU040SExKeFQAAAAAAR7z4hZoOGQ1cEJ4clI4Mmpoa3JtdTFuWGdRFHdCdmdRSFVCUE1xbW1DbElMRnRTAAAAAAF-...-kyUWZXlvZjI0NGFRaGV6TkJxRnY2NzdTQRRfMWZnUUhVQjZ6Q2VTMnFzTEpaVAAAAAABfp16FjFoY3RLRDA5VFlxU2hXWS1TdEdxdEEUR0FMZ1FIVUJCbFMzVXA4TExOMVQAAAAAAX6ZnhZfOGxKRWYtNVFsQ2dHUjVBLVZUNElBFHBPX2dRSFVCS2ZxNW5qY0dMSWRUAAAAAAF-...-mZ8WXzhsSkVmLTVRbENnR1I1QS1WVDRJQRQyMFBnUUhVQnQ0VVFMVndoTENGVAAAAAABHvQcFm5KazdMblJ2UjVPenZwTlVXckluOUEUQnlqZ1FIVUJWQlRjQ0liSExQVlUAAAAAAX6fXhYwUE82ZE9CTFRSR095NERiTHZYQmVRFFptSGdRSFVCXzBjOC1Sam9MQXRVAAAAAAF-pIAWRy1EVG5ZN2xSNHFIUjB2R1EzMUE2QRR0cmJnUUhVQnBhcmpkeXpUTEZsVQAAAAABHvPAFktlZDllMy1yVDhTM09WY2xhNzc3dFEUMVVEZ1FIVUJ1ZVJQRWM4WUxMMVUAAAAAAX6WfhZOc3lzZ0VFQlRCbV9mRzZtbmFnanJRFFZDTGdRSFVCWFd4YktYeEZMSkpVAAAA
#      'isDigital': True,
#      'isPublicDomain': False},
#     'metadata': {'title': 'Aftenposten ',
#      'titleInfos': [{'title': 'Aftenposten '}],
#      'geographic': {'city': 'Oslo', 'county': 'Oslo'},
#      'originInfo': {'issued': '20200826'},
#      'identifiers': {'oaiId': 'oai:mavis.nb.no:/TitleWork/key/18931995',
#       'urn': 'URN:NBN:no-nb_digavis_aftenposten_null_null_20200826_161_196_1'},
#      'languages': [{'code': 'Norsk NOR'}],
#      'pageCount': 52,
#      'mediaTypes': ['aviser'],
#      'contentClasses': ['AviserSeriesWorkkey224001',
#       'avisibibliotek',
#       'legaldeposit',
#       'jp2'],
#      'metadataClasses': ['public'],
#      'series': ['Aftenposten']}}],
#   'aggregations': [{'name': 'year',
#     'buckets': [{'key': '1898', 'count': 965},
#      {'key': '1901', 'count': 952},
#      {'key': '1902', 'count': 941},
#      {'key': '1899', 'count': 934},
#      {'key': '1897', 'count': 912},
#      {'key': '1896', 'count': 901},
#      {'key': '1900', 'count': 901},
#      {'key': '1891', 'count': 844},
#      {'key': '1890', 'count': 793},
#      {'key': '1895', 'count': 788},
#      {'key': '1888', 'count': 739},
#      {'key': '1889', 'count': 730},
#      {'key': '1894', 'count': 729},
#      {'key': '1910', 'count': 720},
#      {'key': '1886', 'count': 715},
#      {'key': '1923', 'count': 712},
#      {'key': '1906', 'count': 703},
#      {'key': '1907', 'count': 701},
#      {'key': '1892', 'count': 684},
#      {'key': '1903', 'count': 684},
#      {'key': '1909', 'count': 684},
#      {'key': '1905', 'count': 681},
#      {'key': '1893', 'count': 668},
#      {'key': '1904', 'count': 668},
#      {'key': '1908', 'count': 653},
#      {'key': '2013', 'count': 627},
#      {'key': '1887', 'count': 626},
#      {'key': '1924', 'count': 621},
#      {'key': '2015', 'count': 592},
#      {'key': '2008', 'count': 576},
#      {'key': '1916', 'count': 575},
#      {'key': '2007', 'count': 573},
#      {'key': '2014', 'count': 571},
#      {'key': '1918', 'count': 562},
#      {'key': '1922', 'count': 557},
#      {'key': '1917', 'count': 548},
#      {'key': '1915', 'count': 541},
#      {'key': '1929', 'count': 534},
#      {'key': '2011', 'count': 533},
#      {'key': '1935', 'count': 532},
#      {'key': '2009', 'count': 532},
#      {'key': '1925', 'count': 519},
#      {'key': '1938', 'count': 519},
#      {'key': '1930', 'count': 513},
#      {'key': '1920', 'count': 504},
#      {'key': '1931', 'count': 504},
#      {'key': '1885', 'count': 503},
#      {'key': '1936', 'count': 503},
#      {'key': '1928', 'count': 500},
#      {'key': '1933', 'count': 500}]}]}}

# %%
requests.get(r['_links']['next']['href']).json()
# Out:
# {'_links': {'self': {'href': 'https://api.nb.no/catalog/v1/items?page=0&size=1'}},
#  'page': {'size': 0, 'totalElements': 0, 'totalPages': 1, 'number': 0},
#  '_embedded': {}}

# %%
results = []
for x in r['contentFragments']:
    urn = x['pageid']
    hit = x['text']
    splits = hit.split('<em>')
    s2 = splits[1].split('</em>')
    before = splits[0]
    word = s2[0]
    after = s2[1]
    results.append({'urn': urn, 'before': before, 'word':word, 'after':after})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-55d952610e7c> in <module>
#       1 results = []
# ----> 2 for x in r['contentFragments']:
#       3     urn = x['pageid']
#       4     hit = x['text']
#       5     splits = hit.split('<em>')
#
# KeyError: 'contentFragments'

# %%
results

# %%
r = get_konks("URN:NBN:no-nb_digibok_2011021403034", "pølse i handa", window=2000)
r
# Out:
# [{'urn': 'URN:NBN:no-nb_digibok_2011021403034_0009',
#   'before': 'gjør vi jo alle pølser: En enslig mann på en bensinstasjon tre! ved middagstider, med ei ',
#   'word': 'pølse i handa,',
#   'after': ' bryter god spiseskikk. Pølsa blir da for mange et symbol på forfall. Vi har ikke som'}]

# %%
r = get_konks("URN:NBN:no-nb_digibok_2011021403034", "og", window=500)
r
# Out:
# [{'urn': 'URN:NBN:no-nb_digibok_2011021403034_0006',
#   'before': '2008 ISBN 978-82-02-28996-6 1. opplag 2008 W Design ',
#   'word': 'og',
#   'after': ' omslag: Laila Sundet Gundersen, Artell Omslagsfoto: Morten Brun Sats: Laila Sundet Gundersen, Artell Trykk '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0006',
#   'before': 'omfattet av åndsverklovens bestemmelser. Uten særskilt avtale med Cappelen Damm AS er enhver eksemplarfremstilling ',
#   'word': 'og',
#   'after': ' tilgjengeliggjøring bare tillatt i den utstrekning det er hjemlet i lov eller tillatt gjennom avtale med'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0006',
#   'before': 'rettighetshavere til \u2029� I Utnyttelse i strid med lov eller avtale kan medføre erstatningsansvar ',
#   'word': 'og',
#   'after': ' inndragning, '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0007',
#   'before': '.. .. , . . . .Kalkunpølser. Kylling- Om politikk, kjærlighet. sjel bratwurst. Veg etarpølser ',
#   'word': 'og',
#   'after': ' pø ser R j S p o i ser me[ j svinekjøtt Pølsemaker, pølsemaker, .Havregrynspølser hvor har'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0007',
#   'before': "dv pølser mcd mester'n« Utstyr «Kjøttsorter Del 4: Matrettar 120 / / / / Krydder ",
#   'word': 'og',
#   'after': ' smak. Nitritt '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0009',
#   'before': 'Vossakorv Register 234 7 NORDMENN ELSKER PØLSER. Vi spiser mellom 50 ',
#   'word': 'og',
#   'after': ' 60 000 tonn i året! '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0009',
#   'before': '',
#   'word': 'og',
#   'after': ' journalisten. Begeistringa for pølser hadde vi. Men var pølsespising her i landet. Mat kategoriseres det nok til å skrive ei stor pølsebok også? alltid moralsk i forhold til tid, sted '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0009',
#   'before': 'Vi har derfor gjerne en formening dag", forstod vi at dette ville holde hele om hvem, hvor ',
#   'word': 'og',
#   'after': ' når det passer sega spise veien til forleggeren. For det gjør vi jo alle pølser: En enslig'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0009',
#   'before': 'pølser hver dag. Men vi håper at du som blar i denne boka skal få lyst på gode pølser ',
#   'word': 'og',
#   'after': ' pølseretter. Ja, kanskje du får lyst til å lage dine egne pølser? Pølseoppskriftene er derfor stort'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0010',
#   'before': 'Det var et veldig søtt ',
#   'word': 'og',
#   'after': ' helt annerledes dyr, veldig redd '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0010',
#   'before': 'var alltid vakent. Pølsedyret ble med Doktor Dyregod til England, helt frivillig, ',
#   'word': 'og',
#   'after': ' fordi Doktor Dyregod var så snill '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0010',
#   'before': 'TORE WILHELM TEIGEN, hvem er vanlig blant pølsemakere å bruke det? Med over 50 år i bransjen, ',
#   'word': 'og',
#   'after': ' uttrykket resept.) Nærmere 5 000 mange ganger hoveddommer i NM pølsevarianter har han skrevet'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0010',
#   'before': '1 som kan pølser. hvor det tenkes stort: Ei bøtte Der et trent gamblerøye raskt med ditt, ',
#   'word': 'og',
#   'after': ' en neve med datt. kan se hvilken travhest som blir Utfordringa for en samler blir å » I'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0010',
#   'before': "stikkord for helt uten betydning! pølsemakermester Teigen. Både Det har ikke vært mange Mester'n på jobben ",
#   'word': 'og',
#   'after': ' i fritida. Hva annet nedturer for Teigen som fagmann skulle vel en pølsemakerlærling på pølser, men'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0010',
#   'before': 'med sans for proteiner drive fra en frisør på 50-tallet har brent med, enn sykling, sleggekast ',
#   'word': 'og',
#   'after': ' seg fast: styrkeløft? - Nei, så godt det lukter av deg. Men premiesamlinga overgår Du lukter så'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0010',
#   'before': 'resepter - eller ARBEIDSANTREKK: Alltid hvit oppskrifter - på pølser. [Det er frakk ',
#   'word': 'og',
#   'after': ' caps 9 TURBQBUDEIA BODIL er i Til '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0011',
#   'before': '',
#   'word': 'Og',
#   'after': ' de elsker Pølser er, ifølge Bodil, den mest det. Kursdeltakerne, altså. maskuline maten som fins. '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0011',
#   'before': 'dei gløymt kven dei er ',
#   'word': 'og',
#   'after': ' kor det bli. (Her er det kanskje dei kjerne frå! på sin plass å nevne at Bodil Det har ikke Bodil. Allerede bruker både konjakk '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0011',
#   'before': 'få den grytene hjemme i Byrte, ',
#   'word': 'og',
#   'after': ' hun rette smaken. Ikke rart at det er har opparbeida seg et rykte som mange mannfolk med!] ei hardt arbeidende kokke '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0011',
#   'before': 'tradisjonsmatstudiet ved Høgskulen i Telemark avd. ARBEIDSANTREKK: Skaut, Rauland, vet hun hvordan hun stakk ',
#   'word': 'og',
#   'after': ' forkle skal bringe fram urmennesket i oss. Budeia NAVN: Bodil Irene Gunnarsdotter Nordjore, spesialist på'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0011',
#   'before': 'kalt gaudaganer], klar: Vi nordmenn bare elsker entusiasten med sin dobbelt pølser! stemme, ',
#   'word': 'og',
#   'after': " mester'n vakent til "},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0011',
#   'before': 'FAVORITTPØLE Premierte julepølser TILBEHØR: Grov sennep, en akevitt ',
#   'word': 'og',
#   'after': ' litt juleøl BESTE TARM: Vil helst ikke tenke på det ... fjøllmatakevitt '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0014',
#   'before': 'budeie frå fjølli, er ikkje alltid so enkelt. Nei ein sku vore hane med staskam ',
#   'word': 'og',
#   'after': ' prakt! I denne te kort i høve til industrien med sine store, tunge maskinar., Men sukk ikkje. Det er'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0014',
#   'before': 'ein skuff, ',
#   'word': 'og',
#   'after': ' du veit akkurat kor det du treng "frelste" på pylser frå landet. ligge. Entusiasten elskar gørrgoe pylsur. Mesteren æ nysgjerrig, men litt atterhalden til budeias sprell '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0014',
#   'before': 'pølse. Pølse det no som kjem ut av pylsefogemaskina? Ja, er nokso kjedeleg ',
#   'word': 'og',
#   'after': ' kjønslaust, spør du meg. ja. Overberande '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0014',
#   'before': 'umedvetne augnekast skjøna at du - Bærre det er feitt nok, seier entusiasten, har med kvalitet, smak ',
#   'word': 'og',
#   'after': ' levande matkultur å sø er alt greitt! Mykje smak lyt det vera. gjera når du ser ordet'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0014',
#   'before': 'med feitt, goe smakar ',
#   'word': 'og',
#   'after': ' ein forførande fasong, det gjer I I susen folkens. Tenk om resten av mm Det er nesten to planetar som skal foreinast i ein '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0014',
#   'before': 'Entusiasten vil berre eta pylsene, ',
#   'word': 'og',
#   'after': ' helst sleppe å ha dei nette pianofingrane sine borti tarmar '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0014',
#   'before': 'InQentinQ GT Entusiasten er også relativt lett Eg har som kvinne ',
#   'word': 'og',
#   'after': ' å forføre, det ligg langt utanpå fagformidlar ofte undra meg over SO morosamt h an kva han eigentleg syns om kva det er'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0014',
#   'before': 'Orføre det meste av både smått ',
#   'word': 'og',
#   'after': ' som appellerarso mykje til menn. „ . „ Eg spurde ein kar eg kjenner kva *O atale stort. Han er lett å lesa, '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0014',
#   'before': 'Meistaren er nok meir av den typen Akkurat ja. Spanande ',
#   'word': 'og',
#   'after': ' morosam pylse. tanke. '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0014',
#   'before': 'ufatteleg moro ',
#   'word': 'og',
#   'after': ' viktig so enkelt å gå tett på, eller vera nere to store å foreine desse to roma. Entusiasten der ute, pylsekarar frå byn? Når du som ei enkel sjel '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0014',
#   'before': 'sakene frå fjøllet ser på pylse som eit mataukemne, ',
#   'word': 'og',
#   'after': ' sine. Han kan pylsur, '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0014',
#   'before': 'skal framstille arbeidsglede ',
#   'word': 'og',
#   'after': ' kvinneglede i heime produksjon, kan du ofte kjenne at du kjem So kan han humre stille i skjegget sitt '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0015',
#   'before': 'renner tungt ',
#   'word': 'og',
#   'after': ' stille gjennom Østerdalen. Den skal til havet. Jeg skal til Trondheim. '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0015',
#   'before': 'ikke kjøre ',
#   'word': 'og',
#   'after': ' spise salat samtidig. Bilen må jo på rens før du kommer fram. En stor hamburger eller en kebab, duger heller ikke. ...jeg kan ikke kjøre i spise salat samtidig. '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0015',
#   'before': 'begge hendene Jeg kan hver eneste sving på rundt maten ',
#   'word': 'og',
#   'after': ' dressing o rundt maten '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0015',
#   'before': 'sted. Inn i bilen igjen. På med cruisekontrollen. ',
#   'word': 'Og',
#   'after': ' så det første utålmodige bittet. "Ligg unna fet mat når du kjører bil", messer ekspertene. "'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0015',
#   'before': 'visst dette lenge. Pølse i brød er ',
#   'word': 'og',
#   'after': ' blir den perfekte sjåførmaten. Du har fri sikt over '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0015',
#   'before': 'overalt, er du rett ',
#   'word': 'og',
#   'after': ' slett trafikkfarlig! 14 71 Den som vet hvordan lover '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0016',
#   'before': "uker i bare i bassar'n (mester'n sier ikke basaren). vakuumpakning. I dag blir disse bare liggende ",
#   'word': 'Og',
#   'after': ' én av dem drev kun med hestekjøtt! sju til åtte dager ute i butikkene. De røkte Teigen husker'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0016',
#   'before': 'da kundene måtte til slakteren for å få kjøtt. ',
#   'word': 'Og',
#   'after': ' fruene fra vestkanten kom ens ærend til sentrum for å handle kjøttpålegg. To hekto skinke '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0016',
#   'before': 'Noe har gått tapt underveis. Bransjen enn ol Qe SIOSS fulgte ikke med i timen, ',
#   'word': 'og',
#   'after': ' i dag leverer de '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0016',
#   'before': 'det 8-12 dager før pølsene er ute hos forbrukerne! - Dette går ut over de urøkte variantene ',
#   'word': 'og',
#   'after': ' mangfoldet, mener Teigen Delikatesse- Bjørn Halvorsen ved produktene forsvmner. Alle vil jo bare satse sentrum'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0017',
#   'before': 'oppe fra kl 06.00, baka fire brød ',
#   'word': 'og',
#   'after': ' alle i heimen er klare for uttrykning kl 07.45. Der nyster er gjorde, flasker er fylte, stakken er på, '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0017',
#   'before': 'er innom i fyrste ',
#   'word': 'og',
#   'after': ' beste korg, rekk akkurat å smette '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0017',
#   'before': '',
#   'word': 'og',
#   'after': ' rappar fem kalde wienerpylsur!!! 0 Herre! telefonen. Rekk akkurat fotballtreninga, '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0017',
#   'before': 'gøtt - ',
#   'word': 'og',
#   'after': ' det virkar. Hurra for '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0018',
#   'before': 'kjærleik ',
#   'word': 'og',
#   'after': ' sjel Når eg seier at pølser er fylte med kjærleik, er dette fordi ein kan leggje noko så ufyseleg, men då må ein hugse på at tarmar som reidskap både har vore '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0018',
#   'before': 'dei kommande gongene gå Tenk berre på gode, varme ',
#   'word': 'og',
#   'after': ' blaute arbeidshender som uredde arbeidar med tarmar '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0018',
#   'before': 'ung jente ',
#   'word': 'og',
#   'after': ' vart sendt inn i slakteriet til alle tider, for å hente både stort '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0018',
#   'before': 'produktet som er både unik ',
#   'word': 'og',
#   'after': ' talt fort fekk nok av. Lukt er pussige greier, alt umogleg å oppnå på andre måtar. Nærleiken det kan fa oss } ll a '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0018',
#   'before': 'gjeld også til alt frå steikt * kjøtkaker er for meg noko heilt anna knaing av brøddeigar ',
#   'word': 'og',
#   'after': ' alt som har med enn lukta av n £ a 9 a P^ ser! f . heimeproduksjon å gjere.'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0018',
#   'before': "hypnotisert av fristande arbeidet. Ved å bruke hendene, blir ' ' . , pylsediskar, ",
#   'word': 'og',
#   'after': ' er em pylsefrelst ein fyrst '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0018',
#   'before': 'arbeidar med. Kjøt er som oftast augene seg pa den andre sida av svært kaldt å arbeide med, ',
#   'word': 'og',
#   'after': ' når °pp fOr pylser, disken. Kjøttype, feittmengde, em knar inn saltet legg det seg ofte er ein'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0018',
#   'before': 'ein seld fOF et belegg av feitt på hendene. Av .„ .. , alt bl r Eg tykkjer dette ',
#   'word': 'og',
#   'after': ' til må ein la hendene puste ei eVI 9 tld - eT a vlrke e 9 fantastisk, at noko'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0018',
#   'before': 'mile °? le -.f n u kan J» e ™ n^ aktl^ krydder, vil dette endre både konsistens ',
#   'word': 'og',
#   'after': ' s ° m e fl m s^ v sk Jf tl! alle tlde 1 r! l Er det smak. Utsjånaden'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0018',
#   'before': 'av farge ',
#   'word': 'og',
#   'after': ' lukt. Når dette er sagt, kan eg °9 sa sla tl] d førtl! n 9 en kan , stoppe deg, bli virkeleg salig av å elte på ein stor '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0018',
#   'before': 'Det er kun pylsedeig! Noko av det viktigaste i forhold sluttproduktet som er viktig rett ',
#   'word': 'og',
#   'after': ' slett at til pylselaging, er luktesansen. Å forhalde det smakar gøtt . Som du sikkert har forstått'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0019',
#   'before': 'med kjærleik, men også mengder med feitt! Pylsa rna ha em fin konsistens, 17 ikkje for kort ',
#   'word': 'og',
#   'after': ' ikkje for turr. Derfor er det kjøt. Eg nyttar kim godt råstoff, som blir ein velsigning å'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0019',
#   'before': 'å gjere, pylse til alle tider, ei fersk, ny ',
#   'word': 'og',
#   'after': ' spenstig er å forføre alle rundt deg med deg sjølv '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0019',
#   'before': 'når eg snakkar om kjærleik ',
#   'word': 'og',
#   'after': ' sjel i ei pylse. Spenstige pylser er gode greier, pylsa må ha heng! ein god fasong '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0019',
#   'before': 'lag av entusiastar for å få den uerfarne til å prøve ein rett ',
#   'word': 'og',
#   'after': ' slett ha lyst på maten ein puttar seg på nye '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0019',
#   'before': 'med flott nok også pylser, då ei heimelaga pylse kan kjøt, friske urter ',
#   'word': 'og',
#   'after': ' kjærleiksfylt arbeid, då sjå både grå, kjedeleg '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0019',
#   'before': 'at ordmannen heimegjort pylse, vil ein ny verden opne seg! et så mykje pølser, det er rett ',
#   'word': 'og',
#   'after': ' slett særdeles Då eg var dommar i ein blindtest i Grenland, godt! I Telemark har me eit'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0019',
#   'before': 'ein Odd-supportar av ypparste klasse, i tillegg på noko, ein smak ein rett ',
#   'word': 'og',
#   'after': ' slett må ha ein til ein ung '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0019',
#   'before': 'den Plutseleg fekk eg ei noko grå ',
#   'word': 'og',
#   'after': ' grov pølse smakar godt! Av '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0019',
#   'before': 'alle slag - raust, varmt ',
#   'word': 'og',
#   'after': ' godt. Det vere god. Når alt derimot var prøvesmakt '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0019',
#   'before': 'tilbehør inntil! Pylser er ikkje usunn mat. storleik ',
#   'word': 'og',
#   'after': ' farge som tel mest! Eg lagar pølsene mine utan noko form for tilsetning '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0020',
#   'before': 'du gjort av deg? Et godt refreng, ',
#   'word': 'og',
#   'after': ' et betimelig spørsmål. Det ble første gang stilt i filmen "Den forsvundne pølsemaker" fra 1941, med blant andre Leif Juster i én av hovedrollene. I filmen'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0020',
#   'before': 'filmen forsvinner byens pølsemaker på mystisk vis, ',
#   'word': 'og',
#   'after': ' detektivene Stein Rask '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0020',
#   'before': 'flinke pølsemakere her i landet. ',
#   'word': 'Og',
#   'after': ' de har så mye mer enn en standard pølsemeny å by på. Aldri har det vært solgt så mange forskjellige pølser som nå, '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0022',
#   'before': 'smaksgaranti. Erik Fosnes Hansen, forfatter A 20 Laks, pølser ',
#   'word': 'og',
#   'after': ' rock and roll. Alle gode ting er tre for pølsemakeren som elsker fluefiske '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0022',
#   'before': '',
#   'word': 'og',
#   'after': ' et sjøfly ble rekvirert. Det hadde kanskje holdt med nettutgaven i våre dager, men på nittitallet var det fremdeles papirutgaven som gjaldt. Gode anmeldelser måtte leses - svart på hvitt! '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0022',
#   'before': 'en hel nasjon følte at den var kommet på fornavn med en pølsemaker fra Hønefoss. Uansett når ',
#   'word': 'og',
#   'after': ' hvor vi stoppa for å fylle bensin, ble vi møtt av en Leiv Vidar-plakat. At mange fremdeles'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0022',
#   'before': 'er bilen til kveldens danseband som kommer kjørende, tar Arne Vidar med et smil. Han har rett ',
#   'word': 'og',
#   'after': ' slett ikke mer å by på av navn. Vidar er etternavnet! For ham har det viktigste vært å'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0022',
#   'before': 'som firmabil, faktisk. 11975 tok Arne over: - Det lå litt i genene, kan du si! ',
#   'word': 'Og',
#   'after': ' da det ble mer '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0022',
#   'before': 'Stekeplater ',
#   'word': 'og',
#   'after': ' griller ble montert på bensinstasjonene, '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0022',
#   'before': 'Noen går til ',
#   'word': 'og',
#   'after': ' med så langt at de gir Arne Vidar skylda for at flere hundre pølseboder ble stengt her i landet. Men pølsemakeren fra Hønefoss er ikke enig. - Jeg så bare de'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0022',
#   'before': 'som lå der. Han er i dag den stolte eier av en bedrift hvor tre av fire har fagbrev, ',
#   'word': 'og',
#   'after': ' premiehylla er full! Leiv Vidar er det firmaet som har vunnet mest under Nr i kjøttprodukter de'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0023',
#   'before': 'rikelig tid til sin store lidenskap - fluefiske! 21 Norgesmester i pølser tre ganger på rad, ',
#   'word': 'og',
#   'after': ' gull i enkeltøvelser som bratwurst, det er bare noe av det Morten Haugen fra kjøttbedriften John'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0023',
#   'before': 'ØSTFOLDBEDRIFTEN har 10 Den lille kjøttbedriften har ikke egen butikk lenger. De leverer kim til kantiner ',
#   'word': 'og',
#   'after': ' andre storhusholdninger. Da blir det ofte kunden som bestemmer hva slags pølser de skal lage. Den'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0023',
#   'before': 'på det. Marché kjeden har bestilt ei pølse med kalvekjøtt som smaker som pølser fra Sør-Europa. ',
#   'word': 'Og',
#   'after': ' det har de fått. - Vi vil ha fornøyde kunder. Det er vår enkle filosofi, understreker Haugen.'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0023',
#   'before': 'tilpasse produktene vi leverer til den årsverk, ',
#   'word': 'og',
#   'after': ' omsetter for ca. 30 millioner kroner enkelte kantine, legger han til. i året. 11983 overtok Morten Haugen bedriften '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0023',
#   'before': 'John, som begynte i kjelleren Haugen også har vært "best in show" under NM. hjemme i 1956. ',
#   'word': 'Og',
#   'after': ' junior måtte tidlig opp for Ikke med sin firbemte venn, men en enkel "hot å holde følge med'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0023',
#   'before': 'med speilegg ',
#   'word': 'og',
#   'after': ' kakao. Det var lokkematen som skulle til for å få tenåringen på beina. - Jeg ble jo nesten født "i hakka", sier en noe andpusten pølsemaker. Han er ute '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0023',
#   'before': 'Finn Spjudvik ',
#   'word': 'og',
#   'after': ' Roger Fladberg fikk gull for bratwurst under NM i kjøttprodukter. (Foto: Indre Smaalene) 22 Hvor mye veier en éngangsgrill? Aner du ikke? Nei, vel. Men med to hjul '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0024',
#   'before': 'kjøtt på rista, nærmer grillen til VM-laget seg ett tonn! Monsteret kalles en "smoker", ',
#   'word': 'og',
#   'after': ' brukes under VM i grilling i USA. Doningen kunne like gjerne vært en attraksjon ved Jernbanemuseet på'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0024',
#   'before': "Tore Teigen (sønn av mester'n), diplompølsemakermester ",
#   'word': 'og',
#   'after': ' deltaker under VM i grilling -ÉNGANGSGRILLER SKULLE vært forbudt! Lagleder Bjørn Tore Teigen rister på nodet. '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0024',
#   'before': 'Men både røyken ',
#   'word': 'og',
#   'after': ' stemningen stiger etter hvert. Vi skjønner at våre urøkte pølser ikke er den største utfordringen for en sportsgriller, men de henges nå opp i røykkammeret. '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0024',
#   'before': 'gyllenbrune pølsene ',
#   'word': 'og',
#   'after': ' venter på øverste hylle i grillen. Dinner is served! Teigen forteller at grilling, eller barbecue, er en folkesport i USA. Dette er amerikanernes tradisjonsmat, '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0024',
#   'before': 'Til ',
#   'word': 'og',
#   'after': ' med nobelprisvinner '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0024',
#   'before': 'er barbecue. Temperaturer mellom 100 ',
#   'word': 'og',
#   'after': ' 150 grader er det ideelle. Fra 200 grader '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0024',
#   'before': 'går det ut over røykinga. Det er nemlig samme varmekilde som brukes. Det fyres både med ved ',
#   'word': 'og',
#   'after': ' kull. Men altså, ikke ei flaske tennvæske å se i mils omkrets. Nå er ikke VM i grilling'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0024',
#   'before': 'pølsemesterskap. Det hadde nok blitt en kortvarig affære. Derfor må laget trene på både krydder, logistikk ',
#   'word': 'og',
#   'after': ' tilbehør til annen mat. Det er heller ikke her du trekker fram en ferdig marinert flintstek til'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0024',
#   'before': "fall å se at mester'n ",
#   'word': 'og',
#   'after': ' sønn fortsatt setter pris på ei lita nystekt pølse etter så mange år i bransjen. W V Dver dammen er han 23 Laila Hole '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0025',
#   'before': 'Valderøy er landets beste grillere! De ble norgesmestere i 2007, ',
#   'word': 'og',
#   'after': ' har gode plasseringer fra VM i grilling året etter. KATRINE LDRGEN HAR OGSÅ VUNNET NM i ferdigmat med sin rett fra Hole Kjøtt:'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0025',
#   'before': 'Kjøtt: Kalvegryte irosegelé! Den lille bedriften har både pølsemakeri ',
#   'word': 'og',
#   'after': ' eget kjøkken. Hvis vi så legger til at Ann Kristin Aure jobber som pølsemaker i samme bedrift, begynner vi å nærme oss en liten'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0025',
#   'before': 'en mannsdominert bransje. Hvorfor er det så få kvinnelige pølsemakere, Laila Hole? - Det har vært, ',
#   'word': 'og',
#   'after': ' er, tungt arbeid. Men det er flere damer i bransjen nå. "Grillmore Girls" er ikke bare navnet'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0025',
#   'before': 'som regel vært mannens jobb? - Å grille i dag involverer mye utstyr. Det appellerer til menn. ',
#   'word': 'Og',
#   'after': ' så tror jeg at det "å fyre opp" er noe som bringer fram urmennesket i oss. Å gjøre'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0025',
#   'before': 'nå har vist at du kan. Hva skal vi passe på når vi griller pølser? - Riktig varme ',
#   'word': 'og',
#   'after': ' noen små snitt i pølsene er viktig. Ei god pølse slipper ikke ut fuktigheten, så noen forsiktige'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0025',
#   'before': 'De fleste pølser sprekker under grilling uansett, mener grillvinneren. For Laila Hole er pølser sunn ',
#   'word': 'og',
#   'after': ' god festmat. Men for noen år siden ble bilen til broren hennes påkjørt av en pølsemaker. Mannen'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0025',
#   'before': 'han kunne leve med dem. Pølsemakeren kom da med et tilbud om et gratis råd som kompensasjon. ',
#   'word': 'Og',
#   'after': ' det gikk broren med på. Spis aldri pølser, sa pølsemakeren NAVN: Laila Hole, driver Hole Kjøtt AS'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0026',
#   'before': 'Strøm-Larsen ',
#   'word': 'og',
#   'after': ' broren, slakter '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0026',
#   'before': 'Både pålegg ',
#   'word': 'og',
#   'after': ' pølser. Du finner et stort utvalg av pølser i disken. Alt fra kreolsk chillipølse '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0026',
#   'before': 'en gang på 80-tallet, har vi nordmenn vært klar for det meste. Til ',
#   'word': 'og',
#   'after': ' med nord-afrikanske pølser laga av okse- '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0026',
#   'before': 'salt ',
#   'word': 'og',
#   'after': ' pepper. For 30 år siden var det sju slakterbutikker i denne delen av byen. Så kom supermarkedene. Hvorfor har Strøm-Larsen overlevd? - Skal kundene komme hit, må utvalget være bedre '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0026',
#   'before': 'bredere enn i kjede-butikkene. Vi kan ikke konkurrere på pris, men på kvalitet ',
#   'word': 'og',
#   'after': ' service. Vi må være bedre. Her finner du fagfolk med lang erfaring. Sjefen høster ikke applaus for den uttalelsen. De'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0027',
#   'before': 'er kontrollert, ',
#   'word': 'og',
#   'after': ' helt topp. I høysesongene, juli '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0027',
#   'before': 'ei lammepølse med hvitløk ',
#   'word': 'og',
#   'after': ' kruspersille. - Folk får helt hetta når de får se alle pølsene i butikken. Da skal de ha to av den, to av den, '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0027',
#   'before': 'flere bæreposer fulle av pølser for å ta med hjem eller gi bort til kjente ',
#   'word': 'og',
#   'after': ' kjære. Jeg har til '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0027',
#   'before': 'Pølsemakermesteren i sørlandsbyen har latt seg inspirere til å lage greske, ungarske, tyrkiske, spanske ',
#   'word': 'og',
#   'after': ' tyske pølser. De prøver seg fram i familiebedriften. Noen ganger inspirert av pølser de har fått'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0027',
#   'before': 'vekk oppe i gryta med lanken for å fiske opp ei pølse til seg sjøl også, når han står ',
#   'word': 'og',
#   'after': ' prater med kundene i butikken. NAVN: Steinar Brubakken, pølsemakermester FAVORITTPØLSE Tysk bratwurst med karve'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0028',
#   'before': 'for litt siden slått med et par meter av en "jypling i Trondheim", som han uttrykker det. ',
#   'word': 'Og',
#   'after': ' det er helt greit. Varene i disken er tross alt det viktigste. Der er Idsøe nøye. - VI'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0028',
#   'before': '(såkalte "E\'er"), ',
#   'word': 'og',
#   'after': ' krydderet skal være ferskt. Ingen ferdige krydderblandinger i våre pølser. I de røkte pølsene må vi derimot bruke litt nitrittsalt. A. Idsøe AS har 21 ansatte, '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0028',
#   'before': 'sentrum. - De fine ',
#   'word': 'og',
#   'after': ' gode butikkene er bare med på å løfte nivået i bransjen. Alle tjener på det. Jo høyere standard, desto bedre konkurranseevne mot Rema 1000 '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0028',
#   'before': 'Bort med alt nips, ',
#   'word': 'og',
#   'after': ' rene flislagte flater. Tilbake til den gode, gamle kjøttbutikken, er filosofien i Verksgata. - Vi ville ha tilbake mer av butikkens sjel både inne '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0028',
#   'before': 'også en film vi entusiaster ',
#   'word': 'og',
#   'after': ' fagfolk bør se. Den danske filmen "De Grønne Slagtere". Her lages det frikadeller av en dypfryst elek triker (stengt inne på kjølerommet), '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0028',
#   'before': 'som er hemmeligheten bak de gode kronhjortpølsene i butikken. ',
#   'word': 'Og',
#   'after': ' hun får svar: Først så dreper du, så slakter du, så hakker du, '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0029',
#   'before': 'pølsemaker Johannes Lundal, mor, far ',
#   'word': 'og',
#   'after': ' to søstre. De har tydeligvis ikke vært plaga av lange navnediskusjoner i denne slekta. Er du eldste sønn, får du enkelt '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0029',
#   'before': 'faren til Marianne ',
#   'word': 'og',
#   'after': ' Johannes. Han er nest yngst av sju brødre, som alle har drevet i bransjen. Men det er pinnekjøttet '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0029',
#   'before': '2007 Gullmedaljer ',
#   'word': 'og',
#   'after': ' mye skryt har de fått, både for pinnekjøttet '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0029',
#   'before': 'er det med på å gi denne tradisjonsrike spekepølsa en mild ',
#   'word': 'og',
#   'after': ' fm smak. På middagsbordene rundt om, er det Åkerring '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0029',
#   'before': 'røyking ',
#   'word': 'og',
#   'after': ' navnebytte før den kom ut igjen som en vinner: Lundals hardangerpølse! - Hardangerpølsa minner litt om vossakorv, '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0029',
#   'before': 'litt krydder. Det er den gode kjøttsmaken vi vil ha fram. ',
#   'word': 'Og',
#   'after': ' så er eldhusrøykinga viktig, legger Lundal Berge til. Lundalfamilien er slett ikke vant til å få klager på produktene sine. Derfor ble'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0029',
#   'before': 'holdbarheten til noen små ølpølser han akkurat hadde kjøpt. Marianne Lundal Berge ble litt "øvejidde", ',
#   'word': 'og',
#   'after': ' svarte at pølsene hadde samme holdbarhet som den andre spekematen fra Lundal: et halvt år. - Det'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0030',
#   'before': 'sunnmørske pågangsmotet har skapt så mye glede i den nye bedriften. ',
#   'word': 'Og',
#   'after': ' veldig mye god spekemat! Han husker godt en kveld de sått '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0030',
#   'before': 'fortelle om favorittpølsa si. Den med akevitt-krydder. - Ei lita smaksreise. Først kjenner du litt anis, ',
#   'word': 'og',
#   'after': ' etter hvert kommer karvesmaken. Det er det rike, runde smaksbilde vi prøver å få fram. Vi NAVN:'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0030',
#   'before': 'mcc akevittkrydder TILBEHØR: Oliven ',
#   'word': 'og',
#   'after': ' pesti men drømmer om noe noi STE TARM: Hestetai T riktig diamet bruker lite salt for å unngå de sterke smakene av surt '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0030',
#   'before': 'tok Stabburet over Ringstads pølsefabrikk i 1973. ',
#   'word': 'Og',
#   'after': ' så kom SPIS. I dag leier de nye eierne de gamle produksjonslokalene, '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0031',
#   'before': 'helt med mengden. Mor var borte, ',
#   'word': 'og',
#   'after': ' den unge kokken mente pølser var tingen for far '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0031',
#   'before': 'fort bli litt for mye for den lille bedriften. Da vil de heller bruke kjøtt fra reinsdyr ',
#   'word': 'og',
#   'after': ' annet vilt til å lage spekepølser. Så rene produkter som mulig. Spekepølsene røykes på olderflis. BEDRIFTEN'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011021403034_0031',
#   'before': 'i dag kjøtt fra vilt til våre tre nordligste fylker. ',
#   'word': 'Og',
#   'after': ' de har reinkjøtt i middagspølsene! NAVN: John Anders Lifjell, ARV (Arctic Rein '}]

# %%
korpus = nb.book_corpus(period=(2005,2020))
korpus
# Out:
#               urn                author  \
# 0   2013120206065
# 1   2013020409007  Petersen, Jan Køppen
# 2   2015091406092         Tremain, Rose
# 3   2012060805027  Sporstøl, Ebba-Marie
# 4   2011062309017
# 5   2016072848052        Krauss, Nicole
# 6   2012120606082   Lien, Mona Vangsnes
# 7   2011031703024
# 8   2016011448007       Wedsberg, Malin
# 9   2013011607026
# 10  2011120206086     Torgersen, Oddvar
# 11  2013071608012
# 12  2015090808003    Ersland, Geir Atle
# 13  2014040906032
# 14  2013071706037            Hidle, Mie
# 15  2012101509100       Gautneb, Håvard
# 16  2013012206047        Stanišić, Saša
# 17  2015050648065            Bull, Jane
# 18  2012111408061
# 19  2013110405013   Martinsen, Per Ivar
#
#                                                 title  year
# 0                 Unge lesarar til bry og begeistring  2005
# 1   Slektsbok over Ole Pedersen (1808-1882) og Lor...  2006
# 2                                  Musikk og stillhet  2006
# 3                                           Tuba luba  2006
# 4                                       Advokatkurset  2006
# 5                              Kjærlighetens historie  2006
# 6                                                 VIP  2005
# 7                                  Galleri Semmingsen  2009
# 8                                       Beas familier  2011
# 9                    Oversettelser fra verden nær oss  2009
# 10                                   Lønn og personal  2005
# 11                  På det statlige lederplan i 50 år  2005
# 12                                 Byens konstruksjon  2011
# 13  Undersøkelser for å styrke modeller knyttet ti...  2009
# 14                                        tredje ting  2009
# 15  Ressursundersøkelser i Snåsaskifers brudd ved ...  2005
# 16             Hvordan soldaten reparerer grammofonen  2009
# 17                                       Presangboken  2005
# 18                                             Salome  2005
# 19                         Skisser for en kort sommer  2006

# %%
konks = []
for x in korpus.urn:
    konks += get_konks('URN:NBN:no-nb_digibok_' + str(x), 'kultur')

# %%
konks
# Out:
# [{'urn': 'URN:NBN:no-nb_digibok_2015091406092_0004',
#   'before': 'Design Trykk: Valdres Trykkeri Printed in Norway ISBN 82-530-2880-6 W Utgitt med støtte fra Europakommisjonen, ',
#   'word': 'Kultur',
#   'after': ' 2000 Til min datter Eleanor i evig kjærlighet INNHOLD DEL I København, 1629 9 DEL II Frederiksborg'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011031703024_0012',
#   'before': 'bildene til minnene og det konkrete, bestandige; maleriet som representa sjon av disse. Min tilhørighet tii ',
#   'word': 'kultur;',
#   'after': ' historie, familie og arv er bestanddeler som er viktige utgangspunkt for arbeidene før de kommer ut'},
#  {'urn': 'URN:NBN:no-nb_digibok_2013011607026_0032',
#   'before': "» ' Oversettelse har vært forskjellige ting til forskjellige tider, 5 og er forskjellig fra ",
#   'word': 'kultur',
#   'after': ' til '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011120206086_0003',
#   'before': '1 — Organisasjonen og den ansatte 7 Målsetting 7 Organisasjon 7 Organisasjonsutvikling 9 Ledelse 10 ',
#   'word': 'Kultur',
#   'after': ' 21 Personalforvaltning 22 Personalpolitikk 24 Personalplanlegging 25 Konklusjon? 37 Litteratur 37 Kapittel 2 -'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011120206086_0007',
#   'before': 'Delmålene er nådd når du kan forklare hva en organisasjon er forstår begrepene funksjon, struktur og ',
#   'word': 'kultur',
#   'after': ' kan gi eksempler på klassiske organisasjonsformer vet i hvilken retning organisasjonsutviklingen går kan nevne'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011120206086_0021',
#   'before': 'Ikke glem nettverkene. Ha tro på deg seiv. Gi ros til dine omgivelser. Få kolleger med deg. ',
#   'word': 'Kultur',
#   'after': ' En leder har enorm betydning for kulturen i en bedrift. Med bedriftskultur mener vi de uskrevne'},
#  {'urn': 'URN:NBN:no-nb_digibok_2011120206086_0021',
#   'before': 'de ansatte på det sosiale og følelses messige plan. Vi snakker om positiv og negativ ',
#   'word': 'kultur.',
#   'after': ' En etablert '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011120206086_0021',
#   'before': 'Det er svært ødeleggende for alle om det setter seg en «negativ ',
#   'word': 'kultur»',
#   'after': ' der. På den annen side er en positiv '},
#  {'urn': 'URN:NBN:no-nb_digibok_2011120206086_0031',
#   'before': 'utfelling på børskursen. Men uten et skikkelig for og etterarbeid, basert på bedriftens reelle bemanningsbehov, ',
#   'word': 'kultur',
#   'after': ' og fomtsetninger, er risikoen stor for at tiltakene ikke er optimale for bedriften på lengre sikt.'},
#  {'urn': 'URN:NBN:no-nb_digibok_2013071608012_0039',
#   'before': 'frigjøringen: «Målet var ... å skape et nytt og bedre Norge, rikere både på materielle ressurser og ',
#   'word': 'kultur,',
#   'after': ' og ikke minst i 9 Tekst: Gunnar Aultun Gunnar Aultun har vært LO siden 1974 og medlem'},
#  {'urn': 'URN:NBN:no-nb_digibok_2015090808003_0007',
#   'before': 'av bygrunn og byutviding på 1500- og 1600-talet 176 Brannallmenningane 179 Den einskaplege byen 184 Ein ',
#   'word': 'kultur-',
#   'after': ' og ein helseakse 186 Perspektiv på byutvikling 189 Modernisering og diskontinuitet 190 Ekspansjon og kommunikasjon'},
#  {'urn': 'URN:NBN:no-nb_digibok_2015090808003_0045',
#   'before': 'ved Jonsvollkvartalet ca. 1980 nsvollkvartalet var tvikla seg frå 1600-taIet. Kvartalet var histori amanhengande ',
#   'word': 'kultur',
#   'after': ' rå midten av 1600-talet og i følgjande hundreår Flyfoto 2009. Før rivinqa inneheldt Jonsvollkvartalet element'},
#  {'urn': 'URN:NBN:no-nb_digibok_2015090808003_0052',
#   'before': 'år av hus som strekte seg like opp til den gamle sidan. Likevel, denne feiltolkinga av det ',
#   'word': 'kultur-',
#   'after': ' 51 gj Før strandstaden. Opphavet til Øvregaten var ein vei frå kongsgarden på Alrekstad til'},
#  {'urn': 'URN:NBN:no-nb_digibok_2015090808003_0188',
#   'before': 'i eit bylandskap prega av omfattande reguleringar frå 1850-åra og i tida etter. 186 EIN ',
#   'word': 'KULTUR-',
#   'after': ' OG EIN HELSEAKSE Dei tre klostera Nonneseter, Jonsklosteret og Munkeliv hadde i mellomalderen danna'},
#  {'urn': 'URN:NBN:no-nb_digibok_2015090808003_0189',
#   'before': 'jernbanestasjon låg, blei Stenersens samlings bygg reist (1978), og frå 2000 blei også Bergen 187 ',
#   'word': 'Kultur',
#   'after': ' og helse i det historiske bylandskapet. Her er are eit utval av dei mest sentrale'},
#  {'urn': 'URN:NBN:no-nb_digibok_2013071706037_0335',
#   'before': 'kunne bare skje gjennom en gradvis erkjennelse av egen selvstendighet - gjennom øvelse, dannelse, ',
#   'word': 'kultur.',
#   'after': ' Det ville føre mot stadig større sammenfall mellom de empiriske jegene og den absolutte enheten'},
#  {'urn': 'URN:NBN:no-nb_digibok_2013012206047_0004',
#   'before': 'the support of the Culture Programme (2007-2013) of the European Union. m » » Uddannttsc og ',
#   'word': 'kultur',
#   'after': ' '},
#  {'urn': 'URN:NBN:no-nb_digibok_2012111408061_0016',
#   'before': 'sine forsøk på å legge band på eigen seksualitet, og så utfordrar ho ein undertrykkande, patriarkalsk ',
#   'word': 'kultur.',
#   'after': ' Gail Finney meinte i 1989 at Salome berre under tvil kunne sjåast som ei kvinne. Ho er heller'}]

# %%
nb.concordance(word='morsomt', corpus='avis', title='aftenposten', kind="json")
# Out:
# [{'after': '. Når Kristopher Schaus pølsestunt',
#   'before': '; de synes medier ev',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_20040204_145_58_2',
#   'word': 'morsomt'},
#  {'after': ". Kristoffer Nordvik Ti '",
#   'before': 'det etter all sannsynlighet blir',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_20040204_145_58_2',
#   'word': 'morsomt'},
#  {'after': 'kurs vil dere få kunnskap',
#   'before': 'Gjennom gratis , lærerikt og',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_20040204_145_58_2',
#   'word': 'morsomt'},
#  {'after': 'kurs vil dere få kunnskap',
#   'before': 'Gjennom gratis , lærerikt og',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_20040204_145_58_2',
#   'word': 'morsomt'},
#  {'after': ', innrømmer 18 - åringen',
#   'before': ', men det er ikke',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_20040204_145_58_2',
#   'word': 'morsomt'},
#  {'after': 'å se hvordan finnmaricingrne moter',
#   'before': 'denne gang . Det er',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19560217_97_81_1',
#   'word': 'morsomt'},
#  {'after': 'å mote opp I mßrka',
#   'before': ', det skulle være så',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19560217_97_81_1',
#   'word': 'morsomt'},
#  {'after': 'er det a se Henry',
#   'before': '. « pilt . Sffrllg',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19560217_97_81_1',
#   'word': 'morsomt'},
#  {'after': '— eller spennende . «',
#   'before': 'i det som bare er',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19560217_97_81_1',
#   'word': 'morsomt'},
#  {'after': 'dobbeltspill . De nifse morcll',
#   'before': '« ir anledning til pndel',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19560217_97_81_1',
#   'word': 'morsomt'},
#  {'after': 'å få vite . Overlat',
#   'before': 'leserne av Aftenposten synes var',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19620721_103_329_1',
#   'word': 'morsomt'},
#  {'after': 'at det aioi seg glimrende',
#   'before': "' som er sd umiddelbart",
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19620822_103_383_1',
#   'word': 'morsomt'},
#  {'after': 'og rorende A folge familien',
#   'before': '. De ! er bftdi',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19620824_103_387_1',
#   'word': 'morsomt'},
#  {'after': ', men også farlig .',
#   'before': 'Angrepsspillet var nemlig ikke bare',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19620824_103_387_1',
#   'word': 'morsomt'},
#  {'after': 'innslag Arrangorene lover , \\',
#   'before': 'kaffe og toten-knnpler et meget',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19620830_103_398_1',
#   'word': 'morsomt'},
#  {'after': 'og merkelig hjem med en',
#   'before': 'glæder , og samtidig et',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19130406_54_171_1',
#   'word': 'morsomt'},
#  {'after': '. En av de ferste',
#   'before': 'vi ofte hat det svært',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19130406_54_171_1',
#   'word': 'morsomt'},
#  {'after': 'Program i Hyl : lUB',
#   'before': "I passet godt OL '",
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19130104_54_5_1',
#   'word': 'morsomt'},
#  {'after': 'at røge sin egen tobak',
#   'before': 'Det kunde va » re',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19130105_54_7_1',
#   'word': 'morsomt'},
#  {'after': '. * DomorH Ab »',
#   'before': 'Den nye Mode • rasendo',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19130111_54_18_1',
#   'word': 'morsomt'},
#  {'after': 'aom før ? — Akkurat',
#   'before': 'Møller — er det Ilke',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19310311_72_127_1',
#   'word': 'morsomt'},
#  {'after': "å ' spille sammen med",
#   'before': 'Aabel . Det er skrekkelig',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19310311_72_127_1',
#   'word': 'morsomt'},
#  {'after': ', så går det gærnt',
#   'before': 'skuespillerne synes et stykke er',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19310311_72_127_1',
#   'word': 'morsomt'},
#  {'after': 'å få spille dyrlægen ,',
#   'before': 'del synes det er svært',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19310311_72_127_1',
#   'word': 'morsomt'},
#  {'after': 'som Hansen 1 sin tid',
#   'before': ', men Jeg hadde det',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19310311_72_127_1',
#   'word': 'morsomt'},
#  {'after': 'da Julia sovnet . Like',
#   'before': '. - Det var veldig',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_20030220_144_86_2',
#   'word': 'morsomt'},
#  {'after': 'H , ardeicl . ;',
#   'before': '« 5 ° ^ !',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19520219_0_5_4',
#   'word': 'morsomt'},
#  {'after': 'å se hvoir rent og',
#   'before': 'på øya . Det er',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19470705_88_297_1',
#   'word': 'morsomt'},
#  {'after': 'stevne hvor publikum nektet å',
#   'before': 'Danmark 60 poeng . Et',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19470705_88_297_1',
#   'word': 'morsomt'},
#  {'after': 'oppgjør mellom Nordens beste motorsyklisten',
#   'before': 'en vellykt sesong , et',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19470705_88_297_1',
#   'word': 'morsomt'}]

# %%
phrase_plots([['sykdom', 'vaksine'],['sykdom'],['vaksine']], title='*', colours=['orange', 'skyblue','green'], fra=1840, til=1980, step=10)

# %%
phrase_plots_anno([['vaksine']], title='*', fra=1945, til=2020,  rot=60, colours=['skyblue'])

# %%
phrase_plots([["Ruth maier", 'Jan Erik Vold'], ['Ruth maier', 'Gunvor Hofmo'],['Ruth Maier']], title='*', colours=['green', 'orange', 'skyblue'], fra=1980, til=2020, step=4)
