# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
mu.update("mods_meta")
# Out:
# Updated file `D:\documents\GitHub\Miscellaneous-Notebooks\mods_meta.py`

# %%
import mods_meta as mm

# %% [markdown]
# ## Undersøke oversatt litteratur:
#
# ### Kulturpolitiske virkemidler
#
# Ønsker å undersøke hvorvidt innkjøpsordningen for oversatt skjønnlitteratur, som kom i 1990, har ført til flere oversettelser. Er det andre kulturpolitiske forhold vi bør se på også?
# - Avgrense bøker:
#     - skjønnlitteratur
#     - er oversatt
#     - periode 1950 - 2010
#     - er det mulig å begrense hver tittel til 1 forekomst, slik at nye opplag/utgaver ikke kommer med?
# - Lage graf for antall bøker per år.
#
# ### Multikulturell framvekst?
# - Vi kan også se på fordelingen mellom språk for disse bøkene, og se på utvikling. Er det for eksempel slik at vi kan spore framveksten av et mer flerkulturelt samfunn? Et problem er at mange forfattere er oversatt fra engelsk. Kan vi se på forfatternes nasjonalitet i autoritetsregisteret?

# %%
mm.book_info(2009021104104)
# Out:
# ([('Cortázar, Julio', '1914-1984', 'bibsys.no:authority:90126409')],
#  [],
#  [('Rugstad, Christian', None, '')],
#  'Paradis',
#  '',
#  '1999',
#  'nob',
#  'Solum',
#  ['argentinske', 'romaner', '1960-tallet'],
#  '863',
#  '62c4a4ab4754588ec6639ea82d7e815d',
#  'spa',
#  '')

# %%
mm.book_info(2010050408082)
# Out:
# ([('Roy, Arundhati', '1961-', 'bibsys.no:authority:90988632')],
#  [],
#  [('Stokke, Ragnfrid', None, '')],
#  'Guden for små ting',
#  '',
#  '[1999]',
#  'nob',
#  'Pax',
#  ['skjønnlitteratur', 'india'],
#  '823',
#  '3a5679e91266570f2c9ff87608624465',
#  'eng',
#  '')

# %%
mm.book_info(2014102008081)
# Out:
# ([('Atwood, Margaret', '1939-', 'bibsys.no:authority:90071737')],
#  [],
#  [('Alfsen, Merete', None, '')],
#  'Tjenerinnens beretning',
#  '',
#  '1987',
#  'nob',
#  'Aschehoug',
#  ['Skjønnlitteratur',
#   'fremtid',
#   'skjønnlitteratur',
#   'romaner',
#   'stråling',
#   'katastrofer',
#   'strålingskata',
#   'strofer',
#   'kvinner',
#   'undertrykkelser',
#   'religiøse',
#   'grupper'],
#  '813',
#  '3104552b7422185a8181b9d100d5480b',
#  'eng',
#  '')

# %%
mm.book_info(2007051100026)
# Out:
# ([('Achebe, Chinua', '1930-2013', 'bibsys.no:authority:90082405')],
#  [],
#  [('Bang, Karin', None, '')],
#  'mann av folket',
#  '',
#  '1967',
#  'nob',
#  'Dreyer',
#  ['skjønnlitteratur/voksen'],
#  ' 823',
#  '6ea2b5da60e9e59677902fbf98442b2a',
#  'eng',
#  '')

# %%
mm.book_info(2008020400104)
# Out:
# ([('Murakami, Haruki', '1949-', 'bibsys.no:authority:90667003')],
#  [],
#  [('Risvik, Kari', None, ''), ('Risvik, Kjell', None, '')],
#  'Dans dans dans',
#  '',
#  '1994',
#  'nob',
#  'Pax',
#  [],
#  '895.63',
#  '1ba4d2c99983f8bf38aa167bc3740b6b',
#  'eng',
#  '')

# %% [markdown]
# ### Inkonsekvens i metadata/emneord
#
# Når vi sammenlikner metadata for disse to bøkene, ser vi at det ikke er konsekvent emneordsangivelse:
#  - skjønnlitteratur vs romaner
#  - india vs argentinske
#  - bruk av sammensatte emneord ("skjønnlitteratur/voksen")
#
# Dewey-feltet definerer språk, men ikke område.(Unntak: 813 er amerikansk litteratur på engelsk. 823 er engelsk fiksjon. 863 er spansk fiksjon)

# %%
korpus = nb.book_corpus(period=(1950, 2010), limit=2000000)

# %%
u = nb.pure_urn(korpus)

# %%
# %%time
meta = dict()
for i in range(0, len(u), 10000):
    temp =  mm.metadata(urns = u[i:i+10000])
    for k in temp:
        meta[k] = temp[k]

# %%
meta
# Out:
# {'2006081600045': {'100-1- -a': 'Astrup, Nils',
#   '245-1-0-a': 'Noen tanker om utviklingen i norsk skipsfart og norsk industri i 1970-årene',
#   '260- - -c': '1970',
#   '653- - -a': 'industri, norge, skipsfart',
#   'lang': 'nob',
#   'year': 1970},
#  '2006081700030': {'100-1- -a': 'Aukrust, Olav',
#   '245-1-0-a': 'Skaldespor :',
#   '245-1-0-b': 'artiklar, talar, brev, dikt',
#   '260- - -c': '1965',
#   '653- - -a': 'artiklar, brev, dikt, litteratur, norsk, nynorsk, talar',
#   'lang': 'nno',
#   'year': 1965},
#  '2006082900067': [],
#  '2006082900103': [],
#  '2006110300009': {'100-1- -a': 'Kubelka, Susanna',
#   '245-1-0-a': 'Endelig over 40',
#   '260- - -c': '1981',
#   '653- - -a': 'kvinnefrigjøring, kvinner, politikk/samfunn, psykologi, sosiologi',
#   'lang': 'nob',
#   'year': 1981},
#  '2006110300051': {'245-1-0-a': 'Arbeidervernloven',
#   '245-1-0-b': 'lov om arbeidervern av 7. des. 1956 med endringer ved lov av 28. nov. 1958, lov av 13. april 1962, lov av 29. mai 1964,lov av 10. mai 1968, lov av 13. juni 1969, lov av 5. mai 1972, lov av 16. juni 1972 og lov av 15. desember 1972',
#   '260- - -c': '1973',
#   '653- - -a': 'juss/økonomi',
#   'lang': 'nob',
#   'year': 1973},
#  '2006110600017': [],
#  '2006110600066': {'100-1- -a': 'Høydal, Aslaug',
#   '245-1-0-a': 'Tårer i sand :',
#   '245-1-0-b': 'roman',
#   '260- - -c': '1969',
#   '653- - -a': 'skjønnlitteratur/voksen',
#   'lang': 'nno',
#   'year': 1969},
#  '2006110900027': [],
#  '2006110901008': {'100-1- -a': 'Eriksen, Hans A.',
#   '245-1-0-a': 'Dager og netter på skogen',
#   '260- - -c': '1980',
#   '653- - -a': 'biografi/genealogi, buskerud, idrett/fritid, krokskogen',
#   'lang': 'nob',
#   'year': 1980},
#  '2006110901034': {'100-1- -a': 'Dolci, Danilo',
#   '245-1-0-a': 'Til de unge',
#   '260- - -c': '1968',
#   '653- - -a': 'politikk/samfunn',
#   'lang': 'nob',
#   'year': 1968},
#  '2006110901067': {'100-1- -a': 'Hierman, Audun',
#   '245-1-0-a': 'Offeret',
#   '260- - -c': '1966',
#   '653- - -a': 'skjønnlitteratur/voksen',
#   'lang': 'nob',
#   'year': 1966},
#  '2006111001023': {'100-1- -a': 'Ljone, Oddmund',
#   '245-1-0-a': 'Grønt lys for eventyret',
#   '260- - -c': 'c1954',
#   '653- - -a': 'geografi/historie',
#   'lang': 'nob',
#   'year': 1954},
#  '2006111001042': {'100-1- -a': 'Høydal, Aslaug',
#   '245-1-0-a': 'Fjellvaken',
#   '260- - -c': 'cop. 1995',
#   '653- - -a': 'skjønnlitteratur/voksen',
#   'lang': 'nno',
#   'year': 1995},
#  '2006111300043': {'100-1- -a': 'Nordhus, Alf',
#   '245-1-0-a': 'Jeg tar saken',
#   '260- - -c': '1968',
#   '653- - -a': 'juss/økonomi',
#   'lang': 'nob',
#   'year': 1968},
#  '2006111401025': {'100-1- -a': 'Sjöblom, Kerstin',
#   '245-1-0-a': 'Åtte spedbarn begynner på daghjem :',
#   '245-1-0-b': 'en undersøkelse av barns behov, tilpasning og utvikling på ulike daghjem',
#   '260- - -c': '1976',
#   '653- - -a': '8205087814, barnehager, barnehagestart, barnepsykologi, daghjem, sosial, spedbarn, velferd',
#   'lang': 'nob',
#   'year': 1976},
#  '2006111600025': {'100-1- -a': 'Bolesch, Hermann Otto',
#   '245-1-0-a': 'Willy Brandt',
#   '260- - -c': '1971',
#   '653- - -a': 'biografi/genealogi, biografier, brandt, brandt,, geografi/historie, historie, politiker, tysk, willy',
#   'lang': 'nob',
#   'year': 1971},
#  '2007012601064': {'100-1- -a': 'Ryssel, Edith',
#   '245-1-0-a': 'Sykehuset i urskogen :',
#   '245-1-0-b': 'hos Albert Schweitzer i Lambarene',
#   '260- - -c': '1954',
#   '653- - -a': 'biografi/genealogi, biografier, leger',
#   'lang': 'nob',
#   'year': 1954},
#  '2007012901053': {'260- - -c': '1950',
#   '653- - -a': 'traktater',
#   'lang': 'nob',
#   'year': 1950},
#  '2007020101015': {'100-1- -a': 'Mühr, Alfred',
#   '245-1-0-a': 'Det hvite gull :',
#   '245-1-0-b': 'roman om porselenets makt og hemmelighet',
#   '260- - -c': '1954',
#   'lang': 'nob',
#   'year': 1954},
#  '2007020101033': {'100-1- -a': 'Wiesener, Albert',
#   '245-1-0-a': 'Nordmenn for tysk krigsrett 1940-1942',
#   '260- - -c': '1954',
#   'lang': 'nob',
#   'year': 1954},
#  '2007020201061': {'100-1- -a': 'Miller, Henry',
#   '245-1-0-a': 'Åpent brev til surrealister i alle land',
#   '260- - -c': '1950',
#   '653- - -a': 'filosofi, kunst, litteraturvitenskap, surrealisme',
#   'lang': 'nob',
#   'year': 1950},
#  '2007020901046': [],
#  '2007021401020': [],
#  '2007021401065': [],
#  '2007021501015': [],
#  '2007021901112': {'100-1- -a': 'Nerhus, Hans',
#   '245-1-0-a': 'Frå vikings tid til vår tid :',
#   '245-1-0-b': 'eit stykke vestnorsk skipsbyggingssoge',
#   '260- - -c': '1955',
#   '653- - -a': 'hordaland',
#   'lang': 'nno',
#   'year': 1955},
#  '2007022001011': {'100-1- -a': 'Hamsun, Marie',
#   '245-1-0-a': 'Tina toppen',
#   '260- - -c': '1955',
#   'lang': 'nob',
#   'year': 1955},
#  '2007022001015': {'100-1- -a': 'Ditleff, Niels Christian',
#   '245-1-0-a': 'Da Tysklands-fangene ble reddet',
#   '260- - -c': '1955',
#   'lang': 'nob',
#   'year': 1955},
#  '2007022101026': [],
#  '2007022101040': [],
#  '2007022101081': {'100-1- -a': 'Smith, Krabbe',
#   '245-1-0-a': 'Dette er Canada :',
#   '245-1-0-b': 'Krabbe Smith',
#   '260- - -c': '1956',
#   '653- - -a': 'geografi/historie',
#   'lang': 'nob',
#   'year': 1956},
#  '2007022201007': {'100-1- -a': 'Proske, Roman',
#   '245-1-0-a': 'Mitt liv blant rovdyr',
#   '260- - -c': '1957',
#   'lang': 'nob',
#   'year': 1957},
#  '2007022201026': [],
#  '2007022201081': {'100-1- -a': 'Lagerlöf, Selma',
#   '245-1-0-a': 'Usynlige lenker',
#   '260- - -c': '1956',
#   'lang': 'nob',
#   'year': 1956},
#  '2007022301006': {'100-1- -a': 'Edh, Hans Selmer',
#   '245-1-0-a': 'Tross',
#   '260- - -c': '1956',
#   '653- - -a': 'skjønnlitteratur/voksen',
#   'lang': 'nob',
#   'year': 1956},
#  '2007022601023': {'100-1- -a': 'Morton, H. V.',
#   '245-1-3-a': 'En reise i Rom',
#   '260- - -c': 'c1957',
#   '653- - -a': 'geografi, reiser, roma',
#   'lang': 'nob',
#   'year': 1957},
#  '2007022701012': {'100-1- -a': 'Terhune, William B.',
#   '245-1-0-a': 'Praktisk mentalhygiene for alle',
#   '260- - -c': '1956',
#   '653- - -a': 'mentalhygiene',
#   'lang': 'nob',
#   'year': 1956},
#  '2007022701035': {'100-1- -a': 'Hambræus, Axel',
#   '245-1-0-a': 'Presten i Uddarbo :',
#   '245-1-0-b': 'sangen om en venn',
#   '260- - -c': '1955',
#   'lang': 'nob',
#   'year': 1955},
#  '2007030101058': {'260- - -c': 'c1957',
#   '653- - -a': 'landbruk/husholdning',
#   'lang': 'nob',
#   'year': 1957},
#  '2007030101067': [],
#  '2007030201040': {'100-1- -a': 'Meigs, Cornelia',
#   '245-1-0-a': 'Huset i landsbyen',
#   '260- - -c': '1958',
#   'lang': 'nno',
#   'year': 1958},
#  '2007030601003': {'100-1- -a': 'Paulsen, Almar',
#   '245-1-0-a': 'Porsangerfjorden :',
#   '245-1-0-b': 'en arktisk oase',
#   '260- - -c': 'cop. 1995',
#   '653- - -a': 'fauna, finnmark, fjorder, flora, fotobøker, historie, landskap, natur, porsanger, porsangerfjorden',
#   'lang': 'nob',
#   'year': 1995},
#  '2007030801037': {'100-1- -a': 'Herje, Emil',
#   '245-1-0-a': 'To for en',
#   '260- - -c': '1958',
#   'lang': 'nob',
#   'year': 1958},
#  '2007030801054': [],
#  '2007030901013': {'260- - -c': '1961',
#   '653- - -a': 'biografiar, festskrift',
#   'lang': 'mul',
#   'year': 1961},
#  '2007031201029': {'100-1- -a': 'Patterson, George',
#   '245-1-0-a': 'På hesterygg gjennom Tibet :',
#   '245-1-0-b': 'George Patterson ; [til norsk ved Odd Feydt]',
#   '260- - -c': '1958',
#   '653- - -a': 'geografi/historie',
#   'lang': 'nob',
#   'year': 1958},
#  '2007031301035': {'100-1- -a': 'Falk-Rønne, Arne',
#   '245-1-0-a': 'Skjebnens flod',
#   '260- - -c': '[1961]',
#   'lang': 'nob',
#   'year': 1961},
#  '2007031301065': [],
#  '2007031401011': {'100-1- -a': 'Friis-Baastad, Babbis',
#   '245-1-0-a': 'Hvorfor det?',
#   '260- - -c': '[1960]',
#   'lang': 'nob',
#   'year': 1960},
#  '2007031401022': {'100-1- -a': 'Molander, Greta',
#   '245-1-0-a': 'Petrus og andre',
#   '260- - -c': '1961',
#   'lang': 'nob',
#   'year': 1961},
#  '2007031401034': {'100-1- -a': 'Maugham, W. Somerset',
#   '245-1-0-a': 'Magikeren',
#   '260- - -c': '1960',
#   'lang': 'nob',
#   'year': 1960},
#  '2007031501009': {'100-1- -a': 'Dammann, Axel',
#   '245-1-0-a': 'Norsk selektiv penge- og kredittpolitikk i 1950-årene',
#   '260- - -c': '1961',
#   '653- - -a': 'juss/økonomi',
#   'lang': 'nob',
#   'year': 1961},
#  '2007031501042': {'100-1- -a': 'Prøysen, Alf',
#   '245-1-0-a': 'Sirkus Mikkelikski',
#   '260- - -c': '1963',
#   '653- - -a': 'barnebøker, sirkus',
#   'lang': 'nob',
#   'year': 1963},
#  '2007031901036': {'100-1- -a': 'Gulbranssen, Trygve',
#   '245-1-0-a': 'Det blåser fra Dauingfjell',
#   '260- - -c': '1960',
#   'lang': 'nob',
#   'year': 1960},
#  '2007031901040': {'100-1- -a': 'Le Feuvre, Amy',
#   '245-1-0-a': 'Til fjells',
#   '260- - -c': '1960',
#   'lang': 'nob',
#   'year': 1960},
#  '2007032001055': {'100-1- -a': 'Hagemann, Sonja',
#   '245-1-0-a': 'Henrik Wergelands hustru Amalie Sofie Bekkevold :',
#   '245-1-0-b': '1819-1889',
#   '260- - -c': '1960',
#   '653- - -a': 'biografiar, biografier, litteratur, norsk',
#   'lang': 'nob',
#   'year': 1960},
#  '2007032101052': [],
#  '2007032101053': {'100-1- -a': 'Brochmann, Odd',
#   '245-1-0-a': 'Intellektuelle i alle land :',
#   '245-1-0-b': 'av en sjelevandrers opptegnelser',
#   '260- - -c': '1963',
#   'lang': 'nob',
#   'year': 1963},
#  '2007032101076': [],
#  '2007032101092': {'100-1- -a': 'Gran, Bjarne',
#   '245-1-0-a': 'Streiftog i vår egen tid',
#   '260- - -c': '1960',
#   '653- - -a': '1900-1999, geografi/historie, verdenshistorie',
#   'lang': 'nob',
#   'year': 1960},
#  '2007032201079': {'100-1- -a': 'Bull, Francis',
#   '245-1-0-a': 'Essays i utvalg',
#   '260- - -c': '1964',
#   '653- - -a': 'essays, litteraturforskning, litteraturhistorie/-teori, litterære, norske',
#   'lang': 'nob',
#   'year': 1964},
#  '2007032301008': {'100-1- -a': 'Sunnanå, Olav',
#   '245-1-0-a': 'Georg Kerschensteiner og arbeidsskulen',
#   '260- - -c': '1960',
#   '653- - -a': 'arbeidsskolen, arbeidsskoler, pedagogikk',
#   'lang': 'mul',
#   'year': 1960},
#  '2007032601083': {'100-1- -a': 'Holmvik, Øyvind',
#   '245-1-0-a': 'Farlig dykk',
#   '260- - -c': '1962',
#   'lang': 'nob',
#   'year': 1962},
#  '2007032701003': {'260- - -c': '1964',
#   '653- - -a': 'forfattere, litteratur, norsk, norske',
#   'lang': 'mul',
#   'year': 1964},
#  '2007032701087': {'100-1- -a': 'Lo-Johansson, Ivar',
#   '245-1-0-a': 'Lykken :',
#   '245-1-0-b': 'en roman om kjærlighet på jorden',
#   '260- - -c': '1963',
#   '653- - -a': 'skjønnlitteratur/voksen',
#   'lang': 'nob',
#   'year': 1963},
#  '2007032701089': {'100-1- -a': 'Bjørnseth, Finn',
#   '245-1-0-a': '-og det halve riket',
#   '260- - -c': '1963',
#   '653- - -a': 'skjønnlitteratur/voksen',
#   'lang': 'nob',
#   'year': 1963},
#  '2007032801024': {'245-1-0-a': 'Arvingen til Leikvin',
#   '260- - -c': '1963',
#   'lang': 'nob',
#   'year': 1963},
#  '2007032801025': {'100-1- -a': 'Norborg, Sverre',
#   '245-1-0-a': 'Seksti selsomme år',
#   '260- - -c': '1962',
#   'lang': 'nob',
#   'year': 1962},
#  '2007032801032': {'100-1- -a': 'Knap, Carl',
#   '245-1-0-a': 'Engelsk lesebok for 1. og 2. realskoleklasse',
#   '260- - -c': '1963',
#   'lang': 'mul',
#   'year': 1963},
#  '2007032801033': {'100-1- -a': 'Wisløff, Carl Fr.',
#   '260- - -c': '1963',
#   '653- - -a': 'første, petersbrev',
#   'lang': 'nob',
#   'year': 1963},
#  '2007032801049': [],
#  '2007032901002': {'100-1- -a': 'Hoftun, Odd',
#   '245-1-0-a': 'Fjell-landet Nepal',
#   '260- - -c': '1963',
#   'lang': 'nob',
#   'year': 1963},
#  '2007032901038': [],
#  '2007032901056': {'100-1- -a': 'Berggrav, Eivind',
#   '245-1-0-a': 'Møte med mennesker',
#   '260- - -c': '1962',
#   '653- - -a': 'biografi/genealogi, biografier, religion',
#   'lang': 'nob',
#   'year': 1962},
#  '2007032901075': [],
#  '2007040201047': [],
#  '2007041001003': {'100-1- -a': 'Jenssen, Erik C.',
#   '245-1-0-a': '"China-Jenssen"',
#   '260- - -c': '1963',
#   'lang': 'nob',
#   'year': 1963},
#  '2007041001049': {'100-1- -a': 'Omre, Arthur',
#   '245-1-0-a': 'Utvalgte noveller',
#   '260- - -c': '1962',
#   '653- - -a': 'noveller',
#   'lang': 'nob',
#   'year': 1962},
#  '2007041101046': {'260- - -c': '1964',
#   '653- - -a': 'landbruk/husholdning',
#   'lang': 'nob',
#   'year': 1964},
#  '2007041101060': {'100-1- -a': 'Gulbransen, Reidar I.',
#   '245-1-0-a': 'Villmark',
#   '260- - -c': '1964',
#   'lang': 'nob',
#   'year': 1964},
#  '2007041301024': {'100-1- -a': 'Peterson, Hans',
#   '245-1-0-a': 'Liselill og Garaffen :',
#   '245-1-0-b': 'Hans Peterson ; oversatt av Jo Tenfjord',
#   '260- - -c': '1963',
#   'lang': 'nob',
#   'year': 1963},
#  '2007041301040': {'100-1- -a': 'Nilstun, Ragnhild',
#   '245-1-0-a': 'Gjeldsposter',
#   '260- - -c': '1981',
#   '653- - -a': 'skjønnlitteratur/voksen',
#   'lang': 'nob',
#   'year': 1981},
#  '2007041601055': {'100-1- -a': 'Røine, Wenche Hoel',
#   '245-1-0-a': 'Land i sikte!',
#   '260- - -c': '2003',
#   '653- - -a': 'barnebøker, geografi, lokalhistoriesvalbard, lokalsamling, nord-norge',
#   'lang': 'nob',
#   'year': 2003},
#  '2007041801026': {'100-1- -a': 'Disney, Walt',
#   '245-1-0-a': 'Hvit villmark',
#   '260- - -c': '1961',
#   '653- - -a': 'arktis, dyr, geografi, reiser',
#   'lang': 'nob',
#   'year': 1961},
#  '2007041801034': {'100-1- -a': 'Espeland, Arne',
#   '245-1-0-a': 'Klar til batalje :',
#   '245-1-0-b': 'roman',
#   '260- - -c': '1961',
#   '653- - -a': 'skjønnlitteratur/voksen',
#   'lang': 'mul',
#   'year': 1961},
#  '2007041801054': {'100-1- -a': 'Du Maurier, Daphne',
#   '245-1-0-a': 'Falkens flukt',
#   '260- - -c': 'c1965',
#   '653- - -a': 'skjønnlitteratur/voksen',
#   'lang': 'nob',
#   'year': 1965},
#  '2007041801062': {'100-1- -a': 'Tarsis, Valerij',
#   '260- - -c': 'c1965',
#   'lang': 'nob',
#   'year': 1965},
#  '2007041801100': {'100-1- -a': 'Greene, Graham',
#   '245-1-0-a': 'Utbrent',
#   '260- - -c': '1960',
#   'lang': 'nob',
#   'year': 1960},
#  '2007041801132': {'100-1- -a': 'Jahn, Gunnar',
#   '245-1-0-a': 'Norges bank gjennom 150 år',
#   '260- - -c': '1966',
#   '653- - -a': '1800-tallet, 1900-tallet, bank, banker, bankvesen, historie, juss/økonomi, norge, norges, oslo, pengevesen, sentralbanker',
#   'lang': 'nob',
#   'year': 1966},
#  '2007041801139': [],
#  '2007041901050': {'100-1- -a': 'Stigen, Terje',
#   '245-1-0-a': 'Krystallstjernen :',
#   '245-1-0-b': 'roman',
#   '260- - -c': '1965',
#   '653- - -a': '1960-tallet, norske, romaner, skjønnlitteratur/voksen',
#   'lang': 'nob',
#   'year': 1965},
#  '2007041901085': [],
#  '2007042001062': [],
#  '2007042002005': {'100-1- -a': 'Hætta, Odd Mathis',
#   '245-1-0-a': 'Eldste skriftkilder om samer',
#   '260- - -c': '1980',
#   '653- - -a': 'historie, samisk',
#   'lang': 'nob',
#   'year': 1980},
#  '2007042301010': {'100-1- -a': 'Mishima, Yukio',
#   '260- - -c': '1963',
#   '653- - -a': 'skjønnlitteratur/voksen',
#   'lang': 'nob',
#   'year': 1963},
#  '2007042301013': {'100-1- -a': 'Baklanov, Grigorij',
#   '245-1-3-a': 'En fotsbredd jord',
#   '260- - -c': '1960',
#   '653- - -a': 'skjønnlitteratur/voksen',
#   'lang': 'nob',
#   'year': 1960},
#  '2007042301014': {'260- - -c': '[1957]',
#   '653- - -a': 'geografi/historie, historie',
#   'lang': 'nob',
#   'year': 1957},
#  '2007042301019': [],
#  '2007042301049': [],
#  '2007042301060': [],
#  '2007042401025': {'245-1-0-a': 'Ti rike arbeidsår',
#   '260- - -c': '1965',
#   '653- - -a': 'forskning, historie, hydro, industri, norsk, produksjon, rjukan, teknikk, telemark, økonomi',
#   'lang': 'nob',
#   'year': 1965},
#  '2007042401097': {'260- - -c': '1967',
#   '653- - -a': 'folkediktning, folkeminne, folkeviser, norsk, norske',
#   'lang': 'nno',
#   'year': 1967},
#  '2007042401104': {'100-1- -a': 'Amundsen, Sverre S.',
#   '260- - -c': '1965',
#   'lang': 'nob',
#   'year': 1965},
#  '2007042401132': {'100-1- -a': 'Andrew, Prudence',
#   '245-1-0-a': 'Ginger-gjengen gir seg ikke',
#   '260- - -c': 'c1966',
#   'lang': 'nob',
#   'year': 1966},
#  '2007042501020': {'260- - -c': '1965',
#   '653- - -a': 'kokebøker, matkultur, matlaging, matskikkar, mattradisjoner, norge',
#   'lang': 'nob',
#   'year': 1965},
#  '2007042501078': {'100-1- -a': 'Retterstøl, Nils',
#   '245-1-0-a': 'Medikamentmisbruk :',
#   '245-1-0-b': 'et aktuelt samfunnsproblem',
#   '260- - -c': '1967',
#   '653- - -a': 'avhengighet, behandling, medikamentmisbruk, medisin, narkomani, oversiktsverkstoffmisbruk, rusmiddelmisbruk, rusmidler, rusmisbrukere, rusproblemer, sosial, sosialmedisin, velferd',
#   'lang': 'nob',
#   'year': 1967},
#  '2007042600016': [],
#  '2007042601006': {'100-1- -a': 'Lavolle, L.N.',
#   '245-1-0-a': 'Det bortgjemte tjernet',
#   '260- - -c': '1965',
#   'lang': 'nob',
#   'year': 1965},
#  '2007042601013': {'100-1- -a': 'Madsen, K.B.',
#   '245-1-0-a': 'Læring, hukommelse og glemsel :',
#   '245-1-0-b': '- og litt om innlæringsmaskiner',
#   '260- - -c': '1965',
#   '653- - -a': 'hukommelse, læring, pedagogikk, programmert, psykologi, undervisning',
#   'lang': 'nob',
#   'year': 1965},
#  '2007042601087': {'100-1- -a': 'Brandtzæg, Torgeir',
#   '245-1-0-a': "Friskus'n fra Ogndalen",
#   '260- - -c': 'c1967',
#   '653- - -a': 'biografi/genealogi, biografier, hoppsport, skisport',
#   'lang': 'nob',
#   'year': 1967},
#  '2007042604042': {'100-1- -a': 'Fisher, James',
#   '245-1-0-a': 'Eventyret om havet',
#   '260- - -c': '1958',
#   'lang': 'nob',
#   'year': 1958},
#  '2007042604065': [],
#  '2007042604082': [],
#  '2007042700004': {'100-1- -a': 'Oldervik, Anbjørg Pauline',
#   '245-1-0-a': 'Lytt',
#   '260- - -c': '1967',
#   'lang': 'nob',
#   'year': 1967},
#  '2007042700017': {'100-1- -a': 'Herje, Emil',
#   '245-1-0-a': 'Farlig kar',
#   '260- - -c': 'c1965',
#   'lang': 'nob',
#   'year': 1965},
#  '2007043001061': {'100-1- -a': 'Kullerud, Erik',
#   '245-1-0-a': 'Operasjon Kløverblokk',
#   '260- - -c': '1966',
#   '653- - -a': 'barn, barnebøker, skjønnlitteratur',
#   'lang': 'nob',
#   'year': 1966},
#  '2007043001068': [],
#  '2007043001092': [],
#  '2007050200037': {'100-1- -a': 'Kolltveit, Olav',
#   '245-1-0-a': 'Banken og bygda :',
#   '245-1-0-b': 'Kvam privatbank : 1862 - 1962',
#   '260- - -c': '1962',
#   '653- - -a': 'hordaland, kvam, privatbank',
#   'lang': 'mul',
#   'year': 1962},
#  '2007050204034': [],
#  '2007050301006': {'100-1- -a': 'Haslund, Ebba',
#   '245-1-0-a': 'Miss Eriksen oppdager Amerika',
#   '260- - -c': '[1964]',
#   'lang': 'nob',
#   'year': 1964},
#  '2007050301041': {'100-1- -a': 'Hellevik, Alf',
#   '245-1-0-a': 'Nynorsk ordliste :',
#   '245-1-0-b': 'større utgåve med fornorsknings-tillegg og liste over forkortningar',
#   '260- - -c': '1962',
#   '653- - -a': 'norsk, nynorsk, ordbøker, språk, synonym',
#   'lang': 'nno',
#   'year': 1962},
#  '2007050304004': {'100-1- -a': 'Mack, Lorenz',
#   '245-1-0-a': 'Peter og Anna bor i Østerrike',
#   '260- - -c': '1964',
#   'lang': 'nob',
#   'year': 1964},
#  '2007050400017': {'100-1- -a': 'Seymour, John',
#   '245-1-0-a': 'India på kryss og tvers',
#   '260- - -c': '1962',
#   '653- - -a': 'geografi/historie',
#   'lang': 'nob',
#   'year': 1962},
#  '2007050401033': {'100-1- -a': 'Slapgard, Bjarne',
#   '245-1-0-a': 'Ferjemannen',
#   '260- - -c': '1968',
#   '653- - -a': 'skjønnlitteratur/voksen',
#   'lang': 'mul',
#   'year': 1968},
#  '2007050401037': {'100-1- -a': 'Vik, Bjørg',
#   '245-1-0-a': 'Det grådige hjerte',
#   '260- - -c': '1968',
#   '653- - -a': 'skjønnlitteratur/voksen',
#   'lang': 'nob',
#   'year': 1968},
#  '2007050404028': {'100-1- -a': 'Zuckmayer, Carl',
#   '245-1-0-a': 'Domherrens hemmelighet',
#   '260- - -c': '1960',
#   '653- - -a': 'skjønnlitteratur/voksen',
#   'lang': 'nob',
#   'year': 1960},
#  '2007050801011': {'100-1- -a': 'Mælandsmo, Ingebjørg',
#   '245-1-0-a': 'Blomar i oktober',
#   '260- - -c': '1968',
#   '653- - -a': 'skjønnlitteratur/voksen',
#   'lang': 'nno',
#   'year': 1968},
#  '2007050801049': {'100-1- -a': 'Eckhoff, Torstein',
#   '245-1-0-a': 'Sivilprosess',
#   '260- - -c': '1962',
#   '653- - -a': 'sivilprosess',
#   'lang': 'nob',
#   'year': 1962},
#  '2007050801075': {'100-1- -a': 'Saue, Gerd Grønvold',
#   '245-1-0-a': 'Mennesker underveis',
#   '260- - -c': '[1964]',
#   '653- - -a': 'biografi/genealogi, geografi/historie',
#   'lang': 'nob',
#   'year': 1964},
#  '2007050804002': {'100-1- -a': 'Mendelsohn, Oskar',
#   '260- - -c': '1969',
#   '653- - -a': 'historie, jøder, norge',
#   'lang': 'nob',
#   'year': 1969},
#  '2007050804020': {'100-1- -a': 'Tanner, John',
#   '245-1-0-a': 'Spionen som elsket sin neste',
#   '260- - -c': 'c1967',
#   '653- - -a': 'skjønnlitteratur/voksen',
#   'lang': 'nob',
#   'year': 1967},
#  '2007050804065': {'100-1- -a': 'Vestly, Anne-Cath.',
#   '245-1-0-a': 'Lillebror og Knerten',
#   '260- - -c': 'c1962',
#   'lang': 'nob',
#   'year': 1962},
#  '2007050901002': [],
#  '2007050901019': {'100-1- -a': 'Griffin, John Howard',
#   '245-1-0-a': 'Neger - men hvit',
#   '260- - -c': '1964',
#   '653- - -a': 'politikk/samfunn',
#   'lang': 'nob',
#   'year': 1964},
#  '2007050901032': {'245-1-0-a': 'Arbeidervernlover :',
#   '245-1-0-b': 'lov om arbeidervern av 7. des. 1956 med endringer ved lov av 28. nov. 1958 : lov av 13. april 1962 : lov av 29. mai 1964 og lov av 10. mai 1968',
#   '260- - -c': '1968',
#   '653- - -a': 'arbeidsrett, norge',
#   'lang': 'nob',
#   'year': 1968},
#  '2007050901053': {'100-1- -a': 'Kalstad, Marit',
#   '245-1-0-a': 'Åmund',
#   '260- - -c': '1967',
#   'lang': 'nob',
#   'year': 1967},
#  '2007051000061': {'100-1- -a': 'Vestly, Anne-Cath.',
#   '245-1-0-a': 'Aurora i blokk Z',
#   '260- - -c': '1966',
#   '653- - -a': 'skjønnlitteratur/barn-ungdom',
#   'lang': 'nob',
#   'year': 1966},
#  '2007051001011': {'100-1- -a': 'Haavardsholm, Espen',
#   '245-1-0-a': 'Munnene',
#   '260- - -c': '1968',
#   '653- - -a': 'skjønnlitteratur/voksen',
#   'lang': 'nob',
#   'year': 1968},
#  '2007051004031': {'100-1- -a': 'Draper, Theodore',
#   '245-1-0-a': 'Amerikas maktmisbruk :',
#   '245-1-0-b': 'fra Cuba til Vietnam',
#   '260- - -c': 'c1968',
#   '653- - -a': 'politikk/samfunn',
#   'lang': 'nob',
#   'year': 1968},
#  '2007051004051': {'100-1- -a': 'Christov, Solveig',
#   '245-1-0-a': 'Befrielsen :',
#   '245-1-0-b': 'skuespill i to akter',
#   '260- - -c': '1966',
#   'lang': 'nob',
#   'year': 1966},
#  '2007051101003': {'260- - -c': '1965',
#   '653- - -a': 'biografier, grafikere, grafikk, grafisk, kunst, kunstnere, norge, norske',
#   'lang': 'nob',
#   'year': 1965},
#  '2007051101004': {'100-1- -a': 'Feustel, Günther',
#   '245-1-0-a': 'José :',
#   '245-1-0-b': 'en fortelling fra Sør-Amerika',
#   '260- - -c': '1967',
#   '653- - -a': 'barnebøker, skjønnlitteratur/barn-ungdom',
#   'lang': 'nob',
#   'year': 1967},
#  '2007051101012': {'100-1- -a': 'Prevelakēs, Pantelēs',
#   '245-1-0-a': 'Englenes brød :',
#   '245-1-0-b': 'eventyr på Ithaka : roman',
#   '260- - -c': '1968',
#   'lang': 'nob',
#   'year': 1968},
#  '2007051104003': {'100-1- -a': 'Johanson, Sally',
#   '245-1-0-a': 'Vi knipler',
#   '260- - -c': '1968',
#   '653- - -a': 'knipling, kniplinger',
#   'lang': 'nob',
#   'year': 1968},
#  '2007051400069': [],
#  '2007051401034': {'100-1- -a': 'Mehren, Stein',
#   '245-1-0-a': 'Vind Runer :',
#   '245-1-0-b': 'dikt',
#   '260- - -c': '1967',
#   '653- - -a': 'dikt, lyrikk, skjønnlitteratur',
#   'lang': 'nob',
#   'year': 1967},
#  '2007051401079': {'100-1- -a': 'Nordberg, Carl-Eric',
#   '245-1-0-a': 'Sandemose :',
#   '245-1-0-b': 'en biografi',
#   '260- - -c': '1967',
#   '653- - -a': 'aksel, biografi, biografi/genealogi, biografier, litteraturhistorie, menn, norsk, sandemose',
#   'lang': 'nob',
#   'year': 1967},
#  '2007051404011': {'100-1- -a': 'Stranger, Joyce',
#   '245-1-0-a': 'Fortellingen om de to revene',
#   '260- - -c': '1967',
#   'lang': 'nob',
#   'year': 1967},
#  '2007051404019': {'100-1- -a': 'Haslund, Ebba',
#   '245-1-0-a': 'Det trange hjerte :',
#   '245-1-0-b': 'roman',
#   '260- - -c': '1965',
#   '653- - -a': 'skjønnlitteratur/voksen',
#   'lang': 'nob',
#   'year': 1965},
#  '2007051404039': {'100-1- -a': 'Schwalbe, Ole',
#   '245-1-0-a': 'Se på kunst',
#   '260- - -c': 'c1968',
#   '653- - -a': 'billedkunst, filosofi, kunst, kunstformidling, kunstforståelse, skulptur, stilarter, teori',
#   'lang': 'nob',
#   'year': 1968},
#  '2007051404042': {'260- - -c': '1968', 'lang': 'nob', 'year': 1968},
#  '2007051404051': {'100-1- -a': 'Johannessen, Ola M.',
#   '245-1-0-a': 'Some current measurements in the Drøbak Sound, the narrow entrance to the Oslofjord',
#   '260- - -c': '1968',
#   'lang': 'eng',
#   'year': 1968},
#  '2007051500007': {'100-1- -a': 'Strømnes, Martin',
#   '245-1-0-a': 'Elevstudium i skolen',
#   '260- - -c': '1966',
#   '653- - -a': 'elev, elever, elevobservasjon, elevrollen, forskjeller, individuelle, interaksjon, lærer, observasjon, pedagogikk, pedagogisk, psykologi, samhandling, sosial, teorier, undervisning',
#   'lang': 'nno',
#   'year': 1966},
#  '2007051500035': {'100-1- -a': 'Slapgard, Bjarne',
#   '245-1-0-a': 'Gutar ved klostermur :',
#   '245-1-0-b': 'barnebok',
#   '260- - -c': '1968',
#   '653- - -a': 'fortellinger, kloster, tautra',
#   'lang': 'nno',
#   'year': 1968},
#  '2007051500055': {'100-1- -a': 'Wittgenstein, Ludwig',
#   '245-1-0-a': 'Filosofiske undersøkelser',
#   '260- - -c': '1967',
#   '653- - -a': 'fifosofi',
#   'lang': 'nob',
#   'year': 1967},
#  '2007051500071': {'100-1- -a': 'Frich, Øvre Richter',
#   '245-1-0-a': 'De udødelige dverger',
#   '260- - -c': '[1967]',
#   'lang': 'nob',
#   'year': 1967},
#  '2007051501025': {'260- - -c': '[1968]',
#   '653- - -a': 'varehandel',
#   'lang': 'nob',
#   'year': 1968},
#  '2007051504008': {'100-1- -a': 'Gainham, Sarah',
#   '245-1-0-a': 'Natt over byen',
#   '260- - -c': '1968',
#   'lang': 'nob',
#   'year': 1968},
#  '2007051601007': {'100-1- -a': 'Mehl, Knut',
#   '245-1-0-a': 'Boikott i prisrådet',
#   '260- - -c': 'c1968',
#   '653- - -a': 'avgjørelser, konkurranse, prisdirektoratet, prisrådet',
#   'lang': 'nob',
#   'year': 1968},
#  '2007051601058': {'100-1- -a': 'Kennedy, Robert F.',
#   '245-1-0-a': 'Mot en nyere verden',
#   '260- - -c': '1968',
#   '653- - -a': 'forente, geografi/historie, historie, stater',
#   'lang': 'nob',
#   'year': 1968},
#  '2007051604065': [],
#  '2007052100002': [],
#  '2007052100036': {'260- - -c': 'c1967',
#   '653- - -a': 'etterkrigstiden, historie, nazisme, norge, politikk, politikk/samfunn, radikalisme',
#   'lang': 'nob',
#   'year': 1967},
#  '2007052100042': [],
#  '2007052101019': {'100-1- -a': 'Eidslott, Arnold',
#   '245-1-0-a': 'Manes :',
#   '245-1-0-b': 'dikt',
#   '260- - -c': '1965',
#   'lang': 'nob',
#   'year': 1965},
#  '2007052101047': {'100-1- -a': 'Berg, Lars',
#   '245-1-0-a': 'Du har rett til å leve :',
#   '245-1-0-b': 'roman',
#   '260- - -c': '1965',
#   '653- - -a': 'skjønnlitteratur/voksen',
#   'lang': 'mul',
#   'year': 1965},
#  '2007052104040': {'260- - -c': '1966', 'lang': 'nob', 'year': 1966},
#  '2007052104063': {'100-1- -a': 'Lian, Egil',
#   '245-1-0-a': "Sus og dus på by'n",
#   '260- - -c': '1965',
#   'lang': 'nob',
#   'year': 1965},
#  '2007052200013': {'100-1- -a': 'Spark, Muriel',
#   '245-1-0-a': 'Ubemidlede piker fra gode hjem',
#   '260- - -c': '1964',
#   'lang': 'nob',
#   'year': 1964},
#  '2007052200023': {'100-1- -a': 'Løchen, Einar',
#   '245-1-0-a': 'Norge og Fellesmarkedet',
#   '260- - -c': '1967',
#   '653- - -a': 'politikk/samfunn',
#   'lang': 'nob',
#   'year': 1967},
#  '2007052200066': {'100-1- -a': 'Gayer, Rodney A.',
#   '260- - -c': '1966',
#   '653- - -a': 'arktis, ekspedisjoner, polarekspedisjoner',
#   'lang': 'eng',
#   'year': 1966},
#  '2007052202001': {'260- - -c': 'cop. 2005',
#   '653- - -a': 'arkiver, finnmark, historie, nord-norge, svalbard, troms, tromsø',
#   'lang': 'nob',
#   'year': 2005},
#  '2007052204018': {'100-1- -a': 'Eriksen, Tore Linné',
#   '245-1-0-a': 'Verneplikten i fare :',
#   '245-1-0-b': 'tre innlegg om utvidet forsvarsbegrep',
#   '260- - -c': 'c1966',
#   'lang': 'nob',
#   'year': 1966},
#  '2007052204029': {'100-1- -a': 'Bøckman, Peter Wilhelm',
#   '245-1-0-a': 'Dreyers bibelatlas',
#   '260- - -c': '1961',
#   '653- - -a': 'atlas, bibelatlas, bibelen, bibelsk, geografi, historie, israel, kultur, midt-østen, religion',
#   'lang': 'nob',
#   'year': 1961},
#  '2007052204032': {'100-1- -a': 'Galtung, Johan',
#   '245-1-0-a': 'Notes on technical assistance :',
#   '245-1-0-b': 'with special reference to the Indo-Norwegian project in Kerala',
#   '260- - -c': '1961',
#   '653- - -a': 'antropologi, bistand, india',
#   'lang': 'eng',
#   'year': 1961},
#  '2007052204037': [],
#  '2007052204055': {'100-1- -a': 'Polo, Marco',
#   '245-1-0-a': 'Marco Polos reiser :',
#   '245-1-0-b': 'gjenfortalt av Aage Krarup Nielsen ; til norsk ved Einar Th. Schøning',
#   '260- - -c': '1963',
#   '653- - -a': 'geografi/historie, marco, polo',
#   'lang': 'nob',
#   'year': 1963},
#  '2007052302001': {'100-1- -a': 'Ravna, Øyvind',
#   '245-1-0-a': 'Mitt russiske nord',
#   '260- - -c': 'cop. 1996',
#   '653- - -a': 'arkhangelsknord-vest, geografi, historie, kultur, nordvest-russland, post-kommunisme, postkommunistisk, reisebeskrivelser, reiser, russland, tid',
#   'lang': 'nob',
#   'year': 1996},
#  '2007052304011': {'100-1- -a': 'Lomax, Louis E.',
#   '245-1-0-a': 'Negerrevolten :',
#   '245-1-0-b': 'dei amerikanske negrane i kamp for borgarrettar',
#   '260- - -c': '1965',
#   '653- - -a': 'forente, minoritetsproblemer, raserelasjoner, stater, usa',
#   'lang': 'nno',
#   'year': 1965},
#  '2007052304038': {'100-1- -a': 'Åmlid, Johanne',
#   '245-1-0-a': 'Ut av kurs :',
#   '245-1-0-b': 'en førstehånds beretning fra Arbeiderpartiets lukkede landsmøte i 1949 der avgjørelsen om norsk medlemskap i NATO i realiteten ble tatt',
#   '260- - -c': 'c1966',
#   '653- - -a': '1940-tallet, nato, norge',
#   'lang': 'nob',
#   'year': 1966},
#  '2007052304064': {'100-1- -a': 'Hauge, Yngvar',
#   '245-1-0-a': 'Interiørene på Oslo slott :',
#   '245-1-0-b': 'H.D.F. Linstow og innredningen av det kongelige slott i Oslo',
#   '260- - -c': '1963',
#   'lang': 'nob',
#   'year': 1963},
#  '2007052304082': {'100-1- -a': 'Anderberg, Bengt',
#   '245-1-0-a': "Lasse og Lissom'en",
#   '260- - -c': '1969',
#   'lang': 'nob',
#   'year': 1969},
#  '2007052400005': [],
#  '2007052400019': {'100-1- -a': 'Andrew, Prudence',
#   '245-1-0-a': 'Gamle Billy og gullkronen',
#   '260- - -c': '1966',
#   'lang': 'nob',
#   'year': 1966},
#  '2007052400057': {'100-1- -a': 'Churchill, Winston',
#   '245-1-0-a': 'Ungdom',
#   '260- - -c': '1956',
#   'lang': 'nob',
#   'year': 1956},
#  '2007052401004': {'100-1- -a': 'Andreasen, Hans',
#   '245-1-0-a': 'Spansk serenade',
#   '260- - -c': '1956',
#   '653- - -a': 'geografi/historie, skjønnlitteratur/voksen',
#   'lang': 'nob',
#   'year': 1956},
#  '2007052401027': {'100-1- -a': 'Bergström, Gunilla',
#   '245-1-0-a': 'Heng i, Albert Åberg',
#   '260- - -c': 'cop. 1976',
#   '653- - -a': 'billedbøker, familie, foreldre, tid',
#   'lang': 'nob',
#   'year': 1976},
#  '2007052401043': {'100-1- -a': 'Commoner, Barry',
#   '245-1-0-a': 'Mens det ennå er tid',
#   '260- - -c': '1969',
#   '653- - -a': 'samfunn, vitenskap, økologi',
#   'lang': 'nob',
#   'year': 1969},
#  '2007052500022': {'100-1- -a': 'Galbraith, John Kenneth',
#   '245-1-0-a': 'Det nye industrisamfunnet',
#   '260- - -c': '1968',
#   '653- - -a': 'forhold, industrisamfunnet, sosialøkonomi, økonomi',
#   'lang': 'nob',
#   'year': 1968},
#  '2007052500041': {'100-1- -a': 'Torgersen, K.',
#   '245-1-0-a': 'Skattene',
#   '260- - -c': '1968',
#   '653- - -a': 'juss/økonomi, skatter',
#   'lang': 'nob',
#   'year': 1968},
#  '2007052500056': {'100-1- -a': 'Haslund, Ebba',
#   '245-1-0-a': 'Syndebukkens krets :',
#   '245-1-0-b': 'roman',
#   '260- - -c': '1968',
#   '653- - -a': 'skjønnlitteratur/voksen',
#   'lang': 'nob',
#   'year': 1968},
#  '2007052504016': {'100-1- -a': 'Tingsten, Herbert',
#   '245-1-0-a': 'Notiser om liv og død',
#   '260- - -c': '1968',
#   '653- - -a': 'essays, filosofi/psykologi',
#   'lang': 'nob',
#   'year': 1968},
#  '2007052900024': {'100-1- -a': 'Saugstad, Per',
#   '245-1-0-a': 'J.S. Welhaven :',
#   '245-1-0-b': 'en idealenes vokter',
#   '260- - -c': '1967',
#   '653- - -a': 'biografi/genealogi, biografier, litteratur, litteraturhistorie/-teori, norsk',
#   'lang': 'nob',
#   'year': 1967},
#  '2007053000015': {'100-1- -a': 'Littmann, Arnold',
#   '245-1-0-a': 'Peter hat Pech! :',
#   '245-1-0-b': 'die Jagd nach der fliegenden Untertasse',
#   '260- - -c': '1968',
#   'lang': 'mul',
#   'year': 1968},
#  '2007053001001': [],
#  '2007053004001': {'245-1-0-a': 'Bygda i byen :',
#   '245-1-0-b': 'Oslo fylkeslag, Bygdelagssamskipnaden i Oslo 1923-1973',
#   '260- - -c': '1973',
#   '653- - -a': 'Noregs ungdomslag, Organisasjoner, Ungdomslag',
#   'lang': 'nob',
#   'year': 1973},
#  '2007053100009': [],
#  '2007053100020': {'260- - -c': '1966',
#   '653- - -a': 'bibelen, bibelsyn, hermeneutikk, kritikk, skriftforståelse, skriftsyn, tolking, tolkning',
#   'lang': 'nob',
#   'year': 1966},
#  '2007053100028': {'100-1- -a': 'Flatberg, Per',
#   '245-1-0-a': 'Legemidler og bruken av dem :',
#   '245-1-0-b': 'lærebok i farmakologi og farmakoterapi for sykepleiere',
#   '260- - -c': '1974',
#   '653- - -a': 'farmakokinetikk, farmakologi, farmakoterapi, legemidler',
#   'lang': 'nob',
#   'year': 1974},
#  '2007053100060': {'100-1- -a': 'Nissen, Grete',
#   '260- - -c': '1967',
#   '653- - -a': 'pantomime',
#   'lang': 'nob',
#   'year': 1967},
#  '2007060100043': {'100-1- -a': 'Ose, Eivind',
#   '245-1-0-a': 'Virkninger av strukturendringer i psykiatriske sykehus :',
#   '245-1-0-b': 'en studie belyst ved eget materiale = Effects of changes in structure in psychiatric hospitals : a study based on original observations',
#   '260- - -c': 'c1976',
#   '653- - -a': 'institusjoner, medisin, psykiatriske, sykehus',
#   'lang': 'nob',
#   'year': 1976},
#  '2007060104024': {'100-1- -a': 'Helander, Gunnar',
#   '245-1-0-a': 'Storbyneger :',
#   '245-1-0-b': 'roman',
#   '260- - -c': '1956',
#   'lang': 'nob',
#   'year': 1956},
#  '2007060400006': [],
#  '2007060500005': {'100-1- -a': 'Falkeid, Kolbein',
#   '245-1-0-a': 'Vi :',
#   '245-1-0-b': 'dikt',
#   '260- - -c': '1966',
#   '653- - -a': 'dikt',
#   'lang': 'nob',
#   'year': 1966},
#  '2007060501006': {'100-1- -a': 'Modal, Bitten',
#   '245-1-0-a': 'ABC for abortsøkende',
#   '260- - -c': '1976',
#   'lang': 'nob',
#   'year': 1976},
#  '2007060501011': {'100-1- -a': 'Sandem, Arne',
#   '245-1-0-a': 'Drama i Torskefjord',
#   '260- - -c': '1976',
#   '653- - -a': 'finnmark, romaner, verdenskrigen',
#   'lang': 'nob',
#   'year': 1976},
#  '2007060501054': {'100-1- -a': 'Kreyberg, Leiv',
#   '245-1-0-a': 'Efter ordre - eller uten',
#   '260- - -c': '1976',
#   'lang': 'nob',
#   'year': 1976},
#  '2007060504013': {'100-1- -a': 'Miller, Wright',
#   '245-1-0-a': 'Sovjet',
#   '260- - -c': '1965',
#   'lang': 'mul',
#   'year': 1965},
#  '2007060504093': {'100-1- -a': 'Nørgaard, Poul',
#   '245-1-0-a': 'Harlekin :',
#   '245-1-0-b': 'fortellingen om en shetlandsponni',
#   '260- - -c': '[1961]',
#   'lang': 'nob',
#   'year': 1961},
#  '2007060700011': {'260- - -c': '1975',
#   '653- - -a': 'dagligliv, folkelivsgransking, fortellinger, fylke, historie, kulturhistorie, norge, tradisjoner, vestfold, østfold',
#   'lang': 'nob',
#   'year': 1975},
#  '2007060700020': {'100-1- -a': 'Dørumsgaard, Arne',
#   '245-1-0-a': 'Klassisk kinesisk poesi i norsk gjendiktning',
#   '260- - -c': 'c1976',
#   '653- - -a': 'antologier, kinesisk, litteratur, lyrikk',
#   'lang': 'nob',
#   'year': 1976},
#  '2007060701062': {'100-1- -a': 'Wildhagen, Fredrik',
#   '245-1-0-a': 'Ni artikler omkring alkoholproblemet',
#   '260- - -c': '1956',
#   '653- - -a': 'alkoholisme, oversiktsverk',
#   'lang': 'nob',
#   'year': 1956},
#  '2007060701072': {'100-1- -a': 'Berthelsen, Herman',
#   '245-1-0-a': 'Foreningslivets ABC',
#   '260- - -c': 'cop. 1975',
#   '653- - -a': 'foreninger, foreningsteknikk, organisasjoner, pedagogikk',
#   'lang': 'nob',
#   'year': 1975},
#  '2007061100028': {'260- - -c': '1950', 'lang': 'nob', 'year': 1950},
#  '2007061100036': {'100-1- -a': 'Jahnn, Hans Henny',
#   '245-1-0-a': 'Treskipet',
#   '260- - -c': '1974',
#   'lang': 'nob',
#   'year': 1974},
#  '2007061100060': {'100-1- -a': 'Halse, Sverre',
#   '245-1-0-a': 'Med bestefar til Nederland',
#   '260- - -c': 'c1950',
#   'lang': 'nob',
#   'year': 1950},
#  '2007061101041': {'100-1- -a': 'Brekken, Astrid',
#   '245-1-0-a': 'Å leve sammen',
#   '260- - -c': '1976',
#   '653- - -a': 'ekteskap, familiesosiologi, kriser, parforhold, politikk/samfunn, samboere, samboerforhold, samliv, samlivsformer, samlivsproblemer, studieplan',
#   'lang': 'nob',
#   'year': 1976},
#  '2007061101047': {'100-1- -a': 'Steen, Albert',
#   '245-1-0-a': 'Stoler i Norge',
#   '260- - -c': '1975',
#   '653- - -a': 'historie, interiørarkitektur, kulturhistorie, møbelkunst, møbler, norge, norske, stoler',
#   'lang': 'nob',
#   'year': 1975},
#  '2007061200008': {'245-1-0-a': 'Beretning om nordisk økonomisk samarbejde :',
#   '245-1-0-b': 'fremsendt af den danske, norske og svenske regering til Nordisk Råds 4.session januar-februar 1956',
#   '260- - -c': '1956',
#   'lang': 'dan',
#   'year': 1956},
#  '2007061200012': {'100-1- -a': 'Vestly, Anne-Cath.',
#   '245-1-0-a': 'Ole Aleksander på flyttefot',
#   '260- - -c': 'cop. 1958',
#   'lang': 'nob',
#   'year': 1958},
#  '2007061201028': {'100-1- -a': 'Viksveen, Stein',
#   '245-1-0-a': 'Øst-Tyskland i dag :',
#   '245-1-0-b': 'med 20 korte biografier og med en oversikt over begivenheter 1944-1972',
#   '260- - -c': 'c1973',
#   '653- - -a': '(ddr), 1944-1972, ddr, geografi/historie, historie, tyskland, øst-tyskland',
#   'lang': 'nob',
#   'year': 1973},
#  '2007061204006': {'100-1- -a': 'Myhre, Eivind',
#   '245-1-0-a': 'Alltid kvinne :',
#   '245-1-0-b': 'er overgangsalderen en mangelsykdom?',
#   '260- - -c': 'c1976',
#   '653- - -a': 'gynekologi, klimakteriet, klimakterium, medisin, overgangsalder, overgangsalderen, østrogener',
#   'lang': 'nob',
#   'year': 1976},
#  '2007061204032': [],
#  '2007061204034': {'100-1- -a': 'Elster, Torolf',
#   '245-1-0-a': 'Muren',
#   '260- - -c': '1954',
#   'lang': 'nob',
#   'year': 1954},
#  '2007061400006': {'100-1- -a': 'Lyche, Ingeborg',
#   '245-1-0-a': 'Adult education in Norway',
#   '260- - -c': '1957',
#   'lang': 'eng',
#   'year': 1957},
#  '2007061400044': [],
#  '2007061400053': {'100-1- -a': 'Amundsen, Finn',
#   '245-1-0-a': 'Stjerner på bølgelengde :',
#   '245-1-0-b': 'en illustrert skøytekavalkade - nasjonal og internasjonal',
#   '260- - -c': '1954',
#   'lang': 'nob',
#   'year': 1954},
#  '2007061400068': {'260- - -c': '1961',
#   '653- - -a': 'pedagogikk',
#   'lang': 'nob',
#   'year': 1961},
#  '2007061401003': {'260- - -c': '1957',
#   '653- - -a': 'barneoppdragelse, familiebarn, hjem, kristen, religionspedagogikk',
#   'lang': 'nob',
#   'year': 1957},
#  '2007061401022': {'100-1- -a': 'Mohn, Albert Henrik',
#   '245-1-0-a': 'De siste støvlene :',
#   '245-1-0-b': 'noveller',
#   '260- - -c': '1958',
#   '653- - -a': 'norske, noveller',
#   'lang': 'nob',
#   'year': 1958},
#  '2007061401032': {'100-1- -a': 'Steinbeck, John',
#   '245-1-0-a': 'Dagdrivergjengen',
#   '260- - -c': '1955',
#   '653- - -a': 'oppvekstromaner',
#   'lang': 'nob',
#   'year': 1955},
#  '2007061401038': [],
#  '2007061401041': {'100-1- -a': 'Gjesdahl, Paul',
#   '245-1-0-a': 'Lett blanding',
#   '260- - -c': '1958',
#   'lang': 'nob',
#   'year': 1958},
#  '2007061404018': [],
#  '2007061501005': [],
#  '2007061800038': {'100-1- -a': 'Vigerust, Aasmund',
#   '245-1-0-a': 'Våre skogers tilstand og produksjonsevne',
#   '260- - -c': '1957',
#   'lang': 'nob',
#   'year': 1957},
#  '2007061804067': {'260- - -c': 'c1979',
#   '653- - -a': '1830-1970, kritikk, litteratur, litteraturhistorie, litteraturkritikk, norsk',
#   'lang': 'nob',
#   'year': 1979},
#  '2007061804099': {'100-1- -a': 'Lysne, Anders',
#   '245-1-0-a': 'Karakterer - bruk og misbruk',
#   '260- - -c': 'c1978',
#   '653- - -a': 'elevvurdering, evaluering, evalueringsmetoder, formål, grunnskole, gymnas, hovedkarakter, karakterer, karaktersystem, norge, skolen, skolevirksomhet, studiekompetanse, vurdering',
#   'lang': 'nob',
#   'year': 1978},
#  '2007061804155': {'100-1- -a': 'Brox, Karl H.',
#   '245-1-0-a': 'Menn under polen',
#   '260- - -c': '1978',
#   '653- - -a': 'arctic, arktis, biographies, ekspedisjoner, expeditions, explorations, jeannette, nordvestpassasjennordostpassasjen, ocean, polarekspedisjoner',
#   'lang': 'nob',
#   'year': 1978},
#  '2007061904019': {'100-1- -a': 'Zachariassen, Aksel',
#   '245-1-0-a': 'Martin Tranmæl',
#   '260- - -c': 'c1979',
#   '653- - -a': '1905-, historie, norge, norske, politikere,, politikk',
#   'lang': 'nob',
#   'year': 1979},
#  '2007061904028': {'260- - -c': '[1974]',
#   '653- - -a': 'geografi/historie, historie, norge, norges, tegneserie',
#   'lang': 'nob',
#   'year': 1974},
#  '2007061904045': {'100-1- -a': 'Riise, Arne',
#   '245-1-0-a': 'Interne styringsdata :',
#   '245-1-0-b': 'driftskalkyler for beslutninger og kontroll',
#   '260- - -c': '1979',
#   '653- - -a': 'bedriftsøkonomi, driftskalkyler, driftsregnskap, internregnskap, kalkulasjon, kostnader, kostnadsregnskap, styringsdata',
#   'lang': 'nob',
#   'year': 1979},
#  '2007062001010': {'100-1- -a': 'Skjæraasen, Einar',
#   '245-1-0-a': 'Og alle mine viser',
#   '260- - -c': '1956',
#   '653- - -a': 'lyrikk, sanger, visebøker, viser',
#   'lang': 'nob',
#   'year': 1956},
#  '2007062004002': {'100-1- -a': 'Fett, Per',
#   '245-1-0-a': 'Førhistoriske minne på Voss',
#   '260- - -c': '1956',
#   '653- - -a': 'voss',
#   'lang': 'mul',
#   'year': 1956},
#  '2007062004004': {'100-1- -a': 'Fett, Per',
#   '245-1-0-a': 'Førhistoriske minne i Fjordane',
#   '260- - -c': '1958',
#   '653- - -a': 'bremanger, historie',
#   'lang': 'nob',
#   'year': 1958},
#  '2007062101046': {'100-1- -a': 'Dørumsgaard, Arne',
#   '245-1-0-a': 'Klassisk kinesisk poesi i norsk gjendiktning',
#   '260- - -c': 'c1978',
#   '653- - -a': 'skjønnlitteratur/voksen',
#   'lang': 'nob',
#   'year': 1978},
#  '2007062101050': {'100-1- -a': 'Graarud, Astrid',
#   '245-1-0-a': 'Praktisk bibliotekarbeid for mindre folkeboksamlinger',
#   '260- - -c': '1956',
#   'lang': 'nob',
#   'year': 1956},
#  '2007062104003': {'100-1- -a': 'Obrestad, Tor',
#   '245-1-0-a': 'Vinterdikt',
#   '260- - -c': '1979',
#   '653- - -a': 'dikt, norske',
#   'lang': 'mul',
#   'year': 1979},
#  '2007062104042': {'100-1- -a': 'Blekastad, Milada',
#   '245-1-0-a': 'Millom bork og ved :',
#   '245-1-0-b': 'frå tsjekkisk åndsliv i nyare tid',
#   '260- - -c': '1978',
#   '653- - -a': 'litteratur, litteraturhistorie, tjekkisk, tsjekkisk, tsjekkoslovakia, åndsliv',
#   'lang': 'nno',
#   'year': 1978},
#  '2007062201017': {'100-1- -a': 'Ørbech, Kari',
#   '245-1-0-a': 'Det kan ikke være sant',
#   '260- - -c': '1956',
#   'lang': 'nob',
#   'year': 1956},
#  '2007062202001': {'100-1- -a': 'Heintz, Natascha',
#   '245-1-0-a': 'Mesozoiske øglefunn fra Norge og Svalbard =',
#   '245-1-0-b': 'Mesozoic reptiles from Norway and Svalbard',
#   '260- - -c': '1964',
#   '653- - -a': 'norway, reptils, svalbard',
#   'lang': 'nob',
#   'year': 1964},
#  '2007062500009': {'245-1-0-a': 'Lov om aksjeselskaper :',
#   '245-1-0-b': 'lov 4 juni 1976 nr. 59 med kommentarer',
#   '260- - -c': '1980',
#   '653- - -a': '(1976), aksjeloven, aksjelover, aksjer, aksjeselskap, aksjeselskaper, kommentarer, norge, rettsvitenskap, selskapsrett',
#   'lang': 'nob',
#   'year': 1980},
#  '2007062500020': {'100-1- -a': 'Hognestad, Anne Kristine',
#   '245-1-0-a': 'Helsekost :',
#   '245-1-0-b': 'fikse idéer om mat : studiehefte',
#   '260- - -c': '1980',
#   '653- - -a': 'ernæring',
#   'lang': 'nob',
#   'year': 1980},
#  '2007062500033': {'100-1- -a': 'Asheim, Ivar',
#   '245-1-0-a': 'Embetsplikt og lojalitet :',
#   '245-1-0-b': 'betenkning avgitt til Bispemøtet våren 1980, med Bispemøtets vedtak',
#   '260- - -c': '1980',
#   '653- - -a': 'bispemã¸tet, embete, lojalitet, pastoralteologi, prester, religion',
#   'lang': 'nob',
#   'year': 1980},
#  '2007062500040': {'100-1- -a': 'Michelet, Else',
#   '245-1-3-a': 'En annen historie',
#   '260- - -c': '1981',
#   '653- - -a': 'historie, historikk, kirkepolitikk, kjønnsroller, kvinnehistorie, kvinnen, kvinner, kvinnesak, kvinnesosiologi, politikk/samfunn',
#   'lang': 'nob',
#   'year': 1981},
#  '2007062500042': {'100-1- -a': 'Skjeseth, Jon',
#   '245-1-0-a': 'Samliv og samspill i naturen',
#   '260- - -c': 'c1980',
#   '653- - -a': 'biologi, miljøvern, økologi, økopolitikk, økosystem',
#   'lang': 'nob',
#   'year': 1980},
#  '2007062501045': {'100-1- -a': 'Lie, Olaf',
#   '245-1-0-a': 'Etiopia',
#   '260- - -c': '1954',
#   '653- - -a': 'etiopia, historie, misjon, norsk',
#   'lang': 'nob',
#   'year': 1954},
#  '2007062504051': {'100-1- -a': 'Holmsen, Gunnar',
#   '245-1-0-a': 'Hallingdal :',
#   '245-1-0-b': 'beskrivelse til kvartærgeologisk landgeneralkart',
#   '260- - -c': '1955',
#   'lang': 'nob',
#   'year': 1955},
#  '2007062600051': {'100-1- -a': 'Frerk, F.W.',
#   '245-1-0-a': 'Alt om skarpinnstilling',
#   '260- - -c': 'c1955',
#   'lang': 'nob',
#   'year': 1955},
#  '2007062602001': [],
#  '2007062604048': [],
#  '2007062701013': {'100-1- -a': 'Mathisen, Ida',
#   '245-1-0-a': 'Usynlige krefter',
#   '260- - -c': '[1956]',
#   'lang': 'nob',
#   'year': 1956},
#  '2007062701046': {'100-1- -a': 'Dagnew, Jacob Tsehaye',
#   '245-1-0-a': 'Norsk tigrinja ordliste',
#   '260- - -c': 'cop. 1985',
#   'lang': 'mul',
#   'year': 1985},
#  '2007062701048': [],
#  '2007062701079': {'245-1-0-a': 'Morsmålsundervisning og norskundervisning for innvandrerbarn',
#   '260- - -c': '[1980]',
#   '653- - -a': 'andrespråk, flyktninger, innvandrerbarn, innvandrere, morsmålsundervisning, norsk, norskundervisning, spesialundervisning, språk, språkundervisning, tospråklighet, undervisning',
#   'lang': 'nob',
#   'year': 1980},
#  '2007062704003': {'100-1- -a': 'Møller, Arvid',
#   '245-1-0-a': 'Sigurd fra Klevfos',
#   '260- - -c': 'c1983',
#   '653- - -a': 'barn, biografi/genealogi, cellulose, historier, industri, løten, papir, treforedling',
#   'lang': 'nob',
#   'year': 1983},
#  '2007062800003': {'260- - -c': 'c1978',
#   '653- - -a': 'etikk, horn, humanetikk, kristian, livssyn',
#   'lang': 'nob',
#   'year': 1978},
#  '2007062801024': {'100-1- -a': 'Hanssen, Vidar',
#   '245-1-0-a': 'Programmering i Cobol',
#   '260- - -c': '1982',
#   '653- - -a': 'cobol, databehandling, programmering, programmeringsspråk',
#   'lang': 'nob',
#   'year': 1982},
#  '2007062801052': {'100-1- -a': 'Børde, Haakon',
#   '245-1-0-a': 'Eventyret Antarktis',
#   '260- - -c': '1978',
#   'lang': 'nob',
#   'year': 1978},
#  '2007062900035': [],
#  '2007070201020': {'100-1- -a': 'Martinussen, Willy',
#   '245-1-0-a': 'Fjerndemokratiet :',
#   '245-1-0-b': 'sosial ulikhet, politiske ressurser og politisk medvirkning i Norge',
#   '260- - -c': '1973',
#   '653- - -a': 'aktivitet, deltakelse, demokrati, forhold, klasser, norge, politikk, politisk, samfunnsanalyser, sosial, sosiale, sosiologi, statsvitenskap, ulikhet',
#   'lang': 'nob',
#   'year': 1973},
#  '2007070201078': {'260- - -c': 'c1980',
#   '653- - -a': 'barcelona, barn, forfattere, jenter, kvinnelitteratur, kvinner, litteratur, litteraturen, litteraturhistorie, litterære, motiver, sosiologi',
#   'lang': 'nob',
#   'year': 1980},
#  '2007070201087': {'100-1- -a': 'Lindgren, Astrid',
#   '245-1-0-a': 'Rasmus, Pontus og Trille',
#   '260- - -c': '1980',
#   '653- - -a': 'barnebøker',
#   'lang': 'nob',
#   'year': 1980},
#  '2007070204018': [],
#  '2007070204048': {'100-1- -a': 'Shakespeare, William',
#   '260- - -c': '1980',
#   '653- - -a': 'skjønnlitteratur/voksen, skuespill',
#   'lang': 'mul',
#   'year': 1980},
#  '2007070204061': {'100-1- -a': 'Austad, Torleiv',
#   '245-1-0-a': 'Skapt til å tjene :',
#   '245-1-0-b': 'sosialetiske grunnspørsmål i kristendommen',
#   '260- - -c': 'c1980',
#   '653- - -a': 'etikk, kristen, kristendom, sosial, sosialetikk',
#   'lang': 'nob',
#   'year': 1980},
#  '2007070300004': {'260- - -c': '1978',
#   '653- - -a': 'elgjakt, jakt',
#   'lang': 'nob',
#   'year': 1978},
#  '2007070300040': {'100-1- -a': 'Dannevig, Petter',
#   '245-1-0-a': 'Vær og klima i farger',
#   '260- - -c': '1978',
#   '653- - -a': 'håndbøker, klima, klimatologi, meteorologi, vær, værvarsling',
#   'lang': 'nob',
#   'year': 1978},
#  '2007070300055': {'100-1- -a': 'Bergh, Steinar',
#   '245-1-0-a': 'Homofile :',
#   '245-1-0-b': 'myter og virkelighet : en undersøkelse blant homofile kvinner og menn i Norge',
#   '260- - -c': '1978',
#   '653- - -a': 'homofili, homoseksualitet, politikk, samfunn',
#   'lang': 'nob',
#   'year': 1978},
#  '2007070301014': {'100-1- -a': 'Foss, Øyvind',
#   '245-1-0-a': 'Jeg elsket en terrorist :',
#   '245-1-0-b': 'et oppgjør med Baader-Meinhof',
#   '260- - -c': '1981',
#   '653- - -a': 'homofili, terrorisme, tyskland',
#   'lang': 'nob',
#   'year': 1981},
#  '2007070301045': {'260- - -c': '1980',
#   '653- - -a': 'kvinner, seksualitet',
#   'lang': 'nob',
#   'year': 1980},
#  '2007070301056': {'100-1- -a': 'Sveli, Arvid',
#   '245-1-0-a': 'Det gjemte landet',
#   '260- - -c': '1980',
#   '653- - -a': 'geografi/historie, sør-helgeland',
#   'lang': 'nob',
#   'year': 1980},
#  '2007070400029': {'100-1- -a': 'Hansen, Hans Aleksander',
#   '245-1-0-a': 'Samfunnslære nederst ved bordet',
#   '260- - -c': '1978',
#   '653- - -a': 'biografi/genealogi, rasemotsetninger',
#   'lang': 'nob',
#   'year': 1978},
#  '2007070400035': {'100-1- -a': 'Øyslebø, Olaf',
#   '245-1-0-a': 'Språklig kommunikasjon',
#   '260- - -c': 'c1979',
#   '653- - -a': 'kommunikasjon, norsk, psykologi, språk, språkbruksanalyse, språkfilosofi, språklig, språkpsykologi, språksosiologi, språkvitenskap',
#   'lang': 'nob',
#   'year': 1979},
#  '2007070400039': {'100-1- -a': 'Borgen, Johan',
#   '245-1-0-a': 'Alltid på en søndag :',
#   '245-1-0-b': 'seksti søndagsposter ; radiokåserier i utvalg ved Haagen Ringnes',
#   '260- - -c': '1968',
#   '653- - -a': 'antologier, essays, kåseri, kåserier, norske, radiokåserier',
# ...
#  '2008022800069': [],
#  '2008022800073': [],
#  '2008022800106': {'100-1- -a': 'Däniken, Erich von',
#   '245-1-0-a': 'Gudesjokket',
#   '260- - -c': 'cop. 1995',
#   'lang': 'nob',
#   'year': 1995},
#  '2008022801007': {'100-1- -a': 'Sødal, Kirsten',
#   '245-1-0-a': 'Fanget av baglere',
#   '260- - -c': 'cop. 1995',
#   'lang': 'nob',
#   'year': 1995},
#  '2008022804020': {'100-1- -a': 'Johansen, Hilde Elisabeth',
#   '245-1-0-a': 'Personlig økonomi for kvinner',
#   '260- - -c': 'cop. 1995',
#   'lang': 'nob',
#   'year': 1995},
#  '2008022804065': {'100-1- -a': 'Rønnevig, Else',
#   '245-1-0-a': 'Mat og hus :',
#   '245-1-0-b': 'kulturhistorisk kokebok',
#   '260- - -c': '1995',
#   '653- - -a': 'bevaringsverdige, boliger, bomiljø, historie, kokebøker, kulturhistorie, matlaging, rehabilitering',
#   'lang': 'nob',
#   'year': 1995},
#  '2008022904032': {'260- - -c': '[1995?]',
#   '653- - -a': 'folketellinger',
#   'lang': 'nob',
#   'year': 1995},
#  '2008022904044': [],
#  '2008030300037': {'260- - -c': '[1995?]',
#   '653- - -a': 'folketellinger',
#   'lang': 'nob',
#   'year': 1995},
#  '2008030300049': {'260- - -c': '1995',
#   '653- - -a': 'hole, lokalhistorie, pilegrimer, pilegrimsvandringer, ringerike',
#   'lang': 'nob',
#   'year': 1995},
#  '2008030300101': {'260- - -c': '1995', 'lang': 'nob', 'year': 1995},
#  '2008030300167': [],
#  '2008030400061': [],
#  '2008030400075': [],
#  '2008030400093': {'100-1- -a': 'Søbye, Espen',
#   '245-1-0-a': 'Rolf Stenersen :',
#   '245-1-0-b': 'en biografi',
#   '260- - -c': 'cop. 1995',
#   '653- - -a': 'biografier, historie, kunstsamlere, norge, rolf, stenersen',
#   'lang': 'nob',
#   'year': 1995},
#  '2008030400095': {'100-1- -a': 'Moen, Ellen',
#   '245-1-0-a': 'Skritt for skritt :',
#   '245-1-0-b': 'barn og bevegelse : fysisk fostring/kroppsøving i barnehage og småskole',
#   '260- - -c': '1995',
#   '653- - -a': 'barn, barnehage, barnehagen, barnehager, barnepsykologi, bevegelse, bevegelseskommunikasjon, bevegelsesleik, bevegelseslære, fostring, fysisk, grunnskolen, kognitiv, kroppsøving, lekemiljø, lærebøker, læringsmiljø, metoder, metodikk, motorikk, motorisk, skole, småbarnsalder, småskolen, undervisning, utvikling',
#   'lang': 'nob',
#   'year': 1995},
#  '2008030404052': {'100-1- -a': 'Borge, Per Erik',
#   '245-1-0-a': 'Kondorens flukt',
#   '260- - -c': '1995',
#   '653- - -a': '1990-tallet, krim/spenning, norsk',
#   'lang': 'nob',
#   'year': 1995},
#  '2008030404075': {'100-1- -a': 'Skei, Hans H.',
#   '245-1-0-a': 'På litterære lekeplasser :',
#   '245-1-0-b': 'studier i moderne metafiksjonsdiktning',
#   '260- - -c': '1995',
#   '653- - -a': '1900-1999, 19001999, e, göran, histori, historie, kritikk, litteratur, litteraturteori, litteraturvitenskap, litterær, metadiktning, metafiksjon, metafiksjonsdiktning, metode, metoder, postmodernisme, romaner, tekstanalyse, tekstteori, teori, tunström,',
#   'lang': 'nob',
#   'year': 1995},
#  '2008030404104': {'100-1- -a': 'Smith, Dodie',
#   '245-1-0-a': 'Hundre og en dalmatinere',
#   '260- - -c': '1995',
#   '653- - -a': 'barnebøker, skjønnlitteratur',
#   'lang': 'nob',
#   'year': 1995},
#  '2008030500016': {'100-1- -a': 'Boe, Erik',
#   '245-1-0-a': 'Oppgave- og materialsamling i forvaltningsrett',
#   '260- - -c': '1995',
#   '653- - -a': 'forvaltning, forvaltningsloven, forvaltningsrett, materialsamling, materialsamlinger, norge, norsk, offentlig, oppgaver, oppgavesamlinger',
#   'lang': 'nob',
#   'year': 1995},
#  '2008030504043': {'100-1- -a': 'Jenssen, Steinar Riise',
#   '245-1-0-a': 'Fra landbruksskole til videregående skole :',
#   '245-1-0-b': 'undervisning og gårdsbruk på Kalnes 1870-1995',
#   '260- - -c': '1995',
#   '653- - -a': 'sarpsborg, skoler, tune',
#   'lang': 'nob',
#   'year': 1995},
#  '2008030604006': {'100-1- -a': 'Øia, Tormod',
#   '245-1-0-a': 'Apolitisk ungdom? :',
#   '245-1-0-b': 'sjølbergingsgenerasjonen og politiske verdier',
#   '260- - -c': '[1995]',
#   '653- - -a': 'deltakelse, holdninger, norge, normer, organisasjoner, politikk, politisk, politiske, poltikk, sosiologi, spørreundersøkelser, ungdom',
#   'lang': 'nob',
#   'year': 1995},
#  '2008030604031': {'100-1- -a': 'Aukrust, Kjell',
#   '245-1-3-a': 'En liten og en små :',
#   '245-1-3-b': 'minner og inntrykk',
#   '260- - -c': '1995',
#   '653- - -a': '1990-tallet, humor, norsk',
#   'lang': 'nob',
#   'year': 1995},
#  '2008030700014': [],
#  '2008030700035': [],
#  '2008030700036': {'260- - -c': '1995',
#   '653- - -a': 'antologi, barn, barnebøker, barnelitteratur, kjærlighet, tro',
#   'lang': 'mul',
#   'year': 1995},
#  '2008030700050': {'100-1- -a': 'Fangen, Ronald',
#   '245-1-0-a': 'Essays',
#   '260- - -c': 'c1995',
#   '653- - -a': '1900-tallet/i, essay, essays, fb, litteratur, norsk, norske',
#   'lang': 'nob',
#   'year': 1995},
#  '2008030700072': [],
#  '2008030704041': {'245-1-0-a': 'Regulations on compulsory pilotage in Norwegian waters, pilotage exemption certificates, pilotage readiness dues and pilotage dues (pilotage service dues), transitional provisions for compulsory pilotage and pilotage service dues, and regulations concerning the entry into and passage through Norwegian territorial waters in peacetime of foreign, non-military vessels :',
#   '245-1-0-b': 'all regulations come into force on 1 May 1995',
#   '260- - -c': '[1995]',
#   '653- - -a': 'sjøfartslover, sjøvett',
#   'lang': 'eng',
#   'year': 1995},
#  '2008030704043': {'100-1- -a': 'Despard, Annabelle',
#   '245-1-0-a': 'Fisken tenker sitt',
#   '260- - -c': '1995',
#   '653- - -a': 'dikt, engelsk, skjønnlitteratur/voksen',
#   'lang': 'nob',
#   'year': 1995},
#  '2008031000043': {'245-1-0-a': '25 years of histocompatibility and HLA',
#   '260- - -c': '1995',
#   'lang': 'eng',
#   'year': 1995},
#  '2008031000050': {'260- - -c': 'c1995',
#   '653- - -a': 'allmennyttige, arbeid, frivillig, frivillige, frivillige-organisasjoner, frivillighet, norden, norge, organisasjonar, organisasjoner, organisasjoner,, organisasjoner., organisasjonsarbeid, organisering, private, samfunn, samfunnsvitenskapene,, sammenslutninger, sektor, sosial, sosialarbeid, sosialt, tredje, velferd, velferdssamfunnet, velferdssamfunnet,, velferdstiltak-norge',
#   'lang': 'mul',
#   'year': 1995},
#  '2008031000068': {'260- - -c': '1995',
#   '653- - -a': 'barnelitteratur, barnepoesi, ungdomsbøker',
#   'lang': 'nob',
#   'year': 1995},
#  '2008031000072': {'100-1- -a': 'Holmberg, Veikko',
#   '245-1-0-a': 'Tuuru-kuobža ja elleituáhtár reekkig',
#   '260- - -c': '1995',
#   '653- - -a': 'barn, bjørner, koalabjørner, mánáidgirji, oahpogirji',
#   'lang': 'smn',
#   'year': 1995},
#  '2008031100031': {'100-1- -a': 'Tranøy, Joar',
#   '245-1-0-a': 'Psykiatriens kjemiske makt',
#   '260- - -c': '1995',
#   '653- - -a': 'behandling, farmakoterapi, historie, kjemoterapi, kritikk, legemiddel, legemiddelterapi, lidelser, lobotomi, lsd, medikamentell, medikamentermedikamentmisbruk, medikamentermedikamentmisbrukterapibehandling, neuroleptika, neurologi, neuropleptikaovergrep, neuropleptikaovergrep, nevroleptika, norge, psykiatri, psykiatrisk, psykiske, psykofarmaka, psykofarmakologi, psykoterapi, terapi, tvangsbehandling',
#   'lang': 'nob',
#   'year': 1995},
#  '2008031104002': [],
#  '2008031104016': {'100-1- -a': 'Aspeggen, Jon',
#   '245-1-0-a': 'Beskrivende geometri',
#   '260- - -c': '1995',
#   '653- - -a': 'beskrivende, deskriptiv, geometri, geometrisk, konstruksjonstegning, matematikk, projeksjonstegning, tegning, teknisk',
#   'lang': 'nob',
#   'year': 1995},
#  '2008031200014': {'260- - -c': '1995',
#   '653- - -a': 'afrika, aids, antropologi, arbeid, helsefremmende, helsepolitikk, hiv, tanzania, ungdom',
#   'lang': 'eng',
#   'year': 1995},
#  '2008031200025': {'100-1- -a': 'Hoff, Anne',
#   '245-1-0-a': 'Medievold :',
#   '245-1-0-b': 'fakta og forskning, meninger og myter',
#   '260- - -c': '1995',
#   '653- - -a': 'barn, film, fjernsyn, kommunikasjonssosiologi, massekommunikasjon, massemedia, massemedier, media, medieforskning, mediepåvirkning, medier, mediesosiologi, medievold, politikk/samfunn, tv, video, videovold, vold, voldspåvirkning',
#   'lang': 'nob',
#   'year': 1995},
#  '2008031404014': [],
#  '2008031404042': {'260- - -c': '1995',
#   '653- - -a': 'barn, familie, familien, far, farspermisjon, farsrollen, fedre, folketrygd, foreldrepermisjon, fødeselspenger, fødsel, fødselspengeordningen, fødselspenger, fødselspermisjon, fødselspermisjonar, kjønnsroller, likestilling, likestillingsspørsmål, menn, norsk, omsorg, omsorgsarbeid, omsorgspermisjon, pappapermisjon, pappapermisjoner, sosiale, trygder, trygderett',
#   'lang': 'mul',
#   'year': 1995},
#  '2008031404083': {'100-1- -a': 'García Márquez, Gabriel',
#   '245-1-0-a': 'Generalen i sin labyrint :',
#   '245-1-0-b': 'roman',
#   '260- - -c': '1996',
#   '653- - -a': 'biografisk, bolivar,, fortellinger, latin-amerika, litteratur, simón, spansk',
#   'lang': 'nob',
#   'year': 1996},
#  '2008032500002': [],
#  '2008032600003': {'100-1- -a': 'Nervik, Jon Arve',
#   '245-1-0-a': 'Offentlig politikk og klientløpebaner :',
#   '245-1-0-b': 'sosialhjelp og arbeidsmarkedstiltak - bidrag til selvforsørging eller ringdans i velferdsbyråkratiet?',
#   '260- - -c': '1996',
#   '653- - -a': 'arbeidsmarkedstiltak, doktoravhandling, norge, oslo, sosialhjelp',
#   'lang': 'eng',
#   'year': 1996},
#  '2008032704041': {'100-1- -a': 'Hoem, Edvard',
#   '245-1-0-a': 'Mitt tapre språk',
#   '260- - -c': '1996',
#   '653- - -a': 'historie, litteraturhistorie, norsk, nynorsk, språk, språkhistorie, språkspørsmålet, språkstrid',
#   'lang': 'nno',
#   'year': 1996},
#  '2008032800017': {'100-1- -a': 'Chaikin, Linda',
#   '260- - -c': 'cop. 1996',
#   '653- - -a': 'reformasjonen, skjønnlitteratur',
#   'lang': 'nob',
#   'year': 1996},
#  '2008032800018': {'100-1- -a': 'Evans, Nicholas',
#   '245-1-0-a': 'Hestehviskeren',
#   '260- - -c': 'cop. 1996',
#   'lang': 'nob',
#   'year': 1996},
#  '2008032800019': {'100-1- -a': 'Harvey, Greg',
#   '245-1-0-a': 'Windows 95 for dummies :',
#   '245-1-0-b': 'hurtigreferanse',
#   '260- - -c': '1996',
#   '653- - -a': '95, brukergrensesnitt, databehandling, dataprogram, edb, grafiske, innføring, opplæring, vindussystemer, windows',
#   'lang': 'nob',
#   'year': 1996},
#  '2008032800081': {'100-1- -a': 'Lenz, Siegfried',
#   '245-1-0-a': 'Opprøret',
#   '260- - -c': '1996',
#   '653- - -a': '1990-tallet, romaner, skjønnlitteratur, tyske',
#   'lang': 'nob',
#   'year': 1996},
#  '2008032800089': [],
#  '2008033100051': {'260- - -c': 'cop. 1996', 'lang': 'nob', 'year': 1996},
#  '2008033100092': [],
#  '2008033100108': [],
#  '2008033100115': {'100-1- -a': 'King, Stephen',
#   '245-1-0-a': 'De levende døde',
#   '260- - -c': '1996',
#   'lang': 'nob',
#   'year': 1996},
#  '2008033100124': {'100-1- -a': 'Johansen, Per Ole',
#   '245-1-0-a': 'Nettverk i gråsonen :',
#   '245-1-0-b': 'et perspektiv på organisert kriminalitet',
#   '260- - -c': '1996',
#   '653- - -a': 'korrupsjon, kriminalitet, kriminalpolitikk, kriminologi, mafia, mafiavirksomhet, narkotika, norge, organisasjoner, organisert, økonomisk',
#   'lang': 'nob',
#   'year': 1996},
#  '2008040100022': [],
#  '2008040100026': {'260- - -c': '1996',
#   '653- - -a': 'bestandsforvaltning, bestandsovervåking, elger, forelhogna, hardangervidda, jegerseleksjon, knutshø, nord-ottadalen, nordfjella, rein, reinsdyr, rondane, setesdal-ryfylkeheiene, snøhetta, svalbard, villrein, villreinområder',
#   'lang': 'nob',
#   'year': 1996},
#  '2008040100048': {'100-1- -a': 'Gulden, Bror Petter',
#   '245-1-0-a': 'Revisjon :',
#   '245-1-0-b': 'teori og metode',
#   '260- - -c': '1996',
#   '653- - -a': 'metoder, regnskapsvesen, revisjon',
#   'lang': 'nob',
#   'year': 1996},
#  '2008040100070': [],
#  '2008041804100': [],
#  '2008041804102': {'100-1- -a': 'Elsta, Fanny',
#   '245-1-0-a': 'Boken om Ellen Gulbranson',
#   '260- - -c': '1950',
#   'lang': 'nob',
#   'year': 1950},
#  '2008042201002': {'100-1- -a': 'Galt, John',
#   '245-1-0-a': 'Mr. Balwhidders gjenvordigheter',
#   '260- - -c': '1950',
#   'lang': 'nob',
#   'year': 1950},
#  '2008042204028': [],
#  '2008042204033': {'100-1- -a': 'Lane, Homer',
#   '245-1-0-a': 'Barn og frihet',
#   '260- - -c': '1950',
#   '653- - -a': 'barn, barneoppdragelse, barns, pedagogikk, utvikling',
#   'lang': 'nob',
#   'year': 1950},
#  '2008042204041': {'100-1- -a': 'Hierman, Audun',
#   '245-1-0-a': 'Bertil og brødrene hans',
#   '260- - -c': '1950',
#   'lang': 'nob',
#   'year': 1950},
#  '2008042204080': {'100-1- -a': 'Sherwood, Robert E.',
#   '245-1-0-a': 'Roosevelt og Hopkins',
#   '260- - -c': '1950',
#   'lang': 'nob',
#   'year': 1950},
#  '2008042300034': {'100-1- -a': 'Wohl, Louis de',
#   '245-1-0-a': 'Erobreren',
#   '260- - -c': '1950',
#   'lang': 'nob',
#   'year': 1950},
#  '2008042404076': {'100-1- -a': 'Hermansen, Halfdan',
#   '245-1-0-a': 'Engelsk grammatikk til friundervisningens lærebok i engelsk',
#   '260- - -c': '1951',
#   '653- - -a': 'engelsk, grammatikk, lærebøker, læremiddel, språk',
#   'lang': 'mul',
#   'year': 1951},
#  '2008042504032': {'100-1- -a': 'Berg, Lars',
#   '245-1-0-a': 'Kristen enhet, kristen tro',
#   '260- - -c': '1950',
#   '653- - -a': 'økumenikk',
#   'lang': 'nob',
#   'year': 1950},
#  '2008042800009': {'100-1- -a': 'Fønhus, Mikkjel',
#   '245-1-0-a': 'Tredalsmåren',
#   '260- - -c': '1951',
#   'lang': 'nob',
#   'year': 1951},
#  '2008042800101': {'100-1- -a': 'Kielland, Eugenia',
#   '245-1-0-a': 'Sigurd Christiansen i liv og diktning',
#   '260- - -c': '1952',
#   '653- - -a': 'biografier, christiansen, christiansen,, litteratur, litteraturhistorie, norsk, sigurd',
#   'lang': 'nob',
#   'year': 1952},
#  '2008042804021': {'100-1- -a': 'Masefield, John',
#   '245-1-0-a': 'Død manns kyst',
#   '260- - -c': '1951',
#   'lang': 'nob',
#   'year': 1951},
#  '2008042804039': {'100-1- -a': 'Gaukstad, Øystein',
#   '245-1-0-a': 'Norsk folkemusikk :',
#   '245-1-0-b': 'ein bibliografi',
#   '260- - -c': '1951',
#   '653- - -a': 'bibliografi, bibliografier, folkemusikk, musikk, norge, norsk',
#   'lang': 'mul',
#   'year': 1951},
#  '2008042804048': {'100-1- -a': 'Nansen, Odd',
#   '245-1-0-a': 'I ellevte time :',
#   '245-1-0-b': 'en appell til Europarådet om det tyske flyktningeproblem',
#   '260- - -c': 'c1951',
#   '653- - -a': 'flyktningar, geografi/historie, tyskland',
#   'lang': 'nob',
#   'year': 1951},
#  '2008042804056': {'100-1- -a': 'Williams, J. H.',
#   '245-1-0-a': 'Elefant Bill :',
#   '245-1-0-b': '25 år i Burmas jungel',
#   '260- - -c': '1951',
#   'lang': 'nob',
#   'year': 1951},
#  '2008042804079': {'100-1- -a': 'Sjåmo, Tormod',
#   '245-1-0-a': 'Maling',
#   '260- - -c': '1951',
#   '653- - -a': 'maling',
#   'lang': 'nob',
#   'year': 1951},
#  '2008042804111': {'260- - -c': '[1952]',
#   '653- - -a': 'karikaturtegning',
#   'lang': 'nob',
#   'year': 1952},
#  '2008042804126': {'245-1-0-a': 'Kristi etterfølgelse',
#   '260- - -c': '[1952]',
#   '653- - -a': 'etterfølgelse, kristen, kristenliv, mystikk, oppbyggelseslitteratur, personlig',
#   'lang': 'nob',
#   'year': 1952},
#  '2008042804137': {'100-1- -a': 'Medbøe, Odd',
#   '245-1-0-a': 'Jet-fly og raketter :',
#   '245-1-0-b': 'Odd Medbøe',
#   '260- - -c': '1951',
#   'lang': 'nob',
#   'year': 1951},
#  '2008042804146': {'100-1- -a': 'Mohn, Albert Henrik',
#   '245-1-0-a': 'Rød taifun over Korea',
#   '260- - -c': '1951',
#   '653- - -a': 'geografi/historie',
#   'lang': 'nob',
#   'year': 1951},
#  '2008042900059': {'100-1- -a': 'Andreasen, Hans',
#   '245-1-0-a': 'Italiensk hverdag',
#   '260- - -c': '1952',
#   'lang': 'nob',
#   'year': 1952},
#  '2008042900072': {'100-1- -a': 'Gullers, K.W.',
#   '245-1-0-a': 'Norge :',
#   '245-1-0-b': 'glimt fra et stort lite land',
#   '260- - -c': '1951',
#   'lang': 'nob',
#   'year': 1951},
#  '2008042901007': {'260- - -c': '1953', 'lang': 'mul', 'year': 1953},
#  '2008042904005': {'100-1- -a': 'Harris, Joel Chandler',
#   '245-1-0-a': 'Fortellinger av onkel Remus',
#   '260- - -c': '1952',
#   '653- - -a': 'eventyr, sørstatene',
#   'lang': 'nob',
#   'year': 1952},
#  '2008042904026': {'100-1- -a': 'Juvkam, Lizzie',
#   '245-1-0-a': 'Eneboere',
#   '260- - -c': '1952',
#   '653- - -a': '1950-tallet, fb, norske, romaner',
#   'lang': 'nob',
#   'year': 1952},
#  '2008043000033': [],
#  '2008043004034': {'100-1- -a': 'Ericsson, Ture',
#   '245-1-0-a': 'I Bibelens land',
#   '260- - -c': '1953',
#   'lang': 'nob',
#   'year': 1953},
#  '2008043004086': {'100-1- -a': 'Klæbo, Arthur',
#   '245-1-0-a': 'God jul, granne :',
#   '245-1-0-b': 'ein liten julespøk',
#   '260- - -c': '1953',
#   'lang': 'nno',
#   'year': 1953},
#  ...}

# %%
nb.frame(mm.metadata(urns= nb.pure_urn([2009021104104,2007051100026])))
# Out:
#                      100-1- -a          245-1-3-a 260- - -c  \
# 2007051100026   Achebe, Chinua  En mann av folket      1967
# 2009021104104  Cortázar, Julio                NaN      1999
#
#                                        653- - -a lang  year 245-1-0-a
# 2007051100026            skjønnlitteratur/voksen  nob  1967       NaN
# 2009021104104  1960-tallet, argentinske, romaner  nob  1999   Paradis

# %% [markdown]
# # Oversatt engelsk litteratur

# %%
eng = nb.book_corpus(period=(1950, 2010), trans='eng', limit=50000)

# %%
eng.sort_values(by='year').groupby('year').count()['urn'].plot(lw=5, figsize=(10,5))

# %%
alt = nb.book_corpus(period=(1950, 2010), ddk = '8%', limit = 500000)

# %%
altm = nb.metadata(list(alt.urn))

# %%
nb.frame(altm)
# Out:
#                    0                       1     2  \
# 0      2011072508096              Kava, Alex  2005
# 1      2014032405079                          1999
# 2      2009040200012        Sonesson, Harald  1999
# 3      2007101800013             Devon, Gary  1992
# 4      2011072906079         Bertling, Berit  2005
# ...              ...                     ...   ...
# 68618  2011062108176  Woodiwiss, Kathleen E.  2004
# 68619  2007110901029             Valla, Lise  1992
# 68620  2012072708135           Thoene, Bodie  1988
# 68621  2014100807515       Woolrich, Cornell  1985
# 68622  2011062308114            Perro, Bryan  2007
#
#                                             3      4                  5  \
# 0                      Drapsmannens feiltrinn                      Damm
# 1                          Trøst, en antologi             [Forfatterne]
# 2            Mummitrollet på oppdagelsesreise                  Cappelen
# 3                               Farlig begjær         Hjemmets bokforl.
# 4                                  Maktbegjær                  Cappelen
# ...                                       ...    ...                ...
# 68618                                Evig din                 Schibsted
# 68619  Vi kommer i morgen og henter dine barn  roman               Luna
# 68620                            Zions porter             Hermon forlag
# 68621                    Det svarte forhenget                    Norild
# 68622                           Brahas nøkkel               Magic Press
#
#              6                                 7    8    9
# 0        novel  af805326826715521ebeb594626f4b55  nob  eng
# 1      fiction  b4e20fba6a6647530eee40456959170e  mul
# 2      fiction  a5988266498d2add765fcf6651be63ab  nob  swe
# 3      fiction  cac5ccb4072fd5ce1cb523f40c419b6e  nob  eng
# 4        novel  fd62660e5c0c9ae92dee0bd18493568c  nob
# ...        ...                               ...  ...  ...
# 68618    novel  fe21233f9814a30ee67f60f72f8aa636  nob  eng
# 68619  fiction  e241aaa5f2361ba7d37d1ab5dd6fba51  nob
# 68620  fiction  43c59016ee37f37a15692554b2c64c97  nob  eng
# 68621  fiction  1169e6bd73c0ab864687bf1b4d6172f5  nob  eng
# 68622    novel  6c7714da812cf77252d9d95eb67d787b  nob  fre
#
# [68623 rows x 10 columns]

# %%
språk = nb.frame(altm)[[0, 2, 8, 9]].groupby([2,9]).count()

# %%
språk.plot(figsize=(15,6))

# %%
import pandas as pd

# %%
swe = nb.book_corpus(trans='swe', limit = 100000)
dan = nb.book_corpus(trans='dan', limit = 100000)

# %%
combo = pd.concat([swe, dan])

# %%
combo
# Out:
#                 urn              author  \
# 0     2013032106060  Stinissen, Wilfrid
# 1     2013091905049        Stark, Sigge
# 2     2011061708148        Guillou, Jan
# 3     2013092308092
# 4     2008071604032      Peterson, Hans
# ...             ...                 ...
# 3982  2013071208120    Saxtorph, Peder.
# 3983  2007020701015       Gilberg, Aage
# 3984  2014090108078      Davidsen, Leif
# 3985  2011063008210        Koch, Jørgen
# 3986  2007111600055     Nørgaard, Henry
#
#                                         title  year
# 0                         Evighetens øyeblikk  1993
# 1            Sari og kjærligheten ; Befrieren  2008
# 2                             Arven etter Arn  2007
# 3                                   Nisseboka  2001
# 4                               Pelle JanssoN  1981
# ...                                       ...   ...
# 3982  Peder Saxdorphs Syv Passions-Prædikener  1876
# 3983                  Verdens nordligste lege  1949
# 3984                       troskyldige russer  1994
# 3985                Bli kjent med Access 2003  2005
# 3986                          Stjernehimmelen  1991
#
# [13178 rows x 4 columns]

# %%
langs = "swe lat eng rus dan sme".split()
langs
# Out:
# ['swe', 'lat', 'eng', 'rus', 'dan', 'sme']

# %%
trans_corpus = pd.concat([nb.book_corpus(trans=lang, limit = 100000) for lang in langs])

# %%
trans_corpus
# Out:
#               urn            author  \
# 0   2014070105050  Björk, Christina
# 1   2007112100064      Lärn, Viveca
# 2   2013060708138  Mankell, Henning
# 3   2007010901053    Starbäck, C.G.
# 4   2014120807596  Hoppe, Elisabeth
# ..            ...               ...
# 82  2013093038018      Timár, Jósef
# 83  2016042648118       Persen, Nan
# 84  2014062305010     Sokki, Risten
# 85  2014070108029
# 86  2010071910006   Cappelen, Bodil
#
#                                         title  year
# 0   Du er forelsket, hva? sa Klara til Eufrat  1976
# 1                         Mimmi får en farfar  1991
# 2                              hvite løvinnen  2006
# 3                   Engelbrekt Engelbrektsson  1945
# 4               Veve fritt i ramme og vevstol  1976
# ..                                        ...   ...
# 82                                      Sener  2013
# 83                                Guollemáles  2012
# 84                          Mu ártegis eallin  2011
# 85     Tiden er et skip som ikke kaster anker  2004
# 86                                     Duvrie  1998
#
# [53984 rows x 4 columns]

# %% [markdown]
# Lager en dict av korpus.

# %%
trans_corpus = {lang:nb.book_corpus(trans="%"+lang+"%", limit = 100000) for lang in langs}

# %%
for lang in trans_corpus:
    trans_corpus[lang][lang] = lang

# %%
trans_corpus
# Out:
# {'swe':                 urn              author  \
#  0     2012062206148        Mossberg, Bo
#  1     2013091338026    Strandberg, Mats
#  2     2014112107613   Janouch, Katerina
#  3     2008081804045
#  4     2012121038010       Sjöberg, Lars
#  ...             ...                 ...
#  9333  2016011348055        Beckman, Kaj
#  9334  2013040807095   Ericsson, John O.
#  9335  2013092508053  Janouch, Katerina.
#  9336  2012033008046       Ericson, Stig
#  9337  2012070305012          Wahl, Mats
#
#                                        title  year  swe
#  0                                  Oretreet  1975  swe
#  1                                       Ild  2012  swe
#  2                          Ingrid og dyrene  2011  swe
#  3     Teknologisk forlags store bok om jakt  1998  swe
#  4                          1700-tallsmøbler  2003  swe
#  ...                                     ...   ...  ...
#  9333                    Lisen får ikke sove  1980  swe
#  9334                Robin Hood spenner buen  1974  swe
#  9335                      Ingrid skal reise  2013  swe
#  9336                 Vær på vakt, Dan Henry  1973  swe
#  9337               Når det kommer en elsker  2009  swe
#
#  [9338 rows x 5 columns],
#  'lat':                urn                         author  \
#  0    2014051906008         Ovidius Naso, Publius.
#  1    2014031808023                 Luther, Martin
#  2    2013093028003      Vegetius Renatus, Flavius
#  3    2013022205138
#  4    2011061720001  Cyprianus, Thascius Caecilius
#  ..             ...                            ...
#  261  2014112738094                          Gaius
#  262  2011022205079         Plautus, Titus Maccius
#  263  2009072700041
#  264  2012012406022   Suetonius Tranquillus, Gaius
#  265  2008111700110                Dante Alighieri
#
#                                                   title  year  lat
#  0                Kjærlighetskuren &amp; Brevvekslinger  2009  lat
#  1    Dr. Martin Luthers udførlige Forklaring over P...  1861  lat
#  2                               Dell'arte della guerra  1551  lat
#  3                                    Gud er kjærlighet  2007  lat
#  4    Om den almindelige Kirkes Enhed og om Herrens Bøn  1880  lat
#  ..                                                 ...   ...  ...
#  261                                      Institusjoner  1927  lat
#  262                                         Løgnhalsen  1965  lat
#  263                            Kirkeordinansen av 1537  1990  lat
#  264                                   Romerske keisere  1974  lat
#  265                        Om diktning på folkespråket  2006  lat
#
#  [266 rows x 5 columns],
#  'eng':                  urn            author                       title  year  eng
#  0      2013102407003  Garrett, Richard          Mysterier på havet  1974  eng
#  1      2014102008060    L'Amour, Louis           Villmarken kaller  1996  eng
#  2      2008080804048  Gordimer, Nadine                 Æresgjesten  1998  eng
#  3      2014070907231      Ryan, Denise                     Steiner  2008  eng
#  4      2015101648032                                    Ulf Larsen  2008  eng
#  ...              ...               ...                         ...   ...  ...
#  40268  2009080600089       Mills, Adam         Skolens hemmelighet  1990  eng
#  40269  2010032612008       Steen, Gina  magnetiske hvitløkkokeboka  1995  eng
#  40270  2007112100012          Tan, Amy              Lykke og glede  1993  eng
#  40271  2012071106052   Spock, Benjamin           Spør doktor Spock  1974  eng
#  40272  2007032001057  Martelli, George    Mannen som reddet London  1961  eng
#
#  [40273 rows x 5 columns],
#  'rus':                urn                            author  \
#  0    2015072108032                     Tolstoj, L.N.
#  1    2011051608123                      Gogol', N.V.
#  2    2007022201065                      Gogol', N.V.
#  3    2015011608114                 Berdjaev, Nikolaj
#  4    2012092108049              Tendrjakov, Vladimir
#  ..             ...                               ...
#  719  2013031105078  Kollontaj, Aleksandra Mihajlovna
#  720  2011070108049             Solženicyn, Aleksandr
#  721  2016030809598                     Kulikov, Oleg
#  722  2008011501060                  Ajtmatov, Čingiz
#  723  2014080608007                 Grossman, Vasilij
#
#                               title  year  rus
#  0            Utvalgte fortellinger  1989  rus
#  1                      Døde sjeler  2004  rus
#  2                      Døde sjeler  1948  rus
#  3                     russiske idé  2012  rus
#  4    Hittebarnet og andre noveller  1980  rus
#  ..                             ...   ...  ...
#  719           Veien til kjærlighet  1975  rus
#  720    dag i Ivan Denisovitsj' liv  2005  rus
#  721             Brødrene Karamasov  2009  rus
#  722                hvite dampbåten  1993  rus
#  723              Krigens øyenvitne  2006  rus
#
#  [724 rows x 5 columns],
#  'dan':                 urn             author  \
#  0     2013031108209
#  1     2012071106070       Bjerre, Erik
#  2     2015071308033   Borup, Christian
#  3     2008052600037         Holm, Sven
#  4     2011090108170     Øberg, Ellinor
#  ...             ...                ...
#  4151  2008050700014    Lindhardt, P.G.
#  4152  2013070306022          Lund, Kaj
#  4153  2007111904083     Reuter, Bjarne
#  4154  2011052008066       Bach, Ada v.
#  4155  2006110701003  Birkeland, Thøger
#
#                                             title  year  dan
#  0                            Turen går til Paris  1963  dan
#  1     Les selv om matematikkens spennende verden  2011  dan
#  2                      Astrologisk kalender 1993  1992  dan
#  3                       øy nesten som et paradis  1970  dan
#  4                            Gråt ikke mer Anita  1997  dan
#  ...                                          ...   ...  ...
#  4151                            Helvetesstrategi  1959  dan
#  4152                                     Makramé  1980  dan
#  4153                                         7 A  1993  dan
#  4154                                      Katter  1979  dan
#  4155                         Blir du med, Lasse?  1974  dan
#
#  [4156 rows x 5 columns],
#  'sme':               urn                  author  \
#  0   2007050403003   Valkeapää, Nils-Aslak
#  1   2012052505100
#  2   2014121608200  Olsen, Inger Margrethe
#  3   2011101706008        Skåden, Sigbjørn
#  4   2012110608040         Boine, Liv Tone
#  ..            ...                     ...
#  83  2013100106084        Vars, Elle Márjá
#  84  2008081404044
#  85  2015081808052         Einejord, Magne
#  86  2007041302001    Lukkari, Rauni Magga
#  87  2013100806050        Eira, Karen Inga
#
#                                       title  year  sme
#  0                           Jorda, min mor  2006  sme
#  1               Aperçu de littérature sami  2011  sme
#  2                              Ganij-Lijsá  1994  sme
#  3                De fortapte barns frelser  2010  sme
#  4                             Luonndo ællá  2012  sme
#  ..                                     ...   ...  ...
#  83                 Værálda lájkemus ulmusj  2010  sme
#  84  Fortellinger og hendelser i Kautokeino  1997  sme
#  85                              Molteturen  1981  sme
#  86                                  Farvel  1999  sme
#  87                              Ánin dánin  2010  sme
#
#  [88 rows x 5 columns]}
