# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
mu.update('dhlab_v2')
mu.css('css.css')
# Out:
# Updated file `C:\Users\yoons\Documents\GitHub\Miscellaneous-Notebooks\DHlab_språkbanken\dhlab_v2.py`
# <style>p {
#     font-size:1.2em;
#     color : #223355;
# }
# h1, h2, h3, h4, h5, h6 {
#     color:#3344aa;
#
# }
# html {
#     margin-left:10%;
#     margin-right:5%;
# }
#
# body {
#     counter-reset: h2counter;
# }
# h1 {
#     counter-reset: h2counter;
# }
# h2:before {
#     content: counter(h2counter) ".\0000a0\0000a0";
#     counter-increment: h2counter;
#     counter-reset: h3counter;
# }
# h3:before {
#     content: counter(h2counter) "." counter(h3counter) ".\0000a0\0000a0";
#     counter-increment: h3counter;
# }
# </style>

# %%
import dhlab_v2 as d2

# %% [markdown]
# foreslår make_corpus

# %%
nb.book_corpus()
# Out:
#               urn              author  \
# 0   2011022205156     Gjersvik, Randi
# 1   2014101308032
# 2   2014120206036
# 3   2009110600023
# 4   2010101909037
# 5   2016020308062  Ihlen, Per Gerhard
# 6   2009050600048
# 7   2014031806053
# 8   2013061206090          Hayder, Mo
# 9   2012111506007       Saltveit, Alf
# 10  2011011905054    Johannesen, Aam.
# 11  2012090408067
# 12  2011061605080
# 13  2011092108126          Jünge, Åke
# 14  2011022306256   Berge, Lars Johan
# 15  2012120705001      Ringertz, Nils
# 16  2006083100065      Braaten, Oskar
# 17  2012050408050       Higgins, Jack
# 18  2013011406094     Stubberud, Tore
# 19  2009100804030      Holdø, Lauritz
#
#                                                 title  year
# 0                                 Ventilasjonsteknikk  1969
# 1                                       Bygdepolitikk  1993
# 2   Kulturhistorisk leksikon for nordisk middelald...  1971
# 3                           Kirke-leksikon for Norden  1904
# 4                      Dokumentbehandling på kontoret  1997
# 5             Byggefelt på Gulenakken i Fjell kommune  2008
# 6                                           I språket  1998
# 7                                            Responsa  1964
# 8                                            Ritualer  2010
# 9                                            Vandring  1983
# 10         Rekneskapsbok og skjemabok for folkeskulen  1942
# 11               Tema: Utviklingsarbeid i grunnskolen  1992
# 12                                 Kvinnesyn - tvisyn  1985
# 13  Frå oppvekst i reinfjellet i Grong, via famili...  2007
# 14               Løs Baandene, lad Kræfterne udvikles  2000
# 15                              Behandlingen av kreft  1976
# 16                                  Bak høkerens disk  1977
# 17                                         Gjenferdet  1982
# 18                    Selvbiografi ved seks års alder  2008
# 19                                          Batteriet  1994

# %%
corpus = d2.document_corpus(author = "Amalie Skram")
corpus
# Out:
#                                    urn  \
# 0  URN:NBN:no-nb_digibok_2013040807050
# 1  URN:NBN:no-nb_digibok_2012051408131
# 2  URN:NBN:no-nb_digibok_2015091506165
# 3  URN:NBN:no-nb_digibok_2014090408194
# 4  URN:NBN:no-nb_digibok_2012052905133
# 5  URN:NBN:no-nb_digibok_2018062805029
# 6  URN:NBN:no-nb_digibok_2009020304060
# 5                                       792.642    drama  Skjønnlitteratur
# 6                                       839.823  fiction  Skjønnlitteratur
# 7                   norsk / litteratur           fiction  Skjønnlitteratur
# 8  skjønnlitteratur / norske / romaner             novel  Skjønnlitteratur
# 9                                                            Uklassifisert
#
#    doctype
# 0  digibok
# 1  digibok
# 2  digibok
# 3  digibok
# 4  digibok
# 5  digibok
# 6  digibok
# 7  digibok
# 8  digibok
# 9  digibok

# %%
corpus.city
# Out:
# 0           Oslo
# 1         Bergen
# 2         [Oslo]
# 3    [København]
# 4    [København]
# 5         Bergen
# 6      København
# 7         [Oslo]
# 8     Kjøbenhavn
# 9      [Stabekk]
# Name: city, dtype: object

# %%
concs = d2.concordance(urns = list(corpus.urn), words = "arbeid")
len(concs)
# Out:
# 3

# %%
concs.sample(min(len(concs), 20)).style
# Out:
# <style  type="text/css" >
# </style><table id="T_08a7aa76_2a6c_11ec_b73b_7c7635c6d85a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >docid</th>        <th class="col_heading level0 col1" >urn</th>        <th class="col_heading level0 col2" >conc</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_08a7aa76_2a6c_11ec_b73b_7c7635c6d85alevel0_row0" class="row_heading level0 row0" >2</th>
#                         <td id="T_08a7aa76_2a6c_11ec_b73b_7c7635c6d85arow0_col0" class="data row0 col0" >100508035</td>
#                         <td id="T_08a7aa76_2a6c_11ec_b73b_7c7635c6d85arow0_col1" class="data row0 col1" >URN:NBN:no-nb_digibok_2006081000050</td>
#                         <td id="T_08a7aa76_2a6c_11ec_b73b_7c7635c6d85arow0_col2" class="data row0 col2" >... Martine fortsatte uforstyrret sitt <b>arbeid</b> .</td>
#             </tr>
#             <tr>
#                         <th id="T_08a7aa76_2a6c_11ec_b73b_7c7635c6d85alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_08a7aa76_2a6c_11ec_b73b_7c7635c6d85arow1_col0" class="data row1 col0" >100234778</td>
#                         <td id="T_08a7aa76_2a6c_11ec_b73b_7c7635c6d85arow1_col1" class="data row1 col1" >URN:NBN:no-nb_digibok_2014111008028</td>
#                         <td id="T_08a7aa76_2a6c_11ec_b73b_7c7635c6d85arow1_col2" class="data row1 col2" >... Han sa sig om , men opdaget intet , før han var kommet ved siden av den litle bakkede tverrgaten til venstre , hvor <b>Arbeid</b> erboligen lå . Der... </td>
#             </tr>
#             <tr>
#                         <th id="T_08a7aa76_2a6c_11ec_b73b_7c7635c6d85alevel0_row2" class="row_heading level0 row2" >0</th>
#                         <td id="T_08a7aa76_2a6c_11ec_b73b_7c7635c6d85arow2_col0" class="data row2 col0" >100145046</td>
#                         <td id="T_08a7aa76_2a6c_11ec_b73b_7c7635c6d85arow2_col1" class="data row2 col1" >URN:NBN:no-nb_digibok_2013040807050</td>
#                         <td id="T_08a7aa76_2a6c_11ec_b73b_7c7635c6d85arow2_col2" class="data row2 col2" >... som var litt distré og sterkt optatt av sin musikk og sitt <b>arbeid</b> , ikke skydde å traske lange veier tilbake for å kysse sin dumme... </td>
#             </tr>
#     </tbody></table>

# %%
concs = d2.concordance(urns = list(corpus.urn), words = """  "værelset sto"  """)
len(concs)
# Out:
# 0

# %%
concs.sample(min(len(concs), 20)).style
# Out:
# <style  type="text/css" >
# </style><table id="T_09ae3fdc_2a6c_11ec_8cba_7c7635c6d85a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >docid</th>        <th class="col_heading level0 col1" >urn</th>        <th class="col_heading level0 col2" >conc</th>    </tr></thead><tbody>
#         </tbody></table>

# %%
concs = d2.concordance(urns = list(corpus.urn), words = "cigaret*")
len(concs)
# Out:
# 6

# %%
concs.style
# Out:
# <style  type="text/css" >
# </style><table id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >docid</th>        <th class="col_heading level0 col1" >urn</th>        <th class="col_heading level0 col2" >conc</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85arow0_col0" class="data row0 col0" >100091268</td>
#                         <td id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85arow0_col1" class="data row0 col1" >URN:NBN:no-nb_digibok_2012051408131</td>
#                         <td id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85arow0_col2" class="data row0 col2" >... sod Vin , Masser af Vin i store Pokaler og <b>Cigaretter</b> , nej Cigarer , stærke . fine .</td>
#             </tr>
#             <tr>
#                         <th id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85arow1_col0" class="data row1 col0" >100266953</td>
#                         <td id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85arow1_col1" class="data row1 col1" >URN:NBN:no-nb_digibok_2015091506165</td>
#                         <td id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85arow1_col2" class="data row1 col2" >Saa satte de sig til at drikke Rum , som de spædte med Vand , og sendte Gamlingen afsted efter <b>Cigaretter</b> .</td>
#             </tr>
#             <tr>
#                         <th id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85arow2_col0" class="data row2 col0" >100266953</td>
#                         <td id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85arow2_col1" class="data row2 col1" >URN:NBN:no-nb_digibok_2015091506165</td>
#                         <td id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85arow2_col2" class="data row2 col2" >Sivert gik hen til Rordet , tømte sit Glas og tændte sig en <b>Cigarette</b> .</td>
#             </tr>
#             <tr>
#                         <th id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85arow3_col0" class="data row3 col0" >100266953</td>
#                         <td id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85arow3_col1" class="data row3 col1" >URN:NBN:no-nb_digibok_2015091506165</td>
#                         <td id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85arow3_col2" class="data row3 col2" >Kort efter kom de alle tre med tændte <b>Cigaretter</b> , en sammenslaat Krak under Armen og et Glas Grog i Haanden og satte sig tilrette omkring... </td>
#             </tr>
#             <tr>
#                         <th id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85arow4_col0" class="data row4 col0" >100266953</td>
#                         <td id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85arow4_col1" class="data row4 col1" >URN:NBN:no-nb_digibok_2015091506165</td>
#                         <td id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85arow4_col2" class="data row4 col2" >... Paa Kajen tæt ved Skibet laa Negre og strakte sig paa Vareballerne og damped paa <b>Cigaretter</b> , der lyste som røde Gløder , mens de fjaste med... </td>
#             </tr>
#             <tr>
#                         <th id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85alevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85arow5_col0" class="data row5 col0" >100266953</td>
#                         <td id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85arow5_col1" class="data row5 col1" >URN:NBN:no-nb_digibok_2015091506165</td>
#                         <td id="T_0b08eaca_2a6c_11ec_ad82_7c7635c6d85arow5_col2" class="data row5 col2" >... Tilsidst satte de sig ned paa Kanten af Storingen , med Renene trukkct tæt ind til sig , og røg <b>Cigaretter</b> , men efter en halv Times Forløb... </td>
#             </tr>
#     </tbody></table>

# %%
d2.urn_collocation(urns = list(corpus.urn), word = 'demokrati', before = 15, after = 15).sort_values(by = 'counts', ascending =False)
# Out:
# Empty DataFrame
# Columns: [counts, dist, bdist]
# Index: []

# %%
tot = d2.totals(20000)

# %%
d2.concordance_counts(urns = list(corpus.urn), words = "vårt Norge", window = 5).sort_values(by = 'freq', ascending = False)
# Out:
# Empty DataFrame
# Columns: [freq]
# Index: []

# %%
dtm = d2.get_document_frequencies(urns = list(corpus.urn))

# %%
import pandas as pd

# %%
dtm = pd.DataFrame(dtm)

# %%
dtm.sort_values(by = dtm.columns[1], ascending = False).head(50).fillna(0).applymap(int).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow0_col6 {
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow0_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow0_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow0_col9 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow1_col0 {
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow1_col1 {
#             background-color:  #056fae;
#             color:  #f1f1f1;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow1_col2 {
#             background-color:  #0567a2;
#             color:  #f1f1f1;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow1_col3 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow1_col4 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow1_col5 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow1_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow1_col7 {
#             background-color:  #2a88bc;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow1_col8 {
#             background-color:  #0567a1;
#             color:  #f1f1f1;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow1_col9 {
#             background-color:  #056ba9;
#             color:  #f1f1f1;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow2_col0 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow2_col1 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow2_col2 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow2_col3 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow2_col4 {
#             background-color:  #71a8ce;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow2_col5 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow2_col6 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow2_col7 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow2_col8 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow2_col9 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow3_col0 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow3_col1 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow3_col2 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow3_col3 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow3_col4 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow3_col5 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow3_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow3_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow3_col8 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow3_col9 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow4_col0 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow4_col1 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow4_col3 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow4_col4 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow4_col5 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow4_col6 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow4_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow4_col8 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow4_col9 {
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow5_col0 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow5_col1 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow5_col2 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow5_col3 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow5_col4 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow5_col5 {
#             background-color:  #c8cde4;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow5_col6 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow5_col7 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow5_col8 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_1fda952e_2a6c_11ec_a1bf_7c7635c6d85arow5_col9 {
#             background-color:  #d5d5e8;
#             color:  #000000;
