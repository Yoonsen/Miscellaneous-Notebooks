# %% [markdown]
# ## Oppstart

# %% [markdown]
# ### Preamble
#
# Contains imports and some utility code.

# %%
from dhlab.module_update import update, css, code_toggle

# %%
import dhlab.graph_networkx_louvain as gnl
import dhlab.nbtext as nb
import networkx as nx
# %matplotlib inline

# %%
import pandas as pd

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
def frame_sort(frame, by=0):
    return frame.sort_values(by=by, ascending=False)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Kollokasjoner eller assosiasjoner
#
# Hvilke ord opptrer et ord sammen med innenfor et korpus?

# %% [markdown]
# ### Define a corpus
#
# Bruk gjerne Dewey eller temaord for å definere korpuset, hold det forholdsvis lite rundt 200 bøker.

# %%
collword = 'hvitvin'

# %%
korpus = nb.book_urn(words=[collword], ddk='8%', period=(1960, 2020), limit=500)
len(korpus)
# Out:
# 500

# %% [markdown]
# Kommandoen nb.frame() kan benyttes på en hel del output. Gir en fin oversikt over data, og kan brukes .head() for å se de første eksemplene.

# %%
nb.frame(korpus).head(10)
# Out:
#                0                     1                            2     3
# 0  2010042003102      Gaarder, Jostein        I et speil, i en gåte  1995
# 1  2015030606035  Coughlin, William J.       Kjærlighet og karriere  1987
# 2  2013062506039       Cassella, Carol                      Oksygen  2010
# 3  2011100408258         William, Kate                    Rømlingen  1997
# 4  2012092606104        Hagerup, Helge       Vennlig hilsen Lucifer  1985
# 5  2011091908168         Rendell, Ruth            Forvillede sjeler  2007
# 6  2015021106022               Steriko  svenske fiskeskipperens død  2012
# 7  2014102706083        Iggulden, Conn           Ulven fra steppene  2009
# 8  2009021004067       Sandemo, Margit            hav av kjærlighet  2000
# 9  2008072204064  Christiansen, Sigurd         To levende og en død  1996

# %%
nb.urn_concordance(word='hvitvin', urns=korpus)
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014060308011?searchText=hvitvin' target='_blank' style='text-decoration:none'>Ukjent stjerne, Mortimer, Carole, 2001</a>
#                 </td>
#                 <td>Har du lyst på litt</td>
#                 <td>hvitvin</td>
#                 <td style='text-align:left'>til maten ?</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014051207047?searchText=hvitvin' target='_blank' style='text-decoration:none'>Nedtelling i Santo Domingo, Sanders, Leonard, 1977</a>
#                 </td>
#                 <td>serverte El Jefe en ny</td>
#                 <td>hvitvin</td>
#                 <td style='text-align:left'>fra Alsace som ble en</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008011000027?searchText=hvitvin' target='_blank' style='text-decoration:none'>Frøken Smillas fornemmelse for snø, Høeg, Peter, 1993</a>
#                 </td>
#                 <td>korken . Det er en</td>
#                 <td>hvitvin</td>
#                 <td style='text-align:left'>, fargen er gulgrønn ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008102800121?searchText=hvitvin' target='_blank' style='text-decoration:none'>Et eget prosjekt, Ingvaldsen, Bjørn, 2000</a>
#                 </td>
#                 <td>med hjem . Ganske billig</td>
#                 <td>hvitvin</td>
#                 <td style='text-align:left'>, den Anita og Rune</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008102800121?searchText=hvitvin' target='_blank' style='text-decoration:none'>Et eget prosjekt, Ingvaldsen, Bjørn, 2000</a>
#                 </td>
#                 <td>kjøkkenet . Det fikk bli</td>
#                 <td>hvitvin</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008102800121?searchText=hvitvin' target='_blank' style='text-decoration:none'>Et eget prosjekt, Ingvaldsen, Bjørn, 2000</a>
#                 </td>
#                 <td>jeg i sovepose og tutdrakk</td>
#                 <td>hvitvin</td>
#                 <td style='text-align:left'>til jeg sovnet .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2
# Så kan vi hente ut selve kollokasjonen,dvs. ord som står innenfor en viss avstand fra målordet.

# %%
small_window = 5
large_window = 10

# %%
def collpart(collword, urns, win = 5, limit = 10000):
    return nb.urn_coll(collword, urns = korpus, after = win, before = win, limit = 10000)

# %% [markdown]
# Kollokasjonen er en såkalt **dataframe** som kan undersøkes med `.head()` som ovenfor.

# %%
small = collpart(collword, nb.pure_urn(korpus), win = 5)
large = collpart(collword, nb.pure_urn(korpus), win = 10)

# %% [markdown]
# ## Finn referanse
#
# Det er flere måter å sammenligne på. En er å bruke bokhylla selv om som referanse. For å hente ut ord fra bokhylla brukes kommandoen `totals(<antall ord>)`. Korpuset selv kan også benyttes, for eksempel med kommandoen `aggregate_urns(<korpusdefinisjon>)`.

# %% [markdown]
# #### Sammenlign

# %% [markdown]
# Vi har nå tre frekvenslister som kan sammenlignes med hverandre. For å lette sammenlign normaliseres dem. Kommandoen for normalisering er `normalize_corpus_dataframe(<frekvensliste>)`

# %% [markdown]
# nb.normalize_corpus_dataframe(korpus_agg)
# nb.normalize_corpus_dataframe(tot)
# nb.normalize_corpus_dataframe(small)
# nb.normalize_corpus_dataframe(large)

# %% [markdown]
# Inspiser dataene etter normalisering

# %% [markdown]
# ### Kollokasjonen

# %%
small.head()
# Out:
#        0
# .    671
# og   635
# ,    535
# en   327
# med  278

# %%
large.head()
# Out:
#         0
# .    1289
# ,    1060
# og    992
# en    509
# med   455

# %% [markdown]
# Kollokasjonen *coll* har gjennomgående høyere verdier, noe som sannsynligvis skyldes at det er færre ord.

# %% [markdown]
# #### Utfør sammenligning
#
# For sammenligning måles forskjellen på *coll* med referansen. Forskjellen måles ved å dividere hvert ords frekvens ikollokasjonen på frekvensen ordet har i referansen.
#
# $$\textrm{assosiasjons-styrke}(w) = \frac{\textrm{coll}(w)}{\textrm{referanse}(w)}$$
#
# Divisjonen pr.ord gjøres av Python - resultat sorteres og legges i variabelen `coll_assoc`

# %%
delta = pd.DataFrame()

# %%
delta['small'] = small[0]
delta['large'] = large[0]

# %%
delta['ratio'] = small[0]/large[0]

# %%
#delta['log'] = np.log(delta['ratio'])

# %%
#delta['score'] = delta['ratio'] * delta['log']

# %%
delta[(delta['small'] > 2) & (delta['ratio'] > 0.6)].sort_values(by='ratio', ascending=False)
# Out:
#           small  large     ratio
# karaffel      7      7  1.000000
# serveres      3      3  1.000000
# pils          5      5  1.000000
# Med           5      5  1.000000
# halvfull      5      5  1.000000
# ...         ...    ...       ...
# lunsj         8     13  0.615385
# må            8     13  0.615385
# flasken       8     13  0.615385
# med         278    455  0.610989
# fra          47     78  0.602564
#
# [204 rows x 3 columns]

# %%
delta.loc[[',','.','og','!', '?']]
# Out:
#     small  large     ratio
# ,     535   1060  0.504717
# .     671   1289  0.520559
# og    635    992  0.640121
# !      14     24  0.583333
# ?     104    223  0.466368

# %%
delta_max = delta[delta.small < delta.large][delta.small > 0][delta.ratio > 0.6].sort_values(by='ratio', ascending=False)

# %%
delta_const = delta[delta.small > 2][delta.ratio > 0.6].sort_values(by='ratio', ascending=False)

# %%
delta_max.head(20)
# Out:
#           small  large     ratio
# kald         38     40  0.950000
# søt          18     19  0.947368
# drukket      17     18  0.944444
# halv         17     18  0.944444
# nippet       15     16  0.937500
# tørr         38     41  0.926829
# billig       11     12  0.916667
# flaske      118    129  0.914729
# drakk        78     87  0.896552
# serverte      8      9  0.888889
# kjølig        7      8  0.875000
# ny            7      8  0.875000
# glass       236    272  0.867647
# skjenket     37     43  0.860465
# bestille      6      7  0.857143
# bestilt       6      7  0.857143
# servere       6      7  0.857143
# Vil           6      7  0.857143
# tømte         6      7  0.857143
# reker        17     20  0.850000

# %%
delta_const
# Out:
#           small  large     ratio
# karaffel      7      7  1.000000
# serveres      3      3  1.000000
# pils          5      5  1.000000
# Med           5      5  1.000000
# halvfull      5      5  1.000000
# ...         ...    ...       ...
# lunsj         8     13  0.615385
# må            8     13  0.615385
# flasken       8     13  0.615385
# med         278    455  0.610989
# fra          47     78  0.602564
#
# [204 rows x 3 columns]

# %%
delta_max.head(50).index
# Out:
# Index(['kald', 'søt', 'drukket', 'halv', 'nippet', 'tørr', 'billig', 'flaske',
#        'drakk', 'serverte', 'kjølig', 'ny', 'glass', 'skjenket', 'bestille',
#        'bestilt', 'servere', 'Vil', 'tømte', 'reker', 'nøt', 'først', 'skylte',
#        'soda', 'glasset', 'kopp', 'kjøpte', 'blåskjell', 'deilig', 'del',
#        'bruker', 'rørte', 'pose', 'løftet', 'halvtørr', 'glassene', 'takk',
#        'dyr', 'drikker', 'smør', 'imot', 'ba', 'Et', 'rekene', 'tømt', 'halvt',
#        'fyller', 'forsøkte', 'enda', 'fylt'],
#       dtype='object')

# %%
delta_const.head(50).index
# Out:
# Index(['karaffel', 'serveres', 'pils', 'Med', 'halvfull', 'elsker',
#        'forretten', 'Hvis', 'utmerket', 'liter', 'kjøpe', 'Straks', 'delte',
#        'fat', 'smaker', 'bæres', 'kongens', 'skalldyr', 'skinke', '9',
#        'italiensk', 'iskald', 'øyeblikk', 'skålt', 'bestiller', 'trodde',
#        'enkel', 'naturligvis', 'fin', 'natt', 'Drikk', 'rekesmørbrød',
#        'jordbær', 'enkét', 'husets', 'rosevin', 'takket', 'best',
#        'foretrekker', 'dårlig', 'To', 'blanding', 'muslinger', 'røkelaks',
#        'Tørr', 'stående', 'skj', 'hentet', 'Uten', 'vannet'],
#       dtype='object')

# %% [markdown]
# # Visualiser med en ordsky
#
#
# Visualiseringen trives best med tall mellom 0 og 1, så assosiasjonene divideres på summen av dem for å få til det. Ordskyene lages med kommonandoen `cloud(<data>)`. Pass på å ikke ta med alt for mange; det kan gi feilsituasjoner.

# %%
nb.cloud(nb.frame(delta_max.ratio))

# %%
nb.cloud(nb.frame(delta_const.head(150).small/delta_const.small.sum()))
