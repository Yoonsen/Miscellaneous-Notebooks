# %% [markdown]
# ## Preamble

# %% [markdown]
# ## Get essentials
#
# Import text and graph modules for analysis, and css for display

# %%
from dhlab.module_update import update, css, code_toggle, printmd

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Merriweather|Shippori+Mincho|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Shippori+Mincho';
# 	font-size:1.1em;
# 	color: DarkSlateGray;
# }
#
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
#
#
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
# %%HTML
# <style>
# p {font-size:1.5em;};
# </style>
# Out:
# <style>
# p {font-size:1.5em;};
# </style>

# %% [markdown]
# ## Module

# %%
import dhlab.nbtext as nb   # import the whole module, but individual commands can be imported separately
import dhlab.graph_networkx_louvain as gnl 
import networkx as nx
from dhlab.graph_networkx_louvain import cutdown, make_collocation_graph
from collections import Counter
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
plt.rcParams["font.size"] = 18

# %%
def plotfig(a_plot, font_size = 18, legend = 18, loc = 1, title_size = 20):
    #fsize = plt.rcParams["font.size"
    ax = a_plot
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["bottom"].set_color("grey")
    ax.spines["left"].set_color("grey")
    ax.spines["bottom"].set_linewidth(1)
    ax.spines["left"].set_linewidth(1)
    plt.legend(loc = loc, prop={'size': 18})
    #plt.rcParams["font.size"] = fsize
    return

# %%
def show_cliques(G):
    C = gnl.make_cliques_from_graph(G.to_undirected())
    cliques = [(t, ', '.join(C[1][t])) for t in C[1]]
    cliques.sort(key=lambda x: x[0][1])
    for x, y in cliques:
        print(x, y)
        print()

# %% [markdown]
# # Aggregation data
#
# ### Trend lines, n-grams, word graphs

# %% [markdown]
# ### Trend lines
#
# Data up to trigrams.

# %%
plotfig(nb.nb_ngram("kjærlighed", years=(1800, 1950), smooth=5).plot(figsize=(15,8), lw=3))

# %%
plotfig(nb.nb_ngram("kjcerlighed, kjærlighed", years=(1800, 1950), smooth=1).sort_index().rolling(window=5).mean().plot(figsize=(15,8), lw=3))

# %%
plotfig(nb.nb_ngram("kjcerlighed, kjærlighed, kjærlighet", years=(1800, 1950), smooth=1).sort_index().rolling(window=5).mean().plot(figsize=(15,8), lw=3))

# %%
plotfig(nb.nb_ngram("litauen, latvia, estland", years=(1920, 2010), smooth=1, corpus = "avis").sort_index().rolling(window=5).mean().plot(figsize=(15,8), lw=3))

# %%
plotfig(nb.nb_ngram("likestilling", years=(1920, 2010), smooth=1, corpus = "bok").sort_index().rolling(window=5).mean().plot(figsize=(15,8), lw=3))

# %% [markdown]
# # Using ngrams to measure associations between words
#
# There is a relationship of frequency between nouns (pronouns and common nouns, and verbs and adjectives as well). A context may change that relationship. For instance, two adjectives like "blue" and "red" may switch depending on what they modify.
#
#
# ## nb.difference()
#
# The command `difference(A, B, C, D)` computes
#
# $$\textrm{difference}(A,B,C,D) = \frac{\frac{A}{B}}{\frac{C}{D}}$$
#
# It compares the ratio of the first two arguments with the ratio of the second two. This is useful when one wants to compare two words in different contexts.
#
# For a certain selection of arguments, this leads to a simple interpretations. If *difference* is less than 1, it means the numerator ratio is smaller than the denominator, which can be used to compare contexts, and  see how contexts make a difference. For example is *w* and *v* are two words, and *C* is a context, *difference* can be used to see if the context is associated with *w* or *v*:
#
# If $\textrm{difference}(C(w),C(v),w,v) > 1$ then $C$ is associated with $w$, otherwise with $v$. In this case, we can say that the context $C$ prefers $w$ for $v$.

# %% [markdown]
# ## The case for _red_ and _blue_

# %%
nb.difference('blå bil', 'rød bil', 'blå', 'rød')
# Out:
# 0.44832801345232315

# %%
nb.difference('blå sofa', 'rød sofa', 'blå', 'rød')
# Out:
# 1.5518077670177213

# %% [markdown]
# ## Gender differences

# %%
# measure difference between men and women using pronouns

nb.difference('han gråter', 'hun gråter', 'han', 'hun')
# Out:
# 0.24425557325619277

# %%
# gendered body parts

nb.difference('håret hans', 'håret hennes', 'hans', 'hennes')
# Out:
# 0.18910122506774152

# %%
# gendered body parts

nb.difference('neven hans', 'neven hennes', 'hans', 'hennes')
# Out:
# 1.90045255572505

# %% [markdown]
# ## How about different grammatical cases?

# %%
nb.difference('ham', 'henne', 'han', 'hun')
# Out:
# 0.618438068090108

# %%
nb.difference('hans', 'hennes', 'han', 'hun')
# Out:
# 1.2200543525365617

# %% [markdown]
# At this point it may be helpful to just add in the pronouns in a template and study different contexts

# %%
diff = lambda x: nb.difference("han " + x, "hun " + x, "han", "hun")
diffseries = lambda s: pd.Series(list(map(diff, s)), index = s)

# %% [markdown]
# The examples above can be formulated by specifying only the contexts

# %%
he_she = diffseries("gråter påstår føler hevder sover arbeider snorker kjører".split())

# %%
he_she.plot(kind='bar', figsize = (10,5), alpha = 0.6, rot = 0, fontsize=14 )
plt.axhline(y=1, linewidth=3, color='orange', alpha=0.6)

# %% [markdown]
# In the case above, it is clear that $\textrm{'hun gråter'}$ (she sobs) has a lower frequency than expected, by looking at the ratio $\frac{\textrm{'han'}}{\textrm{'hun'}}$.

# %% [markdown]
# ## Measuring associations
#
# Still in a gendered perspective

# %%
nb.difference('rike menn', 'rike kvinner', 'menn', 'kvinner')
# Out:
# 3.9150311882029563

# %%
# measure difference between men and women
nb.difference('fattige menn', 'fattige kvinner', 'menn', 'kvinner')
# Out:
# 0.2821076768706094

# %% [markdown]
# # Word models
#
# Words as graphs. Three languages, Norwegian, English and German.

# %% [markdown]
# #### Norwegian

# %%
nor = nb.make_graph('demokrati', cutoff = 16)

# %%
gnl.show_graph(nor, spread = 1.9)

# %% [markdown]
# ## Clusters

# %%
gnl.show_communities(nor)
# Out:
# demokrati-menneskerettigheter :  demokrati, menneskerettigheter, rettssikkerhet, ytringsfrihet, diktatur, folkestyre, markedsøkonomi, Demokrati, menneskerettar, personvern, religionsfrihet, trosfrihet, rettsstat, pressefrihet, menneskeretter, forfatning, terror, tvang, sosial, ensretting, folkerett, privatisering, ytringsfridom, miljø, rettigheter, sensur
#
# frihet-rettferdighet :  frihet, rettferdighet, Frihet, menneskeverd, solidaritet, likhet, ansvar, likebehandling, fleksibilitet, selvstendighet, uavhengighet, Fred, integritet, sannhet, Land, Fedreland
#
# fred-fridom :  fred, fridom, rettferd, forsoning, avspenning, glede, nedrustning, forståelse, sikkerhet, ro, krig
#
# likestilling-likeverd :  likestilling, likeverd, medbestemmelse, mangfold, respekt, innflytelse, kvinnesak, likelønn, kvinnefrigjøring, deltakelse, påvirkning, frigjøring, kvinnekamp, medvirkning, inkludering, medinnflytelse, familiepolitikk, samarbeid
#
# åpenhet-toleranse :  åpenhet, toleranse, ærlighet, innsyn, tillit, offentlighet, nysgjerrighet, ryddighet
#
# velferd-trygghet :  velferd, trygghet, velstand, helse, omsorg, verdiskaping, trivsel, liv, sysselsetting
#
# sosialisme-kommunisme :  sosialisme, kommunisme, kapitalisme, kristendom, liberalisme, revolusjon, fascisme, nazisme, Kristendom, planøkonomi, konservatisme

# %% [markdown]
# # Cliques
#
# Image taken from https://en.wikipedia.org/wiki/Clique_(graph_theory)
# ![image.png](attachment:image.png)
# Image taken from https://en.wikipedia.org/wiki/Clique_(graph_theory)

# %%
show_cliques(nor)
# Out:
# (3, 1) menneskerettigheter, trosfrihet, toleranse, demokrati, liberalisme, velferd, likebehandling, selvstendighet, medbestemmelse, kapitalisme, rettferd, rettferdighet, menneskerettar, mangfold, menneskeverd, likestilling, kommunisme, rettsstat, innsyn, sosial, integritet, åpenhet, forsoning, Frihet, uavhengighet, fred, personvern, folkestyre, kristendom, pressefrihet, markedsøkonomi, ytringsfrihet, religionsfrihet, fascisme, likhet, likeverd, sosialisme, Kristendom, glede, fleksibilitet, respekt, frihet, Demokrati, sikkerhet, fridom, trygghet, diktatur, rettssikkerhet, revolusjon, solidaritet
#
# (4, 1) diktatur, demokrati, sosialisme, kommunisme
#
# (5, 1) menneskerettigheter, likeverd, fred, frihet, demokrati, rettferdighet, menneskeverd, likestilling
#
# (4, 2) likhet, menneskerettigheter, likeverd, sosialisme, Frihet, fred, folkestyre, frihet, demokrati, rettferdighet, menneskeverd, trygghet, rettssikkerhet, likestilling, ytringsfrihet

# %% [markdown]
# #### English

# %%
eng = nb.make_graph('democracy', lang='eng')

# %%
gnl.show_graph(eng, spread = 1.9)

# %%
gnl.show_communities(eng)
# Out:
# centralism-totalitarianism :  centralism, totalitarianism, absolutism, statism, militarism, dictatorship, collectivism, regionalism, unitarism, localism, fascism, regimentation
#
# democracy-secularism :  democracy, secularism, atheism, communalism, materialism, ochlocracy, whiggism, anticlericalism, shura
#
# constitutionalism-parliamentarism :  constitutionalism, parliamentarism, parliamentarianism, federalism, reformism, liberalism, political, presidentialism, politics, legality, republicanism, legalism, bourgeois
#
# autocracy-oligarchy :  autocracy, oligarchy, Autocracy, authoritarianism, Democracy, despotism, serfdom, Aristocracy, plutocracy, Orthodoxy, feudalism, Presidentialism, aristocracy, theocracy

# %%
show_cliques(eng)
# Out:
# (3, 1) despotism, centralism, democracy, constitutionalism, absolutism, parliamentarism, reformism, liberalism, parliamentarianism, authoritarianism, ochlocracy, plutocracy, oligarchy, autocracy

# %% [markdown]
# #### German

# %%
ger = nb.make_graph('Demokratische', lang='ger')

# %%
gnl.show_graph(ger, spread = 1.9)

# %%
gnl.show_communities(ger)
# Out:
# liberale-rechtsstaatliche :  liberale, rechtsstaatliche, demokratische, Konservative, tolerante, Sowjetsystem, freiheitliche, klerikale, parlamentarische, konservative
#
# soziale-Soziale :  soziale, Soziale, individualistische, ökologische, kulturelle
#
# autoritäre-totalitäre :  autoritäre, totalitäre, diktatorische, zentralistische, patriarchalische, Diktaturen, repressive, undemokratische, antidemokratische
#
# Liberale-Christlich :  Liberale, Christlich, Demokraten, Radikale, Sozialisten, Klerikale, Conservative
#
# Demokratische-Sozialistische :  Demokratische, Sozialistische, sozialistische, Christliche, kommunistische, radikaldemokratische, Kommunistische
#
# Zentrum-Peripherie :  Zentrum, Peripherie, Linksliberale, DDP, Nationalliberale, BVP, Freisinn, Bayernpartei

# %%
show_cliques(ger)
# Out:
# (3, 1) Demokratische, totalitäre, Diktaturen, diktatorische, autoritäre
#
# (3, 2) Demokratische, liberale, rechtsstaatliche, demokratische, soziale
#
# (3, 3) Demokratische, Zentrum, Christlich

# %% [markdown]
# # Looking at a corpus
#
# How to get data out of a corpus

# %% [markdown]
# Searching using live spec.

# %%
nb.concordance('demokrati', yearfrom=1980, yearto=2070)
# Out:
# <table><tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008010404033?searchText=demokrati' target='_'>,Flyktningpolitikken,1994</a></td><td>Norge etablert en ressursbank for</td><td>demokrati</td><td style='text-align:left'>og menneskerettigheter - NORDEM .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014120208099?searchText=demokrati' target='_'>,Dommere på reise,2001</a></td><td>mot rasisme , forbund for</td><td>demokrati</td><td style='text-align:left'>og toleranse , internasjonalt samarbeid</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009021104031?searchText=demokrati' target='_'>Schaanning, Espen,Fortiden i våre hender,2000</a></td><td>til en politisk tilstand (</td><td>demokrati</td><td style='text-align:left'>) , men til mellommenneskelige</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009021104031?searchText=demokrati' target='_'>Schaanning, Espen,Fortiden i våre hender,2000</a></td><td>. Framveksten av det greske</td><td>demokrati</td><td style='text-align:left'>trekker i denne retningen .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007070500067?searchText=demokrati' target='_'>,Atomkrig i medisinsk perspektiv,1981</a></td><td>. Eksperter må i et</td><td>demokrati</td><td style='text-align:left'>ikke holde noe tilbake i</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009070701096?searchText=demokrati' target='_'>,Nordic statistical yearbook 2003, vol. 41 =,2003</a></td><td>skall kunna fungera som en</td><td>demokrati</td><td style='text-align:left'>. Utbildningsnivån har emellertid aven</td></tr>
# </table>

# %%
nb.concordance('demokrati', yearfrom=1980, yearto=2020, ddk = "839%")
# Out:
# <table><tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013102906031?searchText=demokrati' target='_'>Oksholen, Tore,Undergang,2008</a></td><td>Har du noensinne opplevd et</td><td>demokrati</td><td style='text-align:left'>som fungere?» hadde CIA-offiseren spurt</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013102906031?searchText=demokrati' target='_'>Oksholen, Tore,Undergang,2008</a></td><td>« Det fins ikke noe</td><td>demokrati</td><td style='text-align:left'>som fungerer . Som jeg</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013102906031?searchText=demokrati' target='_'>Oksholen, Tore,Undergang,2008</a></td><td>som har</td><td>demokrati</td><td style='text-align:left'>, ytringsfrihet , velferdsgoder ...</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008120800099?searchText=demokrati' target='_'>Andersen, Per Thomas,Norsk litteraturhistorie,2001</a></td><td>fra embetsmannsregime til moderne politisk</td><td>demokrati</td><td style='text-align:left'>. Som mennesketype var han</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008120800099?searchText=demokrati' target='_'>Andersen, Per Thomas,Norsk litteraturhistorie,2001</a></td><td>veien til et moderne partipolitisk</td><td>demokrati</td><td style='text-align:left'>ikke var noen selvsagt utvikling</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014101506051?searchText=demokrati' target='_'>Senje, Siri,Biografien om Camilla Collett,2009</a></td><td>- tallet begynte tanker om</td><td>demokrati</td><td style='text-align:left'>, selvstendighet og « norskhet</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013080608056?searchText=demokrati' target='_'>Trovik, Tina,Samuel Sekel og flukten fra Paris,2012</a></td><td>for å oppnå rettferdighet og</td><td>demokrati</td><td style='text-align:left'>, slik som jeg vil</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008011004036?searchText=demokrati' target='_'>Kjærstad, Jan,Speil,1993</a></td><td>Det er jo umulig med</td><td>demokrati</td><td style='text-align:left'>i dag . Hva ?</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008011004036?searchText=demokrati' target='_'>Kjærstad, Jan,Speil,1993</a></td><td>med folks samtykke og raserte</td><td>demokrati</td><td style='text-align:left'>og frihet . Selv kjærligheten</td></tr>
# </table>

# %%
nb.concordance('demokrati', yearfrom=1980, yearto=2020, subject = "politikk")
# Out:
# <table><tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013072308015?searchText=demokrati' target='_'>,Medisin og samfunn,2003</a></td><td>mer i et direkte ,</td><td>demokrati</td><td style='text-align:left'>, er adskillelsen tvetydig .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013072308015?searchText=demokrati' target='_'>,Medisin og samfunn,2003</a></td><td>adskillelsen tvetydig . I et</td><td>demokrati</td><td style='text-align:left'>skal der være en stor</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013072308015?searchText=demokrati' target='_'>,Medisin og samfunn,2003</a></td><td>og styrte . Ideen om</td><td>demokrati</td><td style='text-align:left'>er ikke en idé om</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013072308015?searchText=demokrati' target='_'>,Medisin og samfunn,2003</a></td><td>. Også i et indirekte</td><td>demokrati</td><td style='text-align:left'>, en styreform som gir</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013072308015?searchText=demokrati' target='_'>,Medisin og samfunn,2003</a></td><td>teorien er markedet det primære</td><td>demokrati</td><td style='text-align:left'>- ja , det egentlige</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011011808139?searchText=demokrati' target='_'>Østby, Per,Flukten fra Detroit,1995</a></td><td>rekke om " det funksjonelle</td><td>demokrati</td><td style='text-align:left'>" . Sejersted konkluderer med</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011011808139?searchText=demokrati' target='_'>Østby, Per,Flukten fra Detroit,1995</a></td><td>var velstand , velferd og</td><td>demokrati</td><td style='text-align:left'>.</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011011808139?searchText=demokrati' target='_'>Østby, Per,Flukten fra Detroit,1995</a></td><td>" Modeller , makt og</td><td>demokrati</td><td style='text-align:left'>" , i Atle Midttun</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011011808139?searchText=demokrati' target='_'>Østby, Per,Flukten fra Detroit,1995</a></td><td>til forholdet mellom politikk og</td><td>demokrati</td><td style='text-align:left'>.</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011011808139?searchText=demokrati' target='_'>Østby, Per,Flukten fra Detroit,1995</a></td><td>spørsmål knyttet til spørsmålet om</td><td>demokrati</td><td style='text-align:left'>. Forskjellen var at her</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007080601123?searchText=demokrati' target='_'>Walker, Martin,Kjempen våkner,1986</a></td><td>ekstreme sentraliseringen og mangelen på</td><td>demokrati</td><td style='text-align:left'>i økonomiske saker » .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012121406011?searchText=demokrati' target='_'>,Samstemt for utvikling?,2008</a></td><td>svakt styresett og mangel på</td><td>demokrati</td><td style='text-align:left'>.</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012121406011?searchText=demokrati' target='_'>,Samstemt for utvikling?,2008</a></td><td>også styrking av menneskerettigheter og</td><td>demokrati</td><td style='text-align:left'>samt miljømessig bærekraft og likestilling.</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012121406011?searchText=demokrati' target='_'>,Samstemt for utvikling?,2008</a></td><td>igjen er en forutsetning for</td><td>demokrati</td><td style='text-align:left'>. Eiendomsretten er selve grunnmuren</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012121406011?searchText=demokrati' target='_'>,Samstemt for utvikling?,2008</a></td><td>kan forhindre at lånene undergraver</td><td>demokrati</td><td style='text-align:left'>, miljø , korrupsjonsbekjempelse og</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012121406011?searchText=demokrati' target='_'>,Samstemt for utvikling?,2008</a></td><td>fred og forsoningsarbeid , menneskerettigheter,</td><td>demokrati</td><td style='text-align:left'>og humanitær bistand er estimert</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013041505004?searchText=demokrati' target='_'>Bekkemellem, Karita,Mitt røde hjerte,2009</a></td><td>ulike årsaker trengte grunnopplæring i</td><td>demokrati</td><td style='text-align:left'>og likestilling . I 2001</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013041505004?searchText=demokrati' target='_'>Bekkemellem, Karita,Mitt røde hjerte,2009</a></td><td>for å lære om politikk,</td><td>demokrati</td><td style='text-align:left'>, hersketeknikker , feminisme ,</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013041505004?searchText=demokrati' target='_'>Bekkemellem, Karita,Mitt røde hjerte,2009</a></td><td>far også økt likestilling og</td><td>demokrati</td><td style='text-align:left'>. Jeg vil understreke at</td></tr>
# </table>

# %% [markdown]
# # Build a specific corpus

# %%
hamsun = nb.book_urn(author = "hams%kn%", period = (1900, 1990))

# %% [markdown]
# Have a look at the data

# %%
hamsun
# Out:
# [[2012022308010, 'Hamsun, Knut', 'Samlede verker', 1976],
#  [2012010508137, 'Hamsun, Knut', 'ede verker', 1955],
#  [2011112108059, 'Hamsun, Knut', 'Pan', 1954],
#  [2007081501065, 'Hamsun, Knut', 'Schwärmer ; Vagabundentage', 1989],
#  [2011011005045, 'Hamsun, Knut', 'Samlede Verker', 1934],
#  [2011011706058, 'Hamsun, Knut', 'Samlede Verker', 1934],
#  [2014041108102, 'Hamsun, Knut', 'Samlede Verker', 1918],
#  [2014120206051, 'Hamsun, Knut', 'Landstrykere', 1927],
#  [2008090113002, 'Hamsun, Knut', 'Livets Under', 1910],
#  [2011021506002, 'Hamsun, Knut', 'Samlede Verker', 1934],
#  [2012051805119, 'Hamsun, Knut', 'Samlede romaner', 1944],
#  [2008051504040, 'Hamsun, Knut', 'Samlede verker', 1954],
#  [2012021308115, 'Hamsun, Knut', 'Livsfragmenter', 1988],
#  [2014041108101, 'Hamsun, Knut', 'Samlede Verker', 1918],
#  [2014031108009, 'Hamsun, Knut', 'Samlede Verker', 1918],
#  [2013120238049, 'Hamsun, Knut', 'Victoria', 1964],
#  [2012092408107, 'Hamsun, Knut', 'Samlede verker', 1963],
#  [2014021807151, 'Hamsun, Knut', 'Dikte', 1921],
#  [2015052808077, 'Hamsun, Knut', 'På gjengrodde stier', 1979],
#  [2013040824021, 'Hamsun, Knut', 'wilde Chor', 1926]]

# %% [markdown]
# Check for duplicates by collecting all works with the same title in a bag (dictionary):

# %%
duplicates = dict()
for meta in hamsun:
    if meta[2] in duplicates:
        duplicates[meta[2]].append(meta)
    else:
        duplicates[meta[2]] = [meta]

# %%
duplicates
# Out:
# {'Samlede verker': [[2012022308010, 'Hamsun, Knut', 'Samlede verker', 1976],
#   [2008051504040, 'Hamsun, Knut', 'Samlede verker', 1954],
#   [2012092408107, 'Hamsun, Knut', 'Samlede verker', 1963]],
#  'ede verker': [[2012010508137, 'Hamsun, Knut', 'ede verker', 1955]],
#  'Pan': [[2011112108059, 'Hamsun, Knut', 'Pan', 1954]],
#  'Schwärmer ; Vagabundentage': [[2007081501065,
#    'Hamsun, Knut',
#    'Schwärmer ; Vagabundentage',
#    1989]],
#  'Samlede Verker': [[2011011005045, 'Hamsun, Knut', 'Samlede Verker', 1934],
#   [2011011706058, 'Hamsun, Knut', 'Samlede Verker', 1934],
#   [2014041108102, 'Hamsun, Knut', 'Samlede Verker', 1918],
#   [2011021506002, 'Hamsun, Knut', 'Samlede Verker', 1934],
#   [2014041108101, 'Hamsun, Knut', 'Samlede Verker', 1918],
#   [2014031108009, 'Hamsun, Knut', 'Samlede Verker', 1918]],
#  'Landstrykere': [[2014120206051, 'Hamsun, Knut', 'Landstrykere', 1927]],
#  'Livets Under': [[2008090113002, 'Hamsun, Knut', 'Livets Under', 1910]],
#  'Samlede romaner': [[2012051805119, 'Hamsun, Knut', 'Samlede romaner', 1944]],
#  'Livsfragmenter': [[2012021308115, 'Hamsun, Knut', 'Livsfragmenter', 1988]],
#  'Victoria': [[2013120238049, 'Hamsun, Knut', 'Victoria', 1964]],
#  'Dikte': [[2014021807151, 'Hamsun, Knut', 'Dikte', 1921]],
#  'På gjengrodde stier': [[2015052808077,
#    'Hamsun, Knut',
#    'På gjengrodde stier',
#    1979]],
#  'wilde Chor': [[2013040824021, 'Hamsun, Knut', 'wilde Chor', 1926]]}

# %% [markdown]
# Sort duplicates by year, descending

# %%
for item in duplicates:
    duplicates[item].sort(key = lambda x: int(x[3]), reverse=True)

# %% [markdown]
# Display in a nice way:

# %%
for title in duplicates:
    printmd("### " + title )
    for item in duplicates[title]:
        printmd("* " + ' '.join([str(x) for x in item]))
# Out:
# ### Samlede verker
# * 2012022308010 Hamsun, Knut Samlede verker 1976
# * 2012092408107 Hamsun, Knut Samlede verker 1963
# * 2008051504040 Hamsun, Knut Samlede verker 1954
# ### ede verker
# * 2012010508137 Hamsun, Knut ede verker 1955
# ### Pan
# * 2011112108059 Hamsun, Knut Pan 1954
# ### Schwärmer ; Vagabundentage
# * 2007081501065 Hamsun, Knut Schwärmer ; Vagabundentage 1989
# ### Samlede Verker
# * 2011011005045 Hamsun, Knut Samlede Verker 1934
# * 2011011706058 Hamsun, Knut Samlede Verker 1934
# * 2011021506002 Hamsun, Knut Samlede Verker 1934
# * 2014041108102 Hamsun, Knut Samlede Verker 1918
# * 2014041108101 Hamsun, Knut Samlede Verker 1918
# * 2014031108009 Hamsun, Knut Samlede Verker 1918
# ### Landstrykere
# * 2014120206051 Hamsun, Knut Landstrykere 1927
# ### Livets Under
# * 2008090113002 Hamsun, Knut Livets Under 1910
# ### Samlede romaner
# * 2012051805119 Hamsun, Knut Samlede romaner 1944
# ### Livsfragmenter
# * 2012021308115 Hamsun, Knut Livsfragmenter 1988
# ### Victoria
# * 2013120238049 Hamsun, Knut Victoria 1964
# ### Dikte
# * 2014021807151 Hamsun, Knut Dikte 1921
# ### På gjengrodde stier
# * 2015052808077 Hamsun, Knut På gjengrodde stier 1979
# ### wilde Chor
# * 2013040824021 Hamsun, Knut wilde Chor 1926

# %% [markdown]
# Sorted by variants lets us construct a new corpus with unique works

# %%
hamsun_unique = [duplicates[item][0] for item in duplicates]

# %% [markdown]
# This selects the newest editions. Another sorting can select the first editions.

# %%
hamsun_unique
# Out:
# [[2012022308010, 'Hamsun, Knut', 'Samlede verker', 1976],
#  [2012010508137, 'Hamsun, Knut', 'ede verker', 1955],
#  [2011112108059, 'Hamsun, Knut', 'Pan', 1954],
#  [2007081501065, 'Hamsun, Knut', 'Schwärmer ; Vagabundentage', 1989],
#  [2011011005045, 'Hamsun, Knut', 'Samlede Verker', 1934],
#  [2014120206051, 'Hamsun, Knut', 'Landstrykere', 1927],
#  [2008090113002, 'Hamsun, Knut', 'Livets Under', 1910],
#  [2012051805119, 'Hamsun, Knut', 'Samlede romaner', 1944],
#  [2012021308115, 'Hamsun, Knut', 'Livsfragmenter', 1988],
#  [2013120238049, 'Hamsun, Knut', 'Victoria', 1964],
#  [2014021807151, 'Hamsun, Knut', 'Dikte', 1921],
#  [2015052808077, 'Hamsun, Knut', 'På gjengrodde stier', 1979],
#  [2013040824021, 'Hamsun, Knut', 'wilde Chor', 1926]]

# %% [markdown]
# A concordance from a defined corpus

# %%
nb.urn_concordance(word = 'elskede',urns = hamsun_unique)
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011112108059?searchText=elskede' target='_blank' style='text-decoration:none'>Pan, Hamsun, Knut, 1954</a>
#                 </td>
#                 <td>du kom i kvæld ,</td>
#                 <td>elskede</td>
#                 <td style='text-align:left'>! Jeg sat her og</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011112108059?searchText=elskede' target='_blank' style='text-decoration:none'>Pan, Hamsun, Knut, 1954</a>
#                 </td>
#                 <td>har , Eva , min</td>
#                 <td>elskede</td>
#                 <td style='text-align:left'>. Du kalder mig din</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011112108059?searchText=elskede' target='_blank' style='text-decoration:none'>Pan, Hamsun, Knut, 1954</a>
#                 </td>
#                 <td>. Du kalder mig din</td>
#                 <td>elskede</td>
#                 <td style='text-align:left'>! Jeg er en ulærd</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011112108059?searchText=elskede' target='_blank' style='text-decoration:none'>Pan, Hamsun, Knut, 1954</a>
#                 </td>
#                 <td>Eva , Eva ,</td>
#                 <td>elskede</td>
#                 <td style='text-align:left'>, du er gjort til</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011112108059?searchText=elskede' target='_blank' style='text-decoration:none'>Pan, Hamsun, Knut, 1954</a>
#                 </td>
#                 <td>be dig om noget ,</td>
#                 <td>elskede</td>
#                 <td style='text-align:left'>? Og kun svarte beruset</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011011005045?searchText=elskede' target='_blank' style='text-decoration:none'>Samlede Verker, Hamsun, Knut, 1934</a>
#                 </td>
#                 <td>For du skal beseires ,</td>
#                 <td>elskede</td>
#                 <td style='text-align:left'>Fatimat .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012021308115?searchText=elskede' target='_blank' style='text-decoration:none'>Livsfragmenter, Hamsun, Knut, 1988</a>
#                 </td>
#                 <td>kjendte først nu hvormeget jeg</td>
#                 <td>elskede</td>
#                 <td style='text-align:left'>min lille Katarina , og</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013120238049?searchText=elskede' target='_blank' style='text-decoration:none'>Victoria, Hamsun, Knut, 1964</a>
#                 </td>
#                 <td>jeg gikk igjen med min</td>
#                 <td>elskede</td>
#                 <td style='text-align:left'>på gaten og alle vendte</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013120238049?searchText=elskede' target='_blank' style='text-decoration:none'>Victoria, Hamsun, Knut, 1964</a>
#                 </td>
#                 <td>efter henne , efter min</td>
#                 <td>elskede</td>
#                 <td style='text-align:left'>, for hun er så</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013120238049?searchText=elskede' target='_blank' style='text-decoration:none'>Victoria, Hamsun, Knut, 1964</a>
#                 </td>
#                 <td>du min brudgom , min</td>
#                 <td>elskede</td>
#                 <td style='text-align:left'>! stammer den gamle kvinne</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013120238049?searchText=elskede' target='_blank' style='text-decoration:none'>Victoria, Hamsun, Knut, 1964</a>
#                 </td>
#                 <td>evne , minnene om hennes</td>
#                 <td>elskede</td>
#                 <td style='text-align:left'>stormer inn på henne og</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013120238049?searchText=elskede' target='_blank' style='text-decoration:none'>Victoria, Hamsun, Knut, 1964</a>
#                 </td>
#                 <td>kjære venn , min eneste</td>
#                 <td>elskede</td>
#                 <td style='text-align:left'>på jorden , kom til</td>
#             </tr>
# </table>

# %% [markdown]
# # Keywords within a corpus
#
# Here we go about finding keywords in a corpus. First, build a corpus as a collection of URNs.

# %% [markdown]
# Define a corpus using metadata, like Deweys decimal system. [Webdewey](http://deweysearchno.pansoft.de/webdeweysearch/index.html) is good for that.

# %%
korpus = nb.book_corpus(ddk="355%", limit = 200, period = (1980, 2000))

# %%
len(korpus)
# Out:
# 200

# %%
korpus
# Out:
#                urn                author  \
# 0    2007080304004          Enholm, Kari
# 1    2015070209075  Skogan, John Kristen
# 2    2008121504100        Njølstad, Olav
# 3    2011042605100
# 4    2014111438083    Frøysnes, Torbjørn
# ..             ...                   ...
# 195  2007091104011
# 196  2008012404041
# 197  2008082700097
# 198  2012081508240      Huitfeldt, Tønne
# 199  2008091604066       Solheim, Jan A.
#
#                                       title  year
# 0                               Bak fasaden  1987
# 1                   NATO's 1. bruksdoktrine  1982
# 2                        Kunnskap som våpen  1997
# 3    Rapport fra en studiereise til Brussel  1986
# 4                   NATOs militære strategi  1985
# ..                                      ...   ...
# 195           Hæren etter Annen verdenskrig  1990
# 196                      Tysklandsbrigadane  1994
# 197      Materiellforvaltningen i Forsvaret  1999
# 198      NATOs forsvarsstrategi i søkelyset  1985
# 199                 Muntre militærhistorier  1998
#
# [200 rows x 4 columns]

# %% [markdown]
# One possibibility is the grand total of all words

# %%
totalen = nb.frame(nb.totals(25000))
totalen.head()
# Out:
#               0
# .    1265723110
# ,    1105303412
# og    543432056
# i     460246057
# det   273411583

# %% [markdown]
# Normalize to make computations easier to follow.

# %%
nb.normalize_corpus_dataframe(totalen)
# Out:
# True

# %% [markdown]
# Now the numbers are expressed as percentages

# %%
totalen.head()
# Out:
#             0
# .    0.061280
# ,    0.053513
# og   0.026310
# i    0.022283
# det  0.013237

# %% [markdown]
# We aggregate the corpus and normalize. Actually, we normalize, and aggregate as means

# %%
nb.normalize_corpus_dataframe(corpus_text)
# Out:
# True

# %%
corpus_agg = corpus_text.mean(axis=1)

# %%
corpus_agg = nb.frame(corpus_agg).sort_values(by=0, ascending=False)

# %%
corpus_agg.head()
# Out:
#            0
# .   0.044667
# ,   0.034955
# og  0.024881
# i   0.024251
# av  0.014073

# %%
corpus_keywords = nb.frame(corpus_agg[0]**1/totalen[0]).sort_values(by=0, ascending=False )

# %%
corpus_keywords.head(20)
# Out:
#                          0
# Forsvaret       133.419649
# Forsvarets      119.641575
# NATO             96.804308
# Hæren            83.082395
# befal            80.770156
# military         44.302440
# forsvaret        40.572240
# operative        36.393732
# operasjoner      35.863696
# militære         35.194388
# militært         34.904671
# Afghanistan      34.563758
# sivile           33.333227
# styrker          33.222400
# militær          32.366365
# konvensjonelle   32.242374
# nuclear          29.960261
# Forsvar          29.547188
# styrkene         29.306614
# IR               26.675253

# %%
nb.cloud(corpus_keywords.head(150)/corpus_keywords.head(150).sum())

# %% [markdown]
# # Collocations

# %% [markdown]
# A collocation is like a concordance, but we don't see the actual sequence. We just collect the words in the context and tally up.

# %%
coll = nb.urn_coll('kaffe', urns = korpus, before = 5, after = 5)

# %%
coll.sort_values(by=0, ascending=False).head(20)
# Out:
#           0
# ,       119
# og      106
# .        95
# en       38
# med      33
# i        28
# på       26
# av       20
# til      19
# kopp     17
# ble      13
# drakk    12
# kaker    11
# sukker   11
# te       11
# hadde    11
# for      11
# var      11
# det      11
# å        10

# %% [markdown]
# Formally a collocation is just a bag of words, just like the corpus itself after aggregation. So the method is the same.

# %%
diff = (coll**1.01/totalen).sort_values(by=0, ascending = False)

# %%
diff.head(20)
# Out:
#                         0
# kaker        1.632112e+06
# kopp         1.200036e+06
# kruset       1.080636e+06
# kakao        7.348360e+05
# syltetøy     7.169771e+05
# flesk        6.510725e+05
# smørbrød     5.955340e+05
# pølser       5.916292e+05
# spises       5.741141e+05
# søndagen     5.264826e+05
# drukket      4.530496e+05
# drakk        4.253078e+05
# potetene     4.197887e+05
# sigaretter   4.123645e+05
# servert      4.068209e+05
# skuespillet  3.964903e+05
# Tonen        3.934016e+05
# avskaffet    3.898744e+05
# tigge        3.839961e+05
# bordene      3.822854e+05

# %%
nb.cloud(diff[:100]/diff[:100].sum())

# %%
coll2 = nb.urn_coll('offiser', urns = korpus, before = 5, after = 5)

# %%
coll2.sort_values(by=0, ascending=False).head(20)
# Out:
#        0
# .    544
# ,    509
# en   499
# som  352
# i    295
# og   265
# til  159
# var  154
# av   139
# med  135
# å    122
# for  111
# at   109
# er   100
# )     94
# på    87
# (     83
# den   77
# ved   76
# -     72

# %% [markdown]
# Formally a collocation is just a bag of words, just like the corpus itself after aggregation. So the method is the same.

# %%
diff2 = (coll2**1.01/totalen).sort_values(by=0, ascending = False)

# %%
diff2.head(20)
# Out:
#                       0
# officer    1.559683e+07
# offiser    3.125723e+06
# Hæren      2.996764e+06
# stab       2.977661e+06
# beordret   2.912107e+06
# mar        2.436393e+06
# tropp      2.319839e+06
# sersjant   1.751449e+06
# duty       1.715785e+06
# sivil      1.632878e+06
# erfaren    1.629418e+06
# jurist     1.552583e+06
# soldat     1.511608e+06
# Forsvaret  1.443382e+06
# sl         1.353763e+06
# dyktig     1.334488e+06
# am         1.305488e+06
# sjef       1.195075e+06
# lojal      1.185834e+06
# løytnant   1.110826e+06

# %%
nb.cloud(diff2[:100]/diff2[:100].sum())

# %% [markdown]
# # Combining graphs and collocations

# %% [markdown]
# First we make a collocation out of the 100 top words for our dewey set.

# %% [markdown]
# ## Wildcardsearch

# %%
nb.sorted_wildcardsearch({
    'word':'al*ays', 
    'factor':4, 
    'freq_lim':50, 
    'limit':100
})
# Out:
#            al*ays
# always     280944
# alvvays       399
# allways       357
# alvays        253
# al-ways       125
# alleyways     119
# alivays        74
# al-Qays        63
# aluays         57
