# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
mu.update('mods_meta')
import mods_meta as mm
mu.update('collocations')
import collocations as coll
import pandas as pd
# Out:
# Updated file `D:\Documents\GitHub\Miscellaneous-Notebooks\Barn_kropp_Uri\mods_meta.py`
# Updated file `D:\Documents\GitHub\Miscellaneous-Notebooks\Barn_kropp_Uri\collocations.py`

# %%
from random import choice, random, sample

# %% [markdown]
# # Lager korpus - adult and children

# %%
kroppsord = """håret nesen munnen tungen leppen leppene kinnet hjernen hjertet lungene
neglene neglen hendene øynene øyet øyenvippene øyenbrynene ansiktet pannen hodet halsen nakken skulderen skuldrene magen brystet brystene
fingrene tommelen ankelen foten tærne tåen tåa rumpa låret lårene leggene leggen knærne kneet armen hånden albuen fingeren fingrene
lemmet kjønnet grotten skjødet kuken fitta haken kjeven kjevene""".split()

# %%
children_corpus = mm.meta_natbib(children=True, yearfrom=2010, yearto=2020, limit=100000)

# %%
adult_corpus = mm.meta_natbib(children = False, yearfrom = 2010, yearto = 2020, limit = 100000 )

# %%
a_sample = sample(adult_corpus, 1500)

# %%
c_sample = sample(children_corpus, 1500)

# %%
c_meta = mm.metadata([x[1] for x in c_sample])

# %%
a_meta = mm.metadata([x[1] for x in a_sample])

# %%
nb.frame(c_meta).index
# Out:
# Index(['2011011203003', '2011021603045', '2011022203037', '2011040806087',
#        '2011040806130', '2011041305036', '2011041306074', '2011041306081',
#        '2011060905008', '2011090506099',
#        ...
#        '2018100807007', '2018101007162', '2018101007333', '2018101007334',
#        '2018101205008', '2018110607189', '2018120777022', '2019011448523',
#        '2019052107177', '2019072307161'],
#       dtype='object', length=1496)

# %%
from time import time

# %%
def coll(w, corpus, before = 3, after = 3, step = 500):
    return pd.concat([nb.urn_coll(w, urns = corpus[i:i+step], after = after, before= before) for i in range(0, len(corpus), step)], sort=False, axis = 1).sum(axis=1)

def make_colls(urns, kroppsord, after = 1, before = 0):
    t = time()
    colls_bigram = dict()
    step = 50
    for w in  kroppsord:
            #print(w)
            colls_bigram[w] = coll(w, corpus = urns, after = 1, before= 0, step = step) 
            #print(time() - t)
            t = time()
    return colls_bigram

# %%
c0 = make_colls(list(nb.frame(c_meta).index), kroppsord)

# %%
nb.frame(c0)[['hans','hennes']].sort_values(by='hennes',ascending=False).style.background_gradient(axis=1)
# Out:
# D:\Anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row2_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row4_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row5_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row6_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row7_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row7_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row8_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row8_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row9_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row10_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row10_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row11_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row11_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row12_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row12_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row13_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row13_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row14_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row14_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row15_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row15_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row16_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row16_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row17_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row17_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row18_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row18_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row19_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row19_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row20_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row20_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row21_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row21_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row22_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row22_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row23_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row23_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row24_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row24_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row25_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row25_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row26_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row26_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row27_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row27_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row28_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row28_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row29_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_66ac2f40_9f8a_11ea_be1c_000acd2bfab2row29_col1 {
#             background-color:  #

# %%
c1 = make_colls(list(nb.frame(a_meta).index), kroppsord)

# %%
nb.frame(c1)[['hans','hennes']].sort_values(by='hennes',ascending=False).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row2_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row4_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row5_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row6_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row7_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row7_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row8_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row8_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row9_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row10_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row10_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row11_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row11_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row12_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row12_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row13_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row13_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row14_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row14_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row15_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row15_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row16_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row16_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row17_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row17_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row18_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row18_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row19_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row19_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row20_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row20_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row21_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row21_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row22_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row22_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row23_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row23_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row24_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row24_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row25_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row25_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row26_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row26_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row27_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row27_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row28_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row28_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row29_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5dfea5d2_9f8d_11ea_83f1_000acd2bfab2row29_col1 {
#             background-color:  #

# %%
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-2b66fd261ee5> in <module>
# ----> 1 c
#
# NameError: name 'c' is not defined
