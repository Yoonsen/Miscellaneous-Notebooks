# %%
import sys
sys.path.append('../DHLAB')
import dhlab.nbtext as nb

# %%
from dhlab.nbtokenizer import tokenize

# %%
import api.dhlap_api as ap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-1217959f47af> in <module>
# ----> 1 import api.dhlap_api as ap
#
# ModuleNotFoundError: No module named 'api'

# %%
tokenize("det her er en bil")
# Out:
# ['det', 'her', 'er', 'en', 'bil']

# %%
import os

# %%
list(os.walk("../DHLAB"))
# Out:
# [('../DHLAB',
#   ['.git', 'dhlab'],
#   ['LICENSE.txt', 'README.md', 'setup.py', '__init__.py']),
#  ('../DHLAB\\.git',
#   ['hooks', 'info', 'logs', 'objects', 'refs'],
#   ['COMMIT_EDITMSG',
#    'config',
#    'description',
#    'FETCH_HEAD',
#    'HEAD',
#    'index',
#    'packed-refs']),
#  ('../DHLAB\\.git\\hooks',
#   [],
#   ['applypatch-msg.sample',
#    'commit-msg.sample',
#    'fsmonitor-watchman.sample',
#    'post-update.sample',
#    'pre-applypatch.sample',
#    'pre-commit.sample',
#    'pre-merge-commit.sample',
#    'pre-push.sample',
#    'pre-rebase.sample',
#    'pre-receive.sample',
#    'prepare-commit-msg.sample',
#    'push-to-checkout.sample',
#    'update.sample']),
#  ('../DHLAB\\.git\\info', [], ['exclude']),
#  ('../DHLAB\\.git\\logs', ['refs'], ['HEAD']),
#  ('../DHLAB\\.git\\logs\\refs', ['heads', 'remotes'], []),
#  ('../DHLAB\\.git\\logs\\refs\\heads', [], ['main', 'refactor']),
#  ('../DHLAB\\.git\\logs\\refs\\remotes', ['origin'], []),
# ...
