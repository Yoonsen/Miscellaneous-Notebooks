# %% [markdown]
# # Språkbankseminar

# %%
import dhlab.module_update as mu
mu.update('dhlab_v2', silent = True)
import dhlab_v2 as d2
mu.css("css.css")
# Out:
# <style>p {
#     font-size:1.2em;
#     color : #223355;
# }
# h1, h2, h3, h4, h5, h6 {
#     color:#3344aa;
# }
# html {
#     margin-left:10%;
#     margin-right:5%;
# }
#
# body {
#     counter-reset: h2counter;
# }
# h1 {
#     counter-reset: h2counter;
# }
# h2:before {
#     content: counter(h2counter) ".\0000a0\0000a0";
#     counter-increment: h2counter;
#     counter-reset: h3counter;
# }
# h3:before {
#     content: counter(h2counter) "." counter(h3counter) ".\0000a0\0000a0";
#     counter-increment: h3counter;
# }
# </style>

# %%
# %%HTML
# <style>
# .dataframe th {
#     font-size: 18px;
# }
# .dataframe td {
#     font-size: 28px;
# }
# </style>
# Out:
# <style>
# .dataframe th {
#     font-size: 18px;
# }
# .dataframe td {
#     font-size: 28px;
# }
# </style>

# %% [markdown]
# # DH-lab

# %%
from IPython.display import Image
Image(filename="./illustrations/dhlab.jpeg")

# %% [markdown]
# # Stack

# %%
from IPython.display import Image
Image(filename="./illustrations/Stack-web.jpeg")

# %% [markdown]
# # Bygg en bok-kolleksjon (korpus)
#
# En strømlinjeformet metadata. I tråd med det som er på nb.no

# %%
corpus = d2.document_corpus(doctype='digibok', ddk = "641", from_year = 1990, to_year = 2000, limit = 10000)

# %%
corpus.head(5).style
# Out:
# <style  type="text/css" >
# </style><table id="T_de7a93cb_1602_11ec_ac9d_a0a4c554f2a3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >urn</th>        <th class="col_heading level0 col1" >author</th>        <th class="col_heading level0 col2" >title</th>        <th class="col_heading level0 col3" >year</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_de7a93cb_1602_11ec_ac9d_a0a4c554f2a3level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_de7a93cb_1602_11ec_ac9d_a0a4c554f2a3row0_col0" class="data row0 col0" >URN:NBN:no-nb_digibok_2014052308060</td>
#                         <td id="T_de7a93cb_1602_11ec_ac9d_a0a4c554f2a3row0_col1" class="data row0 col1" ></td>
#                         <td id="T_de7a93cb_1602_11ec_ac9d_a0a4c554f2a3row0_col2" class="data row0 col2" >Tradisjonsmat fra nord. 4 : 116 matoppskrifter, gode råd og mathistorie</td>
# ...

# %%
d2.concordance(urns = list(corpus.urn), words="NEAR(salt pepper mel)").head(5).style
# Out:
# <style  type="text/css" >
# </style><table id="T_f58104da_1602_11ec_9bbe_a0a4c554f2a3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >docid</th>        <th class="col_heading level0 col1" >urn</th>        <th class="col_heading level0 col2" >conc</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f58104da_1602_11ec_9bbe_a0a4c554f2a3level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f58104da_1602_11ec_9bbe_a0a4c554f2a3row0_col0" class="data row0 col0" >100090922</td>
#                         <td id="T_f58104da_1602_11ec_9bbe_a0a4c554f2a3row0_col1" class="data row0 col1" >URN:NBN:no-nb_digibok_2012071638006</td>
# ...

# %% [markdown]
# ### Copyright

# %% [markdown]
# Se på copyright og størrelse på tekstutdrag - for eksempel avsnitt (inntill 100 ord)

# %% [markdown]
# ## N-gram

# %%
from IPython.display import Image
Image(filename="./illustrations/kongen_aviser.PNG")
