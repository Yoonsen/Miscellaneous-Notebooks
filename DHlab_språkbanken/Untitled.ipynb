# %%
import dhlab.module_update as mu
mu.update('dhlab_v2')
import dhlab_v2 as d2
# Out:
# Updated file `C:\Users\larsj\Documents\GitHub\Miscellaneous-Notebooks\DHlab_språkbanken\dhlab_v2.py`

# %%
corpus = d2.document_corpus(author = "Bjørnstjerne bjørnson")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-19-ad7e3b009fb0> in <module>
# ----> 1 corpus = d2.document_corpus(author = "Bjørnstjerne bjørnson")
#
# ~\Documents\GitHub\Miscellaneous-Notebooks\DHlab_språkbanken\dhlab_v2.py in document_corpus(doctype, author, from_year, to_year, from_timestamp, to_timestamp, title, ddk, subject, lang, limit)
#     213
#     214
# --> 215     return pd.DataFrame(r.json())
#     216
#     217
#
# ~\Anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
# ...

# %%
corpus
# Out:
#                                    urn  \
# 0  URN:NBN:no-nb_digibok_2016060348129
# 1  URN:NBN:no-nb_digibok_2008011503001
# 2  URN:NBN:no-nb_digibok_2012060605066
# 3  URN:NBN:no-nb_digibok_2009062204063
# 4  URN:NBN:no-nb_digibok_2012011906033
# 5  URN:NBN:no-nb_digibok_2017062068128
# 6  URN:NBN:no-nb_digibok_2009062204013
# 7  URN:NBN:no-nb_digibok_2015042908174
# 8  URN:NBN:no-nb_digibok_2016042109531
# 9  URN:NBN:no-nb_digibok_2013040824024
#
#                                                title  \
# 0                                  Synnöve Solbakken
# 1                    Halte-Hulda : drama i tre akter
# 2                                  Samlede værker. 2
# 3                          En glad gutt : fortelling
# 4                    Samlede værker : mindeutgave. 1
# 5  Ved Bjørnstjerne Bjørnsons begravelse tirsdag ...
# 6                                  Synnøve Solbakken
# 7  Fragmenter av Bjørnstjerne Bjørnsons Arnljot G...
# ...

# %%
book = "URN:NBN:no-nb_digibok_2016110248023"

# %%
words = d2.get_document_frequencies(urns=list(corpus.urn))

# %%
word_list = list(words.index)

# %% [markdown]
# # group by common prefix - if prefix exists as word

# %%
groups = dict()
i = 0
for common in word_list:
    paradigm = [w for w in word_list if w.startswith(common) and common != w]
    i += 1
    if i % 1000 == 0:
        print(paradigm, i)
    if paradigm != []:
        groups[common] =  paradigm
# Out:
# [] 1000
# [] 2000
# [] 3000
# [] 4000
# [] 5000
# ['Ranket'] 6000
# [] 7000
# ['forsømmes'] 8000
# [] 9000
# [] 10000
# [] 11000
# [] 12000
# [] 13000
# ['dampskibene', 'dampskibet', 'dampskibsselskaper', 'dampskibe', 'dampskibsrøken', 'dampskibsselskaber'] 14000
# [] 15000
# [] 16000
# [] 17000
# ['deia', 'deim', 'deiligt', 'deier', 'deilig', 'deilige'] 18000
# [] 19000
# [] 20000
# [] 21000
# [] 22000
# ['tusmørkets'] 23000
# ['ødter'] 24000
# [] 25000
# [] 26000
# [] 27000
# [] 28000
# [] 29000
# ['fuigte', 'fuigct', 'fuiitøanbclu', 'fuittc'] 30000
# [] 31000
# [] 32000
# ['ovvatf'] 33000
# [] 34000
# ['Slbenbd'] 35000
# [] 36000
# [] 37000
# [] 38000
# [] 39000
# [] 40000
# [] 41000
# [] 42000
# [] 43000
# [] 44000

# %%
groups['ovvat']
# Out:
# ['ovvatf']
