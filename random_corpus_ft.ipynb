# %% [markdown]
# # Fetch concordances and analyze them
#
# Lars G. Johnsen, National Library of Norway
#
# lars.johnsen@nb.no
#
# Solstrand june 2021

# %% [markdown]
# ### Initial code

# %%
import json
import pandas as pd
import requests
import spacy
from dhlab.module_update import css

def search_nb(word = 'demokrati', window=20, limit = 300):
    parameters = {
        'query': word,
        'window':window,
        'limit':limit
    }
    r = requests.get("https://api.nb.no/ngram/db1/konk", params = parameters)
    return pd.DataFrame(json.loads(r.text), columns = 'doc-id concordance'.split())

# %%
import spacy

nlp = spacy.load("nb_core_news_sm")

# %%
def parse(string):
    cols = "token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop".split(', ')
    doc = nlp(string)
    rows = [(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop) for token in doc]
    return pd.DataFrame(rows, columns = cols), doc

# %%
pd.set_option('max_colwidth', None)
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Merriweather|Shippori+Mincho|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Shippori+Mincho';
# 	font-size:1.1em;
# 	color: DarkSlateGray;
# }
#
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
#
#
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# # Concordances
#
# A random collection of newspapers, periodicals and/or books are created on each query. Use SQLite fts5 syntax in formulating search https://www2.sqlite.org/fts5.html

# %%
df = search_nb(""" "boken han" """, limit = 200)
df.style
# Out:
# <style  type="text/css" >
# </style><table id="T_9c6e1_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >doc-id</th>        <th class="col_heading level0 col1" >concordance</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9c6e1_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9c6e1_row0_col0" class="data row0 col0" >100200065</td>
#                         <td id="T_9c6e1_row0_col1" class="data row0 col1" >... forhindret ham i å få noen mening ut av <b>boken han</b> lå og leste i , - så kan vi ligge litt... </td>
#             </tr>
#             <tr>
#                         <th id="T_9c6e1_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9c6e1_row1_col0" class="data row1 col0" >100122276</td>
#                         <td id="T_9c6e1_row1_col1" class="data row1 col1" >... I mangel av bedre råd åpnet han derfor <b>boken han</b> bar på og begynte å deklamere .</td>
#             </tr>
#             <tr>
#                         <th id="T_9c6e1_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9c6e1_row2_col0" class="data row2 col0" >100122276</td>
#                         <td id="T_9c6e1_row2_col1" class="data row2 col1" >Andreas så opp fra <b>boken . Han</b> hadde fått besøk - av pater Leo , på vei til eller fra et eller annet .</td>
#             </tr>
#             <tr>
#                         <th id="T_9c6e1_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9c6e1_row3_col0" class="data row3 col0" >100242714</td>
#                         <td id="T_9c6e1_row3_col1" class="data row3 col1" >... det var som de meldte sig i logisk rekkefolge , og føiet sig villig inn i <b>boken han</b> holdt på med.</td>
#             </tr>
#             <tr>
#                         <th id="T_9c6e1_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9c6e1_row4_col0" class="data row4 col0" >100081702</td>
#                         <td id="T_9c6e1_row4_col1" class="data row4 col1" >... Han forteller Irakli om <b>boken han</b> leser . Han</td>
#             </tr>
#             <tr>
#                         <th id="T_9c6e1_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_9c6e1_row5_col0" class="data row5 col0" >100081702</td>
#                         <td id="T_9c6e1_row5_col1" class="data row5 col1" >Irakli åpnet <b>boken . Han</b> leste ett dikt , så lukket han boken og la hånden på permen . Han så opp i... </td>
#             </tr>
#             <tr>
#                         <th id="T_9c6e1_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_9c6e1_row6_col0" class="data row6 col0" >100064151</td>
#                         <td id="T_9c6e1_row6_col1" class="data row6 col1" >... Borges ble derfor dobbelt overrasket over å oppdage at <b>boken han</b> hadde begynt å lese , var skrevet på et språk... </td>
#             </tr>
#             <tr>
#                         <th id="T_9c6e1_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_9c6e1_row7_col0" class="data row7 col0" >100162420</td>
#                         <td id="T_9c6e1_row7_col1" class="data row7 col1" >... som nok er opphavsmann for mange av vendingene i denne <b>boken . Han</b> vet mer om digitalt fjernsyn enn noen andre .</td>
#             </tr>
#             <tr>
#                         <th id="T_9c6e1_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_9c6e1_row8_col0" class="data row8 col0" >100540465</td>
#                         <td id="T_9c6e1_row8_col1" class="data row8 col1" >... Hovmesteren går bort til podiet og studerer <b>boken . Han</b> får en telefon og legger på igjen etter få sekunder , deretter... </td>
#             </tr>
#             <tr>
#                         <th id="T_9c6e1_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_9c6e1_row9_col0" class="data row9 col0" >100422335</td>
#                         <td id="T_9c6e1_row9_col1" class="data row9 col1" >... Der på nattbordet hans sto fotografiet av henne seiv i sin smale bronseramme , der lå den siste <b>boken han</b> hadde... </td>
#             </tr>
#             <tr>
#                         <th id="T_9c6e1_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_9c6e1_row10_col0" class="data row10 col0" >100422965</td>
#                         <td id="T_9c6e1_row10_col1" class="data row10 col1" >... Ferdinand hadde også løftet blikket fra <b>boken . Han</b> tittet nysgjerrig først på henne , så søsteren .</td>
#             </tr>
#             <tr>
#                         <th id="T_9c6e1_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_9c6e1_row11_col0" class="data row11 col0" >100461162</td>
#                         <td id="T_9c6e1_row11_col1" class="data row11 col1" >... Samuel Johnson raste over <b>boken , han</b> reiste endog til det skotske høiland for å vise at det hele var humbug... </td>
#             </tr>
#             <tr>
#                         <th id="T_9c6e1_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_9c6e1_row12_col0" class="data row12 col0" >100461162</td>
#                         <td id="T_9c6e1_row12_col1" class="data row12 col1" >... Han viser Frollo lesende i sin bok , den nye trykte bok , Kanß sinn er delt mellem kirken og <b>boken , han</b>... </td>
#             </tr>
#             <tr>
#                         <th id="T_9c6e1_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_9c6e1_row13_col0" class="data row13 col0" >100520549</td>
#                         <td id="T_9c6e1_row13_col1" class="data row13 col1" >... Det var ikke så farlig med den som skrev <b>boken , han</b> kunne godt være übarbert . Jeg kjente meg litt fra... </td>
#             </tr>
#             <tr>
#                         <th id="T_9c6e1_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_9c6e1_row14_col0" class="data row14 col0" >100522673</td>
#                         <td id="T_9c6e1_row14_col1" class="data row14 col1" >Jeg vil spesielt takke professor Henry Valen for mange nyttige og interessante diskusjoner både før og under arbeidet med <b>boken</b>... </td>
#             </tr>
#             <tr>
#                         <th id="T_9c6e1_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_9c6e1_row15_col0" class="data row15 col0" >100494457</td>
#                         <td id="T_9c6e1_row15_col1" class="data row15 col1" >... Og hvorfor var det bare den tredje delen av <b>boken han</b> hadde gjemt her ? Hvorfor hadde Cullie stjålet disse spesielle... </td>
#             </tr>
#             <tr>
#                         <th id="T_9c6e1_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_9c6e1_row16_col0" class="data row16 col0" >200006252</td>
#                         <td id="T_9c6e1_row16_col1" class="data row16 col1" >... Sjefen for hæren har ellers visse innvendinger mot <b>boken . Han</b> har nå sått i gang arbeidet med et reglement i... </td>
#             </tr>
#             <tr>
#                         <th id="T_9c6e1_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_9c6e1_row17_col0" class="data row17 col0" >200350174</td>
#                         <td id="T_9c6e1_row17_col1" class="data row17 col1" >... Vi har alle våre ulike sider , men med tanke på <b>boken han</b> nå har gitt ut , vet jeg ikke om... </td>
#             </tr>
#             <tr>
#                         <th id="T_9c6e1_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_9c6e1_row18_col0" class="data row18 col0" >200088979</td>
#                         <td id="T_9c6e1_row18_co

# %% [markdown]
# # Parse using Spacy

# %% [markdown]
# ## Collect all the concordances
#
# These are all contained in the variable `df`
#
# The function parse returns the parse as a data frame or as a spacy doc

# %%
# remove the phrase markers and parse the sentences

parses = [parse(s.replace("<b>", "").replace("</b>","")) for s in df['concordance']]

df_versions = [p[0] for p in parses]
spacy_docs = [p[1] for p in parses]

# %%
df_parses = pd.concat(df_versions)
df_parses
# Out:
#       token.text  token.lemma_ token.pos_ token.tag_ token.dep_ token.shape_  \
# 0            ...           ...      PUNCT      PUNCT       ROOT          ...
# 1             Og            og      CCONJ      CCONJ         cc           Xx
# 2        hvordan       hvordan        ADV        ADV     advmod         xxxx
# 3            går          gåre       VERB       VERB       ROOT          xxx
# 4            det           det       PRON       PRON       expl          xxx
# ..           ...           ...        ...        ...        ...          ...
# 18          bred          bred        ADJ        ADJ       amod         xxxx
# 19  fremstilling  fremstilling       NOUN       NOUN        obj         xxxx
# 20            av            av        ADP        ADP       case           xx
# 21  sydafrikansk  sydafrikansk        ADJ        ADJ       nmod         xxxx
# 22           ...           ...      PUNCT      PUNCT      punct          ...
#
#     token.is_alpha  token.is_stop
# 0            False          False
# 1             True           True
# 2             True           True
# 3             True           True
# 4             True           True
# ..             ...            ...
# 18            True          False
# 19            True          False
# 20            True           True
# 21            True          False
# 22           False          False
#
# [2654 rows x 8 columns]

# %% [markdown]
# ## Check out frequency of some tags

# %%
df_parses.groupby("token.pos_").count()['token.text'].sort_values(ascending=False)
# Out:
# token.pos_
# PUNCT    465
# NOUN     398
# PRON     331
# VERB     326
# ADP      288
# ADJ      171
# DET      131
# AUX      129
# PROPN    124
# SCONJ     76
# CCONJ     75
# ADV       60
# PART      41
# NUM       25
# X          9
# INTJ       4
# SYM        1
# Name: token.text, dtype: int64

# %%
df_parses.groupby("token.dep_").count()['token.text'].sort_values(ascending=False)
# Out:
# token.dep_
# punct           410
# nsubj           306
# ROOT            288
# case            243
# obl             168
# obj             130
# advmod          123
# nmod            117
# det             115
# conj             90
# mark             84
# aux              76
# amod             72
# cc               70
# acl:relcl        60
# cop              52
# compound:prt     34
# flat:name        34
# advcl            29
# xcomp            28
# dep              21
# expl             20
# ccomp            19
# nummod           15
# acl              13
# iobj              8
# parataxis         8
# appos             7
# csubj             3
# compound          3
# discourse         2
# nsubj:pass        2
# flat:foreign      1
# aux:pass          1
# orphan            1
# acl:cleft         1
# Name: token.text, dtype: int64

# %% [markdown]
# ## Which words are in certain relations?
#
# Searching using standard pandas expressions

# %%
df_parses[df_parses['token.dep_'] == 'nsubj'].groupby('token.text').count()['token.lemma_'].sort_values(ascending=False).head(20)
# Out:
# token.text
# han         93
# Han         57
# jeg         10
# som          8
# boken        7
# Det          5
# Hun          4
# De           4
# du           3
# Jeg          3
# det          2
# John         2
# ham          2
# man          2
# mange        2
# alle         2
# den          2
# Boken        2
# vi           2
# tiltalte     2
# Name: token.lemma_, dtype: int64

# %% [markdown]
# # Se på et tre

# %%
df.concordance[6]
# Out:
# '... Han hadde begynt å lese i Nestors bok , den eneste <b>boken han</b> noensinne hadde sett Nestor lese i . Da Cesar... '

# %%
spacy.displacy.render(spacy_docs[6])
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="nb" id="c224b7a3d49d4ec9a73a4445343448e4-0" class="displacy" width="3725" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">...</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Han</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">hadde</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">begynt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">å</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">lese</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">i</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Nestors</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">bok ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">den</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">eneste</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">boken</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">han</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">noensinne</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">hadde</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">sett</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Nestor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">lese</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">i .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">Da</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">Cesar...</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c224b7a3d49d4ec9a73a4445343448e4-0-0" stroke-width="2px" d="M245,439.5 C245,264.5 560.0,264.5 560.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c224b7a3d49d4ec9a73a4445343448e4-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,441.5 L237,429.5 253,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c224b7a3d49d4ec9a73a4445343448e4-0-1" stroke-width="2px" d="M420,439.5 C420,352.0 555.0,352.0 555.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c224b7a3d49d4ec9a73a4445343448e4-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,441.5 L412,429.5 428,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c224b7a3d49d4ec9a73a4445343448e4-0-2" stroke-width="2px" d="M770,439.5 C770,352.0 905.0,352.0 905.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c224b7a3d49d4ec9a73a4445343448e4-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,441.5 L762,429.5 778,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c224b7a3d49d4ec9a73a4445343448e4-0-3" stroke-width="2px" d="M595,439.5 C595,264.5 910.0,264.5 910.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c224b7a3d49d4ec9a73a4445343448e4-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M910.0,441.5 L918.0,429.5 902.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c224b7a3d49d4ec9a73a4445343448e4-0-4" stroke-width="2px" d="M1120,439.
