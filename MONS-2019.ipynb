# %%
import dhlab.nbtext as nb
import dhlab.graph_networkx_louvain as gnl
import dhlab.module_update as mu

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22, 'figure.figsize':(14,7), 'lines.linewidth': 6})

# %%
#plt.rcParams.keys()

# %%
nb.nb_ngram("* åpen munn").plot()

# %%
nb.nb_ngram("et slu", smooth=1, mode='abs', corpus='bok').sum()
# Out:
# et slu    278.0
# dtype: float64

# %%
nb.concordance(word='slu', size=50, corpus='bok')
# Out:
# <table><tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013100306069?searchText=slu' target='_'>Cussler, Clive,Dødelig vind,2012</a></td><td>nye sjefen for NUMA var</td><td>slu</td><td style='text-align:left'>og benyttet anledningen til å</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013041608118?searchText=slu' target='_'>Storm, Omar,Mannen med de tusen ansikter,1977</a></td><td>. Det visste nok den</td><td>slu</td><td style='text-align:left'>Farr også . Det var</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013041608118?searchText=slu' target='_'>Storm, Omar,Mannen med de tusen ansikter,1977</a></td><td>gods . Det var en</td><td>slu</td><td style='text-align:left'>gammel rev , denne Halte-Frantz</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013041608118?searchText=slu' target='_'>Storm, Omar,Mannen med de tusen ansikter,1977</a></td><td>viste det seg at den</td><td>slu</td><td style='text-align:left'>Farr igjen hadde gitt en</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013041608118?searchText=slu' target='_'>Storm, Omar,Mannen med de tusen ansikter,1977</a></td><td>GRIBB VISST hvor enkelt den</td><td>slu</td><td style='text-align:left'>Simon Farr hadde sikret seg</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013041608118?searchText=slu' target='_'>Storm, Omar,Mannen med de tusen ansikter,1977</a></td><td>Med</td><td>slu</td><td style='text-align:left'>beregning hadde han forutsett også</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013041608118?searchText=slu' target='_'>Storm, Omar,Mannen med de tusen ansikter,1977</a></td><td>kom seg vekk ved sin</td><td>slu</td><td style='text-align:left'>forslagenhet og sin frekke kaldblodighet</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009092804078?searchText=slu' target='_'>,Faktum leksikon,1995</a></td><td>1825 ) tsar 1801 ,</td><td>slu</td><td style='text-align:left'>None</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009092804078?searchText=slu' target='_'>,Faktum leksikon,1995</a></td><td>pjerrot [ - å ]</td><td>slu</td><td style='text-align:left'>og komisk tjenertype i Pitt</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009092804078?searchText=slu' target='_'>,Faktum leksikon,1995</a></td><td>, it . Scapino ,</td><td>slu</td><td style='text-align:left'>og beregnende tjener i commedia</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007020801059?searchText=slu' target='_'>Christiansen, Sigurd,Samlede verker,1949</a></td><td>nar der vxrr anderledes .</td><td>slu</td><td style='text-align:left'>nar jeg IZerr a innse</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007020801059?searchText=slu' target='_'>Christiansen, Sigurd,Samlede verker,1949</a></td><td>, 8 a kan .</td><td>slu</td><td style='text-align:left'>lcommer kun Bnart .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007020801059?searchText=slu' target='_'>Christiansen, Sigurd,Samlede verker,1949</a></td><td>nenne ur av stolen .</td><td>slu</td><td style='text-align:left'>var nun ute pa gulvet</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007020801059?searchText=slu' target='_'>Christiansen, Sigurd,Samlede verker,1949</a></td><td>av 6 em begge .</td><td>slu</td><td style='text-align:left'>balanserte 6 e nenne i</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007020801059?searchText=slu' target='_'>Christiansen, Sigurd,Samlede verker,1949</a></td><td>—</td><td>slu</td><td style='text-align:left'>er jeg endelig lerdig til</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007020801059?searchText=slu' target='_'>Christiansen, Sigurd,Samlede verker,1949</a></td><td>t op den gangen .</td><td>slu</td><td style='text-align:left'>er nan rykket I ^</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007020801059?searchText=slu' target='_'>Christiansen, Sigurd,Samlede verker,1949</a></td><td>lenge , sa kan .</td><td>slu</td><td style='text-align:left'>rna 6 u kuske pa</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016082408043?searchText=slu' target='_'>Grover, Marshall,Big Jim viser sin styrke,2004</a></td><td>bande . Men Slotte er</td><td>slu</td><td style='text-align:left'>. Og han er full</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007062104040?searchText=slu' target='_'>Johansen, Jahn Otto,Når Kina våkner,1979</a></td><td>sterkeste blant de onde og</td><td>slu</td><td style='text-align:left'>regnet sine felt i tusentall,</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014032408113?searchText=slu' target='_'>Du Maurier, Daphne,Rebecca,1949</a></td><td>så på meg med sine</td><td>slu</td><td style='text-align:left'>idiotøyne.</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014032408113?searchText=slu' target='_'>Du Maurier, Daphne,Rebecca,1949</a></td><td>hodet sitt . Øynene var</td><td>slu</td><td style='text-align:left'>som før . Han la</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009082503015?searchText=slu' target='_'>,Registrum prædiorum et redituum ad ecclesias dioecesis Bergensis sæculo P.C. XIV.to, pertinentium, vulgo dictum "Bergens Kalvskind" (Bjørgynjar Kalfskinn),1843</a></td><td>j , ri</td><td>slu</td><td style='text-align:left'>ta j liid æinn .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011022808059?searchText=slu' target='_'>Kristofersen, Knut,Spermasett,2000</a></td><td>var en av disse overnaturlig</td><td>slu</td><td style='text-align:left'>albatrossene som moret seg med</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011022808059?searchText=slu' target='_'>Kristofersen, Knut,Spermasett,2000</a></td><td>Det var en av disse</td><td>slu</td><td style='text-align:left'>kjempene , og tro meg</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007071304013?searchText=slu' target='_'>Mann, Leon,Sosialpsykologi,1972</a></td><td>de fleste patagoniere virkelig er</td><td>slu</td><td style='text-align:left'>, beregnende og overtroiske ,</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016022308192?searchText=slu' target='_'>Dahl, Rolf,Engelsk skolegrammatikk,1963</a></td><td>slew [</td><td>slu</td><td style='text-align:left'>: ) slept</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013102508010?searchText=slu' target='_'>Ustad, Willy,For rikets sikkerhet,1993</a></td><td>men Ryer er en usedvanlig</td><td>slu</td><td style='text-align:left'>mann . Vi klarer ikke</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015052108125?searchText=slu' target='_'>Lamark, Svein,Halsa,1983</a></td><td>r 11 ? i å</td><td>slu</td><td style='text-align:left'>t ts iu e d</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011072508101?searchText=slu' target='_'>Halberg, Jonny,All verdens ulykker,2007</a></td><td>, Sanda Tomescu var en</td><td>slu</td><td style='text-align:left'>rev , så mye var</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013120305103?searchText=slu' target='_'>Amirrezvani, Anita,Blomster og blod,2009</a></td><td>meg om eventyrene til en</td><td>slu</td><td style='text-align:left'>mus og en stor ,</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013102407137?searchText=slu' target='_'>West, Morris L.,Fiskerens sko,1978</a></td><td>Rafaels fresker , var den</td><td>slu</td><td style='text-align:left'>torturisten Kamenev hos ham .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013102407137?searchText=slu' target='_'>West, Morris L.,Fiskerens sko,1978</a></td><td

# %%
nb.nb_ngram("* munn").sort_index().plot()

# %%
nb.nb_ngram("hodet hans, hans hode", years=(1910, 2010)).plot()

# %%
nb.nb_ngram("moren hans, hans mor", years=(1910, 2010)).plot()

# %%
nb.nb_ngram("moren hans, hans mor", years=(1910, 2010), mode='abs').sum(axis=0)
# Out:
# moren hans    15745.50
# hans mor      46095.75
# dtype: float64

# %%
nb.nb_ngram("ei krone, en krone", corpus='avis', years=(1910, 2010)).plot()

# %%
nb.nb_ngram("ei seng, en seng, senga, sengen", corpus='avis', years=(1910, 2010)).plot()

# %%
nb.nb_ngram("på, paa", corpus='avis', years=(1880, 1970)).plot()

# %%
nb.nb_ngram("bogen, boken", corpus='bok', years=(1810, 2010)).plot()

# %%
nb.nb_ngram("brunsnigel", corpus='avis', mode='ab', smooth=1,years=(1810, 2010)).plot()

# %%
nb.nb_ngram("krona, kronen", corpus='avis', years=(1910, 2010)).plot()

# %%
nb.nb_ngram("dette her, det her", corpus='avis', years=(1910, 2010)).plot()

# %%
nb.nb_ngram("animasjon", corpus='avis', years=(1910, 2010)).plot()

# %%
def dobbel(word, det='den', **kwarg):
    dobbel = nb.nb_ngram('{w}, {det} {w}'.format(w=word, det=det), **kwarg)
    return nb.frame(dobbel['{det} {w}'.format(w=word, det=det)]/dobbel[word], word)

# %%
import pandas as pd

# %%
pd.concat([dobbel('regjeringen'), dobbel('sengen'), dobbel('mannen'), dobbel('flyet', 'det'), dobbel('klassen')], sort=False).plot()

# %%
dobbel('sykkelen', smooth = 5, years=(1950,1980), mode='abs')
# Out:
#       sykkelen
# 1950       NaN
# 1951       NaN
# 1952       NaN
# 1953       NaN
# 1954  0.014223
# 1955  0.016091
# 1956  0.015230
# 1957  0.014085
# 1958  0.014067
# 1959  0.016172
# 1960  0.017246
# 1961  0.015143
# 1962  0.014620
# 1963  0.015630
# 1964  0.016955
# 1965  0.016156
# 1966  0.013296
# 1967  0.013291
# 1968  0.013286
# 1969  0.015210
# 1970  0.013882
# 1971  0.012609
# 1972  0.009574
# 1973  0.009045
# 1974       NaN
# 1975       NaN
# 1976       NaN
# 1977       NaN
# 1978       NaN
# 1979  0.008426
# 1980  0.006859

# %%
nb.nb_ngram("dette her, det her", corpus='avis', years=(1910, 2010)).plot()

# %%
nb.nb_ngram("gravferd", corpus='avis', years=(1910, 2010)).plot()

# %%
nb.concordance(word = 'løpende', subject='finans', yearfrom = 1980, yearto = 2010, before = 4, after = 3)
# Out:
# <table><tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011101408035?searchText=løpende' target='_'>Bøhren, Øyvind,Finansiell økonomi,2006</a></td><td>forlag og forfattere samt</td><td>løpende</td><td style='text-align:left'>oppdatering av feil</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011101408035?searchText=løpende' target='_'>Bøhren, Øyvind,Finansiell økonomi,2006</a></td><td>nominell ( regnet i</td><td>løpende</td><td style='text-align:left'>priser ) eller</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011101408035?searchText=løpende' target='_'>Bøhren, Øyvind,Finansiell økonomi,2006</a></td><td>i forvaltningskapital målt i</td><td>løpende</td><td style='text-align:left'>priser vært temmelig</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011101408035?searchText=løpende' target='_'>Bøhren, Øyvind,Finansiell økonomi,2006</a></td><td>markedet , er den</td><td>løpende</td><td style='text-align:left'>kontantstrømmen definert .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011101408035?searchText=løpende' target='_'>Bøhren, Øyvind,Finansiell økonomi,2006</a></td><td>alle beløp målt i</td><td>løpende</td><td style='text-align:left'>priser . Både</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011010706014?searchText=løpende' target='_'>Olsen, Eigil,Verdensbanken,1994</a></td><td>imidlertid brukt til myndighetenes</td><td>løpende</td><td style='text-align:left'>utgifter , eller</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011033108018?searchText=løpende' target='_'>Pedersen, Rune,Aksjer &amp; pengeplassering,2000</a></td><td>. Dette gir deg</td><td>løpende</td><td style='text-align:left'>beregninger av gevinst</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011033108018?searchText=løpende' target='_'>Pedersen, Rune,Aksjer &amp; pengeplassering,2000</a></td><td>for høye marginen Høy</td><td>løpende</td><td style='text-align:left'>kontantstrøm og god</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010031606015?searchText=løpende' target='_'>Hagen, Terje P.,Storbyenes finanser 1983-1997,1999</a></td><td>overfor prosjektet . Den</td><td>løpende</td><td style='text-align:left'>oppfølgingen av prosjektet</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010031606015?searchText=løpende' target='_'>Hagen, Terje P.,Storbyenes finanser 1983-1997,1999</a></td><td>grad forholde seg til</td><td>løpende</td><td style='text-align:left'>saker knyttet til</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010031606015?searchText=løpende' target='_'>Hagen, Terje P.,Storbyenes finanser 1983-1997,1999</a></td><td>I Trondheim skjer rapporteringen</td><td>løpende</td><td style='text-align:left'>. Det vil</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010031606015?searchText=løpende' target='_'>Hagen, Terje P.,Storbyenes finanser 1983-1997,1999</a></td><td>at kommunene stort sett</td><td>løpende</td><td style='text-align:left'>bruker de økte</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008010304035?searchText=løpende' target='_'>Hansen, Per H.,Det danske finansielle system ca. 1850-1992,1994</a></td><td>er å gi en</td><td>løpende</td><td style='text-align:left'>dokumentasjon og formidling</td></tr>
# </table>

# %%
korpus = nb.book_corpus(subject='språkvitenskap', limit = 50)

# %%
agg = nb.get_aggregated_corpus(nb.pure_urn(korpus))

# %%
agg.loc['løpende']
# Out:
# 0    29
# Name: løpende, dtype: int64

# %%
coll = nb.urn_coll(word = 'løpende', urns = nb.pure_urn(korpus), before = 0, after = 5)

# %%
tot = nb.totals(50000)

# %%
tot = nb.frame(tot)

# %%
viktige = nb.frame_sort(nb.frame(coll[0]/tot[0]))

# %% [markdown]
# Metonymiske relasjoner mellom objektene, del for hele, hele for del.
# stickers game vs. stickers
# 1. sognsvann for tur til sognsvann

# %%
nb.cloud(viktige[:20])

# %%
MK = {
"Kamp" : "kamp, rifle, krutt, revolver, riflen, hylster, sår, blod, kjøtt, skjøt, skudd, avtrekkeren, siktet, død, døde, fyrte, ladegrep, siktet".split(', '),
"Glad":"glad, munter, plystret, lo, smilte, lettet, plystre, plystrer, muntre, live, lever, lettet, livlig, ler, smiler".split(', ')
}

# %%
MK
# Out:
# {'Kamp': ['kamp',
#   'rifle',
#   'krutt',
#   'revolver',
#   'riflen',
#   'hylster',
#   'sår',
#   'blod',
#   'kjøtt',
#   'skjøt',
#   'skudd',
#   'avtrekkeren',
#   'siktet',
#   'død',
#   'døde',
#   'fyrte',
#   'ladegrep',
#   'siktet'],
#  'Glad': ['glad',
#   'munter',
#   'plystret',
#   'lo',
#   'smilte',
#   'lettet',
#   'plystre',
#   'plystrer',
#   'muntre',
#   'live',
#   'lever',
#   'lettet',
#   'livlig',
#   'ler',
#   'smiler']}

# %%
nb.book_corpus(author='masterson%', title="%tigeren%montana%")
# Out:
#              urn            author  \
# 0  2014051908121  Masterson, Louis
# 1  2015011608010  Masterson, Louis
# 2  2013060408158  Masterson, Louis
#
#                                             title  year
# 0  Tigeren fra Montana ; Den gale hunden fra Utah  2007
# 1                             Tigeren fra Montana  1980
# 2                             Tigeren fra Montana  1972

# %%
nb.plot_book_wordbags(2014051908121, MK).plot(title = "Tigeren fra Montana ; Den gale hunden fra Utah" )

# %%
nb.plot_book_wordbags(2011100608069, MK).plot()
