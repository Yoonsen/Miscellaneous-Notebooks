# %% [markdown]
# ### Galakser som embeddinger

# %%
# Hvis dhlab ikke er installert, avkommenter linjen under og kjør
#!pip install dhlab

# %%
import dhlab.nbtext as nb
import dhlab.graph_networkx_louvain as gnl

# %%
nb.concordance('bil')
# Out:
# <table><tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013121108179?searchText=bil' target='_'>Dahl, Roald,Verdens største fersken,1993</a></td><td>så stor som en liten</td><td>bil</td><td style='text-align:left'>, og nådde halweis ned</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013121108179?searchText=bil' target='_'>Dahl, Roald,Verdens største fersken,1993</a></td><td>bilen ( en kjempestor apen</td><td>bil</td><td style='text-align:left'>) satt James og alle</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013121108179?searchText=bil' target='_'>Dahl, Roald,Verdens største fersken,1993</a></td><td>Bak ferskenen fulgte borgermesterens</td><td>bil</td><td style='text-align:left'>, som skled hit og</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012011012006?searchText=bil' target='_'>Lindeman, Ludv. M. (Ludvig Mathias),Melodier til N. Fr. S. Grundtvigs Krønike-Rim,1874</a></td><td>- ha - vet sig</td><td>bil</td><td style='text-align:left'>- der ind , Verden</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016033008113?searchText=bil' target='_'>Rustadbakken, Atle,Prosjekt Randsfjordfisk,2003</a></td><td>observasjoner fra</td><td>bil</td><td style='text-align:left'>og studie av kart .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010031806002?searchText=bil' target='_'>,Kjemisk og økotoksikologisk karakterisering av veistøv,1999</a></td><td>PCS ) • utslipp fra</td><td>bil</td><td style='text-align:left'>( PC2 )</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011070505150?searchText=bil' target='_'>Førsund, Finn Borgen,mageligste Maade at reise paa",1983</a></td><td>kunne få det ordna med</td><td>bil</td><td style='text-align:left'>eller motorbåt 21</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011070505150?searchText=bil' target='_'>Førsund, Finn Borgen,mageligste Maade at reise paa",1983</a></td><td>hushalda i Solund som disponerte</td><td>bil</td><td style='text-align:left'>, mens gjennomsnittet for fylket</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011070505150?searchText=bil' target='_'>Førsund, Finn Borgen,mageligste Maade at reise paa",1983</a></td><td>som hadde færrast personar pr.</td><td>bil</td><td style='text-align:left'>var Førde med 3,0 .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011070505150?searchText=bil' target='_'>Førsund, Finn Borgen,mageligste Maade at reise paa",1983</a></td><td>i talet på personar pr.</td><td>bil</td><td style='text-align:left'>mellom kystkommunane og fylket elles</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011070505150?searchText=bil' target='_'>Førsund, Finn Borgen,mageligste Maade at reise paa",1983</a></td><td>Samstundes er mange som har</td><td>bil</td><td style='text-align:left'>avhengig av ein lang -</td></tr>
# </table>

# %% [markdown]
# ## Test ut med kommando `relaterte_ord`
#
# Det er en egenvektorbasert måte å hente ut tilsvarende ord fra grafen gitt under.

# %%
def cluster_for(w, cutoff = 12, lang = 'nob'):
    G = nb.make_graph(w, cutoff = cutoff, lang=lang)
    c = gnl.community_dict(G)
    res = []
    for x in c:
        if w in c[x]:
            res = c[x]
    return res

# %%
def cliques_for(w, cutoff = 12, lang = 'nob'):
    G = nb.make_graph(w, cutoff = cutoff, lang=lang)
    c = gnl.make_cliques_from_graph(G.to_undirected())
    res = []
    for x in c:
        if w in c[x]:
            res = c[x]
    return res

# %%
g = nb.make_graph('vold', cutoff = 20)

# %%
gnl.make_cliques_from_graph(g.to_undirected())
# Out:
# (<networkx.classes.graph.Graph at 0x22bc97df6d8>,
#  {(3, 1): frozenset({'Bråk',
#              'Kjærlighet',
#              'Tortur',
#              'Ungdom',
#              'Vold',
#              'alkohol',
#              'bortføring',
#              'brudd',
#              'brutalitet',
#              'bråk',
#              'diktatur',
#              'diskriminering',
#              'dop',
#              'drap',
#              'drapsforsøk',
#              'drapstrusler',
#              'erotikk',
#              'fattigdom',
#              'fest',
#              'festing',
#              'flaskeknusing',
#              'folkemord',
#              'forfølgelse',
#              'frihetsberøvelse',
#              'frykt',
#              'fyll',
#              'grov',
#              'hat',
#              'hets',
#              'hevn',
#              'hærverk',
#              'incest',
#              'intriger',
#              'kidnapping',
#              'kjærlighet',
#              'kjønn',
#              'konflikter',
#              'korrupsjon',
#              'krig',
#              'kriminalitet',
#              'legemsbeskadigelse',
#              'legemsfornærmelse',
#              'makt',
#              'misbruk',
#              'mishandling',
#              'misunnelse',
#              'mobbing',
#              'mord',
#              'narkotika',
#              'narkotikamisbruk',
#              'nød',
#              'okkupasjon',
#              'omsorgssvikt',
#              'overfall',
#              'overgrep',
#              'porno',
#              'prostitusjon',
#              'ran',
#              'rasisme',
#              'rus',
#              'røyk',
#              'sadisme',
#              'seksuelle',
#              'sex',
#              'sjalusi',
#              'sjikane',
#              'sjikanering',
#              'skadeverk',
#              'slagsmål',
#              'slåssing',
#              'spetakkel',
#              'spionasje',
#              'sprit',
#              'terror',
#              'tortur',
#              'trakassering',
#              'trusler',
#              'tvang',
#              'undertrykkelse',
#              'ungdom',
#              'urett',
#              'urettferdighet',
#              'uro',
#              'utpressing',
#              'vald',
#              'vanskjøtsel',
#              'vold',
#              'voldtekt',
#              'voldtekter'}),
#   (4, 1): frozenset({'Ungdom',
#              'Vold',
#              'alkohol',
#              'brutalitet',
#              'dop',
#              'drap',
#              'drapstrusler',
#              'forfølgelse',
#              'frihetsberøvelse',
#              'fyll',
#              'grov',
#              'hærverk',
#              'kidnapping',
#              'korrupsjon',
#              'krig',
#              'kriminalitet',
#              'makt',
#              'mishandling',
#              'mobbing',
#              'narkotika',
#              'overfall',
#              'overgrep',
#              'porno',
#              'ran',
#              'rasisme',
#              'rus',
#              'sadisme',
#              'sex',
#              'sjikane',
#              'terror',
#              'tortur',
#              'trakassering',
#              'trusler',
#              'undertrykkelse',
#              'ungdom',
#              'vald',
#              'vold',
#              'voldtekt',
#              'voldtekter'}),
#   (4, 2): frozenset({'bråk', 'flaskeknusing', 'fyll', 'hærverk', 'vold'}),
#   (5, 1): frozenset({'drap',
#              'drapstrusler',
#              'hærverk',
#              'mishandling',
#              'mobbing',
#              'overgrep',
#              'tortur',
#              'trakassering',
#              'trusler',
#              'vold',
#              'voldtekt'}),
#   (5, 2): frozenset({'brutalitet',
#              'krig',
#              'overgrep',
#              'terror',
#              'tortur',
#              'undertrykkelse',
#              'vold'}),
#   (5, 3): frozenset({'fyll', 'narkotika', 'rus', 'sex', 'vold'})},
#  <networkx.classes.digraph.DiGraph at 0x22bc97dfb70>)

# %%
cliques_for('vold')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-e077cb328d4d> in <module>
# ----> 1 cliques_for('vold')
#
# <ipython-input-67-568b8b70bf2d> in cliques_for(w, cutoff, lang)
#       4     res = []
#       5     for x in c:
# ----> 6         if w in c[x]:
#       7             res = c[x]
#       8     return res
#
# TypeError: tuple indices must be integers or slices, not Graph

# %%
cluster_for('vold')
# Out:
# ['vold',
#  'overgrep',
#  'mishandling',
#  'drap',
#  'tortur',
#  'voldtekt',
#  'seksuelle',
#  'voldtekter',
#  'omsorgssvikt',
#  'mord',
#  'kidnapping',
#  'korrupsjon',
#  'incest',
#  'maktmisbruk',
#  'vanskjøtsel',
#  'fysiske',
#  'bortføring',
#  'krenkelser',
#  'traumatisk']

# %%
nb.relaterte_ord('incest')
# Out:
# ['overgrep',
#  'vold',
#  'mishandling',
#  'voldtekt',
#  'drap',
#  'incest',
#  'seksuell',
#  'misbruk',
#  'seksuelt',
#  'seksuelle',
#  'tortur',
#  'prostitusjon',
#  'selvmord',
#  'trakassering',
#  'voldtekter',
#  'grov',
#  'vanskjøtsel',
#  'omsorgssvikt',
#  'undertrykkelse',
#  'trusler']

# %%
cluster_for('incest')
# Out:
# ['incest',
#  'voldtekt',
#  'seksuelle',
#  'pedofili',
#  'seksuelt',
#  'kvinnemishandling',
#  'utukt',
#  'seksuell',
#  'voldtektsforsøk',
#  'utuktig',
#  'Voldtekt',
#  'homofili',
#  'fysiske']

# %%
cluster_for('laks')
# Out:
# ['laks', 'aure', 'hvitfisk', 'orret', 'vannmiljø', 'pelagisk', 'avløp']

# %%
syn('seks')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-483496845ac9> in <module>
# ----> 1 syn('seks')
#
# NameError: name 'syn' is not defined

# %%
G= nb.make_graph('democracy' , lang='eng')

# %%
nb.relaterte_ord('voldtekt', score = True)
# Out:
# [('vold', 0.32009902120057576),
#  ('voldtekt', 0.3050382055678084),
#  ('drap', 0.30495319420316286),
#  ('mishandling', 0.2844058047962756),
#  ('tortur', 0.24175078549468657),
#  ('ran', 0.2381268743939038),
#  ('overgrep', 0.2239245070871494),
#  ('kidnapping', 0.19906002678433704),
#  ('mord', 0.1989042467843932),
#  ('overfall', 0.19118733596006526),
#  ('trusler', 0.1724449589379935),
#  ('frihetsberøvelse', 0.16262907802027135),
#  ('plyndring', 0.15308106788649828),
#  ('incest', 0.1480535032746876),
#  ('voldtekter', 0.14301739433059196),
#  ('seksuell', 0.14185031211212387),
#  ('drapsforsøk', 0.13845518295116696),
#  ('trakassering', 0.13400531322782652),
#  ('seksuelt', 0.12347516197334563),
#  ('seksuelle', 0.1226803037209363)]

# %% [markdown]
# ## Ta ut grafen og hent ut med passende algoritem
#
#
# Grafen er et **networkx**- objekt.

# %%
G = nb.make_graph('seks', cutoff = 12)

# %%
gnl.show_graph(G, spread = 1)

# %% [markdown]
# Med `show_communities` gis en litt mer detaljert clustring fra grafen

# %%
gnl.show_communities(G)
# Out:
# tre-to :  tre, to, hustru, betong, mur, buskar, kunstlær
#
# seks-fem :  seks, fem, åtte, tolv, ti, syv, elleve, fire, sju, ni, drept, uavgjorte, fagdommere, femten, tjue, tretten, fjorten, minutt, tredive, fengsel, firti, jaktfalker, tyvende, seksten, legdommere, null, år, lasteplass, shilling
#
# tyve-tredve :  tyve, tredve, åtti, seksti, sytti, hundre, noen, femti, nogen, par, nitti, førti, IVere, meter
#
# sølv-bronse :  sølv, bronse, tinn, gull, cape, skjorte
#
# kone-barnebarn :  kone, barnebarn, barn, datter, mor, svigersønner, svigerbarn

# %%
gnl.show_cliques(G)
# Out:
# (3, 1) tyvende, sju, fagdommere, uavgjorte, seks, barnebarn, minutt, tjue, tredive, åtte, sytti, hustru, tretten, fjorten, åtti, syv, femten, noen, ni, nogen, kone, seksti, tyve, ti, fem, elleve, par, seksten, fengsel, to, tolv, firti, drept, tredve, fire, tre
#
# (4, 1) sju, fagdommere, uavgjorte, seks, barnebarn, minutt, tjue, tredive, åtte, hustru, tretten, fjorten, syv, femten, ni, kone, tyve, ti, fem, elleve, tolv, drept, tredve, fire, tre
#
# (5, 1) sju, fagdommere, uavgjorte, seks, barnebarn, tjue, åtte, tretten, syv, femten, ni, kone, tyve, ti, fem, elleve, tolv, drept, fire, tre
#
# (6, 1) tyve, elleve, fem, ti, sju, seks, tolv, drept, åtte, tretten, syv, fire, ni
#
# (7, 1) elleve, ti, sju, seks, tolv, drept, åtte, syv, ni

# %%
gnl.show_cliques??

# %%
nb.central_characters(G, n=50)
# Out:
# [('seks', 0.3870967741935484),
#  ('fem', 0.3387096774193548),
#  ('åtte', 0.3064516129032258),
#  ('tre', 0.29032258064516125),
#  ('tolv', 0.29032258064516125),
#  ('ti', 0.25806451612903225),
#  ('syv', 0.24193548387096775),
#  ('tyve', 0.22580645161290322),
#  ('fire', 0.2096774193548387),
#  ('ni', 0.2096774193548387),
#  ('elleve', 0.2096774193548387),
#  ('sju', 0.2096774193548387),
#  ('kone', 0.1935483870967742),
#  ('sølv', 0.1774193548387097),
#  ('barnebarn', 0.1774193548387097),
#  ('tredve', 0.16129032258064516),
#  ('drept', 0.16129032258064516),
#  ('åtti', 0.14516129032258063),
#  ('seksti', 0.12903225806451613),
#  ('uavgjorte', 0.11290322580645161),
#  ('femten', 0.0967741935483871),
#  ('fagdommere', 0.0967741935483871),
#  ('tjue', 0.08064516129032258),
#  ('sytti', 0.08064516129032258),
#  ('tretten', 0.08064516129032258),
#  ('to', 0.06451612903225806),
#  ('noen', 0.06451612903225806),
#  ('fjorten', 0.06451612903225806),
#  ('hundre', 0.06451612903225806),
#  ('nogen', 0.04838709677419355),
#  ('tredive', 0.04838709677419355),
#  ('barn', 0.04838709677419355),
#  ('datter', 0.04838709677419355),
#  ('hustru', 0.04838709677419355),
#  ('femti', 0.04838709677419355),
#  ('minutt', 0.04838709677419355),
#  ('buskar', 0.03225806451612903),
#  ('null', 0.03225806451612903),
#  ('jaktfalker', 0.03225806451612903),
#  ('mur', 0.03225806451612903),
#  ('betong', 0.03225806451612903),
#  ('kunstlær', 0.03225806451612903),
#  ('meter', 0.03225806451612903),
#  ('fengsel', 0.03225806451612903),
#  ('skjorte', 0.03225806451612903),
#  ('tyvende', 0.03225806451612903),
#  ('legdommere', 0.03225806451612903),
#  ('firti', 0.03225806451612903),
#  ('mor', 0.03225806451612903),
#  ('svigerbarn', 0.03225806451612903)]

# %% [markdown]
# Ta ut clusteret som et python-objekt

# %%
gnl.community_dict(G)
# Out:
# {'tre-to': ['tre', 'to', 'hustru', 'betong', 'mur', 'buskar', 'kunstlær'],
#  'seks-fem': ['seks',
#   'fem',
#   'åtte',
#   'tolv',
#   'ti',
#   'syv',
#   'elleve',
#   'fire',
#   'sju',
#   'ni',
#   'drept',
#   'uavgjorte',
#   'fagdommere',
#   'femten',
#   'tjue',
#   'tretten',
#   'fjorten',
#   'minutt',
#   'tredive',
#   'fengsel',
#   'firti',
#   'jaktfalker',
#   'tyvende',
#   'seksten',
#   'legdommere',
#   'null',
#   'år',
#   'lasteplass',
#   'shilling'],
#  'tyve-tredve': ['tyve',
#   'tredve',
#   'åtti',
#   'seksti',
#   'sytti',
#   'hundre',
#   'noen',
#   'femti',
#   'nogen',
#   'par',
#   'nitti',
#   'førti',
#   'IVere',
#   'meter'],
#  'sølv-bronse': ['sølv', 'bronse', 'tinn', 'gull', 'cape', 'skjorte'],
#  'kone-barnebarn': ['kone',
#   'barnebarn',
#   'barn',
#   'datter',
#   'mor',
#   'svigersønner',
#   'svigerbarn']}

# %%
indianere = nb.make_graph('indians', lang='eng')

# %%
gnl.show_graph(indianere)

# %%
gnl.show_communities(indianere)
# Out:
# mestizos-mulattoes :  mestizos, mulattoes, criollos, mestizas, mulatos, cholos
#
# cowboys-ranchmen :  cowboys, ranchmen, cowgirls, vaqueros, sheepherders, cowmen
#
# negroes-indians :  negroes, indians, mulattos, carpetbaggers, scalawags
#
# blacks-whites :  blacks, whites, coloureds, pardos, coloreds, greys, hispanics, nonblacks

# %%
violence = nb.make_graph('violence', lang='eng')

# %%
gnl.show_graph(violence, spread = 1)

# %%
gnl.show_cliques(violence)
# Out:
# (3, 1) bloodshed, pillage, lawlessness, Rapine, incendiarism, rapine, violence
#
# (3, 2) intimidation, thuggery, terrorisation, violence

# %%
gnl.show_communities(violence)
# Out:
# lawlessness-thuggery :  lawlessness, thuggery, hooliganism, banditry, ruffianism, brigandage, corruption
#
# rapine-Rapine :  rapine, Rapine, bloodshed, pillage, Plunder, Murder, plunder, Lust, Extortion, incendiarism, Spoil
#
# nonviolence-peacemaking :  nonviolence, peacemaking, satyagraha, nonresistance, noncooperation, pacifism
#
# violence-Lawlessness :  violence, Lawlessness, anarchy, Violence, Crime, terrorisation, counterviolence, Fickleness, vagabondism, oppreffion
#
# rapines-depredations :  rapines, depredations, extortions, robberies, murders
#
# intimidation-extortion :  intimidation, extortion, terrorization, coercion, cajolery, harrassment, harassment, bribery
#
# suddenness-abruptness :  suddenness, abruptness, unexpectedness, swiftness

# %%
a =  [1,2,3,4]

# %%
a[2:4]
# Out:
# [3, 4]

# %%
nb.concordance('demokrati', corpus = 'avis', size=1, kind ='json')
# Out:
# [{'after': 'i Den norske kirke »',
#   'before': 'OSLO : Innstillingen « Styrket',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_gudbrandsdolendagnin_null_null_20080514_171_109_1',
#   'word': 'demokrati'},
#  {'after': '? Begge deler , antakeligvis',
#   'before': 'det uttrykk for det optimale',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_gudbrandsdolendagnin_null_null_20080205_171_30_1',
#   'word': 'demokrati'},
#  {'after': '? Tilsetjingar i kommunen signaliserer',
#   'before': '. Er det lenger noko',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_gudbrandsdolendagnin_null_null_20080207_171_32_1',
#   'word': 'demokrati'},
#  {'after': 'setter . Det mest skremmende',
#   'before': 'de overordnede målsettingene som vårt',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_gudbrandsdolendagnin_null_null_20080211_171_35_1',
#   'word': 'demokrati'},
#  {'after': '» . Vårt syn på',
#   'before': 'av fattigfolk og , økonomisk',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19550106_63_4_1',
#   'word': 'demokrati'},
#  {'after': 'konsentrerer seg først og fremst',
#   'before': 'Vårt syn på det økonomiske',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19550106_63_4_1',
#   'word': 'demokrati'},
#  {'after': 'at nokre få skal peika',
#   'before': 'i samsvar med eit fritt',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19550122_63_18_1',
#   'word': 'demokrati'},
#  {'after': 'er ikkje krangel . Overlnstansane',
#   'before': 'med litt usemje , men',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19550122_63_18_1',
#   'word': 'demokrati'},
#  {'after': 'Øog « fair play »',
#   'before': 'Øog til deres sans for',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_klassekampen_null_null_19910904_22_203_1',
#   'word': 'demokrati'},
#  {'after': 'for arbeidstakerne går mye lenger',
#   'before': 'folkevegelse , der kravet til',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_klassekampen_null_null_19910904_22_203_1',
#   'word': 'demokrati'},
#  {'after': ', Øog kaller seg «',
#   'before': 'dannet sin egen organisasjon for',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_klassekampen_null_null_19910907_22_206_1',
#   'word': 'demokrati'},
#  {'after': 'på Cuba . De åtte',
#   'before': ', nasjonal forsoning Øog fullstendig',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_klassekampen_null_null_19910907_22_206_1',
#   'word': 'demokrati'},
#  {'after': 'i Tyrkia . Han traikk',
#   'before': 'på å opprette et sosialistisk',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_haugesundsavis_null_null_19751215_81_291_1',
#   'word': 'demokrati'},
#  {'after': ', sier justisministeren . den',
#   'before': 'en viss fare for vårt',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_haugesundsavis_null_null_19751215_81_291_1',
#   'word': 'demokrati'},
#  {'after': '? J Cand oecon Ellingsen',
#   'before': '( Kommer frem i et',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_haugesundsavis_null_null_19720105_77_3_1',
#   'word': 'demokrati'},
#  {'after': 'i arbeidslivet der også representanter',
#   'before': 'ko fe . ranse om',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_haugesundsavis_null_null_19720112_77_9_1',
#   'word': 'demokrati'},
#  {'after': '? Dette ganet for Arbeidernes',
#   'before': 'at også Klassekampen or- vestlige',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_dagogtid_null_null_19740118_13_6_1',
#   'word': 'demokrati'},
#  {'after': 'Noreg tradisjo- Klassekampen har sitt',
#   'before': '. ( Vi trur for',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_dagogtid_null_null_19740118_13_6_1',
#   'word': 'demokrati'},
#  {'after': '? Dette sporsmal kommer ikke',
#   'before': 'parti som undergraver vårt vestlige',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_dagogtid_null_null_19740118_13_6_1',
#   'word': 'demokrati'},
#  {'after': 'Noreg tradisjonelt vedkjenner seg til',
#   'before': 'ting at den forma for',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_dagogtid_null_null_19740118_13_6_1',
#   'word': 'demokrati'},
#  {'after': ', men neppe mer kunstig',
#   'before': 'var ikke Kuwait noe egentlig',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_dagensnaeringsliv_null_null_19910115_102_12_1',
#   'word': 'demokrati'},
#  {'after': 'som langt overgår det våre',
#   'before': 'samarbeidsavtaler og utviklet et representativt',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_dagensnaeringsliv_null_null_19910118_102_15_1',
#   'word': 'demokrati'},
#  {'after': 'på arbeidsplassene i Norge .',
#   'before': 'få til et mer reelt',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_dagensnaeringsliv_null_null_19910118_102_15_1',
#   'word': 'demokrati'},
#  {'after': 'som er iferd med å',
#   'before': 'har friheten , et annet',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_dagensnaeringsliv_null_null_19910118_102_15_1',
#   'word': 'demokrati'},
#  {'after': '* k koleordning , «',
#   'before': 'fra 191 aarene om en',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19240618_32_138_1',
#   'word': 'demokrati'},
#  {'after': 'vi ! forhaabentlig være likesaa',
#   'before': '- sikkerhet . Det tyske',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19240620_32_140_1',
#   'word': 'demokrati'},
#  {'after': '. Frankrig hasber . at',
#   'before': 'endnu mer til det tyske',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19240625_32_144_1',
#   'word': 'demokrati'},
#  {'after': '* og den av venstre',
#   'before': 'folkets for agt for dette',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19240707_32_154_1',
#   'word': 'demokrati'},
#  {'after': 'at det finnes en våken',
#   'before': 'betydning det har for et',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_adresseavisen_null_null_19621027_196_250_1',
#   'word': 'demokrati'},
#  {'after': 'opp til fornyet vurdering .',
#   'before': 'bekjempe isdannelsen . tok begrepet',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_adresseavisen_null_null_19621027_196_250_1',
#   'word': 'demokrati'},
#  {'after': ', or landsmøtet , sluttet',
#   'before': 'Bjørn Sørensen innledet om industrielt',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_adresseavisen_null_null_19621108_196_260_1',
#   'word': 'demokrati'},
#  {'after': 'i arbeidslivet . I denne',
#   'before': 'som er reist om okt',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_adresseavisen_null_null_19621108_196_260_1',
#   'word': 'demokrati'},
#  {'after': 'er stater diktatoriske . Nå',
#   'before': 'fasit om god levestandard og',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_ostlandetsblad_null_null_20100729_103_171_1',
#   'word': 'demokrati'},
#  {'after': 'KAI PETTER PETTERSEN , NKP',
#   'before': 'FrP En annen form for',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_ostlandetsblad_null_null_20100729_103_171_1',
#   'word': 'demokrati'},
#  {'after': 'bør sterke overbevisningsgrunner kunne gi',
#   'before': 'bære bort demonstranten I et',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_ostlandetsblad_null_null_20100802_103_174_1',
#   'word': 'demokrati'},
#  {'after': 'på Cuba . Feil valg',
#   'before': 'kun for å kjempe for',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_ostlandetsblad_null_null_20100803_103_175_1',
#   'word': 'demokrati'},
#  {'after': '. Vår , folkets reaksjon',
#   'before': 'klokt er bærebjelken i et',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_helgelandarbeiderbla_null_null_20100617_80_135_1',
#   'word': 'demokrati'},
#  {'after': '. I Europas hjerte er',
#   'before': 'klokt er bærebjelken i et',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_helgelandarbeiderbla_null_null_20100617_80_135_1',
#   'word': 'demokrati'},
#  {'after': '. Nasjonen må også spørre',
#   'before': 'ikke bærekraftig i et moderne',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_helgelandarbeiderbla_null_null_20100621_80_138_1',
#   'word': 'demokrati'},
#  {'after': 'og friluftsinteresser , mener leder',
#   'before': 'et mindretall på bekostning av',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_helgelandarbeiderbla_null_null_20100622_80_139_1',
#   'word': 'demokrati'},
#  {'after': 'og plutokrati ! Avlen av',
#   'before': '- Ti års kamp mot',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_nordtrondelaginntrondelagen_null_null_19430130_0_8_1',
#   'word': 'demokrati'},
#  {'after': '» . U.S . A.',
#   'before': 'velsignet med « frihet og',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_nordtrondelaginntrondelagen_null_null_19430331_0_25_1',
#   'word': 'demokrati'},
#  {'after': 'og alt det som vi',
#   'before': 'maler opp om frihet ,',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_nordtrondelaginntrondelagen_null_null_19430619_0_47_1',
#   'word': 'demokrati'},
#  {'after': ', men en imperialisme som',
#   'before': 'ansikt . Kommunismen er intet',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_nordtrondelaginntrondelagen_null_null_19430721_0_56_1',
#   'word': 'demokrati'},
#  {'after': '» . fortøyningene til flyet',
#   'before': '« frihet » og «',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_friheten_null_null_19511101_11_254_1',
#   'word': 'demokrati'},
#  {'after': 'Heller ikke for en såret',
#   'before': 'som bygger for fred og',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_friheten_null_null_19511101_11_254_1',
#   'word': 'demokrati'},
#  {'after': 'så holde stillingen ? Et',
#   'before': '. Kan det spede tyske',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_friheten_null_null_19511101_11_254_1',
#   'word': 'demokrati'},
#  {'after': '» slett ikke er noe',
#   'before': 'demonstrere at det borgerlige «',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_friheten_null_null_19511106_11_258_1',
#   'word': 'demokrati'},
#  {'after': '. » Harry Blomberg (',
#   'before': 'virkelige fellesskap , det riktige',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_askerogbaerumsbudstikke_null_null_19380829_40_100_1',
#   'word': 'demokrati'},
#  {'after': '. De trenger den ihellige',
#   'before': 'betale prisen for et fritt',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_askerogbaerumsbudstikke_null_null_19380829_40_100_1',
#   'word': 'demokrati'},
#  {'after': '» a la Sovjet —',
#   'before': 'at hennes mål — «',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_askerogbaerumsbudstikke_null_null_19380905_40_103_1',
#   'word': 'demokrati'},
#  {'after': 'Det er sopptid nå .',
#   'before': 'et billede fra vårt eget',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_askerogbaerumsbudstikke_null_null_19380905_40_103_1',
#   'word': 'demokrati'},
#  {'after': '? nm imidlertid ikke bare',
#   'before': 'seirr i Algerie , et',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19560217_97_81_1',
#   'word': 'demokrati'},
#  {'after': "de sist ' par a",
#   'before': "' no bliti svært mye",
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19560218_97_83_1',
#   'word': 'demokrati'},
#  {'after': 'vil det neste sondag ,',
#   'before': 'av et forelobig forholdsvis primitivt',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19560224_97_93_2',
#   'word': 'demokrati'},
#  {'after': 'å fungere uten at det',
#   'before': 'er helt umulig for et',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19560225_97_95_1',
#   'word': 'demokrati'},
#  {'after': ', har ikke rad til',
#   'before': 'har okonomisk eller sosialt ,',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19620822_103_383_1',
#   'word': 'demokrati'},
#  {'after': 'og dets tids- og kraftodende',
#   'before': 'A flotte seg med politisk',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19620822_103_383_1',
#   'word': 'demokrati'},
#  {'after': 'egentlig var ! Og Koreakrlgen',
#   'before': 'klart for japanerne hva amerikansk',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19620903_103_403_1',
#   'word': 'demokrati'},
#  {'after': ". En reki . '",
#   'before': 'debatt om selveierdemokrali og Industriell',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19620903_103_403_1',
#   'word': 'demokrati'},
#  {'after': '" ogsaa gjelder i kommunornes',
#   'before': 'om " det . samlede',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19130101_54_1_1',
#   'word': 'demokrati'},
#  {'after': 'og yocialisme heder . Derfor',
#   'before': 'ogma for alt , som',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19130115_54_26_2',
#   'word': 'demokrati'},
#  {'after': '" har fnaet , Saaledes',
#   'before': 'regjering for det " samlede',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19130131_54_56_2',
#   'word': 'demokrati'},
#  {'after': '— en advarsel der jo',
#   'before': 'sin person med det norske',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19160106_57_9_2',
#   'word': 'demokrati'},
#  {'after': 'komme til å ligne angelsakserncs',
#   'before': 'Derfor kan ikke det franske',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19310328_72_161_3',
#   'word': 'demokrati'},
#  {'after': '. Det vllde være ganske',
#   'before': 'idag er fremskritt og sant',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19310417_72_189_1',
#   'word': 'demokrati'},
#  {'after': '! Hvor mango misbruk foretar',
#   'before': 'liten omskrivning : O hellige',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19310124_72_44_3',
#   'word': 'demokrati'},
#  {'after': 'har ødelagt dem . Andreas',
#   'before': 'demokratiske innbilninger . Et misforstått',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19310128_72_49_1',
#   'word': 'demokrati'},
#  {'after': 'og nasjonal frihet var umistelige',
#   'before': 'adgangen til å mene at',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_lofotposten_null_null_19490204_54_29_1',
#   'word': 'demokrati'},
#  {'after': 'i vekst . Aller verst',
#   'before': 'skulle være kjennemerket på et',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_lofotposten_null_null_19490218_54_41_1',
#   'word': 'demokrati'},
#  {'after': '. Men før landet kan',
#   'before': 'kristne sivilisasjon og det vestlige',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_lofotposten_null_null_19490218_54_41_1',
#   'word': 'demokrati'},
#  {'after': 'og parlamentarisme . Dette lover',
#   'before': 'på å undergrave respekten for',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_lofotposten_null_null_19490808_54_180_1',
#   'word': 'demokrati'},
#  {'after': 'og store nye markeder skriker',
#   'before': 'Russland er på vei mot',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_nordlys_null_null_20050818_104_190_1',
#   'word': 'demokrati'},
#  {'after': 'er helt overlegent det amerikanske',
#   'before': ', ønsker Dagens sitat Russisk',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_nordlys_null_null_20050824_104_195_1',
#   'word': 'demokrati'},
#  {'after': 'tar tid ! Det må',
#   'before': 'en skoletime eller to. Men',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_nordlys_null_null_20050826_104_197_1',
#   'word': 'demokrati'},
#  {'after': 'og med en hersketeknikk på',
#   'before': 'med sin med mangel på',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_nordlys_null_null_20050826_104_197_1',
#   'word': 'demokrati'},
#  {'after': 'og parlanu nlaiisme grepet sterkt',
#   'before': 'm in . > og',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_indheredsposten_null_null_19111219_50_100_1',
#   'word': 'demokrati'},
#  {'after': 'i di rene Porbindel &',
#   'before': 'har nawnl n gol om',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_indheredsposten_null_null_19120326_51_25_1',
#   'word': 'demokrati'},
#  {'after': 'uininlslaaelig . . Inabæks energi',
#   'before': 'sammen , blev det fremtrængende',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_indheredsposten_null_null_19140403_53_39_1',
#   'word': 'demokrati'},
#  {'after': ', » g iremskrilt .',
#   'before': 'ni Føre sil slag mol',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_indheredsposten_null_null_19140911_53_96_1',
#   'word': 'demokrati'},
#  {'after': 'Og fred . Koldt vand',
#   'before': 'med dem aa arbeide fof',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_nordenfjeldsktidende_null_null_19170601_44_62_1',
#   'word': 'demokrati'},
#  {'after': 'i Norge fortiden . Fortsætter',
#   'before': '. Det er tip top',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_nordenfjeldsktidende_null_null_19170613_44_67_1',
#   'word': 'demokrati'},
#  {'after': 'likesaa hy ; : _',
#   'before': 'usselhet kunde trives under et',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_nordenfjeldsktidende_null_null_19170618_44_69_1',
#   'word': 'demokrati'},
#  {'after': 'har faat det Dæataørate antal',
#   'before': 'Rusland . Det konsti tutionelle',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_nordenfjeldsktidende_null_null_19170618_44_69_1',
#   'word': 'demokrati'},
#  {'after': '04 folkestyre . Og dei',
#   'before': 'nu » : det sanne',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_firdafolkeblad_null_null_19361002_31_75_1',
#   'word': 'demokrati'},
#  {'after': 'fra Arneidernes LeksiKotiv . —',
#   'before': 'par stupnar inn marxisme ug',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_firdafolkeblad_null_null_19370226_32_16_1',
#   'word': 'demokrati'},
#  {'after': ', Øog eg trur dei',
#   'before': 'sterke ord um tolkestyre Øog',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_firdafolkeblad_null_null_19370316_32_21_1',
#   'word': 'demokrati'},
#  {'after': 'alt den 17 de. so',
#   'before': 'lm det ikkje smakar av',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_firdafolkeblad_null_null_19370525_32_40_1',
#   'word': 'demokrati'},
#  {'after': '. « Soria Moria-erklæringen Jøtul-hugget',
#   'before': ', mest fundamentale i vårt',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_driva_null_null_20090911_35_104_1',
#   'word': 'demokrati'},
#  {'after': 'som er bygd på nestekjærlighet',
#   'before': 'verdigrunnlag tilbake inn i vårt',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_driva_null_null_20090911_35_104_1',
#   'word': 'demokrati'},
#  {'after': 'er ikke flertallsdiktatur . Demokrati',
#   'before': 'diskusjon for mange , men',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_driva_null_null_20080213_37_19_1',
#   'word': 'demokrati'},
#  {'after': '. Kommunane må For Venstre',
#   'before': 'ha desentralisering og meir lokalt',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_driva_null_null_20090720_39_81_1',
#   'word': 'demokrati'},
#  {'after': '? ( ttv ) (',
#   'before': ': Digitale arenaer og digitalt',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_sandnesposten_null_null_20081030_19_80_1',
#   'word': 'demokrati'},
#  {'after': '1840 - 1850 ( t',
#   'before': 'under lupen : Dandyer og',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_sandnesposten_null_null_20081211_19_92_1',
#   'word': 'demokrati'},
#  {'after': '? 00.10 - 00.40 I',
#   'before': 'terror en trussel mot USAs',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_sandnesposten_null_null_20080710_19_51_1',
#   'word': 'demokrati'},
#  {'after': '. Men å hedre noen',
#   'before': 'en av hjørnestenene i dagens',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_sandnesposten_null_null_20090428_20_32_1',
#   'word': 'demokrati'},
#  {'after': 'og kvinnefrigjering Raudt Høyanger Ottar',
#   'before': 'humanitær operasjon som skal skape',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_ytresogn_null_null_20091030_12_81_1',
#   'word': 'demokrati'},
#  {'after': '. Dei slåst for sentrale',
#   'before': 'og viktige i eit levande',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_ytresogn_null_null_20091106_12_83_1',
#   'word': 'demokrati'},
#  {'after': '. tok Mjømna Bygdelag over',
#   'before': 'Med Mjømna praktiserer såleis direkte',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_ytresogn_null_null_20091106_12_83_1',
#   'word': 'demokrati'},
#  {'after': '. Der har eg god',
#   'before': 'interessante er korleis ein byggjer',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_ytresogn_null_null_20091113_12_85_1',
#   'word': 'demokrati'},
#  {'after': ', sier Vidar Kleppe .',
#   'before': 'vi kan tåle i et',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_helgelandarbeiderblad_null_null_19990628_70_144_1',
#   'word': 'demokrati'},
#  {'after': '. Norge har til nå',
#   'before': 'for sitt arbeid for mer',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_helgelandarbeiderblad_null_null_19990715_70_159_1',
#   'word': 'demokrati'},
#  {'after': 'og integrasjon i Europa ,',
#   'before': 'ikke deler våre visjoner om',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_helgelandarbeiderblad_null_null_19990715_70_159_1',
#   'word': 'demokrati'},
#  {'after': 'behøver en kritisk , kildekritisk',
#   'before': 'arbeidsplass . Vårt samfunn og',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_helgelandarbeiderblad_null_null_19990726_70_168_1',
#   'word': 'demokrati'},
#  {'after': 'med en trebiebet av for',
#   'before': 'et engelsk blad . Et',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_oeieren_null_null_19121120_5_87_1',
#   'word': 'demokrati'},
#  {'after': 'har vi intet anbet suste',
#   'before': ', men for det tyste',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_oeieren_null_null_19171003_10_76_1',
#   'word': 'demokrati'},
#  {'after': 'blev ingen kamp mellem samfundsklasserne',
#   'before': 'pligter at opfylde . Wergelands',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_oeieren_null_null_19080725_1_48_1',
#   'word': 'demokrati'},
#  {'after': 'er bet , fom af',
#   'before': 'ilke . sæfenåmerfet ved Wergelands',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_oeieren_null_null_19080725_1_48_1',
#   'word': 'demokrati'},
#  {'after': ', og i alle fall',
#   'before': 'har vi da ? Ikke',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_sunnmorsposten_null_null_19630308_81_57_1',
#   'word': 'demokrati'},
#  {'after': '. ■ NYRETFRA Etter Standals',
#   'before': 'er det høyeste uttrykk for',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_sunnmorsposten_null_null_19630312_81_60_1',
#   'word': 'demokrati'},
#  {'after': 'å kjenne . Til hjelp',
#   'before': 'komiteens gjester og lærte vårt',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_sunnmorsposten_null_null_19630320_81_67_1',
#   'word': 'demokrati'},
#  {'after': ', berre eit overnasjonalt organ',
#   'before': 'Berre det vil vere sant',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_sunnmorsposten_null_null_19630326_81_72_1',
#   'word': 'demokrati'},
#  {'after': ', gjennom sin negative holdning',
#   'before': 'har kjempet for frihet og',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_sandefjordsblad_null_null_19570209_66_34_1',
#   'word': 'demokrati'},
#  {'after': '. Jeg fikk nesten lyst',
#   'before': 'allerede var begynt å innføra',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_sandefjordsblad_null_null_19570305_66_54_1',
#   'word': 'demokrati'},
#  {'after': ', og det er selve',
#   'before': 'for et stabilt og levende',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_sandefjordsblad_null_null_19570327_66_73_1',
#   'word': 'demokrati'},
#  {'after': ', hvor velgerne ikke bør',
#   'before': 'psykologiske . virkninger i et',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_sandefjordsblad_null_null_19570904_66_203_1',
#   'word': 'demokrati'},
#  {'after': ': Det er noen hundretusentalls',
#   'before': 'uvettig . Mer åpenhet og',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_dagbladet_null_null_20120907_144_247_1',
#   'word': 'demokrati'},
#  {'after': 'og åpenhet . Popwlir Historia',
#   'before': 'egypterne seiv å kjempe for',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_dagbladet_null_null_20120901_144_241_1',
#   'word': 'demokrati'},
#  {'after': 'ikke trenger å være fiender',
#   'before': 'beviset på at gastronomi og',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_dagbladet_null_null_20120901_144_241_1',
#   'word': 'demokrati'},
#  {'after': 'ikke trenger å være bitre',
#   'before': 'eksempel på at gastronomi og',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_dagbladet_null_null_20120901_144_241_1',
#   'word': 'demokrati'},
#  {'after': 'er for noe ? Det',
#   'before': 'du egentlig hva demokrat og',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_fredriksstadblad_null_null_19941130_106_278_1',
#   'word': 'demokrati'},
#  {'after': 'er bare et annet ord',
#   'before': '? Det du tror er',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_fredriksstadblad_null_null_19941130_106_278_1',
#   'word': 'demokrati'},
#  {'after': 'bare er blitt et politisk',
#   'before': 'er det vi tror er',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_fredriksstadblad_null_null_19941130_106_278_1',
#   'word': 'demokrati'},
#  {'after': 'er i fare og fremdeles',
#   'before': 'allmuen mener med et riktig',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_fredriksstadblad_null_null_19941130_106_278_1',
#   'word': 'demokrati'},
#  {'after': '» brer seg fra toppen',
#   'before': 'bemerkelsesverdige trekk i vårt «',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_ostlandsposten_null_null_19650304_85_56_1',
#   'word': 'demokrati'},
#  {'after': '. Smånytt fra Hedrum Sogneprest',
#   'before': 'ikke bør forekomme i et',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_ostlandsposten_null_null_19650308_85_59_1',
#   'word': 'demokrati'},
#  {'after': 'i utviklingen fra samtalene og',
#   'before': 'er god tradisjon og sunt',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_ostlandsposten_null_null_19650727_85_169_1',
#   'word': 'demokrati'},
#  {'after': 'og kongemakt i Norge og',
#   'before': 'ta med i beregningen at',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_ostlandsposten_null_null_19650729_85_171_1',
#   'word': 'demokrati'},
#  {'after': '. - Vi opplever nå',
#   'before': 'spørsmål om hva som er',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_opplandarbeiderblad_null_null_19910311_68_59_1',
#   'word': 'demokrati'},
#  {'after': 'i Kuwait Taif , Saudi-Arabia',
#   'before': 'Sunday Times . Emiren lover',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_opplandarbeiderblad_null_null_19910311_68_59_1',
#   'word': 'demokrati'},
#  {'after': 'må føres videre , og',
#   'before': 'påskeuka . - Kampen for',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_opplandarbeiderblad_null_null_19910319_68_66_1',
#   'word': 'demokrati'},
#  {'after': 'hvis ikke politikken er attraktiv',
#   'before': 'Vi får ikke et levende',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_opplandarbeiderblad_null_null_19910322_68_69_1',
#   'word': 'demokrati'},
#  {'after': ', iutret av ulykken og',
#   'before': '« Måtte det nye Norges',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_morgenbladet_null_null_19460608_128_130_1',
#   'word': 'demokrati'},
#  {'after': 'kan utrette , og Utenriksdepartementet',
#   'before': 'å vise hva et lite',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_morgenbladet_null_null_19460613_128_133_1',
#   'word': 'demokrati'},
#  {'after': '- men uten konge »',
#   'before': 'vil gjøre India til et',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_morgenbladet_null_null_19460615_128_135_1',
#   'word': 'demokrati'},
#  {'after': ', s » m Amerika',
#   'before': 'å gjøre India til et',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_morgenbladet_null_null_19460615_128_135_1',
#   'word': 'demokrati'},
#  {'after': 'i forkant opplevde vi ikke',
#   'before': 'kommunene sist . het og',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_lillehammerbyavisno_null_null_20110915_6_32_1',
#   'word': 'demokrati'},
#  {'after': ', men er det sannheten',
#   'before': 'kamp mot diktatur og for',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_lillehammerbyavisno_null_null_20110915_6_32_1',
#   'word': 'demokrati'},
#  {'after': '. NHO Innlandet arbeider aktivt',
#   'before': 'inn og fikk innført såkalt',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_lillehammerbyavisno_null_null_20110915_6_32_1',
#   'word': 'demokrati'},
#  {'after': '. Vi vet god historisk',
#   'before': 'fare for både sikkerhet og',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_lillehammerbyavisno_null_null_20111103_6_39_1',
#   'word': 'demokrati'},
#  {'after': 'som Norge . Lars Vidar',
#   'before': 'skal følgene retningslinjer i et',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_arendalstidende_null_null_20110226_5_16_1',
#   'word': 'demokrati'},
#  {'after': 'blir " overkjørt " av',
#   'before': 'eller at det " lokale',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_arendalstidende_null_null_20110326_6_24_1',
#   'word': 'demokrati'},
#  {'after': '. Politikerne la Valen-planen død',
#   'before': 'tisk dette som er overskriften',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_arendalstidende_null_null_20110326_6_24_1',
#   'word': 'demokrati'},
#  {'after': 'og skjønn . Det er',
#   'before': 'overkjøring " av det lokale',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_arendalstidende_null_null_20110326_6_24_1',
#   'word': 'demokrati'},
#  {'after': 'har begynt å vakle .',
#   'before': 'innrømmelse av at det parlamentariske',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_morgenposten_null_null_19630819_103_190_1',
#   'word': 'demokrati'},
#  {'after': '. Før sin død syntes',
#   'before': 'bryte ryggen på Italias parlamentariske',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_morgenposten_null_null_19630819_103_190_1',
#   'word': 'demokrati'},
#  {'after': 'skal være nokså varsom med',
#   'before': 'Jeg tror en i et',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_morgenposten_null_null_19630826_103_196_1',
#   'word': 'demokrati'},
#  {'after': 'som en styreform der flertallet',
#   'before': 'seg vel for å definere',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_morgenposten_null_null_19630826_103_196_1',
#   'word': 'demokrati'},
#  {'after': '. Med dei demokratiske tradisjonar',
#   'before': 'i land med relativt skjøre',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_synstemore_null_null_20100923_41_34_1',
#   'word': 'demokrati'},
#  {'after': 'og dei verdiar nasjonen vår',
#   'before': 'Eidsvolldagen som grunnlaget for vårt',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_synstemore_null_null_20100520_41_19_1',
#   'word': 'demokrati'},
#  {'after': '? Det er eg ikkje',
#   'before': 'Kva ville det vere slags',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_synstemore_null_null_20100107_40_1_1',
#   'word': 'demokrati'},
#  {'after': '. ÅREMÅL Jorun Nystøyl butikkeigar',
#   'before': 'ikkje bør finnast i eit',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_synstemore_null_null_20100225_40_8_1',
#   'word': 'demokrati'},
#  {'after': '. Hr. Doktor Kreybergs Artikkel',
#   'before': 'fil * , Redaktsr !',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_romsdalsamtstidende_null_null_19090331_71_38_1',
#   'word': 'demokrati'},
#  {'after': '. Industrinyft . 19 :',
#   'before': 'Orgelkonsert . 18 : Industrielt',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_sognogfjordane_null_null_19620105_31_2_1',
#   'word': 'demokrati'},
#  {'after': ', på tvers av ekspertsyn',
#   'before': 'verta til røyndom i vårt',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_sognogfjordane_null_null_19620219_31_21_1',
#   'word': 'demokrati'},
#  {'after': 'holder valg i disse dager',
#   'before': 'forfallen . India verdens største',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_sognogfjordane_null_null_19620226_31_24_1',
#   'word': 'demokrati'},
#  {'after': '» , vi nar ikke',
#   'before': 'nar regjert under navn «',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_hedemarkensamtstidende_null_null_19200920_74_215_1',
#   'word': 'demokrati'},
#  {'after': 'og socialisering av de ,',
#   'before': 'magt . Krav om økonomisk',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_hedemarkensamtstidende_null_null_19200525_74_116_1',
#   'word': 'demokrati'},
#  {'after': 'grundsyn , som ikke viker',
#   'before': 'Hoin « trib 03 samlende',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_hedemarkensamtstidende_null_null_19200324_74_71_1',
#   'word': 'demokrati'},
#  {'after': ', den var eii lysets',
#   'before': 'for ret og retfærdighet og',
#   'urn': 'https://www.nb.no/items/URN:NBN:no-nb_digavis_hedemarkensamtstidende_null_null_19200628_74_145_1',
#   'word': 'demokrati'}]

# %%
curl "https://api.nb.no/catalog/v1/items?q=hamsun^&filter=mediatype:
b^%^C3^%^B8ker^&filter=digital:Ja^&
    filter=contentClasses^%^3Ajp2^&a
    ggs=mediatype^&aggs=year^%^3A9999^&
    aggs=literaryform^&aggs=languages^%^3A9999^&aggs=bibliography^&aggs=ddc1^&size=18^&
    digitalAccessibleOnly=true^&profile=wwwnbno" ^
  -X "OPTIONS" ^
  -H "authority: api.nb.no" ^
  -H "accept: */*" ^
  -H "access-control-request-method: GET" ^
  -H "access-control-request-headers: authorization" ^
  -H "origin: https://www.nb.no" ^
  -H "user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36" ^
  -H "sec-fetch-mode: cors" ^
  -H "sec-fetch-site: same-site" ^
  -H "sec-fetch-dest: empty" ^
  -H "referer: https://www.nb.no/" ^
  -H "accept-language: nb-NO,nb;q=0.9,en-US;q=0.8,en;q=0.7,no;q=0.6,nn;q=0.5" ^
  --compressed
