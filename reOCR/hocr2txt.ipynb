# %%
from zipfile import ZipFile
from bs4 import BeautifulSoup
import os

# %% [markdown]
# with ZipFile('first_reOCR.zip') as z:
#     z.extractall()

# %%
def soup_to_lines(soup):
    """Returns the lines in a hocr-file, typically representing one page"""
    para_text = []
    for para in soup.find_all('p', {'class': 'ocr_par'}):
        for line in para.find_all('span', {'class': 'ocr_line'}):
            para_text.append(" ".join([w.text for w in line.find_all('span', {'class':'ocrx_word'})]))
    return para_text

# %%
def folder_to_book:
pages = dict()
contents = os.walk('ocrfiles')
for _,_,files in contents:
    for file in files:
        with open(os.path.join('ocrfiles', file), encoding = 'utf-8') as f:
            soup = BeautifulSoup(f.read())
            pages[file] = soup_to_lines(soup)

# %%
pages
# Out:
# {'2014010224001_side10.xml': ['7TI1',
#   'VDa han hørte, jeg var gridskpaa at eie den, sendte han',
#   'mig fra Christiania til Souvenir det eneste Exemplar',
#   'han medhavde.',
#   'Af de Par Dage, han glædede mig med sin Nærvæ-',
#   'relse, lærte jeg ham at kjende som en Mand, der brugte',
#   'sine Øine, hvor han foer frem. Af ovevnævnte hans Pil-',
#   'legrimeren i Norge sees, at han dog har seet endeel af',
#   'det til Fjelds og Fjære. Vel foer han her i Landet',
#   'med Sigvard Snarensvends Fart, men de Bemærkninger,',
#   'han paa sine Vandringer i Nye Holland har gjort, rise',
#   'Jagttagelsesevne. Han vil nok ogsaa udgive sin Reise i',
#   'Norge, som meget ligner, sagde han, Nye Seeland, som',
#   'han ogsaa besøgte. Fornemmelig reiste han i Nye Hol-',
#   'land langs Kysten, og i det Indre af Landet, saavidt',
#   'man hidtil har kunnet indtrænge, ppt. 60  so engelske',
#   'Mile. Bogen er egentligst skreven, siger han, for dem',
#   'som fra England ville nedsætte sig i Nye Holland, emi-',
#   'grere kalder han det, og der ville blive Nybyggere (Set-',
#   'lers); der var ikke mindste Gasconnade eller Rodomontade',
#   'at mærke i Mandens hele Tale og Væsen. Han trac-',
#   'terede saare behageligt et Instrument, det han kaldede',
#   'Flageolet, troer jeg. Da det er mig saare vanskeligt at',
#   'forstaae en indfødt Englænders Pronunciation, talede han',
#   'Tydsk og Fransk, som for mit Øre klingede heel forstaae-',
#   'ligt. »Kjender man i England Legenden om Jerusalems',
#   'Skomager?» spurgte jeg ham, »Javist» var Svaret,',
#   '»ogsaa under Navn af den evige Jøde.» Jeg: »Saa er',
#   'De da den selvstændige Jerusalems Skomager.» – Bogen',
#   'er inddeelt i 7 Capitler; jeg har udpillet af disse det,',
#   'jeg troer at have almeen Interesse, udeladende det Belæ-',
#   'rende for Nybyggerne, da neppe Nogen af os Nordmænd',
#   'vil emigrere til Australien, ikke selv engang den forag-',
#   'telige Person, som for flere Aar tilbage tilskrev mig',
#   'et anonymt Brev, hvori han satte sin Forstand og Hjer-',
#   ' '],
#  '2014010224001_side11.xml': ['rx',
#   'te en sand Skamstøtte, om jeg hadde, efter hans eget',
#   'Forlangende ladet ham den offentligen reise. Men om',
#   'den, som søger Ære i Skjændsel, bør man tie gvar, for-',
#   'agte og vnke. Brevet var et Svar paa, at jeg i et af',
#   'mine Indsendter i Morgenbladet havde yttret, at Norge',
#   'befandt sig saare vel ved sin Constitution, og at den, der',
#   'det ei gjorde, kunde længe nok emigrere til Amerika.',
#   'Bretons Cxcursions ere ikke forfattede som en Dag-',
#   'bog. Datum og Aar, naar han forlod London, anføres',
#   'ei, men tidlig i Aaret 1830 tiltraadte han Reisen.',
#   '1ste Cap. begynder med: »Skibe afgaae til Coloni-',
#   'en i Australien paa alle Aarets Tider; men de ere langt-',
#   'fra ikke saasnart færdige, som der averteres.»',
#   'Efter dette Foreløbige, som et avant propos, vil',
#   'jeg da følge brave Breton, deels ertrahere af ham, deels',
#   'oversætte Ord til andet af ovenmeldte Reise.'],
#  '2014010224001_side12.xml': [],
#  '2014010224001_side13.xml': [' ',
#   'WRiong Reise gik først til Swanbay, vest paa',
#   'Ny-Holland. Hans Tour til og fra Ny-Holland',
#   'var blandt de nu ikke faa heldige, 4 Maaneder',
#   'frem, og 4 tilbage. Man maa nu have fundet',
#   'ret Cours at søge Passaterne. 400 Spd. Norsk',
#   'for Koie i Kahytten, 200 Spd. for ditto i Stern-',
#   'Cabin. Zooo ere nu Colonisterne i Ny-Holland.',
#   'Naar Skibe skulle afgaae til Ny-Holland, da ud-',
#   'basune the agents o0. ventelig Skibsmæglerne, i',
#   'Londons Aviser, for at faae jo flere jo bedre Pas-',
#   'sagerer, hvor godt man har det ombord, som om',
#   'man var i Abrahams Skjød. »Den Agent for',
#   'det Skib, jeg fulgte,» skriver Breton, »gav mig',
#   'sit Æresord paa hvor comfortable 0. herligt og',
#   'begvemmeligt jeg skulde have det ombord – gid',
#   'han saa trives, som han holdt sit Æresord! Thi',
#   'ved bedærvet Kjød, Flæsk, Brød ic., blev ombord',
#   'saare vel sørget for, at ingen Passageer foraad',
#   'sig.» Jøvrigt falder Tiden slet ikke lang paa',
#   'Skibet, man passiarer, spiller Skak, læser, gjør si-'],
#  '2014010224001_side14.xml': ['2',
#   'ne Betragtninger over Hav og Himmel, og hvad',
#   'man der bliver vaer, og nedskriver dem.',
#   'Ovennævnte Agent havde averteret i Avisen',
#   'til ydermere Trøst og Husvalelse for de Medrei-',
#   'sende, at en duelig Chirurg var blandt Passage-',
#   'rerne, som ogsaavilde emigrere til Ny-Holland. Bre-',
#   'ton gjorde hans Bekjendtskab ombord. Hvo var vel',
#   'denne Doctor legitime promotusø Jo det var en',
#   'Apothekerdreng, der kun havde lært at støde Pul-',
#   'ver. Han skulde engang aarelade, hvilket han',
#   'aldrig før havde gjort, anlagde Bindselet neden-',
#   'for, istedetfor oventil. Han skulde engang aare-',
#   'lade en Hest, fandt ei Aaren – Hesten crepere-',
#   'de. Høorlunde gik det Doetoren? Jo, i Swan-',
#   'bay vilde han vade over en Bæk, kun 2 Alen dyb,',
#   'Doctoren var 2» Alen høi; i Bækken var en smal',
#   'Rende 3 Alen dyb, Doctor Klodrian kunde ei',
#   'svømme 2 a 3 Alen, derfor fandt man ham Da⸗-',
#   'gen efter staaende smukt i Attitude som en Støt-',
#   'te i Renden, med nogle faa Tommer Vand over',
#   'Hovedet. Om han staaer der endnu, død eller',
#   'levende, melder ei vor Autor. Der foer den Au-',
#   'straliske Hypocrates.',
#   'Paa Excursion i Swanbay, nogle Mile (jeg',
#   'vil reducere stedse de Engelske til Norske, 6 En-',
#   'gelske omtrent – 1 Norsk Miil) ind i Landet,',
#   'traf Breton 204 go Indfødte (aborigenes), høie,',
#   'ranke, stærklemmede, vævre, med en Fjeder eller',
#   'et Been eller en Træpind gjennem Næsebrusken'],
#  '2014010224001_side15.xml': ['3',
#   '(oeptuma). Deres Ovinder finge ei Lov at kom-',
#   'me frem, maaskee af Mændenes Jalousie, »dog',
#   'saae vi et og andet sort Qvindehoved titte frem',
#   'mellem Buskene,» (Fo naturaly to W1',
#   'Autois Ord). Mandfolkene vare ellers rede at',
#   'have en tøtø a tetø med Colonistinderne, naar de',
#   'finge Audience.',
#   '»De gjentoge alt, hvad vi sagde, og efterabe-',
#   'de alle vore Gebærder. Nogle af os hørte, at de',
#   'tilraabte os fra Buskene, naar vi ginge forbi:',
#   'go it, ye cripples crut ches are cheap!» (frem',
#   'I Krybere, Krykkerne ere godt Kiøb, eller hvad',
#   'dette Engelske Udtryk vil sige). Breton mener,',
#   'at de Indfødte havde ofte hørt Officierer saa at',
#   'tilraabe dem som ginge at undersøge Landet, og',
#   'at de Indfødte meente, at dette var Englænder-',
#   'nes sædvanlige Maade at hilse hverandre paa.',
#   'Han kunde lagt til: »Mange Tak for Com-',
#   'plimenten!»',
#   'En Reisende fra Danmark spurgte en Norsk',
#   'Jente i en af Fjelddalene, hvad de kaldte det',
#   'Tørklæde, Jentene bære om Hovedet; hun svare-',
#   'de: »Plag, kalla me da.» Han skrev da i sin',
#   'Dagbog: »I Norge kaldes det Tørklæde, Piger-',
#   'ne bære om Hovedet »Plagkallameda». – Det',
#   'skal saamen have været den samme Professor,',
#   'som i sin Reise i Norge 176. skriver: I Norge ædes',
#   'ei Makrel fordi Makrelen æder Matroser.» »Javist',
#   'staaer der saa skrevet. Nu undrer man sig ei'],
#  '2014010224001_side16.xml': ['4',
#   'længere over de Vildes Feiltagelse i Swanbay.',
#   '»Disse Indfødte ere her som overalt i Nye Hol-',
#   'land, saa øvede i Mimik, at de kunde særdeles',
#   'vel forklare sin Mening ved Gebærder.» – De',
#   'ere saare bange for de engelske Hunde, dog de',
#   'selv have Hunde, siger han, men han maa have',
#   'glemt, at han selv beretter, at Colonisterne hidse',
#   'Hundene paa de stakkels Vilde. – Længere hen',
#   'skal mere anfsres om Omgangen af Settlers (Co-',
#   'lonisterne) og de afskyelige Convicter, (I0. de som',
#   'ere dømte til Botanybay) med de arme uskvldige',
#   'Indfødte (natives); dog tager den rettænkende,',
#   'oplyste Breton stedse disse Vilde istørste Forsvar',
#   'mod hine.',
#   'Jordbunden er for det meste god til Dyrk-',
#   'ning der (Sswanbay). Thermometret varierer frag2',
#   'til 105» Fahrenheits Scala – 10 og  320',
#   'Reaumur. Scala pt. pt.',
#   'Han bemærker, at han af saa kolde Nætter',
#   'og en saadan trykkende Hede, og det i Skyggen',
#   'om Dagen, var saa langt fra at befinde sig ilde,',
#   'at han og flere befunde sig saare vel og friske ved',
#   'Nattens Kulde eller Kjølighed. –',
#   'I Maanederne Mai, Juni, Juli og August',
#   '1829 regnede det næsten uophørlig, der var neppe',
#   '1 Times Stands. Da han senere kom til Sid-',
#   'nep, kom Beretning fra Swanbay, at der herske-'],
#  '2014010224001_side17.xml': ['5',
#   'de en stor Tørke. – Baade Øst- og Vestkvsten',
#   'af Nye Holland ere meget udsatte for stærk Tør-',
#   'ke og stor Vandoversvømmelse. –',
#   'Der er overalt i det hele Land de herligste Pro-',
#   'specter (ccenery) og meest romantiske Egne. Dog',
#   'har man gjort baade formeget og forlidet i at be-',
#   'skrive Landet. Mange Englændere ere flyttede til',
#   'Nye Holland, i Tanke, at der var det sande Ntopia–',
#   'Slaraffenland, hvor stegte Duer flyve med Gaf-',
#   'fel og Kniv i Ryggen. Da ere de Emigranter',
#   'ofte blevne storligen bedragne. Oversætteren erindrer',
#   'sig herved Manden, som i Europa ei fik Fred for Fan-',
#   'den og derfor flyttede til Amerika. Did kom han, og',
#   'paa Taget af det første Huus, han der saae, saae han',
#   'Fanden sidde, nu udbrød han: »Havde Jeg',
#   'tænkt, at du ogsaa var her, da havde jeg bleven',
#   'hvor jeg var.» Endog Beretningerne fra det',
#   'ene Sted i Nye Holland til det andet, modsige',
#   'hinanden. Saa skriver Breton Pag. 34: »Jeg',
#   'var i Syd Wales og van Diemens Land 1830.',
#   'Indberetninger fra alle Dele af Landet indløbe,',
#   'at Colonisterne manglede alle Livets Nødvendighe-',
#   'der. Netop paa samme Tid læste jeg et Brevi Sid-',
#   'ney fra en Mand i van Diemens Land til en',
#   'hans Ven i Sidney, hvori han melder: »»Vi',
#   'have slet ingen Mangel paa Fødevarer her, und-',
#   'tagen paa Ingredientser til Fiskesous, send os',
#   'disse, de vilde finde god Afsætning.»»» – »En',
#   'Gentleman kom fra van Diemens Land, forsikkre-',
#   'de, at der var ei et grønt Blad eller Græsstraae'],
#  '2014010224001_side18.xml': ['6',
#   'at see i hele Landet, han havde kun seet den nøg-',
#   'ne Sandstrand, og ei mere af Landet!!! – Bre-',
#   'ton gjorde Reiser ind i Landet, fandt mange Ste-',
#   'der gode Enge, grønne Skove og god Jordbund',
#   '(soil). – Nok herom, thi dette og mere er kun',
#   'for Settlers. –',
#   'Han fandt dog ikke faa Emigranker at leve',
#   'ret fornøiet og lykkelige i van Diemens Land.',
#   'Guvernementet der er saa godt, at Colonien maa',
#   'komme sig.',
#   'Sidney er Hovedstaden i Nye Holland, ikke',
#   'Paramatta. Guverneuren boer der. Breton gjor-',
#   'de flere Excursioner fra Sidney langs Kysten og',
#   'ind i Landet, dog er man hidtil ei længere trængt',
#   'ind i Landet end forbi de saakaldte blaae Bjerge',
#   '20 4 Zo Norske Miil. Han besøgte flere adspredt',
#   'liggende Settlers (Nybyggere) der, som alle mod-',
#   'tage ham med største Hospitalitet. Det gaaer her,',
#   'som allevegne, hvor Folk boe isolerede, Verten er',
#   'gladere ved Besøget end Gjæsten. Oversætteren',
#   'vil følge ham paa disse forskjellige Excursioner,',
#   'og bemerke deraf det lidet, som kan interessere',
#   'andre Læsere, end dem, som ville bygge og boe',
#   'der. Man maa reise til Hest, bestige Fjeldene',
#   'til Fods, Blvouaguere ofte. Høiere Bjerge end',
#   '6ooo norske Fod ere hidtil ikke trufne. Skove,',
#   'uigjennemtrængelige formedelst Snylteplanter eller',
#   'Værxter, der have hvasse Torne, omslynge Træerne',
#   'til Toppene, ofte 70  80 Norske Alen høie. De'],
#  '2014010224001_side19.xml': ['-',
#   'fleste Træer ere en Slags pinus (Furu). Han',
#   'traf paa en perpendiculair Hule, som ved nedka-',
#   'stede store Stene maaltes at være omtrent 60o',
#   'N. Alen dyb; thi man hørte Stenene falde i Vand.',
#   'Høiden beregnedes, som bekjendt, ved Tiden af',
#   'faldende Legemer. Mangfoldige af de store Flag',
#   'germuus, som boei Hulens Vægge, forstyrredes–det',
#   'var hele Opdagelsen. Paa mange græsrige Slet-',
#   'ter, omtrent 100o N. Alen over Havet, fandt han',
#   'hypvigen de saakaldte Troldringe (Pairy-',
#   'Rings). Han beskriver dem saaledes, som Overs.',
#   'har nogle Gange her seet dem paa græsrig Mark,',
#   'næsten runde Ringe af 1 Fods Bredde, og hele',
#   'Ringens Diameter omtrent nogle Alen. Inden',
#   'Ringen var Jorden bar, som om alt Græas der',
#   'var afbrændt. Jeg troer, at Botaniker mene, at',
#   'det er en Slags microscopisk Plante eller Mos,',
#   'der saaledes, ligesom et Slags Paddehatte, i en',
#   'Hast, ja i een Nat, voxe og fortære Græsset.',
#   'Han traf kun eengang paa en Flok af Aborigi',
#   'rs (de Vilde), omtrent 6o i Tallet; han var',
#   'selv 3die, og 7 af Convicterne som Tjenere (Con-',
#   'victer kaldes de til Ny Holland forviste Domfæld-',
#   'Opvartere, siger han:»En passent maa jeg lade',
#   'dem (Convicterne) vederfares den Ret, at jeg al-',
#   'drig saae Folk opføre sig bedre, og uagtet de of-',
#   'te maatte gaae 35 Engelske Mile (6 N. Mile)',
#   'ligviis havde man valgt af de Bedste.',
#   'B']}
