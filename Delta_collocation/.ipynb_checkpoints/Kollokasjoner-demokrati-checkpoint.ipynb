# %% [markdown]
# ## Oppstart

# %% [markdown]
# ### Preamble
#
# Contains imports and some utility code.

# %%
from dhlab.module_update import update, css, code_toggle

# %%
import dhlab.graph_networkx_louvain as gnl
import dhlab.nbtext as nb
import networkx as nx
# %matplotlib inline

# %%
import pandas as pd

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
def frame_sort(frame, by=0):
    return frame.sort_values(by=by, ascending=False)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Kollokasjoner eller assosiasjoner
#
# Hvilke ord opptrer et ord sammen med innenfor et korpus?

# %% [markdown]
# ### Define a corpus
#
# Bruk gjerne Dewey eller temaord for å definere korpuset, hold det forholdsvis lite rundt 200 bøker.

# %%
collword = 'bil'

# %%
korpus = nb.book_urn(words=[collword], ddk='8%', period=(1960, 2020), limit=500)
len(korpus)
# Out:
# 500

# %% [markdown]
# Kommandoen nb.frame() kan benyttes på en hel del output. Gir en fin oversikt over data, og kan brukes .head() for å se de første eksemplene.

# %%
nb.frame(korpus).head(10)
# Out:
#                0                        1  \
# 0  2012091308043         Stenersen, Helge
# 1  2012061305090             Kerr, Philip
# 2  2012041308040            Mehren, Stein
# 3  2016090848075           Hagerup, Klaus
# 4  2007072404001              Krog, Helge
# 5  2014082108002             Aamodt, John
# 6  2014102708033  Pullein-Thompson, Diana
# 7  2008091701001           Ludlum, Robert
# 8  2015052208194             Wolf, Stefan
# 9  2015042808167             Førde, Bjørn
#
#                                         2     3
# 0       Har'u sty'en? Glade vers og andre  1975
# 1                             Skogens øye  2012
# 2               Dikt for enhver som våger  1973
# 3                     Høyere enn himmelen  1992
# 4        Meninger om religion og politikk  1971
# 5                                Nostalgi  1999
# 6                          Black Princess  1977
# 7                        Matareser-hevnen  1998
# 8  TROL-gjengen og det mystiske spøkelset  1988
# 9                        Vi holder sammen  1987

# %%
nb.urn_concordance(word=collword, urns=korpus)
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012091308043?searchText=bil' target='_blank' style='text-decoration:none'>Har'u sty'en? Glade vers og andre, Stenersen, Helge, 1975</a>
#                 </td>
#                 <td>buss og</td>
#                 <td>bil</td>
#                 <td style='text-align:left'>None</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012061305090?searchText=bil' target='_blank' style='text-decoration:none'>Skogens øye, Kerr, Philip, 2012</a>
#                 </td>
#                 <td>pelskåper og kjørte i hennes</td>
#                 <td>bil</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012061305090?searchText=bil' target='_blank' style='text-decoration:none'>Skogens øye, Kerr, Philip, 2012</a>
#                 </td>
#                 <td>kroppene sine i herr Vodyannoys</td>
#                 <td>bil</td>
#                 <td style='text-align:left'>og passerte usynlige forbi politimannen</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012061305090?searchText=bil' target='_blank' style='text-decoration:none'>Skogens øye, Kerr, Philip, 2012</a>
#                 </td>
#                 <td>Lyden av en</td>
#                 <td>bil</td>
#                 <td style='text-align:left'>utenfor fikk Philippa til å</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012061305090?searchText=bil' target='_blank' style='text-decoration:none'>Skogens øye, Kerr, Philip, 2012</a>
#                 </td>
#                 <td>insekter mot frontruten på en</td>
#                 <td>bil</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012061305090?searchText=bil' target='_blank' style='text-decoration:none'>Skogens øye, Kerr, Philip, 2012</a>
#                 </td>
#                 <td>det en mann ved Laylas</td>
#                 <td>bil</td>
#                 <td style='text-align:left'>og fiklet med låsen .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2
# %%
small_window = 5
large_window = 10

# %%
def collpart(collword, urns, win = 5, limit = 10000):
    return nb.urn_coll(collword, urns = korpus, after = win, before = win, limit = 10000)

# %% [markdown]
# Kollokasjonen er en såkalt **dataframe** som kan undersøkes med `.head()` som ovenfor.

# %%
small = collpart(collword, nb.pure_urn(korpus), win = 5)
large = collpart(collword, nb.pure_urn(korpus), win = 10)

# %% [markdown]
# ## Finn referanse
#
# Det er flere måter å sammenligne på. En er å bruke bokhylla selv om som referanse. For å hente ut ord fra bokhylla brukes kommandoen `totals(<antall ord>)`. Korpuset selv kan også benyttes, for eksempel med kommandoen `aggregate_urns(<korpusdefinisjon>)`.

# %% [markdown]
# #### Sammenlign

# %% [markdown]
# Vi har nå tre frekvenslister som kan sammenlignes med hverandre. For å lette sammenlign normaliseres dem. Kommandoen for normalisering er `normalize_corpus_dataframe(<frekvensliste>)`

# %% [markdown]
# nb.normalize_corpus_dataframe(korpus_agg)
# nb.normalize_corpus_dataframe(tot)
# nb.normalize_corpus_dataframe(small)
# nb.normalize_corpus_dataframe(large)

# %% [markdown]
# Inspiser dataene etter normalisering

# %% [markdown]
# ### Kollokasjonen

# %%
small.head()
# Out:
#        0
# .   2638
# en  2321
# ,   1773
# i   1160
# og  1086

# %%
large.head()
# Out:
#        0
# .   5392
# ,   3414
# en  2905
# og  2202
# i   1863

# %% [markdown]
# Kollokasjonen *coll* har gjennomgående høyere verdier, noe som sannsynligvis skyldes at det er færre ord.

# %% [markdown]
# #### Utfør sammenligning
#
# For sammenligning måles forskjellen på *coll* med referansen. Forskjellen måles ved å dividere hvert ords frekvens ikollokasjonen på frekvensen ordet har i referansen.
#
# $$\textrm{assosiasjons-styrke}(w) = \frac{\textrm{coll}(w)}{\textrm{referanse}(w)}$$
#
# Divisjonen pr.ord gjøres av Python - resultat sorteres og legges i variabelen `coll_assoc`

# %%
delta = pd.DataFrame()

# %%
delta['small'] = small[0]
delta['large'] = large[0]

# %%
delta['ratio'] = small[0]/large[0]

# %%
#delta['log'] = np.log(delta['ratio'])

# %%
#delta['score'] = delta['ratio'] * delta['log']

# %%
delta[(delta['small'] > 2) & (delta['ratio'] > 0.6)].sort_values(by='ratio', ascending=False)
# Out:
#           small  large     ratio
# kostbar       3      3  1.000000
# japansk       4      4  1.000000
# kamerat       5      5  1.000000
# fjellene      4      4  1.000000
# trikk         4      4  1.000000
# ...         ...    ...       ...
# langsomt     11     18  0.611111
# fart         25     41  0.609756
# penger       14     23  0.608696
# satte        17     28  0.607143
# inn         197    325  0.606154
#
# [520 rows x 3 columns]

# %%
delta.loc[[',','.','og','!', '?']]
# Out:
#     small  large     ratio
# ,    1773   3414  0.519332
# .    2638   5392  0.489243
# og   1086   2202  0.493188
# !      61    138  0.442029
# ?     462    920  0.502174

# %%
delta_max = delta[delta.small < delta.large][delta.small > 0][delta.ratio > 0.6].sort_values(by='ratio', ascending=False)

# %%
delta_const = delta[delta.small > 2][delta.ratio > 0.6].sort_values(by='ratio', ascending=False)

# %%
delta_max.head(20)
# Out:
#             small  large     ratio
# leie           29     30  0.966667
# stjålet        35     37  0.945946
# skaffe         14     15  0.933333
# én             28     30  0.933333
# henter         13     14  0.928571
# egen          163    176  0.926136
# sendt          12     13  0.923077
# Wallanders     10     11  0.909091
# gul            10     11  0.909091
# amerikansk      9     10  0.900000
# lånt            9     10  0.900000
# tuter           9     10  0.900000
# leide          26     29  0.896552
# tutet          25     28  0.892857
# svinge          8      9  0.888889
# Deres           8      9  0.888889
# byttet          8      9  0.888889
# ny             76     86  0.883721
# kjøpe          29     33  0.878788
# utfor           7      8  0.875000

# %%
delta_const
# Out:
#           small  large     ratio
# kostbar       3      3  1.000000
# japansk       4      4  1.000000
# kamerat       5      5  1.000000
# fjellene      4      4  1.000000
# trikk         4      4  1.000000
# ...         ...    ...       ...
# langsomt     11     18  0.611111
# fart         25     41  0.609756
# penger       14     23  0.608696
# satte        17     28  0.607143
# inn         197    325  0.606154
#
# [520 rows x 3 columns]

# %%
delta_max.head(50).index
# Out:
# Index(['leie', 'stjålet', 'skaffe', 'én', 'henter', 'egen', 'sendt',
#        'Wallanders', 'gul', 'amerikansk', 'lånt', 'tuter', 'leide', 'tutet',
#        'svinge', 'Deres', 'byttet', 'ny', 'kjøpe', 'utfor', 'varm', 'stanser',
#        'passerer', 'tvers', 'dyr', 'sitter', 'fin', 'parkert', 'hvilken',
#        'stjal', 'kjøper', 'Jenny', 'hører', 'turen', 'diger', 'tjue', 'type',
#        'passere', 'tilhørte', 'slags', 'motsatt', 'fremmed', 'farens',
#        'påkjørt', 'hver', 'ligget', 'svingen', 'Joanna', 'starter', 'hu'],
#       dtype='object')

# %%
delta_const.head(50).index
# Out:
# Index(['kostbar', 'japansk', 'kamerat', 'fjellene', 'trikk', 'kvar', 'borti',
#        'ringer', 'oppmerksom', 'klimaanlegg', 'Marinos', 'spør', 'overkjørt',
#        'stjele', 'leier', 'Brodys', 'ventende', 'stige', 'oberstens',
#        'Dolders', 'Torstenssons', 'Ivans', 'ensom', 'Merket', 'elektrisk',
#        'Strangs', 'baki', 'inni', 'ambulanse', 'avgarde', 'utafor', 'iltert',
#        'Pen', 'flunkende', 'kapre', 'hende', 'bakenden', 'Nancys', 'suser',
#        'sivil', 'høyrde', 'krevde', 'per', 'ukjent', 'køyrde', 'Flemings',
#        'Bodils', 'Connors', 'Wolffs', 'brennende'],
#       dtype='object')

# %% [markdown]
# # Visualiser med en ordsky
#
#
# Visualiseringen trives best med tall mellom 0 og 1, så assosiasjonene divideres på summen av dem for å få til det. Ordskyene lages med kommonandoen `cloud(<data>)`. Pass på å ikke ta med alt for mange; det kan gi feilsituasjoner.

# %%
nb.cloud(nb.frame(delta_max.ratio))

# %%
nb.cloud(nb.frame(delta_const.head(150).small/delta_const.small.sum()))
