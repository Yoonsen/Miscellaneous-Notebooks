# %%
import dhlab.module_update as mu
mu.update('dhlab_v2')
mu.css('css.css')
# Out:
# Updated file `C:\Users\larsj\Documents\GitHub\Miscellaneous-Notebooks\DHlab_språkbanken\dhlab_v2.py`
# <style>p {
#     font-size:1.2em;
#     color : #223355;
# }
# h1, h2, h3, h4, h5, h6 {
#     color:#3344aa;
#
# }
# html {
#     margin-left:10%;
#     margin-right:5%;
# }
#
# body {
#     counter-reset: h2counter;
# }
# h1 {
#     counter-reset: h2counter;
# }
# h2:before {
#     content: counter(h2counter) ".\0000a0\0000a0";
#     counter-increment: h2counter;
#     counter-reset: h3counter;
# }
# h3:before {
#     content: counter(h2counter) "." counter(h3counter) ".\0000a0\0000a0";
#     counter-increment: h3counter;
# }
# </style>

# %%
import dhlab_v2 as d2

# %% [markdown]
# foreslår make_corpus

# %%
corpus = d2.document_corpus(author = "Amalie Skram")
corpus
# Out:
#                                    urn  \
# 0  URN:NBN:no-nb_digibok_2018062805029
# 1  URN:NBN:no-nb_digibok_2006081000050
# 2  URN:NBN:no-nb_digibok_2007121304030
# 3  URN:NBN:no-nb_digibok_2009042810003
# 4  URN:NBN:no-nb_digibok_2020112548105
# 5  URN:NBN:no-nb_digibok_2007112804057
# 6  URN:NBN:no-nb_digibok_2015062508159
# 7  URN:NBN:no-nb_digibok_2020060448001
# 8  URN:NBN:no-nb_digibok_2014022708239
# 9  URN:NBN:no-nb_digibok_2007110500083
#
#                                                title  \
# 0                     Hellemyrsfolket. Del 2 : Noter
# 1                                      Lucie : roman
# 2  Sivert Skuteløs : fritt etter Amalie Skrams "T...
# 3                                  S.G. Myre : roman
# 4  Hellemyrsfolket : av Amalie Skram ; redaktør S...
# 5  Norske kvinnetekster 1600-1900 : "først kvinde...
# 6                                     Constance Ring
# 7                               Professor Hieronimus
# 8                                       Fortellinger
# 9                                           Julehelg
#
#                                              authors  \
# 0  Skram, Amalie / Osuldsen, Johan / Berntzen, Ju...
# 1                                      Skram, Amalie
# 2                  Staalesen, Gunnar / Skram, Amalie
# 3                                      Skram, Amalie
# 4            Wilhelmsen, Sverre Chr. / Skram, Amalie
# 5  Garborg, Hulda / Hareide, Karen / Grytten, Ing...
# 6                                      Skram, Amalie
# 7                                      Skram, Amalie
# 8                                      Skram, Amalie
# 9                                      Skram, Amalie
#
#                                  oaiid                           sesamid  \
# 0  oai:nb.bibsys.no:999919916090902202  353ee8a7177b559168af12fe640c1ac5
# 1  oai:nb.bibsys.no:997530017804702202  3027a87fc46b705aea2c397bc14f0a78
# 2  oai:nb.bibsys.no:999423628294702202  d6cd07adad7cfc8517fe80134e93acff
# 3  oai:nb.bibsys.no:999609014854702202  58adf541ce3a94d12e883cc44f17b3ba
# 4  oai:nb.bibsys.no:999920098304302202  13d4e307703bb93fc164e798300731eb
# 5  oai:nb.bibsys.no:999300260714702202  616fda96c89ded83c727f8c4f3b7a73a
# 6  oai:nb.bibsys.no:998902370424702202  77a46ed37d71ec95d699868379d3e42e
# 7  oai:nb.bibsys.no:999920004500902202  8bffa208ee4ade7015f56200e087688d
# 8  oai:nb.bibsys.no:999323595074702202  1b2a12e8750d1a6628f06bd1c071265e
# 9  oai:nb.bibsys.no:999202228384702202  e0d95d25c76822e1d7ce126ce5ede559
#
#                     isbn10        city timestamp  year             publisher  \
# 0                              [Bergen      2014  2014   Den Nationale scene
# 1                                 Oslo      1952  1952             Gyldendal
# 2               8205225915        Oslo      1994  1994             Gyldendal
# 3                           Kjøbenhavn      1890  1890  Schubothes Boghandel
# 4                             [Bergen]      1992  1992   Den Nationale scene
# 5               8253015763        Oslo      1992  1992                   Pax
# 6  8203155863 / 8203155928        Oslo      1987  1987             Aschehoug
# 7                                 Oslo      2019  2019        Pax forlag A/S
# 8               8253016166        Oslo      1993  1993                   Pax
# 9               8205205272        Oslo      1992  1992             Gyldendal
#
#   langs                                           subjects  \
# 0   nob
# 1   nob                skjønnlitteratur / norske / romaner
# 2   nob                         skram / amalie / skuespill
# 3   nob
# 4   nob
# 5   nob  litteraturhistorie / forfattere / norsk / litt...
# 6   nob
# 7   nob  Sykehus / Sjukehus / Kvinner / Kvinner / Psyki...
# 8   nob                                 noveller / barndom
# 9   nob                                              roman
#
#                    ddc         genres      literaryform  doctype
# 0              792.642          drama  Skjønnlitteratur  digibok
# 1                               novel  Skjønnlitteratur  digibok
# 2              839.822        fiction  Skjønnlitteratur  digibok
# 3                                         Uklassifisert  digibok
# 4                               tekst     Uklassifisert  digibok
# 5  839.8208 / 839.8208        fiction  Skjønnlitteratur  digibok
# 6              839.823        fiction  Skjønnlitteratur  digibok
# 7             839.8236  novel / tekst  Skjønnlitteratur  digibok
# 8              839.823        fiction  Skjønnlitteratur  digibok
# 9              839.823        fiction  Skjønnlitteratur  digibok

# %%
corpus.city
# Out:
# 0       [Bergen
# 1          Oslo
# 2          Oslo
# 3    Kjøbenhavn
# 4      [Bergen]
# 5          Oslo
# 6          Oslo
# 7          Oslo
# 8          Oslo
# 9          Oslo
# Name: city, dtype: object

# %%
concs = d2.concordance(urns = list(corpus.urn), words = "")
len(concs)
# Out:
# 173

# %%
concs.sample(min(len(concs), 20)).style
# Out:
# <style  type="text/css" >
# </style><table id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >docid</th>        <th class="col_heading level0 col1" >urn</th>        <th class="col_heading level0 col2" >conc</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3level0_row0" class="row_heading level0 row0" >63</th>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row0_col0" class="data row0 col0" >100254859</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row0_col1" class="data row0 col1" >URN:NBN:no-nb_digibok_2015062508159</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row0_col2" class="data row0 col2" >Hun satt i det ytterste <b>værelse</b> . Døren inn til Lorck stod åpen ; fra den lave lenestol borte ved det runde bord kunne hun se ham... </td>
#             </tr>
#             <tr>
#                         <th id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3level0_row1" class="row_heading level0 row1" >29</th>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row1_col0" class="data row1 col0" >100405935</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row1_col1" class="data row1 col1" >URN:NBN:no-nb_digibok_2020060448001</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row1_col2" class="data row1 col2" >De fulgtes ad inn i det rommelige <b>værelse</b> ved siden av Elses . Det var blitt gjort i stand til komtessen og inneholdt to senger , og... </td>
#             </tr>
#             <tr>
#                         <th id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3level0_row2" class="row_heading level0 row2" >117</th>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row2_col0" class="data row2 col0" >100558622</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row2_col1" class="data row2 col1" >URN:NBN:no-nb_digibok_2009042810003</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row2_col2" class="data row2 col2" >« Hvordan Du bærer Dig ad ! » Lydia læned sig tilbage mod klædeskabet oppe på sit <b>værelse</b> med hænderne på ryggen . Hendes store , lyse øjne flakked om... </td>
#             </tr>
#             <tr>
#                         <th id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3level0_row3" class="row_heading level0 row3" >155</th>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row3_col0" class="data row3 col0" >100508035</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row3_col1" class="data row3 col1" >URN:NBN:no-nb_digibok_2006081000050</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row3_col2" class="data row3 col2" >Lucies øine fulgte ham gjennom <b>værelset</b> med et sugende blikk . Hun syntes rent å ha glemt at Gerner stod ved siden av henne .</td>
#             </tr>
#             <tr>
#                         <th id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3level0_row4" class="row_heading level0 row4" >93</th>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row4_col0" class="data row4 col0" >100558622</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row4_col1" class="data row4 col1" >URN:NBN:no-nb_digibok_2009042810003</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row4_col2" class="data row4 col2" >Oppe på sit <b>værelse</b> la hun bøgerne fra sig , satte sig ved vinduet og så hen på en firkant i vedbodtaget hvor der mangled nogle... </td>
#             </tr>
#             <tr>
#                         <th id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3level0_row5" class="row_heading level0 row5" >171</th>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row5_col0" class="data row5 col0" >100500775</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row5_col1" class="data row5 col1" >URN:NBN:no-nb_digibok_2007110500083</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row5_col2" class="data row5 col2" >« Det er dig , han elsker , Ally , » ropte Mally , da hun og fru Alvilda var kommet op på Mallys <b>værelse</b> . « Vet du det ikke ? Har han... </td>
#             </tr>
#             <tr>
#                         <th id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3level0_row6" class="row_heading level0 row6" >53</th>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row6_col0" class="data row6 col0" >100254859</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row6_col1" class="data row6 col1" >URN:NBN:no-nb_digibok_2015062508159</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row6_col2" class="data row6 col2" >... av den , videre avsted , gjennom den neste , kom inn i et mørkt <b>værelse</b> , og tørnet så mot noe spisst . Slaget var så heftig at hun... </td>
#             </tr>
#             <tr>
#                         <th id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3level0_row7" class="row_heading level0 row7" >118</th>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row7_col0" class="data row7 col0" >100558622</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row7_col1" class="data row7 col1" >URN:NBN:no-nb_digibok_2009042810003</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row7_col2" class="data row7 col2" >... I halvmørket virked stanken i <b>værelset</b> , den hodeløse manden og så denne sinte kjærring , der havde noget uldent om hodet , liksom Zigøjnerkonen i Hamburg , som... </td>
#             </tr>
#             <tr>
#                         <th id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3level0_row8" class="row_heading level0 row8" >7</th>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row8_col0" class="data row8 col0" >100193764</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row8_col1" class="data row8 col1" >URN:NBN:no-nb_digibok_2014022708239</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row8_col2" class="data row8 col2" >... det ble anbrakt en kokeovn i stedet for det gammeldagse ildsted med den åpne gruen , for så gjorde det tjeneste som <b>værelse</b> og kjøkken på... </td>
#             </tr>
#             <tr>
#                         <th id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3level0_row9" class="row_heading level0 row9" >58</th>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row9_col0" class="data row9 col0" >100254859</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row9_col1" class="data row9 col1" >URN:NBN:no-nb_digibok_2015062508159</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row9_col2" class="data row9 col2" >... Så forlot hun stuen og lukket seg inne på sitt <b>værelse</b> . Men om aftenen i sengen spurte hun seg seiv for første gang om hun... </td>
#             </tr>
#             <tr>
#                         <th id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3level0_row10" class="row_heading level0 row10" >83</th>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row10_col0" class="data row10 col0" >100254859</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row10_col1" class="data row10 col1" >URN:NBN:no-nb_digibok_2015062508159</td>
#                         <td id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3row10_col2" class="data row10 col2" >... Månelyset kastet skyggen av hotellet bort over den åpne plass , som deres <b>værelse</b> vendte ut til , skinte på vannspringet med den basunkinnete gutt på toppen... </td>
#             </tr>
#             <tr>
#                         <th id="T_4f7e3495_25ce_11ec_90c1_a0a4c554f2a3level0_row11" class="row_heading l

# %%
concs = d2.concordance(urns = list(corpus.urn), words = """  "værelset sto"  """)
len(concs)
# Out:
# 1

# %%
concs.sample(min(len(concs), 20)).style
# Out:
# <style  type="text/css" >
# </style><table id="T_b7b35f70_25ce_11ec_bfe2_a0a4c554f2a3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >docid</th>        <th class="col_heading level0 col1" >urn</th>        <th class="col_heading level0 col2" >conc</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b7b35f70_25ce_11ec_bfe2_a0a4c554f2a3level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b7b35f70_25ce_11ec_bfe2_a0a4c554f2a3row0_col0" class="data row0 col0" >100193764</td>
#                         <td id="T_b7b35f70_25ce_11ec_bfe2_a0a4c554f2a3row0_col1" class="data row0 col1" >URN:NBN:no-nb_digibok_2014022708239</td>
#                         <td id="T_b7b35f70_25ce_11ec_bfe2_a0a4c554f2a3row0_col2" class="data row0 col2" >Før tante Lise forlot <b>værelset , sto</b> hun litt ved sengen og lyttet til den tørre krampaktige hiven , som tross søvnen ble ved å riste Johannes... </td>
#             </tr>
#     </tbody></table>

# %%
concs = d2.concordance(urns = list(corpus.urn), words = "cigaret*")
len(concs)

# %%
concs.style

# %%
d2.urn_collocation(urns = list(corpus.urn), word = 'demokrati', before = 15, after = 15).sort_values(by = 'counts', ascending =False)
# Out:
#                  counts  dist     bdist
# .                    12    36  2.571429
# ,                    11    54  4.153846
# og                    9    17  1.545455
# som                   6    16  2.000000
# en                    5    25  3.571429
# ...                 ...   ...       ...
# ver                   1     6  2.000000
# strid                 1     6  2.000000
# mestre                1     6  2.000000
# parlamentarisme       1     2  0.666667
# Oslo                  1     8  2.666667
#
# [164 rows x 3 columns]

# %%
tot = d2.totals(20000)

# %%
d2.concordance_counts(urns = list(corpus.urn), words = "vårt Norge", window = 5).sort_values(by = 'freq', ascending = False)
# Out:
#                     freq
# .                  10917
# ,                   8431
# i                   4231
# og                  3934
# er                  2689
# ...                  ...
# forhåndssolgte         1
# forhåndsligningen      1
# Kloedcr                1
# forhv                  1
# forelder               1
#
# [39980 rows x 1 columns]

# %%
dtm = d2.frequencies(urns = list(corpus.urn[0]))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-37-218a59412e81> in <module>
# ----> 1 dtm = d2.frequencies(urns = list(corpus.urn[0]))
#
# ~\Documents\GitHub\Miscellaneous-Notebooks\DHlab_språkbanken\dhlab_v2.py in frequencies(urns, cutoff)
#      70     params = locals()
#      71     r = requests.post(BASE_URL1 + "/frequencies", json = params)
# ---> 72     result = r.json()
#      73     structure = {u[0][0] : dict([tuple(x[1:]) for x in u]) for u in result if u != []}
#      74     return structure
#
# ~\Anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
import pandas as pd

# %%
dtm = pd.DataFrame(dtm)

# %%
dtm.sort_values(by = dtm.columns[1], ascending = False).head(50).fillna(0).applymap(int).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row0_col5 {
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row0_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row0_col7 {
#             background-color:  #045a8d;
#             color:  #f1f1f1;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row0_col8 {
#             background-color:  #034d79;
#             color:  #f1f1f1;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row0_col9 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row1_col0 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row1_col1 {
#             background-color:  #358fc0;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row1_col2 {
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row1_col3 {
#             background-color:  #2484ba;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row1_col4 {
#             background-color:  #4897c4;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row1_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row1_col6 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row1_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row1_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row1_col9 {
#             background-color:  #045a8d;
#             color:  #f1f1f1;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row2_col0 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row2_col1 {
#             background-color:  #99b8d8;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row2_col2 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row2_col3 {
#             background-color:  #9ebad9;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row2_col4 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row2_col5 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row2_col6 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row2_col7 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row2_col8 {
#             background-color:  #3991c1;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row2_col9 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row3_col0 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row3_col1 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row3_col2 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row3_col3 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row3_col4 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row3_col5 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row3_col6 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row3_col7 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row3_col8 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row3_col9 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row4_col0 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row4_col1 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row4_col2 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row4_col3 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row4_col4 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row4_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row4_col6 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row4_col7 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row4_col8 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row4_col9 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row5_col0 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row5_col1 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row5_col2 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row5_col3 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row5_col4 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row5_col5 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row5_col6 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row5_col7 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row5_col8 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_32c6eca0_25d3_11ec_bb15_a0a4c554f2a3row5_col9 {
#             background-color:  #cacee5;
#             color:  #000000;
