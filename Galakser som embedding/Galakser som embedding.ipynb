# %% [markdown]
# ### Galakser som embeddinger

# %%
# Hvis dhlab ikke er installert, avkommenter linjen under og kjør
#!pip install dhlab

# %%
import dhlab.nbtext as nb
import dhlab.graph_networkx_louvain as gnl

# %%
nb.concordance('bil')
# Out:
# <table><tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013042305150?searchText=bil' target='_'>Schewe, Olav,Utvekslingselev,2010</a></td><td>jeg ta førerkort og kjøre</td><td>bil</td><td style='text-align:left'>mens jeg er i utlandet</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013042305150?searchText=bil' target='_'>Schewe, Olav,Utvekslingselev,2010</a></td><td>ta førerkort enn å kjøre</td><td>bil</td><td style='text-align:left'>. Merk at i enkelte</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013042305150?searchText=bil' target='_'>Schewe, Olav,Utvekslingselev,2010</a></td><td>ta førerkort og å kjøre</td><td>bil</td><td style='text-align:left'>.</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013042305150?searchText=bil' target='_'>Schewe, Olav,Utvekslingselev,2010</a></td><td>og ( minst ) én</td><td>bil</td><td style='text-align:left'>per familiemedlem med førerkort, er</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013042305150?searchText=bil' target='_'>Schewe, Olav,Utvekslingselev,2010</a></td><td>i USA kan man kjøre</td><td>bil</td><td style='text-align:left'>fra fylte 16 år i</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011060106091?searchText=bil' target='_'>Bramness, Hanne,Regnet i Buenos Aires,2002</a></td><td>finnes . En og annen</td><td>bil</td><td style='text-align:left'>kommer kjørende tilbake gjennom døden</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011060106091?searchText=bil' target='_'>Bramness, Hanne,Regnet i Buenos Aires,2002</a></td><td>gater eller kjøre den i</td><td>bil</td><td style='text-align:left'>, når natten</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009121100003?searchText=bil' target='_'>,Nordiske språk i møte med andre språk,2002</a></td><td>None</td><td>bil</td><td style='text-align:left'>None</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009121100003?searchText=bil' target='_'>,Nordiske språk i møte med andre språk,2002</a></td><td>None</td><td>bil</td><td style='text-align:left'>None</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009121100003?searchText=bil' target='_'>,Nordiske språk i møte med andre språk,2002</a></td><td>None</td><td>bil</td><td style='text-align:left'>None</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007070400021?searchText=bil' target='_'>Gleditsch, Nini Haslund,Vær utålmodig menneske!,1980</a></td><td>sent , jeg tar en</td><td>bil</td><td style='text-align:left'>hjem . »</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007070400021?searchText=bil' target='_'>Gleditsch, Nini Haslund,Vær utålmodig menneske!,1980</a></td><td>Jeg tar ikke</td><td>bil</td><td style='text-align:left'>hjem . Med hendene dypt</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007070400021?searchText=bil' target='_'>Gleditsch, Nini Haslund,Vær utålmodig menneske!,1980</a></td><td>nr. hvitt . Tøiet skal</td><td>bil</td><td style='text-align:left'>rent Og</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007070400021?searchText=bil' target='_'>Gleditsch, Nini Haslund,Vær utålmodig menneske!,1980</a></td><td>sammen til Teruel i min</td><td>bil</td><td style='text-align:left'>, jeg for å evakuere</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007070400021?searchText=bil' target='_'>Gleditsch, Nini Haslund,Vær utålmodig menneske!,1980</a></td><td>komme fram med en vanlig</td><td>bil</td><td style='text-align:left'>og jeg må gi opp</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008082600028?searchText=bil' target='_'>Klepp, Ingun Grimstad,På stier mellom natur og kultur,1998</a></td><td>, men blir fraktet med</td><td>bil</td><td style='text-align:left'>. Vandrernes antall og sammensetningen</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008082600028?searchText=bil' target='_'>Klepp, Ingun Grimstad,På stier mellom natur og kultur,1998</a></td><td>1 dag kjører de alle</td><td>bil</td><td style='text-align:left'>opp . « Eg bila</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008082600028?searchText=bil' target='_'>Klepp, Ingun Grimstad,På stier mellom natur og kultur,1998</a></td><td>snart ikke tør å kjøre</td><td>bil</td><td style='text-align:left'>i byen , det er</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008082600028?searchText=bil' target='_'>Klepp, Ingun Grimstad,På stier mellom natur og kultur,1998</a></td><td>gå och kjopa en ny</td><td>bil</td><td style='text-align:left'>, och så e vi</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008082600028?searchText=bil' target='_'>Klepp, Ingun Grimstad,På stier mellom natur og kultur,1998</a></td><td>stedene som nåes per ,</td><td>bil</td><td style='text-align:left'>støtter en slik forklaring .</td></tr>
# </table>

# %% [markdown]
# ## Test ut med kommando `relaterte_ord`
#
# Det er en egenvektorbasert måte å hente ut tilsvarende ord fra grafen gitt under.

# %%
G= nb.make_graph('democracy' , lang='eng')

# %%
nb.relaterte_ord('voldtekt', score = True)
# Out:
# [('vold', 0.32009902120057576),
#  ('voldtekt', 0.30503820556780836),
#  ('drap', 0.30495319420316286),
#  ('mishandling', 0.2844058047962756),
#  ('tortur', 0.24175078549468657),
#  ('ran', 0.23812687439390373),
#  ('overgrep', 0.2239245070871493),
#  ('kidnapping', 0.199060026784337),
#  ('mord', 0.19890424678439314),
#  ('overfall', 0.19118733596006526),
#  ('trusler', 0.17244495893799344),
#  ('frihetsberøvelse', 0.1626290780202713),
#  ('plyndring', 0.15308106788649828),
#  ('incest', 0.14805350327468755),
#  ('voldtekter', 0.14301739433059193),
#  ('seksuell', 0.14185031211212384),
#  ('drapsforsøk', 0.1384551829511669),
#  ('trakassering', 0.13400531322782647),
#  ('seksuelt', 0.12347516197334561),
#  ('seksuelle', 0.12268030372093626)]

# %% [markdown]
# ## Ta ut grafen og hent ut med passende algoritem
#
#
# Grafen er et **networkx**- objekt.

# %%
G = nb.make_graph('hode')

# %%
gnl.show_graph(G, spread = 1.3)

# %% [markdown]
# Med `show_communities` gis en litt mer detaljert clustring fra grafen

# %%
gnl.show_communities(G)
# Out:
# armer-bein :  armer, bein, ben, overmadrass, arm, skinn, hen, brusk, arme, marg, knokler, armar, Armer, ball
#
# rygg-knær :  rygg, knær, nakke, skuldre, mage, skulder, lår, hofter, ankler, hofte, albuer, buk, legger, skuldrer, armlener, kinn, rumpe, rygger, kne, ledd, korsrygg, nakker, bog, sete, front
#
# hode-bryst :  hode, bryst, hals, ansikt, labber, poter, innmat, overkropp, snute, labb, ermer, nese, node, hoved, hud, mave, svelg, butterfly, munn, indmat, hvit, blod, bode, Hud, haand, allergi, stykk, hake, forlabber
#
# hender-føtter :  hender, føtter, hoder, fingre, hår, tær, øyne, negler
#
# hale-vinger :  hale, vinger, horn, ører, ister
#
# sykkel-kollektivtrafikk :  sykkel, kollektivtrafikk, moped, rulleski, hjelm, ski, bil, spark, kjerre
#
# kropp-hjerte :  kropp, hjerte, sjel, hovud, hjerne, stemme, sinn, lunger, sex, seksualitet, muskler, klær, utseende, ånd, lunge, nyrer, helse
#
# klør-klor :  klør, klor, nebb, skjell, tenner, Stikk, myke, smidighet, pels, neb, svir, Tenner
#
# lengder-farger :  lengder, farger, bredder, dybder, dimensjoner, tykkelser

# %%
nb.central_betweenness_characters(G)
# Out:
# [('hode', 0.25754132212093134),
#  ('kropp', 0.09112255177962386),
#  ('bein', 0.08636824414882424),
#  ('hals', 0.07238451222829317),
#  ('rygg', 0.06390101622535826),
#  ('hjerte', 0.05873945518852263),
#  ('armer', 0.05800031551479542),
#  ('sykkel', 0.05245213742460006),
#  ('bryst', 0.04544247716769904),
#  ('ben', 0.041694632096549604)]

# %%
nb.central_characters(G)
# Out:
# [('hode', 0.3709677419354839),
#  ('rygg', 0.3064516129032258),
#  ('armer', 0.29032258064516125),
#  ('hals', 0.282258064516129),
#  ('bryst', 0.282258064516129),
#  ('bein', 0.2661290322580645),
#  ('kropp', 0.25),
#  ('knær', 0.23387096774193547),
#  ('hender', 0.1935483870967742),
#  ('nakke', 0.1935483870967742)]

# %% [markdown]
# Ta ut clusteret som et python-objekt

# %%
gnl.community_dict(G)
# Out:
# {'kultur-miljø': ['kultur',
#   'miljø',
#   'oppvekst',
#   'næring',
#   'energi',
#   'sikkerhet',
#   'samferdsel',
#   'teknikk',
#   'fritid',
#   'historie',
#   'landbruk',
#   'natur',
#   'medier',
#   'utvikling',
#   'kunst',
#   'trafikksikkerhet',
#   'samfunn',
#   'vitenskap',
#   'økonomi',
#   'næringsliv',
#   'religion',
#   'byutvikling',
#   'tradisjon',
#   'språk',
#   'klima',
#   'Natur'],
#  'utdanning-skole': ['utdanning',
#   'skole',
#   'Arbeid',
#   'forskning',
#   'butikk',
#   'yrke',
#   'læring',
#   'administrativ',
#   'jobb',
#   'forsking',
#   'Skole',
#   'praksis',
#   'daghjem',
#   'Ungdom',
#   'erfaring',
#   'barnehage',
#   'barnehave',
#   'hjem',
#   'psykisk',
#   'Trygd'],
#  'trivsel-velferd': ['trivsel',
#   'velferd',
#   'livskvalitet',
#   'velvære',
#   'sunnhet',
#   'Helse',
#   'trygghet',
#   'glede',
#   'sysselsetting',
#   'arbeidsplasser',
#   'vitalitet',
#   'livsglede',
#   'trim',
#   'sykdom',
#   'utfoldelse',
#   'vekst',
#   'skjønnhet',
#   'levekår',
#   'Heise',
#   'bolyst',
#   'framgang',
#   'styrke',
#   'velstand',
#   'smak',
#   'hygge',
#   'demokrati',
#   'lykke',
#   'verdiskaping',
#   'fremgang',
#   'menneskeverd',
#   'mestring',
#   'sundhet',
#   'verdighet',
#   'arbeidsevne',
#   'luksus',
#   'komfort',
#   'samhold'],
#  'sosiale-økonomiske': ['sosiale',
#   'økonomiske',
#   'pedagogiske',
#   'psykologiske',
#   'helsemessige',
#   'humanitære',
#   'faglige',
#   'medisinske',
#   'kulturelle',
#   'okonomiske',
#   'politiske',
#   'psykiske',
#   'menneskelige'],
#  'helse--sosialetaten': ['helse-',
#   'sosialetaten',
#   'sosialsjefen',
#   'sosialstyret',
#   'sosialsjef',
#   'sosialfag',
#   'Helse-',
#   'sosialsektoren',
#   'sosialutvalget',
#   'se-',
#   'sosialfaglig',
#   'sosialsaker',
#   'heise-',
#   'lelse-',
#   'omsorgs-',
#   'trygde-',
#   'Heise-',
#   'omsorg-',
#   'helsesjef',
#   'rådmannen',
#   'helserådet',
#   'politiet',
#   'formannskapet',
#   'sosialrådmannen',
#   'skole-',
#   'kultur-'],
#  'mat-medisin': ['mat',
#   'medisin',
#   'Mat',
#   'teknologi',
#   'rehabilitering',
#   'psykologi',
#   'drikke',
#   'klær',
#   'kaffi',
#   'kaffe',
#   'vin',
#   'kopp',
#   'tobakk',
#   'kirurgi',
#   'overnatting',
#   'naturvitenskap',
#   'farmasi',
#   'vann',
#   'jus',
#   'biologi',
#   'fysiologi',
#   'vinhus',
#   'medisiner',
#   'husly'],
#  'helse-eldreomsorg': ['helse',
#   'eldreomsorg',
#   'sosial',
#   'røyking',
#   'aldring',
#   'telekom',
#   'barnehager',
#   'psykiatri',
#   'helsefag',
#   'skoler',
#   'helsevesen',
#   'barnevern',
#   'overvekt',
#   'okonomisk',
#   'kulturell',
#   'medisinsk',
#   'helsestell',
#   'internett',
#   'politisk',
#   'utadvendt',
#   'tuberkulinforhold',
#   'it',
#   'snusing',
#   'lungekreft',
#   'helsevern',
#   'skule',
#   'faglig',
#   'økonomisk',
#   'drikking',
#   'helsetjenester'],
#  'kropp-liv': ['kropp',
#   'liv',
#   'sjel',
#   'død',
#   'ånd',
#   'utseende',
#   'seksualitet',
#   'sex',
#   'lemmer',
#   'lære',
#   'dod',
#   'stemme',
#   'ansikt',
#   'sinn',
#   'hjerne',
#   'diktning',
#   'hode',
#   'virke'],
#  'idrett-aktivitet': ['idrett',
#   'aktivitet',
#   'kosthold',
#   'ernæring',
#   'Kosthold',
#   'trening',
#   'kreft',
#   'alkohol',
#   'sport',
#   'livsstil',
#   'hygiene',
#   'fysisk',
#   'lek',
#   'friluftsliv',
#   'folkehelse',
#   'arbeid',
#   'mosjon',
#   'bosetting',
#   'matvaner',
#   'kroppsøving',
#   'musikk',
#   'avslapping',
#   'Kultur',
#   'politikk',
#   'jordbruk',
#   'leik',
#   'engasjement'],
#  'omsorg-kjærlighet': ['omsorg',
#   'kjærlighet',
#   'stell',
#   'støtte',
#   'god',
#   'pleie',
#   'behandling',
#   'omtanke',
#   'pleie-',
#   'godhet',
#   'hjelp',
#   'varme']}

# %%
indianere = nb.make_graph('indians', lang='eng')

# %%
gnl.show_graph(indianere)
# Out:
# C:\Users\larsj\AppData\Local\Continuum\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
gnl.show_communities(indianere)
# Out:
# blacks-whites :  blacks, whites, indians, coloureds, greys, nonblacks, hispanics, coloreds
#
# cowboys-ranchmen :  cowboys, ranchmen, sheepherders, cowgirls, vaqueros, cowmen
#
# mestizos-pardos :  mestizos, pardos, mestizas, cholos, mulatos, criollos
#
# negroes-mulattos :  negroes, mulattos, mulattoes, carpetbaggers, scalawags

# %%
violence = nb.make_graph('violence', lang='eng')

# %%
gnl.show_graph(violence, spread = 1)

# %%
gnl.show_cliques(violence)
# Out:
# (3, 1) lawlessness, Rapine, violence, pillage, bloodshed, rapine, incendiarism
#
# (3, 2) terrorisation, violence, thuggery, intimidation

# %%
gnl.show_communities(violence)
# Out:
# rapine-Rapine :  rapine, Rapine, bloodshed, pillage, Plunder, ruffianism, Extortion, Murder, Spoil, plunder, Lust, incendiarism
#
# rapines-murders :  rapines, murders, depredations, extortions, robberies
#
# violence-terrorisation :  violence, terrorisation, vagabondism, oppreffion, Fickleness
#
# nonviolence-satyagraha :  nonviolence, satyagraha, noncooperation, pacifism, nonresistance, peacemaking
#
# Lawlessness-Violence :  Lawlessness, Violence, anarchy, Crime, counterviolence
#
# intimidation-harassment :  intimidation, harassment, bribery, coercion, cajolery, harrassment, terrorization, extortion
#
# lawlessness-thuggery :  lawlessness, thuggery, hooliganism, banditry, brigandage, corruption
#
# suddenness-unexpectedness :  suddenness, unexpectedness, swiftness, abruptness
