# %% [markdown]
# # Nye kanon NTNU - februar 2020
#
# Lage tematiske ord: stedsnavn, se på bredden av stedsnavn i korpuset
# minoriteter. Miljø og klima osv.
#
# * helse
# * medbrorgere
# * bærekraft
# * oppgaver - analyse
#
# Hvordan kan arkivet bli nyttig for lærere og lærerstudenter?
#
# Litteratur og klassifisering som mengde av ord - cluster etc.
#
# STTR
# Ordforråd, bredde etc. sjeldne ord.

# %%
import dhlab.nbtext as nb
import pandas as pd
import qgrid as qg

# %% [markdown]
# ## Lag et korpus

# %%
nb.get_urn??

# %%
korpus = nb.book_corpus( trans='sme')

# %%
qg.show_grid(korpus)
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
texts = nb.get_corpus_text(nb.pure_urn(korpus), cutoff = 1)

# %%
texts
# Out:
#               2008052104076  2012062705080  2013080908061  2012033008103  \
# .                    7238.0          252.0         5177.0         1727.0
# ,                    6020.0          125.0         2615.0          888.0
# i                    3502.0          101.0         1041.0          416.0
# er                   3477.0           39.0          548.0          272.0
# og                   3440.0          125.0         1144.0          914.0
# ...                     ...            ...            ...            ...
# Bjørnstjerne            NaN            NaN            NaN            NaN
# Bing                    NaN            NaN            NaN            NaN
# Bestandig               NaN            NaN            NaN            NaN
# Askeladden              NaN            NaN            NaN            NaN
# Aristoteles             NaN            NaN            NaN            NaN
#
#               2013092407098  2012062905066  2007072604055  2007052504015  \
# ...

# %% [markdown]
# # Hent noe å sammenligne med

# %%
top = nb.frame(nb.totals(50000), 'tot')

# %%
top
# Out:
#                      tot
# .             1265723110
# ,             1105303412
# og             543432056
# i              460246057
# det            273411583
# ...                  ...
# innst              21677
# parsellen          21676
# containere         21676
# Islamic            21676
# kvinnelighet       21675
#
# [50000 rows x 1 columns]

# %% [markdown]
# # Vekstdiagram
