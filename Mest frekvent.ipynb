# %%
import dhlab.nbtext as nb

# %%
tot = nb.frame(nb.totals(100))

# %%
'a'.isalpha()
# Out:
# True

# %%
tot[tot.index.str.isalpha()].head(50).sort_values(by=0, ascending=False).plot(kind='bar',figsize =( 15, 5))

# %%
tot[tot.index.str.isalpha()].head(50).sum()
# Out:
# 0    6048891727
# dtype: int64

# %%
tot.head(50).sum()
# Out:
# 0    9167418185
# dtype: int64

# %%
t = nb.frame(nb.totals(3000000))

# %%
t.sum()
# Out:
# 0    23789049866
# dtype: int64

# %%
ts = t[t.index.str.isalpha()]

# %%
tts = ts.groupby(ts.index.str.lower()).sum().sort_values(by=0, ascending = False)

# %%
tts.sum()
# Out:
# 0    18444718522
# dtype: int64

# %%
tts.head(50).sum()
# Out:
# 0    6458385185
# dtype: int64

# %%
tts = tts.drop(index ='the')
tts = tts.drop(index ='a')
tts = tts.drop(index ='s')
tts = tts.drop(index ='in')
tts = tts.drop(index ='to')

# %%
tts = tts.drop(index ='f')

# %%
tts = tts.drop(index ='and')

# %%
tts.head(50).plot(kind='bar', legend=False, figsize=(18,5), rot=60)

# %%
tts.head(20)
# Out:
#               0
# og    568501941
# i     525465855
# det   357418483
# som   271361148
# til   260531942
# er    254505268
# en    251196318
# av    239259517
# for   216677594
# på    215365195
# at    202895387
# å     188521278
# med   188353096
# den   176742948
# de    174123714
# han   156375806
# var   155161557
# ikke  142644454
# jeg   119646997
# om    110430871

# %%
 [x for x in tts.head(500).index if len(x) >= 8 ]
# Out:
# ['imidlertid',
#  'tidligere',
#  'eksempel',
#  'arbeidet',
#  'allerede',
#  'mennesker',
#  'forskjellige',
#  'samtidig',
#  'hverandre',
#  'spørsmål',
#  'betydning',
#  'vanskelig',
#  'virkelig',
#  'kapittel',
#  'følgende',
#  'nødvendig',
#  'forbindelse',
#  'innenfor',
#  'dessuten',
#  'spesielt']

# %%
tots = tot[tot.index.str.isalpha()]

# %%
tots.groupby(tots.index.str.lower()).sum().sort_values(by=0, ascending = False).plot(kind='bar', legend=False, figsize=(18,5), rot=60)

# %%
tot.loc ['Det']
# Out:
# 0    83547318
# Name: Det, dtype: int64

# %%
lengde = [sum([len(x) for x in tts[:i].index]) for i in range(0, 10000, 100)]

# %%
divs = [x for x in range(0, 10000, 100)]

# %%
lengde [1:]/divs [1:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-07cef99c28fd> in <module>
# ----> 1 lengde [1:]/divs [1:]
#
# TypeError: unsupported operand type(s) for /: 'list' and 'list'

# %%
import pandas as pd

# %%
ls = pd.Series(lengde[1:])

# %%
ds = pd.Series(divs [1:])

# %%
lsa = pd.Series(ls/ds)

# %%
lsa[:10]
# Out:
# 0    2.990000
# 1    3.340000
# 2    3.650000
# 3    3.897500
# 4    4.096000
# 5    4.226667
# 6    4.318571
# 7    4.482500
# 8    4.536667
# 9    4.616000
# dtype: float64

# %%
lsa [:20].plot(figsize=(10,5))
