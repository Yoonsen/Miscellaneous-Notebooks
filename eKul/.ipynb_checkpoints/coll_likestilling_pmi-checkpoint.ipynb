# %% [markdown]
# # Kollokasjoner for nøkkelord

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
import dhlab.graph_networkx_louvain as gnl
from dhlab.module_update import update, css, code_toggle

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
def categorize(list_of_words):
    proprium = [x for x in list_of_words if x[0].upper() == x[0]]
    other = [x for x in list_of_words if not x in proprium]

    return {'propr':proprium,
           'other': other }

def select_form(w):
    fs = [x.split()[0] for x in nb.word_form(w)]
    if 'verb' in fs:
        res = 'verb'
    elif 'subst' in fs:
        res = 'subst'
    elif len(fs) > 0:
        res = fs[0]
    else:
        res = 'unknown'
    return res

def sort_word_forms(words):
    res = {select_form(w):w for w in words}
    return res

def character_words(Character_name, number_of_words=50):
    res = {w:select_form(w) for w in categorize(list(nb.frame_sort(nb.frame(coll_matrix[Character_name]/tot['tot'], 'association')).head(number_of_words).index))['other']}
    result = {cat:[w for w in res if res[w] == cat] for cat in res.values()}
    return result

def mdprint(forskjell, cutoff=5):
    categories = categorize(forskjell[forskjell > cutoff].dropna().index)
    forms = {w:select_form(w) for w in categories['other']}
    Grouping = {cat:[word for word in forms if forms[word] == cat] for cat in forms.values()}
    navn = "## Benevnelser \n"
    navn += "<span style='font-size:150%'>{stuff}</span>".format(stuff= ', '.join(categories['propr']))
    pos = ""
    for cat in Grouping:
        pos += "## " + cat + "\n"
        pos += "<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ', '.join(Grouping[cat]) ) + "\n"
    mu.printmd(navn)
    mu.printmd(pos)
    return

# %%
import pandas as pd

# %%
import ast

# %%
#colls_before = pd.read_json('demokrati_before.json')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})

# %%
cliques = lambda G: [list(x) for  x in list(gnl.make_cliques_from_graph(G.to_undirected())[1].values())]

# %% [markdown]
# ## Definer nøkkelordet
#
# noteboken blir kjørt flere ganger, en notebook for hvert nøkkelord, *influensa*, *helse*

# %%
reference = nb.frame(nb.totals(50000), 'tot')

# %%
keyword = 'likestilling'

# %%
filename = 'collocation_' + keyword + ".csv"

# %% [markdown]
# ## Grafstruktur topos

# %%
keyword_graph = nb.make_graph(keyword, cutoff=16)

# %%
comm = gnl.community_dict(keyword_graph)

# %%
gnl.show_graph(keyword_graph, spread=1.2, fontsize=12)

# %% [markdown]
# # Topoi fra grafen
#
# Der klikkstrukturen kombinerer færre element, er alle nodene i grafen med og definerer et topos.

# %%
pos=""
for x in comm:
    pos += "### " + x + "\n"
    pos += "<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ', '.join(comm[x]) ) + "\n"
mu.printmd(pos)
# Out:
# ### diskriminering-undertrykking
# <span style='font-size:1.1em'>diskriminering, undertrykking, trakassering, undertrykkelse, vold, forskjellsbehandling, mobbing, fordommer, stigmatisering, rasisme, forfølgelse</span>
# ### deltakelse-deltaking
# <span style='font-size:1.1em'>deltakelse, deltaking, omtanke, medkjensle, omsorg, blomster, helsingar, ba, medfølelse, hjelp, oppmerksomhet, blomehelsingar, blomsterhelsingar, aktivitet, blomar, blomsterhilsener</span>
# ### demokrati-frihet
# <span style='font-size:1.1em'>demokrati, frihet, likeverd, rettferdighet, ytringsfrihet, likebehandling, menneskerettigheter, toleranse, fred, likhet, rettssikkerhet, solidaritet, menneskeverd, selvstendighet, trygghet, respekt, religionsfrihet, åpenhet, folkestyre, uavhengighet, diktatur, ansvar, medbestemmelse, forutsigbarhet, personvern, rettferd, sannhet, markedsøkonomi, sosialisme, fleksibilitet, trosfrihet, pressefrihet, urettferdighet, Frihet</span>
# ### likestilling-kvinners
# <span style='font-size:1.1em'>likestilling, kvinners, frigjøring, likelønn, kvinnekamp, kvinnesak, kvinnefrigjøring, jenters, familiepolitikk, menns, kvinner, lavtlønn, Likestilling, feminisme, lavlønn, barns, mannsroller</span>
# ### kunnskap-engasjement
# <span style='font-size:1.1em'>kunnskap, engasjement, teknologi, inspirasjon, kompetanse, forståelse, interesse, læring, informasjon, viten, innsikt, forskning, erfaring, erfaringer</span>
# ### mangfold-integrering
# <span style='font-size:1.1em'>mangfold, integrering, inkludering, valgfrihet, mangfald, innvandring, normalisering, bredde, kvalitet, språkopplæring, bosetting, variasjon</span>
# ### kjønn-kjønnsroller
# <span style='font-size:1.1em'>kjønn, kjønnsroller, seksualitet, alder, rase, geografi, etnisitet</span>

# %%
gnl.show_cliques(keyword_graph)
# Out:
# (3, 1) kvinners, kvinnesak, kvinnekamp, kvinner, likestilling, likelønn
#
# (3, 2) menneskeverd, mangfold, rettssikkerhet, integrering, fred, solidaritet, inkludering, kvinnefrigjøring, rettferdighet, likeverd, demokrati, likebehandling, respekt, selvstendighet, trygghet, folkestyre, frihet, åpenhet, diskriminering, Frihet, menneskerettigheter, likhet, frigjøring, uavhengighet, ytringsfrihet, likestilling, toleranse
#
# (3, 3) likestilling, kjønn, seksualitet, kjønnsroller
#
# (4, 1) menneskeverd, mangfold, trygghet, frihet, fred, menneskerettigheter, likhet, rettferdighet, likeverd, demokrati, likebehandling, likestilling
#
# (5, 1) frihet, menneskerettigheter, rettferdighet, likeverd, demokrati, likestilling

# %% [markdown]
# # Assosiasjoner fra kollokasjonene
#
# <span style="font-size:150%">nb.collocation(keyword, yearfrom=1950, yearto=2000, before=10, after=10, corpus='avis')</span>

# %%
barchart = lambda word, df: df.loc[word].plot(kind='bar', rot=0, figsize=(10,5),title=word);

# %%
barchart(keyword, reference);

# %%
from time import time

collocations = dict()
step = 1

for i in range(1950, 2000):
    print(i)
    t0 = time()
    try:
        collocations[i] = nb.collocation(keyword, yearfrom = i, yearto = i + step, before = 10, after = 10, corpus = 'bok')
    except:
        try:
            collocations[i] = nb.collocation(keyword, yearfrom= i, yearto= i + step, before = 10, after = 10, corpus = 'bok')
        except:
            print("gir opp", i)
    print((time() - t0)/60, "minutter")
# Out:
# 1950
# 0.13747245868047078 minutter
# 1951
# 0.06853238741556804 minutter
# 1952
# 0.06705645720163982 minutter
# 1953
# 0.05069777170817057 minutter
# 1954
# 0.05606826941172282 minutter
# 1955
# 0.05227683782577515 minutter
# 1956
# 0.05685049295425415 minutter
# 1957
# 0.07702164649963379 minutter
# 1958
# 0.076234765847524 minutter
# 1959
# 0.06549493074417115 minutter
# 1960
# 0.07518213192621867 minutter
# 1961
# 0.06977049112319947 minutter
# 1962
# 0.058695423603057864 minutter
# 1963
# 0.06789537668228149 minutter
# 1964
# 0.08500603040059408 minutter
# 1965
# 0.07548208634058634 minutter
# 1966
# 0.12394527991612753 minutter
# 1967
# 0.07851991653442383 minutter
# 1968
# 0.1349899689356486 minutter
# 1969
# 0.13210113048553468 minutter
# 1970
# 0.14783590634663898 minutter
# 1971
# 0.1745434800783793 minutter
# 1972
# 0.1539449453353882 minutter
# 1973
# 0.2029654026031494 minutter
# 1974
# 0.2193311889966329 minutter
# 1975
# 0.2655542016029358 minutter
# 1976
# 0.2262092391649882 minutter
# 1977
# 0.26637783845265706 minutter
# 1978
# 0.3020666519800822 minutter
# 1979
# 0.331841234366099 minutter
# 1980
# 0.3386440594991048 minutter
# 1981
# 0.37265188694000245 minutter
# 1982
# 0.3124387343724569 minutter
# 1983
# 0.39662307500839233 minutter
# 1984
# 0.3601555109024048 minutter
# 1985
# 0.48660074869791664 minutter
# 1986
# 0.36818156639734906 minutter
# 1987
# 0.4747422933578491 minutter
# 1988
# 0.5154765645662943 minutter
# 1989
# 0.5969330151875814 minutter
# 1990
# 0.6810732245445251 minutter
# 1991
# 0.7791164596875508 minutter
# 1992
# 0.6859608332316081 minutter
# 1993
# 0.7300817330678304 minutter
# 1994
# 0.7099008719126384 minutter
# 1995
# 0.7250401616096497 minutter
# 1996
# 0.8086762269337971 minutter
# 1997
# 0.8313207427660624 minutter
# 1998
# 0.8121818939844767 minutter
# 1999
# 0.8102282722791035 minutter

# %%
colls.to_csv('likestilling.csv')

# %%
colls = nb.frame(collocations)

# %%
colls = pd.concat([nb.frame(collocations[i], i) for i in collocations], axis=1).fillna(0)

# %%
def group_frames(df, bins=10, mode='rel'):
    agg = pd.DataFrame()
    step = 10
    for i in range(0, len(df.columns), step):
        agg[df.columns[i]] = df[df.columns[i:i+step]].sum(axis=1)
    return agg

# %%
agg = group_frames(colls)

# %%
nb.normalize_corpus_dataframe(agg)
# Out:
# True

# %% [markdown]
# # Opptelling

# %% [markdown]
# # Sammenligner med en referanse

# %%
reference.sort_values(by=reference.columns[2], ascending=False)[:10].style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col9 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col10 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col11 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col12 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col13 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col14 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col15 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col16 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col17 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col18 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col19 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col20 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col21 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col22 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col23 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col24 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col25 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col26 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col27 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col28 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col29 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col30 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col31 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col32 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col33 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col34 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col35 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col36 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col37 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col38 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col39 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col40 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col41 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col42 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col43 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col44 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col45 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col46 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col47 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col48 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row0_col49 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row1_col0 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row1_col1 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row1_col2 {
#             background-color:  #62a2cb;
#             color:  #000000;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row1_col3 {
#             background-color:  #3d93c2;
#             color:  #000000;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row1_col4 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row1_col5 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row1_col6 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row1_col7 {
#             background-color:  #6da6cd;
#             color:  #000000;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row1_col8 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_1402c788_58c8_11ea_9dd3_a0a4c554f2a3row1_col9 {
#             background-color:  #

# %%
agg.sort_values(by=agg.columns[2], ascending=False)[:10].style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row1_col0 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row1_col1 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row1_col2 {
#             background-color:  #2383ba;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row1_col3 {
#             background-color:  #157ab5;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row1_col4 {
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row2_col0 {
#             background-color:  #2a88bc;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row2_col1 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row2_col2 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row2_col3 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row2_col4 {
#             background-color:  #056aa6;
#             color:  #f1f1f1;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row3_col0 {
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row3_col1 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row3_col2 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row3_col3 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row3_col4 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row4_col0 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row4_col1 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row4_col2 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row4_col3 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row4_col4 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row5_col2 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row5_col3 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row5_col4 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row6_col0 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row6_col1 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row6_col2 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row6_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row7_col0 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row7_col1 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row7_col2 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row7_col3 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row7_col4 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row8_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row8_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row8_col2 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row8_col3 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row8_col4 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row9_col0 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row9_col1 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row9_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row9_col3 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row9_col4 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }</style><table id="T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1950</th>        <th class="col_heading level0 col1" >1960</th>        <th class="col_heading level0 col2" >1970</th>        <th class="col_heading level0 col3" >1980</th>        <th class="col_heading level0 col4" >1990</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3level0_row0" class="row_heading level0 row0" >.</th>
#                         <td id="T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row0_col0" class="data row0 col0" >0.0479531</td>
#                         <td id="T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row0_col1" class="data row0 col1" >0.0465799</td>
#                         <td id="T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row0_col2" class="data row0 col2" >0.0468917</td>
#                         <td id="T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row0_col3" class="data row0 col3" >0.046896</td>
#                         <td id="T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3row0_col4" class="data row0 col4" >0.0434321</td>
#             </tr>
#             <tr>
#                         <th id="T_bd24a2fa_5e12_11ea_913a_a0a4c554f2a3level0_row1" class="row_heading level0 row1" >og</th>

# %%
pmi = pd.DataFrame()
for i in agg:
    pmi[i] = agg[i]**1.02/(pd.concat([agg[i], reference[i]],axis=1).sum(axis=1))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1950
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-6dc4ee76a8f8> in <module>
#       1 pmi = pd.DataFrame()
#       2 for i in agg:
# ----> 3     pmi[i] = agg[i]**1.02/(pd.concat([agg[i], reference[i]],axis=1).sum(axis=1))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1950

# %%
nb.normalize_corpus_dataframe(pmi)

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
#
# # De 15 beste for passende kolonne

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(15).fillna(0).style.background_gradient(axis=0)
# Out:
# <style  type="text/css" >
#     #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row0_col2 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row0_col3 {
#             background-color:  #03466e;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row0_col4 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row1_col0 {
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row1_col1 {
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row1_col2 {
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row1_col3 {
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row2_col0 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row2_col1 {
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row2_col2 {
#             background-color:  #167bb6;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row2_col3 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row2_col4 {
#             background-color:  #4897c4;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row3_col0 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row3_col1 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row3_col2 {
#             background-color:  #4a98c5;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row3_col3 {
#             background-color:  #034d79;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row3_col4 {
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row4_col0 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row4_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row4_col2 {
#             background-color:  #84b0d3;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row4_col3 {
#             background-color:  #03456c;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row5_col0 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row5_col1 {
#             background-color:  #045d92;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row5_col2 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row5_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row5_col4 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row6_col0 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row6_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row6_col3 {
#             background-color:  #034c78;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row6_col4 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row7_col0 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row7_col1 {
#             background-color:  #02395a;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row7_col2 {
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row7_col3 {
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row7_col4 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row8_col0 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row8_col1 {
#             background-color:  #023d60;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row8_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row8_col3 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row8_col4 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row9_col0 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row9_col1 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row9_col2 {
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row9_col3 {
#             background-color:  #03466e;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row9_col4 {
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row10_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row10_col1 {
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row10_col2 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row10_col3 {
#             background-color:  #84b0d3;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row10_col4 {
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row11_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row11_col1 {
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row11_col2 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row11_col3 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_1fbb9312_58c8_11ea_8364_a0a4c554f2a3row11_col4 {
#             background-color:  #bdc8e1;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(15).fillna(0).style.background_gradient(axis=0)
# Out:
# <style  type="text/css" >
#     #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row0_col2 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row0_col3 {
#             background-color:  #03466e;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row0_col4 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row1_col0 {
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row1_col1 {
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row1_col2 {
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row1_col3 {
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row2_col0 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row2_col1 {
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row2_col2 {
#             background-color:  #167bb6;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row2_col3 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row2_col4 {
#             background-color:  #4897c4;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row3_col0 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row3_col1 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row3_col2 {
#             background-color:  #4a98c5;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row3_col3 {
#             background-color:  #034d79;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row3_col4 {
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row4_col0 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row4_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row4_col2 {
#             background-color:  #84b0d3;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row4_col3 {
#             background-color:  #03456c;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row5_col0 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row5_col1 {
#             background-color:  #045d92;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row5_col2 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row5_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row5_col4 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row6_col0 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row6_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row6_col3 {
#             background-color:  #034c78;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row6_col4 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row7_col0 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row7_col1 {
#             background-color:  #02395a;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row7_col2 {
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row7_col3 {
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row7_col4 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row8_col0 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row8_col1 {
#             background-color:  #023d60;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row8_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row8_col3 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row8_col4 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row9_col0 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row9_col1 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row9_col2 {
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row9_col3 {
#             background-color:  #03466e;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row9_col4 {
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row10_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row10_col1 {
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row10_col2 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row10_col3 {
#             background-color:  #84b0d3;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row10_col4 {
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row11_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row11_col1 {
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row11_col2 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row11_col3 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_1ff1ff80_58c8_11ea_b6e4_a0a4c554f2a3row11_col4 {
#             background-color:  #bdc8e1;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[1], ascending=False).head(15).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row0_col1 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row0_col2 {
#             background-color:  #056ba9;
#             color:  #f1f1f1;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row0_col3 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row1_col1 {
#             background-color:  #2a88bc;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row1_col2 {
#             background-color:  #2383ba;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row1_col3 {
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row2_col0 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row2_col1 {
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row2_col3 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row3_col1 {
#             background-color:  #9ebad9;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row3_col2 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row3_col3 {
#             background-color:  #2383ba;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row4_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row4_col1 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row4_col2 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row4_col3 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row5_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row5_col1 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row5_col2 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row5_col3 {
#             background-color:  #358fc0;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row6_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row6_col1 {
#             background-color:  #2383ba;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row6_col2 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row6_col3 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row7_col0 {
#             background-color:  #03456c;
#             color:  #f1f1f1;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row7_col1 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row7_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row7_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row7_col4 {
#             background-color:  #589ec8;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row8_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row8_col1 {
#             background-color:  #b0c2de;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row8_col2 {
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row8_col3 {
#             background-color:  #63a2cb;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row9_col0 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row9_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row9_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row9_col3 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row9_col4 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row10_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row10_col1 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row10_col2 {
#             background-color:  #62a2cb;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row10_col3 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row10_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row11_col0 {
#             background-color:  #056ba9;
#             color:  #f1f1f1;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row11_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row11_col2 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row11_col3 {
#             background-color:  #c8cde4;
#             color:  #000000;
#         }    #T_2028c9dc_58c8_11ea_a4f8_a0a4c554f2a3row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[2], ascending=False).head(15).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row0_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row0_col2 {
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row0_col3 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row1_col1 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row1_col2 {
#             background-color:  #056ba9;
#             color:  #f1f1f1;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row1_col3 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row2_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row2_col1 {
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row2_col2 {
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row2_col3 {
#             background-color:  #60a1ca;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row3_col1 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row3_col2 {
#             background-color:  #4697c4;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row3_col3 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row4_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row4_col2 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row4_col3 {
#             background-color:  #3991c1;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row4_col4 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row5_col1 {
#             background-color:  #04639b;
#             color:  #f1f1f1;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row5_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row5_col3 {
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row5_col4 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row6_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row6_col1 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row6_col2 {
#             background-color:  #62a2cb;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row6_col3 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row7_col1 {
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row7_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row7_col3 {
#             background-color:  #023a5b;
#             color:  #f1f1f1;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row7_col4 {
#             background-color:  #2d8abd;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row8_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row8_col1 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row8_col2 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row8_col3 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row9_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row9_col1 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row9_col2 {
#             background-color:  #76aad0;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row9_col3 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row10_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row10_col1 {
#             background-color:  #0567a1;
#             color:  #f1f1f1;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row10_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row10_col3 {
#             background-color:  #1077b4;
#             color:  #f1f1f1;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row10_col4 {
#             background-color:  #3790c0;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row11_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row11_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row11_col2 {
#             background-color:  #1c7fb8;
#             color:  #000000;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row11_col3 {
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }    #T_20636274_58c8_11ea_9f90_a0a4c554f2a3row11_col4 {
#             background-color:  #b8c6e0;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[3], ascending=False).head(15).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row0_col4 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row1_col1 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row1_col2 {
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row1_col3 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row2_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row2_col1 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row2_col2 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row2_col3 {
#             background-color:  #358fc0;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row3_col1 {
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row3_col2 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row3_col4 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row4_col1 {
#             background-color:  #157ab5;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row4_col2 {
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row4_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row4_col4 {
#             background-color:  #358fc0;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row5_col2 {
#             background-color:  #045585;
#             color:  #f1f1f1;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row5_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row5_col4 {
#             background-color:  #63a2cb;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row6_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row6_col2 {
#             background-color:  #1c7fb8;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row6_col3 {
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row6_col4 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row7_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row7_col1 {
#             background-color:  #9ebad9;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row7_col2 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row7_col3 {
#             background-color:  #2383ba;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row7_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row8_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row8_col1 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row8_col2 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row8_col3 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row9_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row9_col2 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row9_col3 {
#             background-color:  #3991c1;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row9_col4 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row10_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row10_col1 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row10_col2 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row10_col3 {
#             background-color:  #3d93c2;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row10_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row11_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row11_col1 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row11_col2 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row11_col3 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_2096cd26_58c8_11ea_9460_a0a4c554f2a3row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[4], ascending=False).head(15).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row0_col1 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row0_col2 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row0_col3 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row1_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row1_col2 {
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row1_col3 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row2_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row2_col2 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row2_col3 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row2_col4 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row3_col2 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row3_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row3_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row4_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row5_col1 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row5_col2 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row5_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row5_col4 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row6_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row6_col2 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row6_col3 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row6_col4 {
#             background-color:  #03517e;
#             color:  #f1f1f1;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row7_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row7_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row7_col2 {
#             background-color:  #4897c4;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row7_col3 {
#             background-color:  #1e80b8;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row7_col4 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row8_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row8_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row8_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row8_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row9_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row9_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row9_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row10_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row10_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row10_col2 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row10_col3 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row10_col4 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row11_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row11_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row11_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row11_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_20d014de_58c8_11ea_a1a8_a0a4c554f2a3row11_col4 {
#             background-color:  #2383ba;
#             color:  #0

# %% [markdown]
# <br>
# <br>

# %%
pmi.to_csv(filename)

# %% [markdown]
# # Assosiasjoner og variasjon over år.

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(12, 8));

# %%
def freq_assoc_val(agg, pmi, col):
    vals = list(pmi.sort_values(by=pmi.columns[col], ascending=False).head(5).fillna(0).index)
    agg.loc[vals].sort_values(by= agg.columns[col], ascending=False).transpose().plot(kind="bar", rot=0, figsize=(12, 8))

# %%
freq_assoc_val(agg, pmi, 0)

# %%
freq_assoc_val(agg, pmi, 1)

# %%
freq_assoc_val(agg, pmi, 3)

# %%
freq_assoc_val(agg, pmi, 4)

# %%
freq_assoc_val(pmi, pmi, 1)

# %%
freq_assoc_val(pmi, pmi, 2)

# %%
freq_assoc_val(pmi, pmi, 3)

# %%
freq_assoc_val(pmi, pmi, 4)

# %%
freq_assoc_val(pmi, pmi, 0)

# %%
freq_assoc_val(pmi, pmi, 0)

# %%
freq_assoc_val(pmi, pmi, 0)

# %%
pmi.sort_values(by=pmi.columns[4], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(12, 8));

# %%
agg.sort_values(by=agg.columns[3], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(14, 8));

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # De hundre ordene med høyest assosiasjon for perioden sortert på ordklasser

# %%
mdprint(pmi.sort_values(by=pmi.columns[2], ascending=False).head(100),-1)
# Out:
# ## Benevnelser
# <span style='font-size:150%'>Diktatur, Karamanlis, Demokratiet, AKP, Soares, Colombia, Sletbak, Weber, Vestens, Kongress, Kommunisme, ØD, Rhodesia, Presserunden, Begrepet, SVs, Francos, Suarez, Notaker, Libertas, Romatraktaten, Dahl-Hansen, Janata</span>
# ## subst
# <span style='font-size:1.1em'>folkestyre, rettssikkerhet, styreform, bedriftsdemokrati, respekten, bedriftsdemokratiet, rettsstat, medinnflytelse, pressefrihet, ulydighet, styresett, politistat, sentralisme, hverdagen, anarki, humanisme, menneskerett, menneskerettighetene, ytringsfriheten, sosialisering, organisasjonsfrihet, folkeviljen, råderett, ideal, grasrota, pluralisme, sunnhetstegn, selvråderett, diktatur, folkedemokrati, demokratier, forsoning, likhetstegn, rettsstaten, monarki, folkeavstemninger, pamper, flerpartisystem, styreformer, spillfekteri, makthavere</span>
# ## adj
# <span style='font-size:1.1em'>industrielt, uforenlig, funksjonsdyktig, livskraftig, konstitusjonelle, autoritært, fullkomment, konstitusjonelt, proletarisk, fascistisk, totalitært, sunne, ufullkomment</span>
# ## unknown
# <span style='font-size:1.1em'>medbestemmelse, kvardagen, folkenes, samfunnsform, kriseløsning, flertallets, øst-europeiske, borgarleg, vest-europeisk, lønnstakerfond, maktkonsentrasjon, kyrkjelege, gjeninnføring, språkleg, enkeltmennesket, flertallsdiktatur, meningsfrihet, vestlege, flertallsstyre</span>
# ## verb
# <span style='font-size:1.1em'>gjeninnføre, misbrukes, avskaffe</span>
# ## fork
# <span style='font-size:1.1em'>m-l</span>

# %% [markdown]
# # Hvordan utvikler ordene seg?

# %%
barchart = lambda w, title='', df=pmi: df.loc[w].transpose().plot(kind='bar',title=title, rot=20, figsize=(12,6)) ;

# %%
barchart(['helse','kreft',"sengeliggende", 'arbeidsplassen'], 'Utvalgte ord, frekvens', df=agg);

# %%
barchart(['helse','kreft',"sengeliggende", 'arbeidsplassen'], 'Utvalgte ord, assosiasjon');

# %% [markdown]
# <br>
# <br>
#
# # Sjekk ut vanlige ord
#
# Bare for å se at de har lave verdier og er stabile gjennom kollokasjonen

# %%
barchart(['.','og', ',','eller', 'men'], 'Punktueringer og vanlige ord', pmi);

# %%
barchart(['.','og', ',','eller', 'men'], 'Punktueringer og vanlige ord', agg);

# %% [markdown]
# <br>
# <br>
#
# # De fremste blandt topoi
#
# Merk at på grunn av louvain-algoritmen kan topoiene endre seg litt fra kjøring til kjøring

# %%
commchart = lambda x, part =(1,6): barchart(comm[list(comm.keys())[x]][part[0]:part[1]], list(comm.keys())[x]);

# %%
commchart(2, (0,5));

# %%
commchart(1, (3, 8))

# %%
commchart(3)
