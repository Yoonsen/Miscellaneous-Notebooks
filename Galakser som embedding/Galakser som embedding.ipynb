# %% [markdown]
# ### Galakser som embeddinger

# %%
# Hvis dhlab ikke er installert, avkommenter linjen under og kjør
#!pip install dhlab

# %%
import dhlab.nbtext as nb
import dhlab.graph_networkx_louvain as gnl

# %%
nb.concordance('bil')
# Out:
# <table><tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013022006086?searchText=bil' target='_'>Grønnerud, Bjørg Randi,Min barndoms Kongsvinger,2010</a></td><td>Ingen i vår familie hadde</td><td>bil</td><td style='text-align:left'>. Jeg gledet meg voldsomt</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013022006086?searchText=bil' target='_'>Grønnerud, Bjørg Randi,Min barndoms Kongsvinger,2010</a></td><td>kunder eller lå under en</td><td>bil</td><td style='text-align:left'>. Åpningstida var fra morgen</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013022006086?searchText=bil' target='_'>Grønnerud, Bjørg Randi,Min barndoms Kongsvinger,2010</a></td><td>Schøyen . Kom det en</td><td>bil</td><td style='text-align:left'>, svingte den bare forbi</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013022006086?searchText=bil' target='_'>Grønnerud, Bjørg Randi,Min barndoms Kongsvinger,2010</a></td><td>Skulle det komme en</td><td>bil</td><td style='text-align:left'>på glatt føre , var</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013022006086?searchText=bil' target='_'>Grønnerud, Bjørg Randi,Min barndoms Kongsvinger,2010</a></td><td>. Framkomstmiddelet vårt var verken</td><td>bil</td><td style='text-align:left'>eller sykkel , men robåt</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012121206235?searchText=bil' target='_'>Matland, Inge,Mann i dag,1985</a></td><td>I stedet for å bruke</td><td>bil</td><td style='text-align:left'>eller buss hele veien til</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015082548150?searchText=bil' target='_'>,Ferie &amp; Fritidshavner,1996</a></td><td>med en mo- unna med</td><td>bil</td><td style='text-align:left'>ligger Bondalseidet</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2006110700023?searchText=bil' target='_'>Elstad, Ingunn,store snøvinteren,1981</a></td><td>vegen - rett tl2mtol sin</td><td>bil</td><td style='text-align:left'>. LremBene kvin og lyktene</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2006110700023?searchText=bil' target='_'>Elstad, Ingunn,store snøvinteren,1981</a></td><td>Tin kunne leike at kvar</td><td>bil</td><td style='text-align:left'>var ein tiger Bom Bprang</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011012108058?searchText=bil' target='_'>Akselsen, Sigmund,Helsevesenet &amp; ISDN,1991</a></td><td>( RiTø ) reiser med</td><td>bil</td><td style='text-align:left'>til Setermoen en dag hver</td></tr>
# </table>

# %% [markdown]
# ## Test ut med kommando `relaterte_ord`
#
# Det er en egenvektorbasert måte å hente ut tilsvarende ord fra grafen gitt under.

# %%
G= nb.make_graph('democracy' , lang='eng')

# %%
nb.relaterte_ord('voldtekt', score = True)
# Out:
# [('vold', 0.3200990212005758),
#  ('voldtekt', 0.3050382055678085),
#  ('drap', 0.30495319420316286),
#  ('mishandling', 0.28440580479627564),
#  ('tortur', 0.24175078549468665),
#  ('ran', 0.2381268743939038),
#  ('overgrep', 0.22392450708714934),
#  ('kidnapping', 0.1990600267843371),
#  ('mord', 0.19890424678439322),
#  ('overfall', 0.1911873359600653),
#  ('trusler', 0.17244495893799341),
#  ('frihetsberøvelse', 0.16262907802027135),
#  ('plyndring', 0.15308106788649828),
#  ('incest', 0.1480535032746876),
#  ('voldtekter', 0.14301739433059193),
#  ('seksuell', 0.14185031211212387),
#  ('drapsforsøk', 0.13845518295116696),
#  ('trakassering', 0.13400531322782647),
#  ('seksuelt', 0.12347516197334563),
#  ('seksuelle', 0.12268030372093627)]

# %% [markdown]
# ## Ta ut grafen og hent ut med passende algoritem
#
#
# Grafen er et **networkx**- objekt.

# %%
G = nb.make_graph('seks', cutoff = 12)

# %%
syn('seks')
# Out:
# ['seks',
#  'åtte',
#  'tolv',
#  'syv',
#  'ni',
#  'elleve',
#  'sju',
#  'drept',
#  'tretten',
#  'fjorten',
#  'minutt',
#  'jaktfalker',
#  'tyvende',
#  'seksten',
#  'lasteplass',
#  'år',
#  'shilling']

# %%
gnl.show_graph(G, spread = 1)

# %% [markdown]
# Med `show_communities` gis en litt mer detaljert clustring fra grafen

# %%
gnl.show_communities(G)
# Out:
# eik-furu :  eik, furu, bjørk, bjerk, merbau, gran, teak, bøk, mahogni, ask, ek, blandingsved, Eik, bjork, edelgran, mahogny, bl.ved, osp, Bjørk, palisander, valnøtt, redwood, blanding, briketter, skogsved
#
# lønn-personal :  lønn, personal
#
# kirsebær-bringebær :  kirsebær, bringebær, jordbær, solbær, blåbær, bjørnebær, moreller, Solbær, rips, tyttebær, fronter, Moreller, multer, krekling, Bringebær, stikkelsbær, is, skuffer, champagne, molter, Stikkelsbær, Jordbær
#
# plommer-pærer :  plommer, pærer, epler, eple, bananer, appelsiner, Epler
#
# krydder-grønnsaker :  krydder, grønnsaker, urter, bær, lakris, salt, hvitløk, tomatpuré
#
# Diamanter-Perler :  Diamanter, Perler

# %%
gnl.show_cliques(G
                )
# Out:
# (3, 1) Moreller, bringebær, rips, multer, plommer, bær, Jordbær, lakris, jordbær, kirsebær, Epler, urter, tyttebær, eple, blåbær, pærer, krekling, bjørnebær, epler, moreller, stikkelsbær, solbær, krydder, Solbær, Bringebær
#
# (3, 2) valnøtt, bøk, bjerk, fronter, mahogny, lønn, eik, kirsebær, teak, blandingsved, furu, ask, Bjørk, mahogni, ek, merbau, bjørk, gran
#
# (4, 1) tyttebær, bringebær, rips, plommer, blåbær, krekling, bjørnebær, epler, moreller, solbær, jordbær, kirsebær, Solbær, Bringebær
#
# (4, 2) bjerk, eik, kirsebær, bjørk, furu
#
# (5, 1) bringebær, plommer, blåbær, bjørnebær, moreller, solbær, jordbær, kirsebær
#
# (6, 1) bringebær, plommer, blåbær, bjørnebær, moreller, solbær, jordbær, kirsebær
#
# (7, 1) bjørnebær, moreller, bringebær, solbær, plommer, jordbær, kirsebær

# %%
nb.central_characters(G, n=50)
# Out:
# [('hode', 0.3709677419354839),
#  ('rygg', 0.3064516129032258),
#  ('armer', 0.29032258064516125),
#  ('hals', 0.282258064516129),
#  ('bryst', 0.282258064516129),
#  ('bein', 0.2661290322580645),
#  ('kropp', 0.25),
#  ('knær', 0.23387096774193547),
#  ('hender', 0.1935483870967742),
#  ('nakke', 0.1935483870967742),
#  ('ansikt', 0.1935483870967742),
#  ('skuldre', 0.18548387096774194),
#  ('ben', 0.1774193548387097),
#  ('føtter', 0.1774193548387097),
#  ('mage', 0.1774193548387097),
#  ('hjerte', 0.16129032258064516),
#  ('labber', 0.1532258064516129),
#  ('sykkel', 0.13709677419354838),
#  ('klør', 0.13709677419354838),
#  ('skulder', 0.12096774193548387),
#  ('hale', 0.12096774193548387),
#  ('lengder', 0.10483870967741934),
#  ('lår', 0.08064516129032258),
#  ('hofter', 0.07258064516129031),
#  ('klor', 0.07258064516129031),
#  ('innmat', 0.06451612903225806),
#  ('poter', 0.06451612903225806),
#  ('overkropp', 0.056451612903225805),
#  ('hofte', 0.04838709677419355),
#  ('ankler', 0.04838709677419355),
#  ('labb', 0.04032258064516129),
#  ('ermer', 0.04032258064516129),
#  ('albuer', 0.04032258064516129),
#  ('snute', 0.04032258064516129),
#  ('hovud', 0.04032258064516129),
#  ('sjel', 0.04032258064516129),
#  ('buk', 0.04032258064516129),
#  ('arm', 0.03225806451612903),
#  ('overmadrass', 0.03225806451612903),
#  ('hoder', 0.03225806451612903),
#  ('hår', 0.03225806451612903),
#  ('fingre', 0.03225806451612903),
#  ('legger', 0.03225806451612903),
#  ('skuldrer', 0.03225806451612903),
#  ('sinn', 0.03225806451612903),
#  ('hjerne', 0.03225806451612903),
#  ('skinn', 0.03225806451612903),
#  ('stemme', 0.03225806451612903),
#  ('armlener', 0.024193548387096774),
#  ('vinger', 0.024193548387096774)]

# %% [markdown]
# Ta ut clusteret som et python-objekt

# %%
gnl.community_dict(G)
# Out:
# {'armer-bein': ['armer',
#   'bein',
#   'ben',
#   'overmadrass',
#   'arm',
#   'skinn',
#   'hen',
#   'brusk',
#   'arme',
#   'marg',
#   'knokler',
#   'armar',
#   'Armer',
#   'ball'],
#  'rygg-knær': ['rygg',
#   'knær',
#   'nakke',
#   'skuldre',
#   'mage',
#   'skulder',
#   'lår',
#   'hofter',
#   'ankler',
#   'hofte',
#   'albuer',
#   'buk',
#   'legger',
#   'skuldrer',
#   'armlener',
#   'kinn',
#   'rumpe',
#   'rygger',
#   'kne',
#   'ledd',
#   'korsrygg',
#   'nakker',
#   'bog',
#   'sete',
#   'front'],
#  'hode-bryst': ['hode',
#   'bryst',
#   'hals',
#   'ansikt',
#   'labber',
#   'poter',
#   'innmat',
#   'overkropp',
#   'snute',
#   'labb',
#   'ermer',
#   'nese',
#   'node',
#   'hoved',
#   'hud',
#   'mave',
#   'svelg',
#   'butterfly',
#   'munn',
#   'indmat',
#   'hvit',
#   'blod',
#   'bode',
#   'Hud',
#   'haand',
#   'allergi',
#   'stykk',
#   'hake',
#   'forlabber'],
#  'hender-føtter': ['hender',
#   'føtter',
#   'hoder',
#   'fingre',
#   'hår',
#   'tær',
#   'øyne',
#   'negler'],
#  'hale-vinger': ['hale', 'vinger', 'horn', 'ører', 'ister'],
#  'sykkel-kollektivtrafikk': ['sykkel',
#   'kollektivtrafikk',
#   'moped',
#   'rulleski',
#   'hjelm',
#   'ski',
#   'bil',
#   'spark',
#   'kjerre'],
#  'kropp-hjerte': ['kropp',
#   'hjerte',
#   'sjel',
#   'hovud',
#   'hjerne',
#   'stemme',
#   'sinn',
#   'lunger',
#   'sex',
#   'seksualitet',
#   'muskler',
#   'klær',
#   'utseende',
#   'ånd',
#   'lunge',
#   'nyrer',
#   'helse'],
#  'klør-klor': ['klør',
#   'klor',
#   'nebb',
#   'skjell',
#   'tenner',
#   'Stikk',
#   'myke',
#   'smidighet',
#   'pels',
#   'neb',
#   'svir',
#   'Tenner'],
#  'lengder-farger': ['lengder',
#   'farger',
#   'bredder',
#   'dybder',
#   'dimensjoner',
#   'tykkelser']}

# %%
indianere = nb.make_graph('indians', lang='eng')

# %%
gnl.show_graph(indianere)
# Out:
# C:\Users\larsj\AppData\Local\Continuum\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
gnl.show_communities(indianere)
# Out:
# blacks-whites :  blacks, whites, indians, coloureds, greys, nonblacks, hispanics, coloreds
#
# cowboys-ranchmen :  cowboys, ranchmen, sheepherders, cowgirls, vaqueros, cowmen
#
# mestizos-pardos :  mestizos, pardos, mestizas, cholos, mulatos, criollos
#
# negroes-mulattos :  negroes, mulattos, mulattoes, carpetbaggers, scalawags

# %%
violence = nb.make_graph('violence', lang='eng')

# %%
gnl.show_graph(violence, spread = 1)

# %%
gnl.show_cliques(violence)
# Out:
# (3, 1) lawlessness, Rapine, violence, pillage, bloodshed, rapine, incendiarism
#
# (3, 2) terrorisation, violence, thuggery, intimidation

# %%
gnl.show_communities(violence)
# Out:
# rapine-Rapine :  rapine, Rapine, bloodshed, pillage, Plunder, ruffianism, Extortion, Murder, Spoil, plunder, Lust, incendiarism
#
# rapines-murders :  rapines, murders, depredations, extortions, robberies
#
# violence-terrorisation :  violence, terrorisation, vagabondism, oppreffion, Fickleness
#
# nonviolence-satyagraha :  nonviolence, satyagraha, noncooperation, pacifism, nonresistance, peacemaking
#
# Lawlessness-Violence :  Lawlessness, Violence, anarchy, Crime, counterviolence
#
# intimidation-harassment :  intimidation, harassment, bribery, coercion, cajolery, harrassment, terrorization, extortion
#
# lawlessness-thuggery :  lawlessness, thuggery, hooliganism, banditry, brigandage, corruption
#
# suddenness-unexpectedness :  suddenness, unexpectedness, swiftness, abruptness

# %%
nb.unigram()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-156b2c83ec38> in <module>
# ----> 1 nb.unigram()
#
# TypeError: unigram() missing 1 required positional argument: 'word'

# %%
curl "https://api.nb.no/catalog/v1/items?q=hamsun^&filter=mediatype:
b^%^C3^%^B8ker^&filter=digital:Ja^&
    filter=contentClasses^%^3Ajp2^&a
    ggs=mediatype^&aggs=year^%^3A9999^&
    aggs=literaryform^&aggs=languages^%^3A9999^&aggs=bibliography^&aggs=ddc1^&size=18^&
    digitalAccessibleOnly=true^&profile=wwwnbno" ^
  -X "OPTIONS" ^
  -H "authority: api.nb.no" ^
  -H "accept: */*" ^
  -H "access-control-request-method: GET" ^
  -H "access-control-request-headers: authorization" ^
  -H "origin: https://www.nb.no" ^
  -H "user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36" ^
  -H "sec-fetch-mode: cors" ^
  -H "sec-fetch-site: same-site" ^
  -H "sec-fetch-dest: empty" ^
  -H "referer: https://www.nb.no/" ^
  -H "accept-language: nb-NO,nb;q=0.9,en-US;q=0.8,en;q=0.7,no;q=0.6,nn;q=0.5" ^
  --compressed
