# %% [markdown]
# ### Galakser som embeddinger

# %%
# Hvis dhlab ikke er installert, avkommenter linjen under og kjør
#!pip install dhlab

# %%
import dhlab.nbtext as nb
import dhlab.graph_networkx_louvain as gnl

# %%
nb.concordance('bil')
# Out:
# <table><tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015043007540?searchText=bil' target='_'>Maxim, John R.,Mannen med tre ansikter,1985</a></td><td>og dirigerte kroppen mot en</td><td>bil</td><td style='text-align:left'>som ventet . Advokatens andre</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015043007540?searchText=bil' target='_'>Maxim, John R.,Mannen med tre ansikter,1985</a></td><td>om et hjul på en</td><td>bil</td><td style='text-align:left'>, for å sitere ordrett</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015043007540?searchText=bil' target='_'>Maxim, John R.,Mannen med tre ansikter,1985</a></td><td>burde fa tak i en</td><td>bil</td><td style='text-align:left'>? »</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015043007540?searchText=bil' target='_'>Maxim, John R.,Mannen med tre ansikter,1985</a></td><td>. fant henne i en</td><td>bil</td><td style='text-align:left'>. . . A ,</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015043007540?searchText=bil' target='_'>Maxim, John R.,Mannen med tre ansikter,1985</a></td><td>satt bak i en parkert</td><td>bil</td><td style='text-align:left'>med ansiktet mot vinduet .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012092808058?searchText=bil' target='_'>Gjerdrum, Anne-Lise,Eg reknar,1989</a></td><td>Figuren viser bensinforbruket til ein</td><td>bil</td><td style='text-align:left'>Kor mykje bensin bruker bilen</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013060408199?searchText=bil' target='_'>Messel, Gunnar,Rød hevn,1978</a></td><td>i gaten sto en mørk</td><td>bil</td><td style='text-align:left'>med lysene slukket , men</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013060408199?searchText=bil' target='_'>Messel, Gunnar,Rød hevn,1978</a></td><td>nærheten av en ven tende</td><td>bil</td><td style='text-align:left'>. Der skjøt han dem</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013060408199?searchText=bil' target='_'>Messel, Gunnar,Rød hevn,1978</a></td><td>ført ut av Hellas med</td><td>bil</td><td style='text-align:left'>, tog eller fly .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009081904011?searchText=bil' target='_'>Kindem, Ingeborg,Sangbok for den høgre skolen,1955</a></td><td>le og stir- red i</td><td>bil</td><td style='text-align:left'>- led sag 1 -</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016091248053?searchText=bil' target='_'>Straume, Jakob,Kristenliv i Bjørgvin,1952</a></td><td>Kameratane køyrde heim i ein</td><td>bil</td><td style='text-align:left'>. Men bilen gjekk ut</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016091248053?searchText=bil' target='_'>Straume, Jakob,Kristenliv i Bjørgvin,1952</a></td><td>er som i ein overfylt</td><td>bil</td><td style='text-align:left'>i fart . Ein sikkast</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016091248053?searchText=bil' target='_'>Straume, Jakob,Kristenliv i Bjørgvin,1952</a></td><td>til å fylgje buss eller</td><td>bil</td><td style='text-align:left'>, men han måtte til</td></tr>
# </table>

# %% [markdown]
# ## Test ut med kommando `relaterte_ord`
#
# Det er en egenvektorbasert måte å hente ut tilsvarende ord fra grafen gitt under.

# %%
G= nb.make_graph('democracy' , lang='eng')

# %%
nb.relaterte_ord('suverenitet', score=True)
# Out:
# [('uavhengighet', 0.369458551549911),
#  ('frihet', 0.3659626152969472),
#  ('demokrati', 0.29737915987218744),
#  ('selvstendighet', 0.2739477341553014),
#  ('integritet', 0.2603010469683872),
#  ('suverenitet', 0.22816185026060373),
#  ('sikkerhet', 0.22254089623295945),
#  ('nasjonal', 0.21645412936204048),
#  ('selvbestemmelsesrett', 0.19785841428815443),
#  ('fred', 0.15791785508950923),
#  ('territoriale', 0.14529870663055316),
#  ('handlefrihet', 0.12636128131865268),
#  ('ansvar', 0.11716438408263057),
#  ('fleksibilitet', 0.11716438408263057),
#  ('menneskeverd', 0.1114868845131059),
#  ('sosialisme', 0.10852347243866088),
#  ('humanitet', 0.10287579724370285),
#  ('folkestyre', 0.10142691114275199),
#  ('menneskerettigheter', 0.10142691114275199),
#  ('rettferdighet', 0.10142691114275199)]

# %% [markdown]
# ## Ta ut grafen og hent ut med passende algoritem
#
#
# Grafen er et **networkx**- objekt.

# %%
G = nb.make_graph('hode')

# %%
gnl.show_graph(G, spread = 1.3)
# Out:
# C:\Users\larsj\AppData\Local\Continuum\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %% [markdown]
# Med `show_communities` gis en litt mer detaljert clustring fra grafen

# %%
gnl.show_communities(G)
# Out:
# hode-bryst :  hode, bryst, mage, labber, lår, poter, innmat, snute, labb, node, hud, kinn, mave, bode, hake, indmat, butterfly, stykk, hvit, blod, Hud, forlabber
#
# rygg-knær :  rygg, knær, nakke, skuldre, skulder, hofter, hofte, ankler, buk, albuer, skuldrer, legger, armlener, rumpe, korsrygg, bog, rygger, sete, ledd, nakker, front, kne
#
# armer-bein :  armer, bein, ben, overmadrass, arm, skinn, arme, ball, brusk, marg, hen, knokler, armar, Armer
#
# hals-ansikt :  hals, ansikt, hender, føtter, overkropp, ermer, fingre, hoder, hår, hoved, nese, tær, øyne, svelg, allergi, haand, negler, munn
#
# kropp-hjerte :  kropp, hjerte, sjel, hovud, stemme, sinn, hjerne, lunger, seksualitet, sex, muskler, ånd, lunge, utseende, klær, nyrer, helse
#
# sykkel-ski :  sykkel, ski, rulleski, hjelm, kollektivtrafikk, spark, kjerre, moped, bil
#
# klør-klor :  klør, klor, skjell, nebb, tenner, pels, Stikk, neb, svir, smidighet, myke, Tenner
#
# hale-vinger :  hale, vinger, ører, horn, ister
#
# lengder-dimensjoner :  lengder, dimensjoner, farger, tykkelser, bredder, dybder

# %%
nb.central_betweenness_characters(G)
# Out:
# [('democracy', 0.34708603145235883),
#  ('autocracy', 0.2695453944760143),
#  ('constitutionalism', 0.19983921413153607),
#  ('centralism', 0.18922954935905908),
#  ('totalitarianism', 0.14598255583454475),
#  ('parliamentarism', 0.09665983877362232),
#  ('oligarchy', 0.0943978238844104),
#  ('secularism', 0.07770582793709528),
#  ('Autocracy', 0.055807012906920396),
#  ('Orthodoxy', 0.05550416281221092)]

# %% [markdown]
# Ta ut clusteret som et python-objekt

# %%
gnl.community_dict(G)
# Out:
# {'kultur-miljø': ['kultur',
#   'miljø',
#   'oppvekst',
#   'næring',
#   'energi',
#   'sikkerhet',
#   'samferdsel',
#   'teknikk',
#   'fritid',
#   'historie',
#   'landbruk',
#   'natur',
#   'medier',
#   'utvikling',
#   'kunst',
#   'trafikksikkerhet',
#   'samfunn',
#   'vitenskap',
#   'økonomi',
#   'næringsliv',
#   'religion',
#   'byutvikling',
#   'tradisjon',
#   'språk',
#   'klima',
#   'Natur'],
#  'utdanning-skole': ['utdanning',
#   'skole',
#   'Arbeid',
#   'forskning',
#   'butikk',
#   'yrke',
#   'læring',
#   'administrativ',
#   'jobb',
#   'forsking',
#   'Skole',
#   'praksis',
#   'daghjem',
#   'Ungdom',
#   'erfaring',
#   'barnehage',
#   'barnehave',
#   'hjem',
#   'psykisk',
#   'Trygd'],
#  'trivsel-velferd': ['trivsel',
#   'velferd',
#   'livskvalitet',
#   'velvære',
#   'sunnhet',
#   'Helse',
#   'trygghet',
#   'glede',
#   'sysselsetting',
#   'arbeidsplasser',
#   'vitalitet',
#   'livsglede',
#   'trim',
#   'sykdom',
#   'utfoldelse',
#   'vekst',
#   'skjønnhet',
#   'levekår',
#   'Heise',
#   'bolyst',
#   'framgang',
#   'styrke',
#   'velstand',
#   'smak',
#   'hygge',
#   'demokrati',
#   'lykke',
#   'verdiskaping',
#   'fremgang',
#   'menneskeverd',
#   'mestring',
#   'sundhet',
#   'verdighet',
#   'arbeidsevne',
#   'luksus',
#   'komfort',
#   'samhold'],
#  'sosiale-økonomiske': ['sosiale',
#   'økonomiske',
#   'pedagogiske',
#   'psykologiske',
#   'helsemessige',
#   'humanitære',
#   'faglige',
#   'medisinske',
#   'kulturelle',
#   'okonomiske',
#   'politiske',
#   'psykiske',
#   'menneskelige'],
#  'helse--sosialetaten': ['helse-',
#   'sosialetaten',
#   'sosialsjefen',
#   'sosialstyret',
#   'sosialsjef',
#   'sosialfag',
#   'Helse-',
#   'sosialsektoren',
#   'sosialutvalget',
#   'se-',
#   'sosialfaglig',
#   'sosialsaker',
#   'heise-',
#   'lelse-',
#   'omsorgs-',
#   'trygde-',
#   'Heise-',
#   'omsorg-',
#   'helsesjef',
#   'rådmannen',
#   'helserådet',
#   'politiet',
#   'formannskapet',
#   'sosialrådmannen',
#   'skole-',
#   'kultur-'],
#  'mat-medisin': ['mat',
#   'medisin',
#   'Mat',
#   'teknologi',
#   'rehabilitering',
#   'psykologi',
#   'drikke',
#   'klær',
#   'kaffi',
#   'kaffe',
#   'vin',
#   'kopp',
#   'tobakk',
#   'kirurgi',
#   'overnatting',
#   'naturvitenskap',
#   'farmasi',
#   'vann',
#   'jus',
#   'biologi',
#   'fysiologi',
#   'vinhus',
#   'medisiner',
#   'husly'],
#  'helse-eldreomsorg': ['helse',
#   'eldreomsorg',
#   'sosial',
#   'røyking',
#   'aldring',
#   'telekom',
#   'barnehager',
#   'psykiatri',
#   'helsefag',
#   'skoler',
#   'helsevesen',
#   'barnevern',
#   'overvekt',
#   'okonomisk',
#   'kulturell',
#   'medisinsk',
#   'helsestell',
#   'internett',
#   'politisk',
#   'utadvendt',
#   'tuberkulinforhold',
#   'it',
#   'snusing',
#   'lungekreft',
#   'helsevern',
#   'skule',
#   'faglig',
#   'økonomisk',
#   'drikking',
#   'helsetjenester'],
#  'kropp-liv': ['kropp',
#   'liv',
#   'sjel',
#   'død',
#   'ånd',
#   'utseende',
#   'seksualitet',
#   'sex',
#   'lemmer',
#   'lære',
#   'dod',
#   'stemme',
#   'ansikt',
#   'sinn',
#   'hjerne',
#   'diktning',
#   'hode',
#   'virke'],
#  'idrett-aktivitet': ['idrett',
#   'aktivitet',
#   'kosthold',
#   'ernæring',
#   'Kosthold',
#   'trening',
#   'kreft',
#   'alkohol',
#   'sport',
#   'livsstil',
#   'hygiene',
#   'fysisk',
#   'lek',
#   'friluftsliv',
#   'folkehelse',
#   'arbeid',
#   'mosjon',
#   'bosetting',
#   'matvaner',
#   'kroppsøving',
#   'musikk',
#   'avslapping',
#   'Kultur',
#   'politikk',
#   'jordbruk',
#   'leik',
#   'engasjement'],
#  'omsorg-kjærlighet': ['omsorg',
#   'kjærlighet',
#   'stell',
#   'støtte',
#   'god',
#   'pleie',
#   'behandling',
#   'omtanke',
#   'pleie-',
#   'godhet',
#   'hjelp',
#   'varme']}

# %%
indianere = nb.make_graph('indians', lang='eng')

# %%
gnl.show_graph(indianere)
# Out:
# C:\Users\larsj\AppData\Local\Continuum\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
gnl.show_communities(indianere)
# Out:
# blacks-whites :  blacks, whites, indians, coloureds, greys, nonblacks, hispanics, coloreds
#
# cowboys-ranchmen :  cowboys, ranchmen, sheepherders, cowgirls, vaqueros, cowmen
#
# mestizos-pardos :  mestizos, pardos, mestizas, cholos, mulatos, criollos
#
# negroes-mulattos :  negroes, mulattos, mulattoes, carpetbaggers, scalawags

# %%
violence = nb.make_graph('violence', lang='eng')

# %%
gnl.show_graph(violence, spread = 1)

# %%
gnl.show_cliques(violence)
# Out:
# (3, 1) lawlessness, Rapine, violence, pillage, bloodshed, rapine, incendiarism
#
# (3, 2) terrorisation, violence, thuggery, intimidation

# %%
gnl.show_communities(violence)
# Out:
# rapine-Rapine :  rapine, Rapine, bloodshed, pillage, Plunder, ruffianism, Extortion, Murder, Spoil, plunder, Lust, incendiarism
#
# rapines-murders :  rapines, murders, depredations, extortions, robberies
#
# violence-terrorisation :  violence, terrorisation, vagabondism, oppreffion, Fickleness
#
# nonviolence-satyagraha :  nonviolence, satyagraha, noncooperation, pacifism, nonresistance, peacemaking
#
# Lawlessness-Violence :  Lawlessness, Violence, anarchy, Crime, counterviolence
#
# intimidation-harassment :  intimidation, harassment, bribery, coercion, cajolery, harrassment, terrorization, extortion
#
# lawlessness-thuggery :  lawlessness, thuggery, hooliganism, banditry, brigandage, corruption
#
# suddenness-unexpectedness :  suddenness, unexpectedness, swiftness, abruptness
