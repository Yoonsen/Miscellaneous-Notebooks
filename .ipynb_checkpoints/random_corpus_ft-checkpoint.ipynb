# %% [markdown]
# # Fetch concordances and analyze them

# %% [markdown]
# ### Initial code

# %%
import json
import pandas as pd
import requests
import spacy

def search_nb(word = 'demokrati', window=20, limit = 300):
    parameters = {
        'query': word,
        'window':window,
        'limit':limit
    }
    r = requests.get("https://api.nb.no/ngram/db1/konk", params = parameters)
    return pd.DataFrame(json.loads(r.text), columns = 'doc-id concordance'.split())

# %%
pd.set_option('max_colwidth', None)

# %% [markdown]
# # Concordances
#
# A random collection of newspapers, periodicals and/or books are created on each query

# %%
df = search_nb("NEAR (eller og, 5)", limit = 2000)
df.style
# Out:
# <style  type="text/css" >
# </style><table id="T_36a04_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >doc-id</th>        <th class="col_heading level0 col1" >concordance</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_36a04_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_36a04_row0_col0" class="data row0 col0" >100260049</td>
#                         <td id="T_36a04_row0_col1" class="data row0 col1" >... I 1980 utgjorde derfor nasjonale <b>og</b> europeiske organisasjoner <b>eller</b> føderasjoner innenfor landbruk , næringsliv , handel <b>og</b> finans den største andelen . Omkring... </td>
#             </tr>
#             <tr>
#                         <th id="T_36a04_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_36a04_row1_col0" class="data row1 col0" >100260049</td>
#                         <td id="T_36a04_row1_col1" class="data row1 col1" >... sektorer , enkeltfirmaer og profesjonelle lobbyister ( inkludert regnskapsf irmaer <b>og</b> juridiske rådgivere ) <b>eller</b> representanter for selskaper , land , fylker <b>og</b> byer . Organisasjo-</td>
#             </tr>
#             <tr>
#                         <th id="T_36a04_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_36a04_row2_col0" class="data row2 col0" >100260049</td>
#                         <td id="T_36a04_row2_col1" class="data row2 col1" >... regler som styrer interesseartikulasjon ( den korporativ tradisjon ) , <b>eller</b> samspillet mellom parlamentarisk <b>og</b> korporativ innflytelse ( korporativ pluralisme ) ( Rokkan 1966 , Dahl 1967... </td>
#             </tr>
#             <tr>
#                         <th id="T_36a04_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_36a04_row3_col0" class="data row3 col0" >100260049</td>
#                         <td id="T_36a04_row3_col1" class="data row3 col1" >... Tilgang for lobbyister i slike tilfeller er avhengig av spesielle politiske <b>og</b> / <b>eller</b> personlige kontakter på høyt nivå . Generelt er... </td>
#             </tr>
#             <tr>
#                         <th id="T_36a04_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_36a04_row4_col0" class="data row4 col0" >100260049</td>
#                         <td id="T_36a04_row4_col1" class="data row4 col1" >Flere viktige politikkområder går på tvers av økonomiske sektorer , for eksempel forbruker- <b>og</b> miljøbeskyttelse <b>eller</b> sikkerhet i arbeidslivet . Disse politikkområdene... </td>
#             </tr>
#             <tr>
#                         <th id="T_36a04_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_36a04_row5_col0" class="data row5 col0" >100240008</td>
#                         <td id="T_36a04_row5_col1" class="data row5 col1" >Blant de økonomiske faktorene kan det skilles mellom generelle markedsmessige faktorer på den ene siden <b>og</b> bruks- <b>eller</b> distriktsspesif ikke... </td>
#             </tr>
#             <tr>
#                         <th id="T_36a04_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_36a04_row6_col0" class="data row6 col0" >100240008</td>
#                         <td id="T_36a04_row6_col1" class="data row6 col1" >... Dette har i tillegg skjedd etter et relativt fast mønster <b>og</b> vært knyttet til de rettigheter <b>eller</b> den rangordning som... </td>
#             </tr>
#             <tr>
#                         <th id="T_36a04_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_36a04_row7_col0" class="data row7 col0" >100240008</td>
#                         <td id="T_36a04_row7_col1" class="data row7 col1" >... Brukerne som har de minste ekspansjonsmulighetene <b>og</b> / <b>eller</b> de høyest kostnader er mest utsatt . For disse vil inntektssvikten ofte føre... </td>
#             </tr>
#             <tr>
#                         <th id="T_36a04_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_36a04_row8_col0" class="data row8 col0" >100240008</td>
#                         <td id="T_36a04_row8_col1" class="data row8 col1" >... sammen med andre i felles aktiviteter hemmes , <b>eller</b> fordi inntektsgapet mellom landbruket <b>og</b> andre næringer ikke gir rom for det... </td>
#             </tr>
#             <tr>
#                         <th id="T_36a04_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_36a04_row9_col0" class="data row9 col0" >100240008</td>
#                         <td id="T_36a04_row9_col1" class="data row9 col1" >... I tillegg til de sykliske prosessene vil vi ha kumulative prosesser <b>og</b> prosesser som går rykkvis <b>eller</b> uten å følge... </td>
#             </tr>
#             <tr>
#                         <th id="T_36a04_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_36a04_row10_col0" class="data row10 col0" >200025052</td>
#                         <td id="T_36a04_row10_col1" class="data row10 col1" >... den travle Fisketid kunde bortkaste en Dags <b>eller</b> rettere en Nats Indtergt , <b>og</b> Moderens Bonner , da hun nok mente , han... </td>
#             </tr>
#             <tr>
#                         <th id="T_36a04_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_36a04_row11_col0" class="data row11 col0" >200025052</td>
#                         <td id="T_36a04_row11_col1" class="data row11 col1" ><b>Og</b> har dette bæret med <b>eller</b> uden Hr. Politimesterens Samtykke ?</td>
#             </tr>
#             <tr>
#                         <th id="T_36a04_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_36a04_row12_col0" class="data row12 col0" >200025052</td>
#                         <td id="T_36a04_row12_col1" class="data row12 col1" >... hvori Manden gjores til Gjenstand for Omtale <b>eller</b> blot ncrvnev . Kun Kvinden , <b>og</b> hvad der angaar hende og hendes Anliggender... </td>
#             </tr>
#             <tr>
#                         <th id="T_36a04_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_36a04_row13_col0" class="data row13 col0" >200150009</td>
#                         <td id="T_36a04_row13_col1" class="data row13 col1" >... Tidligere har det vært med litt gul saft <b>og</b> kanskje en sang <b>eller</b> to til solas pris . Det kommer ikke... </td>
#             </tr>
#             <tr>
#                         <th id="T_36a04_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_36a04_row14_col0" class="data row14 col0" >200150009</td>
#                         <td id="T_36a04_row14_col1" class="data row14 col1" >... Da kan man plutselig våkne med hjertet i halsen <b>og</b> føle seg veldig redd <b>eller</b> trist . Det er ikke farlig... </td>
#             </tr>
#             <tr>
#                         <th id="T_36a04_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_36a04_row15_col0" class="data row15 col0" >200150009</td>
#                         <td id="T_36a04_row15_col1" class="data row15 col1" >Supermanner , tigergutter , prinsesser , drager , klovner <b>og</b> mange andre mer <b>eller</b> mindre kjente figurer , var fredag klare til kamevalsfeiring , pølser i... </td>
#             </tr>
#             <tr>
#                         <th id="T_36a04_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_36a04_row16_col0" class="data row16 col0" >200950006</td>
#                         <td id="T_36a04_row16_col1" class="data row16 col1" >... gi konkrete tilfelle på krangel med den kommunale administrasjon <b>og</b> / <b>eller</b> de kommunevalgte myndigheter i Tana . I motsatt fall er... </td

# %% [markdown]
# # Parse using Spacy

# %% [markdown]
# ### Imports and a definiton of `parse`

# %%
import spacy

nlp = spacy.load("nb_core_news_sm")

# %%
def parse(string):
    cols = "token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop".split(', ')
    doc = nlp(string)
    rows = [(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop) for token in doc]
    return pd.DataFrame(rows, columns = cols), doc

# %% [markdown]
# ## Collect all the concordances
#
# These are all contained in the variable `df`
#
# The function parse returns the parse as a data frame or as a spacy doc

# %%
res = pd.concat([parse(s)[0] for s in df['concordance']])

# %%
res
# Out:
#    token.text token.lemma_ token.pos_ token.tag_ token.dep_ token.shape_  \
# 0         ...          ...      PUNCT      PUNCT       ROOT          ...
# 1         Per          Per      PROPN      PROPN      nsubj          Xxx
# 2       ville        ville        AUX        AUX        aux         xxxx
# 3       helst        helst        ADV        ADV     advmod         xxxx
# 4      glemme       glemme       VERB       VERB       ROOT         xxxx
# ..        ...          ...        ...        ...        ...          ...
# 3           b            b        ADP        ADP       case            x
# 4           >            >        ADJ        ADJ        dep            >
# 5         løp         løpe       VERB       VERB       ROOT          xxx
# 6     hjem</b      hjem</b        ADJ        ADJ      punct      xxxx</x
# 7           >            >       VERB       VERB       ROOT            >
#
#     token.is_alpha  token.is_stop
# 0            False          False
# 1             True          False
# 2             True           True
# 3             True          False
# 4             True          False
# ..             ...            ...
# 3             True          False
# 4            False          False
# 5             True          False
# 6            False          False
# 7            False          False
#
# [1775 rows x 8 columns]

# %% [markdown]
# # Se på et tre

# %%
from spacy import displacy

# %%
docs = [parse(s)[1] for s in df['concordance']]

# %%
displacy.render(docs[0])
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="nb" id="a9411aebc65a465fb846628a69965d67-0" class="displacy" width="4425" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">...</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Per</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">ville</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">helst</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">glemme</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">hele</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">historien ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">og</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">&lt;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">b</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">&gt;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">løp</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">hjem&lt;/b</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">&gt;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">ikke</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">å</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">møte</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">flere</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">som</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">stilte</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">spørsmål</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">om</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">det</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">de...</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PRON</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a9411aebc65a465fb846628a69965d67-0-0" stroke-width="2px" d="M245,527.0 C245,264.5 735.0,264.5 735.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a9411aebc65a465fb846628a69965d67-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,529.0 L237,517.0 253,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a9411aebc65a465fb846628a69965d67-0-1" stroke-width="2px" d="M420,527.0 C420,352.0 730.0,352.0 730.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a9411aebc65a465fb846628a69965d67-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,529.0 L412,517.0 428,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a9411aebc65a465fb846628a69965d67-0-2" stroke-width="2px" d="M595,527.0 C595,439.5 725.0,439.5 725.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="
