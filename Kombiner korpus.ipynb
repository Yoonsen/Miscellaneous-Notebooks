# %%
import dhlab.nbtext as nb
import pandas as pd

# %%
korpus1 = nb.book_corpus( ddk = "907.4%", period = (1940, 2000), limit = 50000)  
korpus2 = nb.book_corpus(ddk = "907.2%", period = (1940, 2000), limit = 5000)
korpus = pd.concat([korpus1, korpus2])

# %%
korpus
# Out:
#               urn                    author  \
# 0   2011011208173             Brenna, Brita
# 0   2008071004108
# 1   2007070301051              Lunden, Kåre
# 2   2010082508003
# 3   2007082801017           Seip, Jens Arup
# 4   2013041807136           Seip, Jens Arup
# 5   2012121206261
# 6   2007072400001               Dahl, Ottar
# 7   2014101306032
# 8   2016031408090          Slettan, Dagfinn
# 9   2011071506026
# 10  2007080700068               Dahl, Ottar
# 11  2011011106015
# 12  2010112406061               Dahl, Ottar
# 13  2007080601121               Dahl, Ottar
# 14  2014111008171
# 15  2013110508032               Alsvik, Ola
# 16  2008052104006
# 17  2007062901050
# 18  2016062408111
# 19  2007071201079
# 20  2007121104017          Stoa, Nils Johan
# 21  2008052701012               Dahl, Ottar
# 22  2008052804048
# 23  2010080223002
# 24  2008090300018         Kjeldstadli, Knut
# 25  2008061100052                Graff, Ola
# 26  2007070504056
# 27  2013011806082
# ...
