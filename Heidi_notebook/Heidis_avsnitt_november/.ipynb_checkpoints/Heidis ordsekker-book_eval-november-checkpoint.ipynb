# %%
import dhlab.nbtext as nb
import json

# %%
def interesting_urns(df, limit):
    jaccard = dict((df > 0).astype(int).sum(axis=1))
    res = []
    for urn in jaccard:
        if jaccard[urn] >= limit:
            res.append(urn)
    return res

def get_para(para_list):
    import ast
    paras = []
    for p in para_list:
        paras.append(ast.literal_eval(p))
    urns = [x[0] for x in paras]
    paradict = {u:[x[1] for x in paras if x[0] == u] for u in urns}
    paragraphs = dict()
    for u in paradict:
        paragraphs[u] = get_paragraphs(u, paradict[u])
    return paragraphs

def interesting_paragraphs(urns, wordbag, limit):
    interest = dict()
    for u in urns:
        paragraphs = nb.wordbag_eval_para(wordbag, [u])
        for x in paragraphs:
            if len(paragraphs[x]) >= limit:
                #rint(paragraphs[x])
                interest[x] = paragraphs[x]
    return interest

import requests
def get_paragraphs(urn, paras):
    """Return paragraphs for urn"""
    param = dict()
    param['paragraphs'] = paras
    param['urn'] = urn
    r = requests.get("https://api.nb.no/ngram/paragraphs", json=param)
    return r.json()

# %%
def major_urns(df):
    res = []
    means = df.mean()
    for urn in df.index:
        good_urn = True
        for theme in means.index:
            good_urn &= df[theme][urn] > means[theme]
        if good_urn:
            res.append(urn)
    return res

# %%
#temaene ble lagret med annen notebook - Heidis definisjoner_0_november
with open('heidis_temadefinisjoner_november.json') as f:
    first = json.load(f)

# %% [markdown]
# import json
#
# json.dump(first, open('heidis_temadefinisjoner.json', 'w', encoding='utf-8'))

# %%
list_of_themes = list(first.keys())
list_of_themes
# Out:
# ['“Kvindens Sandhed” (Minst 3 av 4).',
#  '“Kvinde, lesning og religion” (Minst 4 av 5)',
#  '“Forfatterinder og religion”  (Minst 3 av 4)',
#  '“Kvindens posisjon” (Minst 4 av 6)',
#  '“Kvinden og offentlig hygiene” (Minst 4 av 6)']

# %% [markdown]
# Her er URNene det skal søkes i

# %%
urns = nb.book_urn(period=(1830, 1880), limit=12000)

len(urns)
# Out:
# 6803

# %%
round(90*7/100)
# Out:
# 6

# %% [markdown]
# ## Evaluering av bøker
#
#
# Her er datarammen for klassifikasjon av bøker, med frekvens av hvert tema.

# %%
# sett inn et temanavn eller bare bruk indeks inn i temalisten, som her - 0 er første element 1 er andre osv.

theme_eval = nb.wordbag_eval(first[list_of_themes[0]], urns)

# %%
theme_eval.head(10)
# Out:
#                Frihed_  Kvinde_  Legeme_  Sandhed_   snitt
# 2014062048059    699.0    676.0    597.0     483.0  613.75
# 2009091403021    342.0   1225.0    365.0     424.0  589.00
# 2008082512001    376.0   1085.0    484.0     400.0  586.25
# 2008100603020    419.0    433.0    451.0     954.0  564.25
# 2008111303008    298.0     95.0    785.0     704.0  470.50
# 2013042608062    472.0    391.0    536.0     440.0  459.75
# 2016102148034    430.0    443.0    484.0     392.0  437.25
# 2015010648113    445.0    389.0    512.0     384.0  432.50
# 2016101129001    526.0     92.0    416.0     694.0  432.00
# 2016051048081    519.0     88.0    413.0     696.0  429.00

# %% [markdown]
# ### Hva er gjennomsnittet for temaene?
#
# Gjennomsnittet tas over alle bøkene.

# %%
theme_eval.mean()
# Out:
# Frihed_     23.937969
# Kvinde_     45.470735
# Legeme_     22.421878
# Sandhed_    25.786893
# snitt       29.404369
# dtype: float64

# %% [markdown]
# # Se på effekten av `major_urns`
#
# Den plukker ut de URN-ene som har best sjanse for treff.

# %%
sorted_urns = theme_eval.loc[major_urns(theme_eval)]

# %%
sorted_urns.head(20).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row0_col1 {
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row0_col2 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row0_col3 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row1_col0 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row1_col2 {
#             background-color:  #9ebad9;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row1_col3 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row1_col4 {
#             background-color:  #045585;
#             color:  #f1f1f1;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row2_col0 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row2_col1 {
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row2_col2 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row2_col3 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row2_col4 {
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row3_col0 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row3_col1 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row3_col2 {
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row3_col4 {
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row4_col0 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row4_col1 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row4_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row4_col3 {
#             background-color:  #2d8abd;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row4_col4 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row5_col0 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row5_col1 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row5_col2 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row5_col3 {
#             background-color:  #c8cde4;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row5_col4 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row6_col0 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row6_col1 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row6_col2 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row6_col3 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row6_col4 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row7_col0 {
#             background-color:  #4697c4;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row7_col1 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row7_col2 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row7_col3 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row7_col4 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row8_col0 {
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row8_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row8_col2 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row8_col3 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row8_col4 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row9_col0 {
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row9_col2 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row9_col3 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row9_col4 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row10_col0 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row10_col1 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row10_col2 {
#             background-color:  #71a8ce;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row10_col3 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row10_col4 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row11_col0 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row11_col1 {
#             background-color:  #045483;
#             color:  #f1f1f1;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row11_col2 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row11_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_aa29c682_04d1_11ea_bc96_000acd2bfab2row11_col4 {
#             background-color:  #e7e3f0;
#             color:  #0

# %%
sorted_urns.mean()
# Out:
# Frihed_     106.886207
# Kvinde_     198.120690
# Legeme_      96.144828
# Sandhed_    130.508621
# snitt       132.915086
# dtype: float64

# %% [markdown]
# # Hovedloop - generer avsnitt

# %%
for theme in first:
    theme_eval = nb.wordbag_eval(first[theme], urns)
    sorted_urns = theme_eval.loc[major_urns(theme_eval)]
    print(theme,'antall urner', len(sorted_urns))
    filename = "".join([c for c in theme if c.isalpha() or c.isdigit() or c==' ']).rstrip() + '.json'
    theme_dict = dict()
    for urn in nb.pure_urn(list(sorted_urns.index)):
        try:
            paras = interesting_paragraphs( [urn], first[theme], round(90*len(first[theme])/100))
            if len(paras) > 0:
                print(', '.join([str(x) for x in nb.metadata(urn)[0]]), len(paras))
            for w in paras:
                theme_dict[w] = paras[w]
        except:
            print('problember med:',  ', '.join([str(x) for x in nb.metadata(urn)[0]]))
    print('\n')      
    json.dump(theme_dict, open(filename, 'w', encoding='utf-8'))
