# %%
import dhlab.module_update as mu

# %% [markdown]
# mu.update("dhlab_v2")

# %%
import dhlab_v2 as d2

# %%
import imp

# %%
imp.reload(d2)
# Out:
# <module 'dhlab_v2' from 'C:\\Users\\yoons\\Documents\\Github\\Miscellaneous-Notebooks\\N-grammer-dhlab-v2\\dhlab_v2.py'>

# %%
# %%time
d2.ngram_book(word = ". , om men ikke aldri".split(), period = (1950, 1960)).plot()
# Out:
# 200
# Wall time: 413 ms
# <AxesSubplot:>

# %%
# %%time
d2.ngram_book(word = "demokrati arbeiderpartiet alle sammen".split(), period = (1950, 1960)).plot()
# Out:
# 200
# Wall time: 350 ms
# <AxesSubplot:>

# %%
# %%time
d2.ngram_news(word = "aldri i livet . sa han og stakk".split(), period = (1950, 1960))
# Out:
# 200
# Wall time: 5.12 s
#                    .   aldri      han         i  livet        og      sa  \
# 1950-01-01  33369729   95473  1275933  11453098  63522  10820735  303582
# 1951-01-01  33994479   93885  1304308  11890125  64570  10887220  325665
# 1952-01-01  35907493  100267  1434297  12678275  69111  11758012  390966
# 1953-01-01  37779922  112038  1553894  13448425  77789  12228786  392891
# 1954-01-01  38678715  119582  1728472  13915475  78889  13017724  405773
# 1955-01-01  40746624  123647  1770814  14825945  82303  13639154  430982
# 1956-01-01  38325315  115120  1630204  14049225  77355  12628894  420363
# 1957-01-01  38512361  118263  1668066  14446916  77436  12791438  417632
# 1958-01-01  39676796  119788  1694464  15105040  81774  13235665  440191
# 1959-01-01  37760929  112493  1635615  14219195  76690  12428144  431460
# 1960-01-01  41015572  124217  1832629  15685209  83696  13616407  493895
#
#             stakk
# 1950-01-01  10108
# 1951-01-01   9680
# ...
