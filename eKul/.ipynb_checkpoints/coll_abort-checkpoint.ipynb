# %% [markdown]
# # Kollokasjoner for nøkkelord

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
import dhlab.graph_networkx_louvain as gnl
from dhlab.module_update import update, css, code_toggle

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
def categorize(list_of_words):
    proprium = [x for x in list_of_words if x[0].upper() == x[0]]
    other = [x for x in list_of_words if not x in proprium]

    return {'propr':proprium,
           'other': other }

def select_form(w):
    fs = [x.split()[0] for x in nb.word_form(w)]
    if 'verb' in fs:
        res = 'verb'
    elif 'subst' in fs:
        res = 'subst'
    elif len(fs) > 0:
        res = fs[0]
    else:
        res = 'unknown'
    return res

def sort_word_forms(words):
    res = {select_form(w):w for w in words}
    return res

def character_words(Character_name, number_of_words=50):
    res = {w:select_form(w) for w in categorize(list(nb.frame_sort(nb.frame(coll_matrix[Character_name]/tot['tot'], 'association')).head(number_of_words).index))['other']}
    result = {cat:[w for w in res if res[w] == cat] for cat in res.values()}
    return result

def mdprint(forskjell, cutoff=5):
    categories = categorize(forskjell[forskjell > cutoff].dropna().index)
    forms = {w:select_form(w) for w in categories['other']}
    Grouping = {cat:[word for word in forms if forms[word] == cat] for cat in forms.values()}
    navn = "## Benevnelser \n"
    navn += "<span style='font-size:150%'>{stuff}</span>".format(stuff= ', '.join(categories['propr']))
    pos = ""
    for cat in Grouping:
        pos += "## " + cat + "\n"
        pos += "<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ', '.join(Grouping[cat]) ) + "\n"
    mu.printmd(navn)
    mu.printmd(pos)
    return

# %%
import pandas as pd

# %%
import ast

# %%
#colls_before = pd.read_json('demokrati_before.json')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})

# %%
cliques = lambda G: [list(x) for  x in list(gnl.make_cliques_from_graph(G.to_undirected())[1].values())]

# %% [markdown]
# ## Definer nøkkelordet
#
# noteboken blir kjørt flere ganger, en notebook for hvert nøkkelord, *influensa*, *helse*

# %%
reference = nb.frame(nb.totals(50000), 'tot')

# %%
keyword = 'likestilling'

# %%
filename = 'collocation_' + keyword + ".csv"

# %% [markdown]
# ## Grafstruktur topos

# %%
keyword_graph = nb.make_graph(keyword, cutoff=16)

# %%
comm = gnl.community_dict(keyword_graph)

# %%
gnl.show_graph(keyword_graph, spread=1.2, fontsize=12)

# %% [markdown]
# # Topoi fra grafen
#
# Der klikkstrukturen kombinerer færre element, er alle nodene i grafen med og definerer et topos.

# %%
pos=""
for x in comm:
    pos += "### " + x + "\n"
    pos += "<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ', '.join(comm[x]) ) + "\n"
mu.printmd(pos)
# Out:
# ### diskriminering-undertrykking
# <span style='font-size:1.1em'>diskriminering, undertrykking, mobbing, fordommer, vold, trakassering, stigmatisering, undertrykkelse, forskjellsbehandling, forfølgelse, rasisme</span>
# ### deltakelse-deltaking
# <span style='font-size:1.1em'>deltakelse, deltaking, omtanke, medkjensle, blomster, omsorg, helsingar, medfølelse, blomsterhilsener, blomsterhelsingar, ba, hjelp, oppmerksomhet, blomar, aktivitet, blomehelsingar</span>
# ### demokrati-frihet
# <span style='font-size:1.1em'>demokrati, frihet, likeverd, rettferdighet, likebehandling, menneskerettigheter, toleranse, fred, inkludering, likhet, solidaritet, rettssikkerhet, trygghet, menneskeverd, selvstendighet, åpenhet, uavhengighet, folkestyre, respekt, medbestemmelse, Frihet, diktatur, sannhet, urettferdighet, ansvar, fleksibilitet, forutsigbarhet, markedsøkonomi, sosialisme, rettferd</span>
# ### likestilling-kvinners
# <span style='font-size:1.1em'>likestilling, kvinners, likelønn, frigjøring, kvinnekamp, kvinnesak, kvinnefrigjøring, familiepolitikk, kvinner, Likestilling, lavlønn, jenters, menns, feminisme, mannsroller, lavtlønn, barns</span>
# ### kunnskap-engasjement
# <span style='font-size:1.1em'>kunnskap, engasjement, innsikt, læring, forståelse, viten, inspirasjon, erfaringer, interesse, kompetanse, teknologi, erfaring, informasjon, forskning</span>
# ### mangfold-integrering
# <span style='font-size:1.1em'>mangfold, integrering, innvandring, mangfald, variasjon, språkopplæring, valgfrihet, normalisering, kvalitet, bosetting, bredde</span>
# ### kjønn-kjønnsroller
# <span style='font-size:1.1em'>kjønn, kjønnsroller, seksualitet, etnisitet, geografi, rase, alder</span>
# ### ytringsfrihet-religionsfrihet
# <span style='font-size:1.1em'>ytringsfrihet, religionsfrihet, trosfrihet, personvern, pressefrihet</span>

# %%
gnl.show_cliques(keyword_graph)
# Out:
# (3, 1) likestilling, likebehandling, rettferdighet, menneskeverd, åpenhet, Frihet, selvstendighet, folkestyre, solidaritet, demokrati, inkludering, mangfold, fred, frigjøring, rettssikkerhet, diskriminering, trygghet, ytringsfrihet, likeverd, likhet, menneskerettigheter, toleranse, uavhengighet, frihet, integrering, kvinnefrigjøring, respekt
#
# (3, 2) likestilling, kvinners, kvinner, likelønn, kvinnekamp, kvinnesak
#
# (3, 3) seksualitet, likestilling, kjønnsroller, kjønn
#
# (4, 1) likestilling, likebehandling, rettferdighet, likhet, likeverd, trygghet, menneskerettigheter, menneskeverd, demokrati, frihet, mangfold, fred
#
# (5, 1) likestilling, rettferdighet, likeverd, menneskerettigheter, demokrati, frihet

# %% [markdown]
# # Assosiasjoner fra kollokasjonene
#
# <span style="font-size:150%">nb.collocation(keyword, yearfrom=1950, yearto=2000, before=10, after=10, corpus='avis')</span>

# %%
barchart = lambda word, df: df.loc[word].plot(kind='bar', rot=0, figsize=(10,5),title=word);

# %%
barchart(keyword, reference);

# %%
from time import time

collocations = dict()
step = 1

for i in range(1950, 2000):
    print(i)
    t0 = time()
    try:
        collocations[i] = nb.collocation(keyword, yearfrom = i, yearto = i + step, before = 10, after = 10, corpus = 'bok')
    except:
        try:
            collocations[i] = nb.collocation(keyword, yearfrom= i, yearto= i + step, before = 10, after = 10, corpus = 'bok')
        except:
            print("gir opp", i)
    print((time() - t0)/60, "minutter")
# Out:
# 1950
# 0.0075417160987854 minutter
# 1951
# 0.007188347975413004 minutter
# 1952
# 0.007649437586466471 minutter
# 1953
# 0.007348295052846273 minutter
# 1954
# 0.0071626861890157064 minutter
# 1955
# 0.007374191284179687 minutter
# 1956
# 0.007500664393107096 minutter
# 1957
# 0.007607499758402507 minutter
# 1958
# 0.007763230800628662 minutter
# 1959
# 0.007304938634236654 minutter
# 1960
# 0.007988822460174561 minutter
# 1961
# 0.007029044628143311 minutter
# 1962
# 0.007721455891927084 minutter
# 1963
# 0.009977400302886963 minutter
# 1964
# 0.009444646040598552 minutter
# 1965
# 0.009915924072265625 minutter
# 1966
# 0.011341607570648194 minutter
# 1967
# 0.010437750816345214 minutter
# 1968
# 0.008768006165822347 minutter
# 1969
# 0.00861817200978597 minutter
# 1970
# 0.009680020809173583 minutter
# 1971
# 0.010332051912943523 minutter
# 1972
# 0.012963203589121501 minutter
# 1973
# 0.010867937405904134 minutter
# 1974
# 0.012417229016621907 minutter
# 1975
# 0.014139719804128011 minutter
# 1976
# 0.013207455476125082 minutter
# 1977
# 0.012053894996643066 minutter
# 1978
# 0.014399286111195881 minutter
# 1979
# 0.016913342475891113 minutter
# 1980
# 0.016896657148996987 minutter
# 1981
# 0.017628475030263265 minutter
# 1982
# 0.01546307404836019 minutter
# 1983
# 0.01575084129969279 minutter
# 1984
# 0.017748669783274332 minutter
# 1985
# 0.01815850337346395 minutter
# 1986
# 0.0173079252243042 minutter
# 1987
# 0.01781022548675537 minutter
# 1988
# 0.020957422256469727 minutter
# 1989
# 0.02059537172317505 minutter
# 1990
# 0.020863787333170573 minutter
# 1991
# 0.03035767873128255 minutter
# 1992
# 0.029241534074147542 minutter
# 1993
# 0.02203970750172933 minutter
# 1994
# 0.02997678518295288 minutter
# 1995
# 0.025124494234720865 minutter
# 1996
# 0.023541776339213054 minutter
# 1997
# 0.023676292101542155 minutter
# 1998
# 0.02362478176752726 minutter
# 1999
# 0.022995285193125405 minutter

# %%
colls = nb.frame(collocations)

# %%
colls = pd.concat([nb.frame(collocations[i], i) for i in collocations], axis=1).fillna(0)

# %%
def group_frames(df, bins=10, mode='rel'):
    agg = pd.DataFrame()
    step = 10
    for i in range(0, len(df.columns), step):
        agg[df.columns[i]] = df[df.columns[i:i+step]].sum(axis=1)
    return agg

# %%
agg = group_frames(colls)

# %%
nb.normalize_corpus_dataframe(agg)
# Out:
# True

# %% [markdown]
# # Opptelling

# %% [markdown]
# # Sammenligner med en referanse

# %%
reference.sort_values(by=reference.columns[0], ascending=False)[:10].style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3row1_col0 {
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }    #T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3row2_col0 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3row3_col0 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3row4_col0 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3row5_col0 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3row6_col0 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3row7_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3row8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3row9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >tot</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3level0_row0" class="row_heading level0 row0" >.</th>
#                         <td id="T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3row0_col0" class="data row0 col0" >1265723110</td>
#             </tr>
#             <tr>
#                         <th id="T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3level0_row1" class="row_heading level0 row1" >,</th>
#                         <td id="T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3row1_col0" class="data row1 col0" >1105303412</td>
#             </tr>
#             <tr>
#                         <th id="T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3level0_row2" class="row_heading level0 row2" >og</th>
#                         <td id="T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3row2_col0" class="data row2 col0" >543432056</td>
#             </tr>
#             <tr>
#                         <th id="T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3level0_row3" class="row_heading level0 row3" >i</th>
#                         <td id="T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3row3_col0" class="data row3 col0" >460246057</td>
#             </tr>
#             <tr>
#                         <th id="T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3level0_row4" class="row_heading level0 row4" >det</th>
#                         <td id="T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3row4_col0" class="data row4 col0" >273411583</td>
#             </tr>
#             <tr>
#                         <th id="T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3level0_row5" class="row_heading level0 row5" >som</th>
#                         <td id="T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3row5_col0" class="data row5 col0" >265144740</td>
#             </tr>
#             <tr>
#                         <th id="T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3level0_row6" class="row_heading level0 row6" >til</th>
#                         <td id="T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3row6_col0" class="data row6 col0" >254500136</td>
#             </tr>
#             <tr>
#                         <th id="T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3level0_row7" class="row_heading level0 row7" >er</th>
#                         <td id="T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3row7_col0" class="data row7 col0" >248764786</td>
#             </tr>
#             <tr>
#                         <th id="T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3level0_row8" class="row_heading level0 row8" >av</th>
#                         <td id="T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3row8_col0" class="data row8 col0" >235180661</td>
#             </tr>
#             <tr>
#                         <th id="T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3level0_row9" class="row_heading level0 row9" >en</th>
#                         <td id="T_d81b74ba_5e2b_11ea_8d4f_a0a4c554f2a3row9_col0" class="data row9 col0" >231631623</td>
#             </tr>
#     </tbody></table>

# %%
agg.sort_values(by=agg.columns[2], ascending=False)[:10].style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row1_col0 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row1_col1 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row1_col2 {
#             background-color:  #2383ba;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row1_col3 {
#             background-color:  #157ab5;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row1_col4 {
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row2_col0 {
#             background-color:  #2a88bc;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row2_col1 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row2_col2 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row2_col3 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row2_col4 {
#             background-color:  #056aa6;
#             color:  #f1f1f1;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row3_col0 {
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row3_col1 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row3_col2 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row3_col3 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row3_col4 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row4_col0 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row4_col1 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row4_col2 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row4_col3 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row4_col4 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row5_col2 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row5_col3 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row5_col4 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row6_col0 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row6_col1 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row6_col2 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row6_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row7_col0 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row7_col1 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row7_col2 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row7_col3 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row7_col4 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row8_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row8_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row8_col2 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row8_col3 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row8_col4 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row9_col0 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row9_col1 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row9_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row9_col3 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row9_col4 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }</style><table id="T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1950</th>        <th class="col_heading level0 col1" >1960</th>        <th class="col_heading level0 col2" >1970</th>        <th class="col_heading level0 col3" >1980</th>        <th class="col_heading level0 col4" >1990</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3level0_row0" class="row_heading level0 row0" >.</th>
#                         <td id="T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row0_col0" class="data row0 col0" >0.0479531</td>
#                         <td id="T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row0_col1" class="data row0 col1" >0.0465799</td>
#                         <td id="T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row0_col2" class="data row0 col2" >0.0468917</td>
#                         <td id="T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row0_col3" class="data row0 col3" >0.046896</td>
#                         <td id="T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3row0_col4" class="data row0 col4" >0.0434321</td>
#             </tr>
#             <tr>
#                         <th id="T_da5aae18_5e2b_11ea_8d07_a0a4c554f2a3level0_row1" class="row_heading level0 row1" >og</th>

# %%
pmi = pd.DataFrame()
for i in agg:
    pmi[i] = agg[i]**1.02/(pd.concat([agg[i], reference['tot']],axis=1).mean(axis=1))

# %%
nb.normalize_corpus_dataframe(pmi)
# Out:
# True

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
#
# # De 15 beste for passende kolonne

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(25).fillna(0).style.background_gradient(axis=0)
# Out:
# <style  type="text/css" >
#     #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row0_col1 {
#             background-color:  #023d60;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row0_col3 {
#             background-color:  #023b5d;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row0_col4 {
#             background-color:  #023c5f;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row1_col0 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row1_col1 {
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row1_col2 {
#             background-color:  #023a5b;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row1_col3 {
#             background-color:  #023b5d;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row1_col4 {
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row2_col0 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row2_col1 {
#             background-color:  #023b5d;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row2_col2 {
#             background-color:  #023a5b;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row2_col3 {
#             background-color:  #02395a;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row2_col4 {
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row3_col0 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row3_col1 {
#             background-color:  #034b76;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row3_col2 {
#             background-color:  #023d60;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row3_col3 {
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row3_col4 {
#             background-color:  #045280;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row4_col0 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row4_col1 {
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row4_col2 {
#             background-color:  #034267;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row4_col3 {
#             background-color:  #03456c;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row4_col4 {
#             background-color:  #034b76;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row5_col0 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row5_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row5_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row5_col3 {
#             background-color:  #023d60;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row5_col4 {
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row6_col0 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row6_col1 {
#             background-color:  #034369;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row6_col2 {
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row6_col3 {
#             background-color:  #023c5f;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row6_col4 {
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row7_col0 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row7_col1 {
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row7_col2 {
#             background-color:  #034369;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row7_col3 {
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row7_col4 {
#             background-color:  #034b76;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row8_col0 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row8_col1 {
#             background-color:  #034267;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row8_col2 {
#             background-color:  #034267;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row8_col3 {
#             background-color:  #023d60;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row8_col4 {
#             background-color:  #034369;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row9_col0 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row9_col1 {
#             background-color:  #03456c;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row9_col2 {
#             background-color:  #03456c;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row9_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row9_col4 {
#             background-color:  #034b76;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row10_col0 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row10_col1 {
#             background-color:  #034369;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row10_col2 {
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row10_col3 {
#             background-color:  #034267;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row10_col4 {
#             background-color:  #034a74;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row11_col0 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row11_col1 {
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row11_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row11_col3 {
#             background-color:  #034a74;
#             color:  #f1f1f1;
#         }    #T_4de4d826_5e2d_11ea_bf14_a0a4c554f2a3row11_col4 {
#             background-color:  #034e7b;
#             color:  #f

# %%
pmi.sort_values(by=pmi.columns[1], ascending=False).head(25).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row0_col1 {
#             background-color:  #3991c1;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row0_col2 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row0_col3 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row1_col1 {
#             background-color:  #4094c3;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row1_col2 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row1_col3 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row2_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row2_col1 {
#             background-color:  #4697c4;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row2_col2 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row2_col3 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row3_col1 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row3_col2 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row3_col3 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row4_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row4_col2 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row4_col3 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row4_col4 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row5_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row5_col1 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row5_col2 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row5_col3 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row6_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row6_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row6_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row7_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row7_col1 {
#             background-color:  #3790c0;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row7_col2 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row7_col3 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row7_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row8_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row8_col1 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row8_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row8_col3 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row8_col4 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row9_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row9_col2 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row9_col3 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row9_col4 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row10_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row10_col1 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row10_col2 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row10_col3 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row10_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row11_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row11_col1 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row11_col2 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row11_col3 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_54106470_5e2d_11ea_abc0_a0a4c554f2a3row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[2], ascending=False).head(25).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row0_col3 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row0_col4 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row1_col2 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row1_col3 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row1_col4 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row2_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row2_col2 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row2_col3 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row2_col4 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row3_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row3_col2 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row3_col3 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row3_col4 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row4_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row4_col3 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row4_col4 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row5_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row5_col3 {
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row5_col4 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row6_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row6_col1 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row6_col2 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row6_col3 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row7_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row7_col2 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row7_col3 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row7_col4 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row8_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row8_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row8_col3 {
#             background-color:  #60a1ca;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row8_col4 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row9_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row9_col1 {
#             background-color:  #3991c1;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row9_col2 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row9_col3 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row10_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row10_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row10_col2 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row10_col3 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row10_col4 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row11_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row11_col1 {
#             background-color:  #4697c4;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row11_col2 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row11_col3 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_5464ed64_5e2d_11ea_94d4_a0a4c554f2a3row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[3], ascending=False).head(25).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row0_col3 {
#             background-color:  #60a1ca;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row0_col4 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row1_col3 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row1_col4 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row2_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row2_col2 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row2_col3 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row2_col4 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row3_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row3_col2 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row3_col3 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row3_col4 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row4_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row4_col3 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row4_col4 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row5_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row5_col2 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row5_col3 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row5_col4 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row6_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row6_col3 {
#             background-color:  #60a1ca;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row6_col4 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row7_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row7_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row7_col3 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row7_col4 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row8_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row8_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row8_col3 {
#             background-color:  #63a2cb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row8_col4 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row9_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row9_col2 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row9_col3 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row9_col4 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row10_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row10_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row10_col2 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row10_col3 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row10_col4 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row11_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row11_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row11_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row11_col3 {
#             background-color:  #62a2cb;
#             color:  #000000;
#         }    #T_54bd7f2c_5e2d_11ea_9969_a0a4c554f2a3row11_col4 {
#             background-color:  #a7bddb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[4], ascending=False).head(25).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row0_col3 {
#             background-color:  #60a1ca;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row0_col4 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row1_col2 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row1_col3 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row1_col4 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row2_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row2_col2 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row2_col3 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row2_col4 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row3_col3 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row3_col4 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row4_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row4_col3 {
#             background-color:  #60a1ca;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row4_col4 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row5_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row5_col3 {
#             background-color:  #63a2cb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row5_col4 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row6_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row6_col1 {
#             background-color:  #4094c3;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row6_col2 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row6_col3 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row7_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row7_col2 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row7_col3 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row7_col4 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row8_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row8_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row8_col3 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row8_col4 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row9_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row9_col3 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row9_col4 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row10_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row10_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row10_col2 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row10_col3 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row10_col4 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row11_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row11_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row11_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row11_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_554c67ba_5e2d_11ea_bcb7_a0a4c554f2a3row11_col4 {
#             background-color:  #023858;
#             color:  #f

# %% [markdown]
# <br>
# <br>

# %%
pmi.to_csv(filename)

# %%
pmi.sort_values(by=pmi.columns[4], ascending=False).head(50).index
# Out:
# Index(['Klagenemnda', 'kjønna', 'Likestilling', 'Likestillingsrådet',
#        'Likestillingsombudet', 'likestillingsloven', 'nnene', 'åndsfrihet',
#        'kjønnsroller', 'Likestillingsloven', 'samfunnsområder',
#        'Kompetansesenter', 'likelønn', 'Markedsrådet', 'kvinnefrigjøring',
#        'handlingsplaner', 'Kjønnsroller', 'levevilkårene', 'Minifakta',
#        'likestillingen', 'Ombudet', 'Handlingsprogram', 'kvinnebevegelsen',
#        'kvinnesak', 'Omstilling', 'kjønnskvotering', 'Reell',
#        'likestillingsarbeidet', 'kjønnsperspektiv', 'tilsies', 'kjønnsmessig',
#        'kvinneforskning', 'Likeverd', 'Ulik', 'NORAS', 'Integrering',
#        'femokratisk', 'Fedrekvote', 'Forbrukerombudet', 'særbehandling',
#        'forskningsprosjektet', 'Oftung', 'Handlingsplanen', 'kjønnenes',
#        'Formell', 'virkemiddal', 'Rammeavtale', 'FFOs', 'LIKESTILLING',
#        'Holli'],
#       dtype='object')

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(50).index
# Out:
# Index(['kjønnenes', 'tollpolitisk', 'lønnsmessig', 'språkenes', 'katolikkenes',
#        'negrenes', 'landsforvisning', 'konkurransemessig', 'katolikkene',
#        'nasjonaliteter', 'selvbestemmelsesrett', 'unionsspørsmålet', 'rikene',
#        'hedningenes', 'formuesforhold', 'prismessig', 'deltakolse',
#        'nordmennenes', 'Kvinnesaken', 'likelønn', 'statsborgerrett',
#        'skolespråk', 'jamsides', 'patrisierne', 'utenrikske', 'toUpolitisk',
#        'toleranseedikt', 'emansipasjon', 'målformer', 'jamstilling',
#        'kvinnesakens', 'gjennomført,', 'deltakclse', 'likerett',
#        'husmoryrkets', 'jordbruksbefolkningen', 'tilkjempet', 'rikenes',
#        'monogame', 'stelling', 'kvinnesak', 'agitasjonen', 'jevnbyrdighet',
#        'målformene', 'unionsrikene', 'samrøring', 'hustruene', 'unionstiden',
#        'yrkene', 'kjempes'],
#       dtype='object')

# %%
pmi.sort_values(by=pmi.columns[1], ascending=False).head(50).index
# Out:
# Index(['negrenes', 'lønnsmessig', 'kjønnenes', 'rasene', 'enkemenn',
#        'tollpolitisk', 'næringsgreinene', 'rasemessig', 'unionsspørsmålet',
#        'Roma-traktaten', 'likestillingen', 'katolikkenes', 'lan-',
#        'inntektsmessig', 'konkurransemessig', 'råsene', 'kannene',
#        'katolikkene', 'kvinnesaken', 'patrisierne', 'Komitéinnstillingen',
#        'prismessig', 'kvinnesak', 'Kvinnesaken', 'lovmessig', 'negre',
#        'språkformer', 'stemmeretten', 'rikenes', 'landsforvisning', 'nensvn',
#        'Prispolitisk', 'Tollpolitisk', 'afrikanere', 'rasenes', 'mannssamfunn',
#        'manntallsførte', 'bestrebelsene', 'statsrettslig',
#        'selvbestemmelsesrett', 'emansipasjon', 'rustninger', 'statenes',
#        'Formell', 'ikke-konvensjonstat', 'utjamning', 'traktatens',
#        'agitasjonen', 'nynorsken', 'forkjempere'],
#       dtype='object')

# %% [markdown]
# # Assosiasjoner og variasjon over år.

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(12, 8));

# %%
def freq_assoc_val(agg, pmi, col):
    vals = list(pmi.sort_values(by=pmi.columns[col], ascending=False).head(5).fillna(0).index)
    agg.loc[vals].sort_values(by= agg.columns[col], ascending=False).transpose().plot(kind="bar", rot=0, figsize=(12, 8))

# %%
freq_assoc_val(agg, pmi, 0)

# %%
freq_assoc_val(agg, pmi, 1)

# %%
freq_assoc_val(agg, pmi, 3)

# %%
freq_assoc_val(agg, pmi, 4)

# %%
freq_assoc_val(pmi, pmi, 1)

# %%
freq_assoc_val(pmi, pmi, 2)

# %%
freq_assoc_val(pmi, pmi, 3)

# %%
freq_assoc_val(pmi, pmi, 4)

# %%
freq_assoc_val(pmi, pmi, 0)

# %%
freq_assoc_val(pmi, pmi, 0)

# %%
freq_assoc_val(pmi, pmi, 0)

# %%
pmi.sort_values(by=pmi.columns[4], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(12, 8));

# %%
agg.sort_values(by=agg.columns[3], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(14, 8));

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # De hundre ordene med høyest assosiasjon for perioden sortert på ordklasser

# %%
mdprint(pmi.sort_values(by=pmi.columns[2], ascending=False).head(100),-1)
# Out:
# ## Benevnelser
# <span style='font-size:150%'>Diktatur, Karamanlis, Demokratiet, AKP, Soares, Colombia, Sletbak, Weber, Vestens, Kongress, Kommunisme, ØD, Rhodesia, Presserunden, Begrepet, SVs, Francos, Suarez, Notaker, Libertas, Romatraktaten, Dahl-Hansen, Janata</span>
# ## subst
# <span style='font-size:1.1em'>folkestyre, rettssikkerhet, styreform, bedriftsdemokrati, respekten, bedriftsdemokratiet, rettsstat, medinnflytelse, pressefrihet, ulydighet, styresett, politistat, sentralisme, hverdagen, anarki, humanisme, menneskerett, menneskerettighetene, ytringsfriheten, sosialisering, organisasjonsfrihet, folkeviljen, råderett, ideal, grasrota, pluralisme, sunnhetstegn, selvråderett, diktatur, folkedemokrati, demokratier, forsoning, likhetstegn, rettsstaten, monarki, folkeavstemninger, pamper, flerpartisystem, styreformer, spillfekteri, makthavere</span>
# ## adj
# <span style='font-size:1.1em'>industrielt, uforenlig, funksjonsdyktig, livskraftig, konstitusjonelle, autoritært, fullkomment, konstitusjonelt, proletarisk, fascistisk, totalitært, sunne, ufullkomment</span>
# ## unknown
# <span style='font-size:1.1em'>medbestemmelse, kvardagen, folkenes, samfunnsform, kriseløsning, flertallets, øst-europeiske, borgarleg, vest-europeisk, lønnstakerfond, maktkonsentrasjon, kyrkjelege, gjeninnføring, språkleg, enkeltmennesket, flertallsdiktatur, meningsfrihet, vestlege, flertallsstyre</span>
# ## verb
# <span style='font-size:1.1em'>gjeninnføre, misbrukes, avskaffe</span>
# ## fork
# <span style='font-size:1.1em'>m-l</span>

# %% [markdown]
# # Hvordan utvikler ordene seg?

# %%
barchart = lambda w, title='', df=pmi: df.loc[w].transpose().plot(kind='bar',title=title, rot=20, figsize=(12,6)) ;

# %%
barchart(['helse','kreft',"sengeliggende", 'arbeidsplassen'], 'Utvalgte ord, frekvens', df=agg);

# %%
barchart(['helse','kreft',"sengeliggende", 'arbeidsplassen'], 'Utvalgte ord, assosiasjon');

# %% [markdown]
# <br>
# <br>
#
# # Sjekk ut vanlige ord
#
# Bare for å se at de har lave verdier og er stabile gjennom kollokasjonen

# %%
barchart(['.','og', ',','eller', 'men'], 'Punktueringer og vanlige ord', pmi);

# %%
barchart(['.','og', ',','eller', 'men'], 'Punktueringer og vanlige ord', agg);

# %% [markdown]
# <br>
# <br>
#
# # De fremste blandt topoi
#
# Merk at på grunn av louvain-algoritmen kan topoiene endre seg litt fra kjøring til kjøring

# %%
commchart = lambda x, part =(1,6): barchart(comm[list(comm.keys())[x]][part[0]:part[1]], list(comm.keys())[x]);

# %%
commchart(2, (0,5));

# %%
commchart(1, (3, 8))

# %%
commchart(3)
