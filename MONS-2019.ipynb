# %%
import dhlab.nbtext as nb
import dhlab.graph_networkx_louvain as gnl
import module_update as mu

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22, 'figure.figsize':(14,7), 'lines.linewidth': 6})

# %%
#plt.rcParams.keys()

# %%
nb.nb_ngram("* åpen munn").plot()

# %%
nb.nb_ngram("et slu", smooth=1, mode='abs', corpus='bok').sum()
# Out:
# et slu    278.0
# dtype: float64

# %%
nb.concordance(word='slu', size=50, corpus='bok')
# Out:
# <table><tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2006112300027?searchText=slu' target='_'>Aas, Einar,Sjæleliv og intelligens hos dyr,1893</a></td><td>spi3te 3 in mad ,</td><td>slu</td><td style='text-align:left'>^ te den en naal</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012120506026?searchText=slu' target='_'>Riordan, Rick,røde pyramiden,2011</a></td><td>, men Isis er en</td><td>slu</td><td style='text-align:left'>og maktsyk ... »</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013022606077?searchText=slu' target='_'>Lindh, Knut,Bokmål-nynorsk skoleordbok,2009</a></td><td>slovensk - , - e</td><td>slu</td><td style='text-align:left'>slu - , slu (</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013022606077?searchText=slu' target='_'>Lindh, Knut,Bokmål-nynorsk skoleordbok,2009</a></td><td>- , - e slu</td><td>slu</td><td style='text-align:left'>- , slu ( e</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013022606077?searchText=slu' target='_'>Lindh, Knut,Bokmål-nynorsk skoleordbok,2009</a></td><td>e slu slu - ,</td><td>slu</td><td style='text-align:left'>( e )</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014030606023?searchText=slu' target='_'>Kellerman, Jonathan,Konspirasjonsklubben,2009</a></td><td>tok eksamen ved , den</td><td>slu</td><td style='text-align:left'>digresjonen til jobbprat .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015111908243?searchText=slu' target='_'>Oppenheim, E. Phillips,Hans privatsekretær,1928</a></td><td>“ nd er8eriig ’ U1</td><td>slu</td><td style='text-align:left'>“ føiet han — Nå</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013081305063?searchText=slu' target='_'>,Ord i tid,1982</a></td><td>polisk : lur ,</td><td>slu</td><td style='text-align:left'>None</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013082605056?searchText=slu' target='_'>Stensrud, Eva J.,Kvaler,2008</a></td><td>I ) a er hun</td><td>slu</td><td style='text-align:left'>.</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013082605056?searchText=slu' target='_'>Stensrud, Eva J.,Kvaler,2008</a></td><td>- Like</td><td>slu</td><td style='text-align:left'>som broren sin , vil</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2006120701006?searchText=slu' target='_'>Gierløff, Christian,Naar byene vokser,1917</a></td><td>er nsi nok nu .</td><td>slu</td><td style='text-align:left'>k3n < ^ en le6eB</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013010808194?searchText=slu' target='_'>Slaughter, Karin,Hun visste hvem han var,2012</a></td><td>utenfor fengselsmurene - brutal ,</td><td>slu</td><td style='text-align:left'>og ustoppelig . Han hadde</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015042808158?searchText=slu' target='_'>Garborg, Arne,Fred,2005</a></td><td>1849 ) 5 grådig ,</td><td>slu</td><td style='text-align:left'>None</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014082108029?searchText=slu' target='_'>Cussler, Clive,Dødelig vind,2008</a></td><td>nye sjefen for NUMA var</td><td>slu</td><td style='text-align:left'>og benyttet anledningen til å</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010100508068?searchText=slu' target='_'>Ottersen, Olav,Over grensen,1996</a></td><td>Men Brøcker var</td><td>slu</td><td style='text-align:left'>som en gammel rev ;</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014110507506?searchText=slu' target='_'>,Lillehammer kunstmuseum,2002</a></td><td>avslører sin svikefullhet med et</td><td>slu</td><td style='text-align:left'>sideblikk . Jesus er i</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008110704089?searchText=slu' target='_'>Walters, Minette,Krutt,2001</a></td><td>Den gamle fikk et</td><td>slu</td><td style='text-align:left'>uttrykk i øynene , som</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008110704089?searchText=slu' target='_'>Walters, Minette,Krutt,2001</a></td><td>var da jeg så det</td><td>slu</td><td style='text-align:left'>uttrykket i øynene hennes og</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013061108033?searchText=slu' target='_'>Ludlum, Robert,Lazarus' hevn,2012</a></td><td>ordre fra den mektige ,</td><td>slu</td><td style='text-align:left'>og utspekulerte dronning Catarina av</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014040908068?searchText=slu' target='_'>Solheim, Anton,Gutane på Sandvoll,1945</a></td><td>han Søren . « Og</td><td>slu</td><td style='text-align:left'>er han , det kan</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013031905017?searchText=slu' target='_'>Erdman, Paul E.,Så sikkert som gull,1974</a></td><td>kjent for å være både</td><td>slu</td><td style='text-align:left'>og primitiv . Tredjemann var</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011061608053?searchText=slu' target='_'>Koontz, Dean R.,Besynderlige Odd,2007</a></td><td>. Du er omtrent like</td><td>slu</td><td style='text-align:left'>som et lam . »</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011061608053?searchText=slu' target='_'>Koontz, Dean R.,Besynderlige Odd,2007</a></td><td>De britiske øyer , en</td><td>slu</td><td style='text-align:left'>ting som kommer ned gjennom</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015120306003?searchText=slu' target='_'>Adler, Warren,Tilfeldighetenes spill,2000</a></td><td>for det også . En</td><td>slu</td><td style='text-align:left'>giftighet steg i henne .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013102407254?searchText=slu' target='_'>Jaffe, Rona,Etter klassefesten,1986</a></td><td>? Hun hadde aldri vært</td><td>slu</td><td style='text-align:left'>og smart . Alt hun</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013102407254?searchText=slu' target='_'>Jaffe, Rona,Etter klassefesten,1986</a></td><td>sies , er hun ganske</td><td>slu</td><td style='text-align:left'>og slett ikke så dum</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014102208088?searchText=slu' target='_'>,Caithreim Cellachain Caisil,1905</a></td><td>pal nafn af figlskylldri sy</td><td>slu</td><td style='text-align:left'>, pm at peir gista</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007111601045?searchText=slu' target='_'>Scott, Elwood,Paradiset, den hellige stad og tronens herlighet,1991</a></td><td>på en ny og høyst</td><td>slu</td><td style='text-align:left'>list fra satan , menneskets</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007112204057?searchText=slu' target='_'>al-Sa'dawi, Nawal,Imamens fall,1991</a></td><td>? tro at hun var</td><td>slu</td><td style='text-align:left'>. Ved det avsl ?</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009012600038?searchText=slu' target='_'>Sandemose, Aksel,flyktning krysser sitt spor,2002</a></td><td>. Han var erfaren og</td><td>slu</td><td style='text-align:left'>, han lokket for Eva</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007052200063?searchText=slu' target='_'>Collier, Richard,Generalen,1965</a></td><td>til - en lumsk OF</td><td>slu</td><td style='text-align:left'>OF k2rli ^ tiende ,</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014120208230?searchText=slu' target='_'>Nesland, Anna,Ord og uttrykk i Drangedals-målet,1980</a></td><td>None</td><td>slu</td><td style='text-align:left'>- sløg , lur ,</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014120208230?searchText=slu' target='_'>Nesland, Anna,Ord og uttrykk i

# %%
nb.nb_ngram("* munn").plot()

# %%
nb.nb_ngram("hodet hans, hans hode", years=(1910, 2010)).plot()

# %%
nb.nb_ngram("moren hans, hans mor", years=(1910, 2010)).plot()

# %%
nb.nb_ngram("moren hans, hans mor", years=(1910, 2010), mode='abs').sum(axis=0)
# Out:
# moren hans    15724.75
# hans mor      45720.50
# dtype: float64

# %%
nb.nb_ngram("ei krone, en krone", corpus='avis', years=(1910, 2010)).plot()

# %%
nb.nb_ngram("ei seng, en seng, senga, sengen", corpus='avis', years=(1910, 2010)).plot()

# %%
nb.nb_ngram("på, paa", corpus='avis', years=(1880, 1970)).plot()

# %%
nb.nb_ngram("bogen, boken", corpus='bok', years=(1810, 2010)).plot()

# %%
nb.nb_ngram("brunsnigel", corpus='avis', mode='ab', smooth=1,years=(1810, 2010)).plot()

# %%
nb.nb_ngram("krona, kronen", corpus='avis', years=(1910, 2010)).plot()

# %%
nb.nb_ngram("dette her, det her", corpus='avis', years=(1910, 2010)).plot()

# %%
nb.nb_ngram("animasjon", corpus='avis', years=(1910, 2010)).plot()

# %%
def dobbel(word, det='den', **kwarg):
    dobbel = nb.nb_ngram('{w}, {det} {w}'.format(w=word, det=det), **kwarg)
    return nb.frame(dobbel['{det} {w}'.format(w=word, det=det)]/dobbel[word], word)

# %%
import pandas as pd

# %%
pd.concat([dobbel('regjeringen'), dobbel('sengen'), dobbel('mannen'), dobbel('flyet', 'det'), dobbel('klassen')], sort=False).plot()

# %%
dobbel('sykkelen', smooth = 5, years=(1950,1980), mode='abs')

# %%
nb.nb_ngram("dette her, det her", corpus='avis', years=(1910, 2010)).plot()

# %%
nb.nb_ngram("gravferd", corpus='avis', years=(1910, 2010)).plot()

# %%
nb.concordance(word = 'løpende', subject='finans', yearfrom = 1980, yearto = 2010, before = 4, after = 3)
# Out:
# <table><tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008020501043?searchText=løpende' target='_'>Rich, Bruce,Med jorda i pant,1994</a></td><td>stilling til de mange</td><td>løpende</td><td style='text-align:left'>sakene . I</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008020501043?searchText=løpende' target='_'>Rich, Bruce,Med jorda i pant,1994</a></td><td>på grunn av Bankens</td><td>løpende</td><td style='text-align:left'>prosjekter , og</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008020501043?searchText=løpende' target='_'>Rich, Bruce,Med jorda i pant,1994</a></td><td>der man bare bruker</td><td>løpende</td><td style='text-align:left'>tilgjengelige , økonomisk</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008020501043?searchText=løpende' target='_'>Rich, Bruce,Med jorda i pant,1994</a></td><td>kraftproduksjonen til å dekke</td><td>løpende</td><td style='text-align:left'>kostnader , og</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008020501043?searchText=løpende' target='_'>Rich, Bruce,Med jorda i pant,1994</a></td><td>None</td><td>løpende</td><td style='text-align:left'>prosjektene på alvorlige</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011033108018?searchText=løpende' target='_'>Pedersen, Rune,Aksjer &amp; pengeplassering,2000</a></td><td>. Dette gir deg</td><td>løpende</td><td style='text-align:left'>beregninger av gevinst</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011033108018?searchText=løpende' target='_'>Pedersen, Rune,Aksjer &amp; pengeplassering,2000</a></td><td>for høye marginen Høy</td><td>løpende</td><td style='text-align:left'>kontantstrøm og god</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012052108078?searchText=løpende' target='_'>Høiskar, Thor Erik S.,Lånesyndikat - agentens rolle,1995</a></td><td>er å gi en</td><td>løpende</td><td style='text-align:left'>dokumentasjon og formidling</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012052108078?searchText=løpende' target='_'>Høiskar, Thor Erik S.,Lånesyndikat - agentens rolle,1995</a></td><td>Det skilles mellom en</td><td>løpende</td><td style='text-align:left'>plikt for låntakeren</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012052108078?searchText=løpende' target='_'>Høiskar, Thor Erik S.,Lånesyndikat - agentens rolle,1995</a></td><td>syndikatet kan foreta en</td><td>løpende</td><td style='text-align:left'>risikovurdering av lånet</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012052108078?searchText=løpende' target='_'>Høiskar, Thor Erik S.,Lånesyndikat - agentens rolle,1995</a></td><td>fremst har låntaker en</td><td>løpende</td><td style='text-align:left'>plikt til å</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012052108078?searchText=løpende' target='_'>Høiskar, Thor Erik S.,Lånesyndikat - agentens rolle,1995</a></td><td>kreve ut over den</td><td>løpende</td><td style='text-align:left'>informasjonsplikt som låntakeren</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008010904008?searchText=løpende' target='_'>Vårdal, Erling,Internasjonal makroøkonomi,1994</a></td><td>disponibel inntekt ( i</td><td>løpende</td><td style='text-align:left'>kroner ) og</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008010904008?searchText=løpende' target='_'>Vårdal, Erling,Internasjonal makroøkonomi,1994</a></td><td>midler ut over landets</td><td>løpende</td><td style='text-align:left'>inntekter . Norges</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008010904008?searchText=løpende' target='_'>Vårdal, Erling,Internasjonal makroøkonomi,1994</a></td><td>som følger er i</td><td>løpende</td><td style='text-align:left'>kroner , og</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009020904041?searchText=løpende' target='_'>,Opsjoner &amp; Futures,1998</a></td><td>kan være gjenstand for</td><td>løpende</td><td style='text-align:left'>handel . Vilkårene</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009020904041?searchText=løpende' target='_'>,Opsjoner &amp; Futures,1998</a></td><td>investoren gjør covered calls</td><td>løpende</td><td style='text-align:left'>over 1 år</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009020904041?searchText=løpende' target='_'>,Opsjoner &amp; Futures,1998</a></td><td>kursene on-line , dvs.</td><td>løpende</td><td style='text-align:left'>oppdatering når markedet</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009020904041?searchText=løpende' target='_'>,Opsjoner &amp; Futures,1998</a></td><td>også kan holde seg</td><td>løpende</td><td style='text-align:left'>orientert om utviklingen</td></tr>
# </table>

# %%
korpus = nb.book_corpus(subject='språkvitenskap', limit = 50)

# %%
agg = nb.get_aggregated_corpus(nb.pure_urn(korpus))

# %%
agg.loc['løpende']
# Out:
# 0    40
# Name: løpende, dtype: int64

# %%
coll = nb.urn_coll(word = 'løpende', urns = nb.pure_urn(korpus), before = 0, after = 5)

# %%
tot = nb.totals(50000)

# %%
tot = nb.frame(tot)

# %%
viktige = nb.frame_sort(nb.frame(coll[0]/tot[0]))

# %% [markdown]
# Metonymiske relasjoner mellom objektene, del for hele, hele for del.
# stickers game vs. stickers
# 1. sognsvann for tur til sognsvann

# %%
nb.cloud(viktige[:20])

# %%
MK = {
"Kamp" : "kamp, rifle, krutt, revolver, riflen, hylster, sår, blod, kjøtt, skjøt, skudd, avtrekkeren, siktet, død, døde, fyrte, ladegrep, siktet".split(', '),
"Glad":"glad, munter, plystret, lo, smilte, lettet, plystre, plystrer, muntre, live, lever, lettet, livlig, ler, smiler".split(', ')
}

# %%
MK
# Out:
# {'Kamp': ['kamp',
#   'rifle',
#   'krutt',
#   'revolver',
#   'riflen',
#   'hylster',
#   'sår',
#   'blod',
#   'kjøtt',
#   'skjøt',
#   'skudd',
#   'avtrekkeren',
#   'siktet',
#   'død',
#   'døde',
#   'fyrte',
#   'ladegrep',
#   'siktet'],
#  'Glad': ['glad',
#   'munter',
#   'plystret',
#   'lo',
#   'smilte',
#   'lettet',
#   'plystre',
#   'plystrer',
#   'muntre',
#   'live',
#   'lever',
#   'lettet',
#   'livlig',
#   'ler',
#   'smiler']}

# %%
nb.book_corpus(author='masterson%', title="%tigeren%montana%")
# Out:
#              urn            author  \
# 0  2014051908121  Masterson, Louis
# 1  2015011608010  Masterson, Louis
# 2  2013060408158  Masterson, Louis
#
#                                             title  year
# 0  Tigeren fra Montana ; Den gale hunden fra Utah  2007
# 1                             Tigeren fra Montana  1980
# 2                             Tigeren fra Montana  1972

# %%
nb.plot_book_wordbags(2014051908121, MK).plot(title = "Tigeren fra Montana ; Den gale hunden fra Utah" )

# %%
nb.plot_book_wordbags(2011100608069, MK).plot()
