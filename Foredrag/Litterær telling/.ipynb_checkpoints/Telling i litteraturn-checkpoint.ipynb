# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
import dhlab.graph_networkx_louvain as gnl
from dhlab.module_update import update, css, code_toggle

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Merriweather|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Merriweather';
# 	color: DarkSlateGray;
# }
#
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
#code_toggle()
# Out:
# <div>
#                 <style>
#                  .mybutton {
#                     background-color: lightgrey;
#                     border: none;
#                     color: white;
#                     padding: 10px 16px;
#                     text-align: center;
#                     text-decoration: none;
#                     display: inline-block;
#                     font-size: 16px;
#                     margin: 4px 2px;
#                     cursor: pointer;
#                 }
#             </style>
#             <script>
#                 code_show=true;
#                 function code_toggle() {
#                  if (code_show){
#                  $('div.input').hide();
#                  } else {
#                  $('div.input').show();
#                  }
#                  code_show = !code_show
#                 }
#                 $( document ).ready(code_toggle);
#             </script>
#             <form  action="javascript:code_toggle()">
#                 <input class='mybutton' type="submit" value="Klikk for å vise/skjule kodeceller">
#             </form>
#         </div>

# %%
def categorize(list_of_words):
    proprium = [x for x in list_of_words if x[0].upper() == x[0]]
    other = [x for x in list_of_words if not x in proprium]

    return {'propr':proprium,
           'other': other }

def select_form(w):
    fs = [x.split()[0] for x in nb.word_form(w)]
    if 'verb' in fs:
        res = 'verb'
    elif 'subst' in fs:
        res = 'subst'
    elif len(fs) > 0:
        res = fs[0]
    else:
        res = 'unknown'
    return res

def sort_word_forms(words):
    res = {select_form(w):w for w in words}
    return res

def character_words(Character_name, number_of_words=50):
    res = {w:select_form(w) for w in categorize(list(nb.frame_sort(nb.frame(coll_matrix[Character_name]/tot['tot'], 'association')).head(number_of_words).index))['other']}
    result = {cat:[w for w in res if res[w] == cat] for cat in res.values()}
    return result

def mdprint(forskjell, cutoff=5):
    categories = categorize(forskjell[forskjell > cutoff].dropna().index)
    forms = {w:select_form(w) for w in categories['other']}
    Grouping = {cat:[word for word in forms if forms[word] == cat] for cat in forms.values()}
    navn = "## Benevnelser \n"
    navn += "<span style='font-size:150%'>{stuff}</span>".format(stuff= ', '.join(categories['propr']))
    pos = ""
    for cat in Grouping:
        pos += "## " + cat + "\n"
        pos += "<span style='font-size:150%'>{stuff}</span>".format(stuff= ', '.join(Grouping[cat]) ) + "\n"
    mu.printmd(navn)
    mu.printmd(pos)
    return

# %%
update('collocations')
# Out:
# Updated file `D:\Documents\GitHub\Miscellaneous-Notebooks\Foredrag\Litterær telling\collocations.py`

# %%
from collocations import make_collocations, collocation, colls2df, urn_coll

# %%
import pandas as pd

# %%
import ast

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
show = lambda res, col, axis=1: res.sort_values(by=col, ascending=False).head(20).fillna(0).style.background_gradient(axis=axis)

# %%
demokrati = nb.make_graph('demokrati', cutoff=16)

# %% [markdown]
# # DH-lab

# %% [markdown]
# https://nbviewer.jupyter.org/github/DH-LAB-NB/DHLAB/blob/master/DHLAB_ved_Nasjonalbiblioteket.ipynb

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <br/>
# <br/>
# <br/>
#
# # Ordet *demokrati*

# %%
nb.nb_ngram('demokrati').plot(lw=3, figsize=(12,7));

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
#
# # Flere ord

# %%
nb.nb_ngram('demokrati, diktatur, folkestyre, aristokrati').plot(lw=3, figsize=(12,7));

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # En graf

# %%
gnl.show_graph(demokrati, spread = 1.8);

# %%
gnl.show_communities(demokrati)
# Out:
# rettferdighet-solidaritet :  rettferdighet, solidaritet, toleranse, likhet, sannhet
#
# sosialisme-diktatur :  sosialisme, diktatur, kommunisme, Demokrati, kapitalisme, kristendom, revolusjon, fascisme, liberalisme, Kristendom, nazisme, terror, planøkonomi, konservatisme, ensretting, tvang
#
# demokrati-frihet :  demokrati, frihet, likestilling, likeverd, folkestyre, ansvar, mangfold, markedsøkonomi, menneskerettar, selvstendighet, uavhengighet, rettsstat, kvinnefrigjøring, privatisering, integritet, forfatning, Land, ytringsfridom, kvinnekamp, likelønn, deltakelse, menneskeretter, inkludering, frigjøring, kvinnesak, familiepolitikk
#
# velferd-trygghet :  velferd, trygghet, velstand, helse, verdiskaping, omsorg, trivsel, sysselsetting, liv
#
# fred-fridom :  fred, fridom, rettferd, forsoning, nedrustning, avspenning, krig, glede, sikkerhet, ro, forståelse
#
# åpenhet-medbestemmelse :  åpenhet, medbestemmelse, respekt, fleksibilitet, innsyn, ærlighet, ryddighet, innflytelse, nysgjerrighet, medinnflytelse, påvirkning, medvirkning, samarbeid, tillit, offentlighet
#
# menneskerettigheter-rettssikkerhet :  menneskerettigheter, rettssikkerhet, ytringsfrihet, menneskeverd, likebehandling, religionsfrihet, personvern, pressefrihet, trosfrihet, sensur, miljø, sosial, rettigheter, folkerett
#
# Frihet-Fred :  Frihet, Fred, Fedreland

# %% [markdown]
# <br>
# <br>
# <br>
#
# # Lager en kollokasjon fra aviser

# %%
demokrati_dict = gnl.community_dict(demokrati)

# %%
coll = dict()
step = 3
for i in range(1920, 2000, step):
    #print(i)
    try:
        coll[i] = nb.collocation('demokrati', yearfrom=i, yearto=i+step, before=10, after=10, corpus='avis')
    except:
        try:
            coll[i] = nb.collocation('demokrati', yearfrom=i, yearto=i+step, before=10, after=10, corpus='avis')
        except:
            try:
                coll[i] = nb.collocation('demokrati', yearfrom=i, yearto=i+step, before=10, after=10, corpus='avis')
            except:
                print('gir opp', i)
# Out:
# 1920
# 1923
# 1926
# 1929
# 1932
# 1935
# 1938
# 1941
# 1944
# 1947
# 1950
# 1953
# 1956
# 1959
# 1962
# 1965
# 1968
# 1971
# 1974
# 1977
# 1980
# 1983
# 1986
# 1989
# 1992
# 1995
# 1998

# %% [markdown]
# # Sammenligner med en referanse
#
#
# <br>
#
# <span style="font-size:150%">`tot = nb.frame(nb.totals(50000), 'tot')`</span>

# %%
tot = nb.frame(nb.totals(50000), 'tot')

# %%
colls = pd.concat([nb.frame(coll[d], d) for d in coll], axis=1, sort=False).fillna(0)

# %%
colls.to_json('demokrati_collocations.json')

# %%
agg = pd.DataFrame()
step = 5
for i in range(0, len(colls.columns), step):
    agg[colls.columns[i]] = colls[colls.columns[i:i+step]].sum(axis=1)

# %%
pmi = pd.DataFrame()
for i in agg:
    pmi[i] = agg[i]/tot.tot

# %%
nb.normalize_corpus_dataframe(pmi)
# Out:
# True

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
#
# # De 15 beste for 1965

# %%
pmi.sort_values(by=1965, ascending=False).head(15).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row0_col0 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row0_col1 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row0_col3 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row0_col4 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row1_col1 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row1_col2 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row1_col3 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row1_col4 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row1_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row2_col0 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row2_col1 {
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row2_col2 {
#             background-color:  #2a88bc;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row2_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row2_col4 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row2_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row3_col0 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row3_col2 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row3_col4 {
#             background-color:  #1e80b8;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row3_col5 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row4_col0 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row4_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row4_col2 {
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row4_col3 {
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row4_col4 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row4_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row5_col1 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row5_col2 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row5_col3 {
#             background-color:  #03446a;
#             color:  #f1f1f1;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row5_col4 {
#             background-color:  #2081b9;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row5_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row6_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row6_col2 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row6_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row6_col4 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row6_col5 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row7_col0 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row7_col1 {
#             background-color:  #99b8d8;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row7_col2 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row7_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row7_col4 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row7_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row8_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row8_col1 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row8_col2 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row8_col3 {
#             background-color:  #a1bbda;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row8_col4 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row8_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row9_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row9_col2 {
#             background-color:  #4897c4;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row9_col3 {
#             background-color:  #1e80b8;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row9_col4 {
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }    #T_31c7a8be_01d7_11ea_8cc0_000acd2bfab2row9_col5 {
#             background-color:  #c8cde4;
#             color:  #000000;

# %%
pmi.sort_values(by=1935, ascending=False).head(15).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row0_col1 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row0_col2 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row0_col3 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row0_col4 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row1_col2 {
#             background-color:  #045b8e;
#             color:  #f1f1f1;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row1_col3 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row1_col4 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row1_col5 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row2_col0 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row2_col1 {
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row2_col2 {
#             background-color:  #2a88bc;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row2_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row2_col4 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row2_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row3_col0 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row3_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row3_col2 {
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row3_col3 {
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row3_col4 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row3_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row4_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row4_col2 {
#             background-color:  #4897c4;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row4_col3 {
#             background-color:  #1e80b8;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row4_col4 {
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row4_col5 {
#             background-color:  #c8cde4;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row5_col0 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row5_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row5_col2 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row5_col3 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row5_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row6_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row6_col1 {
#             background-color:  #023c5f;
#             color:  #f1f1f1;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row6_col2 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row6_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row6_col4 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row6_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row7_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row7_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row7_col2 {
#             background-color:  #94b6d7;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row7_col3 {
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row7_col4 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row7_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row8_col0 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row8_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row8_col2 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row8_col3 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row8_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row9_col1 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row9_col2 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row9_col3 {
#             background-color:  #03446a;
#             color:  #f1f1f1;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row9_col4 {
#             background-color:  #2081b9;
#             color:  #000000;
#         }    #T_9bcdb0c6_01d7_11ea_971a_000acd2bfab2row9_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;

# %%
pmi.sort_values(by=1935, ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=40, figsize=(12, 6));

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # De hundre toppordene for 1965 sortert på ordklasser

# %%
mdprint(pmi.sort_values(by=1965, ascending=False).head(100),-1)
# Out:
# ## Benevnelser
# <span style='font-size:150%'>Demokrati, Hellas, NTB, Bratteli, Arbeiderpartiets, Venstres, EEC, Borten, Arbeiderpartiet, 19.00, Portugal, Høyres, Willoch, Sosialistisk, Tsjekkoslovakia, Landsorganisasjonen, Nordli, Vårt, Statsminister, 20.00, Spanias, Gustavsen</span>
# ## adj
# <span style='font-size:150%'>industrielt, parlamentarisk, sosialistisk, parlamentariske, levedyktig, liberalt, sosialistiske, reelt, folkevalgte, vestlig, demokratiske, portugisiske, demokratisk, totalitære, forenlig, uforenlig, uverdig, sunt, representative</span>
# ## subst
# <span style='font-size:150%'>diktatur, sosialisme, demokrati, demokratiet, kommunisme, styreform, hverdagen, rettssikkerhet, ytringsfrihet, spilleregler, styresett, fagbevegelsen, trusel, byråkrati, velgerne, menneskeverd, sosialismen, arbeidslivet, frihet, solidaritet, fridom, folkeavstemning, menneskerettigheter, likestilling, slagord, humanisme, parodi, slagordet, valgkampen, kapitalisme, arbeiderbevegelse, komité, toleranse, medansvar, rettferd, suverenitet, arbeiderbevegelsen, uavhengighet, sosialister</span>
# ## unknown
# <span style='font-size:150%'>arbeidsplassen, demokratiets, proletariatets, demokratisering, kvardagen, desentralisering, arbeidsplassene, onsker, komite, medbestemmelse, arbeiderbevegelsens, folkenes, samfunnslivet, stotte, flertallets, språkleg</span>
# ## verb
# <span style='font-size:150%'>undergrave, praktiserer, framholdt</span>
# ## det
# <span style='font-size:150%'>vårt</span>

# %%
barchart = lambda w: pmi.loc[w].transpose().plot(kind='bar', rot=40, figsize=(12,6)) ;

# %%
barchart(['menneskerettigheter','diktatur',"ytringsfrihet", 'fascismen','arbeidsplassen', 'kapitalisme']);

# %%
barchart(['.','og', ',','eller', 'men']);

# %%
demokrati_dict
# Out:
# {'rettferdighet-solidaritet': ['rettferdighet',
#   'solidaritet',
#   'toleranse',
#   'likhet',
#   'sannhet'],
#  'sosialisme-diktatur': ['sosialisme',
#   'diktatur',
#   'kommunisme',
#   'Demokrati',
#   'kapitalisme',
#   'kristendom',
#   'revolusjon',
#   'fascisme',
#   'liberalisme',
#   'Kristendom',
#   'nazisme',
#   'terror',
#   'planøkonomi',
#   'konservatisme',
#   'ensretting',
#   'tvang'],
#  'demokrati-frihet': ['demokrati',
#   'frihet',
#   'likestilling',
#   'likeverd',
#   'folkestyre',
#   'ansvar',
#   'mangfold',
#   'markedsøkonomi',
#   'menneskerettar',
#   'selvstendighet',
#   'uavhengighet',
#   'rettsstat',
#   'kvinnefrigjøring',
#   'privatisering',
#   'integritet',
#   'forfatning',
#   'Land',
#   'ytringsfridom',
#   'kvinnekamp',
#   'likelønn',
#   'deltakelse',
#   'menneskeretter',
#   'inkludering',
#   'frigjøring',
#   'kvinnesak',
#   'familiepolitikk'],
#  'velferd-trygghet': ['velferd',
#   'trygghet',
#   'velstand',
#   'helse',
#   'verdiskaping',
#   'omsorg',
#   'trivsel',
#   'sysselsetting',
#   'liv'],
#  'fred-fridom': ['fred',
#   'fridom',
#   'rettferd',
#   'forsoning',
#   'nedrustning',
#   'avspenning',
#   'krig',
#   'glede',
#   'sikkerhet',
#   'ro',
#   'forståelse'],
#  'åpenhet-medbestemmelse': ['åpenhet',
#   'medbestemmelse',
#   'respekt',
#   'fleksibilitet',
#   'innsyn',
#   'ærlighet',
#   'ryddighet',
#   'innflytelse',
#   'nysgjerrighet',
#   'medinnflytelse',
#   'påvirkning',
#   'medvirkning',
#   'samarbeid',
#   'tillit',
#   'offentlighet'],
#  'menneskerettigheter-rettssikkerhet': ['menneskerettigheter',
#   'rettssikkerhet',
#   'ytringsfrihet',
#   'menneskeverd',
#   'likebehandling',
#   'religionsfrihet',
#   'personvern',
#   'pressefrihet',
#   'trosfrihet',
#   'sensur',
#   'miljø',
#   'sosial',
#   'rettigheter',
#   'folkerett'],
#  'Frihet-Fred': ['Frihet', 'Fred', 'Fedreland']}

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22})

# %%
barchart(demokrati_dict['demokrati-frihet'][1:6]);

# %%
barchart(demokrati_dict['menneskerettigheter-rettssikkerhet'][0:5]);

# %%
barchart(demokrati_dict['åpenhet-medbestemmelse'][0:5]);
