# %% [markdown]
# ### Galakser som embeddinger

# %%
# Hvis dhlab ikke er installert, avkommenter linjen under og kjør
#!pip install dhlab

# %%
import dhlab.nbtext as nb
import dhlab.graph_networkx_louvain as gnl

# %% [markdown]
# ## Test ut med kommando `relaterte_ord`
#
# Det er en egenvektorbasert måte å hente ut tilsvarende ord fra grafen gitt under.

# %%
nb.relaterte_ord('samer', score=True)
# Out:
# [('nordmenn', 0.5135116431687898),
#  ('svensker', 0.40660397910538715),
#  ('innvandrere', 0.2920275518962041),
#  ('samer', 0.23409948175221013),
#  ('briter', 0.16461338847597395),
#  ('dansker', 0.16461338847597395),
#  ('russere', 0.16461338847597395),
#  ('amerikanere', 0.16461338847597395),
#  ('nederlendere', 0.16461338847597395),
#  ('islendinger', 0.16461338847597395),
#  ('utlendinger', 0.16461338847597395),
#  ('tyskere', 0.16461338847597395),
#  ('engelskmenn', 0.16461338847597395),
#  ('kvener', 0.13375208082837295),
#  ('andre', 0.12974148569320476),
#  ('indianere', 0.09769686620938264),
#  ('samiske', 0.09676901993075508),
#  ('finner', 0.09667251671315237),
#  ('reindrift', 0.09328739862090063),
#  ('svenskar', 0.09186993654356802)]

# %% [markdown]
# ## Ta ut grafen og hent ut med passende algoritem
#
#
# Grafen er et **networkx**- objekt.

# %%
G = nb.make_graph('samer')

# %%
gnl.show_graph(G, spread = 1.3)
# Out:
# C:\Users\larsj\AppData\Local\Continuum\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %% [markdown]
# Med `show_communities` gis en litt mer detaljert clustring fra grafen

# %%
gnl.show_communities(G)
# Out:
# samer-indianere :  samer, indianere, kvener, nybyggere, tatere, vikinger, franskmenn, hvite, Samer, eskimoer, kvæner, troll, Indianere, sigøynere, cowboyer, finnmarkinger
#
# samiske-minoriteter :  samiske, minoriteter, norske, urfolk, kvenske, kvænske, reindriftsnæringen, finske, nordnorske
#
# bønder-bygdefolk :  bønder, bygdefolk, andre, byfolk, turister, arbeidarar, foreldre, naboer, fiskere, turistar, politikere, småbrukere, grunneiere, industriarbeidere, reineiere, tilreisande, skogeiere, forbrukere, arbeidere, fiskarar, hyttefolk, venner
#
# nordmenn-svensker :  nordmenn, svensker, briter, dansker, engelskmenn, nederlendere, russere, utlendinger, finner, tyskere, amerikanere, islendinger, jugoslaver, polakker, svenskar, Dansker, nordmænd, Nordmenn
#
# innvandrere-asylsøkere :  innvandrere, asylsøkere, flyktninger, muslimer, innfødte, homofile, innvandring
#
# reindrift-samisk :  reindrift, samisk, kvensk, kultur, landbruk, sauehold, finsk, jordbruk, fiske, jakt, norsk, norrøn, nordnorsk, ferskvannsfiske, kvænsk
#
# rein-reinsdyr :  rein, reinsdyr, elg, sau, slede, rype, hjort, vilt, rådyr, bufe, trygg, husdyr, sauer, nisser, klår
#
# andres-eget :  andres, eget, egne
#
# sel-isbjørn :  sel, isbjørn, kval, skarv, oter, fugl, sjøfugl, hval, pingviner, hvalross

# %% [markdown]
# Ta ut clusteret som et python-objekt

# %%
gnl.community_dict(G)
# Out:
# {'samer-indianere': ['samer',
#   'indianere',
#   'kvener',
#   'nybyggere',
#   'tatere',
#   'vikinger',
#   'franskmenn',
#   'hvite',
#   'Samer',
#   'eskimoer',
#   'kvæner',
#   'troll',
#   'Indianere',
#   'sigøynere',
#   'cowboyer',
#   'finnmarkinger'],
#  'samiske-minoriteter': ['samiske',
#   'minoriteter',
#   'norske',
#   'urfolk',
#   'kvenske',
#   'kvænske',
#   'reindriftsnæringen',
#   'finske',
#   'nordnorske'],
#  'bønder-bygdefolk': ['bønder',
#   'bygdefolk',
#   'andre',
#   'byfolk',
#   'turister',
#   'arbeidarar',
#   'foreldre',
#   'naboer',
#   'fiskere',
#   'turistar',
#   'politikere',
#   'småbrukere',
#   'grunneiere',
#   'industriarbeidere',
#   'reineiere',
#   'tilreisande',
#   'skogeiere',
#   'forbrukere',
#   'arbeidere',
#   'fiskarar',
#   'hyttefolk',
#   'venner'],
#  'nordmenn-svensker': ['nordmenn',
#   'svensker',
#   'briter',
#   'dansker',
#   'engelskmenn',
#   'nederlendere',
#   'russere',
#   'utlendinger',
#   'finner',
#   'tyskere',
#   'amerikanere',
#   'islendinger',
#   'jugoslaver',
#   'polakker',
#   'svenskar',
#   'Dansker',
#   'nordmænd',
#   'Nordmenn'],
#  'innvandrere-asylsøkere': ['innvandrere',
#   'asylsøkere',
#   'flyktninger',
#   'muslimer',
#   'innfødte',
#   'homofile',
#   'innvandring'],
#  'reindrift-samisk': ['reindrift',
#   'samisk',
#   'kvensk',
#   'kultur',
#   'landbruk',
#   'sauehold',
#   'finsk',
#   'jordbruk',
#   'fiske',
#   'jakt',
#   'norsk',
#   'norrøn',
#   'nordnorsk',
#   'ferskvannsfiske',
#   'kvænsk'],
#  'rein-reinsdyr': ['rein',
#   'reinsdyr',
#   'elg',
#   'sau',
#   'slede',
#   'rype',
#   'hjort',
#   'vilt',
#   'rådyr',
#   'bufe',
#   'trygg',
#   'husdyr',
#   'sauer',
#   'nisser',
#   'klår'],
#  'andres-eget': ['andres', 'eget', 'egne'],
#  'sel-isbjørn': ['sel',
#   'isbjørn',
#   'kval',
#   'skarv',
#   'oter',
#   'fugl',
#   'sjøfugl',
#   'hval',
#   'pingviner',
#   'hvalross']}

# %%
indianere = nb.make_graph('indians', lang='eng')

# %%
gnl.show_graph(indianere)
# Out:
# C:\Users\larsj\AppData\Local\Continuum\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
gnl.show_communities(indianere)
# Out:
# blacks-whites :  blacks, whites, indians, coloureds, greys, nonblacks, hispanics, coloreds
#
# cowboys-ranchmen :  cowboys, ranchmen, sheepherders, cowgirls, vaqueros, cowmen
#
# mestizos-pardos :  mestizos, pardos, mestizas, cholos, mulatos, criollos
#
# negroes-mulattos :  negroes, mulattos, mulattoes, carpetbaggers, scalawags

# %%
violence = nb.make_graph('violence', lang='eng')

# %%
gnl.show_graph(violence, spread = 1)

# %%
gnl.show_cliques(violence)
# Out:
# (3, 1) lawlessness, Rapine, violence, pillage, bloodshed, rapine, incendiarism
#
# (3, 2) terrorisation, violence, thuggery, intimidation

# %%
gnl.show_communities(violence)
# Out:
# rapine-Rapine :  rapine, Rapine, bloodshed, pillage, Plunder, ruffianism, Extortion, Murder, Spoil, plunder, Lust, incendiarism
#
# rapines-murders :  rapines, murders, depredations, extortions, robberies
#
# violence-terrorisation :  violence, terrorisation, vagabondism, oppreffion, Fickleness
#
# nonviolence-satyagraha :  nonviolence, satyagraha, noncooperation, pacifism, nonresistance, peacemaking
#
# Lawlessness-Violence :  Lawlessness, Violence, anarchy, Crime, counterviolence
#
# intimidation-harassment :  intimidation, harassment, bribery, coercion, cajolery, harrassment, terrorization, extortion
#
# lawlessness-thuggery :  lawlessness, thuggery, hooliganism, banditry, brigandage, corruption
#
# suddenness-unexpectedness :  suddenness, unexpectedness, swiftness, abruptness
