# %%
# !pip install pdfminer
# Out:
# Collecting pdfminer
#   Downloading https://files.pythonhosted.org/packages/57/4f/e1df0437858188d2d36466a7bb89aa024d252bd0b7e3ba90cbc567c6c0b8/pdfminer-20140328.tar.gz (4.1MB)
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\users\larsj\appdata\local\continuum\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\larsj\\AppData\\Local\\Temp\\pip-install-cp2kormf\\pdfminer\\setup.py'"'"'; __file__='"'"'C:\\Users\\larsj\\AppData\\Local\\Temp\\pip-install-cp2kormf\\pdfminer\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base pip-egg-info
#          cwd: C:\Users\larsj\AppData\Local\Temp\pip-install-cp2kormf\pdfminer\
#     Complete output (8 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\larsj\AppData\Local\Temp\pip-install-cp2kormf\pdfminer\setup.py", line 3, in <module>
#         from pdfminer import __version__
#       File "C:\Users\larsj\AppData\Local\Temp\pip-install-cp2kormf\pdfminer\pdfminer\__init__.py", line 5
#         print __version__
#                         ^
#     SyntaxError: Missing parentheses in call to 'print'. Did you mean print(__version__)?
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# WARNING: You are using pip version 19.2.2, however version 19.2.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-1.26.0

# %%
import PyPDF2 as PyP

# %%
from PyPDF2 import PdfFileReader

# %%
def get_info(path):
    with open(path, 'rb') as f:
        pdf = PdfFileReader(f)
        info = pdf.getDocumentInfo()
        number_of_pages = pdf.getNumPages()
    print(number_of_pages)


def get_text_from_pdf(path):
    text = ""
    with open(path, 'rb') as f:
        pdf = PdfFileReader(f)
        number_of_pages = pdf.getNumPages()
        for p in range(number_of_pages):
            page = pdf.getPage(p)
            text += page.extractText()
    return text

def files(path):
    import os
    r, d, f = next(os.walk(path))
    pdfer = [file for file in f if file.endswith('.pdf')]
    return pdfer

def get_text_from_word(document):
    """Find all text in a Word document"""
    import sys
    import zipfile
    import re
    from bs4 import BeautifulSoup
    
    with zipfile.ZipFile(document, 'r') as zfp:
        with zfp.open('word/document.xml') as fp:
            soup = BeautifulSoup(fp.read(), 'xml')
    return soup.get_text()

# %%
text = get_text_from_pdf("D:/Downloads/stm200620070012000dddpdfs.pdf")
# Out:
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]

# %%
text.split()
# Out:
# ['Offentlige',
#  'etater',
#  'kan',
#  'bestille',
#  'flere',
#  'eksemplarer',
#  'fra:',
#  'Departementenes',
#  'servicesenter',
#  'Kopi-',
#  'og',
#  'distribusjonsservice',
#  'www.publikasjoner.dep.no',
#  'E-post:',
#  'publikasjonsbestilling@dss.dep.no',
#  'Telefaks:',
#  '22',
#  '24',
#  '27',
#  '86',
#  'Abonnement,',
#  'løssalg',
#  'og',
#  'pris',
#  'fåes',
#  'ved',
#  'henvendelse',
#  'til:Akademika',
#  'AS',
#  'Avdeling',
#  'for',
#  'offentlige',
#  'publikasjoner',
#  'Postboks',
#  '84',
#  'Blindern',
#  '0314',
#  'OSLO',
#  'E-post:',
#  'offpubl@akademika.no',
#  'Telefon:',
#  '22',
#  '18',
#  '81',
#  '00',
#  'Telefaks:',
#  '22',
#  '18',
#  '81',
#  '01',
#  'Grønt',
#  'nummer:',
#  '800',
#  '80',
#  '960',
#  'Publikasjonen',
#  'finnes',
#  'på',
#  'internett:',
#  'www.odin.dep.no',
#  'Omslagsbilder:',
#  '(«Konvoy»',
#  'av',
#  'Elisabeth',
#  'Jarstø)',
#  'Ved',
#  'Obrestad',
#  'havn,',
#  'Jæren.',
#  'Hå,',
#  'Rogaland.',
#  '©',
#  'Bjørn',
#  'Rørslett/NN/Samfoto',
#  'Turistbåt',
#  'på',
#  'vei',
#  'ut',
#  'Geirangerfjorden.',
#  'Stranda',
#  'kommune,',
#  'Møre',
#  'og',
#  'Romsdal.',
#  '©',
#  'Dag',
#  'Røttereng/NN/Samfoto',
#  'Uppigard',
#  'Skjåk,',
#  'Skjåk',
#  'kommune.',
#  'Oppland',
#  'fylke.',
#  '©',
#  'Øystein',
#  'Søbye/NN/Samfoto',
#  'Oslo.',
#  '©',
#  'Kerstin',
#  'Mertens/Samfoto',
#  'Trykk:',
#  'GAN',
#  'Grafisk',
#  'AS',
#  '–',
#  '12/2006',
#  '–',
#  'opplag',
#  '5000',
#  'St.meld.nr.12',
#  '(2006–2007)Regionale',
#  'fortrinn',
#  '–',
#  'regional',
#  'framtid',
#  'St.meld.nr.??',
#  '(2006–2007)',
#  'Regionale',
#  'fortrinn',
#  '–',
#  'regional',
#  'framtid',
#  '73153_STM_KRD.qxp',
#  '01.12.2006',
#  '12:50',
#  'Side',
#  '12002-2003St.meld.',
#  'nr.',
#  '?2Om',
#  'innenlands',
#  'bruk',
#  'av',
#  'naturgass',
#  'mv.3Innhold1˜Hovedinnhold',
#  'i',
#  'meldingen',
#  '...............',
#  '5˜1.1˚Utgangspunkt',
#  'for',
#  'reformen',
#  '..................',
#  '5˜1.2˚Mål',
#  'for',
#  'reformen',
#  '....................................',
#  '6˜1.3˚Forutsetninger',
#  'for',
#  'reformen',
#  '.................',
#  '6˜1.4˚Oppgaver',
#  'til',
#  'de',
#  'nye',
#  'folkevalgte',
#  '˜regionene.................................................',
#  '7˜1.5˚Sametinget...............................................',
#  '8˜1.6˚Hovedstadsområdet',
#  '...............................',
#  '8˜1.7˚Valg',
#  '..........................................................',
#  '9˜1.8˚Sammenhengen',
#  'mellom',
#  'regional',
#  '˜inndeling',
#  'og',
#  'oppgaveportefølje...........',
#  '10˜1.9˚Videre',
#  'prosess',
#  '......................................',
#  '13˜1.10˚Konsekvenser',
#  'for',
#  'andre',
#  '˜forvaltningsnivåer',
#  'av',
#  'endret',
#  '˜oppgavefordeling',
#  'og',
#  'inndeling',
#  '...........',
#  '13˜2˜Mål',
#  'for',
#  'reformen',
#  '..............................',
#  '15˜2.1˚Mål',
#  'for',
#  'reformen',
#  '.................................',
#  '15˜2.2˚Forutsetninger',
#  'for',
#  'reformen',
#  '...............',
#  '16˜2.3˚Styrings-',
#  'og',
#  'samhandlingsforholdet',
#  '˜mellom',
#  'staten',
#  'og',
#  '˜kommunesektoren',
#  '...............................',
#  '17˜2.4˚Krav',
#  'og',
#  'hensyn',
#  'knyttet',
#  'til',
#  '˜oppgavefordelingen',
#  'mellom',
#  '˜forvaltningsnivåene',
#  '..............................',
#  '18˜2.4.1˚Hensynet',
#  'til',
#  'lokalt',
#  'selvstyre',
#  '˜og',
#  'deltakelse',
#  '.........................................',
#  '18˜2.4.2˚Hensynet',
#  'til',
#  'innbyggerne',
#  '...................',
#  '18˜2.4.3˚Hensynet',
#  'til',
#  'nasjonale',
#  'mål...................',
#  '19˜2.5˚Prinsipper',
#  'for',
#  'ansvars-',
#  'og',
#  '˜oppgavefordelingen',
#  'mellom',
#  'staten',
#  '˜og',
#  'kommunesektoren..........................',
#  '19˜3˜Dagens',
#  'fylkeskommune',
#  '..................',
#  '21˜3.1˚Oppgaver',
#  '...............................................',
#  '21˜3.2˚Organisering',
#  'og',
#  'styringsmodeller',
#  '.....',
#  '22˜3.2.1˚Fylkesutvalgsmodell',
#  'eller',
#  '˜parlamentarisk',
#  'modell?........................',
#  '22˜3.2.2˚Forsøk',
#  'med',
#  'enhetsfylke',
#  '......................',
#  '23˜3.3˚Fylkeskommunens',
#  'ulike',
#  'roller',
#  '..........',
#  '24˜3.3.1˚Fylkeskommunen',
#  'som',
#  '˜demokratisk',
#  'aktør',
#  '................................',
#  '24˜3.3.2˚Fylkeskommunen',
#  'som',
#  'regional',
#  '˜utviklingsaktør......................................',
#  '26˜3.3.3˚Fylkeskommunen',
#  'som',
#  '˜tjenesteprodusent',
#  '.................................',
#  '28˜3.3.4˚Fylkeskommunens',
#  'rolle',
#  '˜i',
#  'internasjonalt',
#  'arbeid',
#  '..........................',
#  '31˜3.4˚Synspunkter',
#  'på',
#  'dagens',
#  '˜fylkeskommune',
#  '....................................',
#  '31˜3.4.1˚KS...........................................................',
#  '31˜3.4.2˚Høringsmøter........................................',
#  '33˜3.5˚Sametinget.............................................33˜3.5.1˚Prosess...................................................33˜3.5.2˚Sametingets',
#  'synspunkter.....................34˜3.6˚Regjeringens',
#  'vurdering',
#  '˜av',
#  'dagens',
#  'fylkeskommune...................35˜4˜Det',
#  'framtidige',
#  'folkevalgte',
#  '˚regionale',
#  'nivået...................................37˜4.1˚Den',
#  'framtidige',
#  'rollen',
#  'til',
#  'et',
#  'nytt',
#  '˜folkevalgt',
#  'regionalt',
#  'nivå',
#  '......................37˜4.2˚Regjeringens',
#  'forslag',
#  'til',
#  '˜desentralisering',
#  'av',
#  'oppgaver',
#  '..............39˜4.2.1˚Planlegging',
#  '...........................................39˜4.2.2˚Utdanning',
#  'og',
#  'forskning........................41˜4.2.3˚Samferdsel',
#  '.............................................42˜4.2.4˚Næringsutvikling...................................46˜4.2.5˚Marin',
#  'sektor..........................................49˜4.2.6˚Landbruks-',
#  'og',
#  'matområdet..................52˜4.2.7˚Miljøvernområdet..................................55˜4.2.8˚Kultur......................................................57˜5˜Kommunene',
#  '........................................59˜5.1˚Kommunenes',
#  'rolle',
#  '˜i',
#  'norsk',
#  'forvaltning.................................59˜5.2˚Kommunenes',
#  'oppgaveportefølje',
#  '˜framover',
#  '.................................................60˜5.3˚Kommunene',
#  'og',
#  'det',
#  'folkevalgte',
#  '˜regionale',
#  'nivået',
#  'i',
#  'dag............................62˜5.4˚Forholdet',
#  'mellom',
#  'kommunene',
#  '˜og',
#  'de',
#  'nye',
#  'regionene..............................63˜6˜Styringsutfordringer',
#  '˚i',
#  'Osloregionen',
#  'og',
#  'alternative',
#  '˚styringsmodeller.................................65˜6.1˚Styringsutfordringer',
#  '˜i',
#  'Osloregionen.......................................65˜6.1.1˚Historikk',
#  '................................................65˜6.1.2˚Styringsutfordringer',
#  'og',
#  'geografisk',
#  '˜nedslagsfelt',
#  '............................................66˜6.1.3˚Institusjoner',
#  'involvert',
#  'i',
#  'regional',
#  '˜oppgaveløsning......................................66˜6.2˚Regional',
#  'oppgaveløsning',
#  '.....................67˜6.2.1˚Regional',
#  'utvikling,',
#  '˜areal',
#  'og',
#  'transport..................................67˜6.2.2˚Helsesektoren',
#  '.......................................69˜6.2.3˚Sosialsektoren',
#  '......................................69˜6.2.4˚Videregående',
#  'opplæring',
#  '.....................69˜6.2.5˚Hovedkonklusjoner',
#  'når',
#  'det',
#  'gjelder',
#  '˜styringsutfordringer..............................69˜6.3˚Alternative',
#  'styringsmodeller',
#  '...............70˜6.3.1˚Regionmodell,',
#  'etablering',
#  'av',
#  'et',
#  '˜nytt',
#  'regionalt',
#  'forvaltningsnivå.............70˜6.3.2˚Modifisert',
#  'regionmodell',
#  '......................',
#  '71˜6.3.3˚Særorgan',
#  'for',
#  'Osloregionen.................',
#  '71˜6.3.4˚Pålagt',
#  'regionalt',
#  'plansamarbeid',
#  'med',
#  '˜hjemmel',
#  'i',
#  'plan-',
#  'og',
#  'bygningsloven',
#  '......',
#  '72˜6.3.5˚Samlet',
#  'vurdering',
#  'av',
#  'de',
#  '˜fire',
#  'alternativene...................................',
#  '73˜6.4˚Erfaringer',
#  'fra',
#  'de',
#  'nordiske',
#  'landene',
#  '....',
#  '73˜7˜Valg........................................................',
#  '75˜7.1˚Innledning',
#  '............................................',
#  '75˜7.2˚Valgordning',
#  'Œ',
#  'generelle',
#  'hensyn',
#  '........',
#  '75˜7.2.1˚Valgkretser',
#  'og',
#  'mandatfordeling',
#  '........',
#  '75˜7.2.2˚Utjevningsmandater',
#  '............................',
#  '76˜7.2.3˚Fordelingsmetoder,',
#  'sperregrenser',
#  '˜og',
#  'personvalg........................................',
#  '76˜7.3˚Valgordningen',
#  'ved',
#  'stortingsvalg',
#  '.......',
#  '76˜7.3.1˚Gjeldende',
#  'rett',
#  '.......................................',
#  '76˜7.3.2˚Vurderinger',
#  'som',
#  'ligger',
#  'til',
#  'grunn',
#  'for',
#  '˜valgordningen',
#  'ved',
#  'stortingsvalg.........',
#  '77˜7.4˚Valgordningen',
#  'ved',
#  'valg',
#  'til',
#  '˜regionalt',
#  'nivå.........................................',
#  '78˜7.4.1˚Innledning',
#  '.............................................',
#  '78˜7.4.2˚Gjeldende',
#  'rett',
#  'Œ',
#  'fylkestingsvalg..........',
#  '78˜7.4.3˚Valgkretsinndelingen',
#  'for',
#  '˜det',
#  'framtidige',
#  'folkevalgte',
#  'nivået.........',
#  '78˜7.4.4˚Utjevningsmandater',
#  '.............................',
#  '80˜7.5˚Regjeringens',
#  'vurdering',
#  '.......................',
#  '81˜7.6˚Valg',
#  'til',
#  'fylkesting',
#  'i',
#  '2007',
#  '˜Œ',
#  'valgperiode.........................................',
#  '81˜8˜Alternative',
#  'modeller',
#  'for',
#  'det',
#  '˚regionale',
#  'folkevalgte',
#  'nivået',
#  '............',
#  '82˜8.1˚Innledning',
#  '.............................................',
#  '82˜8.2˚Forsterket',
#  'fylkesmodell.......................',
#  '83˜8.3˚Mellommodell.......................................',
#  '85˜8.4˚Regionmodell',
#  '........................................',
#  '86˜8.5˚Regjeringens',
#  'samlede',
#  'vurdering........',
#  '88˜9˜Region-',
#  'og',
#  'kommuneinndelingen.90',
#  '9.1˚Innledning',
#  '.............................................',
#  '90˜9.2˚Kommune-',
#  'og',
#  'fylkesstrukturen',
#  'Œ',
#  'utvikling',
#  'og',
#  'status',
#  '.............................',
#  '90˜9.2.1˚Kommunestrukturen............................',
#  '90˜9.2.2˚Fylkesstrukturen',
#  '..................................',
#  '91˜9.3˚Framtidig',
#  'regional',
#  'inndeling...............',
#  '92˜9.3.1˚Frivillighet',
#  'er',
#  'utgangspunktet',
#  '............',
#  '93˜9.3.2˚Tidligere',
#  'benyttede',
#  'kriterier',
#  'for',
#  '˜regioninndeling',
#  '.....................................93˜9.3.3˚Forslag',
#  'til',
#  'kriterier',
#  'for',
#  '˜regioninndeling',
#  '.....................................95˜9.4˚Prosess',
#  'knyttet',
#  'til',
#  'regioninndeling',
#  '.....99˜9.4.1˚Nærmere',
#  'om',
#  'fylkesprosessen',
#  '˜(fram',
#  'til',
#  'desember',
#  '2007)....................100˜9.4.2˚Prosessen',
#  'med',
#  'å',
#  'komme',
#  'fram',
#  '˜til',
#  'en',
#  'endelig',
#  'inndeling',
#  '˜(fram',
#  'til',
#  'våren',
#  '2008)............................101˜10˜Regional',
#  'statsforvaltning',
#  '˚Œ',
#  'oppgaver',
#  'og',
#  'organisering............102˜10.1˚Hva',
#  'er',
#  'regional',
#  'stat?',
#  '...........................102˜10.2˚Utviklingen',
#  'de',
#  'senere',
#  'år',
#  '....................103˜10.3˚Hvor',
#  'ligger',
#  'de',
#  'største',
#  '˜utfordringene?',
#  '.....................................104˜10.4˚Regjeringens',
#  'vurdering......................105˜10.5˚Omorganisering',
#  'av',
#  'fylkesmannen',
#  '....107˜10.6˚Nærmere',
#  'om',
#  'fylkesmannens',
#  '˜ulike',
#  'roller',
#  'og',
#  'oppgaver......................107˜10.7˚Regjeringens',
#  'vurdering......................109˜11˜Prosessen',
#  'framover',
#  '˚og',
#  'økonomiske',
#  'og',
#  'administrative',
#  '˚konsekvenser',
#  '....................................112˜11.1˚Innledning............................................112˜11.2˚Kortsiktige',
#  'kostnader',
#  'av',
#  '˜gjennomføring',
#  'av',
#  'reformen',
#  '...............112˜11.3˚Personalmessige',
#  'konsekvenser',
#  '.......114˜11.4˚Langsiktige',
#  'administrative',
#  '˜og',
#  'økonomiske',
#  'konsekvenser...........115˜Vedlegg',
#  '1',
#  'Dagens',
#  'fylkeskommune',
#  '˜Œ',
#  'oppgaver',
#  'og',
#  'økonomi',
#  '.....................117˜2',
#  'Fakta',
#  'om',
#  'regional',
#  'statsforvaltning....121˜3',
#  'Forsøk',
#  'med',
#  '˜oppgavedifferensiering',
#  '.......................124˜4',
#  'Hovedtrekk',
#  'i',
#  'høringsmaterialet',
#  'til',
#  '˜Distriktskommisjonen',
#  'om',
#  '˜oppgavefordeling.................................127˜5',
#  'Oppgavefordeling',
#  'og',
#  'reformutvikling',
#  '˜i',
#  'de',
#  'andre',
#  'nordiske',
#  'land.....................131˜Litteraturliste',
#  '.....................................................141˜',
#  'St.meld.',
#  'nr.',
#  '12(2006Œ2007)',
#  'Regionale',
#  'fortrinn',
#  'Œ',
#  'regional',
#  'framtid',
#  'Tilråding',
#  'fra',
#  'Kommunal-',
#  'og',
#  'regionaldepartementet',
#  'av',
#  '8.',
#  'desember',
#  '2006,',
#  '˜godkjent',
#  'i',
#  'statsråd',
#  'samme',
#  'dag.˜(Regjeringen',
#  'Stoltenberg',
#  'II)˜1',
#  'Hovedinnhold',
#  'i',
#  'meldingen',
#  '1.1',
#  'Utgangspunkt',
#  'for',
#  'reformen',
#  'Et',
#  'levende',
#  'og',
#  'desentralisert',
#  'demokrati',
#  'med',
#  'bred',
#  'deltakelse',
#  'er',
#  'grfunnsutfordringene',
#  'på',
#  'en',
#  'god',
#  'måte.',
#  'Det',
#  'skal',
#  'være',
#  'tre',
#  'folkevalgte',
#  'nivå',
#  'i',
#  'Norge.',
#  'Regjeringen',
#  'vil',
#  'legge',
#  'til',
#  'rette',
#  'for',
#  'et',
#  'levende',
#  'folkestyre',
#  'med',
#  'kommuner',
#  'og',
#  'regioner',
#  'som',
#  'utnytter',
#  'lokale',
#  'og',
#  'retrinn',
#  'til',
#  'beste',
#  'for',
#  'innbyggerne,',
#  'næringslivet',
#  'og',
#  'samfunnet',
#  'for',
#  'øvrig.1',
#  'Kommunene',
#  'utgjør',
#  'fundamentet',
#  'i',
#  'det',
#  'lokale',
#  'folkestyret,',
#  'og',
#  'representerer',
#  'nærhet,',
#  'tilhørighet',
#  'munene',
#  'har',
#  'i',
#  'dag',
#  'en',
#  'omfattende',
#  'oppgaveporfølje',
#  'med',
#  'ansvar',
#  'for',
#  'store',
#  'og',
#  'viktige',
#  'oppgaver.',
#  'Etter',
#  'relig,',
#  'både',
#  'for',
#  'vårt',
#  'demokrati',
#  'og',
#  'for',
#  'å',
#  'nå',
#  'målet',
#  'om',
#  'en',
#  'effektiv',
#  'offentlig',
#  'forvaltning,',
#  'at',
#  'kommunene',
#  'også',
#  'i',
#  'framtiden',
#  'er',
#  'generalistorganer',
#  'med',
#  'en',
#  'bred',
#  'og',
#  'tung',
#  'oppgaveportefølje.',
#  'Kommunestruturen',
#  'i',
#  'Norge',
#  'er',
#  'kjennetegnet',
#  'ved',
#  'kommuner',
#  '1˚For',
#  'å',
#  'skille',
#  'mellom',
#  'nåtid',
#  'og',
#  'framtid',
#  'i',
#  'meldingsteksten',
#  'brkes',
#  'benevnelsen',
#  'region',
#  'for',
#  'å',
#  'betegne',
#  'det',
#  'rvalgte',
#  'nivået',
#  'etter',
#  'at',
#  'reformen',
#  'har',
#  'trådt',
#  'i',
#  'kraft',
#  'i',
#  '2010,',
#  'mens',
#  'benevnelsen',
#  'fylkeskommune',
#  'brukes',
#  'på',
#  'dagens',
#  'regionale',
#  'folkevalgte',
#  'nivå.',
#  'Det',
#  'er',
#  'ikke',
#  'tatt',
#  'stilling',
#  'til',
#  'hva',
#  'som',
#  'skal',
#  'bli',
#  'den',
#  'faktiske',
#  'benevnelsen',
#  'på',
#  'det',
#  'regionale',
#  'folkevalgte',
#  'nivået',
#  'etter',
#  '1.',
#  'januar',
#  '2010.',
#  'sig',
#  'små.',
#  'Sett',
#  'på',
#  'bakgrurede',
#  'har',
#  'ansvarmengde,',
#  'gjør',
#  'en',
#  'slik',
#  'kommunestrudre',
#  'aktuelt',
#  'å',
#  'legge',
#  'nye',
#  'store',
#  'oppgaver',
#  'til',
#  'kommunene.',
#  'Mange',
#  'ofgrafisk',
#  'perspektiv',
#  'mellom',
#  'landet',
#  'som',
#  'helhet',
#  'og',
#  'den',
#  'avgrensning',
#  'som',
#  'kommunene',
#  'representerer.',
#  'Dette',
#  'er',
#  'for',
#  'det',
#  'første',
#  'oppgaver',
#  'som',
#  'angår',
#  'eller',
#  'har',
#  'virkning',
#  'for',
#  'et',
#  'større',
#  'område',
#  'enn',
#  'den',
#  'enkelte',
#  'kommune,',
#  'og',
#  'som',
#  'derfor',
#  'trskridende',
#  'løsninger.',
#  'For',
#  'det',
#  'andrver',
#  'som',
#  'av',
#  'hensyn',
#  'til',
#  'stordriftsfordeler',
#  'løses',
#  'best',
#  'med',
#  'et',
#  'større',
#  'befolkningsgrunnlag',
#  'enn',
#  'det',
#  'de',
#  'fleste',
#  'kommuner',
#  'har.',
#  'For',
#  'det',
#  'trver',
#  'som',
#  'krever',
#  'mer',
#  'ressurser',
#  'i',
#  'form',
#  'av',
#  'økonomi',
#  'og',
#  'spesialisert',
#  'kompetanse',
#  'enn',
#  'hva',
#  'en',
#  'enkelt',
#  'kommune',
#  'har',
#  'til',
#  'rådighet.',
#  'Regjeringen',
#  'mener',
#  'det',
#  'er',
#  'behov',
#  'for',
#  'et',
#  'folkevalgt',
#  'regionalt',
#  'nivå',
#  'for',
#  'å',
#  'løse',
#  'mange',
#  'av',
#  'disse',
#  'oppgavene.',
#  'Regjeringen',
#  'mener',
#  'det',
#  'er',
#  'behov',
#  'for',
#  'å',
#  'styrke',
#  'det',
#  'repotensialet',
#  'kan',
#  'utnyttes',
#  'til',
#  'beste',
#  'for',
#  'en',
#  'helhetlig',
#  'og',
#  'villet',
#  'utvikling',
#  'i',
#  'den',
#  'enkelte',
#  'region.',
#  'Regionene',
#  'må',
#  'gis',
#  'virkemidler',
#  'og',
#  'beslutningsmyndighet',
#  'slik',
#  'at',
#  'de',
#  'kan',
#  'spille',
#  'en',
#  'sentral',
#  'utviklingsrtralisering',
#  'av',
#  'viktige',
#  'oppgaver',
#  'innen',
#  'samferdsel,',
#  'næring,',
#  'landbruk,',
#  'miljøvern,',
#  'planlegging,',
#  'marin',
#  '6',
#  'St.meld.',
#  'nr.',
#  '122006Œ2007',
#  'Regionale',
#  'fortrinn',
#  'Œ',
#  'regional',
#  'framtid',
#  'sektor,',
#  'forskning',
#  'og',
#  'utdanning',
#  'og',
#  'kultur',
#  'blir',
#  'der-for',
#  'viktige',
#  'virkemidler',
#  'for',
#  'å',
#  'legge',
#  'til',
#  ...]

# %% [markdown]
#  gswin32c.exe ^
#   -o repaired.pdf ^
#   -sDEVICE=pdfwrite ^
#   -dPDFSETTINGS=/prepress ^
#    corrupted.pdf
#
#
#     print(pageObj.extractText())

# %%
# !dir c:/users/larsj/Downloads/
# Out:
# Invalid switch - "users".

# %%
pdffil = "c:/users/larsj/Downloads\\forde-kommune---brev.pdf"

# %%
print(get_text_from_pdf(pdffil))
# Out:
#
#
# Postadresse:
#
# Postboks 338, 6802 Førde
#
# Telefon:
#
# 57 72 20 00
#
# Bankkonto
# : 3700 07 00720
#
# www.forde.kommune.no
#
# Besøksadresse:
#
# Hafstadvegen 42
#
# Fax:
#
# 57 82 38 76
#
# Org.nr.:
#
# NO 963923511 mva
#
# E
# -
# post:
#
# postmottak@forde.kommune.no
#
#
#
# Førde kommune
#
#
#
#
#
#
# Byggesak og arealforvaltning
#
#
#
#
#
#
#
#
#
# Sogn og Fjordane Fylkeskommune
#
# Askedalen 2
#
# 6863
#
# LEIKANGER
#
#
#
#
#
# Dykkar referanse:
#
# Sakshandsamar:
#
# Berit Holme
#
# Tlf.
# 57612716
#
# Vår referanse
# :
#
# 14/2395
# -
# 3
# -
# BHO
# -
# K54
#
# Dato:
#
# 08.04.2015
#
#
# Innspel til region
# al plan for vassforvaltning for Sogn og Fjordane vassregion
#
#
# Førde bystyre har i møte den 26.03.2015 handsama framlegg til regional plan for
# vassforvaltning for Sogn og Fjordane vassregion 2016
# -
# 2021 med tilhøyrande
# tiltaksprogram.
#
#
# Det vart gjort følgjand
# e vedtak:
#
#
#
#
# Førde kommune er positiv til arbeidet med å sikre ein felles, bærekraftig bruk av
# vassressursane på tvers av sektorar, og ønskjer å vere ein bidragsyter til å nå
# måla i vassforskrifta.
#
#
#
#
# Førde kommune støttar vassregionen sine ynskje om nye og be
# tre verkemiddel
# og prioriteringar av tema for vidare oppfølging av tiltak i planen.
#
#
#
#
# Førde kommune vil peike på trong for auka økonomiske ressursar frå statleg
# hold for å sikre innføringa av direktivet i vassforvaltninga og gjennomføring av
# aktuelle tiltak
#
# innan ulike sektorområde.
#
#
#
#
# Førde kommune meiner at dersom kostnader skal førast i tiltaksprogrammet må
# dette også gjelde for statlege sektorstyresmakter.
#
#
#
#
# Innspel til høyringsdokumentet som vedkjem vassførekomstar i Førde
# kommune:
#
#
# a.
#
# Førde kommune meiner at
#
# tiltak i første planperiode, 2015
# -
#
# 2021, bør
# konsentrerast om følgjande:
#
#
#
# Lokale forskrifter og vedtekter, med krav og vilkår
#
#
#
# Statuskartlegging og dokumentasjon
#
#
#
# Oppfølging, tilsyn og kontroll med gamle og nye utsleppsløyve
#
#
#
# Utbetring av feil og manglar
#
#
#
# Pro
# blemkartlegging og kost
# -
# nytte
# -
# analyse
#
#
#
# Tiltaks
# -
#
# og finansieringsplan for større tiltak, med informasjon, krav og
# pålegg til ansvarleg «eigar»
#
#
# Vår referanse
# :
# 14/2395
# -
# 3
# -
# BHO
# -
#
#
# 2
#
#
#
# Førde kommune meiner at problemkartlegging og kost
# -
# nytteanalyser bør skje i
# planperioden 2016
#
#
# 2021 og at frist f
# or å nå miljømål vert utsett til 2027
# (Vassforskrifta § 9) for følgjande vassførekomstar: 084
# -
# 288
# -
# R Jølstra Øyrane,
# 084
# -
# 289
# -
# R Jølstra nedre bekkefelt, 084
# -
# 132
# -
# R Angedalselva, 084
# -
#
# 104
# -
# R
# Heilevangselva, 084
# -
# 124
# -
# R Slokedalen bekkefelt, 084
# -
# 139
# -
# R Sagelva i
# Su
# ndsdalen, Rotneselva, 084
# -
# 182
# -
# R Erdøla/Løypingselva, 084
# -
#
# 245
# -
# R
# Skorpeelva, 084
# -
# 1737
# -
# L Digrenesvatnet, 084
# -
# 28494
# -
# L Bekkevatnet,
# 0281010201
# -
# 2
# -
# C Indre Førdefjorden, 084
# -
# 997
# -
# G Førde grunnvatn.
#
#
#
#
# Indre Førdefjorden er påverka av fysiske inngrep som utfylling av
#
# masser og
# endring av elveutløp og er derfor kandidat til SMVF (sterkt modifisert
# vassførekomstar) (Vassforskrifta § 5).
#
#
#
#
# Følgjande vassdrag er vurdert som dårleg/ moderat tilstand og må leggast inn i
# tiltakslista:
#
# 084
# -
# 139
# -
# R Sagelva i Sundsdalen, 084
# -
# 245
# -
# R
#
# Skorpeelva, 084
# -
# 313
# -
# R Jølstra
# sideelvar (Moskog).
#
#
#
#
# Førde kommune viser til kommunen sine framlegg til endringar i tiltakstabell, sjå
# Tiltaksprogram
# -
#
# vedlegg Førde korrigert, tekst merka med raudt.
#
#
# Saksutgreiing med vedtak og korrigert tiltaksprogram for
#
# Førde ligg ved dokumentet.
#
#
# Det ser dessverre ut til at det har falle ut ei setning i det tredje siste punktet, både i
# framlegg til vedtak og under vedtak:
#
#
#
#
# Indre Førdefjorden er påverka av fysiske inngrep som utfylling av masser og endring
# av elveutløp
#
# og er derfor kandidat til SMVF (sterkt modifisert vassførekomstar)
# (Vassforskrifta § 5).
#
# Fristen for å nå miljømål bør derfor settast til 2027
# .
#
#
# Det vert vist til
# siste avsnitt på side 5 under
# Vassførekomstar i Førde
#
# i saksutgreiinga
# :
#
# «Frist for å nå milj
# ømål innan 2021 synest å vere urealistisk sidan den framleis er uklart
# kva miljømål skal vere.
# Fristen for å nå miljømål bør derfor settast til 2027.»
#
# Dette er også lagt inn i revidert tiltakstabell for Førde i vassføreskomst Førdefjorden
# indre i kolonne f
# or miljømål anteke oppnådd.
#
#
#
#
#
# Med
# helsing
#
#
#
# Berit Holme
#
#
# arealplanleggar
#
#
#
#
# Dette brevet er elektronisk godkjent av Førde kommune om det ikkje er signert.
#
#
#
#
# Vedlegg:
#
# Innspel til regional plan for vassforvaltning for Sogn og Fjordane vassregion
#
# Tilta
# ksprogram
# -
# vedlegg Førde korrigert 29.01.15
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]

# %%
get_text_from_word()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-a77f02f24f5e> in <module>
# ----> 1 get_text_from_word()
#
# TypeError: get_text_from_word() missing 1 required positional argument: 'document'

# %%
from PyPDF2 import PdfFileReader
 
 
def text_extractor(path):
    with open(path, 'rb') as f:
        pdf = PdfFileReader(f)
 
        # get the first page
        page = pdf.getPage(1)
        print(page)
        #print('Page type: {}'.format(str(type(page))))
 
        #text = page.extractText()
        #print(text)

# %%
text_extractor("../Semantikk semesteroppgaver 2018.pdf")
