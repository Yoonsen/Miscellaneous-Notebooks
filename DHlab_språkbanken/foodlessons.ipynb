# %%
import dhlab.module_update as mu
import dhlab.nbtext as nb
mu.update('dhlab_v2', silent = True)
import pandas as pd
import dhlab_v2 as d2

# %%
d2.document_corpus(doctype = "digibok", limit = 1000)
# Out:
#                                      urn  \
# 0    URN:NBN:no-nb_digibok_2009100800057
# 1    URN:NBN:no-nb_digibok_2012091008039
# 2    URN:NBN:no-nb_digibok_2018072407082
# 3    URN:NBN:no-nb_digibok_2012070508007
# 4    URN:NBN:no-nb_digibok_2008092300025
# ..                                   ...
# 995  URN:NBN:no-nb_digibok_2015062308086
# 996  URN:NBN:no-nb_digibok_2017032448034
# 997  URN:NBN:no-nb_digibok_2015042108299
# 998  URN:NBN:no-nb_digibok_2014091008053
# 999  URN:NBN:no-nb_digibok_2011021020006
#
#                                                  title  \
# 0                       Samson katt : gammel dyrefabel
# 1    Folke- og boligtelling 1. november 1980 : Komm...
# 2                                          Kaleidoskop
# 3                           Cuba : et land i utvikling
# 4    MET 8006 : statistikk og dataanalyse : studieg...
# ..                                                 ...
# 995  Forlag, forfattere, frihet : taler, artikler o...
# ...
