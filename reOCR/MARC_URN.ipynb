# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
mu.update('mods_meta')
import mods_meta as mm
# Out:
# Updated file `D:\Documents\GitHub\Miscellaneous-Notebooks\reOCR\mods_meta.py`

# %%
import inspect

# %%
def make_corpus(author = None, title = None, subject = None, yearfrom = None, yearto = None):
    _,_,_, values = inspect.getargvalues(inspect.currentframe())
    print(values)

# %%
make_corpus()
# Out:
# {'author': None, 'title': None, 'subject': None, 'yearfrom': None, 'yearto': None}

# %%
corpus = mm.meta_natbib(yearfrom = 1880, yearto=1960, marctuples=[(100, 1, ' ', 'a', '%Hamsun%')])

# %%
nb.frame(mm.metadata([u[1] for u in corpus]))
# Out:
#                    100-1- -a                        245-1-0-a  \
# 2007031901003   Hamsun, Knut                      Paa turne :
# 2007061301025  Hamsun, Marie                      Bygdebarn :
# 2008051600001   Hamsun, Knut        Knut Hamsun som han var :
# 2008051604045   Hamsun, Knut                        Mysterier
# 2008082710002   Hamsun, Knut                            Pan :
# 2008091603014   Hamsun, Knut                              NaN
# 2008091603015   Hamsun, Knut                              NaN
# 2009051813003   Hamsun, Knut                  Stridende Liv :
# 2011011106027   Hamsun, Knut                   Samlede Verker
# 2011011706058   Hamsun, Knut                   Samlede Verker
# 2011021406060   Hamsun, Knut                   Samlede Verker
# 2011021506002   Hamsun, Knut                   Samlede Verker
# 2011111108031   Hamsun, Knut                         Victoria
# 2013012108029   Hamsun, Knut                   Samlede Verker
# ...
