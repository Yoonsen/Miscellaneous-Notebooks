# %% [markdown]
# # NOU-er
#
# For å undersøke en liste NOU-er. Listen består av ca 1300 NOU-rapporter.

# %% [markdown]
# Starter med å importere nødvendige moduler

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
mu.update('collocations', overwrite=True)
import collocations as col
import dhlab.graph_networkx_louvain as gnl
from random import sample
mu.css()
# Out:
# Updated file `C:\Users\larsj\Documents\GitHub\Miscellaneous-Notebooks\NOU\collocations.py`
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# ## NOU
#
# De har en egen liste med URN-er. Filen må ligge i samme mappe som notebooken.

# %%
NOU = nb.pure_urn(open('nou_urn.txt').read())

# %%
len(NOU)
# Out:
# 1384

# %%
nb.frame(nb.metadata(NOU), "urn forfatter år tittel subtittel forlag x x lang trans".split())
# Out:
#                 urn forfatter    år  \
# 0     2011061406050            1979
# 1     2013080806034            1981
# 2     2011092208093            2008
# 3     2011061406083            1979
# 4     2014020408088            1975
# ...             ...       ...   ...
# 1369  2008032800044            1996
# 1370  2008011004071            1993
# 1371  2012071006100            1989
# 1372  2007070601051            1983
# 1373  2011080106056            2004
#
#                                                  tittel  \
# 0        Sjømannsskatt for mannskap på utenlandske skip
# 1     Samordning av minstelottsordningen og arbeidsl...
# 2                                        Barn og straff
# 3      Om utbyggingen av lønns- og inntektsstatistikken
# 4                                            Kartografi
# ...                                                 ...
# 1369                Mer effektiv inndragning av vinning
# 1370                     Nytt fundament for friomsorgen
# 1371                         Databaser til distriktene?
# 1372                  Regulering av regnskapsføreryrket
# 1373                Regional statsstøtte og EØS-reglane
#
#                                               subtittel  \
# 0     delutredning 1 fra utvalget til vurdering av s...
# 1
# 2     utviklingsstøtte og kontroll : utredning fra u...
# 3     rapport nr. 1, 1979 fra Det tekniske beregning...
# 4
# ...                                                 ...
# 1369  utredning fra Inndragningsutvalget oppnevnt av...
# 1370  utredning fra et utvalg oppnevnt av Justis- og...
# 1371  om desentralisering av offentlige dataregistre...
# 1372
# 1373  utgreiing frå eit utval nedsett ved kronprinsr...
#
#                                                  forlag           x  \
# 0                                  Universitetsforlaget  notfiction
# 1                                  Universitetsforlaget  notfiction
# 2     Departementenes servicesenter, Informasjonsfor...  notfiction
# 3                                  Universitetsforlaget     unknown
# 4                                  Universitetsforlaget  notfiction
# ...                                                 ...         ...
# 1369  Statens forvaltningstjeneste, Seksjon statens ...  notfiction
# 1370  Statens forvaltningstjeneste, Seksjon statens ...  notfiction
# 1371    Forvaltningstjenestene, Statens trykningskontor  notfiction
# 1372                               Universitetsforlaget  notfiction
# 1373  Statens forvaltningstjeneste, Informasjonsforv...  notfiction
#
#                                      x lang trans
# 0     dfe5e8a57cc6aa276de58c2bcc6052c8  nob
# 1     6e3e8a2eaa1cb4ff66d1eee1c1094255  nob
# 2     650c7b26c0d989c7c3786dda6285e544  nob
# 3     31983d2e6b6c2744ea3a6d62ddac2349  nob
# 4     98dd5d201e051e6f658786a94c8d0f39  nob
# ...                                ...  ...   ...
# 1369  f566b9fe431b5de64bcccaf14bc8037a  nob
# 1370  35eec42666dad4a9c60b405b9de18c2c  nob
# 1371  65a3ad50fca5e1125b8a99c1882c7bbd  nob
# 1372  807de60ee09bc70c307605e1bde4ca35  nob
# 1373  f7be28c105cdb0cf873459d738f54cd7  mul
#
# [1374 rows x 10 columns]

# %% [markdown]
# ## Totalen fra NB
#
# Skal benyttes som referanse for å beregne relevante ord

# %%
tot = nb.frame(nb.totals(50000), 'tot')

# %% [markdown]
# ## Sjekk en konkordans

# %%
nb.urn_concordance(word='arbeid', urns=nb.refine_book_urn(words=['arbeid'], urns=NOU))
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007121004047?searchText=arbeid' target='_blank' style='text-decoration:none'>Lov om husleieavtaler, , 1993</a>
#                 </td>
#                 <td>han deltok likevel i utvalgets</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>fram til sin død i</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007121004047?searchText=arbeid' target='_blank' style='text-decoration:none'>Lov om husleieavtaler, , 1993</a>
#                 </td>
#                 <td>Grini la ned et omfattende</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>for utvalget og har satt</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007121004047?searchText=arbeid' target='_blank' style='text-decoration:none'>Lov om husleieavtaler, , 1993</a>
#                 </td>
#                 <td>ble fra begynnelsen av utvalgets</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>etablert en ordning hvor formannen</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007121004047?searchText=arbeid' target='_blank' style='text-decoration:none'>Lov om husleieavtaler, , 1993</a>
#                 </td>
#                 <td>I sitt</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>har utvalget lagt vekt på</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007121004047?searchText=arbeid' target='_blank' style='text-decoration:none'>Lov om husleieavtaler, , 1993</a>
#                 </td>
#                 <td>kan være at veksling mellom</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>og utdannelse og mellom forskjellige</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007120404022?searchText=arbeid' target='_blank' style='text-decoration:none'>Sykelønnsordningen, , 1990</a>
#                 </td>
#                 <td>1.3 Utvalgets</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>8</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007120404022?searchText=arbeid' target='_blank' style='text-decoration:none'>Sykelønnsordningen, , 1990</a>
#                 </td>
#                 <td>vært eller er ute av</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>( inaktive ) 23</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007120404022?searchText=arbeid' target='_blank' style='text-decoration:none'>Sykelønnsordningen, , 1990</a>
#                 </td>
#                 <td>grepet direkte inn i utvalgets</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>, idet det er en</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007120404022?searchText=arbeid' target='_blank' style='text-decoration:none'>Sykelønnsordningen, , 1990</a>
#                 </td>
#                 <td>få den sykmeldte tilbake i</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>( bedriftsintern attføring). Når det</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007120404022?searchText=arbeid' target='_blank' style='text-decoration:none'>Sykelønnsordningen, , 1990</a>
#                 </td>
#                 <td>personer som ikke har noe</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>å gå tilbake til etterlyser</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007082300012?searchText=arbeid' target='_blank' style='text-decoration:none'>Lederskap og organisasjonsformer i Forsvaret, , 1991</a>
#                 </td>
#                 <td>1.4 Koordineringsrådets</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>10 5.3 . Vurdering av</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007082300012?searchText=arbeid' target='_blank' style='text-decoration:none'>Lederskap og organisasjonsformer i Forsvaret, , 1991</a>
#                 </td>
#                 <td>2.3 . Bakgrunn for rådets</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>- 6. Lederskap og organisasjon</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007082300012?searchText=arbeid' target='_blank' style='text-decoration:none'>Lederskap og organisasjonsformer i Forsvaret, , 1991</a>
#                 </td>
#                 <td>2.4 . Forsvarets</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>med lederskaps- 6.1 . Innledning</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007082300012?searchText=arbeid' target='_blank' style='text-decoration:none'>Lederskap og organisasjonsformer i Forsvaret, , 1991</a>
#                 </td>
#                 <td>None</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>- Referanseramme 22 7.3 .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007082300012?searchText=arbeid' target='_blank' style='text-decoration:none'>Lederskap og organisasjonsformer i Forsvaret, , 1991</a>
#                 </td>
#                 <td>4. Forsvarets</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>med lederskaps- og</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009022004068?searchText=arbeid' target='_blank' style='text-decoration:none'>Om grunnlaget for inntektsoppgjørene 2003, , 2003</a>
#                 </td>
#                 <td>inntekten inkluderer også avlønning for</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>utført av eierne eller deres</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009022004068?searchText=arbeid' target='_blank' style='text-decoration:none'>Om grunnlaget for inntektsoppgjørene 2003, , 2003</a>
#                 </td>
#                 <td>næringsvirksomhet, som inkluderer avlønning for</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>utført av eierne eller deres</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009022004068?searchText=arbeid' target='_blank' style='text-decoration:none'>Om grunnlaget for inntektsoppgjørene 2003, , 2003</a>
#                 </td>
#                 <td>/ eller avtale om ekstraordinært</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>for å redusere ventelister og</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009022004068?searchText=arbeid' target='_blank' style='text-decoration:none'>Om grunnlaget for inntektsoppgjørene 2003, , 2003</a>
#                 </td>
#                 <td>lønn og honorarer m.m for</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>som ikke er utført som</td>
#             </tr>
# <tr>
#                 <td>
#                     <a

# %% [markdown]
# # Kollokasjoner
#
# På grunn av lengden på URN-listen velger vi her en delmengde av URN-ene.

# %%
arbeid = col.sample_coll(word='arbeiderne', urns=NOU)

# %%
arbeid
# Out:
#                         0
# i                      18
# .                      17
# av                     14
# ,                      13
# og                     11
# ...                    ..
# forsøk                  1
# fortolkes               1
# frossenfiskindustrien   1
# fråvær                  1
# übetalte                1
#
# [226 rows x 1 columns]

# %% [markdown]
# ## Relevant ord
#
# Legges i variabelen diff (differanse)

# %%
diff = nb.frame(arbeid[0]/tot.tot)

# %%
nb.frame_sort(diff)[:10]
# Out:
#                              0
# pliktige              0.000042
# Arbeidsgiverforening  0.000037
# Utstyret              0.000036
# beskyttelsen          0.000035
# fortolkes             0.000030
# oppsummeres           0.000026
# anvist                0.000023
# prosentvise           0.000021
# utsetter              0.000019
# arbeidsgiverne        0.000019

# %%
nb.cloud(nb.frame_sort(diff)[:50])
