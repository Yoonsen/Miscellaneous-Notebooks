# %%
import dhlab.nbtext as nb

# %%
nb.totals(50000)
# Out:
# {'.': 1265723110,
#  ',': 1105303412,
#  'og': 543432056,
#  'i': 460246057,
#  'det': 273411583,
#  'som': 265144740,
#  'til': 254500136,
#  'er': 248764786,
#  'av': 235180661,
#  'en': 231631623,
#  'på': 205990369,
#  'for': 202452659,
#  'at': 199527660,
#  '-': 195716474,
#  'å': 184201667,
#  'med': 182427175,
#  ')': 172258528,
#  'var': 153392365,
#  '?': 151860120,
#  'den': 151216998,
#  '(': 149848981,
#  'de': 140087564,
#  'ikke': 137898651,
#  ':': 121576250,
#  'han': 115410512,
#  '«': 110767054,
#  '»': 109061643,
#  'har': 106345926,
#  'om': 105027818,
#  'et': 101265956,
#  'Det': 83547318,
#  'seg': 81416487,
#  'jeg': 78933399,
#  'kan': 73927079,
#  'hadde': 71847548,
#  'fra': 69117414,
#  'the': 67321844,
#  ';': 66435795,
#  'I': 65219798,
#  'så': 64511455,
#  '/': 63743544,
#  '—': 62755431,
#  'eller': 58977088,
#  '"': 57203817,
#  'vi': 55224841,
#  '1': 55206662,
#  'men': 54226438,
#  'ved': 53804034,
#  "'": 52892026,
#  'du': 51433633,
# ...
