# %%
import dhlab.nbtext as nb
import json

# %%
def interesting_urns(df, limit):
    jaccard = dict((df > 0).astype(int).sum(axis=1))
    res = []
    for urn in jaccard:
        if jaccard[urn] >= limit:
            res.append(urn)
    return res

def get_para(para_list):
    import ast
    paras = []
    for p in para_list:
        paras.append(ast.literal_eval(p))
    urns = [x[0] for x in paras]
    paradict = {u:[x[1] for x in paras if x[0] == u] for u in urns}
    paragraphs = dict()
    for u in paradict:
        paragraphs[u] = get_paragraphs(u, paradict[u])
    return paragraphs

def interesting_paragraphs(urns, wordbag, limit):
    interest = dict()
    for u in urns:
        paragraphs = nb.wordbag_eval_para(wordbag, [u])
        for x in paragraphs:
            if len(paragraphs[x]) >= limit:
                #rint(paragraphs[x])
                interest[x] = paragraphs[x]
    return interest

import requests
def get_paragraphs(urn, paras):
    """Return paragraphs for urn"""
    param = dict()
    param['paragraphs'] = paras
    param['urn'] = urn
    r = requests.get("https://api.nb.no/ngram/paragraphs", json=param)
    return r.json()

# %%
def major_urns(df):
    res = []
    means = df.mean()
    for urn in df.index:
        good_urn = True
        for theme in means.index:
            good_urn &= df[theme][urn] > means[theme]
        if good_urn:
            res.append(urn)
    return res

# %%
#temaene ble lagret med annen notebook - Heidis definisjoner_0_november
with open('heidis_temadefinisjoner_november.json') as f:
    first = json.load(f)

# %% [markdown]
# import json
#
# json.dump(first, open('heidis_temadefinisjoner.json', 'w', encoding='utf-8'))

# %%
list_of_themes = list(first.keys())
list_of_themes
# Out:
# ['“Kvindens Sandhed” (Minst 3 av 4).',
#  '“Kvinde, lesning og religion” (Minst 4 av 5)',
#  '“Forfatterinder og religion”  (Minst 3 av 4)',
#  '“Kvindens posisjon” (Minst 4 av 6)',
#  '“Kvinden og offentlig hygiene” (Minst 4 av 6)']

# %% [markdown]
# Her er URNene det skal søkes i

# %%
urns = nb.book_urn(period=(1830, 1880), limit=12000)

len(urns)
# Out:
# 6803

# %%
round(90*7/100)
# Out:
# 6

# %% [markdown]
# ## Evaluering av bøker
#
#
# Her er datarammen for klassifikasjon av bøker, med frekvens av hvert tema.

# %%
# sett inn et temanavn eller bare bruk indeks inn i temalisten, som her - 0 er første element 1 er andre osv.
books = dict()
for i in range(len(list_of_themes)):
    books[i] = nb.wordbag_eval(first[list_of_themes[i]], urns)

# %%
books[0].head(5)
# Out:
#                Frihed_  Kvinde_  Legeme_  Sandhed_   snitt
# 2014062048059    699.0    676.0    597.0     483.0  613.75
# 2009091403021    342.0   1225.0    365.0     424.0  589.00
# 2008082512001    376.0   1085.0    484.0     400.0  586.25
# 2008100603020    419.0    433.0    451.0     954.0  564.25
# 2008111303008    298.0     95.0    785.0     704.0  470.50

# %%
books[1][books[1]['Kvindeforening_'] > 0].sort_values(by='Kvindeforening_', ascending=False).head(30)
# Out:
#                Kvinde_  Kvindeforening_  Litteratur_  Læserinde_  Religion_  \
# 2013042608147     60.0             16.0          0.0         4.0       18.0
# 2013042608043     58.0              8.0          0.0         1.0       31.0
# 2009092203020    100.0              7.0          2.0         4.0       65.0
# 2013121624012      7.0              4.0          0.0         0.0       12.0
# 2007062210023    422.0              3.0         41.0         5.0      278.0
# 2016050948004     90.0              3.0          5.0         1.0       50.0
# 2014110428001    232.0              2.0         10.0         2.0      220.0
# 2014030408090    501.0              2.0          2.0         5.0       25.0
# 2014021807020    126.0              2.0          6.0         0.0        2.0
# 2012072708119      3.0              2.0          0.0         0.0       10.0
# 2009070201090    172.0              2.0         10.0         0.0        3.0
# 2015012008069     23.0              1.0         14.0         0.0       19.0
# 2011091612003     28.0              1.0          0.0         0.0       22.0
# 2006112201041     31.0              1.0          1.0         2.0       40.0
# 2012073108080     11.0              1.0          4.0         0.0       34.0
# 2009111812007      6.0              1.0          3.0         0.0        0.0
# 2014121208063      7.0              1.0          0.0         0.0        2.0
# 2008061110001      4.0              1.0          1.0         0.0        1.0
# 2014082608059      4.0              1.0          0.0         0.0        0.0
# 2013073108045     38.0              1.0          2.0         1.0       18.0
# 2009092212003    124.0              1.0          3.0         0.0        2.0
# 2006112200043     81.0              1.0          3.0         0.0        0.0
# 2010020412001    153.0              1.0          1.0         4.0        8.0
# 2016031548121     35.0              1.0          0.0         0.0      180.0
# 2012052204013     23.0              1.0          6.0         1.0      214.0
# 2012070608259     99.0              1.0          3.0         0.0      144.0
# 2006112101023    104.0              1.0          9.0         2.0      147.0
# 2010061506023     60.0              1.0          9.0         6.0      256.0
# 2007101812001    316.0              1.0          9.0         0.0        6.0
# 2008093012001    355.0              1.0         17.0         3.0       43.0
#
#                snitt
# 2013042608147   19.6
# 2013042608043   19.6
# 2009092203020   35.6
# 2013121624012    4.6
# 2007062210023  149.8
# 2016050948004   29.8
# 2014110428001   93.2
# 2014030408090  107.0
# 2014021807020   27.2
# 2012072708119    3.0
# 2009070201090   37.4
# 2015012008069   11.4
# 2011091612003   10.2
# 2006112201041   15.0
# 2012073108080   10.0
# 2009111812007    2.0
# 2014121208063    2.0
# 2008061110001    1.4
# 2014082608059    1.0
# 2013073108045   12.0
# 2009092212003   26.0
# 2006112200043   17.0
# 2010020412001   33.4
# 2016031548121   43.2
# 2012052204013   49.0
# 2012070608259   49.4
# 2006112101023   52.6
# 2010061506023   66.4
# 2007101812001   66.4
# 2008093012001   83.8

# %%
books[2][books[2]['Forfatterinde_'] > 0].sort_values(by='Forfatterinde_', ascending=False).head(30)
# Out:
#                Forfatterinde_  Kvinde_  Litteratur_  Religion_   snitt
# 2009073012002            34.0    300.0         24.0        2.0   90.00
# 2012050424001            32.0    123.0         69.0       12.0   59.00
# 2015110908267            25.0     15.0        133.0        3.0   44.00
# 2014112108104            21.0    375.0        293.0      163.0  213.00
# 2008110603030            20.0    293.0        137.0       13.0  115.75
# 2011012406002            20.0     99.0        657.0      102.0  219.50
# 2009072112002            15.0    363.0         97.0        8.0  120.75
# 2008100803022            14.0    312.0          8.0       84.0  104.50
# 2016063008035            14.0    600.0         13.0      104.0  182.75
# 2012041724020            14.0     34.0         34.0       84.0   41.50
# 2013100708166            13.0    106.0          9.0        3.0   32.75
# 2015052748022            12.0    402.0        226.0      273.0  228.25
# 2009072900042            12.0    775.0         38.0        9.0  208.50
# 2014121208055            12.0    183.0         11.0        2.0   52.00
# 2015010648110            12.0    343.0        153.0      166.0  168.50
# 2008112403029            11.0    249.0          4.0      139.0  100.75
# 2009090903009       42.0      46.0   51.500000
# 2009070700046       50.0       8.0   39.333333
# 2009082503001       14.0      11.0   31.000000
# 2006111500059      148.0       7.0   73.666667
# 2009100912002       16.0      22.0   32.166667
# 2009070700080       31.0       0.0   17.166667
# 2016111429001        5.0       2.0   59.833333
# 2014031808070       49.0      15.0   36.333333

# %%
theme_eval[theme_eval.Kvindeforening_ > 0].sort_values(by='Kvindeforening_')
# Out:
#                Kvinde_  Kvindeforening_  Litteratur_  Læserinde_  Religion_  \
# 2013100308023      0.0              1.0          0.0         0.0        2.0
# 2006112200043     81.0              1.0          3.0         0.0        0.0
# 2015012008069     23.0              1.0         14.0         0.0       19.0
# 2011091612003     28.0              1.0          0.0         0.0       22.0
# 2009092212003    124.0              1.0          3.0         0.0        2.0
# 2014082608059      4.0              1.0          0.0         0.0        0.0
# 2012073108080     11.0              1.0          4.0         0.0       34.0
# 2010020412001    153.0              1.0          1.0         4.0        8.0
# 2009111812007      6.0              1.0          3.0         0.0        0.0
# 2006112201041     31.0              1.0          1.0         2.0       40.0
# 2016031548121     35.0              1.0          0.0         0.0      180.0
# 2012070608259     99.0              1.0          3.0         0.0      144.0
# 2006112101023    104.0              1.0          9.0         2.0      147.0
# 2010061506023     60.0              1.0          9.0         6.0      256.0
# 2007101812001    316.0              1.0          9.0         0.0        6.0
# 2008093012001    355.0              1.0         17.0         3.0       43.0
# 2014121208063      7.0              1.0          0.0         0.0        2.0
# 2006112201009    168.0              1.0          6.0         8.0      348.0
# 2008061110001      4.0              1.0          1.0         0.0        1.0
# 2012052204013     23.0              1.0          6.0         1.0      214.0
# 2013073108045     38.0              1.0          2.0         1.0       18.0
# 2012072708119      3.0              2.0          0.0         0.0       10.0
# 2014021807020    126.0              2.0          6.0         0.0        2.0
# 2009070201090    172.0              2.0         10.0         0.0        3.0
# 2014110428001    232.0              2.0         10.0         2.0      220.0
# 2014030408090    501.0              2.0          2.0         5.0       25.0
# 2016050948004     90.0              3.0          5.0         1.0       50.0
# 2007062210023    422.0              3.0         41.0         5.0      278.0
# 2013121624012      7.0              4.0          0.0         0.0       12.0
# 2009092203020    100.0              7.0          2.0         4.0       65.0
# 2013042608043     58.0              8.0          0.0         1.0       31.0
# 2013042608147     60.0             16.0          0.0         4.0       18.0
#
#                snitt
# 2013100308023    0.6
# 2006112200043   17.0
# 2015012008069   11.4
# 2011091612003   10.2
# 2009092212003   26.0
# 2014082608059    1.0
# 2012073108080   10.0
# 2010020412001   33.4
# 2009111812007    2.0
# 2006112201041   15.0
# 2016031548121   43.2
# 2012070608259   49.4
# 2006112101023   52.6
# 2010061506023   66.4
# 2007101812001   66.4
# 2008093012001   83.8
# 2014121208063    2.0
# 2006112201009  106.2
# 2008061110001    1.4
# 2012052204013   49.0
# 2013073108045   12.0
# 2012072708119    3.0
# 2014021807020   27.2
# 2009070201090   37.4
# 2014110428001   93.2
# 2014030408090  107.0
# 2016050948004   29.8
# 2007062210023  149.8
# 2013121624012    4.6
# 2009092203020   35.6
# 2013042608043   19.6
# 2013042608147   19.6

# %% [markdown]
# ### Hva er gjennomsnittet for temaene?
#
# Gjennomsnittet tas over alle bøkene.

# %%
theme_eval.mean()
# Out:
# Frihed_     23.937969
# Kvinde_     45.470735
# Legeme_     22.421878
# Sandhed_    25.786893
# snitt       29.404369
# dtype: float64

# %% [markdown]
# # Se på effekten av `major_urns`
#
# Den plukker ut de URN-ene som har best sjanse for treff.

# %%
sorted_urns = theme_eval.loc[major_urns(theme_eval)]

# %%
sorted_urns.head(20).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_5e417008_096c_11ea_b86a_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row0_col1 {
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row0_col2 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row0_col3 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row1_col0 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row1_col2 {
#             background-color:  #9ebad9;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row1_col3 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row1_col4 {
#             background-color:  #045585;
#             color:  #f1f1f1;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row2_col0 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row2_col1 {
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row2_col2 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row2_col3 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row2_col4 {
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row3_col0 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row3_col1 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row3_col2 {
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row3_col4 {
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row4_col0 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row4_col1 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row4_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row4_col3 {
#             background-color:  #2d8abd;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row4_col4 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row5_col0 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row5_col1 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row5_col2 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row5_col3 {
#             background-color:  #c8cde4;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row5_col4 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row6_col0 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row6_col1 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row6_col2 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row6_col3 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row6_col4 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row7_col0 {
#             background-color:  #4697c4;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row7_col1 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row7_col2 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row7_col3 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row7_col4 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row8_col0 {
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row8_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row8_col2 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row8_col3 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row8_col4 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row9_col0 {
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row9_col2 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row9_col3 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row9_col4 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row10_col0 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row10_col1 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row10_col2 {
#             background-color:  #71a8ce;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row10_col3 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row10_col4 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row11_col0 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row11_col1 {
#             background-color:  #045483;
#             color:  #f1f1f1;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row11_col2 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row11_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_5e417008_096c_11ea_b86a_000acd2bfab2row11_col4 {
#             background-color:  #e7e3f0;
#             color:  #0

# %%
sorted_urns.mean()
# Out:
# Frihed_     106.886207
# Kvinde_     198.120690
# Legeme_      96.144828
# Sandhed_    130.508621
# snitt       132.915086
# dtype: float64

# %% [markdown]
# # Hovedloop - generer avsnitt

# %%
import re
first.keys()
limit = dict()
for k in first.keys():
    m = re.findall("[0-9]", k)
    limit[k] = m[0]

# %%
limit
# Out:
# {'“Kvindens Sandhed” (Minst 3 av 4).': '3',
#  '“Kvinde, lesning og religion” (Minst 4 av 5)': '4',
#  '“Forfatterinder og religion”  (Minst 3 av 4)': '3',
#  '“Kvindens posisjon” (Minst 4 av 6)': '4',
#  '“Kvinden og offentlig hygiene” (Minst 4 av 6)': '4'}

# %%
for theme in first:
    theme_eval = nb.wordbag_eval(first[theme], urns)
    sorted_urns = theme_eval.loc[major_urns(theme_eval)]
    print(theme,'antall urner', len(sorted_urns), '\n\n')
    filename = "".join([c for c in theme if c.isalpha() or c.isdigit() or c==' ']).rstrip() + '.json'
    theme_dict = dict()
    books = 0
    for urn in nb.pure_urn(list(sorted_urns.index)):
        books += 1
        try:
            paras = interesting_paragraphs( [urn], first[theme], limit[theme])
            if len(paras) > 0:
                print(', '.join([str(x) for x in nb.metadata(urn)[0]]), len(paras))
            for w in paras:
                theme_dict[w] = paras[w]
        except:
            True
            #print('problemer med:',  ', '.join([str(x) for x in nb.metadata(urn)[0]]))
        if books % 100 == 0:
            print("prosessert", books, 'bøker', "\n")
    print('\n')      
    json.dump(theme_dict, open(filename, 'w', encoding='utf-8'))
# Out:
# “Kvindens Sandhed” (Minst 3 av 4). antall urner 580
#
#
# prosessert 100 bøker
#
# prosessert 200 bøker
#
# prosessert 300 bøker
#
# prosessert 400 bøker
#
# prosessert 500 bøker
#
#
#
# “Kvinde, lesning og religion” (Minst 4 av 5) antall urner 5
#
#
#
#
# “Forfatterinder og religion”  (Minst 3 av 4) antall urner 78
#
#
#
#
# “Kvindens posisjon” (Minst 4 av 6) antall urner 42
#
#
#
#
# “Kvinden og offentlig hygiene” (Minst 4 av 6) antall urner 174
#
#
# prosessert 100 bøker
