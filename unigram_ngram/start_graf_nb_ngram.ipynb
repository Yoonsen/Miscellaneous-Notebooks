# %%
import dhlab.nbtext as nb
import matplotlib.pyplot as plt
#plt.rcParams.update({'font.size': 24})
import json

# %%
nb.nb_ngram("Sigrid Undset, Knut Hamsun, Camilla Collett, Amalie Skram", corpus='bok', years = (1800, 2020)).sort_index().rolling(window=5).mean().plot(lw=5, figsize=(15,8))

# %%
sk = nb.get_ngram("Sigrid Undset, Knut Hamsun, Camilla Collett, Amalie Skram", corpus = 'bok')

# %%
json.dump(sk, open('start_kurve.json', 'w', encoding='utf-8'))
