# %% [markdown]
# # Start

# %%
from dhlab.module_update import update, css, code_toggle, printmd
import dhlab.nbtext as nb
import dhlab.graph_networkx_louvain as gnl
import networkx as nx
from dhlab.graph_networkx_louvain import cutdown, make_collocation_graph
from collections import Counter
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter("ignore")

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Merriweather|Shippori+Mincho|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Shippori+Mincho';
# 	font-size:1.1em;
# 	color: DarkSlateGray;
# }
#
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
#
#
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
code_toggle()
# Out:
# <div>
#                 <style>
#                  .mybutton {
#                     background-color: lightgrey;
#                     border: none;
#                     color: white;
#                     padding: 10px 16px;
#                     text-align: center;
#                     text-decoration: none;
#                     display: inline-block;
#                     font-size: 16px;
#                     margin: 4px 2px;
#                     cursor: pointer;
#                 }
#             </style>
#             <script>
#                 code_show=true;
#                 function code_toggle() {
#                  if (code_show){
#                  $('div.input').hide();
#                  } else {
#                  $('div.input').show();
#                  }
#                  code_show = !code_show
#                 }
#                 $( document ).ready(code_toggle);
#             </script>
#             <form  action="javascript:code_toggle()">
#                 <input class='mybutton' type="submit" value="Klikk for å vise/skjule kodeceller">
#             </form>
#         </div>

# %%
def plotfig(a_plot, font_size = 18, legend = 18, loc = 1, title_size = 20):
    #fsize = plt.rcParams["font.size"
    plt.rcParams["font.size"] = font_size
    ax = a_plot
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["bottom"].set_color("grey")
    ax.spines["left"].set_color("grey")
    ax.spines["bottom"].set_linewidth(1)
    ax.spines["left"].set_linewidth(1)
    ax.labelsize = font_size
    ax.titlesize = title_size
    plt.legend(loc = loc, prop={'size': legend})

    #plt.rcParams["font.size"] = fsize
    return

# %%
def show_cliques(G):
    C = gnl.make_cliques_from_graph(G.to_undirected())
    cliques = [(t, ', '.join(C[1][t])) for t in C[1]]
    cliques.sort(key=lambda x: x[0][1])
    for x, y in cliques:
        print(x, y)
        print()

# %%
gnl.show_cliques??

# %% [markdown]
# # Adgang til tekster

# %% [markdown]
# ## Trendlinjer

# %% [markdown]
# ## Stedsnavn

# %%
plotfig(
    nb.nb_ngram(
        "Latvia, Litauen, Estland", 
        corpus='avis', 
        years=(1920, 2010), 
        smooth=1).sort_index().rolling(window=5).mean().plot(figsize=(15,8), lw=4, alpha=0.8), 
    legend=18)

# %% [markdown]
# ## Tyskland, England, USA, Russland

# %%
plotfig(
    nb.nb_ngram(
        "Tyskland, England, USA, Russland", 
         years=(1920, 2010), 
         smooth=1
    ).rolling(window=5).mean().plot(figsize=(15,8), lw=3))

# %% [markdown]
# ## USA, Amerika

# %%
sample1 = nb.nb_ngram(" USA, Amerika", years=(1860, 2010), smooth=1).sort_index()
plotfig(sample1.rolling(window=5).mean().plot(figsize=(15,8), lw=3), loc = 2, font_size=18)

# %% [markdown]
# ## Rusland, Russland

# %%
sample2 = nb.nb_ngram("Russland, Rusland", years=(1860, 2010), smooth=1).sort_index()
plotfig(sample2.rolling(window=5).mean().plot(figsize=(15,8), lw=3))

# %% [markdown]
# # Ordmodeller
#
# Vi tenker på at ord står i relasjoner til hverandre, tilhøre samme kategori, være semantisk like og andre ting.

# %% [markdown]
# ## Os

# %%
G = nb.make_graph('Os', cutoff = 12)

# %%
gnl.show_graph(G, spread = 1.9, fontsize=12)

# %% [markdown]
# ## Clustre (et stedsnavn kan stå bare i ett av clustrene)

# %%
gnl.show_community(G)
# Out:
# 1 Omegn, Oppdal, Røros, Brekken, Nord-Østerdal, Holtålen, Tynset, Tydal, Ålen, Alen
#
# 2 Vingelen, Fane, Midtun, Dalsbygda, Fusaposten, Fyllingsdalen, Tolga, Os
#
# 3 Sollia, Alvdal, Folldal, Dovre, Stor-Elvdal, Rendalen, Engerdal
#
# 4 Øygarden, Bergen, Mongstad, Askøy, Sotra
#
# 5 Rakkestad, hjv, Degernes
#
# 6 Fana, Ytrebygda, Åsane, Fyllingen, Laksevåg, Gneist
#
# 7 Skjørsand, Kvinnherad, Voss, Vaksdal, Strandvik, Tysnes, Austevoll, Fuse, Fusa, Kvam, Samnanger
# True

# %% [markdown]
# ## Klikker (navnet kan stå i flere)

# %%
show_cliques(G)
# Out:
# (3, 1) Kvinnherad, Vaksdal, Fuse, Fusa, Kvam, Samnanger, Os
#
# (4, 1) Folldal, Røros, Holtålen, Tynset, Tolga, Os
#
# (3, 2) Alvdal, Oppdal, Folldal, Røros, Rendalen, Holtålen, Tynset, Tydal, Tolga, Ålen, Engerdal, Os
#
# (3, 3) Fana, Bergen, Ytrebygda, Åsane, Sotra, Os

# %% [markdown]
# ## Generelle steder

# %%
G_vanlig = nb.make_graph('Stuen, stuen', cutoff = 20)

# %%
gnl.show_graph(G_vanlig, spread = 1.4, fontsize=12)

# %% [markdown]
# ## Clustre

# %%
gnl.show_community(G_vanlig)
# Out:
# 1 peisovn, vedovn, spiseplass, karnapp, furugulv, Peis, pels, stukkatur, vedkamin, kamin, varmepumpe, pipelop, utgang, peis, parafinovn, utg., kjøkkenløsning, tregulv, kjokkenlosning, ovn, gasspeis, sovealkove, pipeløp
#
# 2 sjøutsikt, garasje, panoramautsikt, hage, heis, fjordutsikt, garasjeplass, Heis, carport, utsikt, takterrasse, terrasse, balkong, veranda, boder, flott
#
# 3 spisestue, kjøkken, stue, bod, alkove, soverom, oppholdsrom, våtrom, bad
#
# 4 parkett, gulvbelegg, fliser, vegger, belegg, laminat, flis, heltre, vinylbelegg, vinyl
#
# 5 nyter, stua, huset, torn, kald, restauranten, verandaen, terrassen, stuen, hagen, balkongen, kjøkkenet, kjokkenet, Stuen, haven, soverommet, eventuelt, tom, badet, spisestuen, nyte
# True

# %% [markdown]
# ## Klikker

# %%
show_cliques(G_vanlig)
# Out:
# (3, 1) fjordutsikt, vedovn, spiseplass, utgang, peis, karnapp, parafinovn, utg., laminat, soverom, utsikt, terrasse, veranda, bad, Peis, sjøutsikt, garasje, panoramautsikt, parkett, hage, heis, garasjeplass, kjøkken, stuen, stue, bod, pels, takterrasse, Heis, balkong, carport, flott
#
# (4, 1) hagen, terrassen, stuen, balkongen
#
# (3, 2) kjøkkenet, stuen, stua, Stuen, soverommet, badet, spisestuen
#
# (4, 2) balkong, vedovn, kjøkken, stuen
#
# (3, 3) balkongen, verandaen, terrassen, stuen, hagen

# %% [markdown]
# ## Fyll inn andre stedsnavn

# %%
G2 = nb.make_graph('Peking', cutoff = 10)

# %%
gnl.show_graph(G2, spread = 1.4, fontsize=12)

# %% [markdown]
# ## Clustre

# %%
gnl.show_community(G2)
# Out:
# 1 Saigon, Vietcong, Hanoi, Haiphong, FNL, Bangkok
#
# 2 Macao, Beijing, Hongkong, Singapore, Japan, Nanking, Taipei, Kina, Taiwan, Shanghai
#
# 3 Tokyo, Tokio, Seoul, Osaka, Hong, Pyongyang, Yokohama
#
# 4 London, Bonn, Paris, Oregon, Washington, York, New
#
# 5 Delhi, Praha, Moskva, Taipeh, Peking, Leningrad
#
# 6 Kreml, Pentagon, Vatikanet
#
# 7 Tientsin, Peiping
# True

# %% [markdown]
# ## Klikker

# %%
show_cliques(G2)
# Out:
# (3, 1) Saigon, Kreml, London, Beijing, Hongkong, Tientsin, Pyongyang, Shanghai, Tokyo, Hanoi, Bonn, Tokio, Paris, Singapore, Moskva, Nanking, Peking, Washington
#
# (4, 1) Peking, Tokio, Hongkong, Shanghai
#
# (4, 2) Hanoi, Tokio, Moskva, Peking, Washington

# %% [markdown]
# # Relaterte ord
#
# kommandoen finner lignende ord

# %%
nb.relaterte_ord('Tønsberg')
# Out:
# ['Tønsberg',
#  'Sandefjord',
#  'omegn',
#  'Omegns',
#  'Horten',
#  'Omegn',
#  'Skien',
#  'Oplands',
#  'Larvik',
#  'Drammen',
#  'Fredrikstad',
#  'omegns',
#  'Holmestrand',
#  'Stokke',
#  'Moss',
#  'Nøtterøy',
#  'hjv',
#  'Vestfold',
#  'Omland',
#  'omland']

# %%
nb.relaterte_ord('Bergen')
# Out:
# ['Bergen',
#  'omegn',
#  'Omegn',
#  'omland',
#  'mellemsteder',
#  'Omland',
#  'mellemst',
#  'mellomsteder',
#  'Trondheim',
#  'Kristiansand',
#  'Stavanger',
#  'Ålesund',
#  'Hordaland',
#  'Hardanger',
#  'Nordhordland',
#  'Haugesund',
#  'Voss',
#  'Mell',
#  'Tromsø',
#  'Kirkenes']

# %%
nb.relaterte_ord('kjøkkenet')
# Out:
# ['spiste',
#  'drakk',
#  'kjøkkenet',
#  'soverommet',
#  'badet',
#  'lager',
#  'stua',
#  'koste',
#  'stekte',
#  'restauranten',
#  'vaskerommet',
#  'spisestuen',
#  'bakte',
#  'spisesalen',
#  'hentet',
#  'koke',
#  'lage',
#  'stuen',
#  'sov',
#  'røkte']

# %% [markdown]
# # Bøker og aviser

# %% [markdown]
# ## Korpus som en samling referanser til bøker, ikke selve bøkene
#
# Hvordan bygge korpus avhenger av materialtypen, bøker, tidsskrift eller aviser. Bøker har rike metadata, og inngår i verksdefinisjoner, mens aviser har en rikere tidsakse, fra dag til dag.

# %%
korpus = nb.book_corpus(words=['Tyskland'], period = (1980, 2000), limit = 200)
korpus
# Out:
#                urn                  author  \
# 0    2010121405062       Andersen, Øystein
# 1    2014071007099  Johansen, Øystein Kock
# 2    2012070308040          Spidsø, Tor K.
# 3    2016033108075     Amundsen, Eva Nesse
# 4    2007082101074       Chretien, Leonard
# ..             ...                     ...
# 195  2010071508125      Brekke, Kari-Mette
# 196  2010083108003            Osland, Erna
# 197  2013091205006             Korbøl, Aud
# 198  2013121108010         Bjørneboe, Jens
# 199  2015062408142
#
#                                                  title  year
# 0                 GIS - geografisk informasjons-system  1992
# 1                                       Bronse og makt  2000
# 2    E6 Korsegården-Vassum, Oslofjordforbindelsen V...  1994
# 3                                Dans i undervisningen  1983
# 4                                       Jehovas vitner  1990
# ..                                                 ...   ...
# 195                                     Resepsjonslære  1995
# 196                                       Bruke havet-  1990
# 197                                   Pell'ongen og je  1989
# 198                            Under en hårdere himmel  1982
# 199         Årbok for Haram kultur-historiske lag 1999  1999
#
# [200 rows x 4 columns]

# %% [markdown]
# # Konkordanser

# %%
nb.concordance('Trøndelag', 
    before = 10,
    after = 10,
    corpus = 'bok', # bytt ut med avis for å se i aviser
    size = 5)
# Out:
# <table><tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014081906028?searchText=Trøndelag' target='_'>Steen-Hansen, Anne Elise,Vurdering av feie- og tilsynstjenesten i Norge,2009</a></td><td>med utrykning til en sotbrann er innhentet fra brannvesenene i</td><td>Trøndelag</td><td style='text-align:left'>, Skien og Tromsø / 24 / . Det er</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014081906028?searchText=Trøndelag' target='_'>Steen-Hansen, Anne Elise,Vurdering av feie- og tilsynstjenesten i Norge,2009</a></td><td>høyest vedforbruk er Hedmark og Oppland , med</td><td>Trøndelag</td><td style='text-align:left'>som nummer tre på listen . Nord- Trøndelag er det</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014081906028?searchText=Trøndelag' target='_'>Steen-Hansen, Anne Elise,Vurdering av feie- og tilsynstjenesten i Norge,2009</a></td><td>, med Trøndelag som nummer tre på listen . Nord-</td><td>Trøndelag</td><td style='text-align:left'>er det fylket med høyest antall sotbranner per 10 000</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014081906028?searchText=Trøndelag' target='_'>Steen-Hansen, Anne Elise,Vurdering av feie- og tilsynstjenesten i Norge,2009</a></td><td>724 / Personlig kommunikasjon med Ole Ludvigsen , leder beredskap</td><td>Trøndelag</td><td style='text-align:left'>brann- og redningstjeneste , Per Ole Sivertsen , Avdelingsleder varslingsavdelingen</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014081108063?searchText=Trøndelag' target='_'>,Sosialt arbeid,1997</a></td><td>analysis of the distribution of services for the elderly in</td><td>Trøndelag</td><td style='text-align:left'>. I began the work in the middle of 1981</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014081108063?searchText=Trøndelag' target='_'>,Sosialt arbeid,1997</a></td><td>Effects of Funding Restraint in the Home Help Services in</td><td>Trøndelag</td><td style='text-align:left'>1980 - 83.</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016031148054?searchText=Trøndelag' target='_'>,Havn og handel i 1000 år,2000</a></td><td>fenomen fbrekommer aven på andra platser i Skandinavien . I</td><td>Trøndelag</td><td style='text-align:left'>i mellersta Norge , har man iakttagit en liknande relation</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016031148054?searchText=Trøndelag' target='_'>,Havn og handel i 1000 år,2000</a></td><td>enskilt hushåll att skapa och vidmakthålla kontakter med omvårlden? I</td><td>Trøndelag</td><td style='text-align:left'>, Norge har undersokningar gjorts som styrker denna fråga ,</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016031148054?searchText=Trøndelag' target='_'>,Havn og handel i 1000 år,2000</a></td><td>qua jarlesete står frem som et regionalt sosiopolitisk maktsentrum i</td><td>Trøndelag</td><td style='text-align:left'>som var avhengig av betydelige ressurstilgangerfor å kunne opprettholde og</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016031148054?searchText=Trøndelag' target='_'>,Havn og handel i 1000 år,2000</a></td><td>. Det økonomiske grunnlaget for reproduksjonen av jarleættens maktposisjon i</td><td>Trøndelag</td><td style='text-align:left'>har vært gaveutveksling og en sosialt betinget frikostighet , noe</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016031148054?searchText=Trøndelag' target='_'>,Havn og handel i 1000 år,2000</a></td><td>Trondheim og</td><td>Trøndelag</td><td style='text-align:left'>spela truleg ... ei viktig rolle i denne sørgåande skinntransporten»</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013022506019?searchText=Trøndelag' target='_'>Damhaug, Torkil,Se meg, Medusa,2009</a></td><td>oppe , er den skremt helt opp i Valdres eller</td><td>Trøndelag</td><td style='text-align:left'>. Du vet vel hvor mange mil en sånn brunbjørn</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015041408063?searchText=Trøndelag' target='_'>Kongsrud, Helge,Det norske kanslerembetet,2011</a></td><td>gjeld , og dels atkomstdokumenter på tidlige re Bjelke-gods i</td><td>Trøndelag</td><td style='text-align:left'>, nemlig Østråt og Tøndel ( Tønnøl ) , 83</td></tr>
# </table>

# %%
nb.concordance(
    'Paris', 
    before = 10,
    after = 10,
    title = 'stavanger%',
    corpus = 'avis', # bytt ut med avis for å se i aviser
    yearfrom = 1990,
    yearto = 2000,
    size = 5)
# Out:
# <table><tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19900104_98_3_1?searchText=Paris' target='_'>stavangeraftenblad-19900104</a></td><td>blant annet Air France og selskapets rute fra Stavanger til</td><td>Paris</td><td style='text-align:left'>, sier Arne Helvik . Chartertrafikken over Sola er den</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19900104_98_3_1?searchText=Paris' target='_'>stavangeraftenblad-19900104</a></td><td>Odd Arild Olsen . Marlene Dietrich utnevnt kommandør av Æreslegionen</td><td>Paris</td><td style='text-align:left'>( NTB-Reuter ) : Marlene Dietrich , den legendariske tyskfødte</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19900104_98_3_1?searchText=Paris' target='_'>stavangeraftenblad-19900104</a></td><td>tilbaketrukket i en leilighet i nærheten av Champs Elysees i</td><td>Paris</td><td style='text-align:left'>, selv om hun ble amerikansk statsborger i 1937. Hun</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19900104_98_3_1?searchText=Paris' target='_'>stavangeraftenblad-19900104</a></td><td>09.30 Eurosport Menu . 10.00 Wolleyball World Cup . 11.00</td><td>Paris</td><td style='text-align:left'>- Dakar Rally . 12.00 Indoor Handball . 13.00 Skiiumping</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19900104_98_3_1?searchText=Paris' target='_'>stavangeraftenblad-19900104</a></td><td>. 19.30 Surfer Magazine . 20.00 Indoor Handball . 21.00</td><td>Paris</td><td style='text-align:left'>- Dakar Rally . 22.00 Best of the Year .</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19910409_99_80_1?searchText=Paris' target='_'>stavangeraftenblad-19910409</a></td><td>de legendariske « Bluebell jentene » i Folies Bergere i</td><td>Paris</td><td style='text-align:left'>. ( 4 : 8 ) . Stavanger Aftenblad ■</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19910415_99_85_1?searchText=Paris' target='_'>stavangeraftenblad-19910415</a></td><td>ha samtaler med dets ledere . Han skal også besøke</td><td>Paris</td><td style='text-align:left'>for å møte franske toppolitikere og inspisere anleggene for •</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19910415_99_85_1?searchText=Paris' target='_'>stavangeraftenblad-19910415</a></td><td>- tallet etter mønster f ra Hayters Atelier 17 i</td><td>Paris</td><td style='text-align:left'>. Det ble snart et internasjonalt samlingssted for kunstnere som</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19910415_99_85_1?searchText=Paris' target='_'>stavangeraftenblad-19910415</a></td><td>. 2,526 .1 - 0.8 Frankfurt , FAZ 672.5 0.1</td><td>Paris</td><td style='text-align:left'>, C AC . 1,821 .4 - 1.6 Milano 594.2</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19910415_99_85_1?searchText=Paris' target='_'>stavangeraftenblad-19910415</a></td><td>S / A ble stiftet i 1958 med hovedkontor i</td><td>Paris</td><td style='text-align:left'>. Firmaet begynte med geologisk / syntetiske studier , foto</td></tr>
# </table>

# %% [markdown]
# # Stedsnavn i bøker

# %% [markdown]
# Lager oss en samling ord å sammenligne med. Henter ned alt fra bokhylla, eller bøker i nettbiblioteket. Basert på 450 000 bøker.

# %%
tot = nb.frame(nb.totals(150000), "tot")
nb.normalize_corpus_dataframe(tot)
# Out:
# True

# %% [markdown]
# Deretter spør vi etter

# %%
coll2 = nb.urn_coll('Tyskland', urns= list(korpus.urn))

# %%
nb.normalize_corpus_dataframe(coll2)
# Out:
# True

# %%
diff2 = nb.frame(coll2[0]**1.5/tot.tot).sort_values(by = 0, ascending = False)

# %%
d2 = nb.frame(diff2[0].loc[[x for x in diff2.index if x.isalpha()]])

# %% [markdown]
# Se på de ordene som skiller seg mest, som frekvensliste eller ordsky

# %%
d2.head(20)
# Out:
#                               0
# Siemens               65.433266
# konsentrasjonsleire   20.691508
# gjenforent            14.968847
# tukthus               12.649575
# Frankrike             12.270621
# Austerrike            12.023337
# Mayer                 10.582127
# nasjonalsosialismen   10.397227
# Forbundsrepublikken    9.495732
# Picture                9.194475
# Østerrike              8.895680
# Lic                    8.805296
# Jemen                  8.707853
# Klein                  8.412404
# benådet                7.782950
# Nederland              7.148797
# Bayern                 6.823817
# AEG                    6.460511
# konsentrasjonsleirer   6.451981
# AG                     6.206444

# %%
nb.cloud(d2.head(100)/d2.head(100).sum(), stretch=4)

# %% [markdown]
# # Navn

# %%
books = nb.book_corpus(author ='hjort%vigdis%')

# %%
books
# Out:
#               urn          author                               title  year
# 0   2013092606085  Hjorth, Vigdis  Fordeler og ulemper ved å være til  2005
# 1   2013121105028  Hjorth, Vigdis               På hjørnet om kvelden  1987
# 2   2009052704021  Hjorth, Vigdis               Jørgen + Anne er sant  2003
# 3   2014030506013  Hjorth, Vigdis                        Sandnes City  2010
# 4   2016070708033  Hjorth, Vigdis                             Om bare  2002
# 5   2007081504030  Hjorth, Vigdis               Med hånden på hjertet  1989
# 6   2011040808036  Hjorth, Vigdis                  17.15 til Tønsberg  2003
# 7   2015050408036  Hjorth, Vigdis               Jørgen + Anne er sant  1994
# 8   2013092606078  Hjorth, Vigdis               Jørgen + Anne er sant  2012
# 9   2011032508155  Hjorth, Vigdis                  17.15 til Tønsberg  2004
# 10  2008030300078  Hjorth, Vigdis                         Død sheriff  1995
# 11  2013031106003  Hjorth, Vigdis                Tredje person entall  2008
# 12  2013112706033  Hjorth, Vigdis                             Om bare  2010
# 13  2013011506069  Hjorth, Vigdis                             Om bare  2009
# 14  2008111100138  Hjorth, Vigdis                             Om bare  2001
# 15  2008090204060  Hjorth, Vigdis                       første gangen  1999
# 16  2009051404036  Hjorth, Vigdis                     dikt til mormor  1990
# 17  2014051306007  Hjorth, Vigdis                Tredje person entall  2009
# 18  2013102905069  Hjorth, Vigdis               Jørgen + Anne er sant  2009
# 19  2007111904047  Hjorth, Vigdis               Med hånden på hjertet  1991

# %%
book = 2007111904047

# %%
F = nb.navn(book)

# %%
Removals = nb.spurious_names(300)

# %%
Removals = Removals + ['Hvem', 'Hva', 'Hvorfor', 'Hei', 'Okay']

# %%
Fn = nb.check_navn(F, remove=Removals)

# %%
Fg = nb.make_network_graph(book, Fn)

# %%
print(nb.metadata(book))
# Out:
# [[2007111904047, 'Hjorth, Vigdis', 1991, 'Med hånden på hjertet', '', 'Cappelen', 'fiction', '8eee52ff2a6408575108e324f3b19bc0', 'nob', '']]

# %%
gnl.show_graph(Fg, spread=1.5, fontsize=12)

# %% [markdown]
# # Clustring av navn

# %%
gnl.show_communities(Fg)
# Out:
# Fr-Johan :  Fr, Johan, Hanna, Norges, Helle, Pauli, Spania, Finnmark, Afrika, Cort, Paulis, Glem, Brun, Saludos
#
# Ambj-Ingvar :  Ambj, Ingvar
#
# Lars-Sverre :  Lars, Sverre, Saabye, Christensen
#
# Nei-Merete :  Nei, Merete, Sk, Ellen, Rikard, Ola, Breivik, Marianne, Unnskyld, Neida, Anne, Sartre, Rikards
#
# Ragnar-Harald :  Ragnar, Harald, Ekre, Gud, Ekres, Hatleberg, Haug, Ragnars, Bryggen, Stud, Eirin, Helleveien, Vest, Vang, Petter, Sinatra, Jaa, Hjelp, John, Dagens, Augustin, Hm
#
# Ave-Frankrike :  Ave, Frankrike, Maria
#
# B-blokken-Sangria :  B-blokken, Sangria, Lennons
#
# Tove-Trosvik :  Tove, Trosvik, Kristine, Bech
#
# Fredrik-Trond :  Fredrik, Trond, Bergen, Fredriks, Nyg, Bergens, Kors, Nietzsche, Bj, Ingenting, St, Torill, Vik, Ellens
#
# Ella-Primavera :  Ella, Primavera
#
# Vigdis-Roy :  Vigdis, Roy, Hjorth, Jacobsen

# %% [markdown]
# # Analyse av enkeltbok

# %%
nb.plot_book_wordbags(book, gnl.community_dict(Fg)).plot(figsize=(15,8), lw=3, alpha=0.5);

# %% [markdown]
# # Nettverksstruktur

# %%
nb.cloud(nb.frame(dict(nb.central_betweenness_characters(Fg, 80))), stretch=3);

# %% [markdown]
# # Agnar Mykle, Sangen om den Røde Rubin

# %%
nb.book_corpus(author = 'Mykle%', title = 'sang%', period = (1955, 2010))
# Out:
#              urn        author                     title  year
# 0  2009011504069  Mykle, Agnar  Sangen om den røde rubin  2000
# 1  2008100104083  Mykle, Agnar  Sangen om den røde rubin  1998
# 2  2008021104029  Mykle, Agnar  Sangen om den røde rubin  1995
# 3  2015090129001  Mykle, Agnar  Sangen om den røde rubin  1956
# 4  2009033100094  Mykle, Agnar  Sangen om den røde rubin  2002
# 5  2008021404040  Mykle, Agnar  Sangen om den røde rubin  1995
# 6  2007052404016  Mykle, Agnar  Sangen om den røde rubin  1967
# 7  2008111304085  Mykle, Agnar  Sangen om den røde rubin  2001
# 8  2016020808126  Mykle, Agnar  Sangen om den røde rubin  2000

# %%
navn = nb.navn('2016020808126')

# %%
navn = nb.check_navn(navn, limit=10)

# %%
navn
# Out:
# {'Abrahamsen': 22,
#  'Ask': 874,
#  'Burlefot': 23,
#  'Constance': 63,
#  'Daniel': 121,
#  'Daniels': 11,
#  'Doffen': 105,
#  'Du': 92,
#  'Eirik': 46,
#  'Embla': 84,
#  'Er': 35,
#  'Fiffolo': 41,
#  'Floden': 32,
#  'Francis': 29,
#  'Frankrike': 18,
#  'Gud': 88,
#  'Guds': 13,
#  'Gunnhild': 19,
#  'Har': 26,
#  'Hitler': 15,
#  'Hm': 18,
#  'Maia': 18,
#  'Marx': 12,
#  'Molly': 36,
#  'Norge': 39,
#  'Oslo': 13,
#  'Poppi': 22,
#  'Robert': 68,
#  'Sosialistisk': 26,
#  'Stabell': 35,
#  'Stallen': 33,
#  'Studentersamfunnet': 16,
#  'Studentlag': 24,
#  'Synnøve': 11,
#  'Takk': 15,
#  'Taraldsen': 20,
#  'Tyskland': 25,
#  'Vil': 15,
#  'Villsvinsen': 25,
#  'Wilhelmine': 44,
#  'Wolfgang': 28,
#  'Økonomiske': 44}

# %%
G = nb.make_network(2016020808126, navn)

# %%
gnl.show_graph(G)

# %%
gnl.show_communities(G)
# Out:
# Norge-Constance :  Norge, Constance, Daniel, Wilhelmine, Er, Tyskland, Molly, Hitler, Vil, Abrahamsen, Hm, Daniels, Takk
#
# Ask-Gud :  Ask, Gud, Fiffolo, Doffen, Wolfgang, Poppi, Robert, Du, Har, Maia, Taraldsen, Guds, Frankrike, Villsvinsen
#
# Eirik-Økonomiske :  Eirik, Økonomiske, Embla, Floden, Burlefot, Sosialistisk, Studentlag, Synnøve, Stallen, Gunnhild, Marx
#
# Stabell-Francis :  Stabell, Francis, Oslo, Studentersamfunnet

# %% [markdown]
# ## Development of clusters

# %%
nb.plot_book_wordbags(2016020808126, gnl.community_dict(G)).plot(figsize=(15,6), lw=3, alpha=0.5);
