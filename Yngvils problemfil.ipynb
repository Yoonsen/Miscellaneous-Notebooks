# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Using cached https://files.pythonhosted.org/packages/b4/01/68fcc0d43daf4c6bdbc6b33cc3f77bda531c86b174cac56ef0ffdb96faab/PyPDF2-1.26.0.tar.gz
# Building wheels for collected packages: PyPDF2
#   Running setup.py bdist_wheel for PyPDF2: started
#   Running setup.py bdist_wheel for PyPDF2: finished with status 'done'
#   Stored in directory: C:\Users\yngvilb\AppData\Local\pip\Cache\wheels\53\84\19\35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built PyPDF2
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-1.26.0

# %%
import PyPDF2 as PyP

# %%
from PyPDF2 import PdfFileReader

# %%
def get_info(path):
    with open(path, 'rb') as f:
        pdf = PdfFileReader(f)
        info = pdf.getDocumentInfo()
        number_of_pages = pdf.getNumPages()
    print(number_of_pages)


def get_text_from_pdf(path):
    text = ""
    with open(path, 'rb') as f:
        pdf = PdfFileReader(f)
        number_of_pages = pdf.getNumPages()
        for p in range(number_of_pages):
            page = pdf.getPage(p)
            text += page.extractText()
    return text

def files(path):
    import os
    r, d, f = next(os.walk(path))
    pdfer = [file for file in f if file.endswith('.pdf')]
    return pdfer

def get_text_from_word(document):
    """Find all text in a Word document"""
    import sys
    import zipfile
    import re
    from bs4 import BeautifulSoup
    
    with zipfile.ZipFile(document, 'r') as zfp:
        with zfp.open('word/document.xml') as fp:
            soup = BeautifulSoup(fp.read(), 'xml')
    return soup.get_text()

# %%
files("..")
# Out:
# ['avbestilling_KARI_STENSRUD.pdf',
#  'Booking.com_ Wroclaw.pdf',
#  'dhn2019-tutorial.pdf',
#  'Dok1.pdf',
#  'Dok2.pdf',
#  'Lars G. Johnsen-uri-jensen.pdf',
#  'Lånekassen Filip USA.pdf',
#  'Lønnsforhandlingsskjema-Lars_Johnsen.pdf',
#  'Probability for semantics.pdf',
#  'Saksnummer 2018-94310.pdf',
#  'Semantikk semesteroppgaver 2018.pdf',
#  'Semantikk semesteroppgaver 2018a.pdf',
#  'Skatteetaten saksnummer 2018-94310.pdf',
#  'Skatteetaten saksnummer 2018.pdf',
#  'Skatteseddel_eiendom_212_129_0_7 (2).pdf',
#  'Timofeij Schwarte - NOLISP350.pdf',
#  'Timofeij Schwarte kommentarer - NOLISP350.pdf']

# %% [markdown]
#  gswin32c.exe ^
#   -o repaired.pdf ^
#   -sDEVICE=pdfwrite ^
#   -dPDFSETTINGS=/prepress ^
#    corrupted.pdf
#
#
#     print(pageObj.extractText())

# %%
get_text_from_pdf("../Semantikk semesteroppgaver 2018.pdf")
# Out:
# 'Candidate \nno.\n \n101\n \nTask 4: Language and Ambiguity\n \nPage \n1\n \nof \n11\n \nAmbiguity\n \nInnhold\n \nIntroduction\n \n................................\n................................\n................................\n...........................\n \n2\n \nThe types of ambiguity\n \n................................\n................................\n................................\n..........\n \n2\n \nCompositional ambiguity\n \n................................\n................................\n................................\n...\n \n2\n \nLexical ambiguity\n \n................................\n................................\n................................\n...............\n \n2\n \nThe subcategories of lexical ambiguity\n \n................................\n................................\n...........\n \n3\n \nContextual ambi\nguity\n \n................................\n................................\n................................\n.........\n \n4\n \nSyntax and ambiguity\n \n................................\n................................\n................................\n............\n \n5\n \nPragmatics and ambiguity\n \n................................\n................................\n................................\n.....\n \n7\n \nLexical ambiguity and conversation efficiency\n \n................................\n................................\n.......\n \n8\n \nConclusion\n \n................................\n................................\n................................\n..........................\n \n10\n \nReferences\n \n................................\n................................\n................................\n.........................\n \n11\n \n \n \n \n \nPage \n2\n \nof \n11\n \n \n \nIntroduction\n \n\ntelescope? Did I see him on a hill and he had a telescope with him? Was there a \nman on a \nhill where a telescope was placed as well? This sentence is an example of ambiguity, or \nrather, more specifically, syntactic ambiguity, where one cannot for certain determine where \n\ne will look at the different \ntypes of ambiguity, how various fields of linguistics interact with ambiguity, and discuss it as \na conscious and subconscious tool in language.\n \n \nThe types of ambiguity\n \nCompositional ambiguity\n \nLet us first discuss the types of \nambiguit\ny\n, as we have already begun a bit above. The first \nsentence in this essay \n\n \n\n\n \ncan, as beforementioned \nbe interpreted in many ways. \nA listener or reader to this phrase cannot by the phrase itself \ndetermine wh\n\ncompositional ambiguity\n \nbecause it occurs on a level of composition, i.e. it occurs with a \nphrase composed of multiple words.\n \n(Löbner, Understanding Semantics 2013, 48\n-\n49)\n \nFurther, it can as mentioned in the introduction, be specified as a syntactic ambiguity, as \nthe \nambiguity occurs when we are trying to find \none\n \nphrase with which to attach the \n\nbe attached to only one other phrase; it fits \ninto multiple, and therefore the reader or listener cannot be sure how the telescope fits in. \n \nLexical ambiguity\n \nAt the smaller, more isolated level, we find lexical ambiguity. This ambiguity occurs \n\n \nas the \nna\nme would suggest \n\n \nat the lexical (or more informally, the word) level. An example of this \n\n(Davis n.d.)\n \nAccording to Davis, \n\nbe a flying mammal, or a (usually) wooden\n \n\n\n \nPage \n3\n \nof \n11\n \n \nutterance, we cannot determine which of the lexemes were intended by the writer/speaker.\n \nThere are of course mult\niple types of lexical ambiguity, for instance, in the above sentence, \n\nThis is called\n \ntotal\n \n\nthey h\n\n(Löbner, \nUnderstanding Semantics 2013, 45)\n \n\nalso has two possible lexemes in the sentence, but these two lexemes are not homonymous \n\n\n\ntwo lexemes are partially homonymous. Löbner defines two lexemes as partially \n\n\n(Löbner, Understanding Semantics 2013, 45)\n. While the term ...

# %%
get_text_from_word()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-a77f02f24f5e> in <module>
# ----> 1 get_text_from_word()
#
# TypeError: get_text_from_word() missing 1 required positional argument: 'document'

# %%
from PyPDF2 import PdfFileReader
 
 
def text_extractor(path):
    with open(path, 'rb') as f:
        pdf = PdfFileReader(f)
 
        # get the first page
        page = pdf.getPage(1)
        print(page)
        #print('Page type: {}'.format(str(type(page))))
 
        #text = page.extractText()
        #print(text)

# %%
text_extractor("../Semantikk semesteroppgaver 2018.pdf")
