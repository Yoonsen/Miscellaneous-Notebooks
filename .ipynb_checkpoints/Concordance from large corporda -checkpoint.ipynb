# %% [markdown]
# ### Illustrasjon av "refine_book_urn"
#
#
# Her er det litt kode som illustrerer konkordans med refine.

# %%
import dhlab.nbtext as nb

# %% [markdown]
# Hent ut et stor sett URN-er, for eksempel de rundt 30 000 som er for nynorsk.

# %%
nynorsk = nb.book_urn(lang = 'nno', limit = 50000)

# %%
len(nynorsk)
# Out:
# 32291

# %% [markdown]
# Før _nb.urn_concordance_ påkalles, kjøres først en refine - her kan det være greit å først sjekke størrelsen på korpuset, er det over en 50 URN-er, kan det være greit å kjøre refine.
#
# Lister over URN-er sendes frem og tilbake. Ideen her er å sende en stor liste for å få en liten liste tilbake som det så søkes i. Refine kalles med søkeordet så alle URNene som kommer tilbake er garantert å ha søkeordet i seg.
#
# Med refine er det forholdsvis enkelt å implementere en OG-logikk i korpusbyggingen, men det er flerer måter å gjøre det på, snitt av urn-lister for eksempel.
#
# Antallet treff og antallet urner påvirker responstid. For et kjapt resultat (under 3 sek) hold dem små. Jo fler URNer, jo mer treff, ditto for size.

# %%
def refine_konk(word, corpus_urns, urnlimit = 10, hits_pr_db = 5):
    
    # limit bestemmer hvor mange bøker det skal tas konk fra, den samples fra listen
    # så konk kan kjøres flerer ganger for å få fullstendige treff. Refine tar også flere parametre
    # som ddk, subject osv., samme som nb.book_urn (tror jeg).
    
    refine = nb.refine_book_urn(words = [word], urns =  corpus_urns, limit = urnlimit)

    # size sier hvor mange konk som skal hentes fra hver db (i praksis blir det ofte at en bok dominerer for små tall) 
    # - så litt shaky parameter
    
    return nb.urn_concordance(word= word, urns = refine, size = hits_pr_db)

# %%
# %%time
refine_konk('medan', nynorsk) # flere kjøringer gir forskjellige resultat - i og med at det samples
# Out:
# Wall time: 2.42 s
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008071604083?searchText=medan' target='_blank' style='text-decoration:none'>Is, stein, bronse, Karlsen, Rolf, 1974</a>
#                 </td>
#                 <td>Da måtte slik mat etast</td>
#                 <td>medan</td>
#                 <td style='text-align:left'>han var fersk . Derfor</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010021700085?searchText=medan' target='_blank' style='text-decoration:none'>Økologi og marknad, Brendehaug, Eivind, 2000</a>
#                 </td>
#                 <td>til 20 liter ) ,</td>
#                 <td>medan</td>
#                 <td style='text-align:left'>Dalsgården berre vert levert i</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010021700085?searchText=medan' target='_blank' style='text-decoration:none'>Økologi og marknad, Brendehaug, Eivind, 2000</a>
#                 </td>
#                 <td>sau med 67 prosent ,</td>
#                 <td>medan</td>
#                 <td style='text-align:left'>tilførsla av storfekjøt auka med</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010021700085?searchText=medan' target='_blank' style='text-decoration:none'>Økologi og marknad, Brendehaug, Eivind, 2000</a>
#                 </td>
#                 <td>5,0 tonn i 1998 ,</td>
#                 <td>medan</td>
#                 <td style='text-align:left'>salet av økolam gjekk ned</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010021700085?searchText=medan' target='_blank' style='text-decoration:none'>Økologi og marknad, Brendehaug, Eivind, 2000</a>
#                 </td>
#                 <td>på dei edle kjøtkvalitetane ,</td>
#                 <td>medan</td>
#                 <td style='text-align:left'>farsekjøtet , som står for</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010021700085?searchText=medan' target='_blank' style='text-decoration:none'>Økologi og marknad, Brendehaug, Eivind, 2000</a>
#                 </td>
#                 <td>kjøt kan auke totalomsetninga ,</td>
#                 <td>medan</td>
#                 <td style='text-align:left'>dei tre andre er opne</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009103000127?searchText=medan' target='_blank' style='text-decoration:none'>Frå det gamle arbeidslivet, Hellemo, Lars, 1957</a>
#                 </td>
#                 <td>. Dei tykte dei kvilde</td>
#                 <td>medan</td>
#                 <td style='text-align:left'>dei gjekk attende og henta</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009103000127?searchText=medan' target='_blank' style='text-decoration:none'>Frå det gamle arbeidslivet, Hellemo, Lars, 1957</a>
#                 </td>
#                 <td>ut på pissoaren , og</td>
#                 <td>medan</td>
#                 <td style='text-align:left'>han var ute , hadde</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009103000127?searchText=medan' target='_blank' style='text-decoration:none'>Frå det gamle arbeidslivet, Hellemo, Lars, 1957</a>
#                 </td>
#                 <td>det vart inga prating av</td>
#                 <td>medan</td>
#                 <td style='text-align:left'>arbeidet stod på .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009103000127?searchText=medan' target='_blank' style='text-decoration:none'>Frå det gamle arbeidslivet, Hellemo, Lars, 1957</a>
#                 </td>
#                 <td>oppe om morgonen og slå</td>
#                 <td>medan</td>
#                 <td style='text-align:left'>det var dogg . Dei</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009103000127?searchText=medan' target='_blank' style='text-decoration:none'>Frå det gamle arbeidslivet, Hellemo, Lars, 1957</a>
#                 </td>
#                 <td>på Sør- og Vestlandet ,</td>
#                 <td>medan</td>
#                 <td style='text-align:left'>det på</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008040300072?searchText=medan' target='_blank' style='text-decoration:none'>Fridtjov og Ingebjørg, Hoprekstad, Olav, 1912</a>
#                 </td>
#                 <td>styra med rike vaart ,</td>
#                 <td>medan</td>
#                 <td style='text-align:left'>me er burte .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008040300072?searchText=medan' target='_blank' style='text-decoration:none'>Fridtjov og Ingebjørg, Hoprekstad, Olav, 1912</a>
#                 </td>
#                 <td>og bu her i Baldershagen</td>
#                 <td>medan</td>
#                 <td style='text-align:left'>me er burte .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008040300072?searchText=medan' target='_blank' style='text-decoration:none'>Fridtjov og Ingebjørg, Hoprekstad, Olav, 1912</a>
#                 </td>
#                 <td>og svei * nane hans</td>
#                 <td>medan</td>
#                 <td style='text-align:left'>me er burte .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008040300072?searchText=medan' target='_blank' style='text-decoration:none'>Fridtjov og Ingebjørg, Hoprekstad, Olav, 1912</a>
#                 </td>
#                 <td>fara fraa Bal * dershagen</td>
#                 <td>medan</td>
#                 <td style='text-align:left'>de er burte .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008040300072?searchText=medan' target='_blank' style='text-decoration:none'>Fridtjov og Ingebjørg, Hoprekstad, Olav, 1912</a>
#                 </td>
#                 <td>hev lagt i mine hender</td>
#                 <td>medan</td>
#                 <td style='text-align:left'>dei er burte , byd</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012112908197?searchText=medan' target='_blank' style='text-decoration:none'>Informasjon om elektromagnetiske felt og helserisiko, Hannevik, Merete, 2000</a>
#                 </td>
#                 <td>kraftleidningane kjenst påtvinga utanfrå ,</td>
#                 <td>medan</td>
#                 <td style='text-align:left'>bruk av elektriske apparat er</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012112908197?searchText=medan' target='_blank' style='text-decoration:none'>Informasjon om elektromagnetiske felt og helserisiko, Hannevik, Merete, 2000</a>
#                 </td>
#                 <td>økt kjensle av utryggleik ,</td>
#                 <td>medan</td>
#                 <td style='text-align:left'>det som oftast er tenkt</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012112908197?searchText=medan' target='_blank' style='text-decoration:none'>Informasjon om elektromagnetiske felt og helserisiko, Hannevik, Merete, 2000</a>
#                 </td>
#                 <td>vitskaplege tolking av kunnskapen ,</td>
#                 <td>medan</td>
#                 <td style='text-ali
